# %%
#Membaut connection terhadap database
import sqlite3
from sqlite3 import Error
db_file = 'DBnews.db'
conn = None
try:
    conn = sqlite3.connect(db_file)
except Error as e:
    print(e)

# %%
#Mengambil comments dari database
comments = []
cur = conn.cursor()
cur.execute("SELECT * from t_comments")
rows = cur.fetchall()
for row in rows:
    comments.append(row)

# %%
comments
# Out:
# [('4207096',
#   'WKWKWK, GAK SEKALIAN PAK, SELAWAT KE DPR... KAN BANYAK KORUPTOR DISANA',
#   -1,
#   None,
#   1),
#  ('4207096',
#   'Mantab.. ini br dakwah yg sejati.. kl d tempat umum mah dh biasa . Ini luar biasa.�',
#   1,
#   None,
#   2),
#  ('4207096', 'Salut buat Gus Miftah', 1, None, 3),
#  ('4207096',
#   'yg nyinyir gak pernah lihat dan baca atw mengetahui sejarah dakwah walisongo \\/ sunan kali jaga...smua ada cara demi kebaikan... asal jng ajk dg cara berjinah .... lakukan dg porsi dan sikon yg tepat',
#   1,
#   None,
#   4),
#  ('4207096',
#   'Ada adabnya sholawat. Lebih baik ajak ke majelis ilmu..',
#   1,
#   None,
#   5),
#  ('4207096',
#   'Setiap ulama punya jalan dan cara dakwah masing2.., jika kamu melihat kemunkaran lawan dengan tanganmu(kekuatanmu) jika tidak mampu lawan dengan mulutmu jika tidak mampu juga dengan hatimu itulah selemah lemahnya iman.., itu sudah menjadi kewajiban para ulama, kalo yg komen masih ada yg nyinyirin ulama berarti otaknya sudah disisipin politik..',
#   1,
#   None,
#   6),
#  ('4207096', 'Umpanin nocannya yak...', 0, None, 7),
#  ('4207096', 'Itulah ceramah yg sebenarnya. ', 0, None, 8),
#  ('4207096', 'Besok bugil aja selawat', -1, None, 9),
#  ('4207096',
#   'Bedanya Gus Miftah dengan FPI  / HTI bagaikan surga dan neraka. Di surga penuh kasih, di neraka penuh penghancuran.',
#   0,
#   None,
#   10),
#  ('4207096',
#   'Knp di tempat kerjanya? Mending diundang ke masjid, ponpes, aula. Supaya berbusana yg sopan.�',
#   0,
#   None,
#   11),
#  ('4207096',
#   'nah ini ulama beneran...diterima di semua kalangan.....kl UAS? malah diblokir sana sini',
#   1,
#   None,
#   12),
#  ('4207096',
#   'Kerennn.... saya pernah dpt info seperti ini dr keyakinan yg lain tapi tujuan utama kurang lebih sama lah. Kita ambil sisi positifnya ajah... Terimakasih atas niat baiknya... saya yakin pasti bermanfaat.',
#   1,
#   None,
#   13),
#  ('4207096',
#   'Hebat Gus.Lanjutkan!inilah makna dakwah sebenarnya, sampaikan marwah Islam dengan penuh kedamaian dan berikan pemahaman, bukan dengan kebencian dan pemaksaan',
#   1,
#   None,
#   14),
#  ('4207096', 'Diskotik syariah jadunya nih wkwkwk..mantap', None, None, 15),
#  ('4207096',
#   'Niat dan tujuan yg baik pasti mendapat berkah dr Allah SWT.',
#   None,
#   None,
#   16),
#  ('4207096',
#   'mantaaapppp..buat di gedung DPR perlu jg kayanya Gus',
#   None,
#   None,
#   17),
#  ('4207096', 'Salut buat owner klub ini.....', None, None, 18),
#  ('4207096', 'Josshhh ini baru luar biasa', None, None, 19),
#  ('4207096', 'dapat gratisan karena sudah punya nope', None, None, 20),
#  ('4207096',
#   'Sebaiknya dimanapun dilakukan batas2 kesopanan tetap harus dijaga...',
#   None,
#   None,
#   21),
#  ('4207096',
#   'Pemandu lagi yang di Manga Besar keknya perlu juga diajak mengaji, bos!',
#   None,
#   None,
#   22),
#  ('4207096',
#   'JUJUR INI KEREENNNNNNN CARA MENYEBARKAN AGAMA YANG BAIK DAN SNAGAT SIMPATIK SEMOGA SUKSES',
#   None,
#   None,
#   23),
#  ('4207096',
#   'katimbang alim kemudian jadi maling, menurut saya lebih baik maling kemudian jadi alim ....',
#   None,
#   None,
#   24),
#  ('4207096',
#   'sebenar ulama, mengajak mereka yg masih tersesat untuk kembali. bukan menjelekkan orang lain, tp merangkul mereka�',
#   None,
#   None,
#   25),
#  ('4207096', 'Ini namanya apa ya?', None, None, 26),
#  ('4207096',
#   'Selamat berjuang Gus,justru tempat seperti itu yg butuh lebih bnyk perhatian dr ulama.',
#   None,
#   None,
#   27),
#  ('4207096', 'Semoga diberikan hidayah..  ', None, None, 28),
#  ('4207096',
#   'hati hati memviralkan berita yang mengandung isu agama bisa menjadi sumber fitnah dan lahan para bedebah yang kerjanya mengadu domba anak bangsa dan rakyat indonesia Ahok sudah jadi korbannya',
#   None,
#   None,
#   29),
#  ('4207096',
#   'Subhanallah..... semoga mendapatkan hidayah dari Allah Swt. Amin......',
#   None,
#   None,
#   30),
#  ('4207096', 'ulama ngurus umat berarti jenengan Gus...', None, None, 31),
#  ('4207096',
#   'Luar biasa, salut...terharu, mengajak orang lain yang dianggap salah dengan cara yang baik, bukan dengan cacian...luar biasa..',
#   None,
#   None,
#   32),
#  ('4207096', "what's up boshe....", None, None, 33),
#  ('4206988',
#   'lol jadi ketahuan dong isinya boshe bali bukan org bali %uD83D%uDE02%uD83D%uDE02',
#   None,
#   None,
#   34),
#  ('4206988', 'Poligami aja guss', None, None, 35),
#  ('4206988', 'Harusnya dibakar tempat begituan kalik', None, None, 36),
#  ('4206988',
#   'Hahahaha,  bahasa hastag y kalo d plesetkan jadi y santri gaul itu yg suka sholawat dan suka dugem... Hahahaha rusak Islam d biaskan seperti ini, ustad y dateng k sono dugem dulu lalu sholawat lalu dugem lagi,  dan d sebut santri gaul.....????????? ',
#   None,
#   None,
#   37),
#  ('4206988',
#   'Knp yg kayak gini berita nya keluar nya pas mau pilpres aja ya...?',
#   None,
#   None,
#   38),
#  ('4206988',
#   'Naaaah ini baru bener, ceramah atau ngajak orang yg belum bersholawat utk bersholawat. Ga kaya somat, ngajak orang sholawat koq ke orang yg udah bersholawat. Maaaaat mat!!!!',
#   None,
#   None,
#   39),
#  ('4206988',
#   'gila nekat juga ulamanya gak tau di usir gitu,, tapi bagus lah ada keberanian dan semuanya jg mendengarkan.. semoga banyak ustad lainnya yang meniru hal ini. ',
#   None,
#   'GILA NEKAT JUGA ULAMANYA TIDAK TAHU DIUSIR BEGITU,, TAPI BAGUSLAH ADA KEBERANIAN DAN SEMUANYA JUGA MENDENGARKAN.. SEMOGA BANYAK ustaz LAIN YANG MENIRU HAL INI.',
#   40),
#  ('4206988',
#   'Tambah tempat... mantap sak cewek seksi nya....dan yg paling penting bole... yg g setuju pasti ngiri...week',
#   None,
#   None,
#   41),
#  ('4206988',
#   'Mengajak orang melakukan sholawat di tempat ibadah ya sudah pasti mudah, tapi mengajak orang melakukan sholawat di tempat dugem yang penuh cobaan itu sudah jelas pahala nya jauh lebih besar...',
#   None,
#   None,
#   42),
#  ('4206988',
#   'Apa sih yg nggak bisa di negeri ini.. semua pada bisa sekrang,,',
#   None,
#   None,
#   43),
#  ('4206988', 'Boleh ya menyebarkan agama seperti ini?�', None, None, 44),
#  ('4206988',
#   'Hahahaha. �Lucu lucuan. Biar masuk tipi laah. Hahaha',
#   None,
#   None,
#   45),
#  ('4206988',
#   'Coba lah ustad yg lain dakwah di nite club spt iti',
#   None,
#   None,
#   46),
#  ('4206988',
#   'Yang ini malah di dukung, yang di sana di jagain supaya ga ceramah. Apalagi ini. ',
#   None,
#   None,
#   47),
#  ('4206988',
#   'Ah entahlah. Satu kau maklumi, yg lain mengikuti. Tinggal tunggu saja.',
#   None,
#   None,
#   48),
#  ('4206988', 'mau ngikik takut dosa', None, None, 49),
#  ('4206988',
#   'kalau mau melakukan ibadah. perbaiki dulu penampilan, jauhi miras, cari tempat yg lebih baik. lebih baik gus kamu mengajak para wanita itu menutupi auratnya.',
#   None,
#   None,
#   50),
#  ('4206988', 'Lokalisasi Harapan Sadar', None, None, 51),
#  ('4206988', 'Setelah selawat selesai, acara selanjutnya ?', None, None, 52),
#  ('4206988', 'Bagus. Lanjutkan..�', None, None, 53),
#  ('4206988',
#   'BAGUS ITU BIAR SADAR ISLAM TDK MENGAJARI KAUMNYA BUKA AURAT BAGUS LANJUT',
#   None,
#   None,
#   54),
#  ('4206988', 'BANSER ANSHOR MANA SUARANYA.....ORMAS LIBERAL', None, None, 55),
#  ('4207126',
#   'PANs itu ketika Simbah yg bicara selalu dibully karena kata katanya terkesan emosional ,nantang nantang ,pdhl ketika tantangan bisa di buktikan oleh yg di tantang trus diem.. tdk ksatria ngakui, dan  sering menjelek jelekkan orang lain ,inilah yg jd penyebab sering di bully dan orang lain jd gak simpati .Mungkin dia dengan berkata seperti itu merasa hebat... dia tdk sadar saat nyapres pun rontok, saat thn 2014 pun keok. artinya rakyat g percaya.seolah bicara dulu urusan belakang spt janji jalan kaki jogja jakarta. . terbukti ?gak kan ?....ini mungkin hal  sepele bagi dia,  tapi itu tertanam di ingatan orang,hingga berkesimpulan  klo hanya bisa ngomong tok.. nglakoni ora iso. ',
#   -1,
#   None,
#   56),
#  ('4207126', 'karena mendukung jokowi jadi tidak dicopot', 1, None, 57),
#  ('4207126', 'Banyak orang pekalongan yg kemakan hoax', 0, None, 58),
#  ('4207126',
#   'PAN ancur lebur gara2 si Amien Rasis ... makasih Amien ... lanjutkan!!! ... #2019PANbakalgurem ...',
#   -1,
#   None,
#   59),
#  ('4207126',
#   'Padahal Sutrisno Bakhir ini dulunya merupakan penyandang dana Pak Amin Rais saat awal reformasi. Akhirnya berjalan sendiri2....�',
#   0,
#   None,
#   60),
#  ('4207126',
#   'Orang bener malah tidak dipake di PAN..Sutrisno itu sdh habis2an demi PAN, tapi tetap tdk berdaya melawan Amien Rais...PAN cahayanya semakin tidak bersinar sejak Amien makin kumat..',
#   -1,
#   None,
#   61),
#  ('4207126', 'Lagu lama...', -1, None, 62),
#  ('4207126', 'PAN sekarang butek karena di-obok2 si Amien.', -1, None, 63),
#  ('4207126', 'Karena mendukung jadi tdk dicopot.', 1, None, 64),
#  ('4207126',
#   'Masak sih dari beberapa ex pemimpin PAN yg punya pikiran sehat cuma pak Sutrisno�',
#   0,
#   None,
#   65),
#  ('4207126',
#   'tolong dikoreksi untuk jabatan pak pramono itu menseskab bukan mensesneg. terima kasih.�',
#   0,
#   None,
#   66),
#  ('4207126',
#   'Mantap bukti orang baik pasti banyak yg mendukung salam 2 periode',
#   1,
#   None,
#   67),
#  ('4011705', 'Ksih mkan buaya aja org kyak gini', None, None, 68),
#  ('4011705',
#   'Mantab... penyebar fitnah bisa tidur di bui jg akhirnya...',
#   None,
#   None,
#   69),
#  ('4011705',
#   'AllahuAkbar. Alhamdulillah akhirnya para ahlul fitnah penebar kebencian tersebut dipenjara juga. Sudah cukup lama mereka menunggu nikmatnya LP Cipinang.',
#   None,
#   None,
#   70),
#  ('4011705',
#   'Selamat menikmati hukuman dunia atas prilaku fitnah menebar kebencian. Hukuman akhirat yg lebih berat menunggu anda para ahlul fitnah penebar kebencian.',
#   None,
#   None,
#   71),
#  ('4011705',
#   'dasar preman ngak tanggung jawab.. kok malah buron.. katanya lu anak buah wowo yg ......bocor bocor itu hehehhe',
#   None,
#   None,
#   72),
#  ('4011705',
#   'orang grindong gak akan ngomentari brita ini, krena sebagian tabir obor rakyat sdh dibuka sebagian oleh rommy',
#   None,
#   None,
#   73),
#  ('4011705',
#   'Ayo, gerombolannya kok nggak ada yang komentar nih? Biasanya koar2, bilang pelanggaran HAM, seperti menangkap teroris, pakai senjata lengkap dsb....',
#   None,
#   'AYO, GEROMBOLANNYA KOK TIDAK ADA YANG KOMENTAR NIH? BIASANYA BERKOAR-KOAR, BILANG PELANGGARAN HAM, SEPERTI MENANGKAP TERORIS, PAKAI SENJATA LENGKAP DAN SEBAGAINYA.',
#   74),
#  ('4011705',
#   'sik asik.. selamat menikmati hotel prodeo kawan, siapa menebar angin dia menuai badai.. ',
#   None,
#   None,
#   75),
#  ('4011705', 'BUNI YANIIII  DIMANA ANDA ??? KEJAAARR !!!!', None, None, 76),
#  ('4011705', 'Wowo ga sekalian ?', None, None, 77),
#  ('4011705',
#   'jangan tangkap pimrednya doank, tangkap penyadang dana dan hubungan mereka dgn kandidat capres yg diusung',
#   None,
#   None,
#   78),
#  ('4011705',
#   'Walaupun cuma 1 tahun ente sudah dapat gelar Mantan Narapidana\nmenjelang pemilu buat lagi biar dikurung 10!tahun makan gratis',
#   None,
#   None,
#   79),
#  ('4011705', 'gantung az', None, None, 80),
#  ('4011705', 'sekalian buni yani biar adil ,,', None, None, 81),
#  ('4011705',
#   'kirim ke kamar bonita.  \n\n# bonita itu nama macan',
#   None,
#   None,
#   82),
#  ('4011705',
#   'gua paling senang liat ginian. buronan, sensasinya kayak di film2 hollywood',
#   None,
#   None,
#   83),
#  ('4011705',
#   'Tungguin aja nih, bentar lagi kubu Prabocor terutama Zonk bakalan komen. Liat aja. ',
#   None,
#   None,
#   84),
#  ('4011705', 'Karena kabur, tambahin yah hukuman nya', None, None, 85),
#  ('4011705',
#   'Ini kabar terbagus yang boleh kudengar hari ini. ',
#   None,
#   None,
#   86),
#  ('4011705', 'telat kabur tong?..kaciann..', None, None, 87),
#  ('4011705',
#   'nyari duit dr nyebar fitnah..duitnya buat makan anak istri..mau jd apa anakmu makan duit gituan?',
#   None,
#   None,
#   88),
#  ('4011705', 'semoga bahagia di rumah yg baru', None, None, 89),
#  ('4011705',
#   'Periksa bank account nya, atau bank account keluarga, ada transferan nggak dari wowo',
#   None,
#   None,
#   90),
#  ('4011705',
#   'Semoga bisa belajar untuk tdk mencari nafkah dari uang hitam dengan cara yang hitam',
#   None,
#   None,
#   91),
#  ('4011705', 'suntik mati', None, None, 92),
#  ('4011705',
#   'sikat semua org org pengacau negeri demi uang, apalagi mo pilpres malah bikin kacau negara klo ga segera dikarungin',
#   None,
#   None,
#   93),
#  ('4011705',
#   'habisin aja jok orang yang gangu elu jadi presiden lgi',
#   None,
#   None,
#   94),
#  ('4011705',
#   'Nunggu buni yani kapan ditangkapnya,  pdhl sdh ada putusan pengadilan jg',
#   None,
#   None,
#   95),
#  ('4011705', 'Koq cuma setahun ?', None, None, 96),
#  ('4011705',
#   'laaaahhh bukannya kata nasbung, pemred obor rakyat diangkat jadi prekom bumn?...weleh..weleh...itu fitnah lagi dong',
#   None,
#   None,
#   97),
#  ('4011705', 'Kapan Buni Yani???', None, None, 98),
#  ('4011705',
#   'Sip, tinggal yg kabur umroh ga balik2 segera dieksekusi pak pol.',
#   None,
#   None,
#   99),
#  ('4011705',
#   'yg model ginian main fitnah sih mesti di KANDANGIN',
#   None,
#   None,
#   100),
#  ('4011705', 'mantap', None, None, 101),
#  ('4011705', 'sip', None, None, 102),
#  ('4011705',
#   'Semoga pas di dalam penjara...kedua2nya gantung diri',
#   None,
#   None,
#   103),
#  ('4011705',
#   'terbukti memfitnah, bukan menghina. dan ingat, fitnah lebih kejam dari pembunuhan, bro',
#   None,
#   None,
#   104),
#  ('4011705', '+hukuman mati.', None, None, 105),
#  ('4011705',
#   'alhamdulillah si penebar dosa sudah tertangkap.',
#   None,
#   None,
#   106),
#  ('4011705',
#   'Jokowi sudah memaafkan, tapi ... proses hukum tetap berlaku, BOS ...',
#   None,
#   None,
#   107),
#  ('4011705', 'Hmm', None, None, 108),
#  ('4011705',
#   'siap2 buat gerombolan micin ama nasi bungkus..',
#   None,
#   None,
#   109),
#  ('4011705', 'tambah hukumannya karena mau kabur ', None, None, 110),
#  ('4011679', 'Lho kok cuma 1  Tahun 5 thn pantas kok', None, None, 111),
#  ('4011679',
#   'Yg menjamin mau mem back up mereka pada kemana? Mau menemani mereka hidup bersama di LP Cipinang? Jangan macem ayam sayur... lari lintang pukang meninggalkan kawan.',
#   None,
#   None,
#   112),
#  ('4011679',
#   'Gagah saat bikin Obor Rakyat, mewek dan buron saat diproses hukum. Dasar preman gembeng, kalau begini apakah orang yang Anda junjung akan gantian membela Anda?',
#   None,
#   None,
#   113),
#  ('4011679',
#   '#2019gantipresiden kelihatan bgt tebang pilihnya, hukum tajam ke lawan politik, tumpul ke cebong😏',
#   None,
#   None,
#   114),
#  ('4011679',
#   'ORANGNYA TAMBAH GEMUK MAKAN UANG SISA ANGGARAN OBOR RAKYAT.',
#   None,
#   None,
#   115),
#  ('4011679',
#   'buset dah..jamintelnya tetangga sebelah rumahnya sendiri...miris',
#   None,
#   None,
#   116),
#  ('4011679', 'bisa jadi 2019 muncul petromak rakyat 😹😹', None, None, 117),
#  ('4011679',
#   'kalau sudah dieksekusi ngga lagi dilindungi kan sama janji back up kalo kena masalah. hehehe\nmakan tuh janji saat kampanye',
#   None,
#   None,
#   118),
#  ('4011679', 'makan pencarian lu tuhhhhh', None, None, 119),
#  ('4011679', 'selamat ya', None, None, 120),
#  ('4011679',
#   'Masih muda,buaknnya mendukung presiden generasi muda.Payah.  ',
#   None,
#   None,
#   121),
#  ('4011679',
#   'Yess tidur aaaah biar cepet besok, ada yg berani taruhan siapa yang belain mereka? ',
#   None,
#   None,
#   122),
#  ('4011679', 'Tukang fitnah. Hukum seberat2nya', None, None, 123),
#  ('4011679', 'Hrsnya min. 10thn di sel...', None, None, 124),
#  ('4011679',
#   'nah ini dia.. paling lawyernya habibu.. getombolan nasi bungkus micin jantungan',
#   None,
#   None,
#   125),
#  ('4011679', 'cuma 1 thn?... enak bener.', None, None, 126),
#  ('4011679',
#   'Ini bodoh amat, cuma 8 bulan seharusnya jangan banding, malah jadi 2 tahun!',
#   None,
#   None,
#   127),
#  ('4011679', 'Bos nya sikat ', None, None, 128),
#  ('4011679',
#   'Mari kita tunggu, siapa saja yg nyinyir atas penangkapan ini... ',
#   None,
#   None,
#   129),
#  ('4011679', 'muka2 tegar menjalani hukuman', None, None, 130),
#  ('4011679', 'Bosnya dah ketangkap blum? ', None, None, 131),
#  ('4011602', 'WOWOK CS BANYAK MUDARAT NYA', None, None, 132),
#  ('4011602', 'Bravo kejaksaan, selamat bertugas.', None, None, 133),
#  ('4011602', 'hukum seberat-beratnya.', None, None, 134),
#  ('4011602',
#   'kalo cebong mah gk di tangkap, kebal hukum spt viktor laiskodat, ade armando, nathan, ananda sukarlan, dll. #2019gantipresiden😏',
#   None,
#   None,
#   135),
#  ('4011602',
#   'good job, jgn lupa gerombolan surveyor INES juga hrs diawasi, dr pada menyebarkan hasil survey abal abal apalagi mo pilpres malah bikin perpecahan ',
#   None,
#   None,
#   136),
#  ('4011602',
#   'sdh dibongkar kan sama pak romi.. pasti ada pendananya.. si kejar juga pak jaksa..terus pak berjuang.. demi bersihnya negara ini dari tukang fitnah',
#   None,
#   None,
#   137),
#  ('4011602', 'Usut dana nya dari mana itu baru hebat👍', None, None, 138),
#  ('4011602',
#   'silahkan bernyanyi denga  bebas walaupum sumbang...tempat telah disediakan...wkwkwkwkkw',
#   None,
#   None,
#   139),
#  ('4011602', 'Kok cuma setahun ???   ', None, None, 140),
#  ('4011602',
#   'Ayo donk polisi. Kalo nangkep2 kaya gini dicari tahu bosnya siapa? Siapa yang memberi dana? Terus kalo udah tau, tangkep lansung!',
#   None,
#   None,
#   141),
#  ('4011602', 'disate aje pak jaksa', None, None, 142),
#  ('4011602', 'Tembak jidat nya', None, None, 143),
#  ('4011602',
#   'Tangkap bandar dan pemimpin gembong hoaxnya biar jelas',
#   None,
#   None,
#   144),
#  ('4011602', 'Tukang Fitnah plus juragannya wajib dihukum', None, None, 145),
#  ('4011602',
#   'sudah terbukti komplotan sana cuma bisa fitnah hoax pki.. kerjanya ngga ada',
#   None,
#   None,
#   146),
#  ('4011602', 'mendingan ditenggelamkan aje', None, None, 147),
#  ('4011602',
#   'aktor intelektual yang mendanai kerja obor rakyat untuk kepentingan politik sang aktor intelektual juga harus di tangkap dan ditenggelamkan ',
#   None,
#   None,
#   148),
#  ('4011602',
#   'mo bgs atau ga..presiden itu kepala negara yg hrs dihormati..kl lu hina ya pantaslah msk bui',
#   None,
#   None,
#   149),
#  ('4011602',
#   'mo bgs atau ga..presiden itu kepala negara yg hrs dihormati..kl lu hina ya pantaslah msk bui',
#   None,
#   None,
#   150),
#  ('4011602',
#   'mo bgs atau ga..presiden itu kepala negara yg hrs dihormati..kl lu hina ya pantaslah msk bui',
#   None,
#   None,
#   151),
#  ('4011602',
#   'Tukang Fitnah dan penyebar hoax.... Tenggelamkan !!! ',
#   None,
#   None,
#   152),
#  ('4011602',
#   'hhahahh ya jelas uda ketebak... negri dagelan...  yg komen jga blaa blaaa blaaaa 😂🤣😂🤣 lanjutakan saja... ',
#   None,
#   None,
#   153),
#  ('4011602', 'Terima kasih Kejaksaan.', None, None, 154),
#  ('4011602',
#   'pak jaksa yg hina pak jokowi berkali2 pasti pak jaksa tau lah..tolong di seret ke penjara. thanks..',
#   None,
#   None,
#   155),
#  ('4011602',
#   'Sekalipun benci dng Jokowi bukan berarti menebar fitnah, biar bgaimanapun Jokowi itu presiden pilihan rakyat...\nMemfitnah presiden = memfitnah rakyat.',
#   None,
#   None,
#   156),
#  ('4011602', 'buron... wkwk', None, None, 157),
#  ('4011602',
#   'kalo di Turki, ini orang sudah diciduk langsung oleh Erdogan (presiden idaman nya pks 🤣)... untung lah di Indonesia ini presiden nya Jokowi yg orang nya lembut dan kalem 😁',
#   None,
#   None,
#   158),
#  ('4011602',
#   'kalo dulu menang.. udah diangkat menteri nih orang',
#   None,
#   None,
#   159),
#  ('4011602',
#   'kalo dulu menang.. udah diangkat menteri nih orang',
#   None,
#   None,
#   160),
#  ('4011602',
#   'kalo dulu menang.. udah diangkat menteri nih orang',
#   None,
#   None,
#   161),
#  ('4011602',
#   'kalo dulu menang.. udah diangkat menteri nih orang',
#   None,
#   None,
#   162),
#  ('4011602',
#   'kalo dulu menang.. udah diangkat menteri nih orang',
#   None,
#   None,
#   163),
#  ('4011602', 'boss nya juga sekalian disikat toilet', None, None, 164),
#  ('4011602', 'boss nya juga sekalian disikat toilet', None, None, 165),
#  ('4011602', 'jadi inget jaman siapa ya...', None, None, 166),
#  ('4011602', 'orang bikin rusak harus musnahkan', None, None, 167),
#  ('4011602', 'super muantap👍👍👍', None, None, 168),
#  ('4011602',
#   'baguslah diciduk, sebelum dikontrak lagi sama tukang fitnah',
#   None,
#   None,
#   169),
#  ('4011602',
#   'menjelekan presiden sama saja menghina lambang negara. harusnya berpikir apalagi seorang redaksi berita yang seharusnya menjadi panutan beritanya.',
#   None,
#   None,
#   170),
#  ('4011602', 'Semoga betah di hotel prodeo ya bro....', None, None, 171),
#  ('4011602', 'Sebaiknya orang spt ini dilenyapkan saja', None, None, 172),
#  ('4011602', 'Sikat ikat berkas ', None, None, 173),
#  ('4011602', 'Fitnah krn duit 😆 ', None, None, 174),
#  ('4011602', 'Tlg dikubur dalam2 org begini', None, None, 175),
#  ('4011602', 'langsung buang aja kelaut', None, None, 176),
#  ('4011602',
#   'Tunggu siapa yang komen membela...nah itu donaturnya',
#   None,
#   None,
#   177),
#  ('4011602', 'Buniyani gmn?', None, None, 178),
#  ('4011602',
#   'Kokk lama sekali pelaku kejahatan Hoax ini baru dijebloskan ke bui sekarang....  Usut dan tangkap segera pelaku Hoax lainnya....  ',
#   None,
#   None,
#   179),
#  ('4011602', 'Obor Hoax', None, None, 180),
#  ('4011602', 'bravo kejaksaan,lumayan ada kerjanya..', None, None, 181),
#  ('4011602', 'Mantap, hajar penyebar hoax. ', None, None, 182),
#  ('4011602', 'Yg di negri sebrang bgmn', None, None, 183),
#  ('3212666', '4 tahun? pantesnya 40 taon', None, None, 184),
#  ('3212666', 'itu dlu timses syp ea?', None, None, 185),
#  ('3212666',
#   'Masih bisa GAYA GAYA an....\nLIHAT BAJU MEREKA seperti.......',
#   None,
#   None,
#   186),
#  ('3352499', 'Mudah 2 an di hukun lebih berat lagi', None, None, 187),
#  ('3352499',
#   'Wkwkwkwkwkw syukurlah kalian banding soalnya hukuman kalian bakal di tambah jd 10 thn, nyungsep kalian .',
#   None,
#   None,
#   188),
#  ('4207145', 'Sakit jiwa luuu...', None, None, 189),
#  ('4207145', 'Sakit jiwa lluu...', None, None, 190),
#  ('4207145',
#   'kasihan bener mas eko, semoga dapat jalan keluarnya..',
#   None,
#   None,
#   191),
#  ('4207145', 'Jahat sekali yang nipu', None, None, 192),
#  ('4207145', 'Sebutin aja pengacaranya', None, None, 193),
#  ('4207145',
#   'Nah, mulai terkuak biang keladinya ... Siapkan bukti2 penyerahan surat2 dan tanda terima uang ... Dikasi ga waktu entu? ... Kalo ga ada bukti, jangan kau harap bisa gugat pengacara ya .... ',
#   None,
#   None,
#   194),
#  ('4207145',
#   'semoga dapat pengganti pengacara kondang mas... yang kemarin itu abal abal punya',
#   None,
#   None,
#   195),
#  ('4207145',
#   'Kasian Mas Eko ini, bisa2 dituduh lg sama cebong sebagai sebar Hoax krn tdk ada buktinya.',
#   None,
#   None,
#   196),
#  ('4206635',
#   'Yang komentar pada ga tahu tentang bagaimana sertifikat dibuat. Sertifikat itu bisa muncul kalau ada akses jalan. Suruh dia tunjukin denah sertifikatnya (kalau dia memang punya). Itu pasti sertifikatnya masih gabung ama sebelah kiri atau sebelah kanannya, dan itu pasti masih saudara dia. Sertifikatnya belum dipecah ama mereka berdua.',
#   None,
#   None,
#   197),
#  ('4206635',
#   'nanti pintu surganya juga diblokade sama Tuhan.',
#   None,
#   None,
#   198),
#  ('4206635',
#   'Sdh bp camat yg harus menyelesaikan biar p camat dpt pahala membantu yg tertindas , toh ga lama lagi kita mati dan runah tanah itu tdk di bawaq',
#   None,
#   None,
#   199),
#  ('4206635',
#   'Saya tahun kemarin beli tanah 20 �15 m. Tapi saya bikin fondasi pagar 19 �15m. Jadi ada 1 meter untuk akses jalan setapak. Berarti saya relakan tanah saya 1�15m utk kepentingan umum. Tetangga sebelah juga demikian. Jadi jalan setapak lebarnya 2 meter. Kita kan hidup bertetangga. Masa tanah satu meter aja menghalangi silaturahmi dengan tetangga?  Jadi harus dibicarakan baik-baik. Semua bisa diatur yg penting dengan hati nurani. ',
#   None,
#   None,
#   200),
#  ('4206635',
#   'lemah mati (tidak ada akses jalan) itu murah harganya, lha ini yg punya tanah maruk ud deal 100jt minta naik 150jt. jengkel di tutup sekalian ma tetangga. yakin tuh yg punya tanah mati pasti kolot jd dikerjai tetangga.�',
#   None,
#   None,
#   201),
#  ('4206635',
#   'Klo tdk salah ada undang-undang (pertanahan) yg mengatur tentang kewajiban bagi pemilik tanah dan bangunan untuk memberi akses jalan bagi pemilik tanah dan bangunan dibelakangnya yg tdk memiliki akses jalan dlm sertifikat tanahnya (istilahnya tanah helikopter) minimal jalan setapak, silahkan dicek saya lupa pasalnya. ',
#   None,
#   None,
#   202),
#  ('4206635',
#   'Tidak berperikemanusiaan yang nutup akses itu. Maukah dia diperlakukan seperti itu? Tanya ke kupingnya dengan keras: MAUKAH DIA DIPERLAKUKAN SEPERTI ITU jika berada di belakang rumah orang lain?',
#   None,
#   None,
#   203),
#  ('4206635',
#   '%u2063Sepertinya ada yang " kurang beres" dengan sertifikat-nya di antara rumah rumah itu, logikanya RT\\/RW, LURAH,CAMAT , BPPN waktu menerbitkan sertifikat itu pasti tahu posisi dan batas batas rumah. pasti ada yang "salah" dengan sertifikat sertifikat itu tentang batas-batas tanahnya. minimal ada hak orang yang diserobot. POLISI harus turun ini.',
#   None,
#   None,
#   204),
#  ('4206635',
#   'Priksa dulu imb nya ada gak?� kalau gak ada suruk satpol yg bongkar jangan korbankan tetangga',
#   None,
#   None,
#   205),
#  ('4206635',
#   'sebelum semuanya menjudge tanpa tabayyun..simple utk mencari siapa yg salah..yg diakui selama ini sbagai akses jalan pak eko ini sebenarnya memang peruntukan jalan atau menggunakan /melewati tanah orang lain?klo memang akses jalan,tetangganya jelas salah!tapi klo itu memang tanah org lain,ya memang haknya dia utk menembok.yg salah adalah pemerintah setempat.mana akses jalan selama ini yg harusnya ada',
#   None,
#   None,
#   206),
#  ('4206635',
#   'yang punya tanah nggak bisa disalahin juga.memang itu haknya dia.klo dia dituntut harus ngasih sebagian untuk jalan,tetangga kiri,kanan n belakang pak eko juga harus dituntut hal yg serupa.apesnya dia adalah dia baru beli n bangun skrg.',
#   None,
#   None,
#   207),
#  ('4206635', 'Kasih jln pak.itu ladang amal bpk�', None, None, 208),
#  ('4206635',
#   'Klo ud deal 100jt kok ingkar jd 150jt ya??? Hrsnya jgn serakah jg ya klo emank maunya 150jt ya jgn buka 100jt donk...ntar ada yg mau 150jt ingkar lgi 200jt...',
#   None,
#   None,
#   209),
#  ('4206635',
#   'akar masalah nya.. � � � � � �DUIT ',
#   None,
#   b'akar masalahnya.. DUIT',
#   210),
#  ('4206635',
#   'Ya sudah to Pak Eko, pindah aja. Rumah lama jadikan kandang ayam atau studio musik. Kan haknya Pak Eko juga to? Saat ketemu tetangga yang gak pedulian, ya sudah jadikan kita gak peduli. Ngalah terus tidak selamanya baik.',
#   None,
#   None,
#   211),
#  ('4206635',
#   'Benernya siapa sie yang mau beli siapa yang mau jual,? Kok keterangan camat beda sama eko? Eko bilang dia yang mau beli tanah tetangganya buat jalan, kata camat malah eko yang mau jual, malah harga naik pula....ini yakin ada yang ga beres sama si eko...',
#   None,
#   None,
#   212),
#  ('4206635',
#   'Gak pernah belajar PMP, mana toleransi,saling menghargai,ssopan santun,empati dalam bertetangga.',
#   None,
#   None,
#   213),
#  ('4206635',
#   'Dulu sudah mau dibeli 100jt tapi ga jadi karena naik minta 150jt giliran dibikin tembok merengek rengek ngadu kesana kamari... Lebay',
#   None,
#   None,
#   214),
#  ('4206635', 'ujung ujungnya duit', None, None, 215),
#  ('4206635', 'Sdh terbaca...pokok permasalah nya...', None, None, 216),
#  ('4206635',
#   'Camat koq minta2. Keluar dari kantor kalian itu hei Camat, Lurah. Jgn ongkang2 keq kumpeni aje lu pade.',
#   None,
#   None,
#   217),
#  ('4206635',
#   'Jangan maen asal ngomong nuduh salah satu pihak. Masalah ini terjadi bukan krn pihak yg bersengketa saja. Ada peran RT RW Lurah Camat serta pihak pertanahan. Rencana tata ruangnya mana? Masing2 punya andil dalam terjadinya masalah ini. Bukan serta merta gr2 pihak pak Eko ataupun tetangganya.�',
#   None,
#   None,
#   218),
#  ('4206635',
#   'Pny tanah pribadi jng dibuat jalanan, nnt diserobot%uD83D%uDE0B',
#   None,
#   None,
#   219),
#  ('4206635',
#   'Jadi sudah jelas to akar masalahnya..lain kumbang lain belangnya...%uD83D%uDE02',
#   None,
#   None,
#   220),
#  ('4206635',
#   "Seharusnya ke pangadilan saja. Apapun hasilnya itu yang akan diakui secara hukum. Kalau curhat kemana2 pasti hanya dapat lip service saja, karena mereka hanya bisa 'menghimbau'...",
#   None,
#   None,
#   221),
#  ('4206635',
#   'Sdh mau dibeli 100jt, tp naik jd 150jt lg....dr sini sdh sdkt jls akar mslhnya',
#   None,
#   None,
#   222),
#  ('4206635',
#   'Ko masih ada ya orang kaya gitu..tinggal di perkampungan ..mending di kubur aja',
#   None,
#   None,
#   223),
#  ('4206635',
#   'Spekulasi tu. Yg jd pertanyaan ketika jual beli kan ada form tanda tangan sepengetahuan jiran kanan kiri dpn blkg. Dr situ sdh dpt awal masalahnya. Kmn tu pak rt rw, kadus n kades???',
#   None,
#   None,
#   224),
#  ('4206635',
#   'Klpun d kasih jalan jg mending pindah aja pak...punya tetangga kayak gitu modelnya susah liat orang senang,senang liat orang susah',
#   None,
#   None,
#   225),
#  ('4206635',
#   'Knpa setelah Viral di medsos, camat nya baru turun tangan,� Pak Eko bilang sdh 3 thn mondarmandir utk cari solusi...� Jadi klu ada masalh sprti ini, mendingan di viralkan,� spya cepat ditanggapi ',
#   None,
#   None,
#   226),
#  ('4206635', 'Masoook Pak Eko', None, None, 227),
#  ('4206635',
#   'Tetangga kayak gini harus buru buru di mandiin, di solatin, di kafanin dan dikuburin langsung. Ga ada adabnya.',
#   None,
#   None,
#   228),
#  ('4206595', 'Gabisa masook pak ekooo', None, None, 229),
#  ('4206595',
#   '"%u2063Saya enggak nyebutin kronologi karena privacy" hmm ada yang aneh',
#   None,
#   None,
#   230),
#  ('4206595',
#   'disini banyak pendukung tetangga pak eko atau mgkn tetangga disitu? wkwkww ',
#   None,
#   None,
#   231),
#  ('4206595', 'Dijual ke tetangga depan/ samping saja pak ', None, None, 232),
#  ('4206595',
#   'RT RW LURAH CAMAT BPN WALKOT /BUPATI tidorrrr semuaaaaaa',
#   None,
#   None,
#   233),
#  ('4206595', 'masssook pak ekoo', None, None, 234),
#  ('4206595',
#   'harusnya dipikirin sejak dini, kalo sudah begini bingung dah lu eko.....%uD83D%uDE33%uD83D%uDE33%uD83D%uDE33 slh elu sendiri    ',
#   None,
#   None,
#   235),
#  ('4206595',
#   'KALAU MAU JUAL YA KE TETANGGANYA... GAK USAH CARI SENSASI... BANYAK KOK ORG LQIN YG RUGI LEBIH BANYAK UTK URUSAN2 TANAH... BAHKAN TANAH DGN SURAT BERLAPIS JUGA ADA.. TOH YG RUGI PEMILIK... ORG BPN PALINGAN HANYA DI MUTASI.. APALAGI KL SDH PENSIUN, GAK ADA SANGSI APA2...!!!!!�',
#   None,
#   None,
#   236),
#  ('4206595',
#   'ini eko nya yg bodohhh sejak awal%uD83D%uDE06%uD83D%uDE06%uD83D%uDE06  ',
#   None,
#   None,
#   237),
#  ('4206595',
#   'Undang2 sdh mengatur klo pembangunan tidal boleh menutup akses jalan bagi rumah atau tempat tinggal yg sudah ada sebelumnya, mohon koreksi klo salah',
#   None,
#   None,
#   238),
#  ('4206595',
#   'Kayak nya si eko ini punya kelainan cara bertetangga deh....',
#   None,
#   None,
#   239),
#  ('4206595', 'Masooookkkk Pak ekooo....', None, None, 240),
#  ('4206595',
#   'Pak eko punya imb?� Kok bisa bangun rumah� tanpa halaman?�',
#   None,
#   None,
#   241),
#  ('4206595',
#   'solusinya ya jual ke tetangga depannya itu Pak. hitung harga tanah saja karena memang rumah \\/ tanah bpk di block sama dia ,banyak yang seperti itu "istilahnya lock land " jadi memang dia beli atau bpk bisa juga beli tanah didepan untuk akses .',
#   None,
#   None,
#   242),
#  ('4206595',
#   'Beli aja tanah tetangga atau jual rumahnya ke tetangganya',
#   None,
#   None,
#   243),
#  ('4206595',
#   'Ya harusnya dari awal Pak Eko sudah membuat jalan utk rumahnya sendiri. Bukan nya membuat Rumah Full bangunan, tp disisakan utk Jalan. Hak tetangga jg membuat Rumah di tanahnya sandiri seperti yg dilakukan Pak Eko. Kejadian sebenarnya masih Misteri siapa yg salah dan yg benar masih abu2..',
#   None,
#   None,
#   244),
#  ('4206595', 'MASUK PAK EKO !!!', None, None, 245),
#  ('4206595', 'Tata ruangnya amburadul', None, None, 246),
#  ('4206595',
#   'Sebetulnya yg paling salah adalah bpn... Karna di peraturan agraria terutuang hukum mengenai pemberian jalan kepada tanah yg tdk memiliki jalan... Cth tanah yg di tengah telah disertifikat... Di kanan dan dikiri pun telah bersertifikat dan menutup jalan... Di depannya jg dibuat sertifikat dan menutup akses yg ditgh sementara blkg belum... Nah ketika belakang membuat sertifikat secara otomatis yg belakang akan kepotong tanahnya dan memberikan akses jalan yg ditengah... Cuma masyarakat bnyk yg awam dgn peraturan tersebut...',
#   None,
#   None,
#   247),
#  ('4206595',
#   'KETUA RT RW LURAH KO PD DIEM AYU BANTU WARGANYA MASA KALAH GANTIAN TUTUP JLNNYA',
#   None,
#   None,
#   248),
#  ('4206595',
#   'Kemungkinan besar ada yg gak beres dg proses penerbitan imb...',
#   None,
#   None,
#   249),
#  ('4206595',
#   'bisa dirundingkan .lha sebelumnya ditawari tanah tetangganya tidak mau .ya bukan salah yang memblokade� .makanya harus baik baik dengan tetangga dan pengurus RT setempat�',
#   None,
#   None,
#   250),
#  ('4206595',
#   'Tdk diperbolehkan (perda) membangun tp merugikan tetangga (walaupun di lahan sendiri), biasanya jika trjadi spt itu dinas pengawasan pembangunan akan bertindak.',
#   None,
#   None,
#   251),
#  ('4206595', 'Masuuukkk pakk ekoo', None, None, 252),
#  ('4206595',
#   'Pastinya orang ini bermasalah dengan tetangganya ....',
#   None,
#   None,
#   253),
#  ('4206595', 'Jual sama yg ngeblokade', None, None, 254),
#  ('4206595',
#   'Silaturahmi dgn tetangga itu penting. Walau akses ditutup kalau tetangga seperti saudara pasti dikasih jalan... Tinggal ketok rumah tetangga terus %u201Cmasuk pak eko%u201D',
#   None,
#   None,
#   255),
#  ('4206595', 'Imb bisa keluar?', None, None, 256),
#  ('4206595',
#   'Ya hak tetangga juga blokade jalan karena mungkin itu tanah tetangga, harusnya di musyawarahkan baik2 dgn tetangga, klo kita baik ke tetangga gak mungkin tetangga akan setega itu memblokade jlan.�',
#   None,
#   None,
#   257),
#  ('4206595',
#   'Waras slamet pak eko tenang aja gusti tak sare',
#   None,
#   None,
#   258),
#  ('4206595',
#   'Mana kades nya??? Masa ada warganya yg bermasalah gini ga diselesaikan',
#   None,
#   None,
#   259),
#  ('4206582',
#   'Surat kog dilempar memangnya koran ??? Meskipun bener koran apa sopan lempar koran ke Presiden ???? Apa gak bisa dititipkan suratnya lewat Paspampres ???? ',
#   None,
#   None,
#   260),
#  ('4206582',
#   'ya jelas dikejar pampapres, ngelempar benda seperti itu ke presiden. itu sudah tugas mereka menjaga presiden',
#   None,
#   None,
#   261),
#  ('4206582',
#   'sifatmu mungkin juga ga benar. main lempar surat tanpa pikir kesopanan.  instropeksi pak eko',
#   None,
#   None,
#   262),
#  ('4206582', 'tetangga masa gitu ??', None, None, 263),
#  ('4206582',
#   '%u2063Sepertinya ada yang " kurang beres" dengan sertifikat-nya di antara rumah rumah itu, logikanya RT\\/RW, LURAH,CAMAT , BPPN waktu menerbitkan sertifikat itu pasti tahu posisi dan batas batas rumah. pasti ada yang "salah" dengan sertifikat sertifikat itu tentang batas-batas tanahnya. minimal ada hak orang yang diserobot. POLISI harus turun ini.',
#   None,
#   None,
#   264),
#  ('4206582',
#   'Wah kalo saja sampe ke telinga jokowi pasti akan dibuatin flyover',
#   None,
#   None,
#   265),
#  ('4206582',
#   'Bandung / Jabar ada Gubernur baru... kalau yang dulu emang PARAH, sekarang lapor pasti di beresin... NGAK SEMUA-SEMUA Ke Presiden kalees',
#   None,
#   None,
#   266),
#  ('4206582', 'Katanya Pak Camat tidak tahu ', None, None, 267),
#  ('4206582',
#   'yang memblokade pasti orang kuat juga orang penting, sampai camat gak bisa nyelesaikan.',
#   None,
#   None,
#   268),
#  ('4206582',
#   'Sudah bodoh mau menang sendiri, ini problem di daerah2 mengharapkan tetangga memberikan jalan, sementara mereka banyak yang membuat rumah atau pagar melebihi ukuran sk tanah yang dimiliki alias menyerobot tanah tetangga.',
#   None,
#   None,
#   269),
#  ('4206582', 'coba ke kopi joni lahh', None, None, 270),
#  ('4206582',
#   'Kalau semua ke Jokowi ya ga mungkin.  Ada jutaan masalah di Indonesia.  Urutannya itu bisa minta mediasi didampingi rt/rw ke kelurahan, kalau gagal ya ke kecamatan.  Kalau ga bisa dateng mediasi, ya tulis surat resmi ke kelurahan, kecamatan, kotamadya.  Kalau tidak ditanggapi bisa tulis pengaduan ke Ombudsman.  Banyak kok permasalahan yg sampai ke Ombudsman, dan langsung di follow up antara 1-2 bulan.  Ga usah tunggu 3 tahun ngejar2 presiden.',
#   None,
#   None,
#   271),
#  ('4206582', 'Tp msh bisa keluar rumah ga?', None, None, 272),
#  ('4206582',
#   'Inilah contoh manusia Indonesia Jaman Now yg katanya Pancasilais Ternyata egois tk ada toleransi sedikitpun kpd sesama pd sesama tetangga.... Rt Rw Lurah nya Camaunya Walikota nya GUBERNUR nya Pancasila nya mana?',
#   None,
#   None,
#   273),
#  ('4206582',
#   'Akalnya aja kurang pinter, itu bikin lif sampai atas genteng kan bisa, terus bikin tol diatas genteng sampai jalan raya, hehehe....',
#   None,
#   None,
#   274),
#  ('4206582',
#   'pertanyaanya...???  bagaimana hubungan bertetangganya kok sampe tega di block gitu?  kita tdk tau ada permasalahan apa.  sedangkan pak eko slalu bilang privacy.  lha piye to?',
#   None,
#   None,
#   275),
#  ('4206582',
#   'Surat rumah Pak Eko ternyata gak beres. Pantesan gak ada yg bisa belain krn secara hukum Pak Eko melakukan pelanggaran. Ternyata Pak Eko minta simpati publik pdhal secara hukum dia bersalah.',
#   None,
#   None,
#   276),
#  ('4206582',
#   'Knapa buat Rumah tidak membuat akses utk jalan sendiri? Bearti selama ini mengambil jalan dari tanah orang lain? Mengambil Hak tetangga utk kepentingan sendiri? ',
#   None,
#   None,
#   277),
#  ('4206582',
#   'mungkin pak eko disuruh bayar akses jalan tp g mau... kl spt ini ya g akan ada titik temu.  krn pemilik jalan mumgkin beli keseluruhan tp pak eko minta cuma2 doang. Tiap jengkal tanah itu berharga,  apalagi diperkotaan',
#   None,
#   None,
#   278),
#  ('4206582',
#   'aneh sih memang kelakuan tetangga sprt ini. biasanya sih....mhn maaf, yg sering model2 tutup jalan, tutup got krn itu dulu tanah engkong gw, itu dulu punya babak gw...kan bukan orang sunda.',
#   None,
#   None,
#   279),
#  ('4206582',
#   'Salah sendiri lah kenapa dulu gak dijual aja tuh rumah. Jual murah aja sama tetangga pake njop jgn pake harga pasar. Dungu dipelihara !! ',
#   None,
#   None,
#   280),
#  ('4206582',
#   'Aparat Kecamatan sama Desa nya saja..� Yg gk becus buat me mediasi masalah seperti itu..� Ganti langsung Camat sama Lurah nya.. Kok ada masyarakat nya susah gk segera di bantu penyelesaian masalah nya..�',
#   None,
#   None,
#   281),
#  ('4206582',
#   'Mas Eko anda harus info ke media sewaktu anda sudah melaporkan ke dinas terkait bahkan sampai gubernur dan tidak ditanggapi.ada hrs cerita siapa saja sehingga anda tidak sebar fitnah.biar oknum2 ini biar ditindak bila itu benar adanya.jgn pernah takut',
#   None,
#   None,
#   282),
#  ('4206582', 'RT RW Kelurahan Camat.� Gk becus�', None, None, 283),
#  ('4206582',
#   'Sabar pak eko semua akan di selesaikan dlm hitungan jam tp di tahun 2019 setelah rezim berganti....',
#   None,
#   None,
#   284),
#  ('4206582',
#   'Hhhh aneh org lempar kertas dikejar tapi org bisa nepuk jokowi wkt touring motor ga diinterogasi atau dilumpuhkan paspampres....setting pencitraan atau paspampresnya yg ga becus ngawal presiden?',
#   None,
#   None,
#   285),
#  ('4206582',
#   'Teu make duit mah... Rek aya anu peduli kumaha atuh kang..?� Sing sadar weh ayeunamah.. Urang hirup di nagara kos kumaha...� ',
#   None,
#   None,
#   286),
#  ('4206582',
#   'Kelihatannya Semua Tanahnya� Sudah ber Sertifikat, kenapa Tidak di pertanyakan Ke Badan Pertanahan. Seharusnya Tidak ada Penerbitan Sertifikat tanpa ada Jalan melalui tanah tersebut, kalo tidak ada tanggapan dari BPN, maka Ajukan Gugatan Ke PTUN dimana BPN sebagai Tergugat 1.',
#   None,
#   None,
#   287),
#  ('4206582',
#   'harusnya waktu dikejar nyerahin diri aja biar pak Jokowi tau masalahnya.. tapi kenapa bapak lari sih.. itu kesempatan emas padahal pak...',
#   None,
#   None,
#   288),
#  ('4206582', 'PEMERINTAH BANDUNG GAK BECUS KERJA', None, None, 289),
#  ('4206582', 'Ya iyalah, maen lempar aja.�', None, None, 290),
#  ('4206582',
#   'Sebenarnya masalahnya apa? Kenapa tidak ada penyelesaian? Mana bupati bandung? Kenapa diam diam saja. Minta dipecat ?!!!',
#   None,
#   None,
#   291),
#  ('4206582',
#   'Coba diselesaikan secara kekeluargaan.. Dg hati dingin tanpa erosi insyaAllah ketemu jalanya.%uD83D%uDE0E',
#   None,
#   None,
#   292),
#  ('4206582',
#   'aneh?? segitu egoisnya kah paravtetangga? RT RW sama Lurah gak bisa tangani kah?? mudah2an masalah ini nyampr ke Jokowi biar masalah selesai... sebenarnya masalah kyk gini bukan urusan presiden.. karena nyangkut2 urusan paspampres atau oknum yg ngaku2 paspampres jadi gak ada salahnya pak Jokowi bantu selesaikan masalah',
#   None,
#   None,
#   293),
#  ('4206582',
#   'Sepertinya dua pihak� awal nya sama2 kepala batu... sehingga kejadian seperti itu akhirnya...',
#   None,
#   None,
#   294),
#  ('4206582',
#   'Kok bisa bangun rumah tp akses ke jalan nya ga ada? Pasti ga ada IMB nya yaaa',
#   None,
#   None,
#   295),
#  ('4206582', 'Tetangga gila...', None, None, 296),
#  ('4206582', 'Jual aja rmhnya pa... Gitu aja repot!', None, None, 297),
#  ('4206582',
#   'gimana mau nuntut Hak? bukan tanah nya kok yg di sekitar nya???? sdh tau dari dulu sehrsnya jual pindah dong.  ',
#   None,
#   None,
#   298),
#  ('4206582', 'Apes...stress...nasib orang kecil...', None, None, 299),
#  ('4206582',
#   'Gambar lokasi bangunan beserta tetangganya bisa diupload jg min',
#   None,
#   None,
#   300),
#  ('4206582',
#   'Ada kades, camat, walkot, gubernur, semua dpt gaji Dr negara, ada hirarki job description�',
#   None,
#   None,
#   301),
#  ('4206582',
#   'Wahh tetangga serahkan, sabar mas di dunia tetangga anda luas tanah nya,nanti di alam kubur dia akan sempit tanah nya,, trs bernaung cari keadilan�',
#   None,
#   None,
#   302),
#  ('4206582',
#   'Lah katanya kelurahan,kec,walikota nggak tahu,teryata udah dilaporkan,teryata sosmed memang tempat megadu yang baik',
#   None,
#   None,
#   303),
#  ('4206582',
#   'Tempat mengadu yang ditanggapi mah di Sosmed, wk...wk...wk...',
#   None,
#   None,
#   304),
#  ('4206582',
#   'Caranya salah pakai lempar kepala negara. Kalau di negara lain mungkin sdh dihukum berat. Kalau di US bisa2 ditembak Secret Service. Mengapa tdk mengadu ke Walikota atau Gubernur dulu.',
#   None,
#   None,
#   305),
#  ('4206582',
#   'emang punya hak atas tanah yg dilalui ngga? jgn sampai berbalik merugikan diri sendiri.',
#   None,
#   None,
#   306),
#  ('4206582',
#   'Gimana RW, dan Lurah serta Camat apa tidak ada solusinya, atau mungkin yg masang tembok itu pingin beli tanahnya Pak Eko',
#   None,
#   None,
#   307),
#  ('4206582',
#   'berita sebelumnya ada photo serifikat dan jelas ada jalan dan gang. ',
#   None,
#   None,
#   308),
#  ('4206582', 'Aneh..sekali', None, None, 309),
#  ('4206582',
#   'ya di modif saja dan dinkmati, ya resiko kalau punya lahan/ rumah di tengah dan ngak ada akses, atau jual saja sama tetangga yg nutupin, uanganya buat cari rumah baru....',
#   None,
#   None,
#   310),
#  ('4206582',
#   'Hehehe, smp urusan spt ini hrs ke p Jokowi ya..�',
#   None,
#   None,
#   311),
#  ('4206582',
#   'Keadilan...?� Memangnya ada pelanggaran hukum apa...?� Sewa pengacara aja seperti Roy Suryo tuh...� ',
#   None,
#   None,
#   312),
#  ('4206582',
#   'Repot,� jual aja ke tetangga,� sesuaikan harga nya,� beli� rumah lagi di komplek perumahan,� jangan Jadi susah sendiri�',
#   None,
#   None,
#   313),
#  ('4206582',
#   'nggak sopan sekali si %u2063Eko Purnomo ini,... kalau tahu pendidikan mestinya tahu cara menyampaikan pendapat ke presiden... bisa lewat gubernur - mentri - ke surat kabar biar viral... ',
#   None,
#   None,
#   314),
#  ('4206582',
#   '%u2063Semoga kasusnya didengar oleh pejabat yang berwenang. Bagaimana pun ada ketiadilan yang dialami pak Eko.',
#   None,
#   None,
#   315),
#  ('4206582',
#   'Tempat mengadu sekarang di sosmed. Jadi viral akan di tangani',
#   None,
#   None,
#   316),
#  ('4206582',
#   'koq bisa gitu.....awalnya gimana.....bisa di urutkan dulu asal muasal tanah serta bangunannya.....',
#   None,
#   None,
#   317),
#  ('4206582',
#   'Harus didengar juga alasan pemilik tanah membangun rumah menutup sepuruh jalan akses pak Eko ... Tanah bangunan yang tadinya ruang terbuka tersebut juga bisa angkat bicara mengenai kasus ini ... ',
#   None,
#   None,
#   318),
#  ('4206582', 'beli heli aja', None, None, 319),
#  ('4206495',
#   'Hhahaha tetangga oh tetangga engkau kadang baik kadang juga buruk rupa',
#   None,
#   None,
#   320),
#  ('4206495',
#   'klo lihat dari denah rumah sih yang salah tetangga ... karna makan hak ases jalan , bukanya tiap perumahan itu dikasih jalan ya sama pengembangnya ',
#   None,
#   None,
#   321),
#  ('4206495',
#   'Itu pak eko punya bukti kuat gambar denah , laporkan saja�',
#   None,
#   None,
#   322),
#  ('4206495',
#   'ini tetangganya udah mau beli rumah pak eko waktu itu tapi pak eko jual mahal...',
#   None,
#   None,
#   323),
#  ('4206495',
#   'Ya harusnya berbagilah..toh TDK dibawa mati jg dunia dan seisinya..paling kita matipun yg kepake 2x1 meter aja',
#   None,
#   None,
#   324),
#  ('4206495',
#   'Bupatinya ditangkap KPK ya??? berarti penerbitan IMB nya bermasalah, tidak ada peninjauan lapangan segala..asal ada amplopnya langsung terbit IMB....gila',
#   None,
#   None,
#   325),
#  ('4206495',
#   'BPN gimana itu bikin peta tanah tidah ada akses jalan ',
#   None,
#   None,
#   326),
#  ('4206495',
#   'Ada hukum-nya, lihat KUHPerd, tidak boleh akses ke tanah orang ditutup,walaupun akses itu punya milik yang menutup... ke pengadilan aja...',
#   None,
#   None,
#   327),
#  ('4206495',
#   '�Ada sebab ada akibat.... panggil kedua belah pihak, di saksikan aparat pemerintahan dan BPN, pemilik lama dan baru.�',
#   None,
#   None,
#   328),
#  ('4206495',
#   'Di bdg dah biasa kalo yg dulunya gang trus jarang orang lewat di tutup sama yg punya tanah, padahal kalo mau wakafkan sebagian tanah dan tanahnya bermanfaat, pahalanya akan trus� mengalir keliang lahat sampai hari kiamat. Maaf kalo sok tau.�',
#   None,
#   None,
#   329),
#  ('4206495',
#   'Bakar aja rumah pak Eko, biar rumah tetangga kena sekalian...',
#   None,
#   None,
#   330),
#  ('4206495',
#   'Kaya apa sih kayanya org ini... sampai nggak py hati..... beda yg di kasih makan uang halal dan haram... coba cek...',
#   None,
#   None,
#   331),
#  ('4206495',
#   'Masya Alloh... kok ada orang yg seperti itu y... kirain cuma ada d sinetron hidayah aja...',
#   None,
#   None,
#   332),
#  ('4206495',
#   'BANTU VIRALKAN AGAR PAK RIDWAN KAMIL TAU ADA WARGANYA YG SEDANG TERZALIMI',
#   None,
#   None,
#   333),
#  ('4206495',
#   'Pak eko ke pasar beli uler cobra aja 100 ekor sama tikus 100 ekor .....lepas aja di rumahnya ...angep2 ternak ...ntar 6 bulan lagi ke sana ya.....�',
#   None,
#   None,
#   334),
#  ('4206495',
#   'Pak Eko sebaiknya bapak menemui pak Gubernur Ridwan Kamil untuk mencari KEADILAN saya yakin bapak akan mendapatkan Solusinya.',
#   None,
#   None,
#   335),
#  ('4206495',
#   'seharusnya sebagai sesama umat tidak boleh memblokade sprti itu... jgn sampai dpt balasan di akheratnya..� �menutup rumah orang spt itu....�',
#   None,
#   None,
#   336),
#  ('4206495',
#   'Sebenarnya kalau ada gang begitu biasanya ada kesepakatan antara pemilik tanah yg menghibahkan sedikit tanah buat gang. Coba aja cari tau dan cari buktinya pak Eko. Baru laporkan.',
#   None,
#   None,
#   337),
#  ('4206495',
#   'Bawa ke pengadilan. Pasti bongkar itu bangunan pakai jalan pemda.�',
#   None,
#   None,
#   338),
#  ('4206495',
#   'Kalo gw jadi pak Eko, kalo emang gk ada solusi dari tetangga angkuh dan pemda,..rmh gw bakar..ntr juga rumay tetangga angkuh kena. Capek amat punya tetangga gitu.',
#   None,
#   None,
#   339),
#  ('4206495',
#   'Ngadu ke hotman Paris juga....� Datang ke kedai kopi joni... Bisa lsg di expose oleh pengacara nyentrik itu....%uD83D%uDE01 ',
#   None,
#   None,
#   340),
#  ('4206495',
#   'Sabar p eko dunia ini hanya semenrara mereka akan mendapat siksa yang pedih di akherat nanti, banyak bedoa p eko karena doa orang yang terzalimi akan diijabah Allah mudah2 Allah memberikan jalan keluar - Aamiin',
#   None,
#   None,
#   341),
#  ('4206495',
#   'Sabar ya pa Eko, mudah mudahan ada jalan keluarnya',
#   None,
#   None,
#   342),
#  ('4206495',
#   'itu gang kok bisa dijual? yg punya tanah yg gabener kalo gitu.. sudah janji kasih akses tapi malah dijual',
#   None,
#   None,
#   343),
#  ('4206495',
#   'Harus diukur lagi denah dan lhat sejarahnya, bisa jadi bagian teras rumah yg ketutup itu mungkin aja gangnya. Krn pernah kejadian ditempat saya, krn awalnya tanah di depan rumah kosong ga dibangun, bagian jalan setapak di depan rumah diambil sama rumah yang bangun duluan. kemudian ketika tanah kosongnya dibangun, otomatis bagian jalan setapaknya sudah hilang. Padahal jalan setapak itu bagian dari fasilitas umum.',
#   None,
#   None,
#   344),
#  ('4206495', 'Mudah2an segera ada solusi.�', None, None, 345),
#  ('4206495',
#   'Loh itu ada gambar gang, klo yg bangun itu main serobot gang nya laporkan aja batal itu imb nya. Jangan jangan gak punya imb juga yg nutup jln',
#   None,
#   None,
#   346),
#  ('4206495',
#   'Sampaikan langsung ke pak Gub ridwan kamil jangan cuma aparat2 gak jelas Insya Allah kang emil bisa kasih solusi... Sekali lagi jangan ngadu ke camat bupati atau lain2... Memang itu jalurnya tapi perlu di ingat jaman sekarang kalo lewat camat bupati hadewww ruwet... Mumpung punya gubernur kayak kang emil... Kita rakyat langsung cus aja ke kang emil. ',
#   None,
#   None,
#   347),
#  ('4206495', 'Cerminan Buruknya Tata kota Bandung.�', None, None, 348),
#  ('4206495',
# ...
#  ('4206311', 'Kalau lulung kan bukan kader ppp lagi pak.', -1, None, 880),
#  ('4206311', 'Habiburohman... Bhuahahahaha', 0, None, 881),
#  ('4206311',
#   'Padahal banten pun bukan daerah pak Jokowi juga. Tapi tetap memihak pak Jokowi... Jadi inti nya..... %uD83D%uDE02%uD83D%uDE02 ',
#   1,
#   None,
#   882),
#  ('4206311',
#   'Kacian..ya koalisi si Zonk..gara2 jatah semua diserobot dan pembagian kardus tdk merata...akhirnya...? sakitnya tuh disini..',
#   -1,
#   None,
#   883),
#  ('4206311',
#   'Yang Ketumnya egk mau keluar uang,kader cari uang sendiri,daripada keluar uang buat prabowo yg jelas kalah ya ogah mereka mendingan ke jokowi agar mendongkrak kader tsb di wilayah mereka ke DPR maupun DPRD ...mereka pintar membaca situasi..tentunya nama Jokowi masih di sukai warganya...memang kader di daerah lebih pandai....kalau di jkt takut dgn ketua umumnya',
#   -1,
#   None,
#   884),
#  ('4206311',
#   'Sebutin donk namanya siapa aja kalo berani. Jangan2 anda sedang halusinasi',
#   0,
#   None,
#   885),
#  ('4206311', 'Namanya juga zonk.. omongane ya zonk', -1, None, 886),
#  ('4206311',
#   'hadew... kartu mati... tak ada bandar mendekat nih...�',
#   -1,
#   None,
#   887),
#  ('4206173',
#   "Pak Ma'ruf bukan gila jabatan, tapi dia tdk rela kalau Indonesia dipimpin orang jahat yg suka nyinyir, Sara, ngadu domba, menghalal kan sgala cara, fitnah sana sini!�",
#   1,
#   None,
#   888),
#  ('4206173', 'Harta tahta...�', -1, None, 889),
#  ('4206173',
#   '#2019PrabowoSandiuno. Semoga menang mbah, biar gak malu kalo kalah. ',
#   1,
#   None,
#   890),
#  ('4206173', 'Lahir batin apa lahirnya saja�', 1, None, 891),
#  ('4206173',
#   'Pake alhamdulillah demi meraih jabatan, istighfar yai',
#   -1,
#   None,
#   892),
#  ('4206173',
#   'Asal jangan mengeluarkan fatwa ya pak... dipapua tidak mengenal fatwa.., indonesia berdasarkan pancasila',
#   1,
#   None,
#   893),
#  ('4206173', 'diabaikan saja,� suaranya dikitkok', -1, None, 894),
#  ('4206173',
#   'biasanya barang /pakaian yg dipakai pejabat harganya bakal naik',
#   0,
#   None,
#   895),
#  ('4206173', 'gila jabatan ki?', -1, None, 896),
#  ('4206173', 'Ah biasa aja tuh', 0, None, 897),
#  ('4206173',
#   'Berita yg bikin sewot fans sebelah nih ,tapi klo kenyataan nya begitu. .mau di bilang apa ?NTB juga kan ? Mereka mendukung tentu dengan alasan yg jelas ..spt papua misal  ..lah yg sering kesana dan bangun papua joko wi. .gmn mau menutup mata? ',
#   1,
#   None,
#   898),
#  ('4206173', 'Sy pendukung ahok.. golput', 0, None, 899),
#  ('4206173',
#   'Mantappp... Keadilan sosial bagi seluruh rakyat Indonesia',
#   1,
#   None,
#   900),
#  ('4206173',
#   'ternyata besar minatnya....%uD83D%uDE04%uD83D%uDE04%uD83D%uDE04',
#   1,
#   None,
#   901),
#  ('4206173',
#   'Klau liat kdekatan dan jasa pak maruf hrusnya SBY mndukung dan mngusungnya\ntpi karena udh kplang baper dan udh kplang janji sama prabowo walau berat hati ya mau gk mau mngusung prabowo',
#   1,
#   None,
#   902),
#  ('4206173', 'Ketum demokrat sdh kagak ada giginya', -1, None, 903),
#  ('4206173', 'Nafsu berkuasa ya.. Hahaha', -1, None, 904),
#  ('4205770',
#   'Jelas bisa dimengerti... rakyat Papua merasakan sekali apa yg sdh dilakukan Pres Jokowi disana..prinsip keadilan nyata dilakukan bukan sekedar jargon politik... #2019OrangBaikHasilnyaBaik ',
#   1,
#   None,
#   905),
#  ('4205770',
#   'Ngomong ngak kuat krn kardus sdh di embat... kelakuan politisi sontoloyo',
#   -1,
#   None,
#   906),
#  ('4205770',
#   'Coba pendapat bapak ini disampaikan ke junjungan bapak....ar. Supaya gak nyinyir.....kata beliau gak mungkin.',
#   0,
#   None,
#   907),
#  ('4205733',
#   'Ibarat bangunan mewah koalisi ini sebenarnya kropos dan rapuh...gmn mau mau menang ini, ngurus intern koalisi iji aja ga bisa...hidup jkw 2 periode',
#   -1,
#   None,
#   908),
#  ('4205733',
#   'Hahahaha....seru neh...mantap masa PKS dan PAN aja yg dapat, sikatlah PD jgn mau dibohongi sama gerindra, pks dan pan..hahaha',
#   -1,
#   None,
#   909),
#  ('4205733',
#   'Hajar bleh, sikat terus, masa cuma mereka doang yang dapat kardus PD engga, ayo jangan mau, tuntut juga bagian kardusmu�',
#   -1,
#   None,
#   910),
#  ('4205733',
#   'Koalisi gak mutu.....percuma lo pada eker2.....nyungsep lo semua',
#   -1,
#   None,
#   911),
#  ('4205733',
#   'Mau menuding dua atau tiga kaki juga gamasalah bos.Yg penting PKS sudah dapat 500 M.berarti pertahun 100M.lumayan kan coba klw ngandalkan dari hasil korupsi atau pemberian jangan2 di OTT sama KPK. Ahirnya gigit jari donk klw ini kan barter meskipun nantinya kalah & pasti kalah dlm Pilpres gamasalah yg rugi kan bukan PKS atau PAN paham kan sekarang?yg penting duitnya GERINDRA sdh keluar & klw ada bahasa untuk KAMPANYE itu kan cuma alasan saja biar garibut.',
#   -1,
#   None,
#   912),
#  ('4205733',
#   'Yahh kenyataannya semuanya main 2 kaki dan oportunis.... mau apa lagi??? ',
#   -1,
#   None,
#   913),
#  ('4205733',
#   'Andi juga aneh pake ngomong udah jelas parte kemunafikan sejati, cebong kejet2 gagal mupe on.',
#   -1,
#   None,
#   914),
#  ('4205733', 'Yah... Apakah masih percaya dengan omomgannya?�', 0, None, 915),
#  ('4205733',
#   'kalau panas dalam minum tuh kaki 3 biar adem..he..he.',
#   0,
#   None,
#   916),
#  ('4205733', 'Ketua diam ... Bisa dianggap seruju', 0, None, 917),
#  ('4205733',
#   'Udaah mending bubar aja niih koalisi ga bermutu...bukanya bikin program malah ribut sendiri, mendiing bubar lagian sdh pasti kalah kok ngapain d lanjutkan�',
#   -1,
#   None,
#   918),
#  ('4205733',
#   'Haqul.yakin Pekaes dan PANte nyungsep suaranya pemilu 2019�',
#   -1,
#   None,
#   919),
#  ('4205733', 'Koalisi serapuh kardus basah', -1, None, 920),
#  ('4205733',
#   'Andi Arief yg selalu menyerang koalisi sendiri ini kenapa tdk ditegur SBY. Ada apa di koalisi Prabowo Sandiaga ??? Padahal bersikap pura2 netral di Pilpres 2014 sama juga bermain 2 kaki, pak Andi.',
#   0,
#   None,
#   921),
#  ('4205733',
#   'Dulu mencari makan setelah menjabat jadi kaya2 bahkan daging juga di empat penjara dan akhirnya neraka',
#   0,
#   None,
#   922),
#  ('4205733', 'Nah lu.... Kena deh ', 0, None, 923),
#  ('4205733',
#   'kardus kardus kardus.........mana bagian kardusku............ ',
#   -1,
#   None,
#   924),
#  ('4205733', 'Politik cari makan alias parpol kardus.', -1, None, 925),
#  ('4205733', 'Dia minta isi kardus tu', -1, None, 926),
#  ('4205733',
#   'Badut badut politik...kerja nolll buat rakyat...nyir nyir bocor coorrrrrrr',
#   -1,
#   None,
#   927),
#  ('4205733',
#   '%u2063jokowi menang mudah di pilpres 2019, democraaat nyungsep',
#   1,
#   None,
#   928),
#  ('4205733',
#   'jokowi menang mudah di pilpres 2019, democraaat nyungsep ',
#   1,
#   None,
#   929),
#  ('4205733', 'Lebih bagus cap kaki tiga..bisa buat kesehatan', 1, None, 930),
#  ('4205733', 'kaki empat..%uD83D%uDE07', 0, None, 931),
#  ('4205733', 'salam dua kaki euy...hahaha', 0, None, 932),
#  ('4205733',
#   'Pak SBY itu kalau ngomong selalu pinjam banyak moncong mas. Kayak ban, bocor alus tapi keliling%uD83D%uDE03. Baru lahir ya?',
#   -1,
#   None,
#   933),
#  ('4205733',
#   'Kl sudah berdasarkan data dan fakta ya susah untuk dijawab.. Hahahaha',
#   -1,
#   None,
#   934),
#  ('4205733',
#   'Setdeh, kho seneng banget� ribut sich, rebutan apa lagi nech, ....eng..ing..eng ..datang Zonk ah nggak papa masih solid kho, itu hanya dinamika politik...capek dech.',
#   -1,
#   None,
#   935),
#  ('4205733',
#   'Sesama begundal politik dilarang saling mendahului ...',
#   -1,
#   None,
#   936),
#  ('4205733',
#   'Karena Aa pakai data dan fakta. Maka tidak bisa berbalas pantun. ',
#   0,
#   None,
#   937),
#  ('4205733', 'PAN - PKS sebaiknya diam klo ga punya kaca.�', -1, None, 938),
#  ('4205733',
#   'Koalisi aja ribut. Gimana mau menang. Jargon doang kenceng kualitas NOL',
#   -1,
#   None,
#   939),
#  ('4205733',
#   'Mari kita bertepuk tangan...sesama begundal sdh mulai ribut....',
#   1,
#   None,
#   940),
#  ('4205733',
#   'Kayaknya bener juga,� dulu kan koalisi Demokrat tp sering gak nurut',
#   -1,
#   None,
#   941),
#  ('4205733', 'Diam itu emas', 0, None, 942),
#  ('4205388',
#   'Lah ngapain jg ribut2 politik. Pilkada kemaren jg banyak koalisi ngacak. Politik disini ya gt, Cari sensasi doang.',
#   -1,
#   None,
#   943),
#  ('4205388',
#   'bukan 2 kaki itu mah yg kita tahu .. tapi 4 kaki .. 2 kaki yg sah , 2 kaki yg siri ..kan ??',
#   0,
#   None,
#   944),
#  ('4205388',
#   'Main dua kaki saat pemilu sudah usai.� Bargain dan kompromi. Lah ini baru mau mulai. Haha Cerdas dong kamu dek�',
#   1,
#   None,
#   945),
#  ('4205388',
#   'PD, PAN, PKS semua ahli main 2 kaki, cuman gerindra yg ga punya kaki',
#   -1,
#   None,
#   946),
#  ('4205388', 'Andi Arief, dicari bawaslu tuh.', 0, None, 947),
#  ('4205388',
#   'Abis mau bagemana lagi ga mau rugi, maunya untung terus',
#   -1,
#   None,
#   948),
#  ('4205388', 'Bertiga saling selingkuh', -1, None, 949),
#  ('4205388',
#   'Andi arief ini awalnya mencak2 teriak2 terkait dana logistik 500M untuk kubu koalisi Prabowo, karena demokrat tdk di ajak bicara, sekarang diem dia di amankan oleh Sandi, wajar Andi arief ini ngebela demokrat dan SBY',
#   -1,
#   None,
#   950),
#  ('4205388',
#   'tepatnya pan dan pks tergantung bayaran................',
#   0,
#   None,
#   951),
#  ('4205388',
#   'Satu koalisi aja udah gak kompak gmn mau menang, udah pd jgn ribut nikmatin aja dl kardus2nya.... mudah2 anjlog /hancura suara kalian di pemilu 2019',
#   -1,
#   None,
#   952),
#  ('4205388',
#   'Salut buat timses PADI, dinamika adalah keharusan dlm sebuah perjuangan politik, ada perbedaan pendapat, kritik juga wajar2 saja, solid gak perlu harus yes semua, diam seribu bahasa spt dikekang & satu suara seperti koalisi jokowi, yg ujung2nya melampiaskan uneg2 dgn menyerang koalisi lawan...berbeda suara bukan masalah, tapi saling menghargai harus dijaga & dekati terus rakyat krn rakyatlah yg menentukan kemenangan di pilpres nanti',
#   1,
#   None,
#   953),
#  ('4205388', 'HAJAR......', -1, None, 954),
#  ('4205388',
#   'Percaya deh,,klo jokowi menang lg,,pan akan merapat ke jokowi lg supaya dpt mentri lg,,kan kmpren brgitu',
#   1,
#   None,
#   955),
#  ('4205388',
#   'PD maen dua kaki di parlemen seabis pilpres, katenye netral tapi condong ke KMP',
#   -1,
#   None,
#   956),
#  ('4205388', 'Kelompok sebelah pemain 2 kaki semua. Wkwkwkwk', 1, None, 957),
#  ('4205388', 'Andi arif buang aja bikin rusuh aja', -1, None, 958),
#  ('4205388', 'Ayo bertengkar lah aku suka hahaha', -1, None, 959),
#  ('4205388', 'Andi arif knp ya..m', 0, None, 960),
#  ('4205388', 'Jadi penonton ah... Menghibur..�', 1, None, 961),
#  ('4205388',
#   'Ular beludak ini keluar lagi, setelah mumpet terkencing2 tdk berani bicara di dpn bawaslu. %uD83D%uDE03',
#   -1,
#   None,
#   962),
#  ('4205388',
#   'Sudah tahu bahwa.... kalau berkata bohong .. tidak sesuai omongan.. kalau janji ingkar .. plinplan... kalau dipercaya ingkar.... tidak konsisten.... tahu munafik kok seteju.. yg waras siapa ya..',
#   -1,
#   None,
#   963),
#  ('4205388',
#   '"%u2063.......pertempuran utama di Pilpres 2019 ialah Jawa Barat, Jawa Tengah, Jawa Timur, Sumatera Utara dan Sulawesi Selatan".  Jawa Tengah jelas sudah dijaga Ganjar, Jawa Timur ada mbak Khofifah, Jawa Barat kemungkinan dengan naiknya RK, Jokowi bakal menang, Sulawesi Selatan, pasti ada efek dari JK sebagai timses Jokowi, hanya Sumatera Utara yang masih bisa diperebutkan oleh kedua koalisi',
#   0,
#   None,
#   964),
#  ('4205388',
#   'Aduh....orang - orang jangan di pilih biar negiri ini tidak segera bubar.',
#   -1,
#   None,
#   965),
#  ('4205388', 'Belah Sono ribut terus y', -1, None, 966),
#  ('4205388',
#   'Mungkin sedang panas dalam (nambah satu kaki lagi)',
#   -1,
#   None,
#   967),
#  ('4205388',
#   'kalo pks mah emang ga ada malunya.  ikut kabinet sby, tapi ngacak2 program sby...presiennya aja sampe makan aspal di jalan nangka noh.... ',
#   -1,
#   None,
#   968),
#  ('4205388', 'ada hubungannya dengan kardus ga nih ???', 0, None, 969),
#  ('4205388',
#   'Maling teriak maling, koalisi kok saling menjelekkan %uD83D%uDE02',
#   -1,
#   None,
#   970),
#  ('4205388', 'bagus bro... hajar terussss ! ', 1, None, 971),
#  ('4205388',
#   'Apa yang diungkapkan bung andi arif benar sekali, kita masih ingat waktu� pks ikut dalam kabinet pak sby, tapi apabila ada kebijakan dari sby selalu ditentang',
#   1,
#   b'Apa yang diungkapkan bung andi arif benar sekali, kita masih ingat waktu pks ikut dalam kabinet pak sby, tapi apabila ada kebijakan dari sby selalu ditentang',
#   972),
#  ('4205388',
#   'Ni orang dri awal udh mulai ribet sebaik nya klo memang gk searah pecat ni pa sby..�',
#   -1,
#   None,
#   973),
#  ('4205207',
#   'PD bubar ajalah.... Uda gak ada wibawa di mata kadernya. Apa karena ketumnya gak tegas? Atau mgkn hal yg sengaja dibuat utk main dua kaki alias mempraktekan politik bermuka dua?�',
#   -1,
#   None,
#   974),
#  ('4205207',
#   'Lo pade ngomong ngaler ngidul ga jelas ... bangsa ini banyak masalah perburuhan, ekonomi, problem kebangsaan benturan umat dll... perlu strong leader ... PAS OK !!!',
#   -1,
#   None,
#   975),
#  ('4205207',
#   'Gawatttt... Harusnya pak Prabowo kirim utusan mautnya kayak Ahmad Dhani, Neno, Sarumpaet ke Papua wkwkwk',
#   -1,
#   None,
#   976),
#  ('4205207',
#   'Kader2mya PD cerdas juga, ga mau dijadikan boneka gerindrong cs',
#   1,
#   None,
#   977),
#  ('4205207',
#   "yang jelas, perolehan suaran Jokowi - Ma'ruf Amin akan bertambah.%uD83D%uDE06 ",
#   1,
#   None,
#   978),
#  ('4205207',
#   'kira2 kalau di adu dari sisi INTELEKTUAL, KECERDASAN, KESEDERHANAAN, KEPEMIMPINAN, KEKAYAAN dari 4 kandidat CAPRES - CAWAPRES siapa yg menang ya ... GAMPANG ... SANDI yg MENANG ... MUDA, KAYA, PINTER, CERDAS, SEDERHANA, DAN YG PALING PENTING ... SETIA SAMA ISTRI dan SAYANG ANAK ... GILA ... PERFECT BANGET SIH LO SANDI ... YG LAIN PADA MAIN BINI MUDA Sama SELINGKUH ... Lo yg Duitnya BANYAK KOK MALAH SETIA ... TOP',
#   1,
#   None,
#   979),
#  ('4205207', '#2019jokowiPresiden', 0, None, 980),
#  ('4205207',
#   'bagi 90% pengurus DPD demokrat di Papua ini, hati nurani mereka lebih punya integritas. krn mereka tau sesungguhnya siapa yg selama ini bekerja utk warganya. ',
#   1,
#   None,
#   981),
#  ('4205207',
#   'Rakyat papua tau mana presiden yang perhatian dengan Papua, mana yang pura-pura perhatian. Btw balikin kardusnya Sandi. ',
#   1,
#   None,
#   982),
#  ('4205207',
#   'jati diri gak pentinglah yah.......yg PENTING MENANG......klik google HAMBALANG....',
#   -1,
#   None,
#   983),
#  ('4205207',
#   'Emang Jokowi masih diinginkan sebagian besar rakyat untuk menjadi Presiden 2 periode kok ',
#   1,
#   None,
#   984),
#  ('4205207',
#   'Masalah papua itu sangat gampang dan malah terlalu gampang merebut suara orang papua sbb orang papua gak denger gubernur asal di serahkan sama yg ahli nya di jamin 100% beres....yg jelas bkn masalah infra struktur sbb yg menikmati nya tetap pendatang sdgkn orang asli papua ttp jd penonton....serahkan pada ahli nya papua pasti prabowo -sandi...',
#   1,
#   None,
#   985),
#  ('4205207',
#   'Demokrat seharusnya join dengan Jokowi saja, tim Prabowo -Sandi ga butuh demokrat cukup Masyarakat-emak2-Gerindra-PKS-PAN saja sudah pasti menang di 2019 ',
#   0,
#   None,
#   986),
#  ('4205207',
#   'Woi kembalikan kardusnya kalo ga 100% dukung wowo....wkwkwk....',
#   -1,
#   None,
#   987),
#  ('4205207', 'Alhamdulillah amin', 1, None, 988),
#  ('4205207',
#   'Sebaiknya demokrat ke jokowi saja, tdk apa apa, PKS PAN Gerindra sangat solid',
#   1,
#   None,
#   989),
#  ('4205207',
#   'Harusx dpd tdk bisa mengatur dpp,kepututsan dpp harusx satu komando,miris jg ini',
#   -1,
#   None,
#   990),
#  ('4205207', 'demokrat plin plan....', -1, None, 991),
#  ('4205207',
#   'karna tdk terbendung, suara kader yg terbelah berobah strategi demi menutup muka yg sudah malu...kasihan demokrat',
#   -1,
#   None,
#   992),
#  ('4205207', '100% pak....soalnya Joko Wi orang baik ..... ', 1, None, 993),
#  ('4205207',
#   'Rakyat papua merasakan langsung pembangunan era presiden jokowi.�',
#   1,
#   None,
#   994),
#  ('4205207',
#   'Hasil akhirnya dan saya yakin Jokowi kalah dipapua.',
#   -1,
#   None,
#   995),
#  ('4205207',
#   'bagus, jangan ikut orang jahat. Saudara2 Papua merasakan pembangunan. ',
#   1,
#   None,
#   996),
#  ('4205207', 'Apa Kata? Gerinda Cs ya? Hayo apa? ', 0, None, 997),
#  ('4205207', 'Karena papu maju', 1, None, 998),
#  ('4205207', 'mbah Mien langsung kejang-kejang....', -1, None, 999),
#  ('4205207',
#   'Mereka ini yg bener2 sdh merasakan langsung dampak pembangunan jalan  dan sebagainya di sana. Tidak bisa ditutupi dan disangkal lagi.',
#   1,
#   None,
#   1000),
#  ...]

# %%
#Mengambil hanya konten comments
new_comments = []
for comment in comments:
    new_comments.append(comment[1])

# %%
new_comments
# Out:
# ['WKWKWK, GAK SEKALIAN PAK, SELAWAT KE DPR... KAN BANYAK KORUPTOR DISANA',
#  'Mantab.. ini br dakwah yg sejati.. kl d tempat umum mah dh biasa . Ini luar biasa.�',
#  'Salut buat Gus Miftah',
#  'yg nyinyir gak pernah lihat dan baca atw mengetahui sejarah dakwah walisongo \\/ sunan kali jaga...smua ada cara demi kebaikan... asal jng ajk dg cara berjinah .... lakukan dg porsi dan sikon yg tepat',
#  'Ada adabnya sholawat. Lebih baik ajak ke majelis ilmu..',
#  'Setiap ulama punya jalan dan cara dakwah masing2.., jika kamu melihat kemunkaran lawan dengan tanganmu(kekuatanmu) jika tidak mampu lawan dengan mulutmu jika tidak mampu juga dengan hatimu itulah selemah lemahnya iman.., itu sudah menjadi kewajiban para ulama, kalo yg komen masih ada yg nyinyirin ulama berarti otaknya sudah disisipin politik..',
#  'Umpanin nocannya yak...',
#  'Itulah ceramah yg sebenarnya. ',
#  'Besok bugil aja selawat',
#  'Bedanya Gus Miftah dengan FPI  / HTI bagaikan surga dan neraka. Di surga penuh kasih, di neraka penuh penghancuran.',
#  'Knp di tempat kerjanya? Mending diundang ke masjid, ponpes, aula. Supaya berbusana yg sopan.�',
#  'nah ini ulama beneran...diterima di semua kalangan.....kl UAS? malah diblokir sana sini',
#  'Kerennn.... saya pernah dpt info seperti ini dr keyakinan yg lain tapi tujuan utama kurang lebih sama lah. Kita ambil sisi positifnya ajah... Terimakasih atas niat baiknya... saya yakin pasti bermanfaat.',
#  'Hebat Gus.Lanjutkan!inilah makna dakwah sebenarnya, sampaikan marwah Islam dengan penuh kedamaian dan berikan pemahaman, bukan dengan kebencian dan pemaksaan',
#  'Diskotik syariah jadunya nih wkwkwk..mantap',
#  'Niat dan tujuan yg baik pasti mendapat berkah dr Allah SWT.',
#  'mantaaapppp..buat di gedung DPR perlu jg kayanya Gus',
#  'Salut buat owner klub ini.....',
#  'Josshhh ini baru luar biasa',
#  'dapat gratisan karena sudah punya nope',
#  'Sebaiknya dimanapun dilakukan batas2 kesopanan tetap harus dijaga...',
#  'Pemandu lagi yang di Manga Besar keknya perlu juga diajak mengaji, bos!',
#  'JUJUR INI KEREENNNNNNN CARA MENYEBARKAN AGAMA YANG BAIK DAN SNAGAT SIMPATIK SEMOGA SUKSES',
#  'katimbang alim kemudian jadi maling, menurut saya lebih baik maling kemudian jadi alim ....',
#  'sebenar ulama, mengajak mereka yg masih tersesat untuk kembali. bukan menjelekkan orang lain, tp merangkul mereka�',
#  'Ini namanya apa ya?',
#  'Selamat berjuang Gus,justru tempat seperti itu yg butuh lebih bnyk perhatian dr ulama.',
#  'Semoga diberikan hidayah..  ',
#  'hati hati memviralkan berita yang mengandung isu agama bisa menjadi sumber fitnah dan lahan para bedebah yang kerjanya mengadu domba anak bangsa dan rakyat indonesia Ahok sudah jadi korbannya',
#  'Subhanallah..... semoga mendapatkan hidayah dari Allah Swt. Amin......',
#  'ulama ngurus umat berarti jenengan Gus...',
#  'Luar biasa, salut...terharu, mengajak orang lain yang dianggap salah dengan cara yang baik, bukan dengan cacian...luar biasa..',
#  "what's up boshe....",
#  'lol jadi ketahuan dong isinya boshe bali bukan org bali %uD83D%uDE02%uD83D%uDE02',
#  'Poligami aja guss',
#  'Harusnya dibakar tempat begituan kalik',
#  'Hahahaha,  bahasa hastag y kalo d plesetkan jadi y santri gaul itu yg suka sholawat dan suka dugem... Hahahaha rusak Islam d biaskan seperti ini, ustad y dateng k sono dugem dulu lalu sholawat lalu dugem lagi,  dan d sebut santri gaul.....????????? ',
#  'Knp yg kayak gini berita nya keluar nya pas mau pilpres aja ya...?',
#  'Naaaah ini baru bener, ceramah atau ngajak orang yg belum bersholawat utk bersholawat. Ga kaya somat, ngajak orang sholawat koq ke orang yg udah bersholawat. Maaaaat mat!!!!',
#  'gila nekat juga ulamanya gak tau di usir gitu,, tapi bagus lah ada keberanian dan semuanya jg mendengarkan.. semoga banyak ustad lainnya yang meniru hal ini. ',
#  'Tambah tempat... mantap sak cewek seksi nya....dan yg paling penting bole... yg g setuju pasti ngiri...week',
#  'Mengajak orang melakukan sholawat di tempat ibadah ya sudah pasti mudah, tapi mengajak orang melakukan sholawat di tempat dugem yang penuh cobaan itu sudah jelas pahala nya jauh lebih besar...',
#  'Apa sih yg nggak bisa di negeri ini.. semua pada bisa sekrang,,',
#  'Boleh ya menyebarkan agama seperti ini?�',
#  'Hahahaha. �Lucu lucuan. Biar masuk tipi laah. Hahaha',
#  'Coba lah ustad yg lain dakwah di nite club spt iti',
#  'Yang ini malah di dukung, yang di sana di jagain supaya ga ceramah. Apalagi ini. ',
#  'Ah entahlah. Satu kau maklumi, yg lain mengikuti. Tinggal tunggu saja.',
#  'mau ngikik takut dosa',
#  'kalau mau melakukan ibadah. perbaiki dulu penampilan, jauhi miras, cari tempat yg lebih baik. lebih baik gus kamu mengajak para wanita itu menutupi auratnya.',
#  'Lokalisasi Harapan Sadar',
#  'Setelah selawat selesai, acara selanjutnya ?',
#  'Bagus. Lanjutkan..�',
#  'BAGUS ITU BIAR SADAR ISLAM TDK MENGAJARI KAUMNYA BUKA AURAT BAGUS LANJUT',
#  'BANSER ANSHOR MANA SUARANYA.....ORMAS LIBERAL',
#  'PANs itu ketika Simbah yg bicara selalu dibully karena kata katanya terkesan emosional ,nantang nantang ,pdhl ketika tantangan bisa di buktikan oleh yg di tantang trus diem.. tdk ksatria ngakui, dan  sering menjelek jelekkan orang lain ,inilah yg jd penyebab sering di bully dan orang lain jd gak simpati .Mungkin dia dengan berkata seperti itu merasa hebat... dia tdk sadar saat nyapres pun rontok, saat thn 2014 pun keok. artinya rakyat g percaya.seolah bicara dulu urusan belakang spt janji jalan kaki jogja jakarta. . terbukti ?gak kan ?....ini mungkin hal  sepele bagi dia,  tapi itu tertanam di ingatan orang,hingga berkesimpulan  klo hanya bisa ngomong tok.. nglakoni ora iso. ',
#  'karena mendukung jokowi jadi tidak dicopot',
#  'Banyak orang pekalongan yg kemakan hoax',
#  'PAN ancur lebur gara2 si Amien Rasis ... makasih Amien ... lanjutkan!!! ... #2019PANbakalgurem ...',
#  'Padahal Sutrisno Bakhir ini dulunya merupakan penyandang dana Pak Amin Rais saat awal reformasi. Akhirnya berjalan sendiri2....�',
#  'Orang bener malah tidak dipake di PAN..Sutrisno itu sdh habis2an demi PAN, tapi tetap tdk berdaya melawan Amien Rais...PAN cahayanya semakin tidak bersinar sejak Amien makin kumat..',
#  'Lagu lama...',
#  'PAN sekarang butek karena di-obok2 si Amien.',
#  'Karena mendukung jadi tdk dicopot.',
#  'Masak sih dari beberapa ex pemimpin PAN yg punya pikiran sehat cuma pak Sutrisno�',
#  'tolong dikoreksi untuk jabatan pak pramono itu menseskab bukan mensesneg. terima kasih.�',
#  'Mantap bukti orang baik pasti banyak yg mendukung salam 2 periode',
#  'Ksih mkan buaya aja org kyak gini',
#  'Mantab... penyebar fitnah bisa tidur di bui jg akhirnya...',
#  'AllahuAkbar. Alhamdulillah akhirnya para ahlul fitnah penebar kebencian tersebut dipenjara juga. Sudah cukup lama mereka menunggu nikmatnya LP Cipinang.',
#  'Selamat menikmati hukuman dunia atas prilaku fitnah menebar kebencian. Hukuman akhirat yg lebih berat menunggu anda para ahlul fitnah penebar kebencian.',
#  'dasar preman ngak tanggung jawab.. kok malah buron.. katanya lu anak buah wowo yg ......bocor bocor itu hehehhe',
#  'orang grindong gak akan ngomentari brita ini, krena sebagian tabir obor rakyat sdh dibuka sebagian oleh rommy',
#  'Ayo, gerombolannya kok nggak ada yang komentar nih? Biasanya koar2, bilang pelanggaran HAM, seperti menangkap teroris, pakai senjata lengkap dsb....',
#  'sik asik.. selamat menikmati hotel prodeo kawan, siapa menebar angin dia menuai badai.. ',
#  'BUNI YANIIII  DIMANA ANDA ??? KEJAAARR !!!!',
#  'Wowo ga sekalian ?',
#  'jangan tangkap pimrednya doank, tangkap penyadang dana dan hubungan mereka dgn kandidat capres yg diusung',
#  'Walaupun cuma 1 tahun ente sudah dapat gelar Mantan Narapidana\nmenjelang pemilu buat lagi biar dikurung 10!tahun makan gratis',
#  'gantung az',
#  'sekalian buni yani biar adil ,,',
#  'kirim ke kamar bonita.  \n\n# bonita itu nama macan',
#  'gua paling senang liat ginian. buronan, sensasinya kayak di film2 hollywood',
#  'Tungguin aja nih, bentar lagi kubu Prabocor terutama Zonk bakalan komen. Liat aja. ',
#  'Karena kabur, tambahin yah hukuman nya',
#  'Ini kabar terbagus yang boleh kudengar hari ini. ',
#  'telat kabur tong?..kaciann..',
#  'nyari duit dr nyebar fitnah..duitnya buat makan anak istri..mau jd apa anakmu makan duit gituan?',
#  'semoga bahagia di rumah yg baru',
#  'Periksa bank account nya, atau bank account keluarga, ada transferan nggak dari wowo',
#  'Semoga bisa belajar untuk tdk mencari nafkah dari uang hitam dengan cara yang hitam',
#  'suntik mati',
#  'sikat semua org org pengacau negeri demi uang, apalagi mo pilpres malah bikin kacau negara klo ga segera dikarungin',
#  'habisin aja jok orang yang gangu elu jadi presiden lgi',
#  'Nunggu buni yani kapan ditangkapnya,  pdhl sdh ada putusan pengadilan jg',
#  'Koq cuma setahun ?',
#  'laaaahhh bukannya kata nasbung, pemred obor rakyat diangkat jadi prekom bumn?...weleh..weleh...itu fitnah lagi dong',
#  'Kapan Buni Yani???',
#  'Sip, tinggal yg kabur umroh ga balik2 segera dieksekusi pak pol.',
#  'yg model ginian main fitnah sih mesti di KANDANGIN',
#  'mantap',
#  'sip',
#  'Semoga pas di dalam penjara...kedua2nya gantung diri',
#  'terbukti memfitnah, bukan menghina. dan ingat, fitnah lebih kejam dari pembunuhan, bro',
#  '+hukuman mati.',
#  'alhamdulillah si penebar dosa sudah tertangkap.',
#  'Jokowi sudah memaafkan, tapi ... proses hukum tetap berlaku, BOS ...',
#  'Hmm',
#  'siap2 buat gerombolan micin ama nasi bungkus..',
#  'tambah hukumannya karena mau kabur ',
#  'Lho kok cuma 1  Tahun 5 thn pantas kok',
#  'Yg menjamin mau mem back up mereka pada kemana? Mau menemani mereka hidup bersama di LP Cipinang? Jangan macem ayam sayur... lari lintang pukang meninggalkan kawan.',
#  'Gagah saat bikin Obor Rakyat, mewek dan buron saat diproses hukum. Dasar preman gembeng, kalau begini apakah orang yang Anda junjung akan gantian membela Anda?',
#  '#2019gantipresiden kelihatan bgt tebang pilihnya, hukum tajam ke lawan politik, tumpul ke cebong😏',
#  'ORANGNYA TAMBAH GEMUK MAKAN UANG SISA ANGGARAN OBOR RAKYAT.',
#  'buset dah..jamintelnya tetangga sebelah rumahnya sendiri...miris',
#  'bisa jadi 2019 muncul petromak rakyat 😹😹',
#  'kalau sudah dieksekusi ngga lagi dilindungi kan sama janji back up kalo kena masalah. hehehe\nmakan tuh janji saat kampanye',
#  'makan pencarian lu tuhhhhh',
#  'selamat ya',
#  'Masih muda,buaknnya mendukung presiden generasi muda.Payah.  ',
#  'Yess tidur aaaah biar cepet besok, ada yg berani taruhan siapa yang belain mereka? ',
#  'Tukang fitnah. Hukum seberat2nya',
#  'Hrsnya min. 10thn di sel...',
#  'nah ini dia.. paling lawyernya habibu.. getombolan nasi bungkus micin jantungan',
#  'cuma 1 thn?... enak bener.',
#  'Ini bodoh amat, cuma 8 bulan seharusnya jangan banding, malah jadi 2 tahun!',
#  'Bos nya sikat ',
#  'Mari kita tunggu, siapa saja yg nyinyir atas penangkapan ini... ',
#  'muka2 tegar menjalani hukuman',
#  'Bosnya dah ketangkap blum? ',
#  'WOWOK CS BANYAK MUDARAT NYA',
#  'Bravo kejaksaan, selamat bertugas.',
#  'hukum seberat-beratnya.',
#  'kalo cebong mah gk di tangkap, kebal hukum spt viktor laiskodat, ade armando, nathan, ananda sukarlan, dll. #2019gantipresiden😏',
#  'good job, jgn lupa gerombolan surveyor INES juga hrs diawasi, dr pada menyebarkan hasil survey abal abal apalagi mo pilpres malah bikin perpecahan ',
#  'sdh dibongkar kan sama pak romi.. pasti ada pendananya.. si kejar juga pak jaksa..terus pak berjuang.. demi bersihnya negara ini dari tukang fitnah',
#  'Usut dana nya dari mana itu baru hebat👍',
#  'silahkan bernyanyi denga  bebas walaupum sumbang...tempat telah disediakan...wkwkwkwkkw',
#  'Kok cuma setahun ???   ',
#  'Ayo donk polisi. Kalo nangkep2 kaya gini dicari tahu bosnya siapa? Siapa yang memberi dana? Terus kalo udah tau, tangkep lansung!',
#  'disate aje pak jaksa',
#  'Tembak jidat nya',
#  'Tangkap bandar dan pemimpin gembong hoaxnya biar jelas',
#  'Tukang Fitnah plus juragannya wajib dihukum',
#  'sudah terbukti komplotan sana cuma bisa fitnah hoax pki.. kerjanya ngga ada',
#  'mendingan ditenggelamkan aje',
#  'aktor intelektual yang mendanai kerja obor rakyat untuk kepentingan politik sang aktor intelektual juga harus di tangkap dan ditenggelamkan ',
#  'mo bgs atau ga..presiden itu kepala negara yg hrs dihormati..kl lu hina ya pantaslah msk bui',
#  'mo bgs atau ga..presiden itu kepala negara yg hrs dihormati..kl lu hina ya pantaslah msk bui',
#  'mo bgs atau ga..presiden itu kepala negara yg hrs dihormati..kl lu hina ya pantaslah msk bui',
#  'Tukang Fitnah dan penyebar hoax.... Tenggelamkan !!! ',
#  'hhahahh ya jelas uda ketebak... negri dagelan...  yg komen jga blaa blaaa blaaaa 😂🤣😂🤣 lanjutakan saja... ',
#  'Terima kasih Kejaksaan.',
#  'pak jaksa yg hina pak jokowi berkali2 pasti pak jaksa tau lah..tolong di seret ke penjara. thanks..',
#  'Sekalipun benci dng Jokowi bukan berarti menebar fitnah, biar bgaimanapun Jokowi itu presiden pilihan rakyat...\nMemfitnah presiden = memfitnah rakyat.',
#  'buron... wkwk',
#  'kalo di Turki, ini orang sudah diciduk langsung oleh Erdogan (presiden idaman nya pks 🤣)... untung lah di Indonesia ini presiden nya Jokowi yg orang nya lembut dan kalem 😁',
#  'kalo dulu menang.. udah diangkat menteri nih orang',
#  'kalo dulu menang.. udah diangkat menteri nih orang',
#  'kalo dulu menang.. udah diangkat menteri nih orang',
#  'kalo dulu menang.. udah diangkat menteri nih orang',
#  'kalo dulu menang.. udah diangkat menteri nih orang',
#  'boss nya juga sekalian disikat toilet',
#  'boss nya juga sekalian disikat toilet',
#  'jadi inget jaman siapa ya...',
#  'orang bikin rusak harus musnahkan',
#  'super muantap👍👍👍',
#  'baguslah diciduk, sebelum dikontrak lagi sama tukang fitnah',
#  'menjelekan presiden sama saja menghina lambang negara. harusnya berpikir apalagi seorang redaksi berita yang seharusnya menjadi panutan beritanya.',
#  'Semoga betah di hotel prodeo ya bro....',
#  'Sebaiknya orang spt ini dilenyapkan saja',
#  'Sikat ikat berkas ',
#  'Fitnah krn duit 😆 ',
#  'Tlg dikubur dalam2 org begini',
#  'langsung buang aja kelaut',
#  'Tunggu siapa yang komen membela...nah itu donaturnya',
#  'Buniyani gmn?',
#  'Kokk lama sekali pelaku kejahatan Hoax ini baru dijebloskan ke bui sekarang....  Usut dan tangkap segera pelaku Hoax lainnya....  ',
#  'Obor Hoax',
#  'bravo kejaksaan,lumayan ada kerjanya..',
#  'Mantap, hajar penyebar hoax. ',
#  'Yg di negri sebrang bgmn',
#  '4 tahun? pantesnya 40 taon',
#  'itu dlu timses syp ea?',
#  'Masih bisa GAYA GAYA an....\nLIHAT BAJU MEREKA seperti.......',
#  'Mudah 2 an di hukun lebih berat lagi',
#  'Wkwkwkwkwkw syukurlah kalian banding soalnya hukuman kalian bakal di tambah jd 10 thn, nyungsep kalian .',
#  'Sakit jiwa luuu...',
#  'Sakit jiwa lluu...',
#  'kasihan bener mas eko, semoga dapat jalan keluarnya..',
#  'Jahat sekali yang nipu',
#  'Sebutin aja pengacaranya',
#  'Nah, mulai terkuak biang keladinya ... Siapkan bukti2 penyerahan surat2 dan tanda terima uang ... Dikasi ga waktu entu? ... Kalo ga ada bukti, jangan kau harap bisa gugat pengacara ya .... ',
#  'semoga dapat pengganti pengacara kondang mas... yang kemarin itu abal abal punya',
#  'Kasian Mas Eko ini, bisa2 dituduh lg sama cebong sebagai sebar Hoax krn tdk ada buktinya.',
#  'Yang komentar pada ga tahu tentang bagaimana sertifikat dibuat. Sertifikat itu bisa muncul kalau ada akses jalan. Suruh dia tunjukin denah sertifikatnya (kalau dia memang punya). Itu pasti sertifikatnya masih gabung ama sebelah kiri atau sebelah kanannya, dan itu pasti masih saudara dia. Sertifikatnya belum dipecah ama mereka berdua.',
#  'nanti pintu surganya juga diblokade sama Tuhan.',
#  'Sdh bp camat yg harus menyelesaikan biar p camat dpt pahala membantu yg tertindas , toh ga lama lagi kita mati dan runah tanah itu tdk di bawaq',
#  'Saya tahun kemarin beli tanah 20 �15 m. Tapi saya bikin fondasi pagar 19 �15m. Jadi ada 1 meter untuk akses jalan setapak. Berarti saya relakan tanah saya 1�15m utk kepentingan umum. Tetangga sebelah juga demikian. Jadi jalan setapak lebarnya 2 meter. Kita kan hidup bertetangga. Masa tanah satu meter aja menghalangi silaturahmi dengan tetangga?  Jadi harus dibicarakan baik-baik. Semua bisa diatur yg penting dengan hati nurani. ',
#  'lemah mati (tidak ada akses jalan) itu murah harganya, lha ini yg punya tanah maruk ud deal 100jt minta naik 150jt. jengkel di tutup sekalian ma tetangga. yakin tuh yg punya tanah mati pasti kolot jd dikerjai tetangga.�',
#  'Klo tdk salah ada undang-undang (pertanahan) yg mengatur tentang kewajiban bagi pemilik tanah dan bangunan untuk memberi akses jalan bagi pemilik tanah dan bangunan dibelakangnya yg tdk memiliki akses jalan dlm sertifikat tanahnya (istilahnya tanah helikopter) minimal jalan setapak, silahkan dicek saya lupa pasalnya. ',
#  'Tidak berperikemanusiaan yang nutup akses itu. Maukah dia diperlakukan seperti itu? Tanya ke kupingnya dengan keras: MAUKAH DIA DIPERLAKUKAN SEPERTI ITU jika berada di belakang rumah orang lain?',
#  '%u2063Sepertinya ada yang " kurang beres" dengan sertifikat-nya di antara rumah rumah itu, logikanya RT\\/RW, LURAH,CAMAT , BPPN waktu menerbitkan sertifikat itu pasti tahu posisi dan batas batas rumah. pasti ada yang "salah" dengan sertifikat sertifikat itu tentang batas-batas tanahnya. minimal ada hak orang yang diserobot. POLISI harus turun ini.',
#  'Priksa dulu imb nya ada gak?� kalau gak ada suruk satpol yg bongkar jangan korbankan tetangga',
#  'sebelum semuanya menjudge tanpa tabayyun..simple utk mencari siapa yg salah..yg diakui selama ini sbagai akses jalan pak eko ini sebenarnya memang peruntukan jalan atau menggunakan /melewati tanah orang lain?klo memang akses jalan,tetangganya jelas salah!tapi klo itu memang tanah org lain,ya memang haknya dia utk menembok.yg salah adalah pemerintah setempat.mana akses jalan selama ini yg harusnya ada',
#  'yang punya tanah nggak bisa disalahin juga.memang itu haknya dia.klo dia dituntut harus ngasih sebagian untuk jalan,tetangga kiri,kanan n belakang pak eko juga harus dituntut hal yg serupa.apesnya dia adalah dia baru beli n bangun skrg.',
#  'Kasih jln pak.itu ladang amal bpk�',
#  'Klo ud deal 100jt kok ingkar jd 150jt ya??? Hrsnya jgn serakah jg ya klo emank maunya 150jt ya jgn buka 100jt donk...ntar ada yg mau 150jt ingkar lgi 200jt...',
#  'akar masalah nya.. � � � � � �DUIT ',
#  'Ya sudah to Pak Eko, pindah aja. Rumah lama jadikan kandang ayam atau studio musik. Kan haknya Pak Eko juga to? Saat ketemu tetangga yang gak pedulian, ya sudah jadikan kita gak peduli. Ngalah terus tidak selamanya baik.',
#  'Benernya siapa sie yang mau beli siapa yang mau jual,? Kok keterangan camat beda sama eko? Eko bilang dia yang mau beli tanah tetangganya buat jalan, kata camat malah eko yang mau jual, malah harga naik pula....ini yakin ada yang ga beres sama si eko...',
#  'Gak pernah belajar PMP, mana toleransi,saling menghargai,ssopan santun,empati dalam bertetangga.',
#  'Dulu sudah mau dibeli 100jt tapi ga jadi karena naik minta 150jt giliran dibikin tembok merengek rengek ngadu kesana kamari... Lebay',
#  'ujung ujungnya duit',
#  'Sdh terbaca...pokok permasalah nya...',
#  'Camat koq minta2. Keluar dari kantor kalian itu hei Camat, Lurah. Jgn ongkang2 keq kumpeni aje lu pade.',
#  'Jangan maen asal ngomong nuduh salah satu pihak. Masalah ini terjadi bukan krn pihak yg bersengketa saja. Ada peran RT RW Lurah Camat serta pihak pertanahan. Rencana tata ruangnya mana? Masing2 punya andil dalam terjadinya masalah ini. Bukan serta merta gr2 pihak pak Eko ataupun tetangganya.�',
#  'Pny tanah pribadi jng dibuat jalanan, nnt diserobot%uD83D%uDE0B',
#  'Jadi sudah jelas to akar masalahnya..lain kumbang lain belangnya...%uD83D%uDE02',
#  "Seharusnya ke pangadilan saja. Apapun hasilnya itu yang akan diakui secara hukum. Kalau curhat kemana2 pasti hanya dapat lip service saja, karena mereka hanya bisa 'menghimbau'...",
#  'Sdh mau dibeli 100jt, tp naik jd 150jt lg....dr sini sdh sdkt jls akar mslhnya',
#  'Ko masih ada ya orang kaya gitu..tinggal di perkampungan ..mending di kubur aja',
#  'Spekulasi tu. Yg jd pertanyaan ketika jual beli kan ada form tanda tangan sepengetahuan jiran kanan kiri dpn blkg. Dr situ sdh dpt awal masalahnya. Kmn tu pak rt rw, kadus n kades???',
#  'Klpun d kasih jalan jg mending pindah aja pak...punya tetangga kayak gitu modelnya susah liat orang senang,senang liat orang susah',
#  'Knpa setelah Viral di medsos, camat nya baru turun tangan,� Pak Eko bilang sdh 3 thn mondarmandir utk cari solusi...� Jadi klu ada masalh sprti ini, mendingan di viralkan,� spya cepat ditanggapi ',
#  'Masoook Pak Eko',
#  'Tetangga kayak gini harus buru buru di mandiin, di solatin, di kafanin dan dikuburin langsung. Ga ada adabnya.',
#  'Gabisa masook pak ekooo',
#  '"%u2063Saya enggak nyebutin kronologi karena privacy" hmm ada yang aneh',
#  'disini banyak pendukung tetangga pak eko atau mgkn tetangga disitu? wkwkww ',
#  'Dijual ke tetangga depan/ samping saja pak ',
#  'RT RW LURAH CAMAT BPN WALKOT /BUPATI tidorrrr semuaaaaaa',
#  'masssook pak ekoo',
#  'harusnya dipikirin sejak dini, kalo sudah begini bingung dah lu eko.....%uD83D%uDE33%uD83D%uDE33%uD83D%uDE33 slh elu sendiri    ',
#  'KALAU MAU JUAL YA KE TETANGGANYA... GAK USAH CARI SENSASI... BANYAK KOK ORG LQIN YG RUGI LEBIH BANYAK UTK URUSAN2 TANAH... BAHKAN TANAH DGN SURAT BERLAPIS JUGA ADA.. TOH YG RUGI PEMILIK... ORG BPN PALINGAN HANYA DI MUTASI.. APALAGI KL SDH PENSIUN, GAK ADA SANGSI APA2...!!!!!�',
#  'ini eko nya yg bodohhh sejak awal%uD83D%uDE06%uD83D%uDE06%uD83D%uDE06  ',
#  'Undang2 sdh mengatur klo pembangunan tidal boleh menutup akses jalan bagi rumah atau tempat tinggal yg sudah ada sebelumnya, mohon koreksi klo salah',
#  'Kayak nya si eko ini punya kelainan cara bertetangga deh....',
#  'Masooookkkk Pak ekooo....',
#  'Pak eko punya imb?� Kok bisa bangun rumah� tanpa halaman?�',
#  'solusinya ya jual ke tetangga depannya itu Pak. hitung harga tanah saja karena memang rumah \\/ tanah bpk di block sama dia ,banyak yang seperti itu "istilahnya lock land " jadi memang dia beli atau bpk bisa juga beli tanah didepan untuk akses .',
#  'Beli aja tanah tetangga atau jual rumahnya ke tetangganya',
#  'Ya harusnya dari awal Pak Eko sudah membuat jalan utk rumahnya sendiri. Bukan nya membuat Rumah Full bangunan, tp disisakan utk Jalan. Hak tetangga jg membuat Rumah di tanahnya sandiri seperti yg dilakukan Pak Eko. Kejadian sebenarnya masih Misteri siapa yg salah dan yg benar masih abu2..',
#  'MASUK PAK EKO !!!',
#  'Tata ruangnya amburadul',
#  'Sebetulnya yg paling salah adalah bpn... Karna di peraturan agraria terutuang hukum mengenai pemberian jalan kepada tanah yg tdk memiliki jalan... Cth tanah yg di tengah telah disertifikat... Di kanan dan dikiri pun telah bersertifikat dan menutup jalan... Di depannya jg dibuat sertifikat dan menutup akses yg ditgh sementara blkg belum... Nah ketika belakang membuat sertifikat secara otomatis yg belakang akan kepotong tanahnya dan memberikan akses jalan yg ditengah... Cuma masyarakat bnyk yg awam dgn peraturan tersebut...',
#  'KETUA RT RW LURAH KO PD DIEM AYU BANTU WARGANYA MASA KALAH GANTIAN TUTUP JLNNYA',
#  'Kemungkinan besar ada yg gak beres dg proses penerbitan imb...',
#  'bisa dirundingkan .lha sebelumnya ditawari tanah tetangganya tidak mau .ya bukan salah yang memblokade� .makanya harus baik baik dengan tetangga dan pengurus RT setempat�',
#  'Tdk diperbolehkan (perda) membangun tp merugikan tetangga (walaupun di lahan sendiri), biasanya jika trjadi spt itu dinas pengawasan pembangunan akan bertindak.',
#  'Masuuukkk pakk ekoo',
#  'Pastinya orang ini bermasalah dengan tetangganya ....',
#  'Jual sama yg ngeblokade',
#  'Silaturahmi dgn tetangga itu penting. Walau akses ditutup kalau tetangga seperti saudara pasti dikasih jalan... Tinggal ketok rumah tetangga terus %u201Cmasuk pak eko%u201D',
#  'Imb bisa keluar?',
#  'Ya hak tetangga juga blokade jalan karena mungkin itu tanah tetangga, harusnya di musyawarahkan baik2 dgn tetangga, klo kita baik ke tetangga gak mungkin tetangga akan setega itu memblokade jlan.�',
#  'Waras slamet pak eko tenang aja gusti tak sare',
#  'Mana kades nya??? Masa ada warganya yg bermasalah gini ga diselesaikan',
#  'Surat kog dilempar memangnya koran ??? Meskipun bener koran apa sopan lempar koran ke Presiden ???? Apa gak bisa dititipkan suratnya lewat Paspampres ???? ',
#  'ya jelas dikejar pampapres, ngelempar benda seperti itu ke presiden. itu sudah tugas mereka menjaga presiden',
#  'sifatmu mungkin juga ga benar. main lempar surat tanpa pikir kesopanan.  instropeksi pak eko',
#  'tetangga masa gitu ??',
#  '%u2063Sepertinya ada yang " kurang beres" dengan sertifikat-nya di antara rumah rumah itu, logikanya RT\\/RW, LURAH,CAMAT , BPPN waktu menerbitkan sertifikat itu pasti tahu posisi dan batas batas rumah. pasti ada yang "salah" dengan sertifikat sertifikat itu tentang batas-batas tanahnya. minimal ada hak orang yang diserobot. POLISI harus turun ini.',
#  'Wah kalo saja sampe ke telinga jokowi pasti akan dibuatin flyover',
#  'Bandung / Jabar ada Gubernur baru... kalau yang dulu emang PARAH, sekarang lapor pasti di beresin... NGAK SEMUA-SEMUA Ke Presiden kalees',
#  'Katanya Pak Camat tidak tahu ',
#  'yang memblokade pasti orang kuat juga orang penting, sampai camat gak bisa nyelesaikan.',
#  'Sudah bodoh mau menang sendiri, ini problem di daerah2 mengharapkan tetangga memberikan jalan, sementara mereka banyak yang membuat rumah atau pagar melebihi ukuran sk tanah yang dimiliki alias menyerobot tanah tetangga.',
#  'coba ke kopi joni lahh',
#  'Kalau semua ke Jokowi ya ga mungkin.  Ada jutaan masalah di Indonesia.  Urutannya itu bisa minta mediasi didampingi rt/rw ke kelurahan, kalau gagal ya ke kecamatan.  Kalau ga bisa dateng mediasi, ya tulis surat resmi ke kelurahan, kecamatan, kotamadya.  Kalau tidak ditanggapi bisa tulis pengaduan ke Ombudsman.  Banyak kok permasalahan yg sampai ke Ombudsman, dan langsung di follow up antara 1-2 bulan.  Ga usah tunggu 3 tahun ngejar2 presiden.',
#  'Tp msh bisa keluar rumah ga?',
#  'Inilah contoh manusia Indonesia Jaman Now yg katanya Pancasilais Ternyata egois tk ada toleransi sedikitpun kpd sesama pd sesama tetangga.... Rt Rw Lurah nya Camaunya Walikota nya GUBERNUR nya Pancasila nya mana?',
#  'Akalnya aja kurang pinter, itu bikin lif sampai atas genteng kan bisa, terus bikin tol diatas genteng sampai jalan raya, hehehe....',
#  'pertanyaanya...???  bagaimana hubungan bertetangganya kok sampe tega di block gitu?  kita tdk tau ada permasalahan apa.  sedangkan pak eko slalu bilang privacy.  lha piye to?',
#  'Surat rumah Pak Eko ternyata gak beres. Pantesan gak ada yg bisa belain krn secara hukum Pak Eko melakukan pelanggaran. Ternyata Pak Eko minta simpati publik pdhal secara hukum dia bersalah.',
#  'Knapa buat Rumah tidak membuat akses utk jalan sendiri? Bearti selama ini mengambil jalan dari tanah orang lain? Mengambil Hak tetangga utk kepentingan sendiri? ',
#  'mungkin pak eko disuruh bayar akses jalan tp g mau... kl spt ini ya g akan ada titik temu.  krn pemilik jalan mumgkin beli keseluruhan tp pak eko minta cuma2 doang. Tiap jengkal tanah itu berharga,  apalagi diperkotaan',
#  'aneh sih memang kelakuan tetangga sprt ini. biasanya sih....mhn maaf, yg sering model2 tutup jalan, tutup got krn itu dulu tanah engkong gw, itu dulu punya babak gw...kan bukan orang sunda.',
#  'Salah sendiri lah kenapa dulu gak dijual aja tuh rumah. Jual murah aja sama tetangga pake njop jgn pake harga pasar. Dungu dipelihara !! ',
#  'Aparat Kecamatan sama Desa nya saja..� Yg gk becus buat me mediasi masalah seperti itu..� Ganti langsung Camat sama Lurah nya.. Kok ada masyarakat nya susah gk segera di bantu penyelesaian masalah nya..�',
#  'Mas Eko anda harus info ke media sewaktu anda sudah melaporkan ke dinas terkait bahkan sampai gubernur dan tidak ditanggapi.ada hrs cerita siapa saja sehingga anda tidak sebar fitnah.biar oknum2 ini biar ditindak bila itu benar adanya.jgn pernah takut',
#  'RT RW Kelurahan Camat.� Gk becus�',
#  'Sabar pak eko semua akan di selesaikan dlm hitungan jam tp di tahun 2019 setelah rezim berganti....',
#  'Hhhh aneh org lempar kertas dikejar tapi org bisa nepuk jokowi wkt touring motor ga diinterogasi atau dilumpuhkan paspampres....setting pencitraan atau paspampresnya yg ga becus ngawal presiden?',
#  'Teu make duit mah... Rek aya anu peduli kumaha atuh kang..?� Sing sadar weh ayeunamah.. Urang hirup di nagara kos kumaha...� ',
#  'Kelihatannya Semua Tanahnya� Sudah ber Sertifikat, kenapa Tidak di pertanyakan Ke Badan Pertanahan. Seharusnya Tidak ada Penerbitan Sertifikat tanpa ada Jalan melalui tanah tersebut, kalo tidak ada tanggapan dari BPN, maka Ajukan Gugatan Ke PTUN dimana BPN sebagai Tergugat 1.',
#  'harusnya waktu dikejar nyerahin diri aja biar pak Jokowi tau masalahnya.. tapi kenapa bapak lari sih.. itu kesempatan emas padahal pak...',
#  'PEMERINTAH BANDUNG GAK BECUS KERJA',
#  'Ya iyalah, maen lempar aja.�',
#  'Sebenarnya masalahnya apa? Kenapa tidak ada penyelesaian? Mana bupati bandung? Kenapa diam diam saja. Minta dipecat ?!!!',
#  'Coba diselesaikan secara kekeluargaan.. Dg hati dingin tanpa erosi insyaAllah ketemu jalanya.%uD83D%uDE0E',
#  'aneh?? segitu egoisnya kah paravtetangga? RT RW sama Lurah gak bisa tangani kah?? mudah2an masalah ini nyampr ke Jokowi biar masalah selesai... sebenarnya masalah kyk gini bukan urusan presiden.. karena nyangkut2 urusan paspampres atau oknum yg ngaku2 paspampres jadi gak ada salahnya pak Jokowi bantu selesaikan masalah',
#  'Sepertinya dua pihak� awal nya sama2 kepala batu... sehingga kejadian seperti itu akhirnya...',
#  'Kok bisa bangun rumah tp akses ke jalan nya ga ada? Pasti ga ada IMB nya yaaa',
#  'Tetangga gila...',
#  'Jual aja rmhnya pa... Gitu aja repot!',
#  'gimana mau nuntut Hak? bukan tanah nya kok yg di sekitar nya???? sdh tau dari dulu sehrsnya jual pindah dong.  ',
#  'Apes...stress...nasib orang kecil...',
#  'Gambar lokasi bangunan beserta tetangganya bisa diupload jg min',
#  'Ada kades, camat, walkot, gubernur, semua dpt gaji Dr negara, ada hirarki job description�',
#  'Wahh tetangga serahkan, sabar mas di dunia tetangga anda luas tanah nya,nanti di alam kubur dia akan sempit tanah nya,, trs bernaung cari keadilan�',
#  'Lah katanya kelurahan,kec,walikota nggak tahu,teryata udah dilaporkan,teryata sosmed memang tempat megadu yang baik',
#  'Tempat mengadu yang ditanggapi mah di Sosmed, wk...wk...wk...',
#  'Caranya salah pakai lempar kepala negara. Kalau di negara lain mungkin sdh dihukum berat. Kalau di US bisa2 ditembak Secret Service. Mengapa tdk mengadu ke Walikota atau Gubernur dulu.',
#  'emang punya hak atas tanah yg dilalui ngga? jgn sampai berbalik merugikan diri sendiri.',
#  'Gimana RW, dan Lurah serta Camat apa tidak ada solusinya, atau mungkin yg masang tembok itu pingin beli tanahnya Pak Eko',
#  'berita sebelumnya ada photo serifikat dan jelas ada jalan dan gang. ',
#  'Aneh..sekali',
#  'ya di modif saja dan dinkmati, ya resiko kalau punya lahan/ rumah di tengah dan ngak ada akses, atau jual saja sama tetangga yg nutupin, uanganya buat cari rumah baru....',
#  'Hehehe, smp urusan spt ini hrs ke p Jokowi ya..�',
#  'Keadilan...?� Memangnya ada pelanggaran hukum apa...?� Sewa pengacara aja seperti Roy Suryo tuh...� ',
#  'Repot,� jual aja ke tetangga,� sesuaikan harga nya,� beli� rumah lagi di komplek perumahan,� jangan Jadi susah sendiri�',
#  'nggak sopan sekali si %u2063Eko Purnomo ini,... kalau tahu pendidikan mestinya tahu cara menyampaikan pendapat ke presiden... bisa lewat gubernur - mentri - ke surat kabar biar viral... ',
#  '%u2063Semoga kasusnya didengar oleh pejabat yang berwenang. Bagaimana pun ada ketiadilan yang dialami pak Eko.',
#  'Tempat mengadu sekarang di sosmed. Jadi viral akan di tangani',
#  'koq bisa gitu.....awalnya gimana.....bisa di urutkan dulu asal muasal tanah serta bangunannya.....',
#  'Harus didengar juga alasan pemilik tanah membangun rumah menutup sepuruh jalan akses pak Eko ... Tanah bangunan yang tadinya ruang terbuka tersebut juga bisa angkat bicara mengenai kasus ini ... ',
#  'beli heli aja',
#  'Hhahaha tetangga oh tetangga engkau kadang baik kadang juga buruk rupa',
#  'klo lihat dari denah rumah sih yang salah tetangga ... karna makan hak ases jalan , bukanya tiap perumahan itu dikasih jalan ya sama pengembangnya ',
#  'Itu pak eko punya bukti kuat gambar denah , laporkan saja�',
#  'ini tetangganya udah mau beli rumah pak eko waktu itu tapi pak eko jual mahal...',
#  'Ya harusnya berbagilah..toh TDK dibawa mati jg dunia dan seisinya..paling kita matipun yg kepake 2x1 meter aja',
#  'Bupatinya ditangkap KPK ya??? berarti penerbitan IMB nya bermasalah, tidak ada peninjauan lapangan segala..asal ada amplopnya langsung terbit IMB....gila',
#  'BPN gimana itu bikin peta tanah tidah ada akses jalan ',
#  'Ada hukum-nya, lihat KUHPerd, tidak boleh akses ke tanah orang ditutup,walaupun akses itu punya milik yang menutup... ke pengadilan aja...',
#  '�Ada sebab ada akibat.... panggil kedua belah pihak, di saksikan aparat pemerintahan dan BPN, pemilik lama dan baru.�',
#  'Di bdg dah biasa kalo yg dulunya gang trus jarang orang lewat di tutup sama yg punya tanah, padahal kalo mau wakafkan sebagian tanah dan tanahnya bermanfaat, pahalanya akan trus� mengalir keliang lahat sampai hari kiamat. Maaf kalo sok tau.�',
#  'Bakar aja rumah pak Eko, biar rumah tetangga kena sekalian...',
#  'Kaya apa sih kayanya org ini... sampai nggak py hati..... beda yg di kasih makan uang halal dan haram... coba cek...',
#  'Masya Alloh... kok ada orang yg seperti itu y... kirain cuma ada d sinetron hidayah aja...',
#  'BANTU VIRALKAN AGAR PAK RIDWAN KAMIL TAU ADA WARGANYA YG SEDANG TERZALIMI',
#  'Pak eko ke pasar beli uler cobra aja 100 ekor sama tikus 100 ekor .....lepas aja di rumahnya ...angep2 ternak ...ntar 6 bulan lagi ke sana ya.....�',
#  'Pak Eko sebaiknya bapak menemui pak Gubernur Ridwan Kamil untuk mencari KEADILAN saya yakin bapak akan mendapatkan Solusinya.',
#  'seharusnya sebagai sesama umat tidak boleh memblokade sprti itu... jgn sampai dpt balasan di akheratnya..� �menutup rumah orang spt itu....�',
#  'Sebenarnya kalau ada gang begitu biasanya ada kesepakatan antara pemilik tanah yg menghibahkan sedikit tanah buat gang. Coba aja cari tau dan cari buktinya pak Eko. Baru laporkan.',
#  'Bawa ke pengadilan. Pasti bongkar itu bangunan pakai jalan pemda.�',
#  'Kalo gw jadi pak Eko, kalo emang gk ada solusi dari tetangga angkuh dan pemda,..rmh gw bakar..ntr juga rumay tetangga angkuh kena. Capek amat punya tetangga gitu.',
#  'Ngadu ke hotman Paris juga....� Datang ke kedai kopi joni... Bisa lsg di expose oleh pengacara nyentrik itu....%uD83D%uDE01 ',
#  'Sabar p eko dunia ini hanya semenrara mereka akan mendapat siksa yang pedih di akherat nanti, banyak bedoa p eko karena doa orang yang terzalimi akan diijabah Allah mudah2 Allah memberikan jalan keluar - Aamiin',
#  'Sabar ya pa Eko, mudah mudahan ada jalan keluarnya',
#  'itu gang kok bisa dijual? yg punya tanah yg gabener kalo gitu.. sudah janji kasih akses tapi malah dijual',
#  'Harus diukur lagi denah dan lhat sejarahnya, bisa jadi bagian teras rumah yg ketutup itu mungkin aja gangnya. Krn pernah kejadian ditempat saya, krn awalnya tanah di depan rumah kosong ga dibangun, bagian jalan setapak di depan rumah diambil sama rumah yang bangun duluan. kemudian ketika tanah kosongnya dibangun, otomatis bagian jalan setapaknya sudah hilang. Padahal jalan setapak itu bagian dari fasilitas umum.',
#  'Mudah2an segera ada solusi.�',
#  'Loh itu ada gambar gang, klo yg bangun itu main serobot gang nya laporkan aja batal itu imb nya. Jangan jangan gak punya imb juga yg nutup jln',
#  'Sampaikan langsung ke pak Gub ridwan kamil jangan cuma aparat2 gak jelas Insya Allah kang emil bisa kasih solusi... Sekali lagi jangan ngadu ke camat bupati atau lain2... Memang itu jalurnya tapi perlu di ingat jaman sekarang kalo lewat camat bupati hadewww ruwet... Mumpung punya gubernur kayak kang emil... Kita rakyat langsung cus aja ke kang emil. ',
#  'Cerminan Buruknya Tata kota Bandung.�',
#  'sabar aja..biar kejepit di liang lahatnya nanti',
#  'Makanya gw gak mau pindah KTP bandung....',
#  'Mungkin takut gk bisa selonjoran kali makanya tanak sejengkal aja dia gk sisain..',
#  'Jng kalian asal koment klu blm tahu pastinya.%uD83D%uDE00',
#  'Kasih tau pak RK biar dirubuhin tuh rumah tetangga..',
#  'Kok gang bisa ada sertinya?',
#  'Pak Ridwan Kamil sbg Gubernur Jabar mungkin harus turun tangan membantu warga yg didzolimi tetangganya. Buktikan Bapak sbg pengayom rakyat.',
#  'tetangganya kejam juga, tapi tetap saja ada ksalahan pemilik rumah, kalo misalakn mau jual lahan harus di liat k masa depan apakah menngangu jalur atau tidak.. akibatnya seperti ini kan? ',
#  'Mungkin tetangga itu mau mati & jalan sendiri ke kuburanya...',
#  'Tetangganya ga punya hati.� Pemerintahnya tidur. Kalau kelak developer beli tanah didepannya dan diblokade, teriak2 minta media datang sambil nangis bawa anak2 kecil dan emak2 sementara bapaknya pada ngilang. ',
#  'Bandung gietuh lohh',
#  'KEMANA PEMERINTAH ????',
#  'Lempar pintu rumah yg bikin tembok pake cangkul pak eko. %uFFFC%uFFFC %uD83D%uDE01',
#  'Tetanga masa gitu jilid 2',
#  'Ud jadi camat .. ngapain ngurusin warga .. kurang kerjaan',
#  'semoga cepat mendapat balasan di dunia untuk para tetangga durjana itu...amiinn..',
#  'ya kita taulah kualitas camat n kelurahan kyk apa. ',
#  'Ini karena aturan yang tidak tersosialisasi, bahkan sampai aparat negara. Harus ditegakkan atas prinsip keadilan',
#  'Klo tu org mati nti biat dia ngubur sendri..�',
#  'Harus berpatokan pd sertipikat tanah, kalo disertipikat ada akses jalan ya bangunan tsb hrs dirobohkan tapi kalo memang ga ada akses jalan ya jangan protes.',
#  'perjuangankan sampe mati pak. kalau ini memang benar hak kamu. ini hartamu yg harus diperjuangkan',
#  'Klu itu mah sm jg nyati gara2 bisa keranah hukum itu?',
#  'Penduduk Ujung Berung sangat heterogen, memiliki karakter masing-masing dan cenderung wataknya keras karena faktor ego masing-masing. Kehadiran pemerintah setempat sebuah keharusan agar ada lsolusi dan desisi, melalui musyawarah mufakat dan atau penegakan hukum.',
#  'Saya kok lama-kelamaan jadi takut, knp Bandung semakin tidak ramah terhadap warganya?!',
#  'Bisa di buat sinetron Rahasia ilahi',
#  'pemilik tembok beruang buktinya  lurah ame camat diem..',
#  'PEMILIK 2 RUMAH YANG YANG NUTUP JALAN HARUSNYA DI RUKYAH DULU SEBELUM BERUNDING, MANDI KEMBANG 7 RUPA, SAMA MAKAN MENYANG YANG KENYANG, KALAU UDAH TAHAK KASI MINUM AIR REBUSAN DAUN SIRIH.',
#  'NGGAK MASHOOK PAK EKO....',
#  'Klo rmh sdh ditembok kirin kanan depan blkg gtu, diwakafkan utk dijadikan kuburan aja pak, biar tetangganya mikir 2x, biar tetangganya tinggal di sebelah kuburan gtu kan ngeri2 sedap.. ,�',
#  'Bongkar bangunannya sekalian,jgn cuma temboknya...benci bgt gw ma org kyk gitu biar digencet dlm kubur luh!!!',
#  'Pejabat tingkat desa tidak peka dengan warganya, jual beli tanah pasti beliau tahu...kan diukur bersama aparat desa, dan kalau urus IMB juga aparat desa survey lokasi....bagaimana ini tdk tahu..... ? Utk bang Hotman Paris pengacara yg dikenal sosial tolongi dong. Obrak abrik itu aparat desanya sampai tingkat kecamatan.. ',
#  'Pemerintah harus bertindak, atau memang tdk peduli pada rakyat tertindas',
#  'Boro boro ngurusin warganya, depan kantor kecamatan ujung berung tiap hari macet parkir motor sembarangan aja dia gak pernah lihat.  ',
#  'Ngadu ke kopi joni 1 hr� beres sama IG bang hotman...',
#  'Orang yang menutup akses jalan rezekinya akan seret... Lihat saja',
#  'eko coba ngadu ke rt dstrunya sampai pak RK, tembuskan ke pak Jokowi yang sering bagi2 sertifikat, pasti beres...',
#  'Camat kerjanya apa? Digaji dari pajak msyarakat selalu saja jawaban klasik.. tidak ada laporan. Mendinga copot camat pemalas. Masih banyak orang yang mau kerja dengan benar.',
#  'Nasib rakyat kecil di rejim ini',
#  'Pidanakan Pak Eko.....!!',
#  'Emang Bandung ngga ada pasal 667 KUH Perdata?',
#  'ini Kades /lurah RT /RW nya kemana aja...',
#  'Kalo masalah ini timbul pas pilkada kemarin, pasti para calon ber lomba lomba nolong',
#  'Ini lah yg perlu y pendidikan agama...hampuraaa',
#  'Kalau kejadiannya di Jakarta, pasti yang komentar udah 1 juta komen',
#  'Bangsa sendiri , lebih ramah , lebih pengertian , syarat dan ketentuan berlaku. ',
#  '%uD83D%uDE02%uD83D%uDE02%uD83D%uDE02%uD83D%uDE02%uD83D%uDE02, siapa yg bilang penduduk INDONESIA ramah tamah ??? Ini tetangga sendiri saja dibabat.....',
#  'MATINYA GK DTERIMA BUMI, TUH ORANG...!!!!!',
#  'Langsung tuntut saja pak Eko. Bapak kan ada denah dari BPN. Tapi cek dahulu dengan sertifikat2 yang ada. Kalau memang keberadaan gang itu di 4 sertifikat muncul. Artinya pemiliki dari dua rumah tersebut melakukan pencurian tanah. Laporkan ke polisi jika memang seperti itu pak Eko. Jangan kebanyakan pasrah, viralkan...',
#  'Ahok...mana ahok.....',
#  'Sabar Mas Eko Saya Juga Pernah Mengalami Persis Kayak Mas Eko Alami . Alhamdullih Dengan Semangat Saya Bekerja Keras Saya Bisa Pindah Rumah Serta Dapat Tanah Yg Jauh Lebih Layak & Besar .',
#  'Ngadu aja ke Jokowi,sama Ridwan Kamil..',
#  'pasti awalnya belagu akhirnya langsung disikat sma tetangganya mgkin situ musti instropeksi diri gak ada orang yang niat sampe sejahat itu kalau ente baik hati gak mgkin RT RW gak tau dan mendiamkan dan warga sekitar juga pasti bantuin kalau ente baik hati. semua hanya mgkin mudah2an segera ada solusinya untuk ente',
#  'Hmmm............. parah bener',
#  'Wah itu pemerintah daerahnya gak beres itu..',
#  'Itu modus untuk memiliki hak tetangga dengan gratis atau dengan harga yang sangat murah.�',
#  'Nah, sekarang camat khan sudah tau maaalah ini, kita lihat apa yg akan dan bisa diperbuat untuk mediasi win-win solution ini',
#  'Hilangnya hati nurani... ayooo gerakan coin to Eko...',
#  'Sdh ada aturannya....',
#  'Coba tempuh jalur hukum perdata, tetangga anda pasti berusaha nyogok hakim tpi jgn putus asa, viralkan trs di medsos utk dukungan',
#  'Gunting pak Eko.....',
#  'Kenapa pake musyawarah? Camat napa bs sampe ga tau? IMB yg keluarin siapa? Emang ga ada satpol pp yg ngawasin? Mustinya lsg robohkan rumah yg halangi itu, balikin akses jalan gang, toh awalnya yg bangun jg ga mau kompromi? Napa takut? Apa udah disuap? Pidanakan juga yg bangun!!�',
#  'pemerintah Bandung nggak becus kerja',
#  'semena-mena,...� nanti kuburan nya menyempit looh.. %uD83D%uDE01%uD83D%uDE01 ',
#  'gila udah gak punya iman tuh tetangga. cocok dijadiin cerita majalah hidayah judulnya k"uburan sempit". :D',
#  'eko cengeng',
#  'Semoga selesai dengan baik dengan mengedepankan hukum. Asas kekeluargaan dan bermasyarakat. Tidak mengedepankan ego..dan status. Aamiin',
#  'Ikut aturan dari sertifikat tanah yg dimiliki saja. Sy percaya pasti gak ikut aturan......',
#  'Sdh jelas dalam SHM  / surat ukur tsb ada gang menuju rmh Eko, aparat harus merubuhkan bangunan yg menutup gang tsb�',
#  'wah, yg nutupi jln bnr2 ga ngerti aturan',
#  'Pasal 5 UUPA di sebutkan bahwa tanah memiliki fungsi sosial.ini artinya bahwa tanah tidak mutlak bisa kita gunakan seenak udel kita tanpa memikirkan kepentingan orang lain',
#  'Kalo diliat denah di sertifikat udah jelas itu gang. �Kenapa aparat tidak baerani berbuat tegas untuk membongkar bangunan tersebutt..jangan jangan...ahh sudahlah',
#  'Ada pejabat yg tdk melaksanakan tugas yg benar',
#  'Kasi akses jln buat orang jg itu sebagian dr amal kita�',
#  "Prihatin.  Itu salah satu contoh masyarakat tidak paham hukum.  Saya ingat betul di KUHP ada pasal mengenai hal ini, kalau tidak salah mengenai 'Hak seseorang atas akses jalan'.  Saran saya, bila mentok, bapak tempuh jalur hukum Perdata, saya yakin pasti menang.",
#  'Pentingnya etika hidup bertetangga.. hrs saling bertegur sapa dan membangun hubungan baik dengan orang lain. Hak memag sudah haknya.. tetapi apakah gak sadar hidup ini hnya sementara dan harta cuma titipan.',
#  'Tetangga masa gtu',
#  'Kejam tetangga ini tdk berkerpimanusiaan',
#  'naon wae masalahna nu nutupna kos bagong teu bisa ngalieuk.. pan tangkurakna ngaliwat nincak jagat batur... dasar bangpak tulak bantingkeun.. ',
#  'Gaya developer nih orang bangun tanpa di beri jalan keluar ',
#  'gak yakin punyaIMB',
#  'Mudah2n pak Eko Purnomo dan keluarga mendapat ganti yg lebih baik,,Aamiin,,sabar ya pak Eko,,',
#  'sudah ga punya rasa kasihan terhadap sesama itu yang baru bangun sudah ada tawaran dari pemilik rumah yang terblokade 10 jt tapi tetap ajah ga mau ngasih toleran kejamnya mau hidup sendiri thu orang nanti kalo mati kubur sendiri sebelum mati bikin liang terlebih dulu x ya',
#  'Koq bisa keluar ijin ngebangun?�',
#  'Jadiin kandang ular aja!!',
#  'Kalo spt ini benar2 sdh pada gak punya rasa tenggang rasa antaranusia bettetanngga, yg lebih aneh lagi spt gak ada gunanya itu namanya ketua RT /RW Lurah dan Camat setempat. Dan bagaimana org mbangun raumah tdk mau peduli sama sekali dg lingkungan tetangga. Benar2 sdh mati segalanya .',
#  'ada yg gak beres keknya , bpn mana nih',
#  "Klo bangunan tanpa akses jalan gitu biasa'y ga akan bisa bikin SHM.",
#  'Gak bisa tuh aturannya itu harysnya tetep kasih jalan minimal 60cm (selebar keranda) ntk org jalan, wajib..',
#  'Aparatur pada kemana.... Rt rw Ny pada budek smua... Gk peduli sekitar ny',
#  'Kejam skali itu tetangganya....trus pemerintah daerah khususnya dinas pertanahan...gmn bisa gitu. Kan ada aturan setiap rumah diwajibkan memberi ruang utk akses baik jln ato parit. Kacau bgt sih',
#  'ini yang disalahkan seharusnya badan pertanahan daerahnya, koq bisa ada ijin yang membuat rumah tidak ada akses jalan.',
#  'Merdeka udah 73 thn..! Aparatur daerahnya pada kemana..?',
#  'Horang kaya... Baru. ..',
#  'salah satu keajaiban dunia lol',
#  'Masa waktu tumpuk tuh batu bata nga nyadar nutupin rumah orang lain wkwkwk.',
#  'Coba jika yang nutup jalan tadi rumahnya di belakang, maukah diperlakukan seperti itu? Serakah amat sih, utk jalan aja nggak boleh. Modar tidak dibawa aja.',
#  'Salah satu tetangga yang lahannya berbatasan langsung dengan rumah itu sebaiknya secara bijaksana membantu ybs dengan cara membeli rumah tersebut, sehingga ybs bisa membeli rumah penggantinya di tempat lain. Hanya itu jalan keluar terbaik tanpa merugikan pihak manapun. Semoga cepat ada solusi terbaik.',
#  'Apakah masyarakat kita semakin lama semakin buas..?�',
#  'Mau beli dgn harga murah...pakai jalan begitu...dugaan saya.',
#  'Lho IMB mewajibkan bangun rumah harus punya akses jalan...',
#  'tetangganya ga ingat� kalo mati cm butuh 2 meter...amal dikit knp?',
#  'Orang kaya tapi kayaknya ngga bermoral ya...',
#  'Awalnya gimana.. Cuma satu rumah aja... Seblum bangun rumah kaga diperhitungkan dulu.. klu tanah orang buat jalan ya ga fair...sblum komen lihat permasalahannya dulu..�',
#  'Gugat aja...pasti menang',
#  'Permasalahannya adalah, kenapa pemda setempat memberikan IMB tanpa mengecek situasi? setiap bangunan harusnya mempunyai IMB, atau kemungkinan pembangunan rumah tidak punya IMB. Hal seperti ini tetangga bisa menggugat ke dinas tata kota (kalau tidak salah) karena mebangun rumah tidak hanya karena punya tanah saja, bisa dibangun semaunya, harus mempertimbangkan kepentingan umum, terutama tetangga sekitar. ',
#  'Kasihan... Tanah itu yg akan melapang dan menyempit ketika kita mati kelak.... Semoga keluarga tersebut senantiasa diberi kesabaran dan ketabahan.. Harta hanya titipan semua milik Tuhan.�',
#  'Viralin aja, imbnya gak beres tuh, bisa dibongkar',
#  'yaudah jadi tetangganya aja',
#  'Tetangganya busuk itu mah.',
#  'Tetangganya pada sakit jiwa!',
#  'Sadis tetangganya pada g mau mati x',
#  'Setahu saya ada di KUH Perdata... Namanya Hak Servituut... Coba yang ahli Hukum...bagaiman itu penjelasannya...',
#  'Terlepas dari p eko yg tidak bagus dalam bertetangga,� Harusnya tetangga yg bangun tembok gank punya nurani biar otaknya kepakek. Dia bisa dituntut kok bisa ngebangun tanpa IMB,� bikin susah org itu namanya. Sekalian laporin polisi tuh RT nya sekalian.��',
#  'Sabar yaaa mas semoga prilaku itu mendapat balasan yang lebuh menyakitkan dari apa yang dia perbuat, serahkan kedirinya pelaku,  memang masih banyak manysia2 tamak serakah tapi sebetulnya diri sendiri ada ati nurani yang ga bisa dia bihongi suatu sa, at penderitaan akan lebih dari apa yang dia perbuat. ',
#  'Masuk pak eko.... ',
# ...
#  'AA mantap....',
#  'Wong edan kui bebas. Wong edan kui bebas , wong edan kui bebas.,.,. By nella karisma .',
#  'Bukan mukanya ajaa yg ga enak dilihat..pikiran dan ucapannya juga ga enak didengar',
#  'Kapal oleng kapten %uD83D%uDE05',
#  'Kenyataan memang menyakitkan!!!',
#  'Andi Arif teriak terus dan Ketumnya diam aja. Org jadi paham kalau andi memang ditugasi untuk itu. Targetnya �ya agar pihak lawan prabowo yakin PD gak all out dan keuntungan yg bisa diraih adalah posisi menteri bagi AHY di kabinet jokowi.... sangat memuakkan!',
#  'Gak terbukti kok ngotot...�',
#  'Awas..... AA itu mata%u201D yg ingin mecah belah koalisi.. masa org pintar ucapannya bgitu %uD83D%uDC4E%uD83C%uDFFB%uD83D%uDC4E%uD83C%uDFFB',
#  'Demokrat itu dulu santun zaman sby...sebenarnya repot juga ya kalo berdiri dikubu sebelah....beda jenis...dan jenis itu sdh dikapling sama pekaes..gerindera dan PAN...gaknada untungnya malah bisa berkurangbkursi di PILEG',
#  'ketiganya pasti parnoko,kita buktikan yah.',
#  'Kehilangan TGB adalah sesuatu yg merugikan demokrat...tapi misalkan didaerah 5 yg disebutkan andi arief itu imbang...bukannya daerah2 lain juga jadi penentu ya %u263A',
#  'Mending tendang dah demokrat...drpd rempong...suaranya demokrat udah loyo....cukup PKS..PAN n berkarya ajah...',
#  'Ada ada saja jurus mengelak nya Upin Ipin kah?hihihihi ',
#  'Masih sakit hati masalah kardus',
#  'Ayo perang, pukul, tendang......emang si andi arief biang perkara, komen seenaknya ayo balas, masa sih kalah sama wakil sekjen doang?????�',
#  '%uD83E%uDD14%uD83E%uDD14%uD83E%uDD14%uD83E%uDD14%uD83E%uDD11%uD83E%uDD11%uD83E%uDD11%uD83E%uDD11%u2620%uFE0F%u2620%uFE0F%u2620%uFE0F%u2620%uFE0F',
#  'Koalisi tdk solid, kacau, pecah, acak kadul.�',
#  'Maling teriak maling, titip salam deh buat si beyek.... KATAKAN YA PADA KORUPSI.....',
#  'Koalisi ya yg kompak, kompak sj blm tentu menang apalagi gontok2an dan setengah hati....',
#  'Ko berkoalisi malah saling serang... Kasihan para kader yg di daerah kalo seperti ini....',
#  'Apapun yg diperlihatkn demokrat tentu bukan pelajaran politik yg baik bagi masyarakat.... faktanya hy politik busuk dan bermuka dua yg tampilkan',
#  'Makin seru.... Hahahahaa',
#  'Koalisi amburadul.... keumatan enggak jadi...ijtimak omong kosong .... ternyata cuma kardus tempe ATM',
#  'ketauan kalo sebenarnya koalisi kardus sangat rapuh dan demokrat merasa akan sia2 menghabiskan energi untuk dukung paslon yang kalah...... ',
#  'Sudah jadi rahasia umum......',
#  'Mungkin aja ada kader PPP dan PKB yang simpatisan kesebelah, khususnya yang doyan karduss',
#  'PARPOL NY KEMANA... KADER DAN PENDUKUNGNYA KEMANA.. ITU ARTINYA PARPOL TIDAK PUNYA PENGARUH TERHADAP PILIHAN INDIVIDU.. BANYAK DUKUNGAN PARPOL JUGA BELUM TENTU MENANG. RAKYAT INDONESIA SUDAH PINTAR. MEREKA TAHU KEMANA PILIHAN POLITIK MEREKA AKAN DIBERIKAN',
#  'knp g bilang aja sekalian pdip di akar rumput dukung prabosan',
#  'Jokowi dua periode RI 1 selanjutnya erick tohir yang sudah disiapkan jokowi.',
#  'Di depan pimpinan parpol boleh saja dukung calon yg didukung parpolnya...tp dalam bilik suara siapa yg tau...dah biasa koq nyeberang sesuai hati nurani',
#  'Ppp yg dukung gerindra palingan jg si usb lunglung',
#  'semakin mendekati pemilu semakin keliatan kalau mereka sebenarnya sudah tak seimbang...',
#  'Bocor...Bocorrrr....',
#  'Emang lulung masih di PPP? Bukanya sudah di pan yah? Wah kayaknya gerindrong lagi mimpi basah deh...alias lagi buat fiksi...',
#  'Paling haji lulung',
#  'paling si lulung doank hahaha',
#  'Kalau sebagian demokrat mendukung jokowi yang bilang orang demokrat sendiri. Kalau PPP mendukung prabowo yang bilang orang gerindra bukan PPP jadi silahkan di cerna',
#  '#2019PrabowoSandiuno. Hak Suara milik Rakyat secara Individu. Dukung mendukung hanya untuk bersaing di media.� Tidak semua rakyat Papua dukung Jokowi, dan tidak semua orang Betawi dukung Prabowo. ',
#  'Omongan habib sama fadli ngawur dan tanpa data valid, kalo negara ini mau maju, jangan kasih kesempatan orang seperti ini menjadi bagian dari penguasa, cek track record habib apakah masih mau memberikan amanah kepada dia, habin dan arief puyuono dua serangkai dari puluhan tahun lalu..',
#  'Sengaja itu.. taktik mainannya SBY..�',
#  'Kalau lulung kan bukan kader ppp lagi pak.',
#  'Habiburohman... Bhuahahahaha',
#  'Padahal banten pun bukan daerah pak Jokowi juga. Tapi tetap memihak pak Jokowi... Jadi inti nya..... %uD83D%uDE02%uD83D%uDE02 ',
#  'Kacian..ya koalisi si Zonk..gara2 jatah semua diserobot dan pembagian kardus tdk merata...akhirnya...? sakitnya tuh disini..',
#  'Yang Ketumnya egk mau keluar uang,kader cari uang sendiri,daripada keluar uang buat prabowo yg jelas kalah ya ogah mereka mendingan ke jokowi agar mendongkrak kader tsb di wilayah mereka ke DPR maupun DPRD ...mereka pintar membaca situasi..tentunya nama Jokowi masih di sukai warganya...memang kader di daerah lebih pandai....kalau di jkt takut dgn ketua umumnya',
#  'Sebutin donk namanya siapa aja kalo berani. Jangan2 anda sedang halusinasi',
#  'Namanya juga zonk.. omongane ya zonk',
#  'hadew... kartu mati... tak ada bandar mendekat nih...�',
#  "Pak Ma'ruf bukan gila jabatan, tapi dia tdk rela kalau Indonesia dipimpin orang jahat yg suka nyinyir, Sara, ngadu domba, menghalal kan sgala cara, fitnah sana sini!�",
#  'Harta tahta...�',
#  '#2019PrabowoSandiuno. Semoga menang mbah, biar gak malu kalo kalah. ',
#  'Lahir batin apa lahirnya saja�',
#  'Pake alhamdulillah demi meraih jabatan, istighfar yai',
#  'Asal jangan mengeluarkan fatwa ya pak... dipapua tidak mengenal fatwa.., indonesia berdasarkan pancasila',
#  'diabaikan saja,� suaranya dikitkok',
#  'biasanya barang /pakaian yg dipakai pejabat harganya bakal naik',
#  'gila jabatan ki?',
#  'Ah biasa aja tuh',
#  'Berita yg bikin sewot fans sebelah nih ,tapi klo kenyataan nya begitu. .mau di bilang apa ?NTB juga kan ? Mereka mendukung tentu dengan alasan yg jelas ..spt papua misal  ..lah yg sering kesana dan bangun papua joko wi. .gmn mau menutup mata? ',
#  'Sy pendukung ahok.. golput',
#  'Mantappp... Keadilan sosial bagi seluruh rakyat Indonesia',
#  'ternyata besar minatnya....%uD83D%uDE04%uD83D%uDE04%uD83D%uDE04',
#  'Klau liat kdekatan dan jasa pak maruf hrusnya SBY mndukung dan mngusungnya\ntpi karena udh kplang baper dan udh kplang janji sama prabowo walau berat hati ya mau gk mau mngusung prabowo',
#  'Ketum demokrat sdh kagak ada giginya',
#  'Nafsu berkuasa ya.. Hahaha',
#  'Jelas bisa dimengerti... rakyat Papua merasakan sekali apa yg sdh dilakukan Pres Jokowi disana..prinsip keadilan nyata dilakukan bukan sekedar jargon politik... #2019OrangBaikHasilnyaBaik ',
#  'Ngomong ngak kuat krn kardus sdh di embat... kelakuan politisi sontoloyo',
#  'Coba pendapat bapak ini disampaikan ke junjungan bapak....ar. Supaya gak nyinyir.....kata beliau gak mungkin.',
#  'Ibarat bangunan mewah koalisi ini sebenarnya kropos dan rapuh...gmn mau mau menang ini, ngurus intern koalisi iji aja ga bisa...hidup jkw 2 periode',
#  'Hahahaha....seru neh...mantap masa PKS dan PAN aja yg dapat, sikatlah PD jgn mau dibohongi sama gerindra, pks dan pan..hahaha',
#  'Hajar bleh, sikat terus, masa cuma mereka doang yang dapat kardus PD engga, ayo jangan mau, tuntut juga bagian kardusmu�',
#  'Koalisi gak mutu.....percuma lo pada eker2.....nyungsep lo semua',
#  'Mau menuding dua atau tiga kaki juga gamasalah bos.Yg penting PKS sudah dapat 500 M.berarti pertahun 100M.lumayan kan coba klw ngandalkan dari hasil korupsi atau pemberian jangan2 di OTT sama KPK. Ahirnya gigit jari donk klw ini kan barter meskipun nantinya kalah & pasti kalah dlm Pilpres gamasalah yg rugi kan bukan PKS atau PAN paham kan sekarang?yg penting duitnya GERINDRA sdh keluar & klw ada bahasa untuk KAMPANYE itu kan cuma alasan saja biar garibut.',
#  'Yahh kenyataannya semuanya main 2 kaki dan oportunis.... mau apa lagi??? ',
#  'Andi juga aneh pake ngomong udah jelas parte kemunafikan sejati, cebong kejet2 gagal mupe on.',
#  'Yah... Apakah masih percaya dengan omomgannya?�',
#  'kalau panas dalam minum tuh kaki 3 biar adem..he..he.',
#  'Ketua diam ... Bisa dianggap seruju',
#  'Udaah mending bubar aja niih koalisi ga bermutu...bukanya bikin program malah ribut sendiri, mendiing bubar lagian sdh pasti kalah kok ngapain d lanjutkan�',
#  'Haqul.yakin Pekaes dan PANte nyungsep suaranya pemilu 2019�',
#  'Koalisi serapuh kardus basah',
#  'Andi Arief yg selalu menyerang koalisi sendiri ini kenapa tdk ditegur SBY. Ada apa di koalisi Prabowo Sandiaga ??? Padahal bersikap pura2 netral di Pilpres 2014 sama juga bermain 2 kaki, pak Andi.',
#  'Dulu mencari makan setelah menjabat jadi kaya2 bahkan daging juga di empat penjara dan akhirnya neraka',
#  'Nah lu.... Kena deh ',
#  'kardus kardus kardus.........mana bagian kardusku............ ',
#  'Politik cari makan alias parpol kardus.',
#  'Dia minta isi kardus tu',
#  'Badut badut politik...kerja nolll buat rakyat...nyir nyir bocor coorrrrrrr',
#  '%u2063jokowi menang mudah di pilpres 2019, democraaat nyungsep',
#  'jokowi menang mudah di pilpres 2019, democraaat nyungsep ',
#  'Lebih bagus cap kaki tiga..bisa buat kesehatan',
#  'kaki empat..%uD83D%uDE07',
#  'salam dua kaki euy...hahaha',
#  'Pak SBY itu kalau ngomong selalu pinjam banyak moncong mas. Kayak ban, bocor alus tapi keliling%uD83D%uDE03. Baru lahir ya?',
#  'Kl sudah berdasarkan data dan fakta ya susah untuk dijawab.. Hahahaha',
#  'Setdeh, kho seneng banget� ribut sich, rebutan apa lagi nech, ....eng..ing..eng ..datang Zonk ah nggak papa masih solid kho, itu hanya dinamika politik...capek dech.',
#  'Sesama begundal politik dilarang saling mendahului ...',
#  'Karena Aa pakai data dan fakta. Maka tidak bisa berbalas pantun. ',
#  'PAN - PKS sebaiknya diam klo ga punya kaca.�',
#  'Koalisi aja ribut. Gimana mau menang. Jargon doang kenceng kualitas NOL',
#  'Mari kita bertepuk tangan...sesama begundal sdh mulai ribut....',
#  'Kayaknya bener juga,� dulu kan koalisi Demokrat tp sering gak nurut',
#  'Diam itu emas',
#  'Lah ngapain jg ribut2 politik. Pilkada kemaren jg banyak koalisi ngacak. Politik disini ya gt, Cari sensasi doang.',
#  'bukan 2 kaki itu mah yg kita tahu .. tapi 4 kaki .. 2 kaki yg sah , 2 kaki yg siri ..kan ??',
#  'Main dua kaki saat pemilu sudah usai.� Bargain dan kompromi. Lah ini baru mau mulai. Haha Cerdas dong kamu dek�',
#  'PD, PAN, PKS semua ahli main 2 kaki, cuman gerindra yg ga punya kaki',
#  'Andi Arief, dicari bawaslu tuh.',
#  'Abis mau bagemana lagi ga mau rugi, maunya untung terus',
#  'Bertiga saling selingkuh',
#  'Andi arief ini awalnya mencak2 teriak2 terkait dana logistik 500M untuk kubu koalisi Prabowo, karena demokrat tdk di ajak bicara, sekarang diem dia di amankan oleh Sandi, wajar Andi arief ini ngebela demokrat dan SBY',
#  'tepatnya pan dan pks tergantung bayaran................',
#  'Satu koalisi aja udah gak kompak gmn mau menang, udah pd jgn ribut nikmatin aja dl kardus2nya.... mudah2 anjlog /hancura suara kalian di pemilu 2019',
#  'Salut buat timses PADI, dinamika adalah keharusan dlm sebuah perjuangan politik, ada perbedaan pendapat, kritik juga wajar2 saja, solid gak perlu harus yes semua, diam seribu bahasa spt dikekang & satu suara seperti koalisi jokowi, yg ujung2nya melampiaskan uneg2 dgn menyerang koalisi lawan...berbeda suara bukan masalah, tapi saling menghargai harus dijaga & dekati terus rakyat krn rakyatlah yg menentukan kemenangan di pilpres nanti',
#  'HAJAR......',
#  'Percaya deh,,klo jokowi menang lg,,pan akan merapat ke jokowi lg supaya dpt mentri lg,,kan kmpren brgitu',
#  'PD maen dua kaki di parlemen seabis pilpres, katenye netral tapi condong ke KMP',
#  'Kelompok sebelah pemain 2 kaki semua. Wkwkwkwk',
#  'Andi arif buang aja bikin rusuh aja',
#  'Ayo bertengkar lah aku suka hahaha',
#  'Andi arif knp ya..m',
#  'Jadi penonton ah... Menghibur..�',
#  'Ular beludak ini keluar lagi, setelah mumpet terkencing2 tdk berani bicara di dpn bawaslu. %uD83D%uDE03',
#  'Sudah tahu bahwa.... kalau berkata bohong .. tidak sesuai omongan.. kalau janji ingkar .. plinplan... kalau dipercaya ingkar.... tidak konsisten.... tahu munafik kok seteju.. yg waras siapa ya..',
#  '"%u2063.......pertempuran utama di Pilpres 2019 ialah Jawa Barat, Jawa Tengah, Jawa Timur, Sumatera Utara dan Sulawesi Selatan".  Jawa Tengah jelas sudah dijaga Ganjar, Jawa Timur ada mbak Khofifah, Jawa Barat kemungkinan dengan naiknya RK, Jokowi bakal menang, Sulawesi Selatan, pasti ada efek dari JK sebagai timses Jokowi, hanya Sumatera Utara yang masih bisa diperebutkan oleh kedua koalisi',
#  'Aduh....orang - orang jangan di pilih biar negiri ini tidak segera bubar.',
#  'Belah Sono ribut terus y',
#  'Mungkin sedang panas dalam (nambah satu kaki lagi)',
#  'kalo pks mah emang ga ada malunya.  ikut kabinet sby, tapi ngacak2 program sby...presiennya aja sampe makan aspal di jalan nangka noh.... ',
#  'ada hubungannya dengan kardus ga nih ???',
#  'Maling teriak maling, koalisi kok saling menjelekkan %uD83D%uDE02',
#  'bagus bro... hajar terussss ! ',
#  'Apa yang diungkapkan bung andi arif benar sekali, kita masih ingat waktu� pks ikut dalam kabinet pak sby, tapi apabila ada kebijakan dari sby selalu ditentang',
#  'Ni orang dri awal udh mulai ribet sebaik nya klo memang gk searah pecat ni pa sby..�',
#  'PD bubar ajalah.... Uda gak ada wibawa di mata kadernya. Apa karena ketumnya gak tegas? Atau mgkn hal yg sengaja dibuat utk main dua kaki alias mempraktekan politik bermuka dua?�',
#  'Lo pade ngomong ngaler ngidul ga jelas ... bangsa ini banyak masalah perburuhan, ekonomi, problem kebangsaan benturan umat dll... perlu strong leader ... PAS OK !!!',
#  'Gawatttt... Harusnya pak Prabowo kirim utusan mautnya kayak Ahmad Dhani, Neno, Sarumpaet ke Papua wkwkwk',
#  'Kader2mya PD cerdas juga, ga mau dijadikan boneka gerindrong cs',
#  "yang jelas, perolehan suaran Jokowi - Ma'ruf Amin akan bertambah.%uD83D%uDE06 ",
#  'kira2 kalau di adu dari sisi INTELEKTUAL, KECERDASAN, KESEDERHANAAN, KEPEMIMPINAN, KEKAYAAN dari 4 kandidat CAPRES - CAWAPRES siapa yg menang ya ... GAMPANG ... SANDI yg MENANG ... MUDA, KAYA, PINTER, CERDAS, SEDERHANA, DAN YG PALING PENTING ... SETIA SAMA ISTRI dan SAYANG ANAK ... GILA ... PERFECT BANGET SIH LO SANDI ... YG LAIN PADA MAIN BINI MUDA Sama SELINGKUH ... Lo yg Duitnya BANYAK KOK MALAH SETIA ... TOP',
#  '#2019jokowiPresiden',
#  'bagi 90% pengurus DPD demokrat di Papua ini, hati nurani mereka lebih punya integritas. krn mereka tau sesungguhnya siapa yg selama ini bekerja utk warganya. ',
#  'Rakyat papua tau mana presiden yang perhatian dengan Papua, mana yang pura-pura perhatian. Btw balikin kardusnya Sandi. ',
#  'jati diri gak pentinglah yah.......yg PENTING MENANG......klik google HAMBALANG....',
#  'Emang Jokowi masih diinginkan sebagian besar rakyat untuk menjadi Presiden 2 periode kok ',
#  'Masalah papua itu sangat gampang dan malah terlalu gampang merebut suara orang papua sbb orang papua gak denger gubernur asal di serahkan sama yg ahli nya di jamin 100% beres....yg jelas bkn masalah infra struktur sbb yg menikmati nya tetap pendatang sdgkn orang asli papua ttp jd penonton....serahkan pada ahli nya papua pasti prabowo -sandi...',
#  'Demokrat seharusnya join dengan Jokowi saja, tim Prabowo -Sandi ga butuh demokrat cukup Masyarakat-emak2-Gerindra-PKS-PAN saja sudah pasti menang di 2019 ',
#  'Woi kembalikan kardusnya kalo ga 100% dukung wowo....wkwkwk....',
#  'Alhamdulillah amin',
#  'Sebaiknya demokrat ke jokowi saja, tdk apa apa, PKS PAN Gerindra sangat solid',
#  'Harusx dpd tdk bisa mengatur dpp,kepututsan dpp harusx satu komando,miris jg ini',
#  'demokrat plin plan....',
#  'karna tdk terbendung, suara kader yg terbelah berobah strategi demi menutup muka yg sudah malu...kasihan demokrat',
#  '100% pak....soalnya Joko Wi orang baik ..... ',
#  'Rakyat papua merasakan langsung pembangunan era presiden jokowi.�',
#  'Hasil akhirnya dan saya yakin Jokowi kalah dipapua.',
#  'bagus, jangan ikut orang jahat. Saudara2 Papua merasakan pembangunan. ',
#  'Apa Kata? Gerinda Cs ya? Hayo apa? ',
#  'Karena papu maju',
#  'mbah Mien langsung kejang-kejang....',
#  'Mereka ini yg bener2 sdh merasakan langsung dampak pembangunan jalan  dan sebagainya di sana. Tidak bisa ditutupi dan disangkal lagi.',
#  ...]

# %%
#Membuat semua comments menjadi lowercase
low_comments = []
for comment in new_comments:
    low_comments.append(comment.lower())

# %%
low_comments
# Out:
# ['wkwkwk, gak sekalian pak, selawat ke dpr... kan banyak koruptor disana',
#  'mantab.. ini br dakwah yg sejati.. kl d tempat umum mah dh biasa . ini luar biasa.�',
#  'salut buat gus miftah',
#  'yg nyinyir gak pernah lihat dan baca atw mengetahui sejarah dakwah walisongo \\/ sunan kali jaga...smua ada cara demi kebaikan... asal jng ajk dg cara berjinah .... lakukan dg porsi dan sikon yg tepat',
#  'ada adabnya sholawat. lebih baik ajak ke majelis ilmu..',
#  'setiap ulama punya jalan dan cara dakwah masing2.., jika kamu melihat kemunkaran lawan dengan tanganmu(kekuatanmu) jika tidak mampu lawan dengan mulutmu jika tidak mampu juga dengan hatimu itulah selemah lemahnya iman.., itu sudah menjadi kewajiban para ulama, kalo yg komen masih ada yg nyinyirin ulama berarti otaknya sudah disisipin politik..',
#  'umpanin nocannya yak...',
#  'itulah ceramah yg sebenarnya. ',
#  'besok bugil aja selawat',
#  'bedanya gus miftah dengan fpi  / hti bagaikan surga dan neraka. di surga penuh kasih, di neraka penuh penghancuran.',
#  'knp di tempat kerjanya? mending diundang ke masjid, ponpes, aula. supaya berbusana yg sopan.�',
#  'nah ini ulama beneran...diterima di semua kalangan.....kl uas? malah diblokir sana sini',
#  'kerennn.... saya pernah dpt info seperti ini dr keyakinan yg lain tapi tujuan utama kurang lebih sama lah. kita ambil sisi positifnya ajah... terimakasih atas niat baiknya... saya yakin pasti bermanfaat.',
#  'hebat gus.lanjutkan!inilah makna dakwah sebenarnya, sampaikan marwah islam dengan penuh kedamaian dan berikan pemahaman, bukan dengan kebencian dan pemaksaan',
#  'diskotik syariah jadunya nih wkwkwk..mantap',
#  'niat dan tujuan yg baik pasti mendapat berkah dr allah swt.',
#  'mantaaapppp..buat di gedung dpr perlu jg kayanya gus',
#  'salut buat owner klub ini.....',
#  'josshhh ini baru luar biasa',
#  'dapat gratisan karena sudah punya nope',
#  'sebaiknya dimanapun dilakukan batas2 kesopanan tetap harus dijaga...',
#  'pemandu lagi yang di manga besar keknya perlu juga diajak mengaji, bos!',
#  'jujur ini kereennnnnnn cara menyebarkan agama yang baik dan snagat simpatik semoga sukses',
#  'katimbang alim kemudian jadi maling, menurut saya lebih baik maling kemudian jadi alim ....',
#  'sebenar ulama, mengajak mereka yg masih tersesat untuk kembali. bukan menjelekkan orang lain, tp merangkul mereka�',
#  'ini namanya apa ya?',
#  'selamat berjuang gus,justru tempat seperti itu yg butuh lebih bnyk perhatian dr ulama.',
#  'semoga diberikan hidayah..  ',
#  'hati hati memviralkan berita yang mengandung isu agama bisa menjadi sumber fitnah dan lahan para bedebah yang kerjanya mengadu domba anak bangsa dan rakyat indonesia ahok sudah jadi korbannya',
#  'subhanallah..... semoga mendapatkan hidayah dari allah swt. amin......',
#  'ulama ngurus umat berarti jenengan gus...',
#  'luar biasa, salut...terharu, mengajak orang lain yang dianggap salah dengan cara yang baik, bukan dengan cacian...luar biasa..',
#  "what's up boshe....",
#  'lol jadi ketahuan dong isinya boshe bali bukan org bali %ud83d%ude02%ud83d%ude02',
#  'poligami aja guss',
#  'harusnya dibakar tempat begituan kalik',
#  'hahahaha,  bahasa hastag y kalo d plesetkan jadi y santri gaul itu yg suka sholawat dan suka dugem... hahahaha rusak islam d biaskan seperti ini, ustad y dateng k sono dugem dulu lalu sholawat lalu dugem lagi,  dan d sebut santri gaul.....????????? ',
#  'knp yg kayak gini berita nya keluar nya pas mau pilpres aja ya...?',
#  'naaaah ini baru bener, ceramah atau ngajak orang yg belum bersholawat utk bersholawat. ga kaya somat, ngajak orang sholawat koq ke orang yg udah bersholawat. maaaaat mat!!!!',
#  'gila nekat juga ulamanya gak tau di usir gitu,, tapi bagus lah ada keberanian dan semuanya jg mendengarkan.. semoga banyak ustad lainnya yang meniru hal ini. ',
#  'tambah tempat... mantap sak cewek seksi nya....dan yg paling penting bole... yg g setuju pasti ngiri...week',
#  'mengajak orang melakukan sholawat di tempat ibadah ya sudah pasti mudah, tapi mengajak orang melakukan sholawat di tempat dugem yang penuh cobaan itu sudah jelas pahala nya jauh lebih besar...',
#  'apa sih yg nggak bisa di negeri ini.. semua pada bisa sekrang,,',
#  'boleh ya menyebarkan agama seperti ini?�',
#  'hahahaha. �lucu lucuan. biar masuk tipi laah. hahaha',
#  'coba lah ustad yg lain dakwah di nite club spt iti',
#  'yang ini malah di dukung, yang di sana di jagain supaya ga ceramah. apalagi ini. ',
#  'ah entahlah. satu kau maklumi, yg lain mengikuti. tinggal tunggu saja.',
#  'mau ngikik takut dosa',
#  'kalau mau melakukan ibadah. perbaiki dulu penampilan, jauhi miras, cari tempat yg lebih baik. lebih baik gus kamu mengajak para wanita itu menutupi auratnya.',
#  'lokalisasi harapan sadar',
#  'setelah selawat selesai, acara selanjutnya ?',
#  'bagus. lanjutkan..�',
#  'bagus itu biar sadar islam tdk mengajari kaumnya buka aurat bagus lanjut',
#  'banser anshor mana suaranya.....ormas liberal',
#  'pans itu ketika simbah yg bicara selalu dibully karena kata katanya terkesan emosional ,nantang nantang ,pdhl ketika tantangan bisa di buktikan oleh yg di tantang trus diem.. tdk ksatria ngakui, dan  sering menjelek jelekkan orang lain ,inilah yg jd penyebab sering di bully dan orang lain jd gak simpati .mungkin dia dengan berkata seperti itu merasa hebat... dia tdk sadar saat nyapres pun rontok, saat thn 2014 pun keok. artinya rakyat g percaya.seolah bicara dulu urusan belakang spt janji jalan kaki jogja jakarta. . terbukti ?gak kan ?....ini mungkin hal  sepele bagi dia,  tapi itu tertanam di ingatan orang,hingga berkesimpulan  klo hanya bisa ngomong tok.. nglakoni ora iso. ',
#  'karena mendukung jokowi jadi tidak dicopot',
#  'banyak orang pekalongan yg kemakan hoax',
#  'pan ancur lebur gara2 si amien rasis ... makasih amien ... lanjutkan!!! ... #2019panbakalgurem ...',
#  'padahal sutrisno bakhir ini dulunya merupakan penyandang dana pak amin rais saat awal reformasi. akhirnya berjalan sendiri2....�',
#  'orang bener malah tidak dipake di pan..sutrisno itu sdh habis2an demi pan, tapi tetap tdk berdaya melawan amien rais...pan cahayanya semakin tidak bersinar sejak amien makin kumat..',
#  'lagu lama...',
#  'pan sekarang butek karena di-obok2 si amien.',
#  'karena mendukung jadi tdk dicopot.',
#  'masak sih dari beberapa ex pemimpin pan yg punya pikiran sehat cuma pak sutrisno�',
#  'tolong dikoreksi untuk jabatan pak pramono itu menseskab bukan mensesneg. terima kasih.�',
#  'mantap bukti orang baik pasti banyak yg mendukung salam 2 periode',
#  'ksih mkan buaya aja org kyak gini',
#  'mantab... penyebar fitnah bisa tidur di bui jg akhirnya...',
#  'allahuakbar. alhamdulillah akhirnya para ahlul fitnah penebar kebencian tersebut dipenjara juga. sudah cukup lama mereka menunggu nikmatnya lp cipinang.',
#  'selamat menikmati hukuman dunia atas prilaku fitnah menebar kebencian. hukuman akhirat yg lebih berat menunggu anda para ahlul fitnah penebar kebencian.',
#  'dasar preman ngak tanggung jawab.. kok malah buron.. katanya lu anak buah wowo yg ......bocor bocor itu hehehhe',
#  'orang grindong gak akan ngomentari brita ini, krena sebagian tabir obor rakyat sdh dibuka sebagian oleh rommy',
#  'ayo, gerombolannya kok nggak ada yang komentar nih? biasanya koar2, bilang pelanggaran ham, seperti menangkap teroris, pakai senjata lengkap dsb....',
#  'sik asik.. selamat menikmati hotel prodeo kawan, siapa menebar angin dia menuai badai.. ',
#  'buni yaniiii  dimana anda ??? kejaaarr !!!!',
#  'wowo ga sekalian ?',
#  'jangan tangkap pimrednya doank, tangkap penyadang dana dan hubungan mereka dgn kandidat capres yg diusung',
#  'walaupun cuma 1 tahun ente sudah dapat gelar mantan narapidana\nmenjelang pemilu buat lagi biar dikurung 10!tahun makan gratis',
#  'gantung az',
#  'sekalian buni yani biar adil ,,',
#  'kirim ke kamar bonita.  \n\n# bonita itu nama macan',
#  'gua paling senang liat ginian. buronan, sensasinya kayak di film2 hollywood',
#  'tungguin aja nih, bentar lagi kubu prabocor terutama zonk bakalan komen. liat aja. ',
#  'karena kabur, tambahin yah hukuman nya',
#  'ini kabar terbagus yang boleh kudengar hari ini. ',
#  'telat kabur tong?..kaciann..',
#  'nyari duit dr nyebar fitnah..duitnya buat makan anak istri..mau jd apa anakmu makan duit gituan?',
#  'semoga bahagia di rumah yg baru',
#  'periksa bank account nya, atau bank account keluarga, ada transferan nggak dari wowo',
#  'semoga bisa belajar untuk tdk mencari nafkah dari uang hitam dengan cara yang hitam',
#  'suntik mati',
#  'sikat semua org org pengacau negeri demi uang, apalagi mo pilpres malah bikin kacau negara klo ga segera dikarungin',
#  'habisin aja jok orang yang gangu elu jadi presiden lgi',
#  'nunggu buni yani kapan ditangkapnya,  pdhl sdh ada putusan pengadilan jg',
#  'koq cuma setahun ?',
#  'laaaahhh bukannya kata nasbung, pemred obor rakyat diangkat jadi prekom bumn?...weleh..weleh...itu fitnah lagi dong',
#  'kapan buni yani???',
#  'sip, tinggal yg kabur umroh ga balik2 segera dieksekusi pak pol.',
#  'yg model ginian main fitnah sih mesti di kandangin',
#  'mantap',
#  'sip',
#  'semoga pas di dalam penjara...kedua2nya gantung diri',
#  'terbukti memfitnah, bukan menghina. dan ingat, fitnah lebih kejam dari pembunuhan, bro',
#  '+hukuman mati.',
#  'alhamdulillah si penebar dosa sudah tertangkap.',
#  'jokowi sudah memaafkan, tapi ... proses hukum tetap berlaku, bos ...',
#  'hmm',
#  'siap2 buat gerombolan micin ama nasi bungkus..',
#  'tambah hukumannya karena mau kabur ',
#  'lho kok cuma 1  tahun 5 thn pantas kok',
#  'yg menjamin mau mem back up mereka pada kemana? mau menemani mereka hidup bersama di lp cipinang? jangan macem ayam sayur... lari lintang pukang meninggalkan kawan.',
#  'gagah saat bikin obor rakyat, mewek dan buron saat diproses hukum. dasar preman gembeng, kalau begini apakah orang yang anda junjung akan gantian membela anda?',
#  '#2019gantipresiden kelihatan bgt tebang pilihnya, hukum tajam ke lawan politik, tumpul ke cebong😏',
#  'orangnya tambah gemuk makan uang sisa anggaran obor rakyat.',
#  'buset dah..jamintelnya tetangga sebelah rumahnya sendiri...miris',
#  'bisa jadi 2019 muncul petromak rakyat 😹😹',
#  'kalau sudah dieksekusi ngga lagi dilindungi kan sama janji back up kalo kena masalah. hehehe\nmakan tuh janji saat kampanye',
#  'makan pencarian lu tuhhhhh',
#  'selamat ya',
#  'masih muda,buaknnya mendukung presiden generasi muda.payah.  ',
#  'yess tidur aaaah biar cepet besok, ada yg berani taruhan siapa yang belain mereka? ',
#  'tukang fitnah. hukum seberat2nya',
#  'hrsnya min. 10thn di sel...',
#  'nah ini dia.. paling lawyernya habibu.. getombolan nasi bungkus micin jantungan',
#  'cuma 1 thn?... enak bener.',
#  'ini bodoh amat, cuma 8 bulan seharusnya jangan banding, malah jadi 2 tahun!',
#  'bos nya sikat ',
#  'mari kita tunggu, siapa saja yg nyinyir atas penangkapan ini... ',
#  'muka2 tegar menjalani hukuman',
#  'bosnya dah ketangkap blum? ',
#  'wowok cs banyak mudarat nya',
#  'bravo kejaksaan, selamat bertugas.',
#  'hukum seberat-beratnya.',
#  'kalo cebong mah gk di tangkap, kebal hukum spt viktor laiskodat, ade armando, nathan, ananda sukarlan, dll. #2019gantipresiden😏',
#  'good job, jgn lupa gerombolan surveyor ines juga hrs diawasi, dr pada menyebarkan hasil survey abal abal apalagi mo pilpres malah bikin perpecahan ',
#  'sdh dibongkar kan sama pak romi.. pasti ada pendananya.. si kejar juga pak jaksa..terus pak berjuang.. demi bersihnya negara ini dari tukang fitnah',
#  'usut dana nya dari mana itu baru hebat👍',
#  'silahkan bernyanyi denga  bebas walaupum sumbang...tempat telah disediakan...wkwkwkwkkw',
#  'kok cuma setahun ???   ',
#  'ayo donk polisi. kalo nangkep2 kaya gini dicari tahu bosnya siapa? siapa yang memberi dana? terus kalo udah tau, tangkep lansung!',
#  'disate aje pak jaksa',
#  'tembak jidat nya',
#  'tangkap bandar dan pemimpin gembong hoaxnya biar jelas',
#  'tukang fitnah plus juragannya wajib dihukum',
#  'sudah terbukti komplotan sana cuma bisa fitnah hoax pki.. kerjanya ngga ada',
#  'mendingan ditenggelamkan aje',
#  'aktor intelektual yang mendanai kerja obor rakyat untuk kepentingan politik sang aktor intelektual juga harus di tangkap dan ditenggelamkan ',
#  'mo bgs atau ga..presiden itu kepala negara yg hrs dihormati..kl lu hina ya pantaslah msk bui',
#  'mo bgs atau ga..presiden itu kepala negara yg hrs dihormati..kl lu hina ya pantaslah msk bui',
#  'mo bgs atau ga..presiden itu kepala negara yg hrs dihormati..kl lu hina ya pantaslah msk bui',
#  'tukang fitnah dan penyebar hoax.... tenggelamkan !!! ',
#  'hhahahh ya jelas uda ketebak... negri dagelan...  yg komen jga blaa blaaa blaaaa 😂🤣😂🤣 lanjutakan saja... ',
#  'terima kasih kejaksaan.',
#  'pak jaksa yg hina pak jokowi berkali2 pasti pak jaksa tau lah..tolong di seret ke penjara. thanks..',
#  'sekalipun benci dng jokowi bukan berarti menebar fitnah, biar bgaimanapun jokowi itu presiden pilihan rakyat...\nmemfitnah presiden = memfitnah rakyat.',
#  'buron... wkwk',
#  'kalo di turki, ini orang sudah diciduk langsung oleh erdogan (presiden idaman nya pks 🤣)... untung lah di indonesia ini presiden nya jokowi yg orang nya lembut dan kalem 😁',
#  'kalo dulu menang.. udah diangkat menteri nih orang',
#  'kalo dulu menang.. udah diangkat menteri nih orang',
#  'kalo dulu menang.. udah diangkat menteri nih orang',
#  'kalo dulu menang.. udah diangkat menteri nih orang',
#  'kalo dulu menang.. udah diangkat menteri nih orang',
#  'boss nya juga sekalian disikat toilet',
#  'boss nya juga sekalian disikat toilet',
#  'jadi inget jaman siapa ya...',
#  'orang bikin rusak harus musnahkan',
#  'super muantap👍👍👍',
#  'baguslah diciduk, sebelum dikontrak lagi sama tukang fitnah',
#  'menjelekan presiden sama saja menghina lambang negara. harusnya berpikir apalagi seorang redaksi berita yang seharusnya menjadi panutan beritanya.',
#  'semoga betah di hotel prodeo ya bro....',
#  'sebaiknya orang spt ini dilenyapkan saja',
#  'sikat ikat berkas ',
#  'fitnah krn duit 😆 ',
#  'tlg dikubur dalam2 org begini',
#  'langsung buang aja kelaut',
#  'tunggu siapa yang komen membela...nah itu donaturnya',
#  'buniyani gmn?',
#  'kokk lama sekali pelaku kejahatan hoax ini baru dijebloskan ke bui sekarang....  usut dan tangkap segera pelaku hoax lainnya....  ',
#  'obor hoax',
#  'bravo kejaksaan,lumayan ada kerjanya..',
#  'mantap, hajar penyebar hoax. ',
#  'yg di negri sebrang bgmn',
#  '4 tahun? pantesnya 40 taon',
#  'itu dlu timses syp ea?',
#  'masih bisa gaya gaya an....\nlihat baju mereka seperti.......',
#  'mudah 2 an di hukun lebih berat lagi',
#  'wkwkwkwkwkw syukurlah kalian banding soalnya hukuman kalian bakal di tambah jd 10 thn, nyungsep kalian .',
#  'sakit jiwa luuu...',
#  'sakit jiwa lluu...',
#  'kasihan bener mas eko, semoga dapat jalan keluarnya..',
#  'jahat sekali yang nipu',
#  'sebutin aja pengacaranya',
#  'nah, mulai terkuak biang keladinya ... siapkan bukti2 penyerahan surat2 dan tanda terima uang ... dikasi ga waktu entu? ... kalo ga ada bukti, jangan kau harap bisa gugat pengacara ya .... ',
#  'semoga dapat pengganti pengacara kondang mas... yang kemarin itu abal abal punya',
#  'kasian mas eko ini, bisa2 dituduh lg sama cebong sebagai sebar hoax krn tdk ada buktinya.',
#  'yang komentar pada ga tahu tentang bagaimana sertifikat dibuat. sertifikat itu bisa muncul kalau ada akses jalan. suruh dia tunjukin denah sertifikatnya (kalau dia memang punya). itu pasti sertifikatnya masih gabung ama sebelah kiri atau sebelah kanannya, dan itu pasti masih saudara dia. sertifikatnya belum dipecah ama mereka berdua.',
#  'nanti pintu surganya juga diblokade sama tuhan.',
#  'sdh bp camat yg harus menyelesaikan biar p camat dpt pahala membantu yg tertindas , toh ga lama lagi kita mati dan runah tanah itu tdk di bawaq',
#  'saya tahun kemarin beli tanah 20 �15 m. tapi saya bikin fondasi pagar 19 �15m. jadi ada 1 meter untuk akses jalan setapak. berarti saya relakan tanah saya 1�15m utk kepentingan umum. tetangga sebelah juga demikian. jadi jalan setapak lebarnya 2 meter. kita kan hidup bertetangga. masa tanah satu meter aja menghalangi silaturahmi dengan tetangga?  jadi harus dibicarakan baik-baik. semua bisa diatur yg penting dengan hati nurani. ',
#  'lemah mati (tidak ada akses jalan) itu murah harganya, lha ini yg punya tanah maruk ud deal 100jt minta naik 150jt. jengkel di tutup sekalian ma tetangga. yakin tuh yg punya tanah mati pasti kolot jd dikerjai tetangga.�',
#  'klo tdk salah ada undang-undang (pertanahan) yg mengatur tentang kewajiban bagi pemilik tanah dan bangunan untuk memberi akses jalan bagi pemilik tanah dan bangunan dibelakangnya yg tdk memiliki akses jalan dlm sertifikat tanahnya (istilahnya tanah helikopter) minimal jalan setapak, silahkan dicek saya lupa pasalnya. ',
#  'tidak berperikemanusiaan yang nutup akses itu. maukah dia diperlakukan seperti itu? tanya ke kupingnya dengan keras: maukah dia diperlakukan seperti itu jika berada di belakang rumah orang lain?',
#  '%u2063sepertinya ada yang " kurang beres" dengan sertifikat-nya di antara rumah rumah itu, logikanya rt\\/rw, lurah,camat , bppn waktu menerbitkan sertifikat itu pasti tahu posisi dan batas batas rumah. pasti ada yang "salah" dengan sertifikat sertifikat itu tentang batas-batas tanahnya. minimal ada hak orang yang diserobot. polisi harus turun ini.',
#  'priksa dulu imb nya ada gak?� kalau gak ada suruk satpol yg bongkar jangan korbankan tetangga',
#  'sebelum semuanya menjudge tanpa tabayyun..simple utk mencari siapa yg salah..yg diakui selama ini sbagai akses jalan pak eko ini sebenarnya memang peruntukan jalan atau menggunakan /melewati tanah orang lain?klo memang akses jalan,tetangganya jelas salah!tapi klo itu memang tanah org lain,ya memang haknya dia utk menembok.yg salah adalah pemerintah setempat.mana akses jalan selama ini yg harusnya ada',
#  'yang punya tanah nggak bisa disalahin juga.memang itu haknya dia.klo dia dituntut harus ngasih sebagian untuk jalan,tetangga kiri,kanan n belakang pak eko juga harus dituntut hal yg serupa.apesnya dia adalah dia baru beli n bangun skrg.',
#  'kasih jln pak.itu ladang amal bpk�',
#  'klo ud deal 100jt kok ingkar jd 150jt ya??? hrsnya jgn serakah jg ya klo emank maunya 150jt ya jgn buka 100jt donk...ntar ada yg mau 150jt ingkar lgi 200jt...',
#  'akar masalah nya.. � � � � � �duit ',
#  'ya sudah to pak eko, pindah aja. rumah lama jadikan kandang ayam atau studio musik. kan haknya pak eko juga to? saat ketemu tetangga yang gak pedulian, ya sudah jadikan kita gak peduli. ngalah terus tidak selamanya baik.',
#  'benernya siapa sie yang mau beli siapa yang mau jual,? kok keterangan camat beda sama eko? eko bilang dia yang mau beli tanah tetangganya buat jalan, kata camat malah eko yang mau jual, malah harga naik pula....ini yakin ada yang ga beres sama si eko...',
#  'gak pernah belajar pmp, mana toleransi,saling menghargai,ssopan santun,empati dalam bertetangga.',
#  'dulu sudah mau dibeli 100jt tapi ga jadi karena naik minta 150jt giliran dibikin tembok merengek rengek ngadu kesana kamari... lebay',
#  'ujung ujungnya duit',
#  'sdh terbaca...pokok permasalah nya...',
#  'camat koq minta2. keluar dari kantor kalian itu hei camat, lurah. jgn ongkang2 keq kumpeni aje lu pade.',
#  'jangan maen asal ngomong nuduh salah satu pihak. masalah ini terjadi bukan krn pihak yg bersengketa saja. ada peran rt rw lurah camat serta pihak pertanahan. rencana tata ruangnya mana? masing2 punya andil dalam terjadinya masalah ini. bukan serta merta gr2 pihak pak eko ataupun tetangganya.�',
#  'pny tanah pribadi jng dibuat jalanan, nnt diserobot%ud83d%ude0b',
#  'jadi sudah jelas to akar masalahnya..lain kumbang lain belangnya...%ud83d%ude02',
#  "seharusnya ke pangadilan saja. apapun hasilnya itu yang akan diakui secara hukum. kalau curhat kemana2 pasti hanya dapat lip service saja, karena mereka hanya bisa 'menghimbau'...",
#  'sdh mau dibeli 100jt, tp naik jd 150jt lg....dr sini sdh sdkt jls akar mslhnya',
#  'ko masih ada ya orang kaya gitu..tinggal di perkampungan ..mending di kubur aja',
#  'spekulasi tu. yg jd pertanyaan ketika jual beli kan ada form tanda tangan sepengetahuan jiran kanan kiri dpn blkg. dr situ sdh dpt awal masalahnya. kmn tu pak rt rw, kadus n kades???',
#  'klpun d kasih jalan jg mending pindah aja pak...punya tetangga kayak gitu modelnya susah liat orang senang,senang liat orang susah',
#  'knpa setelah viral di medsos, camat nya baru turun tangan,� pak eko bilang sdh 3 thn mondarmandir utk cari solusi...� jadi klu ada masalh sprti ini, mendingan di viralkan,� spya cepat ditanggapi ',
#  'masoook pak eko',
#  'tetangga kayak gini harus buru buru di mandiin, di solatin, di kafanin dan dikuburin langsung. ga ada adabnya.',
#  'gabisa masook pak ekooo',
#  '"%u2063saya enggak nyebutin kronologi karena privacy" hmm ada yang aneh',
#  'disini banyak pendukung tetangga pak eko atau mgkn tetangga disitu? wkwkww ',
#  'dijual ke tetangga depan/ samping saja pak ',
#  'rt rw lurah camat bpn walkot /bupati tidorrrr semuaaaaaa',
#  'masssook pak ekoo',
#  'harusnya dipikirin sejak dini, kalo sudah begini bingung dah lu eko.....%ud83d%ude33%ud83d%ude33%ud83d%ude33 slh elu sendiri    ',
#  'kalau mau jual ya ke tetangganya... gak usah cari sensasi... banyak kok org lqin yg rugi lebih banyak utk urusan2 tanah... bahkan tanah dgn surat berlapis juga ada.. toh yg rugi pemilik... org bpn palingan hanya di mutasi.. apalagi kl sdh pensiun, gak ada sangsi apa2...!!!!!�',
#  'ini eko nya yg bodohhh sejak awal%ud83d%ude06%ud83d%ude06%ud83d%ude06  ',
#  'undang2 sdh mengatur klo pembangunan tidal boleh menutup akses jalan bagi rumah atau tempat tinggal yg sudah ada sebelumnya, mohon koreksi klo salah',
#  'kayak nya si eko ini punya kelainan cara bertetangga deh....',
#  'masooookkkk pak ekooo....',
#  'pak eko punya imb?� kok bisa bangun rumah� tanpa halaman?�',
#  'solusinya ya jual ke tetangga depannya itu pak. hitung harga tanah saja karena memang rumah \\/ tanah bpk di block sama dia ,banyak yang seperti itu "istilahnya lock land " jadi memang dia beli atau bpk bisa juga beli tanah didepan untuk akses .',
#  'beli aja tanah tetangga atau jual rumahnya ke tetangganya',
#  'ya harusnya dari awal pak eko sudah membuat jalan utk rumahnya sendiri. bukan nya membuat rumah full bangunan, tp disisakan utk jalan. hak tetangga jg membuat rumah di tanahnya sandiri seperti yg dilakukan pak eko. kejadian sebenarnya masih misteri siapa yg salah dan yg benar masih abu2..',
#  'masuk pak eko !!!',
#  'tata ruangnya amburadul',
#  'sebetulnya yg paling salah adalah bpn... karna di peraturan agraria terutuang hukum mengenai pemberian jalan kepada tanah yg tdk memiliki jalan... cth tanah yg di tengah telah disertifikat... di kanan dan dikiri pun telah bersertifikat dan menutup jalan... di depannya jg dibuat sertifikat dan menutup akses yg ditgh sementara blkg belum... nah ketika belakang membuat sertifikat secara otomatis yg belakang akan kepotong tanahnya dan memberikan akses jalan yg ditengah... cuma masyarakat bnyk yg awam dgn peraturan tersebut...',
#  'ketua rt rw lurah ko pd diem ayu bantu warganya masa kalah gantian tutup jlnnya',
#  'kemungkinan besar ada yg gak beres dg proses penerbitan imb...',
#  'bisa dirundingkan .lha sebelumnya ditawari tanah tetangganya tidak mau .ya bukan salah yang memblokade� .makanya harus baik baik dengan tetangga dan pengurus rt setempat�',
#  'tdk diperbolehkan (perda) membangun tp merugikan tetangga (walaupun di lahan sendiri), biasanya jika trjadi spt itu dinas pengawasan pembangunan akan bertindak.',
#  'masuuukkk pakk ekoo',
#  'pastinya orang ini bermasalah dengan tetangganya ....',
#  'jual sama yg ngeblokade',
#  'silaturahmi dgn tetangga itu penting. walau akses ditutup kalau tetangga seperti saudara pasti dikasih jalan... tinggal ketok rumah tetangga terus %u201cmasuk pak eko%u201d',
#  'imb bisa keluar?',
#  'ya hak tetangga juga blokade jalan karena mungkin itu tanah tetangga, harusnya di musyawarahkan baik2 dgn tetangga, klo kita baik ke tetangga gak mungkin tetangga akan setega itu memblokade jlan.�',
#  'waras slamet pak eko tenang aja gusti tak sare',
#  'mana kades nya??? masa ada warganya yg bermasalah gini ga diselesaikan',
#  'surat kog dilempar memangnya koran ??? meskipun bener koran apa sopan lempar koran ke presiden ???? apa gak bisa dititipkan suratnya lewat paspampres ???? ',
#  'ya jelas dikejar pampapres, ngelempar benda seperti itu ke presiden. itu sudah tugas mereka menjaga presiden',
#  'sifatmu mungkin juga ga benar. main lempar surat tanpa pikir kesopanan.  instropeksi pak eko',
#  'tetangga masa gitu ??',
#  '%u2063sepertinya ada yang " kurang beres" dengan sertifikat-nya di antara rumah rumah itu, logikanya rt\\/rw, lurah,camat , bppn waktu menerbitkan sertifikat itu pasti tahu posisi dan batas batas rumah. pasti ada yang "salah" dengan sertifikat sertifikat itu tentang batas-batas tanahnya. minimal ada hak orang yang diserobot. polisi harus turun ini.',
#  'wah kalo saja sampe ke telinga jokowi pasti akan dibuatin flyover',
#  'bandung / jabar ada gubernur baru... kalau yang dulu emang parah, sekarang lapor pasti di beresin... ngak semua-semua ke presiden kalees',
#  'katanya pak camat tidak tahu ',
#  'yang memblokade pasti orang kuat juga orang penting, sampai camat gak bisa nyelesaikan.',
#  'sudah bodoh mau menang sendiri, ini problem di daerah2 mengharapkan tetangga memberikan jalan, sementara mereka banyak yang membuat rumah atau pagar melebihi ukuran sk tanah yang dimiliki alias menyerobot tanah tetangga.',
#  'coba ke kopi joni lahh',
#  'kalau semua ke jokowi ya ga mungkin.  ada jutaan masalah di indonesia.  urutannya itu bisa minta mediasi didampingi rt/rw ke kelurahan, kalau gagal ya ke kecamatan.  kalau ga bisa dateng mediasi, ya tulis surat resmi ke kelurahan, kecamatan, kotamadya.  kalau tidak ditanggapi bisa tulis pengaduan ke ombudsman.  banyak kok permasalahan yg sampai ke ombudsman, dan langsung di follow up antara 1-2 bulan.  ga usah tunggu 3 tahun ngejar2 presiden.',
#  'tp msh bisa keluar rumah ga?',
#  'inilah contoh manusia indonesia jaman now yg katanya pancasilais ternyata egois tk ada toleransi sedikitpun kpd sesama pd sesama tetangga.... rt rw lurah nya camaunya walikota nya gubernur nya pancasila nya mana?',
#  'akalnya aja kurang pinter, itu bikin lif sampai atas genteng kan bisa, terus bikin tol diatas genteng sampai jalan raya, hehehe....',
#  'pertanyaanya...???  bagaimana hubungan bertetangganya kok sampe tega di block gitu?  kita tdk tau ada permasalahan apa.  sedangkan pak eko slalu bilang privacy.  lha piye to?',
#  'surat rumah pak eko ternyata gak beres. pantesan gak ada yg bisa belain krn secara hukum pak eko melakukan pelanggaran. ternyata pak eko minta simpati publik pdhal secara hukum dia bersalah.',
#  'knapa buat rumah tidak membuat akses utk jalan sendiri? bearti selama ini mengambil jalan dari tanah orang lain? mengambil hak tetangga utk kepentingan sendiri? ',
#  'mungkin pak eko disuruh bayar akses jalan tp g mau... kl spt ini ya g akan ada titik temu.  krn pemilik jalan mumgkin beli keseluruhan tp pak eko minta cuma2 doang. tiap jengkal tanah itu berharga,  apalagi diperkotaan',
#  'aneh sih memang kelakuan tetangga sprt ini. biasanya sih....mhn maaf, yg sering model2 tutup jalan, tutup got krn itu dulu tanah engkong gw, itu dulu punya babak gw...kan bukan orang sunda.',
#  'salah sendiri lah kenapa dulu gak dijual aja tuh rumah. jual murah aja sama tetangga pake njop jgn pake harga pasar. dungu dipelihara !! ',
#  'aparat kecamatan sama desa nya saja..� yg gk becus buat me mediasi masalah seperti itu..� ganti langsung camat sama lurah nya.. kok ada masyarakat nya susah gk segera di bantu penyelesaian masalah nya..�',
#  'mas eko anda harus info ke media sewaktu anda sudah melaporkan ke dinas terkait bahkan sampai gubernur dan tidak ditanggapi.ada hrs cerita siapa saja sehingga anda tidak sebar fitnah.biar oknum2 ini biar ditindak bila itu benar adanya.jgn pernah takut',
#  'rt rw kelurahan camat.� gk becus�',
#  'sabar pak eko semua akan di selesaikan dlm hitungan jam tp di tahun 2019 setelah rezim berganti....',
#  'hhhh aneh org lempar kertas dikejar tapi org bisa nepuk jokowi wkt touring motor ga diinterogasi atau dilumpuhkan paspampres....setting pencitraan atau paspampresnya yg ga becus ngawal presiden?',
#  'teu make duit mah... rek aya anu peduli kumaha atuh kang..?� sing sadar weh ayeunamah.. urang hirup di nagara kos kumaha...� ',
#  'kelihatannya semua tanahnya� sudah ber sertifikat, kenapa tidak di pertanyakan ke badan pertanahan. seharusnya tidak ada penerbitan sertifikat tanpa ada jalan melalui tanah tersebut, kalo tidak ada tanggapan dari bpn, maka ajukan gugatan ke ptun dimana bpn sebagai tergugat 1.',
#  'harusnya waktu dikejar nyerahin diri aja biar pak jokowi tau masalahnya.. tapi kenapa bapak lari sih.. itu kesempatan emas padahal pak...',
#  'pemerintah bandung gak becus kerja',
#  'ya iyalah, maen lempar aja.�',
#  'sebenarnya masalahnya apa? kenapa tidak ada penyelesaian? mana bupati bandung? kenapa diam diam saja. minta dipecat ?!!!',
#  'coba diselesaikan secara kekeluargaan.. dg hati dingin tanpa erosi insyaallah ketemu jalanya.%ud83d%ude0e',
#  'aneh?? segitu egoisnya kah paravtetangga? rt rw sama lurah gak bisa tangani kah?? mudah2an masalah ini nyampr ke jokowi biar masalah selesai... sebenarnya masalah kyk gini bukan urusan presiden.. karena nyangkut2 urusan paspampres atau oknum yg ngaku2 paspampres jadi gak ada salahnya pak jokowi bantu selesaikan masalah',
#  'sepertinya dua pihak� awal nya sama2 kepala batu... sehingga kejadian seperti itu akhirnya...',
#  'kok bisa bangun rumah tp akses ke jalan nya ga ada? pasti ga ada imb nya yaaa',
#  'tetangga gila...',
#  'jual aja rmhnya pa... gitu aja repot!',
#  'gimana mau nuntut hak? bukan tanah nya kok yg di sekitar nya???? sdh tau dari dulu sehrsnya jual pindah dong.  ',
#  'apes...stress...nasib orang kecil...',
#  'gambar lokasi bangunan beserta tetangganya bisa diupload jg min',
#  'ada kades, camat, walkot, gubernur, semua dpt gaji dr negara, ada hirarki job description�',
#  'wahh tetangga serahkan, sabar mas di dunia tetangga anda luas tanah nya,nanti di alam kubur dia akan sempit tanah nya,, trs bernaung cari keadilan�',
#  'lah katanya kelurahan,kec,walikota nggak tahu,teryata udah dilaporkan,teryata sosmed memang tempat megadu yang baik',
#  'tempat mengadu yang ditanggapi mah di sosmed, wk...wk...wk...',
#  'caranya salah pakai lempar kepala negara. kalau di negara lain mungkin sdh dihukum berat. kalau di us bisa2 ditembak secret service. mengapa tdk mengadu ke walikota atau gubernur dulu.',
#  'emang punya hak atas tanah yg dilalui ngga? jgn sampai berbalik merugikan diri sendiri.',
#  'gimana rw, dan lurah serta camat apa tidak ada solusinya, atau mungkin yg masang tembok itu pingin beli tanahnya pak eko',
#  'berita sebelumnya ada photo serifikat dan jelas ada jalan dan gang. ',
#  'aneh..sekali',
#  'ya di modif saja dan dinkmati, ya resiko kalau punya lahan/ rumah di tengah dan ngak ada akses, atau jual saja sama tetangga yg nutupin, uanganya buat cari rumah baru....',
#  'hehehe, smp urusan spt ini hrs ke p jokowi ya..�',
#  'keadilan...?� memangnya ada pelanggaran hukum apa...?� sewa pengacara aja seperti roy suryo tuh...� ',
#  'repot,� jual aja ke tetangga,� sesuaikan harga nya,� beli� rumah lagi di komplek perumahan,� jangan jadi susah sendiri�',
#  'nggak sopan sekali si %u2063eko purnomo ini,... kalau tahu pendidikan mestinya tahu cara menyampaikan pendapat ke presiden... bisa lewat gubernur - mentri - ke surat kabar biar viral... ',
#  '%u2063semoga kasusnya didengar oleh pejabat yang berwenang. bagaimana pun ada ketiadilan yang dialami pak eko.',
#  'tempat mengadu sekarang di sosmed. jadi viral akan di tangani',
#  'koq bisa gitu.....awalnya gimana.....bisa di urutkan dulu asal muasal tanah serta bangunannya.....',
#  'harus didengar juga alasan pemilik tanah membangun rumah menutup sepuruh jalan akses pak eko ... tanah bangunan yang tadinya ruang terbuka tersebut juga bisa angkat bicara mengenai kasus ini ... ',
#  'beli heli aja',
#  'hhahaha tetangga oh tetangga engkau kadang baik kadang juga buruk rupa',
#  'klo lihat dari denah rumah sih yang salah tetangga ... karna makan hak ases jalan , bukanya tiap perumahan itu dikasih jalan ya sama pengembangnya ',
#  'itu pak eko punya bukti kuat gambar denah , laporkan saja�',
#  'ini tetangganya udah mau beli rumah pak eko waktu itu tapi pak eko jual mahal...',
#  'ya harusnya berbagilah..toh tdk dibawa mati jg dunia dan seisinya..paling kita matipun yg kepake 2x1 meter aja',
#  'bupatinya ditangkap kpk ya??? berarti penerbitan imb nya bermasalah, tidak ada peninjauan lapangan segala..asal ada amplopnya langsung terbit imb....gila',
#  'bpn gimana itu bikin peta tanah tidah ada akses jalan ',
#  'ada hukum-nya, lihat kuhperd, tidak boleh akses ke tanah orang ditutup,walaupun akses itu punya milik yang menutup... ke pengadilan aja...',
#  '�ada sebab ada akibat.... panggil kedua belah pihak, di saksikan aparat pemerintahan dan bpn, pemilik lama dan baru.�',
#  'di bdg dah biasa kalo yg dulunya gang trus jarang orang lewat di tutup sama yg punya tanah, padahal kalo mau wakafkan sebagian tanah dan tanahnya bermanfaat, pahalanya akan trus� mengalir keliang lahat sampai hari kiamat. maaf kalo sok tau.�',
#  'bakar aja rumah pak eko, biar rumah tetangga kena sekalian...',
#  'kaya apa sih kayanya org ini... sampai nggak py hati..... beda yg di kasih makan uang halal dan haram... coba cek...',
#  'masya alloh... kok ada orang yg seperti itu y... kirain cuma ada d sinetron hidayah aja...',
#  'bantu viralkan agar pak ridwan kamil tau ada warganya yg sedang terzalimi',
#  'pak eko ke pasar beli uler cobra aja 100 ekor sama tikus 100 ekor .....lepas aja di rumahnya ...angep2 ternak ...ntar 6 bulan lagi ke sana ya.....�',
#  'pak eko sebaiknya bapak menemui pak gubernur ridwan kamil untuk mencari keadilan saya yakin bapak akan mendapatkan solusinya.',
#  'seharusnya sebagai sesama umat tidak boleh memblokade sprti itu... jgn sampai dpt balasan di akheratnya..� �menutup rumah orang spt itu....�',
#  'sebenarnya kalau ada gang begitu biasanya ada kesepakatan antara pemilik tanah yg menghibahkan sedikit tanah buat gang. coba aja cari tau dan cari buktinya pak eko. baru laporkan.',
#  'bawa ke pengadilan. pasti bongkar itu bangunan pakai jalan pemda.�',
#  'kalo gw jadi pak eko, kalo emang gk ada solusi dari tetangga angkuh dan pemda,..rmh gw bakar..ntr juga rumay tetangga angkuh kena. capek amat punya tetangga gitu.',
#  'ngadu ke hotman paris juga....� datang ke kedai kopi joni... bisa lsg di expose oleh pengacara nyentrik itu....%ud83d%ude01 ',
#  'sabar p eko dunia ini hanya semenrara mereka akan mendapat siksa yang pedih di akherat nanti, banyak bedoa p eko karena doa orang yang terzalimi akan diijabah allah mudah2 allah memberikan jalan keluar - aamiin',
#  'sabar ya pa eko, mudah mudahan ada jalan keluarnya',
#  'itu gang kok bisa dijual? yg punya tanah yg gabener kalo gitu.. sudah janji kasih akses tapi malah dijual',
#  'harus diukur lagi denah dan lhat sejarahnya, bisa jadi bagian teras rumah yg ketutup itu mungkin aja gangnya. krn pernah kejadian ditempat saya, krn awalnya tanah di depan rumah kosong ga dibangun, bagian jalan setapak di depan rumah diambil sama rumah yang bangun duluan. kemudian ketika tanah kosongnya dibangun, otomatis bagian jalan setapaknya sudah hilang. padahal jalan setapak itu bagian dari fasilitas umum.',
#  'mudah2an segera ada solusi.�',
#  'loh itu ada gambar gang, klo yg bangun itu main serobot gang nya laporkan aja batal itu imb nya. jangan jangan gak punya imb juga yg nutup jln',
#  'sampaikan langsung ke pak gub ridwan kamil jangan cuma aparat2 gak jelas insya allah kang emil bisa kasih solusi... sekali lagi jangan ngadu ke camat bupati atau lain2... memang itu jalurnya tapi perlu di ingat jaman sekarang kalo lewat camat bupati hadewww ruwet... mumpung punya gubernur kayak kang emil... kita rakyat langsung cus aja ke kang emil. ',
#  'cerminan buruknya tata kota bandung.�',
#  'sabar aja..biar kejepit di liang lahatnya nanti',
#  'makanya gw gak mau pindah ktp bandung....',
#  'mungkin takut gk bisa selonjoran kali makanya tanak sejengkal aja dia gk sisain..',
#  'jng kalian asal koment klu blm tahu pastinya.%ud83d%ude00',
#  'kasih tau pak rk biar dirubuhin tuh rumah tetangga..',
#  'kok gang bisa ada sertinya?',
#  'pak ridwan kamil sbg gubernur jabar mungkin harus turun tangan membantu warga yg didzolimi tetangganya. buktikan bapak sbg pengayom rakyat.',
#  'tetangganya kejam juga, tapi tetap saja ada ksalahan pemilik rumah, kalo misalakn mau jual lahan harus di liat k masa depan apakah menngangu jalur atau tidak.. akibatnya seperti ini kan? ',
#  'mungkin tetangga itu mau mati & jalan sendiri ke kuburanya...',
#  'tetangganya ga punya hati.� pemerintahnya tidur. kalau kelak developer beli tanah didepannya dan diblokade, teriak2 minta media datang sambil nangis bawa anak2 kecil dan emak2 sementara bapaknya pada ngilang. ',
#  'bandung gietuh lohh',
#  'kemana pemerintah ????',
#  'lempar pintu rumah yg bikin tembok pake cangkul pak eko. %ufffc%ufffc %ud83d%ude01',
#  'tetanga masa gitu jilid 2',
#  'ud jadi camat .. ngapain ngurusin warga .. kurang kerjaan',
#  'semoga cepat mendapat balasan di dunia untuk para tetangga durjana itu...amiinn..',
#  'ya kita taulah kualitas camat n kelurahan kyk apa. ',
#  'ini karena aturan yang tidak tersosialisasi, bahkan sampai aparat negara. harus ditegakkan atas prinsip keadilan',
#  'klo tu org mati nti biat dia ngubur sendri..�',
#  'harus berpatokan pd sertipikat tanah, kalo disertipikat ada akses jalan ya bangunan tsb hrs dirobohkan tapi kalo memang ga ada akses jalan ya jangan protes.',
#  'perjuangankan sampe mati pak. kalau ini memang benar hak kamu. ini hartamu yg harus diperjuangkan',
#  'klu itu mah sm jg nyati gara2 bisa keranah hukum itu?',
#  'penduduk ujung berung sangat heterogen, memiliki karakter masing-masing dan cenderung wataknya keras karena faktor ego masing-masing. kehadiran pemerintah setempat sebuah keharusan agar ada lsolusi dan desisi, melalui musyawarah mufakat dan atau penegakan hukum.',
#  'saya kok lama-kelamaan jadi takut, knp bandung semakin tidak ramah terhadap warganya?!',
#  'bisa di buat sinetron rahasia ilahi',
#  'pemilik tembok beruang buktinya  lurah ame camat diem..',
#  'pemilik 2 rumah yang yang nutup jalan harusnya di rukyah dulu sebelum berunding, mandi kembang 7 rupa, sama makan menyang yang kenyang, kalau udah tahak kasi minum air rebusan daun sirih.',
#  'nggak mashook pak eko....',
#  'klo rmh sdh ditembok kirin kanan depan blkg gtu, diwakafkan utk dijadikan kuburan aja pak, biar tetangganya mikir 2x, biar tetangganya tinggal di sebelah kuburan gtu kan ngeri2 sedap.. ,�',
#  'bongkar bangunannya sekalian,jgn cuma temboknya...benci bgt gw ma org kyk gitu biar digencet dlm kubur luh!!!',
#  'pejabat tingkat desa tidak peka dengan warganya, jual beli tanah pasti beliau tahu...kan diukur bersama aparat desa, dan kalau urus imb juga aparat desa survey lokasi....bagaimana ini tdk tahu..... ? utk bang hotman paris pengacara yg dikenal sosial tolongi dong. obrak abrik itu aparat desanya sampai tingkat kecamatan.. ',
#  'pemerintah harus bertindak, atau memang tdk peduli pada rakyat tertindas',
#  'boro boro ngurusin warganya, depan kantor kecamatan ujung berung tiap hari macet parkir motor sembarangan aja dia gak pernah lihat.  ',
#  'ngadu ke kopi joni 1 hr� beres sama ig bang hotman...',
#  'orang yang menutup akses jalan rezekinya akan seret... lihat saja',
#  'eko coba ngadu ke rt dstrunya sampai pak rk, tembuskan ke pak jokowi yang sering bagi2 sertifikat, pasti beres...',
#  'camat kerjanya apa? digaji dari pajak msyarakat selalu saja jawaban klasik.. tidak ada laporan. mendinga copot camat pemalas. masih banyak orang yang mau kerja dengan benar.',
#  'nasib rakyat kecil di rejim ini',
#  'pidanakan pak eko.....!!',
#  'emang bandung ngga ada pasal 667 kuh perdata?',
#  'ini kades /lurah rt /rw nya kemana aja...',
#  'kalo masalah ini timbul pas pilkada kemarin, pasti para calon ber lomba lomba nolong',
#  'ini lah yg perlu y pendidikan agama...hampuraaa',
#  'kalau kejadiannya di jakarta, pasti yang komentar udah 1 juta komen',
#  'bangsa sendiri , lebih ramah , lebih pengertian , syarat dan ketentuan berlaku. ',
#  '%ud83d%ude02%ud83d%ude02%ud83d%ude02%ud83d%ude02%ud83d%ude02, siapa yg bilang penduduk indonesia ramah tamah ??? ini tetangga sendiri saja dibabat.....',
#  'matinya gk dterima bumi, tuh orang...!!!!!',
#  'langsung tuntut saja pak eko. bapak kan ada denah dari bpn. tapi cek dahulu dengan sertifikat2 yang ada. kalau memang keberadaan gang itu di 4 sertifikat muncul. artinya pemiliki dari dua rumah tersebut melakukan pencurian tanah. laporkan ke polisi jika memang seperti itu pak eko. jangan kebanyakan pasrah, viralkan...',
#  'ahok...mana ahok.....',
#  'sabar mas eko saya juga pernah mengalami persis kayak mas eko alami . alhamdullih dengan semangat saya bekerja keras saya bisa pindah rumah serta dapat tanah yg jauh lebih layak & besar .',
#  'ngadu aja ke jokowi,sama ridwan kamil..',
#  'pasti awalnya belagu akhirnya langsung disikat sma tetangganya mgkin situ musti instropeksi diri gak ada orang yang niat sampe sejahat itu kalau ente baik hati gak mgkin rt rw gak tau dan mendiamkan dan warga sekitar juga pasti bantuin kalau ente baik hati. semua hanya mgkin mudah2an segera ada solusinya untuk ente',
#  'hmmm............. parah bener',
#  'wah itu pemerintah daerahnya gak beres itu..',
#  'itu modus untuk memiliki hak tetangga dengan gratis atau dengan harga yang sangat murah.�',
#  'nah, sekarang camat khan sudah tau maaalah ini, kita lihat apa yg akan dan bisa diperbuat untuk mediasi win-win solution ini',
#  'hilangnya hati nurani... ayooo gerakan coin to eko...',
#  'sdh ada aturannya....',
#  'coba tempuh jalur hukum perdata, tetangga anda pasti berusaha nyogok hakim tpi jgn putus asa, viralkan trs di medsos utk dukungan',
#  'gunting pak eko.....',
#  'kenapa pake musyawarah? camat napa bs sampe ga tau? imb yg keluarin siapa? emang ga ada satpol pp yg ngawasin? mustinya lsg robohkan rumah yg halangi itu, balikin akses jalan gang, toh awalnya yg bangun jg ga mau kompromi? napa takut? apa udah disuap? pidanakan juga yg bangun!!�',
#  'pemerintah bandung nggak becus kerja',
#  'semena-mena,...� nanti kuburan nya menyempit looh.. %ud83d%ude01%ud83d%ude01 ',
#  'gila udah gak punya iman tuh tetangga. cocok dijadiin cerita majalah hidayah judulnya k"uburan sempit". :d',
#  'eko cengeng',
#  'semoga selesai dengan baik dengan mengedepankan hukum. asas kekeluargaan dan bermasyarakat. tidak mengedepankan ego..dan status. aamiin',
#  'ikut aturan dari sertifikat tanah yg dimiliki saja. sy percaya pasti gak ikut aturan......',
#  'sdh jelas dalam shm  / surat ukur tsb ada gang menuju rmh eko, aparat harus merubuhkan bangunan yg menutup gang tsb�',
#  'wah, yg nutupi jln bnr2 ga ngerti aturan',
#  'pasal 5 uupa di sebutkan bahwa tanah memiliki fungsi sosial.ini artinya bahwa tanah tidak mutlak bisa kita gunakan seenak udel kita tanpa memikirkan kepentingan orang lain',
#  'kalo diliat denah di sertifikat udah jelas itu gang. �kenapa aparat tidak baerani berbuat tegas untuk membongkar bangunan tersebutt..jangan jangan...ahh sudahlah',
#  'ada pejabat yg tdk melaksanakan tugas yg benar',
#  'kasi akses jln buat orang jg itu sebagian dr amal kita�',
#  "prihatin.  itu salah satu contoh masyarakat tidak paham hukum.  saya ingat betul di kuhp ada pasal mengenai hal ini, kalau tidak salah mengenai 'hak seseorang atas akses jalan'.  saran saya, bila mentok, bapak tempuh jalur hukum perdata, saya yakin pasti menang.",
#  'pentingnya etika hidup bertetangga.. hrs saling bertegur sapa dan membangun hubungan baik dengan orang lain. hak memag sudah haknya.. tetapi apakah gak sadar hidup ini hnya sementara dan harta cuma titipan.',
#  'tetangga masa gtu',
#  'kejam tetangga ini tdk berkerpimanusiaan',
#  'naon wae masalahna nu nutupna kos bagong teu bisa ngalieuk.. pan tangkurakna ngaliwat nincak jagat batur... dasar bangpak tulak bantingkeun.. ',
#  'gaya developer nih orang bangun tanpa di beri jalan keluar ',
#  'gak yakin punyaimb',
#  'mudah2n pak eko purnomo dan keluarga mendapat ganti yg lebih baik,,aamiin,,sabar ya pak eko,,',
#  'sudah ga punya rasa kasihan terhadap sesama itu yang baru bangun sudah ada tawaran dari pemilik rumah yang terblokade 10 jt tapi tetap ajah ga mau ngasih toleran kejamnya mau hidup sendiri thu orang nanti kalo mati kubur sendiri sebelum mati bikin liang terlebih dulu x ya',
#  'koq bisa keluar ijin ngebangun?�',
#  'jadiin kandang ular aja!!',
#  'kalo spt ini benar2 sdh pada gak punya rasa tenggang rasa antaranusia bettetanngga, yg lebih aneh lagi spt gak ada gunanya itu namanya ketua rt /rw lurah dan camat setempat. dan bagaimana org mbangun raumah tdk mau peduli sama sekali dg lingkungan tetangga. benar2 sdh mati segalanya .',
#  'ada yg gak beres keknya , bpn mana nih',
#  "klo bangunan tanpa akses jalan gitu biasa'y ga akan bisa bikin shm.",
#  'gak bisa tuh aturannya itu harysnya tetep kasih jalan minimal 60cm (selebar keranda) ntk org jalan, wajib..',
#  'aparatur pada kemana.... rt rw ny pada budek smua... gk peduli sekitar ny',
#  'kejam skali itu tetangganya....trus pemerintah daerah khususnya dinas pertanahan...gmn bisa gitu. kan ada aturan setiap rumah diwajibkan memberi ruang utk akses baik jln ato parit. kacau bgt sih',
#  'ini yang disalahkan seharusnya badan pertanahan daerahnya, koq bisa ada ijin yang membuat rumah tidak ada akses jalan.',
#  'merdeka udah 73 thn..! aparatur daerahnya pada kemana..?',
#  'horang kaya... baru. ..',
#  'salah satu keajaiban dunia lol',
#  'masa waktu tumpuk tuh batu bata nga nyadar nutupin rumah orang lain wkwkwk.',
#  'coba jika yang nutup jalan tadi rumahnya di belakang, maukah diperlakukan seperti itu? serakah amat sih, utk jalan aja nggak boleh. modar tidak dibawa aja.',
#  'salah satu tetangga yang lahannya berbatasan langsung dengan rumah itu sebaiknya secara bijaksana membantu ybs dengan cara membeli rumah tersebut, sehingga ybs bisa membeli rumah penggantinya di tempat lain. hanya itu jalan keluar terbaik tanpa merugikan pihak manapun. semoga cepat ada solusi terbaik.',
#  'apakah masyarakat kita semakin lama semakin buas..?�',
#  'mau beli dgn harga murah...pakai jalan begitu...dugaan saya.',
#  'lho imb mewajibkan bangun rumah harus punya akses jalan...',
#  'tetangganya ga ingat� kalo mati cm butuh 2 meter...amal dikit knp?',
#  'orang kaya tapi kayaknya ngga bermoral ya...',
#  'awalnya gimana.. cuma satu rumah aja... seblum bangun rumah kaga diperhitungkan dulu.. klu tanah orang buat jalan ya ga fair...sblum komen lihat permasalahannya dulu..�',
#  'gugat aja...pasti menang',
#  'permasalahannya adalah, kenapa pemda setempat memberikan imb tanpa mengecek situasi? setiap bangunan harusnya mempunyai imb, atau kemungkinan pembangunan rumah tidak punya imb. hal seperti ini tetangga bisa menggugat ke dinas tata kota (kalau tidak salah) karena mebangun rumah tidak hanya karena punya tanah saja, bisa dibangun semaunya, harus mempertimbangkan kepentingan umum, terutama tetangga sekitar. ',
#  'kasihan... tanah itu yg akan melapang dan menyempit ketika kita mati kelak.... semoga keluarga tersebut senantiasa diberi kesabaran dan ketabahan.. harta hanya titipan semua milik tuhan.�',
#  'viralin aja, imbnya gak beres tuh, bisa dibongkar',
#  'yaudah jadi tetangganya aja',
#  'tetangganya busuk itu mah.',
#  'tetangganya pada sakit jiwa!',
#  'sadis tetangganya pada g mau mati x',
#  'setahu saya ada di kuh perdata... namanya hak servituut... coba yang ahli hukum...bagaiman itu penjelasannya...',
#  'terlepas dari p eko yg tidak bagus dalam bertetangga,� harusnya tetangga yg bangun tembok gank punya nurani biar otaknya kepakek. dia bisa dituntut kok bisa ngebangun tanpa imb,� bikin susah org itu namanya. sekalian laporin polisi tuh rt nya sekalian.��',
#  'sabar yaaa mas semoga prilaku itu mendapat balasan yang lebuh menyakitkan dari apa yang dia perbuat, serahkan kedirinya pelaku,  memang masih banyak manysia2 tamak serakah tapi sebetulnya diri sendiri ada ati nurani yang ga bisa dia bihongi suatu sa, at penderitaan akan lebih dari apa yang dia perbuat. ',
#  'masuk pak eko.... ',
# ...
#  'aa mantap....',
#  'wong edan kui bebas. wong edan kui bebas , wong edan kui bebas.,.,. by nella karisma .',
#  'bukan mukanya ajaa yg ga enak dilihat..pikiran dan ucapannya juga ga enak didengar',
#  'kapal oleng kapten %ud83d%ude05',
#  'kenyataan memang menyakitkan!!!',
#  'andi arif teriak terus dan ketumnya diam aja. org jadi paham kalau andi memang ditugasi untuk itu. targetnya �ya agar pihak lawan prabowo yakin pd gak all out dan keuntungan yg bisa diraih adalah posisi menteri bagi ahy di kabinet jokowi.... sangat memuakkan!',
#  'gak terbukti kok ngotot...�',
#  'awas..... aa itu mata%u201d yg ingin mecah belah koalisi.. masa org pintar ucapannya bgitu %ud83d%udc4e%ud83c%udffb%ud83d%udc4e%ud83c%udffb',
#  'demokrat itu dulu santun zaman sby...sebenarnya repot juga ya kalo berdiri dikubu sebelah....beda jenis...dan jenis itu sdh dikapling sama pekaes..gerindera dan pan...gaknada untungnya malah bisa berkurangbkursi di pileg',
#  'ketiganya pasti parnoko,kita buktikan yah.',
#  'kehilangan tgb adalah sesuatu yg merugikan demokrat...tapi misalkan didaerah 5 yg disebutkan andi arief itu imbang...bukannya daerah2 lain juga jadi penentu ya %u263a',
#  'mending tendang dah demokrat...drpd rempong...suaranya demokrat udah loyo....cukup pks..pan n berkarya ajah...',
#  'ada ada saja jurus mengelak nya upin ipin kah?hihihihi ',
#  'masih sakit hati masalah kardus',
#  'ayo perang, pukul, tendang......emang si andi arief biang perkara, komen seenaknya ayo balas, masa sih kalah sama wakil sekjen doang?????�',
#  '%ud83e%udd14%ud83e%udd14%ud83e%udd14%ud83e%udd14%ud83e%udd11%ud83e%udd11%ud83e%udd11%ud83e%udd11%u2620%ufe0f%u2620%ufe0f%u2620%ufe0f%u2620%ufe0f',
#  'koalisi tdk solid, kacau, pecah, acak kadul.�',
#  'maling teriak maling, titip salam deh buat si beyek.... katakan ya pada korupsi.....',
#  'koalisi ya yg kompak, kompak sj blm tentu menang apalagi gontok2an dan setengah hati....',
#  'ko berkoalisi malah saling serang... kasihan para kader yg di daerah kalo seperti ini....',
#  'apapun yg diperlihatkn demokrat tentu bukan pelajaran politik yg baik bagi masyarakat.... faktanya hy politik busuk dan bermuka dua yg tampilkan',
#  'makin seru.... hahahahaa',
#  'koalisi amburadul.... keumatan enggak jadi...ijtimak omong kosong .... ternyata cuma kardus tempe atm',
#  'ketauan kalo sebenarnya koalisi kardus sangat rapuh dan demokrat merasa akan sia2 menghabiskan energi untuk dukung paslon yang kalah...... ',
#  'sudah jadi rahasia umum......',
#  'mungkin aja ada kader ppp dan pkb yang simpatisan kesebelah, khususnya yang doyan karduss',
#  'parpol ny kemana... kader dan pendukungnya kemana.. itu artinya parpol tidak punya pengaruh terhadap pilihan individu.. banyak dukungan parpol juga belum tentu menang. rakyat indonesia sudah pintar. mereka tahu kemana pilihan politik mereka akan diberikan',
#  'knp g bilang aja sekalian pdip di akar rumput dukung prabosan',
#  'jokowi dua periode ri 1 selanjutnya erick tohir yang sudah disiapkan jokowi.',
#  'di depan pimpinan parpol boleh saja dukung calon yg didukung parpolnya...tp dalam bilik suara siapa yg tau...dah biasa koq nyeberang sesuai hati nurani',
#  'ppp yg dukung gerindra palingan jg si usb lunglung',
#  'semakin mendekati pemilu semakin keliatan kalau mereka sebenarnya sudah tak seimbang...',
#  'bocor...bocorrrr....',
#  'emang lulung masih di ppp? bukanya sudah di pan yah? wah kayaknya gerindrong lagi mimpi basah deh...alias lagi buat fiksi...',
#  'paling haji lulung',
#  'paling si lulung doank hahaha',
#  'kalau sebagian demokrat mendukung jokowi yang bilang orang demokrat sendiri. kalau ppp mendukung prabowo yang bilang orang gerindra bukan ppp jadi silahkan di cerna',
#  '#2019prabowosandiuno. hak suara milik rakyat secara individu. dukung mendukung hanya untuk bersaing di media.� tidak semua rakyat papua dukung jokowi, dan tidak semua orang betawi dukung prabowo. ',
#  'omongan habib sama fadli ngawur dan tanpa data valid, kalo negara ini mau maju, jangan kasih kesempatan orang seperti ini menjadi bagian dari penguasa, cek track record habib apakah masih mau memberikan amanah kepada dia, habin dan arief puyuono dua serangkai dari puluhan tahun lalu..',
#  'sengaja itu.. taktik mainannya sby..�',
#  'kalau lulung kan bukan kader ppp lagi pak.',
#  'habiburohman... bhuahahahaha',
#  'padahal banten pun bukan daerah pak jokowi juga. tapi tetap memihak pak jokowi... jadi inti nya..... %ud83d%ude02%ud83d%ude02 ',
#  'kacian..ya koalisi si zonk..gara2 jatah semua diserobot dan pembagian kardus tdk merata...akhirnya...? sakitnya tuh disini..',
#  'yang ketumnya egk mau keluar uang,kader cari uang sendiri,daripada keluar uang buat prabowo yg jelas kalah ya ogah mereka mendingan ke jokowi agar mendongkrak kader tsb di wilayah mereka ke dpr maupun dprd ...mereka pintar membaca situasi..tentunya nama jokowi masih di sukai warganya...memang kader di daerah lebih pandai....kalau di jkt takut dgn ketua umumnya',
#  'sebutin donk namanya siapa aja kalo berani. jangan2 anda sedang halusinasi',
#  'namanya juga zonk.. omongane ya zonk',
#  'hadew... kartu mati... tak ada bandar mendekat nih...�',
#  "pak ma'ruf bukan gila jabatan, tapi dia tdk rela kalau indonesia dipimpin orang jahat yg suka nyinyir, sara, ngadu domba, menghalal kan sgala cara, fitnah sana sini!�",
#  'harta tahta...�',
#  '#2019prabowosandiuno. semoga menang mbah, biar gak malu kalo kalah. ',
#  'lahir batin apa lahirnya saja�',
#  'pake alhamdulillah demi meraih jabatan, istighfar yai',
#  'asal jangan mengeluarkan fatwa ya pak... dipapua tidak mengenal fatwa.., indonesia berdasarkan pancasila',
#  'diabaikan saja,� suaranya dikitkok',
#  'biasanya barang /pakaian yg dipakai pejabat harganya bakal naik',
#  'gila jabatan ki?',
#  'ah biasa aja tuh',
#  'berita yg bikin sewot fans sebelah nih ,tapi klo kenyataan nya begitu. .mau di bilang apa ?ntb juga kan ? mereka mendukung tentu dengan alasan yg jelas ..spt papua misal  ..lah yg sering kesana dan bangun papua joko wi. .gmn mau menutup mata? ',
#  'sy pendukung ahok.. golput',
#  'mantappp... keadilan sosial bagi seluruh rakyat indonesia',
#  'ternyata besar minatnya....%ud83d%ude04%ud83d%ude04%ud83d%ude04',
#  'klau liat kdekatan dan jasa pak maruf hrusnya sby mndukung dan mngusungnya\ntpi karena udh kplang baper dan udh kplang janji sama prabowo walau berat hati ya mau gk mau mngusung prabowo',
#  'ketum demokrat sdh kagak ada giginya',
#  'nafsu berkuasa ya.. hahaha',
#  'jelas bisa dimengerti... rakyat papua merasakan sekali apa yg sdh dilakukan pres jokowi disana..prinsip keadilan nyata dilakukan bukan sekedar jargon politik... #2019orangbaikhasilnyabaik ',
#  'ngomong ngak kuat krn kardus sdh di embat... kelakuan politisi sontoloyo',
#  'coba pendapat bapak ini disampaikan ke junjungan bapak....ar. supaya gak nyinyir.....kata beliau gak mungkin.',
#  'ibarat bangunan mewah koalisi ini sebenarnya kropos dan rapuh...gmn mau mau menang ini, ngurus intern koalisi iji aja ga bisa...hidup jkw 2 periode',
#  'hahahaha....seru neh...mantap masa pks dan pan aja yg dapat, sikatlah pd jgn mau dibohongi sama gerindra, pks dan pan..hahaha',
#  'hajar bleh, sikat terus, masa cuma mereka doang yang dapat kardus pd engga, ayo jangan mau, tuntut juga bagian kardusmu�',
#  'koalisi gak mutu.....percuma lo pada eker2.....nyungsep lo semua',
#  'mau menuding dua atau tiga kaki juga gamasalah bos.yg penting pks sudah dapat 500 m.berarti pertahun 100m.lumayan kan coba klw ngandalkan dari hasil korupsi atau pemberian jangan2 di ott sama kpk. ahirnya gigit jari donk klw ini kan barter meskipun nantinya kalah & pasti kalah dlm pilpres gamasalah yg rugi kan bukan pks atau pan paham kan sekarang?yg penting duitnya gerindra sdh keluar & klw ada bahasa untuk kampanye itu kan cuma alasan saja biar garibut.',
#  'yahh kenyataannya semuanya main 2 kaki dan oportunis.... mau apa lagi??? ',
#  'andi juga aneh pake ngomong udah jelas parte kemunafikan sejati, cebong kejet2 gagal mupe on.',
#  'yah... apakah masih percaya dengan omomgannya?�',
#  'kalau panas dalam minum tuh kaki 3 biar adem..he..he.',
#  'ketua diam ... bisa dianggap seruju',
#  'udaah mending bubar aja niih koalisi ga bermutu...bukanya bikin program malah ribut sendiri, mendiing bubar lagian sdh pasti kalah kok ngapain d lanjutkan�',
#  'haqul.yakin pekaes dan pante nyungsep suaranya pemilu 2019�',
#  'koalisi serapuh kardus basah',
#  'andi arief yg selalu menyerang koalisi sendiri ini kenapa tdk ditegur sby. ada apa di koalisi prabowo sandiaga ??? padahal bersikap pura2 netral di pilpres 2014 sama juga bermain 2 kaki, pak andi.',
#  'dulu mencari makan setelah menjabat jadi kaya2 bahkan daging juga di empat penjara dan akhirnya neraka',
#  'nah lu.... kena deh ',
#  'kardus kardus kardus.........mana bagian kardusku............ ',
#  'politik cari makan alias parpol kardus.',
#  'dia minta isi kardus tu',
#  'badut badut politik...kerja nolll buat rakyat...nyir nyir bocor coorrrrrrr',
#  '%u2063jokowi menang mudah di pilpres 2019, democraaat nyungsep',
#  'jokowi menang mudah di pilpres 2019, democraaat nyungsep ',
#  'lebih bagus cap kaki tiga..bisa buat kesehatan',
#  'kaki empat..%ud83d%ude07',
#  'salam dua kaki euy...hahaha',
#  'pak sby itu kalau ngomong selalu pinjam banyak moncong mas. kayak ban, bocor alus tapi keliling%ud83d%ude03. baru lahir ya?',
#  'kl sudah berdasarkan data dan fakta ya susah untuk dijawab.. hahahaha',
#  'setdeh, kho seneng banget� ribut sich, rebutan apa lagi nech, ....eng..ing..eng ..datang zonk ah nggak papa masih solid kho, itu hanya dinamika politik...capek dech.',
#  'sesama begundal politik dilarang saling mendahului ...',
#  'karena aa pakai data dan fakta. maka tidak bisa berbalas pantun. ',
#  'pan - pks sebaiknya diam klo ga punya kaca.�',
#  'koalisi aja ribut. gimana mau menang. jargon doang kenceng kualitas nol',
#  'mari kita bertepuk tangan...sesama begundal sdh mulai ribut....',
#  'kayaknya bener juga,� dulu kan koalisi demokrat tp sering gak nurut',
#  'diam itu emas',
#  'lah ngapain jg ribut2 politik. pilkada kemaren jg banyak koalisi ngacak. politik disini ya gt, cari sensasi doang.',
#  'bukan 2 kaki itu mah yg kita tahu .. tapi 4 kaki .. 2 kaki yg sah , 2 kaki yg siri ..kan ??',
#  'main dua kaki saat pemilu sudah usai.� bargain dan kompromi. lah ini baru mau mulai. haha cerdas dong kamu dek�',
#  'pd, pan, pks semua ahli main 2 kaki, cuman gerindra yg ga punya kaki',
#  'andi arief, dicari bawaslu tuh.',
#  'abis mau bagemana lagi ga mau rugi, maunya untung terus',
#  'bertiga saling selingkuh',
#  'andi arief ini awalnya mencak2 teriak2 terkait dana logistik 500m untuk kubu koalisi prabowo, karena demokrat tdk di ajak bicara, sekarang diem dia di amankan oleh sandi, wajar andi arief ini ngebela demokrat dan sby',
#  'tepatnya pan dan pks tergantung bayaran................',
#  'satu koalisi aja udah gak kompak gmn mau menang, udah pd jgn ribut nikmatin aja dl kardus2nya.... mudah2 anjlog /hancura suara kalian di pemilu 2019',
#  'salut buat timses padi, dinamika adalah keharusan dlm sebuah perjuangan politik, ada perbedaan pendapat, kritik juga wajar2 saja, solid gak perlu harus yes semua, diam seribu bahasa spt dikekang & satu suara seperti koalisi jokowi, yg ujung2nya melampiaskan uneg2 dgn menyerang koalisi lawan...berbeda suara bukan masalah, tapi saling menghargai harus dijaga & dekati terus rakyat krn rakyatlah yg menentukan kemenangan di pilpres nanti',
#  'hajar......',
#  'percaya deh,,klo jokowi menang lg,,pan akan merapat ke jokowi lg supaya dpt mentri lg,,kan kmpren brgitu',
#  'pd maen dua kaki di parlemen seabis pilpres, katenye netral tapi condong ke kmp',
#  'kelompok sebelah pemain 2 kaki semua. wkwkwkwk',
#  'andi arif buang aja bikin rusuh aja',
#  'ayo bertengkar lah aku suka hahaha',
#  'andi arif knp ya..m',
#  'jadi penonton ah... menghibur..�',
#  'ular beludak ini keluar lagi, setelah mumpet terkencing2 tdk berani bicara di dpn bawaslu. %ud83d%ude03',
#  'sudah tahu bahwa.... kalau berkata bohong .. tidak sesuai omongan.. kalau janji ingkar .. plinplan... kalau dipercaya ingkar.... tidak konsisten.... tahu munafik kok seteju.. yg waras siapa ya..',
#  '"%u2063.......pertempuran utama di pilpres 2019 ialah jawa barat, jawa tengah, jawa timur, sumatera utara dan sulawesi selatan".  jawa tengah jelas sudah dijaga ganjar, jawa timur ada mbak khofifah, jawa barat kemungkinan dengan naiknya rk, jokowi bakal menang, sulawesi selatan, pasti ada efek dari jk sebagai timses jokowi, hanya sumatera utara yang masih bisa diperebutkan oleh kedua koalisi',
#  'aduh....orang - orang jangan di pilih biar negiri ini tidak segera bubar.',
#  'belah sono ribut terus y',
#  'mungkin sedang panas dalam (nambah satu kaki lagi)',
#  'kalo pks mah emang ga ada malunya.  ikut kabinet sby, tapi ngacak2 program sby...presiennya aja sampe makan aspal di jalan nangka noh.... ',
#  'ada hubungannya dengan kardus ga nih ???',
#  'maling teriak maling, koalisi kok saling menjelekkan %ud83d%ude02',
#  'bagus bro... hajar terussss ! ',
#  'apa yang diungkapkan bung andi arif benar sekali, kita masih ingat waktu� pks ikut dalam kabinet pak sby, tapi apabila ada kebijakan dari sby selalu ditentang',
#  'ni orang dri awal udh mulai ribet sebaik nya klo memang gk searah pecat ni pa sby..�',
#  'pd bubar ajalah.... uda gak ada wibawa di mata kadernya. apa karena ketumnya gak tegas? atau mgkn hal yg sengaja dibuat utk main dua kaki alias mempraktekan politik bermuka dua?�',
#  'lo pade ngomong ngaler ngidul ga jelas ... bangsa ini banyak masalah perburuhan, ekonomi, problem kebangsaan benturan umat dll... perlu strong leader ... pas ok !!!',
#  'gawatttt... harusnya pak prabowo kirim utusan mautnya kayak ahmad dhani, neno, sarumpaet ke papua wkwkwk',
#  'kader2mya pd cerdas juga, ga mau dijadikan boneka gerindrong cs',
#  "yang jelas, perolehan suaran jokowi - ma'ruf amin akan bertambah.%ud83d%ude06 ",
#  'kira2 kalau di adu dari sisi intelektual, kecerdasan, kesederhanaan, kepemimpinan, kekayaan dari 4 kandidat capres - cawapres siapa yg menang ya ... gampang ... sandi yg menang ... muda, kaya, pinter, cerdas, sederhana, dan yg paling penting ... setia sama istri dan sayang anak ... gila ... perfect banget sih lo sandi ... yg lain pada main bini muda sama selingkuh ... lo yg duitnya banyak kok malah setia ... top',
#  '#2019jokowipresiden',
#  'bagi 90% pengurus dpd demokrat di papua ini, hati nurani mereka lebih punya integritas. krn mereka tau sesungguhnya siapa yg selama ini bekerja utk warganya. ',
#  'rakyat papua tau mana presiden yang perhatian dengan papua, mana yang pura-pura perhatian. btw balikin kardusnya sandi. ',
#  'jati diri gak pentinglah yah.......yg penting menang......klik google hambalang....',
#  'emang jokowi masih diinginkan sebagian besar rakyat untuk menjadi presiden 2 periode kok ',
#  'masalah papua itu sangat gampang dan malah terlalu gampang merebut suara orang papua sbb orang papua gak denger gubernur asal di serahkan sama yg ahli nya di jamin 100% beres....yg jelas bkn masalah infra struktur sbb yg menikmati nya tetap pendatang sdgkn orang asli papua ttp jd penonton....serahkan pada ahli nya papua pasti prabowo -sandi...',
#  'demokrat seharusnya join dengan jokowi saja, tim prabowo -sandi ga butuh demokrat cukup masyarakat-emak2-gerindra-pks-pan saja sudah pasti menang di 2019 ',
#  'woi kembalikan kardusnya kalo ga 100% dukung wowo....wkwkwk....',
#  'alhamdulillah amin',
#  'sebaiknya demokrat ke jokowi saja, tdk apa apa, pks pan gerindra sangat solid',
#  'harusx dpd tdk bisa mengatur dpp,kepututsan dpp harusx satu komando,miris jg ini',
#  'demokrat plin plan....',
#  'karna tdk terbendung, suara kader yg terbelah berobah strategi demi menutup muka yg sudah malu...kasihan demokrat',
#  '100% pak....soalnya joko wi orang baik ..... ',
#  'rakyat papua merasakan langsung pembangunan era presiden jokowi.�',
#  'hasil akhirnya dan saya yakin jokowi kalah dipapua.',
#  'bagus, jangan ikut orang jahat. saudara2 papua merasakan pembangunan. ',
#  'apa kata? gerinda cs ya? hayo apa? ',
#  'karena papu maju',
#  'mbah mien langsung kejang-kejang....',
#  'mereka ini yg bener2 sdh merasakan langsung dampak pembangunan jalan  dan sebagainya di sana. tidak bisa ditutupi dan disangkal lagi.',
#  ...]

# %%
#Melakukan tokenize berdasarkan white space
from nltk.tokenize import RegexpTokenizer
tokenizer = RegexpTokenizer('\s+', gaps=True)
tok_comments = []
for comment in low_comments:
    tok_comments.append(tokenizer.tokenize(comment))

# %%
tok_comments
# Out:
# [['wkwkwk,',
#   'gak',
#   'sekalian',
#   'pak,',
#   'selawat',
#   'ke',
#   'dpr...',
#   'kan',
#   'banyak',
#   'koruptor',
#   'disana'],
#  ['mantab..',
#   'ini',
#   'br',
#   'dakwah',
#   'yg',
#   'sejati..',
#   'kl',
#   'd',
#   'tempat',
#   'umum',
#   'mah',
#   'dh',
#   'biasa',
#   '.',
#   'ini',
#   'luar',
#   'biasa.�'],
#  ['salut', 'buat', 'gus', 'miftah'],
#  ['yg',
#   'nyinyir',
#   'gak',
#   'pernah',
#   'lihat',
#   'dan',
#   'baca',
#   'atw',
#   'mengetahui',
#   'sejarah',
#   'dakwah',
#   'walisongo',
#   '\\/',
#   'sunan',
#   'kali',
#   'jaga...smua',
#   'ada',
#   'cara',
#   'demi',
#   'kebaikan...',
#   'asal',
#   'jng',
#   'ajk',
#   'dg',
#   'cara',
#   'berjinah',
#   '....',
#   'lakukan',
#   'dg',
#   'porsi',
#   'dan',
#   'sikon',
#   'yg',
#   'tepat'],
#  ['ada',
#   'adabnya',
#   'sholawat.',
#   'lebih',
#   'baik',
#   'ajak',
#   'ke',
#   'majelis',
#   'ilmu..'],
#  ['setiap',
#   'ulama',
#   'punya',
#   'jalan',
#   'dan',
#   'cara',
#   'dakwah',
#   'masing2..,',
#   'jika',
#   'kamu',
#   'melihat',
#   'kemunkaran',
#   'lawan',
#   'dengan',
#   'tanganmu(kekuatanmu)',
#   'jika',
#   'tidak',
#   'mampu',
#   'lawan',
#   'dengan',
#   'mulutmu',
#   'jika',
#   'tidak',
#   'mampu',
#   'juga',
#   'dengan',
#   'hatimu',
#   'itulah',
#   'selemah',
#   'lemahnya',
#   'iman..,',
#   'itu',
#   'sudah',
#   'menjadi',
#   'kewajiban',
#   'para',
#   'ulama,',
#   'kalo',
#   'yg',
#   'komen',
#   'masih',
#   'ada',
#   'yg',
#   'nyinyirin',
#   'ulama',
#   'berarti',
#   'otaknya',
#   'sudah',
#   'disisipin',
#   'politik..'],
#  ['umpanin', 'nocannya', 'yak...'],
#  ['itulah', 'ceramah', 'yg', 'sebenarnya.'],
#  ['besok', 'bugil', 'aja', 'selawat'],
#  ['bedanya',
#   'gus',
#   'miftah',
#   'dengan',
#   'fpi',
#   '/',
#   'hti',
#   'bagaikan',
#   'surga',
#   'dan',
#   'neraka.',
#   'di',
#   'surga',
#   'penuh',
#   'kasih,',
#   'di',
#   'neraka',
#   'penuh',
#   'penghancuran.'],
#  ['knp',
#   'di',
#   'tempat',
#   'kerjanya?',
#   'mending',
#   'diundang',
#   'ke',
#   'masjid,',
#   'ponpes,',
#   'aula.',
#   'supaya',
#   'berbusana',
#   'yg',
#   'sopan.�'],
#  ['nah',
#   'ini',
#   'ulama',
#   'beneran...diterima',
#   'di',
#   'semua',
#   'kalangan.....kl',
#   'uas?',
#   'malah',
#   'diblokir',
#   'sana',
#   'sini'],
#  ['kerennn....',
#   'saya',
#   'pernah',
#   'dpt',
#   'info',
#   'seperti',
#   'ini',
#   'dr',
#   'keyakinan',
#   'yg',
#   'lain',
#   'tapi',
#   'tujuan',
#   'utama',
#   'kurang',
#   'lebih',
#   'sama',
#   'lah.',
#   'kita',
#   'ambil',
#   'sisi',
#   'positifnya',
#   'ajah...',
#   'terimakasih',
#   'atas',
#   'niat',
#   'baiknya...',
#   'saya',
#   'yakin',
#   'pasti',
#   'bermanfaat.'],
#  ['hebat',
#   'gus.lanjutkan!inilah',
#   'makna',
#   'dakwah',
#   'sebenarnya,',
#   'sampaikan',
#   'marwah',
#   'islam',
#   'dengan',
#   'penuh',
#   'kedamaian',
#   'dan',
#   'berikan',
#   'pemahaman,',
#   'bukan',
#   'dengan',
#   'kebencian',
#   'dan',
#   'pemaksaan'],
#  ['diskotik', 'syariah', 'jadunya', 'nih', 'wkwkwk..mantap'],
#  ['niat',
#   'dan',
#   'tujuan',
#   'yg',
#   'baik',
#   'pasti',
#   'mendapat',
#   'berkah',
#   'dr',
#   'allah',
#   'swt.'],
#  ['mantaaapppp..buat', 'di', 'gedung', 'dpr', 'perlu', 'jg', 'kayanya', 'gus'],
#  ['salut', 'buat', 'owner', 'klub', 'ini.....'],
#  ['josshhh', 'ini', 'baru', 'luar', 'biasa'],
#  ['dapat', 'gratisan', 'karena', 'sudah', 'punya', 'nope'],
#  ['sebaiknya',
#   'dimanapun',
#   'dilakukan',
#   'batas2',
#   'kesopanan',
#   'tetap',
#   'harus',
#   'dijaga...'],
#  ['pemandu',
#   'lagi',
#   'yang',
#   'di',
#   'manga',
#   'besar',
#   'keknya',
#   'perlu',
#   'juga',
#   'diajak',
#   'mengaji,',
#   'bos!'],
#  ['jujur',
#   'ini',
#   'kereennnnnnn',
#   'cara',
#   'menyebarkan',
#   'agama',
#   'yang',
#   'baik',
#   'dan',
#   'snagat',
#   'simpatik',
#   'semoga',
#   'sukses'],
#  ['katimbang',
#   'alim',
#   'kemudian',
#   'jadi',
#   'maling,',
#   'menurut',
#   'saya',
#   'lebih',
#   'baik',
#   'maling',
#   'kemudian',
#   'jadi',
#   'alim',
#   '....'],
#  ['sebenar',
#   'ulama,',
#   'mengajak',
#   'mereka',
#   'yg',
#   'masih',
#   'tersesat',
#   'untuk',
#   'kembali.',
#   'bukan',
#   'menjelekkan',
#   'orang',
#   'lain,',
#   'tp',
#   'merangkul',
#   'mereka�'],
#  ['ini', 'namanya', 'apa', 'ya?'],
#  ['selamat',
#   'berjuang',
#   'gus,justru',
#   'tempat',
#   'seperti',
#   'itu',
#   'yg',
#   'butuh',
#   'lebih',
#   'bnyk',
#   'perhatian',
#   'dr',
#   'ulama.'],
#  ['semoga', 'diberikan', 'hidayah..'],
#  ['hati',
#   'hati',
#   'memviralkan',
#   'berita',
#   'yang',
#   'mengandung',
#   'isu',
#   'agama',
#   'bisa',
#   'menjadi',
#   'sumber',
#   'fitnah',
#   'dan',
#   'lahan',
#   'para',
#   'bedebah',
#   'yang',
#   'kerjanya',
#   'mengadu',
#   'domba',
#   'anak',
#   'bangsa',
#   'dan',
#   'rakyat',
#   'indonesia',
#   'ahok',
#   'sudah',
#   'jadi',
#   'korbannya'],
#  ['subhanallah.....',
#   'semoga',
#   'mendapatkan',
#   'hidayah',
#   'dari',
#   'allah',
#   'swt.',
#   'amin......'],
#  ['ulama', 'ngurus', 'umat', 'berarti', 'jenengan', 'gus...'],
#  ['luar',
#   'biasa,',
#   'salut...terharu,',
#   'mengajak',
#   'orang',
#   'lain',
#   'yang',
#   'dianggap',
#   'salah',
#   'dengan',
#   'cara',
#   'yang',
#   'baik,',
#   'bukan',
#   'dengan',
#   'cacian...luar',
#   'biasa..'],
#  ["what's", 'up', 'boshe....'],
#  ['lol',
#   'jadi',
#   'ketahuan',
#   'dong',
#   'isinya',
#   'boshe',
#   'bali',
#   'bukan',
#   'org',
#   'bali',
#   '%ud83d%ude02%ud83d%ude02'],
#  ['poligami', 'aja', 'guss'],
#  ['harusnya', 'dibakar', 'tempat', 'begituan', 'kalik'],
#  ['hahahaha,',
#   'bahasa',
#   'hastag',
#   'y',
#   'kalo',
#   'd',
#   'plesetkan',
#   'jadi',
#   'y',
#   'santri',
#   'gaul',
#   'itu',
#   'yg',
#   'suka',
#   'sholawat',
#   'dan',
#   'suka',
#   'dugem...',
#   'hahahaha',
#   'rusak',
#   'islam',
#   'd',
#   'biaskan',
#   'seperti',
#   'ini,',
#   'ustad',
#   'y',
#   'dateng',
#   'k',
#   'sono',
#   'dugem',
#   'dulu',
#   'lalu',
#   'sholawat',
#   'lalu',
#   'dugem',
#   'lagi,',
#   'dan',
#   'd',
#   'sebut',
#   'santri',
#   'gaul.....?????????'],
#  ['knp',
#   'yg',
#   'kayak',
#   'gini',
#   'berita',
#   'nya',
#   'keluar',
#   'nya',
#   'pas',
#   'mau',
#   'pilpres',
#   'aja',
#   'ya...?'],
#  ['naaaah',
#   'ini',
#   'baru',
#   'bener,',
#   'ceramah',
#   'atau',
#   'ngajak',
#   'orang',
#   'yg',
#   'belum',
#   'bersholawat',
#   'utk',
#   'bersholawat.',
#   'ga',
#   'kaya',
#   'somat,',
#   'ngajak',
#   'orang',
#   'sholawat',
#   'koq',
#   'ke',
#   'orang',
#   'yg',
#   'udah',
#   'bersholawat.',
#   'maaaaat',
#   'mat!!!!'],
#  ['gila',
#   'nekat',
#   'juga',
#   'ulamanya',
#   'gak',
#   'tau',
#   'di',
#   'usir',
#   'gitu,,',
#   'tapi',
#   'bagus',
#   'lah',
#   'ada',
#   'keberanian',
#   'dan',
#   'semuanya',
#   'jg',
#   'mendengarkan..',
#   'semoga',
#   'banyak',
#   'ustad',
#   'lainnya',
#   'yang',
#   'meniru',
#   'hal',
#   'ini.'],
#  ['tambah',
#   'tempat...',
#   'mantap',
#   'sak',
#   'cewek',
#   'seksi',
#   'nya....dan',
#   'yg',
#   'paling',
#   'penting',
#   'bole...',
#   'yg',
#   'g',
#   'setuju',
#   'pasti',
#   'ngiri...week'],
#  ['mengajak',
#   'orang',
#   'melakukan',
#   'sholawat',
#   'di',
#   'tempat',
#   'ibadah',
#   'ya',
#   'sudah',
#   'pasti',
#   'mudah,',
#   'tapi',
#   'mengajak',
#   'orang',
#   'melakukan',
#   'sholawat',
#   'di',
#   'tempat',
#   'dugem',
#   'yang',
#   'penuh',
#   'cobaan',
#   'itu',
#   'sudah',
#   'jelas',
#   'pahala',
#   'nya',
#   'jauh',
#   'lebih',
#   'besar...'],
#  ['apa',
#   'sih',
#   'yg',
#   'nggak',
#   'bisa',
#   'di',
#   'negeri',
#   'ini..',
#   'semua',
#   'pada',
#   'bisa',
#   'sekrang,,'],
#  ['boleh', 'ya', 'menyebarkan', 'agama', 'seperti', 'ini?�'],
#  ['hahahaha.', '�lucu', 'lucuan.', 'biar', 'masuk', 'tipi', 'laah.', 'hahaha'],
#  ['coba',
#   'lah',
#   'ustad',
#   'yg',
#   'lain',
#   'dakwah',
#   'di',
#   'nite',
#   'club',
#   'spt',
#   'iti'],
#  ['yang',
#   'ini',
#   'malah',
#   'di',
#   'dukung,',
#   'yang',
#   'di',
#   'sana',
#   'di',
#   'jagain',
#   'supaya',
#   'ga',
#   'ceramah.',
#   'apalagi',
#   'ini.'],
#  ['ah',
#   'entahlah.',
#   'satu',
#   'kau',
#   'maklumi,',
#   'yg',
#   'lain',
#   'mengikuti.',
#   'tinggal',
#   'tunggu',
#   'saja.'],
#  ['mau', 'ngikik', 'takut', 'dosa'],
#  ['kalau',
#   'mau',
#   'melakukan',
#   'ibadah.',
#   'perbaiki',
#   'dulu',
#   'penampilan,',
#   'jauhi',
#   'miras,',
#   'cari',
#   'tempat',
#   'yg',
#   'lebih',
#   'baik.',
#   'lebih',
#   'baik',
#   'gus',
#   'kamu',
#   'mengajak',
#   'para',
#   'wanita',
#   'itu',
#   'menutupi',
#   'auratnya.'],
#  ['lokalisasi', 'harapan', 'sadar'],
#  ['setelah', 'selawat', 'selesai,', 'acara', 'selanjutnya', '?'],
#  ['bagus.', 'lanjutkan..�'],
#  ['bagus',
#   'itu',
#   'biar',
#   'sadar',
#   'islam',
#   'tdk',
#   'mengajari',
#   'kaumnya',
#   'buka',
#   'aurat',
#   'bagus',
#   'lanjut'],
#  ['banser', 'anshor', 'mana', 'suaranya.....ormas', 'liberal'],
#  ['pans',
#   'itu',
#   'ketika',
#   'simbah',
#   'yg',
#   'bicara',
#   'selalu',
#   'dibully',
#   'karena',
#   'kata',
#   'katanya',
#   'terkesan',
#   'emosional',
#   ',nantang',
#   'nantang',
#   ',pdhl',
#   'ketika',
#   'tantangan',
#   'bisa',
#   'di',
#   'buktikan',
#   'oleh',
#   'yg',
#   'di',
#   'tantang',
#   'trus',
#   'diem..',
#   'tdk',
#   'ksatria',
#   'ngakui,',
#   'dan',
#   'sering',
#   'menjelek',
#   'jelekkan',
#   'orang',
#   'lain',
#   ',inilah',
#   'yg',
#   'jd',
#   'penyebab',
#   'sering',
#   'di',
#   'bully',
#   'dan',
#   'orang',
#   'lain',
#   'jd',
#   'gak',
#   'simpati',
#   '.mungkin',
#   'dia',
#   'dengan',
#   'berkata',
#   'seperti',
#   'itu',
#   'merasa',
#   'hebat...',
#   'dia',
#   'tdk',
#   'sadar',
#   'saat',
#   'nyapres',
#   'pun',
#   'rontok,',
#   'saat',
#   'thn',
#   '2014',
#   'pun',
#   'keok.',
#   'artinya',
#   'rakyat',
#   'g',
#   'percaya.seolah',
#   'bicara',
#   'dulu',
#   'urusan',
#   'belakang',
#   'spt',
#   'janji',
#   'jalan',
#   'kaki',
#   'jogja',
#   'jakarta.',
#   '.',
#   'terbukti',
#   '?gak',
#   'kan',
#   '?....ini',
#   'mungkin',
#   'hal',
#   'sepele',
#   'bagi',
#   'dia,',
#   'tapi',
#   'itu',
#   'tertanam',
#   'di',
#   'ingatan',
#   'orang,hingga',
#   'berkesimpulan',
#   'klo',
#   'hanya',
#   'bisa',
#   'ngomong',
#   'tok..',
#   'nglakoni',
#   'ora',
#   'iso.'],
#  ['karena', 'mendukung', 'jokowi', 'jadi', 'tidak', 'dicopot'],
#  ['banyak', 'orang', 'pekalongan', 'yg', 'kemakan', 'hoax'],
#  ['pan',
#   'ancur',
#   'lebur',
#   'gara2',
#   'si',
#   'amien',
#   'rasis',
#   '...',
#   'makasih',
#   'amien',
#   '...',
#   'lanjutkan!!!',
#   '...',
#   '#2019panbakalgurem',
#   '...'],
#  ['padahal',
#   'sutrisno',
#   'bakhir',
#   'ini',
#   'dulunya',
#   'merupakan',
#   'penyandang',
#   'dana',
#   'pak',
#   'amin',
#   'rais',
#   'saat',
#   'awal',
#   'reformasi.',
#   'akhirnya',
#   'berjalan',
#   'sendiri2....�'],
#  ['orang',
#   'bener',
#   'malah',
#   'tidak',
#   'dipake',
#   'di',
#   'pan..sutrisno',
#   'itu',
#   'sdh',
#   'habis2an',
#   'demi',
#   'pan,',
#   'tapi',
#   'tetap',
#   'tdk',
#   'berdaya',
#   'melawan',
#   'amien',
#   'rais...pan',
#   'cahayanya',
#   'semakin',
#   'tidak',
#   'bersinar',
#   'sejak',
#   'amien',
#   'makin',
#   'kumat..'],
#  ['lagu', 'lama...'],
#  ['pan', 'sekarang', 'butek', 'karena', 'di-obok2', 'si', 'amien.'],
#  ['karena', 'mendukung', 'jadi', 'tdk', 'dicopot.'],
#  ['masak',
#   'sih',
#   'dari',
#   'beberapa',
#   'ex',
#   'pemimpin',
#   'pan',
#   'yg',
#   'punya',
#   'pikiran',
#   'sehat',
#   'cuma',
#   'pak',
#   'sutrisno�'],
#  ['tolong',
#   'dikoreksi',
#   'untuk',
#   'jabatan',
#   'pak',
#   'pramono',
#   'itu',
#   'menseskab',
#   'bukan',
#   'mensesneg.',
#   'terima',
#   'kasih.�'],
#  ['mantap',
#   'bukti',
#   'orang',
#   'baik',
#   'pasti',
#   'banyak',
#   'yg',
#   'mendukung',
#   'salam',
#   '2',
#   'periode'],
#  ['ksih', 'mkan', 'buaya', 'aja', 'org', 'kyak', 'gini'],
#  ['mantab...',
#   'penyebar',
#   'fitnah',
#   'bisa',
#   'tidur',
#   'di',
#   'bui',
#   'jg',
#   'akhirnya...'],
#  ['allahuakbar.',
#   'alhamdulillah',
#   'akhirnya',
#   'para',
#   'ahlul',
#   'fitnah',
#   'penebar',
#   'kebencian',
#   'tersebut',
#   'dipenjara',
#   'juga.',
#   'sudah',
#   'cukup',
#   'lama',
#   'mereka',
#   'menunggu',
#   'nikmatnya',
#   'lp',
#   'cipinang.'],
#  ['selamat',
#   'menikmati',
#   'hukuman',
#   'dunia',
#   'atas',
#   'prilaku',
#   'fitnah',
#   'menebar',
#   'kebencian.',
#   'hukuman',
#   'akhirat',
#   'yg',
#   'lebih',
#   'berat',
#   'menunggu',
#   'anda',
#   'para',
#   'ahlul',
#   'fitnah',
#   'penebar',
#   'kebencian.'],
#  ['dasar',
#   'preman',
#   'ngak',
#   'tanggung',
#   'jawab..',
#   'kok',
#   'malah',
#   'buron..',
#   'katanya',
#   'lu',
#   'anak',
#   'buah',
#   'wowo',
#   'yg',
#   '......bocor',
#   'bocor',
#   'itu',
#   'hehehhe'],
#  ['orang',
#   'grindong',
#   'gak',
#   'akan',
#   'ngomentari',
#   'brita',
#   'ini,',
#   'krena',
#   'sebagian',
#   'tabir',
#   'obor',
#   'rakyat',
#   'sdh',
#   'dibuka',
#   'sebagian',
#   'oleh',
#   'rommy'],
#  ['ayo,',
#   'gerombolannya',
#   'kok',
#   'nggak',
#   'ada',
#   'yang',
#   'komentar',
#   'nih?',
#   'biasanya',
#   'koar2,',
#   'bilang',
#   'pelanggaran',
#   'ham,',
#   'seperti',
#   'menangkap',
#   'teroris,',
#   'pakai',
#   'senjata',
#   'lengkap',
#   'dsb....'],
#  ['sik',
#   'asik..',
#   'selamat',
#   'menikmati',
#   'hotel',
#   'prodeo',
#   'kawan,',
#   'siapa',
#   'menebar',
#   'angin',
#   'dia',
#   'menuai',
#   'badai..'],
#  ['buni', 'yaniiii', 'dimana', 'anda', '???', 'kejaaarr', '!!!!'],
#  ['wowo', 'ga', 'sekalian', '?'],
#  ['jangan',
#   'tangkap',
#   'pimrednya',
#   'doank,',
#   'tangkap',
#   'penyadang',
#   'dana',
#   'dan',
#   'hubungan',
#   'mereka',
#   'dgn',
#   'kandidat',
#   'capres',
#   'yg',
#   'diusung'],
#  ['walaupun',
#   'cuma',
#   '1',
#   'tahun',
#   'ente',
#   'sudah',
#   'dapat',
#   'gelar',
#   'mantan',
#   'narapidana',
#   'menjelang',
#   'pemilu',
#   'buat',
#   'lagi',
#   'biar',
#   'dikurung',
#   '10!tahun',
#   'makan',
#   'gratis'],
#  ['gantung', 'az'],
#  ['sekalian', 'buni', 'yani', 'biar', 'adil', ',,'],
#  ['kirim', 'ke', 'kamar', 'bonita.', '#', 'bonita', 'itu', 'nama', 'macan'],
#  ['gua',
#   'paling',
#   'senang',
#   'liat',
#   'ginian.',
#   'buronan,',
#   'sensasinya',
#   'kayak',
#   'di',
#   'film2',
#   'hollywood'],
#  ['tungguin',
#   'aja',
#   'nih,',
#   'bentar',
#   'lagi',
#   'kubu',
#   'prabocor',
#   'terutama',
#   'zonk',
#   'bakalan',
#   'komen.',
#   'liat',
#   'aja.'],
#  ['karena', 'kabur,', 'tambahin', 'yah', 'hukuman', 'nya'],
#  ['ini', 'kabar', 'terbagus', 'yang', 'boleh', 'kudengar', 'hari', 'ini.'],
#  ['telat', 'kabur', 'tong?..kaciann..'],
#  ['nyari',
#   'duit',
#   'dr',
#   'nyebar',
#   'fitnah..duitnya',
#   'buat',
#   'makan',
#   'anak',
#   'istri..mau',
#   'jd',
#   'apa',
#   'anakmu',
#   'makan',
#   'duit',
#   'gituan?'],
#  ['semoga', 'bahagia', 'di', 'rumah', 'yg', 'baru'],
#  ['periksa',
#   'bank',
#   'account',
#   'nya,',
#   'atau',
#   'bank',
#   'account',
#   'keluarga,',
#   'ada',
#   'transferan',
#   'nggak',
#   'dari',
#   'wowo'],
#  ['semoga',
#   'bisa',
#   'belajar',
#   'untuk',
#   'tdk',
#   'mencari',
#   'nafkah',
#   'dari',
#   'uang',
#   'hitam',
#   'dengan',
#   'cara',
#   'yang',
#   'hitam'],
#  ['suntik', 'mati'],
#  ['sikat',
#   'semua',
#   'org',
#   'org',
#   'pengacau',
#   'negeri',
#   'demi',
#   'uang,',
#   'apalagi',
#   'mo',
#   'pilpres',
#   'malah',
#   'bikin',
#   'kacau',
#   'negara',
#   'klo',
#   'ga',
#   'segera',
#   'dikarungin'],
#  ['habisin',
#   'aja',
#   'jok',
#   'orang',
#   'yang',
#   'gangu',
#   'elu',
#   'jadi',
#   'presiden',
#   'lgi'],
#  ['nunggu',
#   'buni',
#   'yani',
#   'kapan',
#   'ditangkapnya,',
#   'pdhl',
#   'sdh',
#   'ada',
#   'putusan',
#   'pengadilan',
#   'jg'],
#  ['koq', 'cuma', 'setahun', '?'],
#  ['laaaahhh',
#   'bukannya',
#   'kata',
#   'nasbung,',
#   'pemred',
#   'obor',
#   'rakyat',
#   'diangkat',
#   'jadi',
#   'prekom',
#   'bumn?...weleh..weleh...itu',
#   'fitnah',
#   'lagi',
#   'dong'],
#  ['kapan', 'buni', 'yani???'],
#  ['sip,',
#   'tinggal',
#   'yg',
#   'kabur',
#   'umroh',
#   'ga',
#   'balik2',
#   'segera',
#   'dieksekusi',
#   'pak',
#   'pol.'],
#  ['yg',
#   'model',
#   'ginian',
#   'main',
#   'fitnah',
#   'sih',
#   'mesti',
#   'di',
#   'kandangin'],
#  ['mantap'],
#  ['sip'],
#  ['semoga', 'pas', 'di', 'dalam', 'penjara...kedua2nya', 'gantung', 'diri'],
#  ['terbukti',
#   'memfitnah,',
#   'bukan',
#   'menghina.',
#   'dan',
#   'ingat,',
#   'fitnah',
#   'lebih',
#   'kejam',
#   'dari',
#   'pembunuhan,',
#   'bro'],
#  ['+hukuman', 'mati.'],
#  ['alhamdulillah', 'si', 'penebar', 'dosa', 'sudah', 'tertangkap.'],
#  ['jokowi',
#   'sudah',
#   'memaafkan,',
#   'tapi',
#   '...',
#   'proses',
#   'hukum',
#   'tetap',
#   'berlaku,',
#   'bos',
#   '...'],
#  ['hmm'],
#  ['siap2', 'buat', 'gerombolan', 'micin', 'ama', 'nasi', 'bungkus..'],
#  ['tambah', 'hukumannya', 'karena', 'mau', 'kabur'],
#  ['lho', 'kok', 'cuma', '1', 'tahun', '5', 'thn', 'pantas', 'kok'],
#  ['yg',
#   'menjamin',
#   'mau',
#   'mem',
#   'back',
#   'up',
#   'mereka',
#   'pada',
#   'kemana?',
#   'mau',
#   'menemani',
#   'mereka',
#   'hidup',
#   'bersama',
#   'di',
#   'lp',
#   'cipinang?',
#   'jangan',
#   'macem',
#   'ayam',
#   'sayur...',
#   'lari',
#   'lintang',
#   'pukang',
#   'meninggalkan',
#   'kawan.'],
#  ['gagah',
#   'saat',
#   'bikin',
#   'obor',
#   'rakyat,',
#   'mewek',
#   'dan',
#   'buron',
#   'saat',
#   'diproses',
#   'hukum.',
#   'dasar',
#   'preman',
#   'gembeng,',
#   'kalau',
#   'begini',
#   'apakah',
#   'orang',
#   'yang',
#   'anda',
#   'junjung',
#   'akan',
#   'gantian',
#   'membela',
#   'anda?'],
#  ['#2019gantipresiden',
#   'kelihatan',
#   'bgt',
#   'tebang',
#   'pilihnya,',
#   'hukum',
#   'tajam',
#   'ke',
#   'lawan',
#   'politik,',
#   'tumpul',
#   'ke',
#   'cebong😏'],
#  ['orangnya',
#   'tambah',
#   'gemuk',
#   'makan',
#   'uang',
#   'sisa',
#   'anggaran',
#   'obor',
#   'rakyat.'],
#  ['buset',
#   'dah..jamintelnya',
#   'tetangga',
#   'sebelah',
#   'rumahnya',
#   'sendiri...miris'],
#  ['bisa', 'jadi', '2019', 'muncul', 'petromak', 'rakyat', '😹😹'],
#  ['kalau',
#   'sudah',
#   'dieksekusi',
#   'ngga',
#   'lagi',
#   'dilindungi',
#   'kan',
#   'sama',
#   'janji',
#   'back',
#   'up',
#   'kalo',
#   'kena',
#   'masalah.',
#   'hehehe',
#   'makan',
#   'tuh',
#   'janji',
#   'saat',
#   'kampanye'],
#  ['makan', 'pencarian', 'lu', 'tuhhhhh'],
#  ['selamat', 'ya'],
#  ['masih',
#   'muda,buaknnya',
#   'mendukung',
#   'presiden',
#   'generasi',
#   'muda.payah.'],
#  ['yess',
#   'tidur',
#   'aaaah',
#   'biar',
#   'cepet',
#   'besok,',
#   'ada',
#   'yg',
#   'berani',
#   'taruhan',
#   'siapa',
#   'yang',
#   'belain',
#   'mereka?'],
#  ['tukang', 'fitnah.', 'hukum', 'seberat2nya'],
#  ['hrsnya', 'min.', '10thn', 'di', 'sel...'],
#  ['nah',
#   'ini',
#   'dia..',
#   'paling',
#   'lawyernya',
#   'habibu..',
#   'getombolan',
#   'nasi',
#   'bungkus',
#   'micin',
#   'jantungan'],
#  ['cuma', '1', 'thn?...', 'enak', 'bener.'],
#  ['ini',
#   'bodoh',
#   'amat,',
#   'cuma',
#   '8',
#   'bulan',
#   'seharusnya',
#   'jangan',
#   'banding,',
#   'malah',
#   'jadi',
#   '2',
#   'tahun!'],
#  ['bos', 'nya', 'sikat'],
#  ['mari',
#   'kita',
#   'tunggu,',
#   'siapa',
#   'saja',
#   'yg',
#   'nyinyir',
#   'atas',
#   'penangkapan',
#   'ini...'],
#  ['muka2', 'tegar', 'menjalani', 'hukuman'],
#  ['bosnya', 'dah', 'ketangkap', 'blum?'],
#  ['wowok', 'cs', 'banyak', 'mudarat', 'nya'],
#  ['bravo', 'kejaksaan,', 'selamat', 'bertugas.'],
#  ['hukum', 'seberat-beratnya.'],
#  ['kalo',
#   'cebong',
#   'mah',
#   'gk',
#   'di',
#   'tangkap,',
#   'kebal',
#   'hukum',
#   'spt',
#   'viktor',
#   'laiskodat,',
#   'ade',
#   'armando,',
#   'nathan,',
#   'ananda',
#   'sukarlan,',
#   'dll.',
#   '#2019gantipresiden😏'],
#  ['good',
#   'job,',
#   'jgn',
#   'lupa',
#   'gerombolan',
#   'surveyor',
#   'ines',
#   'juga',
#   'hrs',
#   'diawasi,',
#   'dr',
#   'pada',
#   'menyebarkan',
#   'hasil',
#   'survey',
#   'abal',
#   'abal',
#   'apalagi',
#   'mo',
#   'pilpres',
#   'malah',
#   'bikin',
#   'perpecahan'],
#  ['sdh',
#   'dibongkar',
#   'kan',
#   'sama',
#   'pak',
#   'romi..',
#   'pasti',
#   'ada',
#   'pendananya..',
#   'si',
#   'kejar',
#   'juga',
#   'pak',
#   'jaksa..terus',
#   'pak',
#   'berjuang..',
#   'demi',
#   'bersihnya',
#   'negara',
#   'ini',
#   'dari',
#   'tukang',
#   'fitnah'],
#  ['usut', 'dana', 'nya', 'dari', 'mana', 'itu', 'baru', 'hebat👍'],
#  ['silahkan',
#   'bernyanyi',
#   'denga',
#   'bebas',
#   'walaupum',
#   'sumbang...tempat',
#   'telah',
#   'disediakan...wkwkwkwkkw'],
#  ['kok', 'cuma', 'setahun', '???'],
#  ['ayo',
#   'donk',
#   'polisi.',
#   'kalo',
#   'nangkep2',
#   'kaya',
#   'gini',
#   'dicari',
#   'tahu',
#   'bosnya',
#   'siapa?',
#   'siapa',
#   'yang',
#   'memberi',
#   'dana?',
#   'terus',
#   'kalo',
#   'udah',
#   'tau,',
#   'tangkep',
#   'lansung!'],
#  ['disate', 'aje', 'pak', 'jaksa'],
#  ['tembak', 'jidat', 'nya'],
#  ['tangkap',
#   'bandar',
#   'dan',
#   'pemimpin',
#   'gembong',
#   'hoaxnya',
#   'biar',
#   'jelas'],
#  ['tukang', 'fitnah', 'plus', 'juragannya', 'wajib', 'dihukum'],
#  ['sudah',
#   'terbukti',
#   'komplotan',
#   'sana',
#   'cuma',
#   'bisa',
#   'fitnah',
#   'hoax',
#   'pki..',
#   'kerjanya',
#   'ngga',
#   'ada'],
#  ['mendingan', 'ditenggelamkan', 'aje'],
#  ['aktor',
#   'intelektual',
#   'yang',
#   'mendanai',
#   'kerja',
#   'obor',
#   'rakyat',
#   'untuk',
#   'kepentingan',
#   'politik',
#   'sang',
#   'aktor',
#   'intelektual',
#   'juga',
#   'harus',
#   'di',
#   'tangkap',
#   'dan',
#   'ditenggelamkan'],
#  ['mo',
#   'bgs',
#   'atau',
#   'ga..presiden',
#   'itu',
#   'kepala',
#   'negara',
#   'yg',
#   'hrs',
#   'dihormati..kl',
#   'lu',
#   'hina',
#   'ya',
#   'pantaslah',
#   'msk',
#   'bui'],
#  ['mo',
#   'bgs',
#   'atau',
#   'ga..presiden',
#   'itu',
#   'kepala',
#   'negara',
#   'yg',
#   'hrs',
#   'dihormati..kl',
#   'lu',
#   'hina',
#   'ya',
#   'pantaslah',
#   'msk',
#   'bui'],
#  ['mo',
#   'bgs',
#   'atau',
#   'ga..presiden',
#   'itu',
#   'kepala',
#   'negara',
#   'yg',
#   'hrs',
#   'dihormati..kl',
#   'lu',
#   'hina',
#   'ya',
#   'pantaslah',
#   'msk',
#   'bui'],
#  ['tukang', 'fitnah', 'dan', 'penyebar', 'hoax....', 'tenggelamkan', '!!!'],
#  ['hhahahh',
#   'ya',
#   'jelas',
#   'uda',
#   'ketebak...',
#   'negri',
#   'dagelan...',
#   'yg',
#   'komen',
#   'jga',
#   'blaa',
#   'blaaa',
#   'blaaaa',
#   '😂🤣😂🤣',
#   'lanjutakan',
#   'saja...'],
#  ['terima', 'kasih', 'kejaksaan.'],
#  ['pak',
#   'jaksa',
#   'yg',
#   'hina',
#   'pak',
#   'jokowi',
#   'berkali2',
#   'pasti',
#   'pak',
#   'jaksa',
#   'tau',
#   'lah..tolong',
#   'di',
#   'seret',
#   'ke',
#   'penjara.',
#   'thanks..'],
#  ['sekalipun',
#   'benci',
#   'dng',
#   'jokowi',
#   'bukan',
#   'berarti',
#   'menebar',
#   'fitnah,',
#   'biar',
#   'bgaimanapun',
#   'jokowi',
#   'itu',
#   'presiden',
#   'pilihan',
#   'rakyat...',
#   'memfitnah',
#   'presiden',
#   '=',
#   'memfitnah',
#   'rakyat.'],
#  ['buron...', 'wkwk'],
#  ['kalo',
#   'di',
#   'turki,',
#   'ini',
#   'orang',
#   'sudah',
#   'diciduk',
#   'langsung',
#   'oleh',
#   'erdogan',
#   '(presiden',
#   'idaman',
#   'nya',
#   'pks',
#   '🤣)...',
#   'untung',
#   'lah',
#   'di',
#   'indonesia',
#   'ini',
#   'presiden',
#   'nya',
#   'jokowi',
#   'yg',
#   'orang',
#   'nya',
#   'lembut',
#   'dan',
#   'kalem',
#   '😁'],
#  ['kalo', 'dulu', 'menang..', 'udah', 'diangkat', 'menteri', 'nih', 'orang'],
#  ['kalo', 'dulu', 'menang..', 'udah', 'diangkat', 'menteri', 'nih', 'orang'],
#  ['kalo', 'dulu', 'menang..', 'udah', 'diangkat', 'menteri', 'nih', 'orang'],
#  ['kalo', 'dulu', 'menang..', 'udah', 'diangkat', 'menteri', 'nih', 'orang'],
#  ['kalo', 'dulu', 'menang..', 'udah', 'diangkat', 'menteri', 'nih', 'orang'],
#  ['boss', 'nya', 'juga', 'sekalian', 'disikat', 'toilet'],
#  ['boss', 'nya', 'juga', 'sekalian', 'disikat', 'toilet'],
#  ['jadi', 'inget', 'jaman', 'siapa', 'ya...'],
#  ['orang', 'bikin', 'rusak', 'harus', 'musnahkan'],
#  ['super', 'muantap👍👍👍'],
#  ['baguslah',
#   'diciduk,',
#   'sebelum',
#   'dikontrak',
#   'lagi',
#   'sama',
#   'tukang',
#   'fitnah'],
#  ['menjelekan',
#   'presiden',
#   'sama',
#   'saja',
#   'menghina',
#   'lambang',
#   'negara.',
#   'harusnya',
#   'berpikir',
#   'apalagi',
#   'seorang',
#   'redaksi',
#   'berita',
#   'yang',
#   'seharusnya',
#   'menjadi',
#   'panutan',
#   'beritanya.'],
#  ['semoga', 'betah', 'di', 'hotel', 'prodeo', 'ya', 'bro....'],
#  ['sebaiknya', 'orang', 'spt', 'ini', 'dilenyapkan', 'saja'],
#  ['sikat', 'ikat', 'berkas'],
#  ['fitnah', 'krn', 'duit', '😆'],
#  ['tlg', 'dikubur', 'dalam2', 'org', 'begini'],
#  ['langsung', 'buang', 'aja', 'kelaut'],
#  ['tunggu', 'siapa', 'yang', 'komen', 'membela...nah', 'itu', 'donaturnya'],
#  ['buniyani', 'gmn?'],
#  ['kokk',
#   'lama',
#   'sekali',
#   'pelaku',
#   'kejahatan',
#   'hoax',
#   'ini',
#   'baru',
#   'dijebloskan',
#   'ke',
#   'bui',
#   'sekarang....',
#   'usut',
#   'dan',
#   'tangkap',
#   'segera',
#   'pelaku',
#   'hoax',
#   'lainnya....'],
#  ['obor', 'hoax'],
#  ['bravo', 'kejaksaan,lumayan', 'ada', 'kerjanya..'],
#  ['mantap,', 'hajar', 'penyebar', 'hoax.'],
#  ['yg', 'di', 'negri', 'sebrang', 'bgmn'],
#  ['4', 'tahun?', 'pantesnya', '40', 'taon'],
#  ['itu', 'dlu', 'timses', 'syp', 'ea?'],
#  ['masih',
#   'bisa',
#   'gaya',
#   'gaya',
#   'an....',
#   'lihat',
#   'baju',
#   'mereka',
#   'seperti.......'],
#  ['mudah', '2', 'an', 'di', 'hukun', 'lebih', 'berat', 'lagi'],
#  ['wkwkwkwkwkw',
#   'syukurlah',
#   'kalian',
#   'banding',
#   'soalnya',
#   'hukuman',
#   'kalian',
#   'bakal',
#   'di',
#   'tambah',
#   'jd',
#   '10',
#   'thn,',
#   'nyungsep',
#   'kalian',
#   '.'],
#  ['sakit', 'jiwa', 'luuu...'],
#  ['sakit', 'jiwa', 'lluu...'],
#  ['kasihan',
#   'bener',
#   'mas',
#   'eko,',
#   'semoga',
#   'dapat',
#   'jalan',
#   'keluarnya..'],
#  ['jahat', 'sekali', 'yang', 'nipu'],
#  ['sebutin', 'aja', 'pengacaranya'],
#  ['nah,',
#   'mulai',
#   'terkuak',
#   'biang',
#   'keladinya',
#   '...',
#   'siapkan',
#   'bukti2',
#   'penyerahan',
#   'surat2',
#   'dan',
#   'tanda',
#   'terima',
#   'uang',
#   '...',
#   'dikasi',
#   'ga',
#   'waktu',
#   'entu?',
#   '...',
#   'kalo',
#   'ga',
#   'ada',
#   'bukti,',
#   'jangan',
#   'kau',
#   'harap',
#   'bisa',
#   'gugat',
#   'pengacara',
#   'ya',
#   '....'],
#  ['semoga',
#   'dapat',
#   'pengganti',
#   'pengacara',
#   'kondang',
#   'mas...',
#   'yang',
#   'kemarin',
#   'itu',
#   'abal',
#   'abal',
#   'punya'],
#  ['kasian',
#   'mas',
#   'eko',
#   'ini,',
#   'bisa2',
#   'dituduh',
#   'lg',
#   'sama',
#   'cebong',
#   'sebagai',
#   'sebar',
#   'hoax',
#   'krn',
#   'tdk',
#   'ada',
#   'buktinya.'],
#  ['yang',
#   'komentar',
#   'pada',
#   'ga',
#   'tahu',
#   'tentang',
#   'bagaimana',
#   'sertifikat',
#   'dibuat.',
#   'sertifikat',
#   'itu',
#   'bisa',
#   'muncul',
#   'kalau',
#   'ada',
#   'akses',
#   'jalan.',
#   'suruh',
#   'dia',
#   'tunjukin',
#   'denah',
#   'sertifikatnya',
#   '(kalau',
#   'dia',
#   'memang',
#   'punya).',
#   'itu',
#   'pasti',
#   'sertifikatnya',
#   'masih',
#   'gabung',
#   'ama',
#   'sebelah',
#   'kiri',
#   'atau',
#   'sebelah',
#   'kanannya,',
#   'dan',
#   'itu',
#   'pasti',
#   'masih',
#   'saudara',
#   'dia.',
#   'sertifikatnya',
#   'belum',
#   'dipecah',
#   'ama',
#   'mereka',
#   'berdua.'],
#  ['nanti', 'pintu', 'surganya', 'juga', 'diblokade', 'sama', 'tuhan.'],
#  ['sdh',
#   'bp',
#   'camat',
#   'yg',
#   'harus',
#   'menyelesaikan',
#   'biar',
#   'p',
#   'camat',
#   'dpt',
#   'pahala',
#   'membantu',
#   'yg',
#   'tertindas',
#   ',',
#   'toh',
#   'ga',
#   'lama',
#   'lagi',
#   'kita',
#   'mati',
#   'dan',
#   'runah',
#   'tanah',
#   'itu',
#   'tdk',
#   'di',
#   'bawaq'],
#  ['saya',
#   'tahun',
#   'kemarin',
#   'beli',
#   'tanah',
#   '20',
#   '�15',
#   'm.',
#   'tapi',
#   'saya',
#   'bikin',
#   'fondasi',
#   'pagar',
#   '19',
#   '�15m.',
#   'jadi',
#   'ada',
#   '1',
#   'meter',
#   'untuk',
#   'akses',
#   'jalan',
#   'setapak.',
#   'berarti',
#   'saya',
#   'relakan',
#   'tanah',
#   'saya',
#   '1�15m',
#   'utk',
#   'kepentingan',
#   'umum.',
#   'tetangga',
#   'sebelah',
#   'juga',
#   'demikian.',
#   'jadi',
#   'jalan',
#   'setapak',
#   'lebarnya',
#   '2',
#   'meter.',
#   'kita',
#   'kan',
#   'hidup',
#   'bertetangga.',
#   'masa',
#   'tanah',
#   'satu',
#   'meter',
#   'aja',
#   'menghalangi',
#   'silaturahmi',
#   'dengan',
#   'tetangga?',
#   'jadi',
#   'harus',
#   'dibicarakan',
#   'baik-baik.',
#   'semua',
#   'bisa',
#   'diatur',
#   'yg',
#   'penting',
#   'dengan',
#   'hati',
#   'nurani.'],
#  ['lemah',
#   'mati',
#   '(tidak',
#   'ada',
#   'akses',
#   'jalan)',
#   'itu',
#   'murah',
#   'harganya,',
#   'lha',
#   'ini',
#   'yg',
#   'punya',
#   'tanah',
#   'maruk',
#   'ud',
#   'deal',
#   '100jt',
#   'minta',
#   'naik',
#   '150jt.',
#   'jengkel',
#   'di',
#   'tutup',
#   'sekalian',
#   'ma',
#   'tetangga.',
#   'yakin',
#   'tuh',
#   'yg',
#   'punya',
#   'tanah',
#   'mati',
#   'pasti',
#   'kolot',
#   'jd',
#   'dikerjai',
#   'tetangga.�'],
#  ['klo',
#   'tdk',
#   'salah',
#   'ada',
#   'undang-undang',
#   '(pertanahan)',
#   'yg',
#   'mengatur',
#   'tentang',
#   'kewajiban',
#   'bagi',
#   'pemilik',
#   'tanah',
#   'dan',
#   'bangunan',
#   'untuk',
#   'memberi',
#   'akses',
#   'jalan',
#   'bagi',
#   'pemilik',
#   'tanah',
#   'dan',
#   'bangunan',
#   'dibelakangnya',
#   'yg',
#   'tdk',
#   'memiliki',
#   'akses',
#   'jalan',
#   'dlm',
#   'sertifikat',
#   'tanahnya',
#   '(istilahnya',
#   'tanah',
#   'helikopter)',
#   'minimal',
#   'jalan',
#   'setapak,',
#   'silahkan',
#   'dicek',
#   'saya',
#   'lupa',
#   'pasalnya.'],
#  ['tidak',
#   'berperikemanusiaan',
#   'yang',
#   'nutup',
#   'akses',
#   'itu.',
#   'maukah',
#   'dia',
#   'diperlakukan',
#   'seperti',
#   'itu?',
#   'tanya',
#   'ke',
#   'kupingnya',
#   'dengan',
#   'keras:',
#   'maukah',
#   'dia',
#   'diperlakukan',
#   'seperti',
#   'itu',
#   'jika',
#   'berada',
#   'di',
#   'belakang',
#   'rumah',
#   'orang',
#   'lain?'],
#  ['%u2063sepertinya',
#   'ada',
#   'yang',
#   '"',
#   'kurang',
#   'beres"',
#   'dengan',
#   'sertifikat-nya',
#   'di',
#   'antara',
#   'rumah',
#   'rumah',
#   'itu,',
#   'logikanya',
#   'rt\\/rw,',
#   'lurah,camat',
#   ',',
#   'bppn',
#   'waktu',
#   'menerbitkan',
#   'sertifikat',
#   'itu',
#   'pasti',
#   'tahu',
#   'posisi',
#   'dan',
#   'batas',
#   'batas',
#   'rumah.',
#   'pasti',
#   'ada',
#   'yang',
#   '"salah"',
#   'dengan',
#   'sertifikat',
#   'sertifikat',
#   'itu',
#   'tentang',
#   'batas-batas',
#   'tanahnya.',
#   'minimal',
#   'ada',
#   'hak',
#   'orang',
#   'yang',
#   'diserobot.',
#   'polisi',
#   'harus',
#   'turun',
#   'ini.'],
#  ['priksa',
#   'dulu',
#   'imb',
#   'nya',
#   'ada',
#   'gak?�',
#   'kalau',
#   'gak',
#   'ada',
#   'suruk',
#   'satpol',
#   'yg',
#   'bongkar',
#   'jangan',
#   'korbankan',
#   'tetangga'],
#  ['sebelum',
#   'semuanya',
#   'menjudge',
#   'tanpa',
#   'tabayyun..simple',
#   'utk',
#   'mencari',
#   'siapa',
#   'yg',
#   'salah..yg',
#   'diakui',
#   'selama',
#   'ini',
#   'sbagai',
#   'akses',
#   'jalan',
#   'pak',
#   'eko',
#   'ini',
#   'sebenarnya',
#   'memang',
#   'peruntukan',
#   'jalan',
#   'atau',
#   'menggunakan',
#   '/melewati',
#   'tanah',
#   'orang',
#   'lain?klo',
#   'memang',
#   'akses',
#   'jalan,tetangganya',
#   'jelas',
#   'salah!tapi',
#   'klo',
#   'itu',
#   'memang',
#   'tanah',
#   'org',
#   'lain,ya',
#   'memang',
#   'haknya',
#   'dia',
#   'utk',
#   'menembok.yg',
#   'salah',
#   'adalah',
#   'pemerintah',
#   'setempat.mana',
#   'akses',
#   'jalan',
#   'selama',
#   'ini',
#   'yg',
#   'harusnya',
#   'ada'],
#  ['yang',
#   'punya',
#   'tanah',
#   'nggak',
#   'bisa',
#   'disalahin',
#   'juga.memang',
#   'itu',
#   'haknya',
#   'dia.klo',
#   'dia',
#   'dituntut',
#   'harus',
#   'ngasih',
#   'sebagian',
#   'untuk',
#   'jalan,tetangga',
#   'kiri,kanan',
#   'n',
#   'belakang',
#   'pak',
#   'eko',
#   'juga',
#   'harus',
#   'dituntut',
#   'hal',
#   'yg',
#   'serupa.apesnya',
#   'dia',
#   'adalah',
#   'dia',
#   'baru',
#   'beli',
#   'n',
#   'bangun',
#   'skrg.'],
#  ['kasih', 'jln', 'pak.itu', 'ladang', 'amal', 'bpk�'],
#  ['klo',
#   'ud',
#   'deal',
#   '100jt',
#   'kok',
#   'ingkar',
#   'jd',
#   '150jt',
#   'ya???',
#   'hrsnya',
#   'jgn',
#   'serakah',
#   'jg',
#   'ya',
#   'klo',
#   'emank',
#   'maunya',
#   '150jt',
#   'ya',
#   'jgn',
#   'buka',
#   '100jt',
#   'donk...ntar',
#   'ada',
#   'yg',
#   'mau',
#   '150jt',
#   'ingkar',
#   'lgi',
#   '200jt...'],
#  ['akar', 'masalah', 'nya..', '�', '�', '�', '�', '�', '�duit'],
#  ['ya',
#   'sudah',
#   'to',
#   'pak',
#   'eko,',
#   'pindah',
#   'aja.',
#   'rumah',
#   'lama',
#   'jadikan',
#   'kandang',
#   'ayam',
#   'atau',
#   'studio',
#   'musik.',
#   'kan',
#   'haknya',
#   'pak',
#   'eko',
#   'juga',
#   'to?',
#   'saat',
#   'ketemu',
#   'tetangga',
#   'yang',
#   'gak',
#   'pedulian,',
#   'ya',
#   'sudah',
#   'jadikan',
#   'kita',
#   'gak',
#   'peduli.',
#   'ngalah',
#   'terus',
#   'tidak',
#   'selamanya',
#   'baik.'],
#  ['benernya',
#   'siapa',
#   'sie',
#   'yang',
#   'mau',
#   'beli',
#   'siapa',
#   'yang',
#   'mau',
#   'jual,?',
#   'kok',
#   'keterangan',
#   'camat',
#   'beda',
#   'sama',
#   'eko?',
#   'eko',
#   'bilang',
#   'dia',
#   'yang',
#   'mau',
#   'beli',
#   'tanah',
#   'tetangganya',
#   'buat',
#   'jalan,',
#   'kata',
#   'camat',
#   'malah',
#   'eko',
#   'yang',
#   'mau',
#   'jual,',
#   'malah',
#   'harga',
#   'naik',
#   'pula....ini',
#   'yakin',
#   'ada',
#   'yang',
#   'ga',
#   'beres',
#   'sama',
#   'si',
#   'eko...'],
#  ['gak',
#   'pernah',
#   'belajar',
#   'pmp,',
#   'mana',
#   'toleransi,saling',
#   'menghargai,ssopan',
#   'santun,empati',
#   'dalam',
#   'bertetangga.'],
#  ['dulu',
#   'sudah',
#   'mau',
#   'dibeli',
#   '100jt',
#   'tapi',
#   'ga',
#   'jadi',
#   'karena',
#   'naik',
#   'minta',
#   '150jt',
#   'giliran',
#   'dibikin',
#   'tembok',
#   'merengek',
#   'rengek',
#   'ngadu',
#   'kesana',
#   'kamari...',
#   'lebay'],
#  ['ujung', 'ujungnya', 'duit'],
#  ['sdh', 'terbaca...pokok', 'permasalah', 'nya...'],
#  ['camat',
#   'koq',
#   'minta2.',
#   'keluar',
#   'dari',
#   'kantor',
#   'kalian',
#   'itu',
#   'hei',
#   'camat,',
#   'lurah.',
#   'jgn',
#   'ongkang2',
#   'keq',
#   'kumpeni',
#   'aje',
#   'lu',
#   'pade.'],
#  ['jangan',
#   'maen',
#   'asal',
#   'ngomong',
#   'nuduh',
#   'salah',
#   'satu',
#   'pihak.',
#   'masalah',
#   'ini',
#   'terjadi',
#   'bukan',
#   'krn',
#   'pihak',
#   'yg',
#   'bersengketa',
#   'saja.',
#   'ada',
#   'peran',
#   'rt',
#   'rw',
#   'lurah',
#   'camat',
#   'serta',
#   'pihak',
#   'pertanahan.',
#   'rencana',
#   'tata',
#   'ruangnya',
#   'mana?',
#   'masing2',
#   'punya',
#   'andil',
#   'dalam',
#   'terjadinya',
#   'masalah',
#   'ini.',
#   'bukan',
#   'serta',
#   'merta',
#   'gr2',
#   'pihak',
#   'pak',
#   'eko',
#   'ataupun',
#   'tetangganya.�'],
#  ['pny',
#   'tanah',
#   'pribadi',
#   'jng',
#   'dibuat',
#   'jalanan,',
#   'nnt',
#   'diserobot%ud83d%ude0b'],
#  ['jadi',
#   'sudah',
#   'jelas',
#   'to',
#   'akar',
#   'masalahnya..lain',
#   'kumbang',
#   'lain',
#   'belangnya...%ud83d%ude02'],
#  ['seharusnya',
#   'ke',
#   'pangadilan',
#   'saja.',
#   'apapun',
#   'hasilnya',
#   'itu',
#   'yang',
#   'akan',
#   'diakui',
#   'secara',
#   'hukum.',
#   'kalau',
#   'curhat',
#   'kemana2',
#   'pasti',
#   'hanya',
#   'dapat',
#   'lip',
#   'service',
#   'saja,',
#   'karena',
#   'mereka',
#   'hanya',
#   'bisa',
#   "'menghimbau'..."],
#  ['sdh',
#   'mau',
#   'dibeli',
#   '100jt,',
#   'tp',
#   'naik',
#   'jd',
#   '150jt',
#   'lg....dr',
#   'sini',
#   'sdh',
#   'sdkt',
#   'jls',
#   'akar',
#   'mslhnya'],
#  ['ko',
#   'masih',
#   'ada',
#   'ya',
#   'orang',
#   'kaya',
#   'gitu..tinggal',
#   'di',
#   'perkampungan',
#   '..mending',
#   'di',
#   'kubur',
#   'aja'],
#  ['spekulasi',
#   'tu.',
#   'yg',
#   'jd',
#   'pertanyaan',
#   'ketika',
#   'jual',
#   'beli',
#   'kan',
#   'ada',
#   'form',
#   'tanda',
#   'tangan',
#   'sepengetahuan',
#   'jiran',
#   'kanan',
#   'kiri',
#   'dpn',
#   'blkg.',
#   'dr',
#   'situ',
#   'sdh',
#   'dpt',
#   'awal',
#   'masalahnya.',
#   'kmn',
#   'tu',
#   'pak',
#   'rt',
#   'rw,',
#   'kadus',
#   'n',
#   'kades???'],
#  ['klpun',
#   'd',
#   'kasih',
#   'jalan',
#   'jg',
#   'mending',
#   'pindah',
#   'aja',
#   'pak...punya',
#   'tetangga',
#   'kayak',
#   'gitu',
#   'modelnya',
#   'susah',
#   'liat',
#   'orang',
#   'senang,senang',
#   'liat',
#   'orang',
#   'susah'],
#  ['knpa',
#   'setelah',
#   'viral',
#   'di',
#   'medsos,',
#   'camat',
#   'nya',
#   'baru',
#   'turun',
#   'tangan,�',
#   'pak',
#   'eko',
#   'bilang',
#   'sdh',
#   '3',
#   'thn',
#   'mondarmandir',
#   'utk',
#   'cari',
#   'solusi...�',
#   'jadi',
#   'klu',
#   'ada',
#   'masalh',
#   'sprti',
#   'ini,',
#   'mendingan',
#   'di',
#   'viralkan,�',
#   'spya',
#   'cepat',
#   'ditanggapi'],
#  ['masoook', 'pak', 'eko'],
#  ['tetangga',
#   'kayak',
#   'gini',
#   'harus',
#   'buru',
#   'buru',
#   'di',
#   'mandiin,',
#   'di',
#   'solatin,',
#   'di',
#   'kafanin',
#   'dan',
#   'dikuburin',
#   'langsung.',
#   'ga',
#   'ada',
#   'adabnya.'],
#  ['gabisa', 'masook', 'pak', 'ekooo'],
#  ['"%u2063saya',
#   'enggak',
#   'nyebutin',
#   'kronologi',
#   'karena',
#   'privacy"',
#   'hmm',
#   'ada',
#   'yang',
#   'aneh'],
#  ['disini',
#   'banyak',
#   'pendukung',
#   'tetangga',
#   'pak',
#   'eko',
#   'atau',
#   'mgkn',
#   'tetangga',
#   'disitu?',
#   'wkwkww'],
#  ['dijual', 'ke', 'tetangga', 'depan/', 'samping', 'saja', 'pak'],
#  ['rt',
#   'rw',
#   'lurah',
#   'camat',
#   'bpn',
#   'walkot',
#   '/bupati',
#   'tidorrrr',
#   'semuaaaaaa'],
#  ['masssook', 'pak', 'ekoo'],
#  ['harusnya',
#   'dipikirin',
#   'sejak',
#   'dini,',
#   'kalo',
#   'sudah',
#   'begini',
#   'bingung',
#   'dah',
#   'lu',
#   'eko.....%ud83d%ude33%ud83d%ude33%ud83d%ude33',
#   'slh',
#   'elu',
#   'sendiri'],
#  ['kalau',
#   'mau',
#   'jual',
#   'ya',
#   'ke',
#   'tetangganya...',
#   'gak',
#   'usah',
#   'cari',
#   'sensasi...',
#   'banyak',
#   'kok',
#   'org',
#   'lqin',
#   'yg',
#   'rugi',
#   'lebih',
#   'banyak',
#   'utk',
#   'urusan2',
#   'tanah...',
#   'bahkan',
#   'tanah',
#   'dgn',
#   'surat',
#   'berlapis',
#   'juga',
#   'ada..',
#   'toh',
#   'yg',
#   'rugi',
#   'pemilik...',
#   'org',
#   'bpn',
#   'palingan',
#   'hanya',
#   'di',
#   'mutasi..',
#   'apalagi',
#   'kl',
#   'sdh',
#   'pensiun,',
#   'gak',
#   'ada',
#   'sangsi',
#   'apa2...!!!!!�'],
#  ['ini',
#   'eko',
#   'nya',
#   'yg',
#   'bodohhh',
#   'sejak',
#   'awal%ud83d%ude06%ud83d%ude06%ud83d%ude06'],
#  ['undang2',
#   'sdh',
#   'mengatur',
#   'klo',
#   'pembangunan',
#   'tidal',
#   'boleh',
#   'menutup',
#   'akses',
#   'jalan',
#   'bagi',
#   'rumah',
#   'atau',
#   'tempat',
#   'tinggal',
#   'yg',
#   'sudah',
#   'ada',
#   'sebelumnya,',
#   'mohon',
#   'koreksi',
#   'klo',
#   'salah'],
#  ['kayak',
#   'nya',
#   'si',
#   'eko',
#   'ini',
#   'punya',
#   'kelainan',
#   'cara',
#   'bertetangga',
#   'deh....'],
#  ['masooookkkk', 'pak', 'ekooo....'],
#  ['pak',
#   'eko',
#   'punya',
#   'imb?�',
#   'kok',
#   'bisa',
#   'bangun',
#   'rumah�',
#   'tanpa',
#   'halaman?�'],
#  ['solusinya',
#   'ya',
#   'jual',
#   'ke',
#   'tetangga',
#   'depannya',
#   'itu',
#   'pak.',
#   'hitung',
#   'harga',
#   'tanah',
#   'saja',
#   'karena',
#   'memang',
#   'rumah',
#   '\\/',
#   'tanah',
#   'bpk',
#   'di',
#   'block',
#   'sama',
#   'dia',
#   ',banyak',
#   'yang',
#   'seperti',
#   'itu',
#   '"istilahnya',
#   'lock',
#   'land',
#   '"',
#   'jadi',
#   'memang',
#   'dia',
#   'beli',
#   'atau',
#   'bpk',
#   'bisa',
#   'juga',
#   'beli',
#   'tanah',
#   'didepan',
#   'untuk',
#   'akses',
#   '.'],
#  ['beli',
#   'aja',
#   'tanah',
#   'tetangga',
#   'atau',
#   'jual',
#   'rumahnya',
#   'ke',
#   'tetangganya'],
#  ['ya',
#   'harusnya',
#   'dari',
#   'awal',
#   'pak',
#   'eko',
#   'sudah',
#   'membuat',
#   'jalan',
#   'utk',
#   'rumahnya',
#   'sendiri.',
#   'bukan',
#   'nya',
#   'membuat',
#   'rumah',
#   'full',
#   'bangunan,',
#   'tp',
#   'disisakan',
#   'utk',
#   'jalan.',
#   'hak',
#   'tetangga',
#   'jg',
#   'membuat',
#   'rumah',
#   'di',
#   'tanahnya',
#   'sandiri',
#   'seperti',
#   'yg',
#   'dilakukan',
#   'pak',
#   'eko.',
#   'kejadian',
#   'sebenarnya',
#   'masih',
#   'misteri',
#   'siapa',
#   'yg',
#   'salah',
#   'dan',
#   'yg',
#   'benar',
#   'masih',
#   'abu2..'],
#  ['masuk', 'pak', 'eko', '!!!'],
#  ['tata', 'ruangnya', 'amburadul'],
#  ['sebetulnya',
#   'yg',
#   'paling',
#   'salah',
#   'adalah',
#   'bpn...',
#   'karna',
#   'di',
#   'peraturan',
#   'agraria',
#   'terutuang',
#   'hukum',
#   'mengenai',
#   'pemberian',
#   'jalan',
#   'kepada',
#   'tanah',
#   'yg',
#   'tdk',
#   'memiliki',
#   'jalan...',
#   'cth',
#   'tanah',
#   'yg',
#   'di',
#   'tengah',
#   'telah',
#   'disertifikat...',
#   'di',
#   'kanan',
#   'dan',
#   'dikiri',
#   'pun',
#   'telah',
#   'bersertifikat',
#   'dan',
#   'menutup',
#   'jalan...',
#   'di',
#   'depannya',
#   'jg',
#   'dibuat',
#   'sertifikat',
#   'dan',
#   'menutup',
#   'akses',
#   'yg',
#   'ditgh',
#   'sementara',
#   'blkg',
#   'belum...',
#   'nah',
#   'ketika',
#   'belakang',
#   'membuat',
#   'sertifikat',
#   'secara',
#   'otomatis',
#   'yg',
#   'belakang',
#   'akan',
#   'kepotong',
#   'tanahnya',
#   'dan',
#   'memberikan',
#   'akses',
#   'jalan',
#   'yg',
#   'ditengah...',
#   'cuma',
#   'masyarakat',
#   'bnyk',
#   'yg',
#   'awam',
#   'dgn',
#   'peraturan',
#   'tersebut...'],
#  ['ketua',
#   'rt',
#   'rw',
#   'lurah',
#   'ko',
#   'pd',
#   'diem',
#   'ayu',
#   'bantu',
#   'warganya',
#   'masa',
#   'kalah',
#   'gantian',
#   'tutup',
#   'jlnnya'],
#  ['kemungkinan',
#   'besar',
#   'ada',
#   'yg',
#   'gak',
#   'beres',
#   'dg',
#   'proses',
#   'penerbitan',
#   'imb...'],
#  ['bisa',
#   'dirundingkan',
#   '.lha',
#   'sebelumnya',
#   'ditawari',
#   'tanah',
#   'tetangganya',
#   'tidak',
#   'mau',
#   '.ya',
#   'bukan',
#   'salah',
#   'yang',
#   'memblokade�',
#   '.makanya',
#   'harus',
#   'baik',
#   'baik',
#   'dengan',
#   'tetangga',
#   'dan',
#   'pengurus',
#   'rt',
#   'setempat�'],
#  ['tdk',
#   'diperbolehkan',
#   '(perda)',
#   'membangun',
#   'tp',
#   'merugikan',
#   'tetangga',
#   '(walaupun',
#   'di',
#   'lahan',
#   'sendiri),',
#   'biasanya',
#   'jika',
#   'trjadi',
#   'spt',
#   'itu',
#   'dinas',
#   'pengawasan',
#   'pembangunan',
#   'akan',
#   'bertindak.'],
#  ['masuuukkk', 'pakk', 'ekoo'],
#  ['pastinya', 'orang', 'ini', 'bermasalah', 'dengan', 'tetangganya', '....'],
#  ['jual', 'sama', 'yg', 'ngeblokade'],
#  ['silaturahmi',
#   'dgn',
#   'tetangga',
#   'itu',
#   'penting.',
#   'walau',
#   'akses',
#   'ditutup',
#   'kalau',
#   'tetangga',
#   'seperti',
#   'saudara',
#   'pasti',
#   'dikasih',
#   'jalan...',
#   'tinggal',
#   'ketok',
#   'rumah',
#   'tetangga',
#   'terus',
#   '%u201cmasuk',
#   'pak',
#   'eko%u201d'],
#  ['imb', 'bisa', 'keluar?'],
#  ['ya',
#   'hak',
#   'tetangga',
#   'juga',
#   'blokade',
#   'jalan',
#   'karena',
#   'mungkin',
#   'itu',
#   'tanah',
#   'tetangga,',
#   'harusnya',
#   'di',
#   'musyawarahkan',
#   'baik2',
#   'dgn',
#   'tetangga,',
#   'klo',
#   'kita',
#   'baik',
#   'ke',
#   'tetangga',
#   'gak',
#   'mungkin',
#   'tetangga',
#   'akan',
#   'setega',
#   'itu',
#   'memblokade',
#   'jlan.�'],
#  ['waras', 'slamet', 'pak', 'eko', 'tenang', 'aja', 'gusti', 'tak', 'sare'],
#  ['mana',
#   'kades',
#   'nya???',
#   'masa',
#   'ada',
#   'warganya',
#   'yg',
#   'bermasalah',
#   'gini',
#   'ga',
#   'diselesaikan'],
#  ['surat',
#   'kog',
#   'dilempar',
#   'memangnya',
#   'koran',
#   '???',
#   'meskipun',
#   'bener',
#   'koran',
#   'apa',
#   'sopan',
#   'lempar',
#   'koran',
#   'ke',
#   'presiden',
#   '????',
#   'apa',
#   'gak',
#   'bisa',
#   'dititipkan',
#   'suratnya',
#   'lewat',
#   'paspampres',
#   '????'],
#  ['ya',
#   'jelas',
#   'dikejar',
#   'pampapres,',
#   'ngelempar',
#   'benda',
#   'seperti',
#   'itu',
#   'ke',
#   'presiden.',
#   'itu',
#   'sudah',
#   'tugas',
#   'mereka',
#   'menjaga',
#   'presiden'],
#  ['sifatmu',
#   'mungkin',
#   'juga',
#   'ga',
#   'benar.',
#   'main',
#   'lempar',
#   'surat',
#   'tanpa',
#   'pikir',
#   'kesopanan.',
#   'instropeksi',
#   'pak',
#   'eko'],
#  ['tetangga', 'masa', 'gitu', '??'],
#  ['%u2063sepertinya',
#   'ada',
#   'yang',
#   '"',
#   'kurang',
#   'beres"',
#   'dengan',
#   'sertifikat-nya',
#   'di',
#   'antara',
#   'rumah',
#   'rumah',
#   'itu,',
#   'logikanya',
#   'rt\\/rw,',
#   'lurah,camat',
#   ',',
#   'bppn',
#   'waktu',
#   'menerbitkan',
#   'sertifikat',
#   'itu',
#   'pasti',
#   'tahu',
#   'posisi',
#   'dan',
#   'batas',
#   'batas',
#   'rumah.',
#   'pasti',
#   'ada',
#   'yang',
#   '"salah"',
#   'dengan',
#   'sertifikat',
#   'sertifikat',
#   'itu',
#   'tentang',
#   'batas-batas',
#   'tanahnya.',
#   'minimal',
#   'ada',
#   'hak',
#   'orang',
#   'yang',
#   'diserobot.',
#   'polisi',
#   'harus',
#   'turun',
#   'ini.'],
#  ['wah',
#   'kalo',
#   'saja',
#   'sampe',
#   'ke',
#   'telinga',
#   'jokowi',
#   'pasti',
#   'akan',
#   'dibuatin',
#   'flyover'],
#  ['bandung',
#   '/',
#   'jabar',
#   'ada',
#   'gubernur',
#   'baru...',
#   'kalau',
#   'yang',
#   'dulu',
#   'emang',
#   'parah,',
#   'sekarang',
#   'lapor',
#   'pasti',
#   'di',
#   'beresin...',
#   'ngak',
#   'semua-semua',
#   'ke',
#   'presiden',
#   'kalees'],
#  ['katanya', 'pak', 'camat', 'tidak', 'tahu'],
#  ['yang',
#   'memblokade',
#   'pasti',
#   'orang',
#   'kuat',
#   'juga',
#   'orang',
#   'penting,',
#   'sampai',
#   'camat',
#   'gak',
#   'bisa',
#   'nyelesaikan.'],
#  ['sudah',
#   'bodoh',
#   'mau',
#   'menang',
#   'sendiri,',
#   'ini',
#   'problem',
#   'di',
#   'daerah2',
#   'mengharapkan',
#   'tetangga',
#   'memberikan',
#   'jalan,',
#   'sementara',
#   'mereka',
#   'banyak',
#   'yang',
#   'membuat',
#   'rumah',
#   'atau',
#   'pagar',
#   'melebihi',
#   'ukuran',
#   'sk',
#   'tanah',
#   'yang',
#   'dimiliki',
#   'alias',
#   'menyerobot',
#   'tanah',
#   'tetangga.'],
#  ['coba', 'ke', 'kopi', 'joni', 'lahh'],
#  ['kalau',
#   'semua',
#   'ke',
#   'jokowi',
#   'ya',
#   'ga',
#   'mungkin.',
#   'ada',
#   'jutaan',
#   'masalah',
#   'di',
#   'indonesia.',
#   'urutannya',
#   'itu',
#   'bisa',
#   'minta',
#   'mediasi',
#   'didampingi',
#   'rt/rw',
#   'ke',
#   'kelurahan,',
#   'kalau',
#   'gagal',
#   'ya',
#   'ke',
#   'kecamatan.',
#   'kalau',
#   'ga',
#   'bisa',
#   'dateng',
#   'mediasi,',
#   'ya',
#   'tulis',
#   'surat',
#   'resmi',
#   'ke',
#   'kelurahan,',
#   'kecamatan,',
#   'kotamadya.',
#   'kalau',
#   'tidak',
#   'ditanggapi',
#   'bisa',
#   'tulis',
#   'pengaduan',
#   'ke',
#   'ombudsman.',
#   'banyak',
#   'kok',
#   'permasalahan',
#   'yg',
#   'sampai',
#   'ke',
#   'ombudsman,',
#   'dan',
#   'langsung',
#   'di',
#   'follow',
#   'up',
#   'antara',
#   '1-2',
#   'bulan.',
#   'ga',
#   'usah',
#   'tunggu',
#   '3',
#   'tahun',
#   'ngejar2',
#   'presiden.'],
#  ['tp', 'msh', 'bisa', 'keluar', 'rumah', 'ga?'],
#  ['inilah',
#   'contoh',
#   'manusia',
#   'indonesia',
#   'jaman',
#   'now',
#   'yg',
#   'katanya',
#   'pancasilais',
#   'ternyata',
#   'egois',
#   'tk',
#   'ada',
#   'toleransi',
#   'sedikitpun',
#   'kpd',
#   'sesama',
#   'pd',
#   'sesama',
#   'tetangga....',
#   'rt',
#   'rw',
#   'lurah',
#   'nya',
#   'camaunya',
#   'walikota',
#   'nya',
#   'gubernur',
#   'nya',
#   'pancasila',
#   'nya',
#   'mana?'],
#  ['akalnya',
#   'aja',
#   'kurang',
#   'pinter,',
#   'itu',
#   'bikin',
#   'lif',
#   'sampai',
#   'atas',
#   'genteng',
#   'kan',
#   'bisa,',
#   'terus',
#   'bikin',
#   'tol',
#   'diatas',
#   'genteng',
#   'sampai',
#   'jalan',
#   'raya,',
#   'hehehe....'],
#  ['pertanyaanya...???',
#   'bagaimana',
#   'hubungan',
#   'bertetangganya',
#   'kok',
#   'sampe',
#   'tega',
#   'di',
#   'block',
#   'gitu?',
#   'kita',
#   'tdk',
#   'tau',
#   'ada',
#   'permasalahan',
#   'apa.',
#   'sedangkan',
#   'pak',
#   'eko',
#   'slalu',
#   'bilang',
#   'privacy.',
#   'lha',
#   'piye',
#   'to?'],
#  ['surat',
#   'rumah',
#   'pak',
#   'eko',
#   'ternyata',
#   'gak',
#   'beres.',
#   'pantesan',
#   'gak',
#   'ada',
#   'yg',
#   'bisa',
#   'belain',
#   'krn',
#   'secara',
#   'hukum',
#   'pak',
#   'eko',
#   'melakukan',
#   'pelanggaran.',
#   'ternyata',
#   'pak',
#   'eko',
#   'minta',
#   'simpati',
#   'publik',
#   'pdhal',
#   'secara',
#   'hukum',
#   'dia',
#   'bersalah.'],
#  ['knapa',
#   'buat',
#   'rumah',
#   'tidak',
#   'membuat',
#   'akses',
#   'utk',
#   'jalan',
#   'sendiri?',
#   'bearti',
#   'selama',
#   'ini',
#   'mengambil',
#   'jalan',
#   'dari',
#   'tanah',
#   'orang',
#   'lain?',
#   'mengambil',
#   'hak',
#   'tetangga',
#   'utk',
#   'kepentingan',
#   'sendiri?'],
#  ['mungkin',
#   'pak',
#   'eko',
#   'disuruh',
#   'bayar',
#   'akses',
#   'jalan',
#   'tp',
#   'g',
#   'mau...',
#   'kl',
#   'spt',
#   'ini',
#   'ya',
#   'g',
#   'akan',
#   'ada',
#   'titik',
#   'temu.',
#   'krn',
#   'pemilik',
#   'jalan',
#   'mumgkin',
#   'beli',
#   'keseluruhan',
#   'tp',
#   'pak',
#   'eko',
#   'minta',
#   'cuma2',
#   'doang.',
#   'tiap',
#   'jengkal',
#   'tanah',
#   'itu',
#   'berharga,',
#   'apalagi',
#   'diperkotaan'],
#  ['aneh',
#   'sih',
#   'memang',
#   'kelakuan',
#   'tetangga',
#   'sprt',
#   'ini.',
#   'biasanya',
#   'sih....mhn',
#   'maaf,',
#   'yg',
#   'sering',
#   'model2',
#   'tutup',
#   'jalan,',
#   'tutup',
#   'got',
#   'krn',
#   'itu',
#   'dulu',
#   'tanah',
#   'engkong',
#   'gw,',
#   'itu',
#   'dulu',
#   'punya',
#   'babak',
#   'gw...kan',
#   'bukan',
#   'orang',
#   'sunda.'],
#  ['salah',
#   'sendiri',
#   'lah',
#   'kenapa',
#   'dulu',
#   'gak',
#   'dijual',
#   'aja',
#   'tuh',
#   'rumah.',
#   'jual',
#   'murah',
#   'aja',
#   'sama',
#   'tetangga',
#   'pake',
#   'njop',
#   'jgn',
#   'pake',
#   'harga',
#   'pasar.',
#   'dungu',
#   'dipelihara',
#   '!!'],
#  ['aparat',
#   'kecamatan',
#   'sama',
#   'desa',
#   'nya',
#   'saja..�',
#   'yg',
#   'gk',
#   'becus',
#   'buat',
#   'me',
#   'mediasi',
#   'masalah',
#   'seperti',
#   'itu..�',
#   'ganti',
#   'langsung',
#   'camat',
#   'sama',
#   'lurah',
#   'nya..',
#   'kok',
#   'ada',
#   'masyarakat',
#   'nya',
#   'susah',
#   'gk',
#   'segera',
#   'di',
#   'bantu',
#   'penyelesaian',
#   'masalah',
#   'nya..�'],
#  ['mas',
#   'eko',
#   'anda',
#   'harus',
#   'info',
#   'ke',
#   'media',
#   'sewaktu',
#   'anda',
#   'sudah',
#   'melaporkan',
#   'ke',
#   'dinas',
#   'terkait',
#   'bahkan',
#   'sampai',
#   'gubernur',
#   'dan',
#   'tidak',
#   'ditanggapi.ada',
#   'hrs',
#   'cerita',
#   'siapa',
#   'saja',
#   'sehingga',
#   'anda',
#   'tidak',
#   'sebar',
#   'fitnah.biar',
#   'oknum2',
#   'ini',
#   'biar',
#   'ditindak',
#   'bila',
#   'itu',
#   'benar',
#   'adanya.jgn',
#   'pernah',
#   'takut'],
#  ['rt', 'rw', 'kelurahan', 'camat.�', 'gk', 'becus�'],
#  ['sabar',
#   'pak',
#   'eko',
#   'semua',
#   'akan',
#   'di',
#   'selesaikan',
#   'dlm',
#   'hitungan',
#   'jam',
#   'tp',
#   'di',
#   'tahun',
#   '2019',
#   'setelah',
#   'rezim',
#   'berganti....'],
#  ['hhhh',
#   'aneh',
#   'org',
#   'lempar',
#   'kertas',
#   'dikejar',
#   'tapi',
#   'org',
#   'bisa',
#   'nepuk',
#   'jokowi',
#   'wkt',
#   'touring',
#   'motor',
#   'ga',
#   'diinterogasi',
#   'atau',
#   'dilumpuhkan',
#   'paspampres....setting',
#   'pencitraan',
#   'atau',
#   'paspampresnya',
#   'yg',
#   'ga',
#   'becus',
#   'ngawal',
#   'presiden?'],
#  ['teu',
#   'make',
#   'duit',
#   'mah...',
#   'rek',
#   'aya',
#   'anu',
#   'peduli',
#   'kumaha',
#   'atuh',
#   'kang..?�',
#   'sing',
#   'sadar',
#   'weh',
#   'ayeunamah..',
#   'urang',
#   'hirup',
#   'di',
#   'nagara',
#   'kos',
#   'kumaha...�'],
#  ['kelihatannya',
#   'semua',
#   'tanahnya�',
#   'sudah',
#   'ber',
#   'sertifikat,',
#   'kenapa',
#   'tidak',
#   'di',
#   'pertanyakan',
#   'ke',
#   'badan',
#   'pertanahan.',
#   'seharusnya',
#   'tidak',
#   'ada',
#   'penerbitan',
#   'sertifikat',
#   'tanpa',
#   'ada',
#   'jalan',
#   'melalui',
#   'tanah',
#   'tersebut,',
#   'kalo',
#   'tidak',
#   'ada',
#   'tanggapan',
#   'dari',
#   'bpn,',
#   'maka',
#   'ajukan',
#   'gugatan',
#   'ke',
#   'ptun',
#   'dimana',
#   'bpn',
#   'sebagai',
#   'tergugat',
#   '1.'],
#  ['harusnya',
#   'waktu',
#   'dikejar',
#   'nyerahin',
#   'diri',
#   'aja',
#   'biar',
#   'pak',
#   'jokowi',
#   'tau',
#   'masalahnya..',
#   'tapi',
#   'kenapa',
#   'bapak',
#   'lari',
#   'sih..',
#   'itu',
#   'kesempatan',
#   'emas',
#   'padahal',
#   'pak...'],
#  ['pemerintah', 'bandung', 'gak', 'becus', 'kerja'],
#  ['ya', 'iyalah,', 'maen', 'lempar', 'aja.�'],
#  ['sebenarnya',
#   'masalahnya',
#   'apa?',
#   'kenapa',
#   'tidak',
#   'ada',
#   'penyelesaian?',
#   'mana',
#   'bupati',
#   'bandung?',
#   'kenapa',
#   'diam',
#   'diam',
#   'saja.',
#   'minta',
#   'dipecat',
#   '?!!!'],
#  ['coba',
#   'diselesaikan',
#   'secara',
#   'kekeluargaan..',
#   'dg',
#   'hati',
#   'dingin',
#   'tanpa',
#   'erosi',
#   'insyaallah',
#   'ketemu',
#   'jalanya.%ud83d%ude0e'],
#  ['aneh??',
#   'segitu',
#   'egoisnya',
#   'kah',
#   'paravtetangga?',
#   'rt',
#   'rw',
#   'sama',
#   'lurah',
#   'gak',
#   'bisa',
# ...
#   'sdh',
#   'dilakukan',
#   'pres',
#   'jokowi',
#   'disana..prinsip',
#   'keadilan',
#   'nyata',
#   'dilakukan',
#   'bukan',
#   'sekedar',
#   'jargon',
#   'politik...',
#   '#2019orangbaikhasilnyabaik'],
#  ['ngomong',
#   'ngak',
#   'kuat',
#   'krn',
#   'kardus',
#   'sdh',
#   'di',
#   'embat...',
#   'kelakuan',
#   'politisi',
#   'sontoloyo'],
#  ['coba',
#   'pendapat',
#   'bapak',
#   'ini',
#   'disampaikan',
#   'ke',
#   'junjungan',
#   'bapak....ar.',
#   'supaya',
#   'gak',
#   'nyinyir.....kata',
#   'beliau',
#   'gak',
#   'mungkin.'],
#  ['ibarat',
#   'bangunan',
#   'mewah',
#   'koalisi',
#   'ini',
#   'sebenarnya',
#   'kropos',
#   'dan',
#   'rapuh...gmn',
#   'mau',
#   'mau',
#   'menang',
#   'ini,',
#   'ngurus',
#   'intern',
#   'koalisi',
#   'iji',
#   'aja',
#   'ga',
#   'bisa...hidup',
#   'jkw',
#   '2',
#   'periode'],
#  ['hahahaha....seru',
#   'neh...mantap',
#   'masa',
#   'pks',
#   'dan',
#   'pan',
#   'aja',
#   'yg',
#   'dapat,',
#   'sikatlah',
#   'pd',
#   'jgn',
#   'mau',
#   'dibohongi',
#   'sama',
#   'gerindra,',
#   'pks',
#   'dan',
#   'pan..hahaha'],
#  ['hajar',
#   'bleh,',
#   'sikat',
#   'terus,',
#   'masa',
#   'cuma',
#   'mereka',
#   'doang',
#   'yang',
#   'dapat',
#   'kardus',
#   'pd',
#   'engga,',
#   'ayo',
#   'jangan',
#   'mau,',
#   'tuntut',
#   'juga',
#   'bagian',
#   'kardusmu�'],
#  ['koalisi',
#   'gak',
#   'mutu.....percuma',
#   'lo',
#   'pada',
#   'eker2.....nyungsep',
#   'lo',
#   'semua'],
#  ['mau',
#   'menuding',
#   'dua',
#   'atau',
#   'tiga',
#   'kaki',
#   'juga',
#   'gamasalah',
#   'bos.yg',
#   'penting',
#   'pks',
#   'sudah',
#   'dapat',
#   '500',
#   'm.berarti',
#   'pertahun',
#   '100m.lumayan',
#   'kan',
#   'coba',
#   'klw',
#   'ngandalkan',
#   'dari',
#   'hasil',
#   'korupsi',
#   'atau',
#   'pemberian',
#   'jangan2',
#   'di',
#   'ott',
#   'sama',
#   'kpk.',
#   'ahirnya',
#   'gigit',
#   'jari',
#   'donk',
#   'klw',
#   'ini',
#   'kan',
#   'barter',
#   'meskipun',
#   'nantinya',
#   'kalah',
#   '&',
#   'pasti',
#   'kalah',
#   'dlm',
#   'pilpres',
#   'gamasalah',
#   'yg',
#   'rugi',
#   'kan',
#   'bukan',
#   'pks',
#   'atau',
#   'pan',
#   'paham',
#   'kan',
#   'sekarang?yg',
#   'penting',
#   'duitnya',
#   'gerindra',
#   'sdh',
#   'keluar',
#   '&',
#   'klw',
#   'ada',
#   'bahasa',
#   'untuk',
#   'kampanye',
#   'itu',
#   'kan',
#   'cuma',
#   'alasan',
#   'saja',
#   'biar',
#   'garibut.'],
#  ['yahh',
#   'kenyataannya',
#   'semuanya',
#   'main',
#   '2',
#   'kaki',
#   'dan',
#   'oportunis....',
#   'mau',
#   'apa',
#   'lagi???'],
#  ['andi',
#   'juga',
#   'aneh',
#   'pake',
#   'ngomong',
#   'udah',
#   'jelas',
#   'parte',
#   'kemunafikan',
#   'sejati,',
#   'cebong',
#   'kejet2',
#   'gagal',
#   'mupe',
#   'on.'],
#  ['yah...', 'apakah', 'masih', 'percaya', 'dengan', 'omomgannya?�'],
#  ['kalau',
#   'panas',
#   'dalam',
#   'minum',
#   'tuh',
#   'kaki',
#   '3',
#   'biar',
#   'adem..he..he.'],
#  ['ketua', 'diam', '...', 'bisa', 'dianggap', 'seruju'],
#  ['udaah',
#   'mending',
#   'bubar',
#   'aja',
#   'niih',
#   'koalisi',
#   'ga',
#   'bermutu...bukanya',
#   'bikin',
#   'program',
#   'malah',
#   'ribut',
#   'sendiri,',
#   'mendiing',
#   'bubar',
#   'lagian',
#   'sdh',
#   'pasti',
#   'kalah',
#   'kok',
#   'ngapain',
#   'd',
#   'lanjutkan�'],
#  ['haqul.yakin',
#   'pekaes',
#   'dan',
#   'pante',
#   'nyungsep',
#   'suaranya',
#   'pemilu',
#   '2019�'],
#  ['koalisi', 'serapuh', 'kardus', 'basah'],
#  ['andi',
#   'arief',
#   'yg',
#   'selalu',
#   'menyerang',
#   'koalisi',
#   'sendiri',
#   'ini',
#   'kenapa',
#   'tdk',
#   'ditegur',
#   'sby.',
#   'ada',
#   'apa',
#   'di',
#   'koalisi',
#   'prabowo',
#   'sandiaga',
#   '???',
#   'padahal',
#   'bersikap',
#   'pura2',
#   'netral',
#   'di',
#   'pilpres',
#   '2014',
#   'sama',
#   'juga',
#   'bermain',
#   '2',
#   'kaki,',
#   'pak',
#   'andi.'],
#  ['dulu',
#   'mencari',
#   'makan',
#   'setelah',
#   'menjabat',
#   'jadi',
#   'kaya2',
#   'bahkan',
#   'daging',
#   'juga',
#   'di',
#   'empat',
#   'penjara',
#   'dan',
#   'akhirnya',
#   'neraka'],
#  ['nah', 'lu....', 'kena', 'deh'],
#  ['kardus', 'kardus', 'kardus.........mana', 'bagian', 'kardusku............'],
#  ['politik', 'cari', 'makan', 'alias', 'parpol', 'kardus.'],
#  ['dia', 'minta', 'isi', 'kardus', 'tu'],
#  ['badut',
#   'badut',
#   'politik...kerja',
#   'nolll',
#   'buat',
#   'rakyat...nyir',
#   'nyir',
#   'bocor',
#   'coorrrrrrr'],
#  ['%u2063jokowi',
#   'menang',
#   'mudah',
#   'di',
#   'pilpres',
#   '2019,',
#   'democraaat',
#   'nyungsep'],
#  ['jokowi',
#   'menang',
#   'mudah',
#   'di',
#   'pilpres',
#   '2019,',
#   'democraaat',
#   'nyungsep'],
#  ['lebih', 'bagus', 'cap', 'kaki', 'tiga..bisa', 'buat', 'kesehatan'],
#  ['kaki', 'empat..%ud83d%ude07'],
#  ['salam', 'dua', 'kaki', 'euy...hahaha'],
#  ['pak',
#   'sby',
#   'itu',
#   'kalau',
#   'ngomong',
#   'selalu',
#   'pinjam',
#   'banyak',
#   'moncong',
#   'mas.',
#   'kayak',
#   'ban,',
#   'bocor',
#   'alus',
#   'tapi',
#   'keliling%ud83d%ude03.',
#   'baru',
#   'lahir',
#   'ya?'],
#  ['kl',
#   'sudah',
#   'berdasarkan',
#   'data',
#   'dan',
#   'fakta',
#   'ya',
#   'susah',
#   'untuk',
#   'dijawab..',
#   'hahahaha'],
#  ['setdeh,',
#   'kho',
#   'seneng',
#   'banget�',
#   'ribut',
#   'sich,',
#   'rebutan',
#   'apa',
#   'lagi',
#   'nech,',
#   '....eng..ing..eng',
#   '..datang',
#   'zonk',
#   'ah',
#   'nggak',
#   'papa',
#   'masih',
#   'solid',
#   'kho,',
#   'itu',
#   'hanya',
#   'dinamika',
#   'politik...capek',
#   'dech.'],
#  ['sesama', 'begundal', 'politik', 'dilarang', 'saling', 'mendahului', '...'],
#  ['karena',
#   'aa',
#   'pakai',
#   'data',
#   'dan',
#   'fakta.',
#   'maka',
#   'tidak',
#   'bisa',
#   'berbalas',
#   'pantun.'],
#  ['pan', '-', 'pks', 'sebaiknya', 'diam', 'klo', 'ga', 'punya', 'kaca.�'],
#  ['koalisi',
#   'aja',
#   'ribut.',
#   'gimana',
#   'mau',
#   'menang.',
#   'jargon',
#   'doang',
#   'kenceng',
#   'kualitas',
#   'nol'],
#  ['mari',
#   'kita',
#   'bertepuk',
#   'tangan...sesama',
#   'begundal',
#   'sdh',
#   'mulai',
#   'ribut....'],
#  ['kayaknya',
#   'bener',
#   'juga,�',
#   'dulu',
#   'kan',
#   'koalisi',
#   'demokrat',
#   'tp',
#   'sering',
#   'gak',
#   'nurut'],
#  ['diam', 'itu', 'emas'],
#  ['lah',
#   'ngapain',
#   'jg',
#   'ribut2',
#   'politik.',
#   'pilkada',
#   'kemaren',
#   'jg',
#   'banyak',
#   'koalisi',
#   'ngacak.',
#   'politik',
#   'disini',
#   'ya',
#   'gt,',
#   'cari',
#   'sensasi',
#   'doang.'],
#  ['bukan',
#   '2',
#   'kaki',
#   'itu',
#   'mah',
#   'yg',
#   'kita',
#   'tahu',
#   '..',
#   'tapi',
#   '4',
#   'kaki',
#   '..',
#   '2',
#   'kaki',
#   'yg',
#   'sah',
#   ',',
#   '2',
#   'kaki',
#   'yg',
#   'siri',
#   '..kan',
#   '??'],
#  ['main',
#   'dua',
#   'kaki',
#   'saat',
#   'pemilu',
#   'sudah',
#   'usai.�',
#   'bargain',
#   'dan',
#   'kompromi.',
#   'lah',
#   'ini',
#   'baru',
#   'mau',
#   'mulai.',
#   'haha',
#   'cerdas',
#   'dong',
#   'kamu',
#   'dek�'],
#  ['pd,',
#   'pan,',
#   'pks',
#   'semua',
#   'ahli',
#   'main',
#   '2',
#   'kaki,',
#   'cuman',
#   'gerindra',
#   'yg',
#   'ga',
#   'punya',
#   'kaki'],
#  ['andi', 'arief,', 'dicari', 'bawaslu', 'tuh.'],
#  ['abis',
#   'mau',
#   'bagemana',
#   'lagi',
#   'ga',
#   'mau',
#   'rugi,',
#   'maunya',
#   'untung',
#   'terus'],
#  ['bertiga', 'saling', 'selingkuh'],
#  ['andi',
#   'arief',
#   'ini',
#   'awalnya',
#   'mencak2',
#   'teriak2',
#   'terkait',
#   'dana',
#   'logistik',
#   '500m',
#   'untuk',
#   'kubu',
#   'koalisi',
#   'prabowo,',
#   'karena',
#   'demokrat',
#   'tdk',
#   'di',
#   'ajak',
#   'bicara,',
#   'sekarang',
#   'diem',
#   'dia',
#   'di',
#   'amankan',
#   'oleh',
#   'sandi,',
#   'wajar',
#   'andi',
#   'arief',
#   'ini',
#   'ngebela',
#   'demokrat',
#   'dan',
#   'sby'],
#  ['tepatnya', 'pan', 'dan', 'pks', 'tergantung', 'bayaran................'],
#  ['satu',
#   'koalisi',
#   'aja',
#   'udah',
#   'gak',
#   'kompak',
#   'gmn',
#   'mau',
#   'menang,',
#   'udah',
#   'pd',
#   'jgn',
#   'ribut',
#   'nikmatin',
#   'aja',
#   'dl',
#   'kardus2nya....',
#   'mudah2',
#   'anjlog',
#   '/hancura',
#   'suara',
#   'kalian',
#   'di',
#   'pemilu',
#   '2019'],
#  ['salut',
#   'buat',
#   'timses',
#   'padi,',
#   'dinamika',
#   'adalah',
#   'keharusan',
#   'dlm',
#   'sebuah',
#   'perjuangan',
#   'politik,',
#   'ada',
#   'perbedaan',
#   'pendapat,',
#   'kritik',
#   'juga',
#   'wajar2',
#   'saja,',
#   'solid',
#   'gak',
#   'perlu',
#   'harus',
#   'yes',
#   'semua,',
#   'diam',
#   'seribu',
#   'bahasa',
#   'spt',
#   'dikekang',
#   '&',
#   'satu',
#   'suara',
#   'seperti',
#   'koalisi',
#   'jokowi,',
#   'yg',
#   'ujung2nya',
#   'melampiaskan',
#   'uneg2',
#   'dgn',
#   'menyerang',
#   'koalisi',
#   'lawan...berbeda',
#   'suara',
#   'bukan',
#   'masalah,',
#   'tapi',
#   'saling',
#   'menghargai',
#   'harus',
#   'dijaga',
#   '&',
#   'dekati',
#   'terus',
#   'rakyat',
#   'krn',
#   'rakyatlah',
#   'yg',
#   'menentukan',
#   'kemenangan',
#   'di',
#   'pilpres',
#   'nanti'],
#  ['hajar......'],
#  ['percaya',
#   'deh,,klo',
#   'jokowi',
#   'menang',
#   'lg,,pan',
#   'akan',
#   'merapat',
#   'ke',
#   'jokowi',
#   'lg',
#   'supaya',
#   'dpt',
#   'mentri',
#   'lg,,kan',
#   'kmpren',
#   'brgitu'],
#  ['pd',
#   'maen',
#   'dua',
#   'kaki',
#   'di',
#   'parlemen',
#   'seabis',
#   'pilpres,',
#   'katenye',
#   'netral',
#   'tapi',
#   'condong',
#   'ke',
#   'kmp'],
#  ['kelompok', 'sebelah', 'pemain', '2', 'kaki', 'semua.', 'wkwkwkwk'],
#  ['andi', 'arif', 'buang', 'aja', 'bikin', 'rusuh', 'aja'],
#  ['ayo', 'bertengkar', 'lah', 'aku', 'suka', 'hahaha'],
#  ['andi', 'arif', 'knp', 'ya..m'],
#  ['jadi', 'penonton', 'ah...', 'menghibur..�'],
#  ['ular',
#   'beludak',
#   'ini',
#   'keluar',
#   'lagi,',
#   'setelah',
#   'mumpet',
#   'terkencing2',
#   'tdk',
#   'berani',
#   'bicara',
#   'di',
#   'dpn',
#   'bawaslu.',
#   '%ud83d%ude03'],
#  ['sudah',
#   'tahu',
#   'bahwa....',
#   'kalau',
#   'berkata',
#   'bohong',
#   '..',
#   'tidak',
#   'sesuai',
#   'omongan..',
#   'kalau',
#   'janji',
#   'ingkar',
#   '..',
#   'plinplan...',
#   'kalau',
#   'dipercaya',
#   'ingkar....',
#   'tidak',
#   'konsisten....',
#   'tahu',
#   'munafik',
#   'kok',
#   'seteju..',
#   'yg',
#   'waras',
#   'siapa',
#   'ya..'],
#  ['"%u2063.......pertempuran',
#   'utama',
#   'di',
#   'pilpres',
#   '2019',
#   'ialah',
#   'jawa',
#   'barat,',
#   'jawa',
#   'tengah,',
#   'jawa',
#   'timur,',
#   'sumatera',
#   'utara',
#   'dan',
#   'sulawesi',
#   'selatan".',
#   'jawa',
#   'tengah',
#   'jelas',
#   'sudah',
#   'dijaga',
#   'ganjar,',
#   'jawa',
#   'timur',
#   'ada',
#   'mbak',
#   'khofifah,',
#   'jawa',
#   'barat',
#   'kemungkinan',
#   'dengan',
#   'naiknya',
#   'rk,',
#   'jokowi',
#   'bakal',
#   'menang,',
#   'sulawesi',
#   'selatan,',
#   'pasti',
#   'ada',
#   'efek',
#   'dari',
#   'jk',
#   'sebagai',
#   'timses',
#   'jokowi,',
#   'hanya',
#   'sumatera',
#   'utara',
#   'yang',
#   'masih',
#   'bisa',
#   'diperebutkan',
#   'oleh',
#   'kedua',
#   'koalisi'],
#  ['aduh....orang',
#   '-',
#   'orang',
#   'jangan',
#   'di',
#   'pilih',
#   'biar',
#   'negiri',
#   'ini',
#   'tidak',
#   'segera',
#   'bubar.'],
#  ['belah', 'sono', 'ribut', 'terus', 'y'],
#  ['mungkin', 'sedang', 'panas', 'dalam', '(nambah', 'satu', 'kaki', 'lagi)'],
#  ['kalo',
#   'pks',
#   'mah',
#   'emang',
#   'ga',
#   'ada',
#   'malunya.',
#   'ikut',
#   'kabinet',
#   'sby,',
#   'tapi',
#   'ngacak2',
#   'program',
#   'sby...presiennya',
#   'aja',
#   'sampe',
#   'makan',
#   'aspal',
#   'di',
#   'jalan',
#   'nangka',
#   'noh....'],
#  ['ada', 'hubungannya', 'dengan', 'kardus', 'ga', 'nih', '???'],
#  ['maling',
#   'teriak',
#   'maling,',
#   'koalisi',
#   'kok',
#   'saling',
#   'menjelekkan',
#   '%ud83d%ude02'],
#  ['bagus', 'bro...', 'hajar', 'terussss', '!'],
#  ['apa',
#   'yang',
#   'diungkapkan',
#   'bung',
#   'andi',
#   'arif',
#   'benar',
#   'sekali,',
#   'kita',
#   'masih',
#   'ingat',
#   'waktu�',
#   'pks',
#   'ikut',
#   'dalam',
#   'kabinet',
#   'pak',
#   'sby,',
#   'tapi',
#   'apabila',
#   'ada',
#   'kebijakan',
#   'dari',
#   'sby',
#   'selalu',
#   'ditentang'],
#  ['ni',
#   'orang',
#   'dri',
#   'awal',
#   'udh',
#   'mulai',
#   'ribet',
#   'sebaik',
#   'nya',
#   'klo',
#   'memang',
#   'gk',
#   'searah',
#   'pecat',
#   'ni',
#   'pa',
#   'sby..�'],
#  ['pd',
#   'bubar',
#   'ajalah....',
#   'uda',
#   'gak',
#   'ada',
#   'wibawa',
#   'di',
#   'mata',
#   'kadernya.',
#   'apa',
#   'karena',
#   'ketumnya',
#   'gak',
#   'tegas?',
#   'atau',
#   'mgkn',
#   'hal',
#   'yg',
#   'sengaja',
#   'dibuat',
#   'utk',
#   'main',
#   'dua',
#   'kaki',
#   'alias',
#   'mempraktekan',
#   'politik',
#   'bermuka',
#   'dua?�'],
#  ['lo',
#   'pade',
#   'ngomong',
#   'ngaler',
#   'ngidul',
#   'ga',
#   'jelas',
#   '...',
#   'bangsa',
#   'ini',
#   'banyak',
#   'masalah',
#   'perburuhan,',
#   'ekonomi,',
#   'problem',
#   'kebangsaan',
#   'benturan',
#   'umat',
#   'dll...',
#   'perlu',
#   'strong',
#   'leader',
#   '...',
#   'pas',
#   'ok',
#   '!!!'],
#  ['gawatttt...',
#   'harusnya',
#   'pak',
#   'prabowo',
#   'kirim',
#   'utusan',
#   'mautnya',
#   'kayak',
#   'ahmad',
#   'dhani,',
#   'neno,',
#   'sarumpaet',
#   'ke',
#   'papua',
#   'wkwkwk'],
#  ['kader2mya',
#   'pd',
#   'cerdas',
#   'juga,',
#   'ga',
#   'mau',
#   'dijadikan',
#   'boneka',
#   'gerindrong',
#   'cs'],
#  ['yang',
#   'jelas,',
#   'perolehan',
#   'suaran',
#   'jokowi',
#   '-',
#   "ma'ruf",
#   'amin',
#   'akan',
#   'bertambah.%ud83d%ude06'],
#  ['kira2',
#   'kalau',
#   'di',
#   'adu',
#   'dari',
#   'sisi',
#   'intelektual,',
#   'kecerdasan,',
#   'kesederhanaan,',
#   'kepemimpinan,',
#   'kekayaan',
#   'dari',
#   '4',
#   'kandidat',
#   'capres',
#   '-',
#   'cawapres',
#   'siapa',
#   'yg',
#   'menang',
#   'ya',
#   '...',
#   'gampang',
#   '...',
#   'sandi',
#   'yg',
#   'menang',
#   '...',
#   'muda,',
#   'kaya,',
#   'pinter,',
#   'cerdas,',
#   'sederhana,',
#   'dan',
#   'yg',
#   'paling',
#   'penting',
#   '...',
#   'setia',
#   'sama',
#   'istri',
#   'dan',
#   'sayang',
#   'anak',
#   '...',
#   'gila',
#   '...',
#   'perfect',
#   'banget',
#   'sih',
#   'lo',
#   'sandi',
#   '...',
#   'yg',
#   'lain',
#   'pada',
#   'main',
#   'bini',
#   'muda',
#   'sama',
#   'selingkuh',
#   '...',
#   'lo',
#   'yg',
#   'duitnya',
#   'banyak',
#   'kok',
#   'malah',
#   'setia',
#   '...',
#   'top'],
#  ['#2019jokowipresiden'],
#  ['bagi',
#   '90%',
#   'pengurus',
#   'dpd',
#   'demokrat',
#   'di',
#   'papua',
#   'ini,',
#   'hati',
#   'nurani',
#   'mereka',
#   'lebih',
#   'punya',
#   'integritas.',
#   'krn',
#   'mereka',
#   'tau',
#   'sesungguhnya',
#   'siapa',
#   'yg',
#   'selama',
#   'ini',
#   'bekerja',
#   'utk',
#   'warganya.'],
#  ['rakyat',
#   'papua',
#   'tau',
#   'mana',
#   'presiden',
#   'yang',
#   'perhatian',
#   'dengan',
#   'papua,',
#   'mana',
#   'yang',
#   'pura-pura',
#   'perhatian.',
#   'btw',
#   'balikin',
#   'kardusnya',
#   'sandi.'],
#  ['jati',
#   'diri',
#   'gak',
#   'pentinglah',
#   'yah.......yg',
#   'penting',
#   'menang......klik',
#   'google',
#   'hambalang....'],
#  ['emang',
#   'jokowi',
#   'masih',
#   'diinginkan',
#   'sebagian',
#   'besar',
#   'rakyat',
#   'untuk',
#   'menjadi',
#   'presiden',
#   '2',
#   'periode',
#   'kok'],
#  ['masalah',
#   'papua',
#   'itu',
#   'sangat',
#   'gampang',
#   'dan',
#   'malah',
#   'terlalu',
#   'gampang',
#   'merebut',
#   'suara',
#   'orang',
#   'papua',
#   'sbb',
#   'orang',
#   'papua',
#   'gak',
#   'denger',
#   'gubernur',
#   'asal',
#   'di',
#   'serahkan',
#   'sama',
#   'yg',
#   'ahli',
#   'nya',
#   'di',
#   'jamin',
#   '100%',
#   'beres....yg',
#   'jelas',
#   'bkn',
#   'masalah',
#   'infra',
#   'struktur',
#   'sbb',
#   'yg',
#   'menikmati',
#   'nya',
#   'tetap',
#   'pendatang',
#   'sdgkn',
#   'orang',
#   'asli',
#   'papua',
#   'ttp',
#   'jd',
#   'penonton....serahkan',
#   'pada',
#   'ahli',
#   'nya',
#   'papua',
#   'pasti',
#   'prabowo',
#   '-sandi...'],
#  ['demokrat',
#   'seharusnya',
#   'join',
#   'dengan',
#   'jokowi',
#   'saja,',
#   'tim',
#   'prabowo',
#   '-sandi',
#   'ga',
#   'butuh',
#   'demokrat',
#   'cukup',
#   'masyarakat-emak2-gerindra-pks-pan',
#   'saja',
#   'sudah',
#   'pasti',
#   'menang',
#   'di',
#   '2019'],
#  ['woi',
#   'kembalikan',
#   'kardusnya',
#   'kalo',
#   'ga',
#   '100%',
#   'dukung',
#   'wowo....wkwkwk....'],
#  ['alhamdulillah', 'amin'],
#  ['sebaiknya',
#   'demokrat',
#   'ke',
#   'jokowi',
#   'saja,',
#   'tdk',
#   'apa',
#   'apa,',
#   'pks',
#   'pan',
#   'gerindra',
#   'sangat',
#   'solid'],
#  ['harusx',
#   'dpd',
#   'tdk',
#   'bisa',
#   'mengatur',
#   'dpp,kepututsan',
#   'dpp',
#   'harusx',
#   'satu',
#   'komando,miris',
#   'jg',
#   'ini'],
#  ['demokrat', 'plin', 'plan....'],
#  ['karna',
#   'tdk',
#   'terbendung,',
#   'suara',
#   'kader',
#   'yg',
#   'terbelah',
#   'berobah',
#   'strategi',
#   'demi',
#   'menutup',
#   'muka',
#   'yg',
#   'sudah',
#   'malu...kasihan',
#   'demokrat'],
#  ['100%', 'pak....soalnya', 'joko', 'wi', 'orang', 'baik', '.....'],
#  ['rakyat',
#   'papua',
#   'merasakan',
#   'langsung',
#   'pembangunan',
#   'era',
#   'presiden',
#   'jokowi.�'],
#  ['hasil', 'akhirnya', 'dan', 'saya', 'yakin', 'jokowi', 'kalah', 'dipapua.'],
#  ['bagus,',
#   'jangan',
#   'ikut',
#   'orang',
#   'jahat.',
#   'saudara2',
#   'papua',
#   'merasakan',
#   'pembangunan.'],
#  ['apa', 'kata?', 'gerinda', 'cs', 'ya?', 'hayo', 'apa?'],
#  ['karena', 'papu', 'maju'],
#  ['mbah', 'mien', 'langsung', 'kejang-kejang....'],
#  ['mereka',
#   'ini',
#   'yg',
#   'bener2',
#   'sdh',
#   'merasakan',
#   'langsung',
#   'dampak',
#   'pembangunan',
#   'jalan',
#   'dan',
#   'sebagainya',
#   'di',
#   'sana.',
#   'tidak',
#   'bisa',
#   'ditutupi',
#   'dan',
#   'disangkal',
#   'lagi.'],
#  ...]

# %%
#Filter dari tanda baca
import string
for i in range(0, len(tok_comments)):
    comment = tok_comments[i]
    for j in range(0, len(comment)):
        sub_comment = tok_comments[i][j]
        for k in sub_comment:
            if k in string.punctuation:
                tok_comments[i][j] = tok_comments[i][j].replace(k, "")

# %%
tok_comments
# Out:
# [['wkwkwk',
#   'gak',
#   'sekalian',
#   'pak',
#   'selawat',
#   'ke',
#   'dpr',
#   'kan',
#   'banyak',
#   'koruptor',
#   'disana'],
#  ['mantab',
#   'ini',
#   'br',
#   'dakwah',
#   'yg',
#   'sejati',
#   'kl',
#   'd',
#   'tempat',
#   'umum',
#   'mah',
#   'dh',
#   'biasa',
#   '',
#   'ini',
#   'luar',
#   'biasa�'],
#  ['salut', 'buat', 'gus', 'miftah'],
#  ['yg',
#   'nyinyir',
#   'gak',
#   'pernah',
#   'lihat',
#   'dan',
#   'baca',
#   'atw',
#   'mengetahui',
#   'sejarah',
#   'dakwah',
#   'walisongo',
#   '',
#   'sunan',
#   'kali',
#   'jagasmua',
#   'ada',
#   'cara',
#   'demi',
#   'kebaikan',
#   'asal',
#   'jng',
#   'ajk',
#   'dg',
#   'cara',
#   'berjinah',
#   '',
#   'lakukan',
#   'dg',
#   'porsi',
#   'dan',
#   'sikon',
#   'yg',
#   'tepat'],
#  ['ada',
#   'adabnya',
#   'sholawat',
#   'lebih',
#   'baik',
#   'ajak',
#   'ke',
#   'majelis',
#   'ilmu'],
#  ['setiap',
#   'ulama',
#   'punya',
#   'jalan',
#   'dan',
#   'cara',
#   'dakwah',
#   'masing2',
#   'jika',
#   'kamu',
#   'melihat',
#   'kemunkaran',
#   'lawan',
#   'dengan',
#   'tanganmukekuatanmu',
#   'jika',
#   'tidak',
#   'mampu',
#   'lawan',
#   'dengan',
#   'mulutmu',
#   'jika',
#   'tidak',
#   'mampu',
#   'juga',
#   'dengan',
#   'hatimu',
#   'itulah',
#   'selemah',
#   'lemahnya',
#   'iman',
#   'itu',
#   'sudah',
#   'menjadi',
#   'kewajiban',
#   'para',
#   'ulama',
#   'kalo',
#   'yg',
#   'komen',
#   'masih',
#   'ada',
#   'yg',
#   'nyinyirin',
#   'ulama',
#   'berarti',
#   'otaknya',
#   'sudah',
#   'disisipin',
#   'politik'],
#  ['umpanin', 'nocannya', 'yak'],
#  ['itulah', 'ceramah', 'yg', 'sebenarnya'],
#  ['besok', 'bugil', 'aja', 'selawat'],
#  ['bedanya',
#   'gus',
#   'miftah',
#   'dengan',
#   'fpi',
#   '',
#   'hti',
#   'bagaikan',
#   'surga',
#   'dan',
#   'neraka',
#   'di',
#   'surga',
#   'penuh',
#   'kasih',
#   'di',
#   'neraka',
#   'penuh',
#   'penghancuran'],
#  ['knp',
#   'di',
#   'tempat',
#   'kerjanya',
#   'mending',
#   'diundang',
#   'ke',
#   'masjid',
#   'ponpes',
#   'aula',
#   'supaya',
#   'berbusana',
#   'yg',
#   'sopan�'],
#  ['nah',
#   'ini',
#   'ulama',
#   'beneranditerima',
#   'di',
#   'semua',
#   'kalangankl',
#   'uas',
#   'malah',
#   'diblokir',
#   'sana',
#   'sini'],
#  ['kerennn',
#   'saya',
#   'pernah',
#   'dpt',
#   'info',
#   'seperti',
#   'ini',
#   'dr',
#   'keyakinan',
#   'yg',
#   'lain',
#   'tapi',
#   'tujuan',
#   'utama',
#   'kurang',
#   'lebih',
#   'sama',
#   'lah',
#   'kita',
#   'ambil',
#   'sisi',
#   'positifnya',
#   'ajah',
#   'terimakasih',
#   'atas',
#   'niat',
#   'baiknya',
#   'saya',
#   'yakin',
#   'pasti',
#   'bermanfaat'],
#  ['hebat',
#   'guslanjutkaninilah',
#   'makna',
#   'dakwah',
#   'sebenarnya',
#   'sampaikan',
#   'marwah',
#   'islam',
#   'dengan',
#   'penuh',
#   'kedamaian',
#   'dan',
#   'berikan',
#   'pemahaman',
#   'bukan',
#   'dengan',
#   'kebencian',
#   'dan',
#   'pemaksaan'],
#  ['diskotik', 'syariah', 'jadunya', 'nih', 'wkwkwkmantap'],
#  ['niat',
#   'dan',
#   'tujuan',
#   'yg',
#   'baik',
#   'pasti',
#   'mendapat',
#   'berkah',
#   'dr',
#   'allah',
#   'swt'],
#  ['mantaaappppbuat', 'di', 'gedung', 'dpr', 'perlu', 'jg', 'kayanya', 'gus'],
#  ['salut', 'buat', 'owner', 'klub', 'ini'],
#  ['josshhh', 'ini', 'baru', 'luar', 'biasa'],
#  ['dapat', 'gratisan', 'karena', 'sudah', 'punya', 'nope'],
#  ['sebaiknya',
#   'dimanapun',
#   'dilakukan',
#   'batas2',
#   'kesopanan',
#   'tetap',
#   'harus',
#   'dijaga'],
#  ['pemandu',
#   'lagi',
#   'yang',
#   'di',
#   'manga',
#   'besar',
#   'keknya',
#   'perlu',
#   'juga',
#   'diajak',
#   'mengaji',
#   'bos'],
#  ['jujur',
#   'ini',
#   'kereennnnnnn',
#   'cara',
#   'menyebarkan',
#   'agama',
#   'yang',
#   'baik',
#   'dan',
#   'snagat',
#   'simpatik',
#   'semoga',
#   'sukses'],
#  ['katimbang',
#   'alim',
#   'kemudian',
#   'jadi',
#   'maling',
#   'menurut',
#   'saya',
#   'lebih',
#   'baik',
#   'maling',
#   'kemudian',
#   'jadi',
#   'alim',
#   ''],
#  ['sebenar',
#   'ulama',
#   'mengajak',
#   'mereka',
#   'yg',
#   'masih',
#   'tersesat',
#   'untuk',
#   'kembali',
#   'bukan',
#   'menjelekkan',
#   'orang',
#   'lain',
#   'tp',
#   'merangkul',
#   'mereka�'],
#  ['ini', 'namanya', 'apa', 'ya'],
#  ['selamat',
#   'berjuang',
#   'gusjustru',
#   'tempat',
#   'seperti',
#   'itu',
#   'yg',
#   'butuh',
#   'lebih',
#   'bnyk',
#   'perhatian',
#   'dr',
#   'ulama'],
#  ['semoga', 'diberikan', 'hidayah'],
#  ['hati',
#   'hati',
#   'memviralkan',
#   'berita',
#   'yang',
#   'mengandung',
#   'isu',
#   'agama',
#   'bisa',
#   'menjadi',
#   'sumber',
#   'fitnah',
#   'dan',
#   'lahan',
#   'para',
#   'bedebah',
#   'yang',
#   'kerjanya',
#   'mengadu',
#   'domba',
#   'anak',
#   'bangsa',
#   'dan',
#   'rakyat',
#   'indonesia',
#   'ahok',
#   'sudah',
#   'jadi',
#   'korbannya'],
#  ['subhanallah',
#   'semoga',
#   'mendapatkan',
#   'hidayah',
#   'dari',
#   'allah',
#   'swt',
#   'amin'],
#  ['ulama', 'ngurus', 'umat', 'berarti', 'jenengan', 'gus'],
#  ['luar',
#   'biasa',
#   'salutterharu',
#   'mengajak',
#   'orang',
#   'lain',
#   'yang',
#   'dianggap',
#   'salah',
#   'dengan',
#   'cara',
#   'yang',
#   'baik',
#   'bukan',
#   'dengan',
#   'cacianluar',
#   'biasa'],
#  ['whats', 'up', 'boshe'],
#  ['lol',
#   'jadi',
#   'ketahuan',
#   'dong',
#   'isinya',
#   'boshe',
#   'bali',
#   'bukan',
#   'org',
#   'bali',
#   'ud83dude02ud83dude02'],
#  ['poligami', 'aja', 'guss'],
#  ['harusnya', 'dibakar', 'tempat', 'begituan', 'kalik'],
#  ['hahahaha',
#   'bahasa',
#   'hastag',
#   'y',
#   'kalo',
#   'd',
#   'plesetkan',
#   'jadi',
#   'y',
#   'santri',
#   'gaul',
#   'itu',
#   'yg',
#   'suka',
#   'sholawat',
#   'dan',
#   'suka',
#   'dugem',
#   'hahahaha',
#   'rusak',
#   'islam',
#   'd',
#   'biaskan',
#   'seperti',
#   'ini',
#   'ustad',
#   'y',
#   'dateng',
#   'k',
#   'sono',
#   'dugem',
#   'dulu',
#   'lalu',
#   'sholawat',
#   'lalu',
#   'dugem',
#   'lagi',
#   'dan',
#   'd',
#   'sebut',
#   'santri',
#   'gaul'],
#  ['knp',
#   'yg',
#   'kayak',
#   'gini',
#   'berita',
#   'nya',
#   'keluar',
#   'nya',
#   'pas',
#   'mau',
#   'pilpres',
#   'aja',
#   'ya'],
#  ['naaaah',
#   'ini',
#   'baru',
#   'bener',
#   'ceramah',
#   'atau',
#   'ngajak',
#   'orang',
#   'yg',
#   'belum',
#   'bersholawat',
#   'utk',
#   'bersholawat',
#   'ga',
#   'kaya',
#   'somat',
#   'ngajak',
#   'orang',
#   'sholawat',
#   'koq',
#   'ke',
#   'orang',
#   'yg',
#   'udah',
#   'bersholawat',
#   'maaaaat',
#   'mat'],
#  ['gila',
#   'nekat',
#   'juga',
#   'ulamanya',
#   'gak',
#   'tau',
#   'di',
#   'usir',
#   'gitu',
#   'tapi',
#   'bagus',
#   'lah',
#   'ada',
#   'keberanian',
#   'dan',
#   'semuanya',
#   'jg',
#   'mendengarkan',
#   'semoga',
#   'banyak',
#   'ustad',
#   'lainnya',
#   'yang',
#   'meniru',
#   'hal',
#   'ini'],
#  ['tambah',
#   'tempat',
#   'mantap',
#   'sak',
#   'cewek',
#   'seksi',
#   'nyadan',
#   'yg',
#   'paling',
#   'penting',
#   'bole',
#   'yg',
#   'g',
#   'setuju',
#   'pasti',
#   'ngiriweek'],
#  ['mengajak',
#   'orang',
#   'melakukan',
#   'sholawat',
#   'di',
#   'tempat',
#   'ibadah',
#   'ya',
#   'sudah',
#   'pasti',
#   'mudah',
#   'tapi',
#   'mengajak',
#   'orang',
#   'melakukan',
#   'sholawat',
#   'di',
#   'tempat',
#   'dugem',
#   'yang',
#   'penuh',
#   'cobaan',
#   'itu',
#   'sudah',
#   'jelas',
#   'pahala',
#   'nya',
#   'jauh',
#   'lebih',
#   'besar'],
#  ['apa',
#   'sih',
#   'yg',
#   'nggak',
#   'bisa',
#   'di',
#   'negeri',
#   'ini',
#   'semua',
#   'pada',
#   'bisa',
#   'sekrang'],
#  ['boleh', 'ya', 'menyebarkan', 'agama', 'seperti', 'ini�'],
#  ['hahahaha', '�lucu', 'lucuan', 'biar', 'masuk', 'tipi', 'laah', 'hahaha'],
#  ['coba',
#   'lah',
#   'ustad',
#   'yg',
#   'lain',
#   'dakwah',
#   'di',
#   'nite',
#   'club',
#   'spt',
#   'iti'],
#  ['yang',
#   'ini',
#   'malah',
#   'di',
#   'dukung',
#   'yang',
#   'di',
#   'sana',
#   'di',
#   'jagain',
#   'supaya',
#   'ga',
#   'ceramah',
#   'apalagi',
#   'ini'],
#  ['ah',
#   'entahlah',
#   'satu',
#   'kau',
#   'maklumi',
#   'yg',
#   'lain',
#   'mengikuti',
#   'tinggal',
#   'tunggu',
#   'saja'],
#  ['mau', 'ngikik', 'takut', 'dosa'],
#  ['kalau',
#   'mau',
#   'melakukan',
#   'ibadah',
#   'perbaiki',
#   'dulu',
#   'penampilan',
#   'jauhi',
#   'miras',
#   'cari',
#   'tempat',
#   'yg',
#   'lebih',
#   'baik',
#   'lebih',
#   'baik',
#   'gus',
#   'kamu',
#   'mengajak',
#   'para',
#   'wanita',
#   'itu',
#   'menutupi',
#   'auratnya'],
#  ['lokalisasi', 'harapan', 'sadar'],
#  ['setelah', 'selawat', 'selesai', 'acara', 'selanjutnya', ''],
#  ['bagus', 'lanjutkan�'],
#  ['bagus',
#   'itu',
#   'biar',
#   'sadar',
#   'islam',
#   'tdk',
#   'mengajari',
#   'kaumnya',
#   'buka',
#   'aurat',
#   'bagus',
#   'lanjut'],
#  ['banser', 'anshor', 'mana', 'suaranyaormas', 'liberal'],
#  ['pans',
#   'itu',
#   'ketika',
#   'simbah',
#   'yg',
#   'bicara',
#   'selalu',
#   'dibully',
#   'karena',
#   'kata',
#   'katanya',
#   'terkesan',
#   'emosional',
#   'nantang',
#   'nantang',
#   'pdhl',
#   'ketika',
#   'tantangan',
#   'bisa',
#   'di',
#   'buktikan',
#   'oleh',
#   'yg',
#   'di',
#   'tantang',
#   'trus',
#   'diem',
#   'tdk',
#   'ksatria',
#   'ngakui',
#   'dan',
#   'sering',
#   'menjelek',
#   'jelekkan',
#   'orang',
#   'lain',
#   'inilah',
#   'yg',
#   'jd',
#   'penyebab',
#   'sering',
#   'di',
#   'bully',
#   'dan',
#   'orang',
#   'lain',
#   'jd',
#   'gak',
#   'simpati',
#   'mungkin',
#   'dia',
#   'dengan',
#   'berkata',
#   'seperti',
#   'itu',
#   'merasa',
#   'hebat',
#   'dia',
#   'tdk',
#   'sadar',
#   'saat',
#   'nyapres',
#   'pun',
#   'rontok',
#   'saat',
#   'thn',
#   '2014',
#   'pun',
#   'keok',
#   'artinya',
#   'rakyat',
#   'g',
#   'percayaseolah',
#   'bicara',
#   'dulu',
#   'urusan',
#   'belakang',
#   'spt',
#   'janji',
#   'jalan',
#   'kaki',
#   'jogja',
#   'jakarta',
#   '',
#   'terbukti',
#   'gak',
#   'kan',
#   'ini',
#   'mungkin',
#   'hal',
#   'sepele',
#   'bagi',
#   'dia',
#   'tapi',
#   'itu',
#   'tertanam',
#   'di',
#   'ingatan',
#   'oranghingga',
#   'berkesimpulan',
#   'klo',
#   'hanya',
#   'bisa',
#   'ngomong',
#   'tok',
#   'nglakoni',
#   'ora',
#   'iso'],
#  ['karena', 'mendukung', 'jokowi', 'jadi', 'tidak', 'dicopot'],
#  ['banyak', 'orang', 'pekalongan', 'yg', 'kemakan', 'hoax'],
#  ['pan',
#   'ancur',
#   'lebur',
#   'gara2',
#   'si',
#   'amien',
#   'rasis',
#   '',
#   'makasih',
#   'amien',
#   '',
#   'lanjutkan',
#   '',
#   '2019panbakalgurem',
#   ''],
#  ['padahal',
#   'sutrisno',
#   'bakhir',
#   'ini',
#   'dulunya',
#   'merupakan',
#   'penyandang',
#   'dana',
#   'pak',
#   'amin',
#   'rais',
#   'saat',
#   'awal',
#   'reformasi',
#   'akhirnya',
#   'berjalan',
#   'sendiri2�'],
#  ['orang',
#   'bener',
#   'malah',
#   'tidak',
#   'dipake',
#   'di',
#   'pansutrisno',
#   'itu',
#   'sdh',
#   'habis2an',
#   'demi',
#   'pan',
#   'tapi',
#   'tetap',
#   'tdk',
#   'berdaya',
#   'melawan',
#   'amien',
#   'raispan',
#   'cahayanya',
#   'semakin',
#   'tidak',
#   'bersinar',
#   'sejak',
#   'amien',
#   'makin',
#   'kumat'],
#  ['lagu', 'lama'],
#  ['pan', 'sekarang', 'butek', 'karena', 'diobok2', 'si', 'amien'],
#  ['karena', 'mendukung', 'jadi', 'tdk', 'dicopot'],
#  ['masak',
#   'sih',
#   'dari',
#   'beberapa',
#   'ex',
#   'pemimpin',
#   'pan',
#   'yg',
#   'punya',
#   'pikiran',
#   'sehat',
#   'cuma',
#   'pak',
#   'sutrisno�'],
#  ['tolong',
#   'dikoreksi',
#   'untuk',
#   'jabatan',
#   'pak',
#   'pramono',
#   'itu',
#   'menseskab',
#   'bukan',
#   'mensesneg',
#   'terima',
#   'kasih�'],
#  ['mantap',
#   'bukti',
#   'orang',
#   'baik',
#   'pasti',
#   'banyak',
#   'yg',
#   'mendukung',
#   'salam',
#   '2',
#   'periode'],
#  ['ksih', 'mkan', 'buaya', 'aja', 'org', 'kyak', 'gini'],
#  ['mantab',
#   'penyebar',
#   'fitnah',
#   'bisa',
#   'tidur',
#   'di',
#   'bui',
#   'jg',
#   'akhirnya'],
#  ['allahuakbar',
#   'alhamdulillah',
#   'akhirnya',
#   'para',
#   'ahlul',
#   'fitnah',
#   'penebar',
#   'kebencian',
#   'tersebut',
#   'dipenjara',
#   'juga',
#   'sudah',
#   'cukup',
#   'lama',
#   'mereka',
#   'menunggu',
#   'nikmatnya',
#   'lp',
#   'cipinang'],
#  ['selamat',
#   'menikmati',
#   'hukuman',
#   'dunia',
#   'atas',
#   'prilaku',
#   'fitnah',
#   'menebar',
#   'kebencian',
#   'hukuman',
#   'akhirat',
#   'yg',
#   'lebih',
#   'berat',
#   'menunggu',
#   'anda',
#   'para',
#   'ahlul',
#   'fitnah',
#   'penebar',
#   'kebencian'],
#  ['dasar',
#   'preman',
#   'ngak',
#   'tanggung',
#   'jawab',
#   'kok',
#   'malah',
#   'buron',
#   'katanya',
#   'lu',
#   'anak',
#   'buah',
#   'wowo',
#   'yg',
#   'bocor',
#   'bocor',
#   'itu',
#   'hehehhe'],
#  ['orang',
#   'grindong',
#   'gak',
#   'akan',
#   'ngomentari',
#   'brita',
#   'ini',
#   'krena',
#   'sebagian',
#   'tabir',
#   'obor',
#   'rakyat',
#   'sdh',
#   'dibuka',
#   'sebagian',
#   'oleh',
#   'rommy'],
#  ['ayo',
#   'gerombolannya',
#   'kok',
#   'nggak',
#   'ada',
#   'yang',
#   'komentar',
#   'nih',
#   'biasanya',
#   'koar2',
#   'bilang',
#   'pelanggaran',
#   'ham',
#   'seperti',
#   'menangkap',
#   'teroris',
#   'pakai',
#   'senjata',
#   'lengkap',
#   'dsb'],
#  ['sik',
#   'asik',
#   'selamat',
#   'menikmati',
#   'hotel',
#   'prodeo',
#   'kawan',
#   'siapa',
#   'menebar',
#   'angin',
#   'dia',
#   'menuai',
#   'badai'],
#  ['buni', 'yaniiii', 'dimana', 'anda', '', 'kejaaarr', ''],
#  ['wowo', 'ga', 'sekalian', ''],
#  ['jangan',
#   'tangkap',
#   'pimrednya',
#   'doank',
#   'tangkap',
#   'penyadang',
#   'dana',
#   'dan',
#   'hubungan',
#   'mereka',
#   'dgn',
#   'kandidat',
#   'capres',
#   'yg',
#   'diusung'],
#  ['walaupun',
#   'cuma',
#   '1',
#   'tahun',
#   'ente',
#   'sudah',
#   'dapat',
#   'gelar',
#   'mantan',
#   'narapidana',
#   'menjelang',
#   'pemilu',
#   'buat',
#   'lagi',
#   'biar',
#   'dikurung',
#   '10tahun',
#   'makan',
#   'gratis'],
#  ['gantung', 'az'],
#  ['sekalian', 'buni', 'yani', 'biar', 'adil', ''],
#  ['kirim', 'ke', 'kamar', 'bonita', '', 'bonita', 'itu', 'nama', 'macan'],
#  ['gua',
#   'paling',
#   'senang',
#   'liat',
#   'ginian',
#   'buronan',
#   'sensasinya',
#   'kayak',
#   'di',
#   'film2',
#   'hollywood'],
#  ['tungguin',
#   'aja',
#   'nih',
#   'bentar',
#   'lagi',
#   'kubu',
#   'prabocor',
#   'terutama',
#   'zonk',
#   'bakalan',
#   'komen',
#   'liat',
#   'aja'],
#  ['karena', 'kabur', 'tambahin', 'yah', 'hukuman', 'nya'],
#  ['ini', 'kabar', 'terbagus', 'yang', 'boleh', 'kudengar', 'hari', 'ini'],
#  ['telat', 'kabur', 'tongkaciann'],
#  ['nyari',
#   'duit',
#   'dr',
#   'nyebar',
#   'fitnahduitnya',
#   'buat',
#   'makan',
#   'anak',
#   'istrimau',
#   'jd',
#   'apa',
#   'anakmu',
#   'makan',
#   'duit',
#   'gituan'],
#  ['semoga', 'bahagia', 'di', 'rumah', 'yg', 'baru'],
#  ['periksa',
#   'bank',
#   'account',
#   'nya',
#   'atau',
#   'bank',
#   'account',
#   'keluarga',
#   'ada',
#   'transferan',
#   'nggak',
#   'dari',
#   'wowo'],
#  ['semoga',
#   'bisa',
#   'belajar',
#   'untuk',
#   'tdk',
#   'mencari',
#   'nafkah',
#   'dari',
#   'uang',
#   'hitam',
#   'dengan',
#   'cara',
#   'yang',
#   'hitam'],
#  ['suntik', 'mati'],
#  ['sikat',
#   'semua',
#   'org',
#   'org',
#   'pengacau',
#   'negeri',
#   'demi',
#   'uang',
#   'apalagi',
#   'mo',
#   'pilpres',
#   'malah',
#   'bikin',
#   'kacau',
#   'negara',
#   'klo',
#   'ga',
#   'segera',
#   'dikarungin'],
#  ['habisin',
#   'aja',
#   'jok',
#   'orang',
#   'yang',
#   'gangu',
#   'elu',
#   'jadi',
#   'presiden',
#   'lgi'],
#  ['nunggu',
#   'buni',
#   'yani',
#   'kapan',
#   'ditangkapnya',
#   'pdhl',
#   'sdh',
#   'ada',
#   'putusan',
#   'pengadilan',
#   'jg'],
#  ['koq', 'cuma', 'setahun', ''],
#  ['laaaahhh',
#   'bukannya',
#   'kata',
#   'nasbung',
#   'pemred',
#   'obor',
#   'rakyat',
#   'diangkat',
#   'jadi',
#   'prekom',
#   'bumnwelehwelehitu',
#   'fitnah',
#   'lagi',
#   'dong'],
#  ['kapan', 'buni', 'yani'],
#  ['sip',
#   'tinggal',
#   'yg',
#   'kabur',
#   'umroh',
#   'ga',
#   'balik2',
#   'segera',
#   'dieksekusi',
#   'pak',
#   'pol'],
#  ['yg',
#   'model',
#   'ginian',
#   'main',
#   'fitnah',
#   'sih',
#   'mesti',
#   'di',
#   'kandangin'],
#  ['mantap'],
#  ['sip'],
#  ['semoga', 'pas', 'di', 'dalam', 'penjarakedua2nya', 'gantung', 'diri'],
#  ['terbukti',
#   'memfitnah',
#   'bukan',
#   'menghina',
#   'dan',
#   'ingat',
#   'fitnah',
#   'lebih',
#   'kejam',
#   'dari',
#   'pembunuhan',
#   'bro'],
#  ['hukuman', 'mati'],
#  ['alhamdulillah', 'si', 'penebar', 'dosa', 'sudah', 'tertangkap'],
#  ['jokowi',
#   'sudah',
#   'memaafkan',
#   'tapi',
#   '',
#   'proses',
#   'hukum',
#   'tetap',
#   'berlaku',
#   'bos',
#   ''],
#  ['hmm'],
#  ['siap2', 'buat', 'gerombolan', 'micin', 'ama', 'nasi', 'bungkus'],
#  ['tambah', 'hukumannya', 'karena', 'mau', 'kabur'],
#  ['lho', 'kok', 'cuma', '1', 'tahun', '5', 'thn', 'pantas', 'kok'],
#  ['yg',
#   'menjamin',
#   'mau',
#   'mem',
#   'back',
#   'up',
#   'mereka',
#   'pada',
#   'kemana',
#   'mau',
#   'menemani',
#   'mereka',
#   'hidup',
#   'bersama',
#   'di',
#   'lp',
#   'cipinang',
#   'jangan',
#   'macem',
#   'ayam',
#   'sayur',
#   'lari',
#   'lintang',
#   'pukang',
#   'meninggalkan',
#   'kawan'],
#  ['gagah',
#   'saat',
#   'bikin',
#   'obor',
#   'rakyat',
#   'mewek',
#   'dan',
#   'buron',
#   'saat',
#   'diproses',
#   'hukum',
#   'dasar',
#   'preman',
#   'gembeng',
#   'kalau',
#   'begini',
#   'apakah',
#   'orang',
#   'yang',
#   'anda',
#   'junjung',
#   'akan',
#   'gantian',
#   'membela',
#   'anda'],
#  ['2019gantipresiden',
#   'kelihatan',
#   'bgt',
#   'tebang',
#   'pilihnya',
#   'hukum',
#   'tajam',
#   'ke',
#   'lawan',
#   'politik',
#   'tumpul',
#   'ke',
#   'cebong😏'],
#  ['orangnya',
#   'tambah',
#   'gemuk',
#   'makan',
#   'uang',
#   'sisa',
#   'anggaran',
#   'obor',
#   'rakyat'],
#  ['buset',
#   'dahjamintelnya',
#   'tetangga',
#   'sebelah',
#   'rumahnya',
#   'sendirimiris'],
#  ['bisa', 'jadi', '2019', 'muncul', 'petromak', 'rakyat', '😹😹'],
#  ['kalau',
#   'sudah',
#   'dieksekusi',
#   'ngga',
#   'lagi',
#   'dilindungi',
#   'kan',
#   'sama',
#   'janji',
#   'back',
#   'up',
#   'kalo',
#   'kena',
#   'masalah',
#   'hehehe',
#   'makan',
#   'tuh',
#   'janji',
#   'saat',
#   'kampanye'],
#  ['makan', 'pencarian', 'lu', 'tuhhhhh'],
#  ['selamat', 'ya'],
#  ['masih', 'mudabuaknnya', 'mendukung', 'presiden', 'generasi', 'mudapayah'],
#  ['yess',
#   'tidur',
#   'aaaah',
#   'biar',
#   'cepet',
#   'besok',
#   'ada',
#   'yg',
#   'berani',
#   'taruhan',
#   'siapa',
#   'yang',
#   'belain',
#   'mereka'],
#  ['tukang', 'fitnah', 'hukum', 'seberat2nya'],
#  ['hrsnya', 'min', '10thn', 'di', 'sel'],
#  ['nah',
#   'ini',
#   'dia',
#   'paling',
#   'lawyernya',
#   'habibu',
#   'getombolan',
#   'nasi',
#   'bungkus',
#   'micin',
#   'jantungan'],
#  ['cuma', '1', 'thn', 'enak', 'bener'],
#  ['ini',
#   'bodoh',
#   'amat',
#   'cuma',
#   '8',
#   'bulan',
#   'seharusnya',
#   'jangan',
#   'banding',
#   'malah',
#   'jadi',
#   '2',
#   'tahun'],
#  ['bos', 'nya', 'sikat'],
#  ['mari',
#   'kita',
#   'tunggu',
#   'siapa',
#   'saja',
#   'yg',
#   'nyinyir',
#   'atas',
#   'penangkapan',
#   'ini'],
#  ['muka2', 'tegar', 'menjalani', 'hukuman'],
#  ['bosnya', 'dah', 'ketangkap', 'blum'],
#  ['wowok', 'cs', 'banyak', 'mudarat', 'nya'],
#  ['bravo', 'kejaksaan', 'selamat', 'bertugas'],
#  ['hukum', 'seberatberatnya'],
#  ['kalo',
#   'cebong',
#   'mah',
#   'gk',
#   'di',
#   'tangkap',
#   'kebal',
#   'hukum',
#   'spt',
#   'viktor',
#   'laiskodat',
#   'ade',
#   'armando',
#   'nathan',
#   'ananda',
#   'sukarlan',
#   'dll',
#   '2019gantipresiden😏'],
#  ['good',
#   'job',
#   'jgn',
#   'lupa',
#   'gerombolan',
#   'surveyor',
#   'ines',
#   'juga',
#   'hrs',
#   'diawasi',
#   'dr',
#   'pada',
#   'menyebarkan',
#   'hasil',
#   'survey',
#   'abal',
#   'abal',
#   'apalagi',
#   'mo',
#   'pilpres',
#   'malah',
#   'bikin',
#   'perpecahan'],
#  ['sdh',
#   'dibongkar',
#   'kan',
#   'sama',
#   'pak',
#   'romi',
#   'pasti',
#   'ada',
#   'pendananya',
#   'si',
#   'kejar',
#   'juga',
#   'pak',
#   'jaksaterus',
#   'pak',
#   'berjuang',
#   'demi',
#   'bersihnya',
#   'negara',
#   'ini',
#   'dari',
#   'tukang',
#   'fitnah'],
#  ['usut', 'dana', 'nya', 'dari', 'mana', 'itu', 'baru', 'hebat👍'],
#  ['silahkan',
#   'bernyanyi',
#   'denga',
#   'bebas',
#   'walaupum',
#   'sumbangtempat',
#   'telah',
#   'disediakanwkwkwkwkkw'],
#  ['kok', 'cuma', 'setahun', ''],
#  ['ayo',
#   'donk',
#   'polisi',
#   'kalo',
#   'nangkep2',
#   'kaya',
#   'gini',
#   'dicari',
#   'tahu',
#   'bosnya',
#   'siapa',
#   'siapa',
#   'yang',
#   'memberi',
#   'dana',
#   'terus',
#   'kalo',
#   'udah',
#   'tau',
#   'tangkep',
#   'lansung'],
#  ['disate', 'aje', 'pak', 'jaksa'],
#  ['tembak', 'jidat', 'nya'],
#  ['tangkap',
#   'bandar',
#   'dan',
#   'pemimpin',
#   'gembong',
#   'hoaxnya',
#   'biar',
#   'jelas'],
#  ['tukang', 'fitnah', 'plus', 'juragannya', 'wajib', 'dihukum'],
#  ['sudah',
#   'terbukti',
#   'komplotan',
#   'sana',
#   'cuma',
#   'bisa',
#   'fitnah',
#   'hoax',
#   'pki',
#   'kerjanya',
#   'ngga',
#   'ada'],
#  ['mendingan', 'ditenggelamkan', 'aje'],
#  ['aktor',
#   'intelektual',
#   'yang',
#   'mendanai',
#   'kerja',
#   'obor',
#   'rakyat',
#   'untuk',
#   'kepentingan',
#   'politik',
#   'sang',
#   'aktor',
#   'intelektual',
#   'juga',
#   'harus',
#   'di',
#   'tangkap',
#   'dan',
#   'ditenggelamkan'],
#  ['mo',
#   'bgs',
#   'atau',
#   'gapresiden',
#   'itu',
#   'kepala',
#   'negara',
#   'yg',
#   'hrs',
#   'dihormatikl',
#   'lu',
#   'hina',
#   'ya',
#   'pantaslah',
#   'msk',
#   'bui'],
#  ['mo',
#   'bgs',
#   'atau',
#   'gapresiden',
#   'itu',
#   'kepala',
#   'negara',
#   'yg',
#   'hrs',
#   'dihormatikl',
#   'lu',
#   'hina',
#   'ya',
#   'pantaslah',
#   'msk',
#   'bui'],
#  ['mo',
#   'bgs',
#   'atau',
#   'gapresiden',
#   'itu',
#   'kepala',
#   'negara',
#   'yg',
#   'hrs',
#   'dihormatikl',
#   'lu',
#   'hina',
#   'ya',
#   'pantaslah',
#   'msk',
#   'bui'],
#  ['tukang', 'fitnah', 'dan', 'penyebar', 'hoax', 'tenggelamkan', ''],
#  ['hhahahh',
#   'ya',
#   'jelas',
#   'uda',
#   'ketebak',
#   'negri',
#   'dagelan',
#   'yg',
#   'komen',
#   'jga',
#   'blaa',
#   'blaaa',
#   'blaaaa',
#   '😂🤣😂🤣',
#   'lanjutakan',
#   'saja'],
#  ['terima', 'kasih', 'kejaksaan'],
#  ['pak',
#   'jaksa',
#   'yg',
#   'hina',
#   'pak',
#   'jokowi',
#   'berkali2',
#   'pasti',
#   'pak',
#   'jaksa',
#   'tau',
#   'lahtolong',
#   'di',
#   'seret',
#   'ke',
#   'penjara',
#   'thanks'],
#  ['sekalipun',
#   'benci',
#   'dng',
#   'jokowi',
#   'bukan',
#   'berarti',
#   'menebar',
#   'fitnah',
#   'biar',
#   'bgaimanapun',
#   'jokowi',
#   'itu',
#   'presiden',
#   'pilihan',
#   'rakyat',
#   'memfitnah',
#   'presiden',
#   '',
#   'memfitnah',
#   'rakyat'],
#  ['buron', 'wkwk'],
#  ['kalo',
#   'di',
#   'turki',
#   'ini',
#   'orang',
#   'sudah',
#   'diciduk',
#   'langsung',
#   'oleh',
#   'erdogan',
#   'presiden',
#   'idaman',
#   'nya',
#   'pks',
#   '🤣',
#   'untung',
#   'lah',
#   'di',
#   'indonesia',
#   'ini',
#   'presiden',
#   'nya',
#   'jokowi',
#   'yg',
#   'orang',
#   'nya',
#   'lembut',
#   'dan',
#   'kalem',
#   '😁'],
#  ['kalo', 'dulu', 'menang', 'udah', 'diangkat', 'menteri', 'nih', 'orang'],
#  ['kalo', 'dulu', 'menang', 'udah', 'diangkat', 'menteri', 'nih', 'orang'],
#  ['kalo', 'dulu', 'menang', 'udah', 'diangkat', 'menteri', 'nih', 'orang'],
#  ['kalo', 'dulu', 'menang', 'udah', 'diangkat', 'menteri', 'nih', 'orang'],
#  ['kalo', 'dulu', 'menang', 'udah', 'diangkat', 'menteri', 'nih', 'orang'],
#  ['boss', 'nya', 'juga', 'sekalian', 'disikat', 'toilet'],
#  ['boss', 'nya', 'juga', 'sekalian', 'disikat', 'toilet'],
#  ['jadi', 'inget', 'jaman', 'siapa', 'ya'],
#  ['orang', 'bikin', 'rusak', 'harus', 'musnahkan'],
#  ['super', 'muantap👍👍👍'],
#  ['baguslah',
#   'diciduk',
#   'sebelum',
#   'dikontrak',
#   'lagi',
#   'sama',
#   'tukang',
#   'fitnah'],
#  ['menjelekan',
#   'presiden',
#   'sama',
#   'saja',
#   'menghina',
#   'lambang',
#   'negara',
#   'harusnya',
#   'berpikir',
#   'apalagi',
#   'seorang',
#   'redaksi',
#   'berita',
#   'yang',
#   'seharusnya',
#   'menjadi',
#   'panutan',
#   'beritanya'],
#  ['semoga', 'betah', 'di', 'hotel', 'prodeo', 'ya', 'bro'],
#  ['sebaiknya', 'orang', 'spt', 'ini', 'dilenyapkan', 'saja'],
#  ['sikat', 'ikat', 'berkas'],
#  ['fitnah', 'krn', 'duit', '😆'],
#  ['tlg', 'dikubur', 'dalam2', 'org', 'begini'],
#  ['langsung', 'buang', 'aja', 'kelaut'],
#  ['tunggu', 'siapa', 'yang', 'komen', 'membelanah', 'itu', 'donaturnya'],
#  ['buniyani', 'gmn'],
#  ['kokk',
#   'lama',
#   'sekali',
#   'pelaku',
#   'kejahatan',
#   'hoax',
#   'ini',
#   'baru',
#   'dijebloskan',
#   'ke',
#   'bui',
#   'sekarang',
#   'usut',
#   'dan',
#   'tangkap',
#   'segera',
#   'pelaku',
#   'hoax',
#   'lainnya'],
#  ['obor', 'hoax'],
#  ['bravo', 'kejaksaanlumayan', 'ada', 'kerjanya'],
#  ['mantap', 'hajar', 'penyebar', 'hoax'],
#  ['yg', 'di', 'negri', 'sebrang', 'bgmn'],
#  ['4', 'tahun', 'pantesnya', '40', 'taon'],
#  ['itu', 'dlu', 'timses', 'syp', 'ea'],
#  ['masih', 'bisa', 'gaya', 'gaya', 'an', 'lihat', 'baju', 'mereka', 'seperti'],
#  ['mudah', '2', 'an', 'di', 'hukun', 'lebih', 'berat', 'lagi'],
#  ['wkwkwkwkwkw',
#   'syukurlah',
#   'kalian',
#   'banding',
#   'soalnya',
#   'hukuman',
#   'kalian',
#   'bakal',
#   'di',
#   'tambah',
#   'jd',
#   '10',
#   'thn',
#   'nyungsep',
#   'kalian',
#   ''],
#  ['sakit', 'jiwa', 'luuu'],
#  ['sakit', 'jiwa', 'lluu'],
#  ['kasihan', 'bener', 'mas', 'eko', 'semoga', 'dapat', 'jalan', 'keluarnya'],
#  ['jahat', 'sekali', 'yang', 'nipu'],
#  ['sebutin', 'aja', 'pengacaranya'],
#  ['nah',
#   'mulai',
#   'terkuak',
#   'biang',
#   'keladinya',
#   '',
#   'siapkan',
#   'bukti2',
#   'penyerahan',
#   'surat2',
#   'dan',
#   'tanda',
#   'terima',
#   'uang',
#   '',
#   'dikasi',
#   'ga',
#   'waktu',
#   'entu',
#   '',
#   'kalo',
#   'ga',
#   'ada',
#   'bukti',
#   'jangan',
#   'kau',
#   'harap',
#   'bisa',
#   'gugat',
#   'pengacara',
#   'ya',
#   ''],
#  ['semoga',
#   'dapat',
#   'pengganti',
#   'pengacara',
#   'kondang',
#   'mas',
#   'yang',
#   'kemarin',
#   'itu',
#   'abal',
#   'abal',
#   'punya'],
#  ['kasian',
#   'mas',
#   'eko',
#   'ini',
#   'bisa2',
#   'dituduh',
#   'lg',
#   'sama',
#   'cebong',
#   'sebagai',
#   'sebar',
#   'hoax',
#   'krn',
#   'tdk',
#   'ada',
#   'buktinya'],
#  ['yang',
#   'komentar',
#   'pada',
#   'ga',
#   'tahu',
#   'tentang',
#   'bagaimana',
#   'sertifikat',
#   'dibuat',
#   'sertifikat',
#   'itu',
#   'bisa',
#   'muncul',
#   'kalau',
#   'ada',
#   'akses',
#   'jalan',
#   'suruh',
#   'dia',
#   'tunjukin',
#   'denah',
#   'sertifikatnya',
#   'kalau',
#   'dia',
#   'memang',
#   'punya',
#   'itu',
#   'pasti',
#   'sertifikatnya',
#   'masih',
#   'gabung',
#   'ama',
#   'sebelah',
#   'kiri',
#   'atau',
#   'sebelah',
#   'kanannya',
#   'dan',
#   'itu',
#   'pasti',
#   'masih',
#   'saudara',
#   'dia',
#   'sertifikatnya',
#   'belum',
#   'dipecah',
#   'ama',
#   'mereka',
#   'berdua'],
#  ['nanti', 'pintu', 'surganya', 'juga', 'diblokade', 'sama', 'tuhan'],
#  ['sdh',
#   'bp',
#   'camat',
#   'yg',
#   'harus',
#   'menyelesaikan',
#   'biar',
#   'p',
#   'camat',
#   'dpt',
#   'pahala',
#   'membantu',
#   'yg',
#   'tertindas',
#   '',
#   'toh',
#   'ga',
#   'lama',
#   'lagi',
#   'kita',
#   'mati',
#   'dan',
#   'runah',
#   'tanah',
#   'itu',
#   'tdk',
#   'di',
#   'bawaq'],
#  ['saya',
#   'tahun',
#   'kemarin',
#   'beli',
#   'tanah',
#   '20',
#   '�15',
#   'm',
#   'tapi',
#   'saya',
#   'bikin',
#   'fondasi',
#   'pagar',
#   '19',
#   '�15m',
#   'jadi',
#   'ada',
#   '1',
#   'meter',
#   'untuk',
#   'akses',
#   'jalan',
#   'setapak',
#   'berarti',
#   'saya',
#   'relakan',
#   'tanah',
#   'saya',
#   '1�15m',
#   'utk',
#   'kepentingan',
#   'umum',
#   'tetangga',
#   'sebelah',
#   'juga',
#   'demikian',
#   'jadi',
#   'jalan',
#   'setapak',
#   'lebarnya',
#   '2',
#   'meter',
#   'kita',
#   'kan',
#   'hidup',
#   'bertetangga',
#   'masa',
#   'tanah',
#   'satu',
#   'meter',
#   'aja',
#   'menghalangi',
#   'silaturahmi',
#   'dengan',
#   'tetangga',
#   'jadi',
#   'harus',
#   'dibicarakan',
#   'baikbaik',
#   'semua',
#   'bisa',
#   'diatur',
#   'yg',
#   'penting',
#   'dengan',
#   'hati',
#   'nurani'],
#  ['lemah',
#   'mati',
#   'tidak',
#   'ada',
#   'akses',
#   'jalan',
#   'itu',
#   'murah',
#   'harganya',
#   'lha',
#   'ini',
#   'yg',
#   'punya',
#   'tanah',
#   'maruk',
#   'ud',
#   'deal',
#   '100jt',
#   'minta',
#   'naik',
#   '150jt',
#   'jengkel',
#   'di',
#   'tutup',
#   'sekalian',
#   'ma',
#   'tetangga',
#   'yakin',
#   'tuh',
#   'yg',
#   'punya',
#   'tanah',
#   'mati',
#   'pasti',
#   'kolot',
#   'jd',
#   'dikerjai',
#   'tetangga�'],
#  ['klo',
#   'tdk',
#   'salah',
#   'ada',
#   'undangundang',
#   'pertanahan',
#   'yg',
#   'mengatur',
#   'tentang',
#   'kewajiban',
#   'bagi',
#   'pemilik',
#   'tanah',
#   'dan',
#   'bangunan',
#   'untuk',
#   'memberi',
#   'akses',
#   'jalan',
#   'bagi',
#   'pemilik',
#   'tanah',
#   'dan',
#   'bangunan',
#   'dibelakangnya',
#   'yg',
#   'tdk',
#   'memiliki',
#   'akses',
#   'jalan',
#   'dlm',
#   'sertifikat',
#   'tanahnya',
#   'istilahnya',
#   'tanah',
#   'helikopter',
#   'minimal',
#   'jalan',
#   'setapak',
#   'silahkan',
#   'dicek',
#   'saya',
#   'lupa',
#   'pasalnya'],
#  ['tidak',
#   'berperikemanusiaan',
#   'yang',
#   'nutup',
#   'akses',
#   'itu',
#   'maukah',
#   'dia',
#   'diperlakukan',
#   'seperti',
#   'itu',
#   'tanya',
#   'ke',
#   'kupingnya',
#   'dengan',
#   'keras',
#   'maukah',
#   'dia',
#   'diperlakukan',
#   'seperti',
#   'itu',
#   'jika',
#   'berada',
#   'di',
#   'belakang',
#   'rumah',
#   'orang',
#   'lain'],
#  ['u2063sepertinya',
#   'ada',
#   'yang',
#   '',
#   'kurang',
#   'beres',
#   'dengan',
#   'sertifikatnya',
#   'di',
#   'antara',
#   'rumah',
#   'rumah',
#   'itu',
#   'logikanya',
#   'rtrw',
#   'lurahcamat',
#   '',
#   'bppn',
#   'waktu',
#   'menerbitkan',
#   'sertifikat',
#   'itu',
#   'pasti',
#   'tahu',
#   'posisi',
#   'dan',
#   'batas',
#   'batas',
#   'rumah',
#   'pasti',
#   'ada',
#   'yang',
#   'salah',
#   'dengan',
#   'sertifikat',
#   'sertifikat',
#   'itu',
#   'tentang',
#   'batasbatas',
#   'tanahnya',
#   'minimal',
#   'ada',
#   'hak',
#   'orang',
#   'yang',
#   'diserobot',
#   'polisi',
#   'harus',
#   'turun',
#   'ini'],
#  ['priksa',
#   'dulu',
#   'imb',
#   'nya',
#   'ada',
#   'gak�',
#   'kalau',
#   'gak',
#   'ada',
#   'suruk',
#   'satpol',
#   'yg',
#   'bongkar',
#   'jangan',
#   'korbankan',
#   'tetangga'],
#  ['sebelum',
#   'semuanya',
#   'menjudge',
#   'tanpa',
#   'tabayyunsimple',
#   'utk',
#   'mencari',
#   'siapa',
#   'yg',
#   'salahyg',
#   'diakui',
#   'selama',
#   'ini',
#   'sbagai',
#   'akses',
#   'jalan',
#   'pak',
#   'eko',
#   'ini',
#   'sebenarnya',
#   'memang',
#   'peruntukan',
#   'jalan',
#   'atau',
#   'menggunakan',
#   'melewati',
#   'tanah',
#   'orang',
#   'lainklo',
#   'memang',
#   'akses',
#   'jalantetangganya',
#   'jelas',
#   'salahtapi',
#   'klo',
#   'itu',
#   'memang',
#   'tanah',
#   'org',
#   'lainya',
#   'memang',
#   'haknya',
#   'dia',
#   'utk',
#   'menembokyg',
#   'salah',
#   'adalah',
#   'pemerintah',
#   'setempatmana',
#   'akses',
#   'jalan',
#   'selama',
#   'ini',
#   'yg',
#   'harusnya',
#   'ada'],
#  ['yang',
#   'punya',
#   'tanah',
#   'nggak',
#   'bisa',
#   'disalahin',
#   'jugamemang',
#   'itu',
#   'haknya',
#   'diaklo',
#   'dia',
#   'dituntut',
#   'harus',
#   'ngasih',
#   'sebagian',
#   'untuk',
#   'jalantetangga',
#   'kirikanan',
#   'n',
#   'belakang',
#   'pak',
#   'eko',
#   'juga',
#   'harus',
#   'dituntut',
#   'hal',
#   'yg',
#   'serupaapesnya',
#   'dia',
#   'adalah',
#   'dia',
#   'baru',
#   'beli',
#   'n',
#   'bangun',
#   'skrg'],
#  ['kasih', 'jln', 'pakitu', 'ladang', 'amal', 'bpk�'],
#  ['klo',
#   'ud',
#   'deal',
#   '100jt',
#   'kok',
#   'ingkar',
#   'jd',
#   '150jt',
#   'ya',
#   'hrsnya',
#   'jgn',
#   'serakah',
#   'jg',
#   'ya',
#   'klo',
#   'emank',
#   'maunya',
#   '150jt',
#   'ya',
#   'jgn',
#   'buka',
#   '100jt',
#   'donkntar',
#   'ada',
#   'yg',
#   'mau',
#   '150jt',
#   'ingkar',
#   'lgi',
#   '200jt'],
#  ['akar', 'masalah', 'nya', '�', '�', '�', '�', '�', '�duit'],
#  ['ya',
#   'sudah',
#   'to',
#   'pak',
#   'eko',
#   'pindah',
#   'aja',
#   'rumah',
#   'lama',
#   'jadikan',
#   'kandang',
#   'ayam',
#   'atau',
#   'studio',
#   'musik',
#   'kan',
#   'haknya',
#   'pak',
#   'eko',
#   'juga',
#   'to',
#   'saat',
#   'ketemu',
#   'tetangga',
#   'yang',
#   'gak',
#   'pedulian',
#   'ya',
#   'sudah',
#   'jadikan',
#   'kita',
#   'gak',
#   'peduli',
#   'ngalah',
#   'terus',
#   'tidak',
#   'selamanya',
#   'baik'],
#  ['benernya',
#   'siapa',
#   'sie',
#   'yang',
#   'mau',
#   'beli',
#   'siapa',
#   'yang',
#   'mau',
#   'jual',
#   'kok',
#   'keterangan',
#   'camat',
#   'beda',
#   'sama',
#   'eko',
#   'eko',
#   'bilang',
#   'dia',
#   'yang',
#   'mau',
#   'beli',
#   'tanah',
#   'tetangganya',
#   'buat',
#   'jalan',
#   'kata',
#   'camat',
#   'malah',
#   'eko',
#   'yang',
#   'mau',
#   'jual',
#   'malah',
#   'harga',
#   'naik',
#   'pulaini',
#   'yakin',
#   'ada',
#   'yang',
#   'ga',
#   'beres',
#   'sama',
#   'si',
#   'eko'],
#  ['gak',
#   'pernah',
#   'belajar',
#   'pmp',
#   'mana',
#   'toleransisaling',
#   'menghargaissopan',
#   'santunempati',
#   'dalam',
#   'bertetangga'],
#  ['dulu',
#   'sudah',
#   'mau',
#   'dibeli',
#   '100jt',
#   'tapi',
#   'ga',
#   'jadi',
#   'karena',
#   'naik',
#   'minta',
#   '150jt',
#   'giliran',
#   'dibikin',
#   'tembok',
#   'merengek',
#   'rengek',
#   'ngadu',
#   'kesana',
#   'kamari',
#   'lebay'],
#  ['ujung', 'ujungnya', 'duit'],
#  ['sdh', 'terbacapokok', 'permasalah', 'nya'],
#  ['camat',
#   'koq',
#   'minta2',
#   'keluar',
#   'dari',
#   'kantor',
#   'kalian',
#   'itu',
#   'hei',
#   'camat',
#   'lurah',
#   'jgn',
#   'ongkang2',
#   'keq',
#   'kumpeni',
#   'aje',
#   'lu',
#   'pade'],
#  ['jangan',
#   'maen',
#   'asal',
#   'ngomong',
#   'nuduh',
#   'salah',
#   'satu',
#   'pihak',
#   'masalah',
#   'ini',
#   'terjadi',
#   'bukan',
#   'krn',
#   'pihak',
#   'yg',
#   'bersengketa',
#   'saja',
#   'ada',
#   'peran',
#   'rt',
#   'rw',
#   'lurah',
#   'camat',
#   'serta',
#   'pihak',
#   'pertanahan',
#   'rencana',
#   'tata',
#   'ruangnya',
#   'mana',
#   'masing2',
#   'punya',
#   'andil',
#   'dalam',
#   'terjadinya',
#   'masalah',
#   'ini',
#   'bukan',
#   'serta',
#   'merta',
#   'gr2',
#   'pihak',
#   'pak',
#   'eko',
#   'ataupun',
#   'tetangganya�'],
#  ['pny',
#   'tanah',
#   'pribadi',
#   'jng',
#   'dibuat',
#   'jalanan',
#   'nnt',
#   'diserobotud83dude0b'],
#  ['jadi',
#   'sudah',
#   'jelas',
#   'to',
#   'akar',
#   'masalahnyalain',
#   'kumbang',
#   'lain',
#   'belangnyaud83dude02'],
#  ['seharusnya',
#   'ke',
#   'pangadilan',
#   'saja',
#   'apapun',
#   'hasilnya',
#   'itu',
#   'yang',
#   'akan',
#   'diakui',
#   'secara',
#   'hukum',
#   'kalau',
#   'curhat',
#   'kemana2',
#   'pasti',
#   'hanya',
#   'dapat',
#   'lip',
#   'service',
#   'saja',
#   'karena',
#   'mereka',
#   'hanya',
#   'bisa',
#   'menghimbau'],
#  ['sdh',
#   'mau',
#   'dibeli',
#   '100jt',
#   'tp',
#   'naik',
#   'jd',
#   '150jt',
#   'lgdr',
#   'sini',
#   'sdh',
#   'sdkt',
#   'jls',
#   'akar',
#   'mslhnya'],
#  ['ko',
#   'masih',
#   'ada',
#   'ya',
#   'orang',
#   'kaya',
#   'gitutinggal',
#   'di',
#   'perkampungan',
#   'mending',
#   'di',
#   'kubur',
#   'aja'],
#  ['spekulasi',
#   'tu',
#   'yg',
#   'jd',
#   'pertanyaan',
#   'ketika',
#   'jual',
#   'beli',
#   'kan',
#   'ada',
#   'form',
#   'tanda',
#   'tangan',
#   'sepengetahuan',
#   'jiran',
#   'kanan',
#   'kiri',
#   'dpn',
#   'blkg',
#   'dr',
#   'situ',
#   'sdh',
#   'dpt',
#   'awal',
#   'masalahnya',
#   'kmn',
#   'tu',
#   'pak',
#   'rt',
#   'rw',
#   'kadus',
#   'n',
#   'kades'],
#  ['klpun',
#   'd',
#   'kasih',
#   'jalan',
#   'jg',
#   'mending',
#   'pindah',
#   'aja',
#   'pakpunya',
#   'tetangga',
#   'kayak',
#   'gitu',
#   'modelnya',
#   'susah',
#   'liat',
#   'orang',
#   'senangsenang',
#   'liat',
#   'orang',
#   'susah'],
#  ['knpa',
#   'setelah',
#   'viral',
#   'di',
#   'medsos',
#   'camat',
#   'nya',
#   'baru',
#   'turun',
#   'tangan�',
#   'pak',
#   'eko',
#   'bilang',
#   'sdh',
#   '3',
#   'thn',
#   'mondarmandir',
#   'utk',
#   'cari',
#   'solusi�',
#   'jadi',
#   'klu',
#   'ada',
#   'masalh',
#   'sprti',
#   'ini',
#   'mendingan',
#   'di',
#   'viralkan�',
#   'spya',
#   'cepat',
#   'ditanggapi'],
#  ['masoook', 'pak', 'eko'],
#  ['tetangga',
#   'kayak',
#   'gini',
#   'harus',
#   'buru',
#   'buru',
#   'di',
#   'mandiin',
#   'di',
#   'solatin',
#   'di',
#   'kafanin',
#   'dan',
#   'dikuburin',
#   'langsung',
#   'ga',
#   'ada',
#   'adabnya'],
#  ['gabisa', 'masook', 'pak', 'ekooo'],
#  ['u2063saya',
#   'enggak',
#   'nyebutin',
#   'kronologi',
#   'karena',
#   'privacy',
#   'hmm',
#   'ada',
#   'yang',
#   'aneh'],
#  ['disini',
#   'banyak',
#   'pendukung',
#   'tetangga',
#   'pak',
#   'eko',
#   'atau',
#   'mgkn',
#   'tetangga',
#   'disitu',
#   'wkwkww'],
#  ['dijual', 'ke', 'tetangga', 'depan', 'samping', 'saja', 'pak'],
#  ['rt',
#   'rw',
#   'lurah',
#   'camat',
#   'bpn',
#   'walkot',
#   'bupati',
#   'tidorrrr',
#   'semuaaaaaa'],
#  ['masssook', 'pak', 'ekoo'],
#  ['harusnya',
#   'dipikirin',
#   'sejak',
#   'dini',
#   'kalo',
#   'sudah',
#   'begini',
#   'bingung',
#   'dah',
#   'lu',
#   'ekoud83dude33ud83dude33ud83dude33',
#   'slh',
#   'elu',
#   'sendiri'],
#  ['kalau',
#   'mau',
#   'jual',
#   'ya',
#   'ke',
#   'tetangganya',
#   'gak',
#   'usah',
#   'cari',
#   'sensasi',
#   'banyak',
#   'kok',
#   'org',
#   'lqin',
#   'yg',
#   'rugi',
#   'lebih',
#   'banyak',
#   'utk',
#   'urusan2',
#   'tanah',
#   'bahkan',
#   'tanah',
#   'dgn',
#   'surat',
#   'berlapis',
#   'juga',
#   'ada',
#   'toh',
#   'yg',
#   'rugi',
#   'pemilik',
#   'org',
#   'bpn',
#   'palingan',
#   'hanya',
#   'di',
#   'mutasi',
#   'apalagi',
#   'kl',
#   'sdh',
#   'pensiun',
#   'gak',
#   'ada',
#   'sangsi',
#   'apa2�'],
#  ['ini',
#   'eko',
#   'nya',
#   'yg',
#   'bodohhh',
#   'sejak',
#   'awalud83dude06ud83dude06ud83dude06'],
#  ['undang2',
#   'sdh',
#   'mengatur',
#   'klo',
#   'pembangunan',
#   'tidal',
#   'boleh',
#   'menutup',
#   'akses',
#   'jalan',
#   'bagi',
#   'rumah',
#   'atau',
#   'tempat',
#   'tinggal',
#   'yg',
#   'sudah',
#   'ada',
#   'sebelumnya',
#   'mohon',
#   'koreksi',
#   'klo',
#   'salah'],
#  ['kayak',
#   'nya',
#   'si',
#   'eko',
#   'ini',
#   'punya',
#   'kelainan',
#   'cara',
#   'bertetangga',
#   'deh'],
#  ['masooookkkk', 'pak', 'ekooo'],
#  ['pak',
#   'eko',
#   'punya',
#   'imb�',
#   'kok',
#   'bisa',
#   'bangun',
#   'rumah�',
#   'tanpa',
#   'halaman�'],
#  ['solusinya',
#   'ya',
#   'jual',
#   'ke',
#   'tetangga',
#   'depannya',
#   'itu',
#   'pak',
#   'hitung',
#   'harga',
#   'tanah',
#   'saja',
#   'karena',
#   'memang',
#   'rumah',
#   '',
#   'tanah',
#   'bpk',
#   'di',
#   'block',
#   'sama',
#   'dia',
#   'banyak',
#   'yang',
#   'seperti',
#   'itu',
#   'istilahnya',
#   'lock',
#   'land',
#   '',
#   'jadi',
#   'memang',
#   'dia',
#   'beli',
#   'atau',
#   'bpk',
#   'bisa',
#   'juga',
#   'beli',
#   'tanah',
#   'didepan',
#   'untuk',
#   'akses',
#   ''],
#  ['beli',
#   'aja',
#   'tanah',
#   'tetangga',
#   'atau',
#   'jual',
#   'rumahnya',
#   'ke',
#   'tetangganya'],
#  ['ya',
#   'harusnya',
#   'dari',
#   'awal',
#   'pak',
#   'eko',
#   'sudah',
#   'membuat',
#   'jalan',
#   'utk',
#   'rumahnya',
#   'sendiri',
#   'bukan',
#   'nya',
#   'membuat',
#   'rumah',
#   'full',
#   'bangunan',
#   'tp',
#   'disisakan',
#   'utk',
#   'jalan',
#   'hak',
#   'tetangga',
#   'jg',
#   'membuat',
#   'rumah',
#   'di',
#   'tanahnya',
#   'sandiri',
#   'seperti',
#   'yg',
#   'dilakukan',
#   'pak',
#   'eko',
#   'kejadian',
#   'sebenarnya',
#   'masih',
#   'misteri',
#   'siapa',
#   'yg',
#   'salah',
#   'dan',
#   'yg',
#   'benar',
#   'masih',
#   'abu2'],
#  ['masuk', 'pak', 'eko', ''],
#  ['tata', 'ruangnya', 'amburadul'],
#  ['sebetulnya',
#   'yg',
#   'paling',
#   'salah',
#   'adalah',
#   'bpn',
#   'karna',
#   'di',
#   'peraturan',
#   'agraria',
#   'terutuang',
#   'hukum',
#   'mengenai',
#   'pemberian',
#   'jalan',
#   'kepada',
#   'tanah',
#   'yg',
#   'tdk',
#   'memiliki',
#   'jalan',
#   'cth',
#   'tanah',
#   'yg',
#   'di',
#   'tengah',
#   'telah',
#   'disertifikat',
#   'di',
#   'kanan',
#   'dan',
#   'dikiri',
#   'pun',
#   'telah',
#   'bersertifikat',
#   'dan',
#   'menutup',
#   'jalan',
#   'di',
#   'depannya',
#   'jg',
#   'dibuat',
#   'sertifikat',
#   'dan',
#   'menutup',
#   'akses',
#   'yg',
#   'ditgh',
#   'sementara',
#   'blkg',
#   'belum',
#   'nah',
#   'ketika',
#   'belakang',
#   'membuat',
#   'sertifikat',
#   'secara',
#   'otomatis',
#   'yg',
#   'belakang',
#   'akan',
#   'kepotong',
#   'tanahnya',
#   'dan',
#   'memberikan',
#   'akses',
#   'jalan',
#   'yg',
#   'ditengah',
#   'cuma',
#   'masyarakat',
#   'bnyk',
#   'yg',
#   'awam',
#   'dgn',
#   'peraturan',
#   'tersebut'],
#  ['ketua',
#   'rt',
#   'rw',
#   'lurah',
#   'ko',
#   'pd',
#   'diem',
#   'ayu',
#   'bantu',
#   'warganya',
#   'masa',
#   'kalah',
#   'gantian',
#   'tutup',
#   'jlnnya'],
#  ['kemungkinan',
#   'besar',
#   'ada',
#   'yg',
#   'gak',
#   'beres',
#   'dg',
#   'proses',
#   'penerbitan',
#   'imb'],
#  ['bisa',
#   'dirundingkan',
#   'lha',
#   'sebelumnya',
#   'ditawari',
#   'tanah',
#   'tetangganya',
#   'tidak',
#   'mau',
#   'ya',
#   'bukan',
#   'salah',
#   'yang',
#   'memblokade�',
#   'makanya',
#   'harus',
#   'baik',
#   'baik',
#   'dengan',
#   'tetangga',
#   'dan',
#   'pengurus',
#   'rt',
#   'setempat�'],
#  ['tdk',
#   'diperbolehkan',
#   'perda',
#   'membangun',
#   'tp',
#   'merugikan',
#   'tetangga',
#   'walaupun',
#   'di',
#   'lahan',
#   'sendiri',
#   'biasanya',
#   'jika',
#   'trjadi',
#   'spt',
#   'itu',
#   'dinas',
#   'pengawasan',
#   'pembangunan',
#   'akan',
#   'bertindak'],
#  ['masuuukkk', 'pakk', 'ekoo'],
#  ['pastinya', 'orang', 'ini', 'bermasalah', 'dengan', 'tetangganya', ''],
#  ['jual', 'sama', 'yg', 'ngeblokade'],
#  ['silaturahmi',
#   'dgn',
#   'tetangga',
#   'itu',
#   'penting',
#   'walau',
#   'akses',
#   'ditutup',
#   'kalau',
#   'tetangga',
#   'seperti',
#   'saudara',
#   'pasti',
#   'dikasih',
#   'jalan',
#   'tinggal',
#   'ketok',
#   'rumah',
#   'tetangga',
#   'terus',
#   'u201cmasuk',
#   'pak',
#   'ekou201d'],
#  ['imb', 'bisa', 'keluar'],
#  ['ya',
#   'hak',
#   'tetangga',
#   'juga',
#   'blokade',
#   'jalan',
#   'karena',
#   'mungkin',
#   'itu',
#   'tanah',
#   'tetangga',
#   'harusnya',
#   'di',
#   'musyawarahkan',
#   'baik2',
#   'dgn',
#   'tetangga',
#   'klo',
#   'kita',
#   'baik',
#   'ke',
#   'tetangga',
#   'gak',
#   'mungkin',
#   'tetangga',
#   'akan',
#   'setega',
#   'itu',
#   'memblokade',
#   'jlan�'],
#  ['waras', 'slamet', 'pak', 'eko', 'tenang', 'aja', 'gusti', 'tak', 'sare'],
#  ['mana',
#   'kades',
#   'nya',
#   'masa',
#   'ada',
#   'warganya',
#   'yg',
#   'bermasalah',
#   'gini',
#   'ga',
#   'diselesaikan'],
#  ['surat',
#   'kog',
#   'dilempar',
#   'memangnya',
#   'koran',
#   '',
#   'meskipun',
#   'bener',
#   'koran',
#   'apa',
#   'sopan',
#   'lempar',
#   'koran',
#   'ke',
#   'presiden',
#   '',
#   'apa',
#   'gak',
#   'bisa',
#   'dititipkan',
#   'suratnya',
#   'lewat',
#   'paspampres',
#   ''],
#  ['ya',
#   'jelas',
#   'dikejar',
#   'pampapres',
#   'ngelempar',
#   'benda',
#   'seperti',
#   'itu',
#   'ke',
#   'presiden',
#   'itu',
#   'sudah',
#   'tugas',
#   'mereka',
#   'menjaga',
#   'presiden'],
#  ['sifatmu',
#   'mungkin',
#   'juga',
#   'ga',
#   'benar',
#   'main',
#   'lempar',
#   'surat',
#   'tanpa',
#   'pikir',
#   'kesopanan',
#   'instropeksi',
#   'pak',
#   'eko'],
#  ['tetangga', 'masa', 'gitu', ''],
#  ['u2063sepertinya',
#   'ada',
#   'yang',
#   '',
#   'kurang',
#   'beres',
#   'dengan',
#   'sertifikatnya',
#   'di',
#   'antara',
#   'rumah',
#   'rumah',
#   'itu',
#   'logikanya',
#   'rtrw',
#   'lurahcamat',
#   '',
#   'bppn',
#   'waktu',
#   'menerbitkan',
#   'sertifikat',
#   'itu',
#   'pasti',
#   'tahu',
#   'posisi',
#   'dan',
#   'batas',
#   'batas',
#   'rumah',
#   'pasti',
#   'ada',
#   'yang',
#   'salah',
#   'dengan',
#   'sertifikat',
#   'sertifikat',
#   'itu',
#   'tentang',
#   'batasbatas',
#   'tanahnya',
#   'minimal',
#   'ada',
#   'hak',
#   'orang',
#   'yang',
#   'diserobot',
#   'polisi',
#   'harus',
#   'turun',
#   'ini'],
#  ['wah',
#   'kalo',
#   'saja',
#   'sampe',
#   'ke',
#   'telinga',
#   'jokowi',
#   'pasti',
#   'akan',
#   'dibuatin',
#   'flyover'],
#  ['bandung',
#   '',
#   'jabar',
#   'ada',
#   'gubernur',
#   'baru',
#   'kalau',
#   'yang',
#   'dulu',
#   'emang',
#   'parah',
#   'sekarang',
#   'lapor',
#   'pasti',
#   'di',
#   'beresin',
#   'ngak',
#   'semuasemua',
#   'ke',
#   'presiden',
#   'kalees'],
#  ['katanya', 'pak', 'camat', 'tidak', 'tahu'],
#  ['yang',
#   'memblokade',
#   'pasti',
#   'orang',
#   'kuat',
#   'juga',
#   'orang',
#   'penting',
#   'sampai',
#   'camat',
#   'gak',
#   'bisa',
#   'nyelesaikan'],
#  ['sudah',
#   'bodoh',
#   'mau',
#   'menang',
#   'sendiri',
#   'ini',
#   'problem',
#   'di',
#   'daerah2',
#   'mengharapkan',
#   'tetangga',
#   'memberikan',
#   'jalan',
#   'sementara',
#   'mereka',
#   'banyak',
#   'yang',
#   'membuat',
#   'rumah',
#   'atau',
#   'pagar',
#   'melebihi',
#   'ukuran',
#   'sk',
#   'tanah',
#   'yang',
#   'dimiliki',
#   'alias',
#   'menyerobot',
#   'tanah',
#   'tetangga'],
#  ['coba', 'ke', 'kopi', 'joni', 'lahh'],
#  ['kalau',
#   'semua',
#   'ke',
#   'jokowi',
#   'ya',
#   'ga',
#   'mungkin',
#   'ada',
#   'jutaan',
#   'masalah',
#   'di',
#   'indonesia',
#   'urutannya',
#   'itu',
#   'bisa',
#   'minta',
#   'mediasi',
#   'didampingi',
#   'rtrw',
#   'ke',
#   'kelurahan',
#   'kalau',
#   'gagal',
#   'ya',
#   'ke',
#   'kecamatan',
#   'kalau',
#   'ga',
#   'bisa',
#   'dateng',
#   'mediasi',
#   'ya',
#   'tulis',
#   'surat',
#   'resmi',
#   'ke',
#   'kelurahan',
#   'kecamatan',
#   'kotamadya',
#   'kalau',
#   'tidak',
#   'ditanggapi',
#   'bisa',
#   'tulis',
#   'pengaduan',
#   'ke',
#   'ombudsman',
#   'banyak',
#   'kok',
#   'permasalahan',
#   'yg',
#   'sampai',
#   'ke',
#   'ombudsman',
#   'dan',
#   'langsung',
#   'di',
#   'follow',
#   'up',
#   'antara',
#   '12',
#   'bulan',
#   'ga',
#   'usah',
#   'tunggu',
#   '3',
#   'tahun',
#   'ngejar2',
#   'presiden'],
#  ['tp', 'msh', 'bisa', 'keluar', 'rumah', 'ga'],
#  ['inilah',
#   'contoh',
#   'manusia',
#   'indonesia',
#   'jaman',
#   'now',
#   'yg',
#   'katanya',
#   'pancasilais',
#   'ternyata',
#   'egois',
#   'tk',
#   'ada',
#   'toleransi',
#   'sedikitpun',
#   'kpd',
#   'sesama',
#   'pd',
#   'sesama',
#   'tetangga',
#   'rt',
#   'rw',
#   'lurah',
#   'nya',
#   'camaunya',
#   'walikota',
#   'nya',
#   'gubernur',
#   'nya',
#   'pancasila',
#   'nya',
#   'mana'],
#  ['akalnya',
#   'aja',
#   'kurang',
#   'pinter',
#   'itu',
#   'bikin',
#   'lif',
#   'sampai',
#   'atas',
#   'genteng',
#   'kan',
#   'bisa',
#   'terus',
#   'bikin',
#   'tol',
#   'diatas',
#   'genteng',
#   'sampai',
#   'jalan',
#   'raya',
#   'hehehe'],
#  ['pertanyaanya',
#   'bagaimana',
#   'hubungan',
#   'bertetangganya',
#   'kok',
#   'sampe',
#   'tega',
#   'di',
#   'block',
#   'gitu',
#   'kita',
#   'tdk',
#   'tau',
#   'ada',
#   'permasalahan',
#   'apa',
#   'sedangkan',
#   'pak',
#   'eko',
#   'slalu',
#   'bilang',
#   'privacy',
#   'lha',
#   'piye',
#   'to'],
#  ['surat',
#   'rumah',
#   'pak',
#   'eko',
#   'ternyata',
#   'gak',
#   'beres',
#   'pantesan',
#   'gak',
#   'ada',
#   'yg',
#   'bisa',
#   'belain',
#   'krn',
#   'secara',
#   'hukum',
#   'pak',
#   'eko',
#   'melakukan',
#   'pelanggaran',
#   'ternyata',
#   'pak',
#   'eko',
#   'minta',
#   'simpati',
#   'publik',
#   'pdhal',
#   'secara',
#   'hukum',
#   'dia',
#   'bersalah'],
#  ['knapa',
#   'buat',
#   'rumah',
#   'tidak',
#   'membuat',
#   'akses',
#   'utk',
#   'jalan',
#   'sendiri',
#   'bearti',
#   'selama',
#   'ini',
#   'mengambil',
#   'jalan',
#   'dari',
#   'tanah',
#   'orang',
#   'lain',
#   'mengambil',
#   'hak',
#   'tetangga',
#   'utk',
#   'kepentingan',
#   'sendiri'],
#  ['mungkin',
#   'pak',
#   'eko',
#   'disuruh',
#   'bayar',
#   'akses',
#   'jalan',
#   'tp',
#   'g',
#   'mau',
#   'kl',
#   'spt',
#   'ini',
#   'ya',
#   'g',
#   'akan',
#   'ada',
#   'titik',
#   'temu',
#   'krn',
#   'pemilik',
#   'jalan',
#   'mumgkin',
#   'beli',
#   'keseluruhan',
#   'tp',
#   'pak',
#   'eko',
#   'minta',
#   'cuma2',
#   'doang',
#   'tiap',
#   'jengkal',
#   'tanah',
#   'itu',
#   'berharga',
#   'apalagi',
#   'diperkotaan'],
#  ['aneh',
#   'sih',
#   'memang',
#   'kelakuan',
#   'tetangga',
#   'sprt',
#   'ini',
#   'biasanya',
#   'sihmhn',
#   'maaf',
#   'yg',
#   'sering',
#   'model2',
#   'tutup',
#   'jalan',
#   'tutup',
#   'got',
#   'krn',
#   'itu',
#   'dulu',
#   'tanah',
#   'engkong',
#   'gw',
#   'itu',
#   'dulu',
#   'punya',
#   'babak',
#   'gwkan',
#   'bukan',
#   'orang',
#   'sunda'],
#  ['salah',
#   'sendiri',
#   'lah',
#   'kenapa',
#   'dulu',
#   'gak',
#   'dijual',
#   'aja',
#   'tuh',
#   'rumah',
#   'jual',
#   'murah',
#   'aja',
#   'sama',
#   'tetangga',
#   'pake',
#   'njop',
#   'jgn',
#   'pake',
#   'harga',
#   'pasar',
#   'dungu',
#   'dipelihara',
#   ''],
#  ['aparat',
#   'kecamatan',
#   'sama',
#   'desa',
#   'nya',
#   'saja�',
#   'yg',
#   'gk',
#   'becus',
#   'buat',
#   'me',
#   'mediasi',
#   'masalah',
#   'seperti',
#   'itu�',
#   'ganti',
#   'langsung',
#   'camat',
#   'sama',
#   'lurah',
#   'nya',
#   'kok',
#   'ada',
#   'masyarakat',
#   'nya',
#   'susah',
#   'gk',
#   'segera',
#   'di',
#   'bantu',
#   'penyelesaian',
#   'masalah',
#   'nya�'],
#  ['mas',
#   'eko',
#   'anda',
#   'harus',
#   'info',
#   'ke',
#   'media',
#   'sewaktu',
#   'anda',
#   'sudah',
#   'melaporkan',
#   'ke',
#   'dinas',
#   'terkait',
#   'bahkan',
#   'sampai',
#   'gubernur',
#   'dan',
#   'tidak',
#   'ditanggapiada',
#   'hrs',
#   'cerita',
#   'siapa',
#   'saja',
#   'sehingga',
#   'anda',
#   'tidak',
#   'sebar',
#   'fitnahbiar',
#   'oknum2',
#   'ini',
#   'biar',
#   'ditindak',
#   'bila',
#   'itu',
#   'benar',
#   'adanyajgn',
#   'pernah',
#   'takut'],
#  ['rt', 'rw', 'kelurahan', 'camat�', 'gk', 'becus�'],
#  ['sabar',
#   'pak',
#   'eko',
#   'semua',
#   'akan',
#   'di',
#   'selesaikan',
#   'dlm',
#   'hitungan',
#   'jam',
#   'tp',
#   'di',
#   'tahun',
#   '2019',
#   'setelah',
#   'rezim',
#   'berganti'],
#  ['hhhh',
#   'aneh',
#   'org',
#   'lempar',
#   'kertas',
#   'dikejar',
#   'tapi',
#   'org',
#   'bisa',
#   'nepuk',
#   'jokowi',
#   'wkt',
#   'touring',
#   'motor',
#   'ga',
#   'diinterogasi',
#   'atau',
#   'dilumpuhkan',
#   'paspampressetting',
#   'pencitraan',
#   'atau',
#   'paspampresnya',
#   'yg',
#   'ga',
#   'becus',
#   'ngawal',
#   'presiden'],
#  ['teu',
#   'make',
#   'duit',
#   'mah',
#   'rek',
#   'aya',
#   'anu',
#   'peduli',
#   'kumaha',
#   'atuh',
#   'kang�',
#   'sing',
#   'sadar',
#   'weh',
#   'ayeunamah',
#   'urang',
#   'hirup',
#   'di',
#   'nagara',
#   'kos',
#   'kumaha�'],
#  ['kelihatannya',
#   'semua',
#   'tanahnya�',
#   'sudah',
#   'ber',
#   'sertifikat',
#   'kenapa',
#   'tidak',
#   'di',
#   'pertanyakan',
#   'ke',
#   'badan',
#   'pertanahan',
#   'seharusnya',
#   'tidak',
#   'ada',
#   'penerbitan',
#   'sertifikat',
#   'tanpa',
#   'ada',
#   'jalan',
#   'melalui',
#   'tanah',
#   'tersebut',
#   'kalo',
#   'tidak',
#   'ada',
#   'tanggapan',
#   'dari',
#   'bpn',
#   'maka',
#   'ajukan',
#   'gugatan',
#   'ke',
#   'ptun',
#   'dimana',
#   'bpn',
#   'sebagai',
#   'tergugat',
#   '1'],
#  ['harusnya',
#   'waktu',
#   'dikejar',
#   'nyerahin',
#   'diri',
#   'aja',
#   'biar',
#   'pak',
#   'jokowi',
#   'tau',
#   'masalahnya',
#   'tapi',
#   'kenapa',
#   'bapak',
#   'lari',
#   'sih',
#   'itu',
#   'kesempatan',
#   'emas',
#   'padahal',
#   'pak'],
#  ['pemerintah', 'bandung', 'gak', 'becus', 'kerja'],
#  ['ya', 'iyalah', 'maen', 'lempar', 'aja�'],
#  ['sebenarnya',
#   'masalahnya',
#   'apa',
#   'kenapa',
#   'tidak',
#   'ada',
#   'penyelesaian',
#   'mana',
#   'bupati',
#   'bandung',
#   'kenapa',
#   'diam',
#   'diam',
#   'saja',
#   'minta',
#   'dipecat',
#   ''],
#  ['coba',
#   'diselesaikan',
#   'secara',
#   'kekeluargaan',
#   'dg',
#   'hati',
#   'dingin',
#   'tanpa',
#   'erosi',
#   'insyaallah',
#   'ketemu',
#   'jalanyaud83dude0e'],
#  ['aneh',
#   'segitu',
#   'egoisnya',
#   'kah',
#   'paravtetangga',
#   'rt',
#   'rw',
#   'sama',
#   'lurah',
#   'gak',
#   'bisa',
#   'tangani',
#   'kah',
#   'mudah2an',
#   'masalah',
#   'ini',
#   'nyampr',
#   'ke',
#   'jokowi',
#   'biar',
#   'masalah',
#   'selesai',
#   'sebenarnya',
#   'masalah',
#   'kyk',
#   'gini',
#   'bukan',
#   'urusan',
#   'presiden',
#   'karena',
#   'nyangkut2',
#   'urusan',
#   'paspampres',
#   'atau',
#   'oknum',
#   'yg',
#   'ngaku2',
#   'paspampres',
#   'jadi',
#   'gak',
#   'ada',
#   'salahnya',
#   'pak',
#   'jokowi',
#   'bantu',
#   'selesaikan',
#   'masalah'],
#  ['sepertinya',
#   'dua',
#   'pihak�',
#   'awal',
#   'nya',
#   'sama2',
#   'kepala',
#   'batu',
#   'sehingga',
#   'kejadian',
#   'seperti',
#   'itu',
#   'akhirnya'],
#  ['kok',
#   'bisa',
#   'bangun',
#   'rumah',
#   'tp',
#   'akses',
#   'ke',
#   'jalan',
#   'nya',
#   'ga',
#   'ada',
#   'pasti',
#   'ga',
#   'ada',
#   'imb',
#   'nya',
#   'yaaa'],
#  ['tetangga', 'gila'],
#  ['jual', 'aja', 'rmhnya', 'pa', 'gitu', 'aja', 'repot'],
#  ['gimana',
#   'mau',
#   'nuntut',
#   'hak',
#   'bukan',
#   'tanah',
#   'nya',
#   'kok',
#   'yg',
#   'di',
#   'sekitar',
#   'nya',
#   'sdh',
#   'tau',
#   'dari',
#   'dulu',
#   'sehrsnya',
#   'jual',
#   'pindah',
#   'dong'],
#  ['apesstressnasib', 'orang', 'kecil'],
#  ['gambar',
#   'lokasi',
#   'bangunan',
#   'beserta',
# ...
#   'dan',
#   'jasa',
#   'pak',
#   'maruf',
#   'hrusnya',
#   'sby',
#   'mndukung',
#   'dan',
#   'mngusungnya',
#   'tpi',
#   'karena',
#   'udh',
#   'kplang',
#   'baper',
#   'dan',
#   'udh',
#   'kplang',
#   'janji',
#   'sama',
#   'prabowo',
#   'walau',
#   'berat',
#   'hati',
#   'ya',
#   'mau',
#   'gk',
#   'mau',
#   'mngusung',
#   'prabowo'],
#  ['ketum', 'demokrat', 'sdh', 'kagak', 'ada', 'giginya'],
#  ['nafsu', 'berkuasa', 'ya', 'hahaha'],
#  ['jelas',
#   'bisa',
#   'dimengerti',
#   'rakyat',
#   'papua',
#   'merasakan',
#   'sekali',
#   'apa',
#   'yg',
#   'sdh',
#   'dilakukan',
#   'pres',
#   'jokowi',
#   'disanaprinsip',
#   'keadilan',
#   'nyata',
#   'dilakukan',
#   'bukan',
#   'sekedar',
#   'jargon',
#   'politik',
#   '2019orangbaikhasilnyabaik'],
#  ['ngomong',
#   'ngak',
#   'kuat',
#   'krn',
#   'kardus',
#   'sdh',
#   'di',
#   'embat',
#   'kelakuan',
#   'politisi',
#   'sontoloyo'],
#  ['coba',
#   'pendapat',
#   'bapak',
#   'ini',
#   'disampaikan',
#   'ke',
#   'junjungan',
#   'bapakar',
#   'supaya',
#   'gak',
#   'nyinyirkata',
#   'beliau',
#   'gak',
#   'mungkin'],
#  ['ibarat',
#   'bangunan',
#   'mewah',
#   'koalisi',
#   'ini',
#   'sebenarnya',
#   'kropos',
#   'dan',
#   'rapuhgmn',
#   'mau',
#   'mau',
#   'menang',
#   'ini',
#   'ngurus',
#   'intern',
#   'koalisi',
#   'iji',
#   'aja',
#   'ga',
#   'bisahidup',
#   'jkw',
#   '2',
#   'periode'],
#  ['hahahahaseru',
#   'nehmantap',
#   'masa',
#   'pks',
#   'dan',
#   'pan',
#   'aja',
#   'yg',
#   'dapat',
#   'sikatlah',
#   'pd',
#   'jgn',
#   'mau',
#   'dibohongi',
#   'sama',
#   'gerindra',
#   'pks',
#   'dan',
#   'panhahaha'],
#  ['hajar',
#   'bleh',
#   'sikat',
#   'terus',
#   'masa',
#   'cuma',
#   'mereka',
#   'doang',
#   'yang',
#   'dapat',
#   'kardus',
#   'pd',
#   'engga',
#   'ayo',
#   'jangan',
#   'mau',
#   'tuntut',
#   'juga',
#   'bagian',
#   'kardusmu�'],
#  ['koalisi',
#   'gak',
#   'mutupercuma',
#   'lo',
#   'pada',
#   'eker2nyungsep',
#   'lo',
#   'semua'],
#  ['mau',
#   'menuding',
#   'dua',
#   'atau',
#   'tiga',
#   'kaki',
#   'juga',
#   'gamasalah',
#   'bosyg',
#   'penting',
#   'pks',
#   'sudah',
#   'dapat',
#   '500',
#   'mberarti',
#   'pertahun',
#   '100mlumayan',
#   'kan',
#   'coba',
#   'klw',
#   'ngandalkan',
#   'dari',
#   'hasil',
#   'korupsi',
#   'atau',
#   'pemberian',
#   'jangan2',
#   'di',
#   'ott',
#   'sama',
#   'kpk',
#   'ahirnya',
#   'gigit',
#   'jari',
#   'donk',
#   'klw',
#   'ini',
#   'kan',
#   'barter',
#   'meskipun',
#   'nantinya',
#   'kalah',
#   '',
#   'pasti',
#   'kalah',
#   'dlm',
#   'pilpres',
#   'gamasalah',
#   'yg',
#   'rugi',
#   'kan',
#   'bukan',
#   'pks',
#   'atau',
#   'pan',
#   'paham',
#   'kan',
#   'sekarangyg',
#   'penting',
#   'duitnya',
#   'gerindra',
#   'sdh',
#   'keluar',
#   '',
#   'klw',
#   'ada',
#   'bahasa',
#   'untuk',
#   'kampanye',
#   'itu',
#   'kan',
#   'cuma',
#   'alasan',
#   'saja',
#   'biar',
#   'garibut'],
#  ['yahh',
#   'kenyataannya',
#   'semuanya',
#   'main',
#   '2',
#   'kaki',
#   'dan',
#   'oportunis',
#   'mau',
#   'apa',
#   'lagi'],
#  ['andi',
#   'juga',
#   'aneh',
#   'pake',
#   'ngomong',
#   'udah',
#   'jelas',
#   'parte',
#   'kemunafikan',
#   'sejati',
#   'cebong',
#   'kejet2',
#   'gagal',
#   'mupe',
#   'on'],
#  ['yah', 'apakah', 'masih', 'percaya', 'dengan', 'omomgannya�'],
#  ['kalau', 'panas', 'dalam', 'minum', 'tuh', 'kaki', '3', 'biar', 'ademhehe'],
#  ['ketua', 'diam', '', 'bisa', 'dianggap', 'seruju'],
#  ['udaah',
#   'mending',
#   'bubar',
#   'aja',
#   'niih',
#   'koalisi',
#   'ga',
#   'bermutubukanya',
#   'bikin',
#   'program',
#   'malah',
#   'ribut',
#   'sendiri',
#   'mendiing',
#   'bubar',
#   'lagian',
#   'sdh',
#   'pasti',
#   'kalah',
#   'kok',
#   'ngapain',
#   'd',
#   'lanjutkan�'],
#  ['haqulyakin',
#   'pekaes',
#   'dan',
#   'pante',
#   'nyungsep',
#   'suaranya',
#   'pemilu',
#   '2019�'],
#  ['koalisi', 'serapuh', 'kardus', 'basah'],
#  ['andi',
#   'arief',
#   'yg',
#   'selalu',
#   'menyerang',
#   'koalisi',
#   'sendiri',
#   'ini',
#   'kenapa',
#   'tdk',
#   'ditegur',
#   'sby',
#   'ada',
#   'apa',
#   'di',
#   'koalisi',
#   'prabowo',
#   'sandiaga',
#   '',
#   'padahal',
#   'bersikap',
#   'pura2',
#   'netral',
#   'di',
#   'pilpres',
#   '2014',
#   'sama',
#   'juga',
#   'bermain',
#   '2',
#   'kaki',
#   'pak',
#   'andi'],
#  ['dulu',
#   'mencari',
#   'makan',
#   'setelah',
#   'menjabat',
#   'jadi',
#   'kaya2',
#   'bahkan',
#   'daging',
#   'juga',
#   'di',
#   'empat',
#   'penjara',
#   'dan',
#   'akhirnya',
#   'neraka'],
#  ['nah', 'lu', 'kena', 'deh'],
#  ['kardus', 'kardus', 'kardusmana', 'bagian', 'kardusku'],
#  ['politik', 'cari', 'makan', 'alias', 'parpol', 'kardus'],
#  ['dia', 'minta', 'isi', 'kardus', 'tu'],
#  ['badut',
#   'badut',
#   'politikkerja',
#   'nolll',
#   'buat',
#   'rakyatnyir',
#   'nyir',
#   'bocor',
#   'coorrrrrrr'],
#  ['u2063jokowi',
#   'menang',
#   'mudah',
#   'di',
#   'pilpres',
#   '2019',
#   'democraaat',
#   'nyungsep'],
#  ['jokowi',
#   'menang',
#   'mudah',
#   'di',
#   'pilpres',
#   '2019',
#   'democraaat',
#   'nyungsep'],
#  ['lebih', 'bagus', 'cap', 'kaki', 'tigabisa', 'buat', 'kesehatan'],
#  ['kaki', 'empatud83dude07'],
#  ['salam', 'dua', 'kaki', 'euyhahaha'],
#  ['pak',
#   'sby',
#   'itu',
#   'kalau',
#   'ngomong',
#   'selalu',
#   'pinjam',
#   'banyak',
#   'moncong',
#   'mas',
#   'kayak',
#   'ban',
#   'bocor',
#   'alus',
#   'tapi',
#   'kelilingud83dude03',
#   'baru',
#   'lahir',
#   'ya'],
#  ['kl',
#   'sudah',
#   'berdasarkan',
#   'data',
#   'dan',
#   'fakta',
#   'ya',
#   'susah',
#   'untuk',
#   'dijawab',
#   'hahahaha'],
#  ['setdeh',
#   'kho',
#   'seneng',
#   'banget�',
#   'ribut',
#   'sich',
#   'rebutan',
#   'apa',
#   'lagi',
#   'nech',
#   'engingeng',
#   'datang',
#   'zonk',
#   'ah',
#   'nggak',
#   'papa',
#   'masih',
#   'solid',
#   'kho',
#   'itu',
#   'hanya',
#   'dinamika',
#   'politikcapek',
#   'dech'],
#  ['sesama', 'begundal', 'politik', 'dilarang', 'saling', 'mendahului', ''],
#  ['karena',
#   'aa',
#   'pakai',
#   'data',
#   'dan',
#   'fakta',
#   'maka',
#   'tidak',
#   'bisa',
#   'berbalas',
#   'pantun'],
#  ['pan', '', 'pks', 'sebaiknya', 'diam', 'klo', 'ga', 'punya', 'kaca�'],
#  ['koalisi',
#   'aja',
#   'ribut',
#   'gimana',
#   'mau',
#   'menang',
#   'jargon',
#   'doang',
#   'kenceng',
#   'kualitas',
#   'nol'],
#  ['mari',
#   'kita',
#   'bertepuk',
#   'tangansesama',
#   'begundal',
#   'sdh',
#   'mulai',
#   'ribut'],
#  ['kayaknya',
#   'bener',
#   'juga�',
#   'dulu',
#   'kan',
#   'koalisi',
#   'demokrat',
#   'tp',
#   'sering',
#   'gak',
#   'nurut'],
#  ['diam', 'itu', 'emas'],
#  ['lah',
#   'ngapain',
#   'jg',
#   'ribut2',
#   'politik',
#   'pilkada',
#   'kemaren',
#   'jg',
#   'banyak',
#   'koalisi',
#   'ngacak',
#   'politik',
#   'disini',
#   'ya',
#   'gt',
#   'cari',
#   'sensasi',
#   'doang'],
#  ['bukan',
#   '2',
#   'kaki',
#   'itu',
#   'mah',
#   'yg',
#   'kita',
#   'tahu',
#   '',
#   'tapi',
#   '4',
#   'kaki',
#   '',
#   '2',
#   'kaki',
#   'yg',
#   'sah',
#   '',
#   '2',
#   'kaki',
#   'yg',
#   'siri',
#   'kan',
#   ''],
#  ['main',
#   'dua',
#   'kaki',
#   'saat',
#   'pemilu',
#   'sudah',
#   'usai�',
#   'bargain',
#   'dan',
#   'kompromi',
#   'lah',
#   'ini',
#   'baru',
#   'mau',
#   'mulai',
#   'haha',
#   'cerdas',
#   'dong',
#   'kamu',
#   'dek�'],
#  ['pd',
#   'pan',
#   'pks',
#   'semua',
#   'ahli',
#   'main',
#   '2',
#   'kaki',
#   'cuman',
#   'gerindra',
#   'yg',
#   'ga',
#   'punya',
#   'kaki'],
#  ['andi', 'arief', 'dicari', 'bawaslu', 'tuh'],
#  ['abis',
#   'mau',
#   'bagemana',
#   'lagi',
#   'ga',
#   'mau',
#   'rugi',
#   'maunya',
#   'untung',
#   'terus'],
#  ['bertiga', 'saling', 'selingkuh'],
#  ['andi',
#   'arief',
#   'ini',
#   'awalnya',
#   'mencak2',
#   'teriak2',
#   'terkait',
#   'dana',
#   'logistik',
#   '500m',
#   'untuk',
#   'kubu',
#   'koalisi',
#   'prabowo',
#   'karena',
#   'demokrat',
#   'tdk',
#   'di',
#   'ajak',
#   'bicara',
#   'sekarang',
#   'diem',
#   'dia',
#   'di',
#   'amankan',
#   'oleh',
#   'sandi',
#   'wajar',
#   'andi',
#   'arief',
#   'ini',
#   'ngebela',
#   'demokrat',
#   'dan',
#   'sby'],
#  ['tepatnya', 'pan', 'dan', 'pks', 'tergantung', 'bayaran'],
#  ['satu',
#   'koalisi',
#   'aja',
#   'udah',
#   'gak',
#   'kompak',
#   'gmn',
#   'mau',
#   'menang',
#   'udah',
#   'pd',
#   'jgn',
#   'ribut',
#   'nikmatin',
#   'aja',
#   'dl',
#   'kardus2nya',
#   'mudah2',
#   'anjlog',
#   'hancura',
#   'suara',
#   'kalian',
#   'di',
#   'pemilu',
#   '2019'],
#  ['salut',
#   'buat',
#   'timses',
#   'padi',
#   'dinamika',
#   'adalah',
#   'keharusan',
#   'dlm',
#   'sebuah',
#   'perjuangan',
#   'politik',
#   'ada',
#   'perbedaan',
#   'pendapat',
#   'kritik',
#   'juga',
#   'wajar2',
#   'saja',
#   'solid',
#   'gak',
#   'perlu',
#   'harus',
#   'yes',
#   'semua',
#   'diam',
#   'seribu',
#   'bahasa',
#   'spt',
#   'dikekang',
#   '',
#   'satu',
#   'suara',
#   'seperti',
#   'koalisi',
#   'jokowi',
#   'yg',
#   'ujung2nya',
#   'melampiaskan',
#   'uneg2',
#   'dgn',
#   'menyerang',
#   'koalisi',
#   'lawanberbeda',
#   'suara',
#   'bukan',
#   'masalah',
#   'tapi',
#   'saling',
#   'menghargai',
#   'harus',
#   'dijaga',
#   '',
#   'dekati',
#   'terus',
#   'rakyat',
#   'krn',
#   'rakyatlah',
#   'yg',
#   'menentukan',
#   'kemenangan',
#   'di',
#   'pilpres',
#   'nanti'],
#  ['hajar'],
#  ['percaya',
#   'dehklo',
#   'jokowi',
#   'menang',
#   'lgpan',
#   'akan',
#   'merapat',
#   'ke',
#   'jokowi',
#   'lg',
#   'supaya',
#   'dpt',
#   'mentri',
#   'lgkan',
#   'kmpren',
#   'brgitu'],
#  ['pd',
#   'maen',
#   'dua',
#   'kaki',
#   'di',
#   'parlemen',
#   'seabis',
#   'pilpres',
#   'katenye',
#   'netral',
#   'tapi',
#   'condong',
#   'ke',
#   'kmp'],
#  ['kelompok', 'sebelah', 'pemain', '2', 'kaki', 'semua', 'wkwkwkwk'],
#  ['andi', 'arif', 'buang', 'aja', 'bikin', 'rusuh', 'aja'],
#  ['ayo', 'bertengkar', 'lah', 'aku', 'suka', 'hahaha'],
#  ['andi', 'arif', 'knp', 'yam'],
#  ['jadi', 'penonton', 'ah', 'menghibur�'],
#  ['ular',
#   'beludak',
#   'ini',
#   'keluar',
#   'lagi',
#   'setelah',
#   'mumpet',
#   'terkencing2',
#   'tdk',
#   'berani',
#   'bicara',
#   'di',
#   'dpn',
#   'bawaslu',
#   'ud83dude03'],
#  ['sudah',
#   'tahu',
#   'bahwa',
#   'kalau',
#   'berkata',
#   'bohong',
#   '',
#   'tidak',
#   'sesuai',
#   'omongan',
#   'kalau',
#   'janji',
#   'ingkar',
#   '',
#   'plinplan',
#   'kalau',
#   'dipercaya',
#   'ingkar',
#   'tidak',
#   'konsisten',
#   'tahu',
#   'munafik',
#   'kok',
#   'seteju',
#   'yg',
#   'waras',
#   'siapa',
#   'ya'],
#  ['u2063pertempuran',
#   'utama',
#   'di',
#   'pilpres',
#   '2019',
#   'ialah',
#   'jawa',
#   'barat',
#   'jawa',
#   'tengah',
#   'jawa',
#   'timur',
#   'sumatera',
#   'utara',
#   'dan',
#   'sulawesi',
#   'selatan',
#   'jawa',
#   'tengah',
#   'jelas',
#   'sudah',
#   'dijaga',
#   'ganjar',
#   'jawa',
#   'timur',
#   'ada',
#   'mbak',
#   'khofifah',
#   'jawa',
#   'barat',
#   'kemungkinan',
#   'dengan',
#   'naiknya',
#   'rk',
#   'jokowi',
#   'bakal',
#   'menang',
#   'sulawesi',
#   'selatan',
#   'pasti',
#   'ada',
#   'efek',
#   'dari',
#   'jk',
#   'sebagai',
#   'timses',
#   'jokowi',
#   'hanya',
#   'sumatera',
#   'utara',
#   'yang',
#   'masih',
#   'bisa',
#   'diperebutkan',
#   'oleh',
#   'kedua',
#   'koalisi'],
#  ['aduhorang',
#   '',
#   'orang',
#   'jangan',
#   'di',
#   'pilih',
#   'biar',
#   'negiri',
#   'ini',
#   'tidak',
#   'segera',
#   'bubar'],
#  ['belah', 'sono', 'ribut', 'terus', 'y'],
#  ['mungkin', 'sedang', 'panas', 'dalam', 'nambah', 'satu', 'kaki', 'lagi'],
#  ['kalo',
#   'pks',
#   'mah',
#   'emang',
#   'ga',
#   'ada',
#   'malunya',
#   'ikut',
#   'kabinet',
#   'sby',
#   'tapi',
#   'ngacak2',
#   'program',
#   'sbypresiennya',
#   'aja',
#   'sampe',
#   'makan',
#   'aspal',
#   'di',
#   'jalan',
#   'nangka',
#   'noh'],
#  ['ada', 'hubungannya', 'dengan', 'kardus', 'ga', 'nih', ''],
#  ['maling',
#   'teriak',
#   'maling',
#   'koalisi',
#   'kok',
#   'saling',
#   'menjelekkan',
#   'ud83dude02'],
#  ['bagus', 'bro', 'hajar', 'terussss', ''],
#  ['apa',
#   'yang',
#   'diungkapkan',
#   'bung',
#   'andi',
#   'arif',
#   'benar',
#   'sekali',
#   'kita',
#   'masih',
#   'ingat',
#   'waktu�',
#   'pks',
#   'ikut',
#   'dalam',
#   'kabinet',
#   'pak',
#   'sby',
#   'tapi',
#   'apabila',
#   'ada',
#   'kebijakan',
#   'dari',
#   'sby',
#   'selalu',
#   'ditentang'],
#  ['ni',
#   'orang',
#   'dri',
#   'awal',
#   'udh',
#   'mulai',
#   'ribet',
#   'sebaik',
#   'nya',
#   'klo',
#   'memang',
#   'gk',
#   'searah',
#   'pecat',
#   'ni',
#   'pa',
#   'sby�'],
#  ['pd',
#   'bubar',
#   'ajalah',
#   'uda',
#   'gak',
#   'ada',
#   'wibawa',
#   'di',
#   'mata',
#   'kadernya',
#   'apa',
#   'karena',
#   'ketumnya',
#   'gak',
#   'tegas',
#   'atau',
#   'mgkn',
#   'hal',
#   'yg',
#   'sengaja',
#   'dibuat',
#   'utk',
#   'main',
#   'dua',
#   'kaki',
#   'alias',
#   'mempraktekan',
#   'politik',
#   'bermuka',
#   'dua�'],
#  ['lo',
#   'pade',
#   'ngomong',
#   'ngaler',
#   'ngidul',
#   'ga',
#   'jelas',
#   '',
#   'bangsa',
#   'ini',
#   'banyak',
#   'masalah',
#   'perburuhan',
#   'ekonomi',
#   'problem',
#   'kebangsaan',
#   'benturan',
#   'umat',
#   'dll',
#   'perlu',
#   'strong',
#   'leader',
#   '',
#   'pas',
#   'ok',
#   ''],
#  ['gawatttt',
#   'harusnya',
#   'pak',
#   'prabowo',
#   'kirim',
#   'utusan',
#   'mautnya',
#   'kayak',
#   'ahmad',
#   'dhani',
#   'neno',
#   'sarumpaet',
#   'ke',
#   'papua',
#   'wkwkwk'],
#  ['kader2mya',
#   'pd',
#   'cerdas',
#   'juga',
#   'ga',
#   'mau',
#   'dijadikan',
#   'boneka',
#   'gerindrong',
#   'cs'],
#  ['yang',
#   'jelas',
#   'perolehan',
#   'suaran',
#   'jokowi',
#   '',
#   'maruf',
#   'amin',
#   'akan',
#   'bertambahud83dude06'],
#  ['kira2',
#   'kalau',
#   'di',
#   'adu',
#   'dari',
#   'sisi',
#   'intelektual',
#   'kecerdasan',
#   'kesederhanaan',
#   'kepemimpinan',
#   'kekayaan',
#   'dari',
#   '4',
#   'kandidat',
#   'capres',
#   '',
#   'cawapres',
#   'siapa',
#   'yg',
#   'menang',
#   'ya',
#   '',
#   'gampang',
#   '',
#   'sandi',
#   'yg',
#   'menang',
#   '',
#   'muda',
#   'kaya',
#   'pinter',
#   'cerdas',
#   'sederhana',
#   'dan',
#   'yg',
#   'paling',
#   'penting',
#   '',
#   'setia',
#   'sama',
#   'istri',
#   'dan',
#   'sayang',
#   'anak',
#   '',
#   'gila',
#   '',
#   'perfect',
#   'banget',
#   'sih',
#   'lo',
#   'sandi',
#   '',
#   'yg',
#   'lain',
#   'pada',
#   'main',
#   'bini',
#   'muda',
#   'sama',
#   'selingkuh',
#   '',
#   'lo',
#   'yg',
#   'duitnya',
#   'banyak',
#   'kok',
#   'malah',
#   'setia',
#   '',
#   'top'],
#  ['2019jokowipresiden'],
#  ['bagi',
#   '90',
#   'pengurus',
#   'dpd',
#   'demokrat',
#   'di',
#   'papua',
#   'ini',
#   'hati',
#   'nurani',
#   'mereka',
#   'lebih',
#   'punya',
#   'integritas',
#   'krn',
#   'mereka',
#   'tau',
#   'sesungguhnya',
#   'siapa',
#   'yg',
#   'selama',
#   'ini',
#   'bekerja',
#   'utk',
#   'warganya'],
#  ['rakyat',
#   'papua',
#   'tau',
#   'mana',
#   'presiden',
#   'yang',
#   'perhatian',
#   'dengan',
#   'papua',
#   'mana',
#   'yang',
#   'purapura',
#   'perhatian',
#   'btw',
#   'balikin',
#   'kardusnya',
#   'sandi'],
#  ['jati',
#   'diri',
#   'gak',
#   'pentinglah',
#   'yahyg',
#   'penting',
#   'menangklik',
#   'google',
#   'hambalang'],
#  ['emang',
#   'jokowi',
#   'masih',
#   'diinginkan',
#   'sebagian',
#   'besar',
#   'rakyat',
#   'untuk',
#   'menjadi',
#   'presiden',
#   '2',
#   'periode',
#   'kok'],
#  ['masalah',
#   'papua',
#   'itu',
#   'sangat',
#   'gampang',
#   'dan',
#   'malah',
#   'terlalu',
#   'gampang',
#   'merebut',
#   'suara',
#   'orang',
#   'papua',
#   'sbb',
#   'orang',
#   'papua',
#   'gak',
#   'denger',
#   'gubernur',
#   'asal',
#   'di',
#   'serahkan',
#   'sama',
#   'yg',
#   'ahli',
#   'nya',
#   'di',
#   'jamin',
#   '100',
#   'beresyg',
#   'jelas',
#   'bkn',
#   'masalah',
#   'infra',
#   'struktur',
#   'sbb',
#   'yg',
#   'menikmati',
#   'nya',
#   'tetap',
#   'pendatang',
#   'sdgkn',
#   'orang',
#   'asli',
#   'papua',
#   'ttp',
#   'jd',
#   'penontonserahkan',
#   'pada',
#   'ahli',
#   'nya',
#   'papua',
#   'pasti',
#   'prabowo',
#   'sandi'],
#  ['demokrat',
#   'seharusnya',
#   'join',
#   'dengan',
#   'jokowi',
#   'saja',
#   'tim',
#   'prabowo',
#   'sandi',
#   'ga',
#   'butuh',
#   'demokrat',
#   'cukup',
#   'masyarakatemak2gerindrapkspan',
#   'saja',
#   'sudah',
#   'pasti',
#   'menang',
#   'di',
#   '2019'],
#  ['woi',
#   'kembalikan',
#   'kardusnya',
#   'kalo',
#   'ga',
#   '100',
#   'dukung',
#   'wowowkwkwk'],
#  ['alhamdulillah', 'amin'],
#  ['sebaiknya',
#   'demokrat',
#   'ke',
#   'jokowi',
#   'saja',
#   'tdk',
#   'apa',
#   'apa',
#   'pks',
#   'pan',
#   'gerindra',
#   'sangat',
#   'solid'],
#  ['harusx',
#   'dpd',
#   'tdk',
#   'bisa',
#   'mengatur',
#   'dppkepututsan',
#   'dpp',
#   'harusx',
#   'satu',
#   'komandomiris',
#   'jg',
#   'ini'],
#  ['demokrat', 'plin', 'plan'],
#  ['karna',
#   'tdk',
#   'terbendung',
#   'suara',
#   'kader',
#   'yg',
#   'terbelah',
#   'berobah',
#   'strategi',
#   'demi',
#   'menutup',
#   'muka',
#   'yg',
#   'sudah',
#   'malukasihan',
#   'demokrat'],
#  ['100', 'paksoalnya', 'joko', 'wi', 'orang', 'baik', ''],
#  ['rakyat',
#   'papua',
#   'merasakan',
#   'langsung',
#   'pembangunan',
#   'era',
#   'presiden',
#   'jokowi�'],
#  ['hasil', 'akhirnya', 'dan', 'saya', 'yakin', 'jokowi', 'kalah', 'dipapua'],
#  ['bagus',
#   'jangan',
#   'ikut',
#   'orang',
#   'jahat',
#   'saudara2',
#   'papua',
#   'merasakan',
#   'pembangunan'],
#  ['apa', 'kata', 'gerinda', 'cs', 'ya', 'hayo', 'apa'],
#  ['karena', 'papu', 'maju'],
#  ['mbah', 'mien', 'langsung', 'kejangkejang'],
#  ['mereka',
#   'ini',
#   'yg',
#   'bener2',
#   'sdh',
#   'merasakan',
#   'langsung',
#   'dampak',
#   'pembangunan',
#   'jalan',
#   'dan',
#   'sebagainya',
#   'di',
#   'sana',
#   'tidak',
#   'bisa',
#   'ditutupi',
#   'dan',
#   'disangkal',
#   'lagi'],
#  ...]

# %%
#Filter dari invalid caracter
invalid = '�'
for i in range(0, len(tok_comments)):
    comment = tok_comments[i]
    for j in range(0, len(comment)):
        sub_comment = tok_comments[i][j]
        for k in sub_comment:
            if k in invalid:
                tok_comments[i][j] = tok_comments[i][j].replace(k, "")

# %%
tok_comments
# Out:
# [['wkwkwk',
#   'gak',
#   'sekalian',
#   'pak',
#   'selawat',
#   'ke',
#   'dpr',
#   'kan',
#   'banyak',
#   'koruptor',
#   'disana'],
#  ['mantab',
#   'ini',
#   'br',
#   'dakwah',
#   'yg',
#   'sejati',
#   'kl',
#   'd',
#   'tempat',
#   'umum',
#   'mah',
#   'dh',
#   'biasa',
#   '',
#   'ini',
#   'luar',
#   'biasa'],
#  ['salut', 'buat', 'gus', 'miftah'],
#  ['yg',
#   'nyinyir',
#   'gak',
#   'pernah',
#   'lihat',
#   'dan',
#   'baca',
#   'atw',
#   'mengetahui',
#   'sejarah',
#   'dakwah',
#   'walisongo',
#   '',
#   'sunan',
#   'kali',
#   'jagasmua',
#   'ada',
#   'cara',
#   'demi',
#   'kebaikan',
#   'asal',
#   'jng',
#   'ajk',
#   'dg',
#   'cara',
#   'berjinah',
#   '',
#   'lakukan',
#   'dg',
#   'porsi',
#   'dan',
#   'sikon',
#   'yg',
#   'tepat'],
#  ['ada',
#   'adabnya',
#   'sholawat',
#   'lebih',
#   'baik',
#   'ajak',
#   'ke',
#   'majelis',
#   'ilmu'],
#  ['setiap',
#   'ulama',
#   'punya',
#   'jalan',
#   'dan',
#   'cara',
#   'dakwah',
#   'masing2',
#   'jika',
#   'kamu',
#   'melihat',
#   'kemunkaran',
#   'lawan',
#   'dengan',
#   'tanganmukekuatanmu',
#   'jika',
#   'tidak',
#   'mampu',
#   'lawan',
#   'dengan',
#   'mulutmu',
#   'jika',
#   'tidak',
#   'mampu',
#   'juga',
#   'dengan',
#   'hatimu',
#   'itulah',
#   'selemah',
#   'lemahnya',
#   'iman',
#   'itu',
#   'sudah',
#   'menjadi',
#   'kewajiban',
#   'para',
#   'ulama',
#   'kalo',
#   'yg',
#   'komen',
#   'masih',
#   'ada',
#   'yg',
#   'nyinyirin',
#   'ulama',
#   'berarti',
#   'otaknya',
#   'sudah',
#   'disisipin',
#   'politik'],
#  ['umpanin', 'nocannya', 'yak'],
#  ['itulah', 'ceramah', 'yg', 'sebenarnya'],
#  ['besok', 'bugil', 'aja', 'selawat'],
#  ['bedanya',
#   'gus',
#   'miftah',
#   'dengan',
#   'fpi',
#   '',
#   'hti',
#   'bagaikan',
#   'surga',
#   'dan',
#   'neraka',
#   'di',
#   'surga',
#   'penuh',
#   'kasih',
#   'di',
#   'neraka',
#   'penuh',
#   'penghancuran'],
#  ['knp',
#   'di',
#   'tempat',
#   'kerjanya',
#   'mending',
#   'diundang',
#   'ke',
#   'masjid',
#   'ponpes',
#   'aula',
#   'supaya',
#   'berbusana',
#   'yg',
#   'sopan'],
#  ['nah',
#   'ini',
#   'ulama',
#   'beneranditerima',
#   'di',
#   'semua',
#   'kalangankl',
#   'uas',
#   'malah',
#   'diblokir',
#   'sana',
#   'sini'],
#  ['kerennn',
#   'saya',
#   'pernah',
#   'dpt',
#   'info',
#   'seperti',
#   'ini',
#   'dr',
#   'keyakinan',
#   'yg',
#   'lain',
#   'tapi',
#   'tujuan',
#   'utama',
#   'kurang',
#   'lebih',
#   'sama',
#   'lah',
#   'kita',
#   'ambil',
#   'sisi',
#   'positifnya',
#   'ajah',
#   'terimakasih',
#   'atas',
#   'niat',
#   'baiknya',
#   'saya',
#   'yakin',
#   'pasti',
#   'bermanfaat'],
#  ['hebat',
#   'guslanjutkaninilah',
#   'makna',
#   'dakwah',
#   'sebenarnya',
#   'sampaikan',
#   'marwah',
#   'islam',
#   'dengan',
#   'penuh',
#   'kedamaian',
#   'dan',
#   'berikan',
#   'pemahaman',
#   'bukan',
#   'dengan',
#   'kebencian',
#   'dan',
#   'pemaksaan'],
#  ['diskotik', 'syariah', 'jadunya', 'nih', 'wkwkwkmantap'],
#  ['niat',
#   'dan',
#   'tujuan',
#   'yg',
#   'baik',
#   'pasti',
#   'mendapat',
#   'berkah',
#   'dr',
#   'allah',
#   'swt'],
#  ['mantaaappppbuat', 'di', 'gedung', 'dpr', 'perlu', 'jg', 'kayanya', 'gus'],
#  ['salut', 'buat', 'owner', 'klub', 'ini'],
#  ['josshhh', 'ini', 'baru', 'luar', 'biasa'],
#  ['dapat', 'gratisan', 'karena', 'sudah', 'punya', 'nope'],
#  ['sebaiknya',
#   'dimanapun',
#   'dilakukan',
#   'batas2',
#   'kesopanan',
#   'tetap',
#   'harus',
#   'dijaga'],
#  ['pemandu',
#   'lagi',
#   'yang',
#   'di',
#   'manga',
#   'besar',
#   'keknya',
#   'perlu',
#   'juga',
#   'diajak',
#   'mengaji',
#   'bos'],
#  ['jujur',
#   'ini',
#   'kereennnnnnn',
#   'cara',
#   'menyebarkan',
#   'agama',
#   'yang',
#   'baik',
#   'dan',
#   'snagat',
#   'simpatik',
#   'semoga',
#   'sukses'],
#  ['katimbang',
#   'alim',
#   'kemudian',
#   'jadi',
#   'maling',
#   'menurut',
#   'saya',
#   'lebih',
#   'baik',
#   'maling',
#   'kemudian',
#   'jadi',
#   'alim',
#   ''],
#  ['sebenar',
#   'ulama',
#   'mengajak',
#   'mereka',
#   'yg',
#   'masih',
#   'tersesat',
#   'untuk',
#   'kembali',
#   'bukan',
#   'menjelekkan',
#   'orang',
#   'lain',
#   'tp',
#   'merangkul',
#   'mereka'],
#  ['ini', 'namanya', 'apa', 'ya'],
#  ['selamat',
#   'berjuang',
#   'gusjustru',
#   'tempat',
#   'seperti',
#   'itu',
#   'yg',
#   'butuh',
#   'lebih',
#   'bnyk',
#   'perhatian',
#   'dr',
#   'ulama'],
#  ['semoga', 'diberikan', 'hidayah'],
#  ['hati',
#   'hati',
#   'memviralkan',
#   'berita',
#   'yang',
#   'mengandung',
#   'isu',
#   'agama',
#   'bisa',
#   'menjadi',
#   'sumber',
#   'fitnah',
#   'dan',
#   'lahan',
#   'para',
#   'bedebah',
#   'yang',
#   'kerjanya',
#   'mengadu',
#   'domba',
#   'anak',
#   'bangsa',
#   'dan',
#   'rakyat',
#   'indonesia',
#   'ahok',
#   'sudah',
#   'jadi',
#   'korbannya'],
#  ['subhanallah',
#   'semoga',
#   'mendapatkan',
#   'hidayah',
#   'dari',
#   'allah',
#   'swt',
#   'amin'],
#  ['ulama', 'ngurus', 'umat', 'berarti', 'jenengan', 'gus'],
#  ['luar',
#   'biasa',
#   'salutterharu',
#   'mengajak',
#   'orang',
#   'lain',
#   'yang',
#   'dianggap',
#   'salah',
#   'dengan',
#   'cara',
#   'yang',
#   'baik',
#   'bukan',
#   'dengan',
#   'cacianluar',
#   'biasa'],
#  ['whats', 'up', 'boshe'],
#  ['lol',
#   'jadi',
#   'ketahuan',
#   'dong',
#   'isinya',
#   'boshe',
#   'bali',
#   'bukan',
#   'org',
#   'bali',
#   'ud83dude02ud83dude02'],
#  ['poligami', 'aja', 'guss'],
#  ['harusnya', 'dibakar', 'tempat', 'begituan', 'kalik'],
#  ['hahahaha',
#   'bahasa',
#   'hastag',
#   'y',
#   'kalo',
#   'd',
#   'plesetkan',
#   'jadi',
#   'y',
#   'santri',
#   'gaul',
#   'itu',
#   'yg',
#   'suka',
#   'sholawat',
#   'dan',
#   'suka',
#   'dugem',
#   'hahahaha',
#   'rusak',
#   'islam',
#   'd',
#   'biaskan',
#   'seperti',
#   'ini',
#   'ustad',
#   'y',
#   'dateng',
#   'k',
#   'sono',
#   'dugem',
#   'dulu',
#   'lalu',
#   'sholawat',
#   'lalu',
#   'dugem',
#   'lagi',
#   'dan',
#   'd',
#   'sebut',
#   'santri',
#   'gaul'],
#  ['knp',
#   'yg',
#   'kayak',
#   'gini',
#   'berita',
#   'nya',
#   'keluar',
#   'nya',
#   'pas',
#   'mau',
#   'pilpres',
#   'aja',
#   'ya'],
#  ['naaaah',
#   'ini',
#   'baru',
#   'bener',
#   'ceramah',
#   'atau',
#   'ngajak',
#   'orang',
#   'yg',
#   'belum',
#   'bersholawat',
#   'utk',
#   'bersholawat',
#   'ga',
#   'kaya',
#   'somat',
#   'ngajak',
#   'orang',
#   'sholawat',
#   'koq',
#   'ke',
#   'orang',
#   'yg',
#   'udah',
#   'bersholawat',
#   'maaaaat',
#   'mat'],
#  ['gila',
#   'nekat',
#   'juga',
#   'ulamanya',
#   'gak',
#   'tau',
#   'di',
#   'usir',
#   'gitu',
#   'tapi',
#   'bagus',
#   'lah',
#   'ada',
#   'keberanian',
#   'dan',
#   'semuanya',
#   'jg',
#   'mendengarkan',
#   'semoga',
#   'banyak',
#   'ustad',
#   'lainnya',
#   'yang',
#   'meniru',
#   'hal',
#   'ini'],
#  ['tambah',
#   'tempat',
#   'mantap',
#   'sak',
#   'cewek',
#   'seksi',
#   'nyadan',
#   'yg',
#   'paling',
#   'penting',
#   'bole',
#   'yg',
#   'g',
#   'setuju',
#   'pasti',
#   'ngiriweek'],
#  ['mengajak',
#   'orang',
#   'melakukan',
#   'sholawat',
#   'di',
#   'tempat',
#   'ibadah',
#   'ya',
#   'sudah',
#   'pasti',
#   'mudah',
#   'tapi',
#   'mengajak',
#   'orang',
#   'melakukan',
#   'sholawat',
#   'di',
#   'tempat',
#   'dugem',
#   'yang',
#   'penuh',
#   'cobaan',
#   'itu',
#   'sudah',
#   'jelas',
#   'pahala',
#   'nya',
#   'jauh',
#   'lebih',
#   'besar'],
#  ['apa',
#   'sih',
#   'yg',
#   'nggak',
#   'bisa',
#   'di',
#   'negeri',
#   'ini',
#   'semua',
#   'pada',
#   'bisa',
#   'sekrang'],
#  ['boleh', 'ya', 'menyebarkan', 'agama', 'seperti', 'ini'],
#  ['hahahaha', 'lucu', 'lucuan', 'biar', 'masuk', 'tipi', 'laah', 'hahaha'],
#  ['coba',
#   'lah',
#   'ustad',
#   'yg',
#   'lain',
#   'dakwah',
#   'di',
#   'nite',
#   'club',
#   'spt',
#   'iti'],
#  ['yang',
#   'ini',
#   'malah',
#   'di',
#   'dukung',
#   'yang',
#   'di',
#   'sana',
#   'di',
#   'jagain',
#   'supaya',
#   'ga',
#   'ceramah',
#   'apalagi',
#   'ini'],
#  ['ah',
#   'entahlah',
#   'satu',
#   'kau',
#   'maklumi',
#   'yg',
#   'lain',
#   'mengikuti',
#   'tinggal',
#   'tunggu',
#   'saja'],
#  ['mau', 'ngikik', 'takut', 'dosa'],
#  ['kalau',
#   'mau',
#   'melakukan',
#   'ibadah',
#   'perbaiki',
#   'dulu',
#   'penampilan',
#   'jauhi',
#   'miras',
#   'cari',
#   'tempat',
#   'yg',
#   'lebih',
#   'baik',
#   'lebih',
#   'baik',
#   'gus',
#   'kamu',
#   'mengajak',
#   'para',
#   'wanita',
#   'itu',
#   'menutupi',
#   'auratnya'],
#  ['lokalisasi', 'harapan', 'sadar'],
#  ['setelah', 'selawat', 'selesai', 'acara', 'selanjutnya', ''],
#  ['bagus', 'lanjutkan'],
#  ['bagus',
#   'itu',
#   'biar',
#   'sadar',
#   'islam',
#   'tdk',
#   'mengajari',
#   'kaumnya',
#   'buka',
#   'aurat',
#   'bagus',
#   'lanjut'],
#  ['banser', 'anshor', 'mana', 'suaranyaormas', 'liberal'],
#  ['pans',
#   'itu',
#   'ketika',
#   'simbah',
#   'yg',
#   'bicara',
#   'selalu',
#   'dibully',
#   'karena',
#   'kata',
#   'katanya',
#   'terkesan',
#   'emosional',
#   'nantang',
#   'nantang',
#   'pdhl',
#   'ketika',
#   'tantangan',
#   'bisa',
#   'di',
#   'buktikan',
#   'oleh',
#   'yg',
#   'di',
#   'tantang',
#   'trus',
#   'diem',
#   'tdk',
#   'ksatria',
#   'ngakui',
#   'dan',
#   'sering',
#   'menjelek',
#   'jelekkan',
#   'orang',
#   'lain',
#   'inilah',
#   'yg',
#   'jd',
#   'penyebab',
#   'sering',
#   'di',
#   'bully',
#   'dan',
#   'orang',
#   'lain',
#   'jd',
#   'gak',
#   'simpati',
#   'mungkin',
#   'dia',
#   'dengan',
#   'berkata',
#   'seperti',
#   'itu',
#   'merasa',
#   'hebat',
#   'dia',
#   'tdk',
#   'sadar',
#   'saat',
#   'nyapres',
#   'pun',
#   'rontok',
#   'saat',
#   'thn',
#   '2014',
#   'pun',
#   'keok',
#   'artinya',
#   'rakyat',
#   'g',
#   'percayaseolah',
#   'bicara',
#   'dulu',
#   'urusan',
#   'belakang',
#   'spt',
#   'janji',
#   'jalan',
#   'kaki',
#   'jogja',
#   'jakarta',
#   '',
#   'terbukti',
#   'gak',
#   'kan',
#   'ini',
#   'mungkin',
#   'hal',
#   'sepele',
#   'bagi',
#   'dia',
#   'tapi',
#   'itu',
#   'tertanam',
#   'di',
#   'ingatan',
#   'oranghingga',
#   'berkesimpulan',
#   'klo',
#   'hanya',
#   'bisa',
#   'ngomong',
#   'tok',
#   'nglakoni',
#   'ora',
#   'iso'],
#  ['karena', 'mendukung', 'jokowi', 'jadi', 'tidak', 'dicopot'],
#  ['banyak', 'orang', 'pekalongan', 'yg', 'kemakan', 'hoax'],
#  ['pan',
#   'ancur',
#   'lebur',
#   'gara2',
#   'si',
#   'amien',
#   'rasis',
#   '',
#   'makasih',
#   'amien',
#   '',
#   'lanjutkan',
#   '',
#   '2019panbakalgurem',
#   ''],
#  ['padahal',
#   'sutrisno',
#   'bakhir',
#   'ini',
#   'dulunya',
#   'merupakan',
#   'penyandang',
#   'dana',
#   'pak',
#   'amin',
#   'rais',
#   'saat',
#   'awal',
#   'reformasi',
#   'akhirnya',
#   'berjalan',
#   'sendiri2'],
#  ['orang',
#   'bener',
#   'malah',
#   'tidak',
#   'dipake',
#   'di',
#   'pansutrisno',
#   'itu',
#   'sdh',
#   'habis2an',
#   'demi',
#   'pan',
#   'tapi',
#   'tetap',
#   'tdk',
#   'berdaya',
#   'melawan',
#   'amien',
#   'raispan',
#   'cahayanya',
#   'semakin',
#   'tidak',
#   'bersinar',
#   'sejak',
#   'amien',
#   'makin',
#   'kumat'],
#  ['lagu', 'lama'],
#  ['pan', 'sekarang', 'butek', 'karena', 'diobok2', 'si', 'amien'],
#  ['karena', 'mendukung', 'jadi', 'tdk', 'dicopot'],
#  ['masak',
#   'sih',
#   'dari',
#   'beberapa',
#   'ex',
#   'pemimpin',
#   'pan',
#   'yg',
#   'punya',
#   'pikiran',
#   'sehat',
#   'cuma',
#   'pak',
#   'sutrisno'],
#  ['tolong',
#   'dikoreksi',
#   'untuk',
#   'jabatan',
#   'pak',
#   'pramono',
#   'itu',
#   'menseskab',
#   'bukan',
#   'mensesneg',
#   'terima',
#   'kasih'],
#  ['mantap',
#   'bukti',
#   'orang',
#   'baik',
#   'pasti',
#   'banyak',
#   'yg',
#   'mendukung',
#   'salam',
#   '2',
#   'periode'],
#  ['ksih', 'mkan', 'buaya', 'aja', 'org', 'kyak', 'gini'],
#  ['mantab',
#   'penyebar',
#   'fitnah',
#   'bisa',
#   'tidur',
#   'di',
#   'bui',
#   'jg',
#   'akhirnya'],
#  ['allahuakbar',
#   'alhamdulillah',
#   'akhirnya',
#   'para',
#   'ahlul',
#   'fitnah',
#   'penebar',
#   'kebencian',
#   'tersebut',
#   'dipenjara',
#   'juga',
#   'sudah',
#   'cukup',
#   'lama',
#   'mereka',
#   'menunggu',
#   'nikmatnya',
#   'lp',
#   'cipinang'],
#  ['selamat',
#   'menikmati',
#   'hukuman',
#   'dunia',
#   'atas',
#   'prilaku',
#   'fitnah',
#   'menebar',
#   'kebencian',
#   'hukuman',
#   'akhirat',
#   'yg',
#   'lebih',
#   'berat',
#   'menunggu',
#   'anda',
#   'para',
#   'ahlul',
#   'fitnah',
#   'penebar',
#   'kebencian'],
#  ['dasar',
#   'preman',
#   'ngak',
#   'tanggung',
#   'jawab',
#   'kok',
#   'malah',
#   'buron',
#   'katanya',
#   'lu',
#   'anak',
#   'buah',
#   'wowo',
#   'yg',
#   'bocor',
#   'bocor',
#   'itu',
#   'hehehhe'],
#  ['orang',
#   'grindong',
#   'gak',
#   'akan',
#   'ngomentari',
#   'brita',
#   'ini',
#   'krena',
#   'sebagian',
#   'tabir',
#   'obor',
#   'rakyat',
#   'sdh',
#   'dibuka',
#   'sebagian',
#   'oleh',
#   'rommy'],
#  ['ayo',
#   'gerombolannya',
#   'kok',
#   'nggak',
#   'ada',
#   'yang',
#   'komentar',
#   'nih',
#   'biasanya',
#   'koar2',
#   'bilang',
#   'pelanggaran',
#   'ham',
#   'seperti',
#   'menangkap',
#   'teroris',
#   'pakai',
#   'senjata',
#   'lengkap',
#   'dsb'],
#  ['sik',
#   'asik',
#   'selamat',
#   'menikmati',
#   'hotel',
#   'prodeo',
#   'kawan',
#   'siapa',
#   'menebar',
#   'angin',
#   'dia',
#   'menuai',
#   'badai'],
#  ['buni', 'yaniiii', 'dimana', 'anda', '', 'kejaaarr', ''],
#  ['wowo', 'ga', 'sekalian', ''],
#  ['jangan',
#   'tangkap',
#   'pimrednya',
#   'doank',
#   'tangkap',
#   'penyadang',
#   'dana',
#   'dan',
#   'hubungan',
#   'mereka',
#   'dgn',
#   'kandidat',
#   'capres',
#   'yg',
#   'diusung'],
#  ['walaupun',
#   'cuma',
#   '1',
#   'tahun',
#   'ente',
#   'sudah',
#   'dapat',
#   'gelar',
#   'mantan',
#   'narapidana',
#   'menjelang',
#   'pemilu',
#   'buat',
#   'lagi',
#   'biar',
#   'dikurung',
#   '10tahun',
#   'makan',
#   'gratis'],
#  ['gantung', 'az'],
#  ['sekalian', 'buni', 'yani', 'biar', 'adil', ''],
#  ['kirim', 'ke', 'kamar', 'bonita', '', 'bonita', 'itu', 'nama', 'macan'],
#  ['gua',
#   'paling',
#   'senang',
#   'liat',
#   'ginian',
#   'buronan',
#   'sensasinya',
#   'kayak',
#   'di',
#   'film2',
#   'hollywood'],
#  ['tungguin',
#   'aja',
#   'nih',
#   'bentar',
#   'lagi',
#   'kubu',
#   'prabocor',
#   'terutama',
#   'zonk',
#   'bakalan',
#   'komen',
#   'liat',
#   'aja'],
#  ['karena', 'kabur', 'tambahin', 'yah', 'hukuman', 'nya'],
#  ['ini', 'kabar', 'terbagus', 'yang', 'boleh', 'kudengar', 'hari', 'ini'],
#  ['telat', 'kabur', 'tongkaciann'],
#  ['nyari',
#   'duit',
#   'dr',
#   'nyebar',
#   'fitnahduitnya',
#   'buat',
#   'makan',
#   'anak',
#   'istrimau',
#   'jd',
#   'apa',
#   'anakmu',
#   'makan',
#   'duit',
#   'gituan'],
#  ['semoga', 'bahagia', 'di', 'rumah', 'yg', 'baru'],
#  ['periksa',
#   'bank',
#   'account',
#   'nya',
#   'atau',
#   'bank',
#   'account',
#   'keluarga',
#   'ada',
#   'transferan',
#   'nggak',
#   'dari',
#   'wowo'],
#  ['semoga',
#   'bisa',
#   'belajar',
#   'untuk',
#   'tdk',
#   'mencari',
#   'nafkah',
#   'dari',
#   'uang',
#   'hitam',
#   'dengan',
#   'cara',
#   'yang',
#   'hitam'],
#  ['suntik', 'mati'],
#  ['sikat',
#   'semua',
#   'org',
#   'org',
#   'pengacau',
#   'negeri',
#   'demi',
#   'uang',
#   'apalagi',
#   'mo',
#   'pilpres',
#   'malah',
#   'bikin',
#   'kacau',
#   'negara',
#   'klo',
#   'ga',
#   'segera',
#   'dikarungin'],
#  ['habisin',
#   'aja',
#   'jok',
#   'orang',
#   'yang',
#   'gangu',
#   'elu',
#   'jadi',
#   'presiden',
#   'lgi'],
#  ['nunggu',
#   'buni',
#   'yani',
#   'kapan',
#   'ditangkapnya',
#   'pdhl',
#   'sdh',
#   'ada',
#   'putusan',
#   'pengadilan',
#   'jg'],
#  ['koq', 'cuma', 'setahun', ''],
#  ['laaaahhh',
#   'bukannya',
#   'kata',
#   'nasbung',
#   'pemred',
#   'obor',
#   'rakyat',
#   'diangkat',
#   'jadi',
#   'prekom',
#   'bumnwelehwelehitu',
#   'fitnah',
#   'lagi',
#   'dong'],
#  ['kapan', 'buni', 'yani'],
#  ['sip',
#   'tinggal',
#   'yg',
#   'kabur',
#   'umroh',
#   'ga',
#   'balik2',
#   'segera',
#   'dieksekusi',
#   'pak',
#   'pol'],
#  ['yg',
#   'model',
#   'ginian',
#   'main',
#   'fitnah',
#   'sih',
#   'mesti',
#   'di',
#   'kandangin'],
#  ['mantap'],
#  ['sip'],
#  ['semoga', 'pas', 'di', 'dalam', 'penjarakedua2nya', 'gantung', 'diri'],
#  ['terbukti',
#   'memfitnah',
#   'bukan',
#   'menghina',
#   'dan',
#   'ingat',
#   'fitnah',
#   'lebih',
#   'kejam',
#   'dari',
#   'pembunuhan',
#   'bro'],
#  ['hukuman', 'mati'],
#  ['alhamdulillah', 'si', 'penebar', 'dosa', 'sudah', 'tertangkap'],
#  ['jokowi',
#   'sudah',
#   'memaafkan',
#   'tapi',
#   '',
#   'proses',
#   'hukum',
#   'tetap',
#   'berlaku',
#   'bos',
#   ''],
#  ['hmm'],
#  ['siap2', 'buat', 'gerombolan', 'micin', 'ama', 'nasi', 'bungkus'],
#  ['tambah', 'hukumannya', 'karena', 'mau', 'kabur'],
#  ['lho', 'kok', 'cuma', '1', 'tahun', '5', 'thn', 'pantas', 'kok'],
#  ['yg',
#   'menjamin',
#   'mau',
#   'mem',
#   'back',
#   'up',
#   'mereka',
#   'pada',
#   'kemana',
#   'mau',
#   'menemani',
#   'mereka',
#   'hidup',
#   'bersama',
#   'di',
#   'lp',
#   'cipinang',
#   'jangan',
#   'macem',
#   'ayam',
#   'sayur',
#   'lari',
#   'lintang',
#   'pukang',
#   'meninggalkan',
#   'kawan'],
#  ['gagah',
#   'saat',
#   'bikin',
#   'obor',
#   'rakyat',
#   'mewek',
#   'dan',
#   'buron',
#   'saat',
#   'diproses',
#   'hukum',
#   'dasar',
#   'preman',
#   'gembeng',
#   'kalau',
#   'begini',
#   'apakah',
#   'orang',
#   'yang',
#   'anda',
#   'junjung',
#   'akan',
#   'gantian',
#   'membela',
#   'anda'],
#  ['2019gantipresiden',
#   'kelihatan',
#   'bgt',
#   'tebang',
#   'pilihnya',
#   'hukum',
#   'tajam',
#   'ke',
#   'lawan',
#   'politik',
#   'tumpul',
#   'ke',
#   'cebong😏'],
#  ['orangnya',
#   'tambah',
#   'gemuk',
#   'makan',
#   'uang',
#   'sisa',
#   'anggaran',
#   'obor',
#   'rakyat'],
#  ['buset',
#   'dahjamintelnya',
#   'tetangga',
#   'sebelah',
#   'rumahnya',
#   'sendirimiris'],
#  ['bisa', 'jadi', '2019', 'muncul', 'petromak', 'rakyat', '😹😹'],
#  ['kalau',
#   'sudah',
#   'dieksekusi',
#   'ngga',
#   'lagi',
#   'dilindungi',
#   'kan',
#   'sama',
#   'janji',
#   'back',
#   'up',
#   'kalo',
#   'kena',
#   'masalah',
#   'hehehe',
#   'makan',
#   'tuh',
#   'janji',
#   'saat',
#   'kampanye'],
#  ['makan', 'pencarian', 'lu', 'tuhhhhh'],
#  ['selamat', 'ya'],
#  ['masih', 'mudabuaknnya', 'mendukung', 'presiden', 'generasi', 'mudapayah'],
#  ['yess',
#   'tidur',
#   'aaaah',
#   'biar',
#   'cepet',
#   'besok',
#   'ada',
#   'yg',
#   'berani',
#   'taruhan',
#   'siapa',
#   'yang',
#   'belain',
#   'mereka'],
#  ['tukang', 'fitnah', 'hukum', 'seberat2nya'],
#  ['hrsnya', 'min', '10thn', 'di', 'sel'],
#  ['nah',
#   'ini',
#   'dia',
#   'paling',
#   'lawyernya',
#   'habibu',
#   'getombolan',
#   'nasi',
#   'bungkus',
#   'micin',
#   'jantungan'],
#  ['cuma', '1', 'thn', 'enak', 'bener'],
#  ['ini',
#   'bodoh',
#   'amat',
#   'cuma',
#   '8',
#   'bulan',
#   'seharusnya',
#   'jangan',
#   'banding',
#   'malah',
#   'jadi',
#   '2',
#   'tahun'],
#  ['bos', 'nya', 'sikat'],
#  ['mari',
#   'kita',
#   'tunggu',
#   'siapa',
#   'saja',
#   'yg',
#   'nyinyir',
#   'atas',
#   'penangkapan',
#   'ini'],
#  ['muka2', 'tegar', 'menjalani', 'hukuman'],
#  ['bosnya', 'dah', 'ketangkap', 'blum'],
#  ['wowok', 'cs', 'banyak', 'mudarat', 'nya'],
#  ['bravo', 'kejaksaan', 'selamat', 'bertugas'],
#  ['hukum', 'seberatberatnya'],
#  ['kalo',
#   'cebong',
#   'mah',
#   'gk',
#   'di',
#   'tangkap',
#   'kebal',
#   'hukum',
#   'spt',
#   'viktor',
#   'laiskodat',
#   'ade',
#   'armando',
#   'nathan',
#   'ananda',
#   'sukarlan',
#   'dll',
#   '2019gantipresiden😏'],
#  ['good',
#   'job',
#   'jgn',
#   'lupa',
#   'gerombolan',
#   'surveyor',
#   'ines',
#   'juga',
#   'hrs',
#   'diawasi',
#   'dr',
#   'pada',
#   'menyebarkan',
#   'hasil',
#   'survey',
#   'abal',
#   'abal',
#   'apalagi',
#   'mo',
#   'pilpres',
#   'malah',
#   'bikin',
#   'perpecahan'],
#  ['sdh',
#   'dibongkar',
#   'kan',
#   'sama',
#   'pak',
#   'romi',
#   'pasti',
#   'ada',
#   'pendananya',
#   'si',
#   'kejar',
#   'juga',
#   'pak',
#   'jaksaterus',
#   'pak',
#   'berjuang',
#   'demi',
#   'bersihnya',
#   'negara',
#   'ini',
#   'dari',
#   'tukang',
#   'fitnah'],
#  ['usut', 'dana', 'nya', 'dari', 'mana', 'itu', 'baru', 'hebat👍'],
#  ['silahkan',
#   'bernyanyi',
#   'denga',
#   'bebas',
#   'walaupum',
#   'sumbangtempat',
#   'telah',
#   'disediakanwkwkwkwkkw'],
#  ['kok', 'cuma', 'setahun', ''],
#  ['ayo',
#   'donk',
#   'polisi',
#   'kalo',
#   'nangkep2',
#   'kaya',
#   'gini',
#   'dicari',
#   'tahu',
#   'bosnya',
#   'siapa',
#   'siapa',
#   'yang',
#   'memberi',
#   'dana',
#   'terus',
#   'kalo',
#   'udah',
#   'tau',
#   'tangkep',
#   'lansung'],
#  ['disate', 'aje', 'pak', 'jaksa'],
#  ['tembak', 'jidat', 'nya'],
#  ['tangkap',
#   'bandar',
#   'dan',
#   'pemimpin',
#   'gembong',
#   'hoaxnya',
#   'biar',
#   'jelas'],
#  ['tukang', 'fitnah', 'plus', 'juragannya', 'wajib', 'dihukum'],
#  ['sudah',
#   'terbukti',
#   'komplotan',
#   'sana',
#   'cuma',
#   'bisa',
#   'fitnah',
#   'hoax',
#   'pki',
#   'kerjanya',
#   'ngga',
#   'ada'],
#  ['mendingan', 'ditenggelamkan', 'aje'],
#  ['aktor',
#   'intelektual',
#   'yang',
#   'mendanai',
#   'kerja',
#   'obor',
#   'rakyat',
#   'untuk',
#   'kepentingan',
#   'politik',
#   'sang',
#   'aktor',
#   'intelektual',
#   'juga',
#   'harus',
#   'di',
#   'tangkap',
#   'dan',
#   'ditenggelamkan'],
#  ['mo',
#   'bgs',
#   'atau',
#   'gapresiden',
#   'itu',
#   'kepala',
#   'negara',
#   'yg',
#   'hrs',
#   'dihormatikl',
#   'lu',
#   'hina',
#   'ya',
#   'pantaslah',
#   'msk',
#   'bui'],
#  ['mo',
#   'bgs',
#   'atau',
#   'gapresiden',
#   'itu',
#   'kepala',
#   'negara',
#   'yg',
#   'hrs',
#   'dihormatikl',
#   'lu',
#   'hina',
#   'ya',
#   'pantaslah',
#   'msk',
#   'bui'],
#  ['mo',
#   'bgs',
#   'atau',
#   'gapresiden',
#   'itu',
#   'kepala',
#   'negara',
#   'yg',
#   'hrs',
#   'dihormatikl',
#   'lu',
#   'hina',
#   'ya',
#   'pantaslah',
#   'msk',
#   'bui'],
#  ['tukang', 'fitnah', 'dan', 'penyebar', 'hoax', 'tenggelamkan', ''],
#  ['hhahahh',
#   'ya',
#   'jelas',
#   'uda',
#   'ketebak',
#   'negri',
#   'dagelan',
#   'yg',
#   'komen',
#   'jga',
#   'blaa',
#   'blaaa',
#   'blaaaa',
#   '😂🤣😂🤣',
#   'lanjutakan',
#   'saja'],
#  ['terima', 'kasih', 'kejaksaan'],
#  ['pak',
#   'jaksa',
#   'yg',
#   'hina',
#   'pak',
#   'jokowi',
#   'berkali2',
#   'pasti',
#   'pak',
#   'jaksa',
#   'tau',
#   'lahtolong',
#   'di',
#   'seret',
#   'ke',
#   'penjara',
#   'thanks'],
#  ['sekalipun',
#   'benci',
#   'dng',
#   'jokowi',
#   'bukan',
#   'berarti',
#   'menebar',
#   'fitnah',
#   'biar',
#   'bgaimanapun',
#   'jokowi',
#   'itu',
#   'presiden',
#   'pilihan',
#   'rakyat',
#   'memfitnah',
#   'presiden',
#   '',
#   'memfitnah',
#   'rakyat'],
#  ['buron', 'wkwk'],
#  ['kalo',
#   'di',
#   'turki',
#   'ini',
#   'orang',
#   'sudah',
#   'diciduk',
#   'langsung',
#   'oleh',
#   'erdogan',
#   'presiden',
#   'idaman',
#   'nya',
#   'pks',
#   '🤣',
#   'untung',
#   'lah',
#   'di',
#   'indonesia',
#   'ini',
#   'presiden',
#   'nya',
#   'jokowi',
#   'yg',
#   'orang',
#   'nya',
#   'lembut',
#   'dan',
#   'kalem',
#   '😁'],
#  ['kalo', 'dulu', 'menang', 'udah', 'diangkat', 'menteri', 'nih', 'orang'],
#  ['kalo', 'dulu', 'menang', 'udah', 'diangkat', 'menteri', 'nih', 'orang'],
#  ['kalo', 'dulu', 'menang', 'udah', 'diangkat', 'menteri', 'nih', 'orang'],
#  ['kalo', 'dulu', 'menang', 'udah', 'diangkat', 'menteri', 'nih', 'orang'],
#  ['kalo', 'dulu', 'menang', 'udah', 'diangkat', 'menteri', 'nih', 'orang'],
#  ['boss', 'nya', 'juga', 'sekalian', 'disikat', 'toilet'],
#  ['boss', 'nya', 'juga', 'sekalian', 'disikat', 'toilet'],
#  ['jadi', 'inget', 'jaman', 'siapa', 'ya'],
#  ['orang', 'bikin', 'rusak', 'harus', 'musnahkan'],
#  ['super', 'muantap👍👍👍'],
#  ['baguslah',
#   'diciduk',
#   'sebelum',
#   'dikontrak',
#   'lagi',
#   'sama',
#   'tukang',
#   'fitnah'],
#  ['menjelekan',
#   'presiden',
#   'sama',
#   'saja',
#   'menghina',
#   'lambang',
#   'negara',
#   'harusnya',
#   'berpikir',
#   'apalagi',
#   'seorang',
#   'redaksi',
#   'berita',
#   'yang',
#   'seharusnya',
#   'menjadi',
#   'panutan',
#   'beritanya'],
#  ['semoga', 'betah', 'di', 'hotel', 'prodeo', 'ya', 'bro'],
#  ['sebaiknya', 'orang', 'spt', 'ini', 'dilenyapkan', 'saja'],
#  ['sikat', 'ikat', 'berkas'],
#  ['fitnah', 'krn', 'duit', '😆'],
#  ['tlg', 'dikubur', 'dalam2', 'org', 'begini'],
#  ['langsung', 'buang', 'aja', 'kelaut'],
#  ['tunggu', 'siapa', 'yang', 'komen', 'membelanah', 'itu', 'donaturnya'],
#  ['buniyani', 'gmn'],
#  ['kokk',
#   'lama',
#   'sekali',
#   'pelaku',
#   'kejahatan',
#   'hoax',
#   'ini',
#   'baru',
#   'dijebloskan',
#   'ke',
#   'bui',
#   'sekarang',
#   'usut',
#   'dan',
#   'tangkap',
#   'segera',
#   'pelaku',
#   'hoax',
#   'lainnya'],
#  ['obor', 'hoax'],
#  ['bravo', 'kejaksaanlumayan', 'ada', 'kerjanya'],
#  ['mantap', 'hajar', 'penyebar', 'hoax'],
#  ['yg', 'di', 'negri', 'sebrang', 'bgmn'],
#  ['4', 'tahun', 'pantesnya', '40', 'taon'],
#  ['itu', 'dlu', 'timses', 'syp', 'ea'],
#  ['masih', 'bisa', 'gaya', 'gaya', 'an', 'lihat', 'baju', 'mereka', 'seperti'],
#  ['mudah', '2', 'an', 'di', 'hukun', 'lebih', 'berat', 'lagi'],
#  ['wkwkwkwkwkw',
#   'syukurlah',
#   'kalian',
#   'banding',
#   'soalnya',
#   'hukuman',
#   'kalian',
#   'bakal',
#   'di',
#   'tambah',
#   'jd',
#   '10',
#   'thn',
#   'nyungsep',
#   'kalian',
#   ''],
#  ['sakit', 'jiwa', 'luuu'],
#  ['sakit', 'jiwa', 'lluu'],
#  ['kasihan', 'bener', 'mas', 'eko', 'semoga', 'dapat', 'jalan', 'keluarnya'],
#  ['jahat', 'sekali', 'yang', 'nipu'],
#  ['sebutin', 'aja', 'pengacaranya'],
#  ['nah',
#   'mulai',
#   'terkuak',
#   'biang',
#   'keladinya',
#   '',
#   'siapkan',
#   'bukti2',
#   'penyerahan',
#   'surat2',
#   'dan',
#   'tanda',
#   'terima',
#   'uang',
#   '',
#   'dikasi',
#   'ga',
#   'waktu',
#   'entu',
#   '',
#   'kalo',
#   'ga',
#   'ada',
#   'bukti',
#   'jangan',
#   'kau',
#   'harap',
#   'bisa',
#   'gugat',
#   'pengacara',
#   'ya',
#   ''],
#  ['semoga',
#   'dapat',
#   'pengganti',
#   'pengacara',
#   'kondang',
#   'mas',
#   'yang',
#   'kemarin',
#   'itu',
#   'abal',
#   'abal',
#   'punya'],
#  ['kasian',
#   'mas',
#   'eko',
#   'ini',
#   'bisa2',
#   'dituduh',
#   'lg',
#   'sama',
#   'cebong',
#   'sebagai',
#   'sebar',
#   'hoax',
#   'krn',
#   'tdk',
#   'ada',
#   'buktinya'],
#  ['yang',
#   'komentar',
#   'pada',
#   'ga',
#   'tahu',
#   'tentang',
#   'bagaimana',
#   'sertifikat',
#   'dibuat',
#   'sertifikat',
#   'itu',
#   'bisa',
#   'muncul',
#   'kalau',
#   'ada',
#   'akses',
#   'jalan',
#   'suruh',
#   'dia',
#   'tunjukin',
#   'denah',
#   'sertifikatnya',
#   'kalau',
#   'dia',
#   'memang',
#   'punya',
#   'itu',
#   'pasti',
#   'sertifikatnya',
#   'masih',
#   'gabung',
#   'ama',
#   'sebelah',
#   'kiri',
#   'atau',
#   'sebelah',
#   'kanannya',
#   'dan',
#   'itu',
#   'pasti',
#   'masih',
#   'saudara',
#   'dia',
#   'sertifikatnya',
#   'belum',
#   'dipecah',
#   'ama',
#   'mereka',
#   'berdua'],
#  ['nanti', 'pintu', 'surganya', 'juga', 'diblokade', 'sama', 'tuhan'],
#  ['sdh',
#   'bp',
#   'camat',
#   'yg',
#   'harus',
#   'menyelesaikan',
#   'biar',
#   'p',
#   'camat',
#   'dpt',
#   'pahala',
#   'membantu',
#   'yg',
#   'tertindas',
#   '',
#   'toh',
#   'ga',
#   'lama',
#   'lagi',
#   'kita',
#   'mati',
#   'dan',
#   'runah',
#   'tanah',
#   'itu',
#   'tdk',
#   'di',
#   'bawaq'],
#  ['saya',
#   'tahun',
#   'kemarin',
#   'beli',
#   'tanah',
#   '20',
#   '15',
#   'm',
#   'tapi',
#   'saya',
#   'bikin',
#   'fondasi',
#   'pagar',
#   '19',
#   '15m',
#   'jadi',
#   'ada',
#   '1',
#   'meter',
#   'untuk',
#   'akses',
#   'jalan',
#   'setapak',
#   'berarti',
#   'saya',
#   'relakan',
#   'tanah',
#   'saya',
#   '115m',
#   'utk',
#   'kepentingan',
#   'umum',
#   'tetangga',
#   'sebelah',
#   'juga',
#   'demikian',
#   'jadi',
#   'jalan',
#   'setapak',
#   'lebarnya',
#   '2',
#   'meter',
#   'kita',
#   'kan',
#   'hidup',
#   'bertetangga',
#   'masa',
#   'tanah',
#   'satu',
#   'meter',
#   'aja',
#   'menghalangi',
#   'silaturahmi',
#   'dengan',
#   'tetangga',
#   'jadi',
#   'harus',
#   'dibicarakan',
#   'baikbaik',
#   'semua',
#   'bisa',
#   'diatur',
#   'yg',
#   'penting',
#   'dengan',
#   'hati',
#   'nurani'],
#  ['lemah',
#   'mati',
#   'tidak',
#   'ada',
#   'akses',
#   'jalan',
#   'itu',
#   'murah',
#   'harganya',
#   'lha',
#   'ini',
#   'yg',
#   'punya',
#   'tanah',
#   'maruk',
#   'ud',
#   'deal',
#   '100jt',
#   'minta',
#   'naik',
#   '150jt',
#   'jengkel',
#   'di',
#   'tutup',
#   'sekalian',
#   'ma',
#   'tetangga',
#   'yakin',
#   'tuh',
#   'yg',
#   'punya',
#   'tanah',
#   'mati',
#   'pasti',
#   'kolot',
#   'jd',
#   'dikerjai',
#   'tetangga'],
#  ['klo',
#   'tdk',
#   'salah',
#   'ada',
#   'undangundang',
#   'pertanahan',
#   'yg',
#   'mengatur',
#   'tentang',
#   'kewajiban',
#   'bagi',
#   'pemilik',
#   'tanah',
#   'dan',
#   'bangunan',
#   'untuk',
#   'memberi',
#   'akses',
#   'jalan',
#   'bagi',
#   'pemilik',
#   'tanah',
#   'dan',
#   'bangunan',
#   'dibelakangnya',
#   'yg',
#   'tdk',
#   'memiliki',
#   'akses',
#   'jalan',
#   'dlm',
#   'sertifikat',
#   'tanahnya',
#   'istilahnya',
#   'tanah',
#   'helikopter',
#   'minimal',
#   'jalan',
#   'setapak',
#   'silahkan',
#   'dicek',
#   'saya',
#   'lupa',
#   'pasalnya'],
#  ['tidak',
#   'berperikemanusiaan',
#   'yang',
#   'nutup',
#   'akses',
#   'itu',
#   'maukah',
#   'dia',
#   'diperlakukan',
#   'seperti',
#   'itu',
#   'tanya',
#   'ke',
#   'kupingnya',
#   'dengan',
#   'keras',
#   'maukah',
#   'dia',
#   'diperlakukan',
#   'seperti',
#   'itu',
#   'jika',
#   'berada',
#   'di',
#   'belakang',
#   'rumah',
#   'orang',
#   'lain'],
#  ['u2063sepertinya',
#   'ada',
#   'yang',
#   '',
#   'kurang',
#   'beres',
#   'dengan',
#   'sertifikatnya',
#   'di',
#   'antara',
#   'rumah',
#   'rumah',
#   'itu',
#   'logikanya',
#   'rtrw',
#   'lurahcamat',
#   '',
#   'bppn',
#   'waktu',
#   'menerbitkan',
#   'sertifikat',
#   'itu',
#   'pasti',
#   'tahu',
#   'posisi',
#   'dan',
#   'batas',
#   'batas',
#   'rumah',
#   'pasti',
#   'ada',
#   'yang',
#   'salah',
#   'dengan',
#   'sertifikat',
#   'sertifikat',
#   'itu',
#   'tentang',
#   'batasbatas',
#   'tanahnya',
#   'minimal',
#   'ada',
#   'hak',
#   'orang',
#   'yang',
#   'diserobot',
#   'polisi',
#   'harus',
#   'turun',
#   'ini'],
#  ['priksa',
#   'dulu',
#   'imb',
#   'nya',
#   'ada',
#   'gak',
#   'kalau',
#   'gak',
#   'ada',
#   'suruk',
#   'satpol',
#   'yg',
#   'bongkar',
#   'jangan',
#   'korbankan',
#   'tetangga'],
#  ['sebelum',
#   'semuanya',
#   'menjudge',
#   'tanpa',
#   'tabayyunsimple',
#   'utk',
#   'mencari',
#   'siapa',
#   'yg',
#   'salahyg',
#   'diakui',
#   'selama',
#   'ini',
#   'sbagai',
#   'akses',
#   'jalan',
#   'pak',
#   'eko',
#   'ini',
#   'sebenarnya',
#   'memang',
#   'peruntukan',
#   'jalan',
#   'atau',
#   'menggunakan',
#   'melewati',
#   'tanah',
#   'orang',
#   'lainklo',
#   'memang',
#   'akses',
#   'jalantetangganya',
#   'jelas',
#   'salahtapi',
#   'klo',
#   'itu',
#   'memang',
#   'tanah',
#   'org',
#   'lainya',
#   'memang',
#   'haknya',
#   'dia',
#   'utk',
#   'menembokyg',
#   'salah',
#   'adalah',
#   'pemerintah',
#   'setempatmana',
#   'akses',
#   'jalan',
#   'selama',
#   'ini',
#   'yg',
#   'harusnya',
#   'ada'],
#  ['yang',
#   'punya',
#   'tanah',
#   'nggak',
#   'bisa',
#   'disalahin',
#   'jugamemang',
#   'itu',
#   'haknya',
#   'diaklo',
#   'dia',
#   'dituntut',
#   'harus',
#   'ngasih',
#   'sebagian',
#   'untuk',
#   'jalantetangga',
#   'kirikanan',
#   'n',
#   'belakang',
#   'pak',
#   'eko',
#   'juga',
#   'harus',
#   'dituntut',
#   'hal',
#   'yg',
#   'serupaapesnya',
#   'dia',
#   'adalah',
#   'dia',
#   'baru',
#   'beli',
#   'n',
#   'bangun',
#   'skrg'],
#  ['kasih', 'jln', 'pakitu', 'ladang', 'amal', 'bpk'],
#  ['klo',
#   'ud',
#   'deal',
#   '100jt',
#   'kok',
#   'ingkar',
#   'jd',
#   '150jt',
#   'ya',
#   'hrsnya',
#   'jgn',
#   'serakah',
#   'jg',
#   'ya',
#   'klo',
#   'emank',
#   'maunya',
#   '150jt',
#   'ya',
#   'jgn',
#   'buka',
#   '100jt',
#   'donkntar',
#   'ada',
#   'yg',
#   'mau',
#   '150jt',
#   'ingkar',
#   'lgi',
#   '200jt'],
#  ['akar', 'masalah', 'nya', '', '', '', '', '', 'duit'],
#  ['ya',
#   'sudah',
#   'to',
#   'pak',
#   'eko',
#   'pindah',
#   'aja',
#   'rumah',
#   'lama',
#   'jadikan',
#   'kandang',
#   'ayam',
#   'atau',
#   'studio',
#   'musik',
#   'kan',
#   'haknya',
#   'pak',
#   'eko',
#   'juga',
#   'to',
#   'saat',
#   'ketemu',
#   'tetangga',
#   'yang',
#   'gak',
#   'pedulian',
#   'ya',
#   'sudah',
#   'jadikan',
#   'kita',
#   'gak',
#   'peduli',
#   'ngalah',
#   'terus',
#   'tidak',
#   'selamanya',
#   'baik'],
#  ['benernya',
#   'siapa',
#   'sie',
#   'yang',
#   'mau',
#   'beli',
#   'siapa',
#   'yang',
#   'mau',
#   'jual',
#   'kok',
#   'keterangan',
#   'camat',
#   'beda',
#   'sama',
#   'eko',
#   'eko',
#   'bilang',
#   'dia',
#   'yang',
#   'mau',
#   'beli',
#   'tanah',
#   'tetangganya',
#   'buat',
#   'jalan',
#   'kata',
#   'camat',
#   'malah',
#   'eko',
#   'yang',
#   'mau',
#   'jual',
#   'malah',
#   'harga',
#   'naik',
#   'pulaini',
#   'yakin',
#   'ada',
#   'yang',
#   'ga',
#   'beres',
#   'sama',
#   'si',
#   'eko'],
#  ['gak',
#   'pernah',
#   'belajar',
#   'pmp',
#   'mana',
#   'toleransisaling',
#   'menghargaissopan',
#   'santunempati',
#   'dalam',
#   'bertetangga'],
#  ['dulu',
#   'sudah',
#   'mau',
#   'dibeli',
#   '100jt',
#   'tapi',
#   'ga',
#   'jadi',
#   'karena',
#   'naik',
#   'minta',
#   '150jt',
#   'giliran',
#   'dibikin',
#   'tembok',
#   'merengek',
#   'rengek',
#   'ngadu',
#   'kesana',
#   'kamari',
#   'lebay'],
#  ['ujung', 'ujungnya', 'duit'],
#  ['sdh', 'terbacapokok', 'permasalah', 'nya'],
#  ['camat',
#   'koq',
#   'minta2',
#   'keluar',
#   'dari',
#   'kantor',
#   'kalian',
#   'itu',
#   'hei',
#   'camat',
#   'lurah',
#   'jgn',
#   'ongkang2',
#   'keq',
#   'kumpeni',
#   'aje',
#   'lu',
#   'pade'],
#  ['jangan',
#   'maen',
#   'asal',
#   'ngomong',
#   'nuduh',
#   'salah',
#   'satu',
#   'pihak',
#   'masalah',
#   'ini',
#   'terjadi',
#   'bukan',
#   'krn',
#   'pihak',
#   'yg',
#   'bersengketa',
#   'saja',
#   'ada',
#   'peran',
#   'rt',
#   'rw',
#   'lurah',
#   'camat',
#   'serta',
#   'pihak',
#   'pertanahan',
#   'rencana',
#   'tata',
#   'ruangnya',
#   'mana',
#   'masing2',
#   'punya',
#   'andil',
#   'dalam',
#   'terjadinya',
#   'masalah',
#   'ini',
#   'bukan',
#   'serta',
#   'merta',
#   'gr2',
#   'pihak',
#   'pak',
#   'eko',
#   'ataupun',
#   'tetangganya'],
#  ['pny',
#   'tanah',
#   'pribadi',
#   'jng',
#   'dibuat',
#   'jalanan',
#   'nnt',
#   'diserobotud83dude0b'],
#  ['jadi',
#   'sudah',
#   'jelas',
#   'to',
#   'akar',
#   'masalahnyalain',
#   'kumbang',
#   'lain',
#   'belangnyaud83dude02'],
#  ['seharusnya',
#   'ke',
#   'pangadilan',
#   'saja',
#   'apapun',
#   'hasilnya',
#   'itu',
#   'yang',
#   'akan',
#   'diakui',
#   'secara',
#   'hukum',
#   'kalau',
#   'curhat',
#   'kemana2',
#   'pasti',
#   'hanya',
#   'dapat',
#   'lip',
#   'service',
#   'saja',
#   'karena',
#   'mereka',
#   'hanya',
#   'bisa',
#   'menghimbau'],
#  ['sdh',
#   'mau',
#   'dibeli',
#   '100jt',
#   'tp',
#   'naik',
#   'jd',
#   '150jt',
#   'lgdr',
#   'sini',
#   'sdh',
#   'sdkt',
#   'jls',
#   'akar',
#   'mslhnya'],
#  ['ko',
#   'masih',
#   'ada',
#   'ya',
#   'orang',
#   'kaya',
#   'gitutinggal',
#   'di',
#   'perkampungan',
#   'mending',
#   'di',
#   'kubur',
#   'aja'],
#  ['spekulasi',
#   'tu',
#   'yg',
#   'jd',
#   'pertanyaan',
#   'ketika',
#   'jual',
#   'beli',
#   'kan',
#   'ada',
#   'form',
#   'tanda',
#   'tangan',
#   'sepengetahuan',
#   'jiran',
#   'kanan',
#   'kiri',
#   'dpn',
#   'blkg',
#   'dr',
#   'situ',
#   'sdh',
#   'dpt',
#   'awal',
#   'masalahnya',
#   'kmn',
#   'tu',
#   'pak',
#   'rt',
#   'rw',
#   'kadus',
#   'n',
#   'kades'],
#  ['klpun',
#   'd',
#   'kasih',
#   'jalan',
#   'jg',
#   'mending',
#   'pindah',
#   'aja',
#   'pakpunya',
#   'tetangga',
#   'kayak',
#   'gitu',
#   'modelnya',
#   'susah',
#   'liat',
#   'orang',
#   'senangsenang',
#   'liat',
#   'orang',
#   'susah'],
#  ['knpa',
#   'setelah',
#   'viral',
#   'di',
#   'medsos',
#   'camat',
#   'nya',
#   'baru',
#   'turun',
#   'tangan',
#   'pak',
#   'eko',
#   'bilang',
#   'sdh',
#   '3',
#   'thn',
#   'mondarmandir',
#   'utk',
#   'cari',
#   'solusi',
#   'jadi',
#   'klu',
#   'ada',
#   'masalh',
#   'sprti',
#   'ini',
#   'mendingan',
#   'di',
#   'viralkan',
#   'spya',
#   'cepat',
#   'ditanggapi'],
#  ['masoook', 'pak', 'eko'],
#  ['tetangga',
#   'kayak',
#   'gini',
#   'harus',
#   'buru',
#   'buru',
#   'di',
#   'mandiin',
#   'di',
#   'solatin',
#   'di',
#   'kafanin',
#   'dan',
#   'dikuburin',
#   'langsung',
#   'ga',
#   'ada',
#   'adabnya'],
#  ['gabisa', 'masook', 'pak', 'ekooo'],
#  ['u2063saya',
#   'enggak',
#   'nyebutin',
#   'kronologi',
#   'karena',
#   'privacy',
#   'hmm',
#   'ada',
#   'yang',
#   'aneh'],
#  ['disini',
#   'banyak',
#   'pendukung',
#   'tetangga',
#   'pak',
#   'eko',
#   'atau',
#   'mgkn',
#   'tetangga',
#   'disitu',
#   'wkwkww'],
#  ['dijual', 'ke', 'tetangga', 'depan', 'samping', 'saja', 'pak'],
#  ['rt',
#   'rw',
#   'lurah',
#   'camat',
#   'bpn',
#   'walkot',
#   'bupati',
#   'tidorrrr',
#   'semuaaaaaa'],
#  ['masssook', 'pak', 'ekoo'],
#  ['harusnya',
#   'dipikirin',
#   'sejak',
#   'dini',
#   'kalo',
#   'sudah',
#   'begini',
#   'bingung',
#   'dah',
#   'lu',
#   'ekoud83dude33ud83dude33ud83dude33',
#   'slh',
#   'elu',
#   'sendiri'],
#  ['kalau',
#   'mau',
#   'jual',
#   'ya',
#   'ke',
#   'tetangganya',
#   'gak',
#   'usah',
#   'cari',
#   'sensasi',
#   'banyak',
#   'kok',
#   'org',
#   'lqin',
#   'yg',
#   'rugi',
#   'lebih',
#   'banyak',
#   'utk',
#   'urusan2',
#   'tanah',
#   'bahkan',
#   'tanah',
#   'dgn',
#   'surat',
#   'berlapis',
#   'juga',
#   'ada',
#   'toh',
#   'yg',
#   'rugi',
#   'pemilik',
#   'org',
#   'bpn',
#   'palingan',
#   'hanya',
#   'di',
#   'mutasi',
#   'apalagi',
#   'kl',
#   'sdh',
#   'pensiun',
#   'gak',
#   'ada',
#   'sangsi',
#   'apa2'],
#  ['ini',
#   'eko',
#   'nya',
#   'yg',
#   'bodohhh',
#   'sejak',
#   'awalud83dude06ud83dude06ud83dude06'],
#  ['undang2',
#   'sdh',
#   'mengatur',
#   'klo',
#   'pembangunan',
#   'tidal',
#   'boleh',
#   'menutup',
#   'akses',
#   'jalan',
#   'bagi',
#   'rumah',
#   'atau',
#   'tempat',
#   'tinggal',
#   'yg',
#   'sudah',
#   'ada',
#   'sebelumnya',
#   'mohon',
#   'koreksi',
#   'klo',
#   'salah'],
#  ['kayak',
#   'nya',
#   'si',
#   'eko',
#   'ini',
#   'punya',
#   'kelainan',
#   'cara',
#   'bertetangga',
#   'deh'],
#  ['masooookkkk', 'pak', 'ekooo'],
#  ['pak',
#   'eko',
#   'punya',
#   'imb',
#   'kok',
#   'bisa',
#   'bangun',
#   'rumah',
#   'tanpa',
#   'halaman'],
#  ['solusinya',
#   'ya',
#   'jual',
#   'ke',
#   'tetangga',
#   'depannya',
#   'itu',
#   'pak',
#   'hitung',
#   'harga',
#   'tanah',
#   'saja',
#   'karena',
#   'memang',
#   'rumah',
#   '',
#   'tanah',
#   'bpk',
#   'di',
#   'block',
#   'sama',
#   'dia',
#   'banyak',
#   'yang',
#   'seperti',
#   'itu',
#   'istilahnya',
#   'lock',
#   'land',
#   '',
#   'jadi',
#   'memang',
#   'dia',
#   'beli',
#   'atau',
#   'bpk',
#   'bisa',
#   'juga',
#   'beli',
#   'tanah',
#   'didepan',
#   'untuk',
#   'akses',
#   ''],
#  ['beli',
#   'aja',
#   'tanah',
#   'tetangga',
#   'atau',
#   'jual',
#   'rumahnya',
#   'ke',
#   'tetangganya'],
#  ['ya',
#   'harusnya',
#   'dari',
#   'awal',
#   'pak',
#   'eko',
#   'sudah',
#   'membuat',
#   'jalan',
#   'utk',
#   'rumahnya',
#   'sendiri',
#   'bukan',
#   'nya',
#   'membuat',
#   'rumah',
#   'full',
#   'bangunan',
#   'tp',
#   'disisakan',
#   'utk',
#   'jalan',
#   'hak',
#   'tetangga',
#   'jg',
#   'membuat',
#   'rumah',
#   'di',
#   'tanahnya',
#   'sandiri',
#   'seperti',
#   'yg',
#   'dilakukan',
#   'pak',
#   'eko',
#   'kejadian',
#   'sebenarnya',
#   'masih',
#   'misteri',
#   'siapa',
#   'yg',
#   'salah',
#   'dan',
#   'yg',
#   'benar',
#   'masih',
#   'abu2'],
#  ['masuk', 'pak', 'eko', ''],
#  ['tata', 'ruangnya', 'amburadul'],
#  ['sebetulnya',
#   'yg',
#   'paling',
#   'salah',
#   'adalah',
#   'bpn',
#   'karna',
#   'di',
#   'peraturan',
#   'agraria',
#   'terutuang',
#   'hukum',
#   'mengenai',
#   'pemberian',
#   'jalan',
#   'kepada',
#   'tanah',
#   'yg',
#   'tdk',
#   'memiliki',
#   'jalan',
#   'cth',
#   'tanah',
#   'yg',
#   'di',
#   'tengah',
#   'telah',
#   'disertifikat',
#   'di',
#   'kanan',
#   'dan',
#   'dikiri',
#   'pun',
#   'telah',
#   'bersertifikat',
#   'dan',
#   'menutup',
#   'jalan',
#   'di',
#   'depannya',
#   'jg',
#   'dibuat',
#   'sertifikat',
#   'dan',
#   'menutup',
#   'akses',
#   'yg',
#   'ditgh',
#   'sementara',
#   'blkg',
#   'belum',
#   'nah',
#   'ketika',
#   'belakang',
#   'membuat',
#   'sertifikat',
#   'secara',
#   'otomatis',
#   'yg',
#   'belakang',
#   'akan',
#   'kepotong',
#   'tanahnya',
#   'dan',
#   'memberikan',
#   'akses',
#   'jalan',
#   'yg',
#   'ditengah',
#   'cuma',
#   'masyarakat',
#   'bnyk',
#   'yg',
#   'awam',
#   'dgn',
#   'peraturan',
#   'tersebut'],
#  ['ketua',
#   'rt',
#   'rw',
#   'lurah',
#   'ko',
#   'pd',
#   'diem',
#   'ayu',
#   'bantu',
#   'warganya',
#   'masa',
#   'kalah',
#   'gantian',
#   'tutup',
#   'jlnnya'],
#  ['kemungkinan',
#   'besar',
#   'ada',
#   'yg',
#   'gak',
#   'beres',
#   'dg',
#   'proses',
#   'penerbitan',
#   'imb'],
#  ['bisa',
#   'dirundingkan',
#   'lha',
#   'sebelumnya',
#   'ditawari',
#   'tanah',
#   'tetangganya',
#   'tidak',
#   'mau',
#   'ya',
#   'bukan',
#   'salah',
#   'yang',
#   'memblokade',
#   'makanya',
#   'harus',
#   'baik',
#   'baik',
#   'dengan',
#   'tetangga',
#   'dan',
#   'pengurus',
#   'rt',
#   'setempat'],
#  ['tdk',
#   'diperbolehkan',
#   'perda',
#   'membangun',
#   'tp',
#   'merugikan',
#   'tetangga',
#   'walaupun',
#   'di',
#   'lahan',
#   'sendiri',
#   'biasanya',
#   'jika',
#   'trjadi',
#   'spt',
#   'itu',
#   'dinas',
#   'pengawasan',
#   'pembangunan',
#   'akan',
#   'bertindak'],
#  ['masuuukkk', 'pakk', 'ekoo'],
#  ['pastinya', 'orang', 'ini', 'bermasalah', 'dengan', 'tetangganya', ''],
#  ['jual', 'sama', 'yg', 'ngeblokade'],
#  ['silaturahmi',
#   'dgn',
#   'tetangga',
#   'itu',
#   'penting',
#   'walau',
#   'akses',
#   'ditutup',
#   'kalau',
#   'tetangga',
#   'seperti',
#   'saudara',
#   'pasti',
#   'dikasih',
#   'jalan',
#   'tinggal',
#   'ketok',
#   'rumah',
#   'tetangga',
#   'terus',
#   'u201cmasuk',
#   'pak',
#   'ekou201d'],
#  ['imb', 'bisa', 'keluar'],
#  ['ya',
#   'hak',
#   'tetangga',
#   'juga',
#   'blokade',
#   'jalan',
#   'karena',
#   'mungkin',
#   'itu',
#   'tanah',
#   'tetangga',
#   'harusnya',
#   'di',
#   'musyawarahkan',
#   'baik2',
#   'dgn',
#   'tetangga',
#   'klo',
#   'kita',
#   'baik',
#   'ke',
#   'tetangga',
#   'gak',
#   'mungkin',
#   'tetangga',
#   'akan',
#   'setega',
#   'itu',
#   'memblokade',
#   'jlan'],
#  ['waras', 'slamet', 'pak', 'eko', 'tenang', 'aja', 'gusti', 'tak', 'sare'],
#  ['mana',
#   'kades',
#   'nya',
#   'masa',
#   'ada',
#   'warganya',
#   'yg',
#   'bermasalah',
#   'gini',
#   'ga',
#   'diselesaikan'],
#  ['surat',
#   'kog',
#   'dilempar',
#   'memangnya',
#   'koran',
#   '',
#   'meskipun',
#   'bener',
#   'koran',
#   'apa',
#   'sopan',
#   'lempar',
#   'koran',
#   'ke',
#   'presiden',
#   '',
#   'apa',
#   'gak',
#   'bisa',
#   'dititipkan',
#   'suratnya',
#   'lewat',
#   'paspampres',
#   ''],
#  ['ya',
#   'jelas',
#   'dikejar',
#   'pampapres',
#   'ngelempar',
#   'benda',
#   'seperti',
#   'itu',
#   'ke',
#   'presiden',
#   'itu',
#   'sudah',
#   'tugas',
#   'mereka',
#   'menjaga',
#   'presiden'],
#  ['sifatmu',
#   'mungkin',
#   'juga',
#   'ga',
#   'benar',
#   'main',
#   'lempar',
#   'surat',
#   'tanpa',
#   'pikir',
#   'kesopanan',
#   'instropeksi',
#   'pak',
#   'eko'],
#  ['tetangga', 'masa', 'gitu', ''],
#  ['u2063sepertinya',
#   'ada',
#   'yang',
#   '',
#   'kurang',
#   'beres',
#   'dengan',
#   'sertifikatnya',
#   'di',
#   'antara',
#   'rumah',
#   'rumah',
#   'itu',
#   'logikanya',
#   'rtrw',
#   'lurahcamat',
#   '',
#   'bppn',
#   'waktu',
#   'menerbitkan',
#   'sertifikat',
#   'itu',
#   'pasti',
#   'tahu',
#   'posisi',
#   'dan',
#   'batas',
#   'batas',
#   'rumah',
#   'pasti',
#   'ada',
#   'yang',
#   'salah',
#   'dengan',
#   'sertifikat',
#   'sertifikat',
#   'itu',
#   'tentang',
#   'batasbatas',
#   'tanahnya',
#   'minimal',
#   'ada',
#   'hak',
#   'orang',
#   'yang',
#   'diserobot',
#   'polisi',
#   'harus',
#   'turun',
#   'ini'],
#  ['wah',
#   'kalo',
#   'saja',
#   'sampe',
#   'ke',
#   'telinga',
#   'jokowi',
#   'pasti',
#   'akan',
#   'dibuatin',
#   'flyover'],
#  ['bandung',
#   '',
#   'jabar',
#   'ada',
#   'gubernur',
#   'baru',
#   'kalau',
#   'yang',
#   'dulu',
#   'emang',
#   'parah',
#   'sekarang',
#   'lapor',
#   'pasti',
#   'di',
#   'beresin',
#   'ngak',
#   'semuasemua',
#   'ke',
#   'presiden',
#   'kalees'],
#  ['katanya', 'pak', 'camat', 'tidak', 'tahu'],
#  ['yang',
#   'memblokade',
#   'pasti',
#   'orang',
#   'kuat',
#   'juga',
#   'orang',
#   'penting',
#   'sampai',
#   'camat',
#   'gak',
#   'bisa',
#   'nyelesaikan'],
#  ['sudah',
#   'bodoh',
#   'mau',
#   'menang',
#   'sendiri',
#   'ini',
#   'problem',
#   'di',
#   'daerah2',
#   'mengharapkan',
#   'tetangga',
#   'memberikan',
#   'jalan',
#   'sementara',
#   'mereka',
#   'banyak',
#   'yang',
#   'membuat',
#   'rumah',
#   'atau',
#   'pagar',
#   'melebihi',
#   'ukuran',
#   'sk',
#   'tanah',
#   'yang',
#   'dimiliki',
#   'alias',
#   'menyerobot',
#   'tanah',
#   'tetangga'],
#  ['coba', 'ke', 'kopi', 'joni', 'lahh'],
#  ['kalau',
#   'semua',
#   'ke',
#   'jokowi',
#   'ya',
#   'ga',
#   'mungkin',
#   'ada',
#   'jutaan',
#   'masalah',
#   'di',
#   'indonesia',
#   'urutannya',
#   'itu',
#   'bisa',
#   'minta',
#   'mediasi',
#   'didampingi',
#   'rtrw',
#   'ke',
#   'kelurahan',
#   'kalau',
#   'gagal',
#   'ya',
#   'ke',
#   'kecamatan',
#   'kalau',
#   'ga',
#   'bisa',
#   'dateng',
#   'mediasi',
#   'ya',
#   'tulis',
#   'surat',
#   'resmi',
#   'ke',
#   'kelurahan',
#   'kecamatan',
#   'kotamadya',
#   'kalau',
#   'tidak',
#   'ditanggapi',
#   'bisa',
#   'tulis',
#   'pengaduan',
#   'ke',
#   'ombudsman',
#   'banyak',
#   'kok',
#   'permasalahan',
#   'yg',
#   'sampai',
#   'ke',
#   'ombudsman',
#   'dan',
#   'langsung',
#   'di',
#   'follow',
#   'up',
#   'antara',
#   '12',
#   'bulan',
#   'ga',
#   'usah',
#   'tunggu',
#   '3',
#   'tahun',
#   'ngejar2',
#   'presiden'],
#  ['tp', 'msh', 'bisa', 'keluar', 'rumah', 'ga'],
#  ['inilah',
#   'contoh',
#   'manusia',
#   'indonesia',
#   'jaman',
#   'now',
#   'yg',
#   'katanya',
#   'pancasilais',
#   'ternyata',
#   'egois',
#   'tk',
#   'ada',
#   'toleransi',
#   'sedikitpun',
#   'kpd',
#   'sesama',
#   'pd',
#   'sesama',
#   'tetangga',
#   'rt',
#   'rw',
#   'lurah',
#   'nya',
#   'camaunya',
#   'walikota',
#   'nya',
#   'gubernur',
#   'nya',
#   'pancasila',
#   'nya',
#   'mana'],
#  ['akalnya',
#   'aja',
#   'kurang',
#   'pinter',
#   'itu',
#   'bikin',
#   'lif',
#   'sampai',
#   'atas',
#   'genteng',
#   'kan',
#   'bisa',
#   'terus',
#   'bikin',
#   'tol',
#   'diatas',
#   'genteng',
#   'sampai',
#   'jalan',
#   'raya',
#   'hehehe'],
#  ['pertanyaanya',
#   'bagaimana',
#   'hubungan',
#   'bertetangganya',
#   'kok',
#   'sampe',
#   'tega',
#   'di',
#   'block',
#   'gitu',
#   'kita',
#   'tdk',
#   'tau',
#   'ada',
#   'permasalahan',
#   'apa',
#   'sedangkan',
#   'pak',
#   'eko',
#   'slalu',
#   'bilang',
#   'privacy',
#   'lha',
#   'piye',
#   'to'],
#  ['surat',
#   'rumah',
#   'pak',
#   'eko',
#   'ternyata',
#   'gak',
#   'beres',
#   'pantesan',
#   'gak',
#   'ada',
#   'yg',
#   'bisa',
#   'belain',
#   'krn',
#   'secara',
#   'hukum',
#   'pak',
#   'eko',
#   'melakukan',
#   'pelanggaran',
#   'ternyata',
#   'pak',
#   'eko',
#   'minta',
#   'simpati',
#   'publik',
#   'pdhal',
#   'secara',
#   'hukum',
#   'dia',
#   'bersalah'],
#  ['knapa',
#   'buat',
#   'rumah',
#   'tidak',
#   'membuat',
#   'akses',
#   'utk',
#   'jalan',
#   'sendiri',
#   'bearti',
#   'selama',
#   'ini',
#   'mengambil',
#   'jalan',
#   'dari',
#   'tanah',
#   'orang',
#   'lain',
#   'mengambil',
#   'hak',
#   'tetangga',
#   'utk',
#   'kepentingan',
#   'sendiri'],
#  ['mungkin',
#   'pak',
#   'eko',
#   'disuruh',
#   'bayar',
#   'akses',
#   'jalan',
#   'tp',
#   'g',
#   'mau',
#   'kl',
#   'spt',
#   'ini',
#   'ya',
#   'g',
#   'akan',
#   'ada',
#   'titik',
#   'temu',
#   'krn',
#   'pemilik',
#   'jalan',
#   'mumgkin',
#   'beli',
#   'keseluruhan',
#   'tp',
#   'pak',
#   'eko',
#   'minta',
#   'cuma2',
#   'doang',
#   'tiap',
#   'jengkal',
#   'tanah',
#   'itu',
#   'berharga',
#   'apalagi',
#   'diperkotaan'],
#  ['aneh',
#   'sih',
#   'memang',
#   'kelakuan',
#   'tetangga',
#   'sprt',
#   'ini',
#   'biasanya',
#   'sihmhn',
#   'maaf',
#   'yg',
#   'sering',
#   'model2',
#   'tutup',
#   'jalan',
#   'tutup',
#   'got',
#   'krn',
#   'itu',
#   'dulu',
#   'tanah',
#   'engkong',
#   'gw',
#   'itu',
#   'dulu',
#   'punya',
#   'babak',
#   'gwkan',
#   'bukan',
#   'orang',
#   'sunda'],
#  ['salah',
#   'sendiri',
#   'lah',
#   'kenapa',
#   'dulu',
#   'gak',
#   'dijual',
#   'aja',
#   'tuh',
#   'rumah',
#   'jual',
#   'murah',
#   'aja',
#   'sama',
#   'tetangga',
#   'pake',
#   'njop',
#   'jgn',
#   'pake',
#   'harga',
#   'pasar',
#   'dungu',
#   'dipelihara',
#   ''],
#  ['aparat',
#   'kecamatan',
#   'sama',
#   'desa',
#   'nya',
#   'saja',
#   'yg',
#   'gk',
#   'becus',
#   'buat',
#   'me',
#   'mediasi',
#   'masalah',
#   'seperti',
#   'itu',
#   'ganti',
#   'langsung',
#   'camat',
#   'sama',
#   'lurah',
#   'nya',
#   'kok',
#   'ada',
#   'masyarakat',
#   'nya',
#   'susah',
#   'gk',
#   'segera',
#   'di',
#   'bantu',
#   'penyelesaian',
#   'masalah',
#   'nya'],
#  ['mas',
#   'eko',
#   'anda',
#   'harus',
#   'info',
#   'ke',
#   'media',
#   'sewaktu',
#   'anda',
#   'sudah',
#   'melaporkan',
#   'ke',
#   'dinas',
#   'terkait',
#   'bahkan',
#   'sampai',
#   'gubernur',
#   'dan',
#   'tidak',
#   'ditanggapiada',
#   'hrs',
#   'cerita',
#   'siapa',
#   'saja',
#   'sehingga',
#   'anda',
#   'tidak',
#   'sebar',
#   'fitnahbiar',
#   'oknum2',
#   'ini',
#   'biar',
#   'ditindak',
#   'bila',
#   'itu',
#   'benar',
#   'adanyajgn',
#   'pernah',
#   'takut'],
#  ['rt', 'rw', 'kelurahan', 'camat', 'gk', 'becus'],
#  ['sabar',
#   'pak',
#   'eko',
#   'semua',
#   'akan',
#   'di',
#   'selesaikan',
#   'dlm',
#   'hitungan',
#   'jam',
#   'tp',
#   'di',
#   'tahun',
#   '2019',
#   'setelah',
#   'rezim',
#   'berganti'],
#  ['hhhh',
#   'aneh',
#   'org',
#   'lempar',
#   'kertas',
#   'dikejar',
#   'tapi',
#   'org',
#   'bisa',
#   'nepuk',
#   'jokowi',
#   'wkt',
#   'touring',
#   'motor',
#   'ga',
#   'diinterogasi',
#   'atau',
#   'dilumpuhkan',
#   'paspampressetting',
#   'pencitraan',
#   'atau',
#   'paspampresnya',
#   'yg',
#   'ga',
#   'becus',
#   'ngawal',
#   'presiden'],
#  ['teu',
#   'make',
#   'duit',
#   'mah',
#   'rek',
#   'aya',
#   'anu',
#   'peduli',
#   'kumaha',
#   'atuh',
#   'kang',
#   'sing',
#   'sadar',
#   'weh',
#   'ayeunamah',
#   'urang',
#   'hirup',
#   'di',
#   'nagara',
#   'kos',
#   'kumaha'],
#  ['kelihatannya',
#   'semua',
#   'tanahnya',
#   'sudah',
#   'ber',
#   'sertifikat',
#   'kenapa',
#   'tidak',
#   'di',
#   'pertanyakan',
#   'ke',
#   'badan',
#   'pertanahan',
#   'seharusnya',
#   'tidak',
#   'ada',
#   'penerbitan',
#   'sertifikat',
#   'tanpa',
#   'ada',
#   'jalan',
#   'melalui',
#   'tanah',
#   'tersebut',
#   'kalo',
#   'tidak',
#   'ada',
#   'tanggapan',
#   'dari',
#   'bpn',
#   'maka',
#   'ajukan',
#   'gugatan',
#   'ke',
#   'ptun',
#   'dimana',
#   'bpn',
#   'sebagai',
#   'tergugat',
#   '1'],
#  ['harusnya',
#   'waktu',
#   'dikejar',
#   'nyerahin',
#   'diri',
#   'aja',
#   'biar',
#   'pak',
#   'jokowi',
#   'tau',
#   'masalahnya',
#   'tapi',
#   'kenapa',
#   'bapak',
#   'lari',
#   'sih',
#   'itu',
#   'kesempatan',
#   'emas',
#   'padahal',
#   'pak'],
#  ['pemerintah', 'bandung', 'gak', 'becus', 'kerja'],
#  ['ya', 'iyalah', 'maen', 'lempar', 'aja'],
#  ['sebenarnya',
#   'masalahnya',
#   'apa',
#   'kenapa',
#   'tidak',
#   'ada',
#   'penyelesaian',
#   'mana',
#   'bupati',
#   'bandung',
#   'kenapa',
#   'diam',
#   'diam',
#   'saja',
#   'minta',
#   'dipecat',
#   ''],
#  ['coba',
#   'diselesaikan',
#   'secara',
#   'kekeluargaan',
#   'dg',
#   'hati',
#   'dingin',
#   'tanpa',
#   'erosi',
#   'insyaallah',
#   'ketemu',
#   'jalanyaud83dude0e'],
#  ['aneh',
#   'segitu',
#   'egoisnya',
#   'kah',
#   'paravtetangga',
#   'rt',
#   'rw',
#   'sama',
#   'lurah',
#   'gak',
#   'bisa',
#   'tangani',
#   'kah',
#   'mudah2an',
#   'masalah',
#   'ini',
#   'nyampr',
#   'ke',
#   'jokowi',
#   'biar',
#   'masalah',
#   'selesai',
#   'sebenarnya',
#   'masalah',
#   'kyk',
#   'gini',
#   'bukan',
#   'urusan',
#   'presiden',
#   'karena',
#   'nyangkut2',
#   'urusan',
#   'paspampres',
#   'atau',
#   'oknum',
#   'yg',
#   'ngaku2',
#   'paspampres',
#   'jadi',
#   'gak',
#   'ada',
#   'salahnya',
#   'pak',
#   'jokowi',
#   'bantu',
#   'selesaikan',
#   'masalah'],
#  ['sepertinya',
#   'dua',
#   'pihak',
#   'awal',
#   'nya',
#   'sama2',
#   'kepala',
#   'batu',
#   'sehingga',
#   'kejadian',
#   'seperti',
#   'itu',
#   'akhirnya'],
#  ['kok',
#   'bisa',
#   'bangun',
#   'rumah',
#   'tp',
#   'akses',
#   'ke',
#   'jalan',
#   'nya',
#   'ga',
#   'ada',
#   'pasti',
#   'ga',
#   'ada',
#   'imb',
#   'nya',
#   'yaaa'],
#  ['tetangga', 'gila'],
#  ['jual', 'aja', 'rmhnya', 'pa', 'gitu', 'aja', 'repot'],
#  ['gimana',
#   'mau',
#   'nuntut',
#   'hak',
#   'bukan',
#   'tanah',
#   'nya',
#   'kok',
#   'yg',
#   'di',
#   'sekitar',
#   'nya',
#   'sdh',
#   'tau',
#   'dari',
#   'dulu',
#   'sehrsnya',
#   'jual',
#   'pindah',
#   'dong'],
#  ['apesstressnasib', 'orang', 'kecil'],
#  ['gambar',
#   'lokasi',
#   'bangunan',
#   'beserta',
#   'tetangganya',
#   'bisa',
#   'diupload',
#   'jg',
# ...
#   'kdekatan',
#   'dan',
#   'jasa',
#   'pak',
#   'maruf',
#   'hrusnya',
#   'sby',
#   'mndukung',
#   'dan',
#   'mngusungnya',
#   'tpi',
#   'karena',
#   'udh',
#   'kplang',
#   'baper',
#   'dan',
#   'udh',
#   'kplang',
#   'janji',
#   'sama',
#   'prabowo',
#   'walau',
#   'berat',
#   'hati',
#   'ya',
#   'mau',
#   'gk',
#   'mau',
#   'mngusung',
#   'prabowo'],
#  ['ketum', 'demokrat', 'sdh', 'kagak', 'ada', 'giginya'],
#  ['nafsu', 'berkuasa', 'ya', 'hahaha'],
#  ['jelas',
#   'bisa',
#   'dimengerti',
#   'rakyat',
#   'papua',
#   'merasakan',
#   'sekali',
#   'apa',
#   'yg',
#   'sdh',
#   'dilakukan',
#   'pres',
#   'jokowi',
#   'disanaprinsip',
#   'keadilan',
#   'nyata',
#   'dilakukan',
#   'bukan',
#   'sekedar',
#   'jargon',
#   'politik',
#   '2019orangbaikhasilnyabaik'],
#  ['ngomong',
#   'ngak',
#   'kuat',
#   'krn',
#   'kardus',
#   'sdh',
#   'di',
#   'embat',
#   'kelakuan',
#   'politisi',
#   'sontoloyo'],
#  ['coba',
#   'pendapat',
#   'bapak',
#   'ini',
#   'disampaikan',
#   'ke',
#   'junjungan',
#   'bapakar',
#   'supaya',
#   'gak',
#   'nyinyirkata',
#   'beliau',
#   'gak',
#   'mungkin'],
#  ['ibarat',
#   'bangunan',
#   'mewah',
#   'koalisi',
#   'ini',
#   'sebenarnya',
#   'kropos',
#   'dan',
#   'rapuhgmn',
#   'mau',
#   'mau',
#   'menang',
#   'ini',
#   'ngurus',
#   'intern',
#   'koalisi',
#   'iji',
#   'aja',
#   'ga',
#   'bisahidup',
#   'jkw',
#   '2',
#   'periode'],
#  ['hahahahaseru',
#   'nehmantap',
#   'masa',
#   'pks',
#   'dan',
#   'pan',
#   'aja',
#   'yg',
#   'dapat',
#   'sikatlah',
#   'pd',
#   'jgn',
#   'mau',
#   'dibohongi',
#   'sama',
#   'gerindra',
#   'pks',
#   'dan',
#   'panhahaha'],
#  ['hajar',
#   'bleh',
#   'sikat',
#   'terus',
#   'masa',
#   'cuma',
#   'mereka',
#   'doang',
#   'yang',
#   'dapat',
#   'kardus',
#   'pd',
#   'engga',
#   'ayo',
#   'jangan',
#   'mau',
#   'tuntut',
#   'juga',
#   'bagian',
#   'kardusmu'],
#  ['koalisi',
#   'gak',
#   'mutupercuma',
#   'lo',
#   'pada',
#   'eker2nyungsep',
#   'lo',
#   'semua'],
#  ['mau',
#   'menuding',
#   'dua',
#   'atau',
#   'tiga',
#   'kaki',
#   'juga',
#   'gamasalah',
#   'bosyg',
#   'penting',
#   'pks',
#   'sudah',
#   'dapat',
#   '500',
#   'mberarti',
#   'pertahun',
#   '100mlumayan',
#   'kan',
#   'coba',
#   'klw',
#   'ngandalkan',
#   'dari',
#   'hasil',
#   'korupsi',
#   'atau',
#   'pemberian',
#   'jangan2',
#   'di',
#   'ott',
#   'sama',
#   'kpk',
#   'ahirnya',
#   'gigit',
#   'jari',
#   'donk',
#   'klw',
#   'ini',
#   'kan',
#   'barter',
#   'meskipun',
#   'nantinya',
#   'kalah',
#   '',
#   'pasti',
#   'kalah',
#   'dlm',
#   'pilpres',
#   'gamasalah',
#   'yg',
#   'rugi',
#   'kan',
#   'bukan',
#   'pks',
#   'atau',
#   'pan',
#   'paham',
#   'kan',
#   'sekarangyg',
#   'penting',
#   'duitnya',
#   'gerindra',
#   'sdh',
#   'keluar',
#   '',
#   'klw',
#   'ada',
#   'bahasa',
#   'untuk',
#   'kampanye',
#   'itu',
#   'kan',
#   'cuma',
#   'alasan',
#   'saja',
#   'biar',
#   'garibut'],
#  ['yahh',
#   'kenyataannya',
#   'semuanya',
#   'main',
#   '2',
#   'kaki',
#   'dan',
#   'oportunis',
#   'mau',
#   'apa',
#   'lagi'],
#  ['andi',
#   'juga',
#   'aneh',
#   'pake',
#   'ngomong',
#   'udah',
#   'jelas',
#   'parte',
#   'kemunafikan',
#   'sejati',
#   'cebong',
#   'kejet2',
#   'gagal',
#   'mupe',
#   'on'],
#  ['yah', 'apakah', 'masih', 'percaya', 'dengan', 'omomgannya'],
#  ['kalau', 'panas', 'dalam', 'minum', 'tuh', 'kaki', '3', 'biar', 'ademhehe'],
#  ['ketua', 'diam', '', 'bisa', 'dianggap', 'seruju'],
#  ['udaah',
#   'mending',
#   'bubar',
#   'aja',
#   'niih',
#   'koalisi',
#   'ga',
#   'bermutubukanya',
#   'bikin',
#   'program',
#   'malah',
#   'ribut',
#   'sendiri',
#   'mendiing',
#   'bubar',
#   'lagian',
#   'sdh',
#   'pasti',
#   'kalah',
#   'kok',
#   'ngapain',
#   'd',
#   'lanjutkan'],
#  ['haqulyakin',
#   'pekaes',
#   'dan',
#   'pante',
#   'nyungsep',
#   'suaranya',
#   'pemilu',
#   '2019'],
#  ['koalisi', 'serapuh', 'kardus', 'basah'],
#  ['andi',
#   'arief',
#   'yg',
#   'selalu',
#   'menyerang',
#   'koalisi',
#   'sendiri',
#   'ini',
#   'kenapa',
#   'tdk',
#   'ditegur',
#   'sby',
#   'ada',
#   'apa',
#   'di',
#   'koalisi',
#   'prabowo',
#   'sandiaga',
#   '',
#   'padahal',
#   'bersikap',
#   'pura2',
#   'netral',
#   'di',
#   'pilpres',
#   '2014',
#   'sama',
#   'juga',
#   'bermain',
#   '2',
#   'kaki',
#   'pak',
#   'andi'],
#  ['dulu',
#   'mencari',
#   'makan',
#   'setelah',
#   'menjabat',
#   'jadi',
#   'kaya2',
#   'bahkan',
#   'daging',
#   'juga',
#   'di',
#   'empat',
#   'penjara',
#   'dan',
#   'akhirnya',
#   'neraka'],
#  ['nah', 'lu', 'kena', 'deh'],
#  ['kardus', 'kardus', 'kardusmana', 'bagian', 'kardusku'],
#  ['politik', 'cari', 'makan', 'alias', 'parpol', 'kardus'],
#  ['dia', 'minta', 'isi', 'kardus', 'tu'],
#  ['badut',
#   'badut',
#   'politikkerja',
#   'nolll',
#   'buat',
#   'rakyatnyir',
#   'nyir',
#   'bocor',
#   'coorrrrrrr'],
#  ['u2063jokowi',
#   'menang',
#   'mudah',
#   'di',
#   'pilpres',
#   '2019',
#   'democraaat',
#   'nyungsep'],
#  ['jokowi',
#   'menang',
#   'mudah',
#   'di',
#   'pilpres',
#   '2019',
#   'democraaat',
#   'nyungsep'],
#  ['lebih', 'bagus', 'cap', 'kaki', 'tigabisa', 'buat', 'kesehatan'],
#  ['kaki', 'empatud83dude07'],
#  ['salam', 'dua', 'kaki', 'euyhahaha'],
#  ['pak',
#   'sby',
#   'itu',
#   'kalau',
#   'ngomong',
#   'selalu',
#   'pinjam',
#   'banyak',
#   'moncong',
#   'mas',
#   'kayak',
#   'ban',
#   'bocor',
#   'alus',
#   'tapi',
#   'kelilingud83dude03',
#   'baru',
#   'lahir',
#   'ya'],
#  ['kl',
#   'sudah',
#   'berdasarkan',
#   'data',
#   'dan',
#   'fakta',
#   'ya',
#   'susah',
#   'untuk',
#   'dijawab',
#   'hahahaha'],
#  ['setdeh',
#   'kho',
#   'seneng',
#   'banget',
#   'ribut',
#   'sich',
#   'rebutan',
#   'apa',
#   'lagi',
#   'nech',
#   'engingeng',
#   'datang',
#   'zonk',
#   'ah',
#   'nggak',
#   'papa',
#   'masih',
#   'solid',
#   'kho',
#   'itu',
#   'hanya',
#   'dinamika',
#   'politikcapek',
#   'dech'],
#  ['sesama', 'begundal', 'politik', 'dilarang', 'saling', 'mendahului', ''],
#  ['karena',
#   'aa',
#   'pakai',
#   'data',
#   'dan',
#   'fakta',
#   'maka',
#   'tidak',
#   'bisa',
#   'berbalas',
#   'pantun'],
#  ['pan', '', 'pks', 'sebaiknya', 'diam', 'klo', 'ga', 'punya', 'kaca'],
#  ['koalisi',
#   'aja',
#   'ribut',
#   'gimana',
#   'mau',
#   'menang',
#   'jargon',
#   'doang',
#   'kenceng',
#   'kualitas',
#   'nol'],
#  ['mari',
#   'kita',
#   'bertepuk',
#   'tangansesama',
#   'begundal',
#   'sdh',
#   'mulai',
#   'ribut'],
#  ['kayaknya',
#   'bener',
#   'juga',
#   'dulu',
#   'kan',
#   'koalisi',
#   'demokrat',
#   'tp',
#   'sering',
#   'gak',
#   'nurut'],
#  ['diam', 'itu', 'emas'],
#  ['lah',
#   'ngapain',
#   'jg',
#   'ribut2',
#   'politik',
#   'pilkada',
#   'kemaren',
#   'jg',
#   'banyak',
#   'koalisi',
#   'ngacak',
#   'politik',
#   'disini',
#   'ya',
#   'gt',
#   'cari',
#   'sensasi',
#   'doang'],
#  ['bukan',
#   '2',
#   'kaki',
#   'itu',
#   'mah',
#   'yg',
#   'kita',
#   'tahu',
#   '',
#   'tapi',
#   '4',
#   'kaki',
#   '',
#   '2',
#   'kaki',
#   'yg',
#   'sah',
#   '',
#   '2',
#   'kaki',
#   'yg',
#   'siri',
#   'kan',
#   ''],
#  ['main',
#   'dua',
#   'kaki',
#   'saat',
#   'pemilu',
#   'sudah',
#   'usai',
#   'bargain',
#   'dan',
#   'kompromi',
#   'lah',
#   'ini',
#   'baru',
#   'mau',
#   'mulai',
#   'haha',
#   'cerdas',
#   'dong',
#   'kamu',
#   'dek'],
#  ['pd',
#   'pan',
#   'pks',
#   'semua',
#   'ahli',
#   'main',
#   '2',
#   'kaki',
#   'cuman',
#   'gerindra',
#   'yg',
#   'ga',
#   'punya',
#   'kaki'],
#  ['andi', 'arief', 'dicari', 'bawaslu', 'tuh'],
#  ['abis',
#   'mau',
#   'bagemana',
#   'lagi',
#   'ga',
#   'mau',
#   'rugi',
#   'maunya',
#   'untung',
#   'terus'],
#  ['bertiga', 'saling', 'selingkuh'],
#  ['andi',
#   'arief',
#   'ini',
#   'awalnya',
#   'mencak2',
#   'teriak2',
#   'terkait',
#   'dana',
#   'logistik',
#   '500m',
#   'untuk',
#   'kubu',
#   'koalisi',
#   'prabowo',
#   'karena',
#   'demokrat',
#   'tdk',
#   'di',
#   'ajak',
#   'bicara',
#   'sekarang',
#   'diem',
#   'dia',
#   'di',
#   'amankan',
#   'oleh',
#   'sandi',
#   'wajar',
#   'andi',
#   'arief',
#   'ini',
#   'ngebela',
#   'demokrat',
#   'dan',
#   'sby'],
#  ['tepatnya', 'pan', 'dan', 'pks', 'tergantung', 'bayaran'],
#  ['satu',
#   'koalisi',
#   'aja',
#   'udah',
#   'gak',
#   'kompak',
#   'gmn',
#   'mau',
#   'menang',
#   'udah',
#   'pd',
#   'jgn',
#   'ribut',
#   'nikmatin',
#   'aja',
#   'dl',
#   'kardus2nya',
#   'mudah2',
#   'anjlog',
#   'hancura',
#   'suara',
#   'kalian',
#   'di',
#   'pemilu',
#   '2019'],
#  ['salut',
#   'buat',
#   'timses',
#   'padi',
#   'dinamika',
#   'adalah',
#   'keharusan',
#   'dlm',
#   'sebuah',
#   'perjuangan',
#   'politik',
#   'ada',
#   'perbedaan',
#   'pendapat',
#   'kritik',
#   'juga',
#   'wajar2',
#   'saja',
#   'solid',
#   'gak',
#   'perlu',
#   'harus',
#   'yes',
#   'semua',
#   'diam',
#   'seribu',
#   'bahasa',
#   'spt',
#   'dikekang',
#   '',
#   'satu',
#   'suara',
#   'seperti',
#   'koalisi',
#   'jokowi',
#   'yg',
#   'ujung2nya',
#   'melampiaskan',
#   'uneg2',
#   'dgn',
#   'menyerang',
#   'koalisi',
#   'lawanberbeda',
#   'suara',
#   'bukan',
#   'masalah',
#   'tapi',
#   'saling',
#   'menghargai',
#   'harus',
#   'dijaga',
#   '',
#   'dekati',
#   'terus',
#   'rakyat',
#   'krn',
#   'rakyatlah',
#   'yg',
#   'menentukan',
#   'kemenangan',
#   'di',
#   'pilpres',
#   'nanti'],
#  ['hajar'],
#  ['percaya',
#   'dehklo',
#   'jokowi',
#   'menang',
#   'lgpan',
#   'akan',
#   'merapat',
#   'ke',
#   'jokowi',
#   'lg',
#   'supaya',
#   'dpt',
#   'mentri',
#   'lgkan',
#   'kmpren',
#   'brgitu'],
#  ['pd',
#   'maen',
#   'dua',
#   'kaki',
#   'di',
#   'parlemen',
#   'seabis',
#   'pilpres',
#   'katenye',
#   'netral',
#   'tapi',
#   'condong',
#   'ke',
#   'kmp'],
#  ['kelompok', 'sebelah', 'pemain', '2', 'kaki', 'semua', 'wkwkwkwk'],
#  ['andi', 'arif', 'buang', 'aja', 'bikin', 'rusuh', 'aja'],
#  ['ayo', 'bertengkar', 'lah', 'aku', 'suka', 'hahaha'],
#  ['andi', 'arif', 'knp', 'yam'],
#  ['jadi', 'penonton', 'ah', 'menghibur'],
#  ['ular',
#   'beludak',
#   'ini',
#   'keluar',
#   'lagi',
#   'setelah',
#   'mumpet',
#   'terkencing2',
#   'tdk',
#   'berani',
#   'bicara',
#   'di',
#   'dpn',
#   'bawaslu',
#   'ud83dude03'],
#  ['sudah',
#   'tahu',
#   'bahwa',
#   'kalau',
#   'berkata',
#   'bohong',
#   '',
#   'tidak',
#   'sesuai',
#   'omongan',
#   'kalau',
#   'janji',
#   'ingkar',
#   '',
#   'plinplan',
#   'kalau',
#   'dipercaya',
#   'ingkar',
#   'tidak',
#   'konsisten',
#   'tahu',
#   'munafik',
#   'kok',
#   'seteju',
#   'yg',
#   'waras',
#   'siapa',
#   'ya'],
#  ['u2063pertempuran',
#   'utama',
#   'di',
#   'pilpres',
#   '2019',
#   'ialah',
#   'jawa',
#   'barat',
#   'jawa',
#   'tengah',
#   'jawa',
#   'timur',
#   'sumatera',
#   'utara',
#   'dan',
#   'sulawesi',
#   'selatan',
#   'jawa',
#   'tengah',
#   'jelas',
#   'sudah',
#   'dijaga',
#   'ganjar',
#   'jawa',
#   'timur',
#   'ada',
#   'mbak',
#   'khofifah',
#   'jawa',
#   'barat',
#   'kemungkinan',
#   'dengan',
#   'naiknya',
#   'rk',
#   'jokowi',
#   'bakal',
#   'menang',
#   'sulawesi',
#   'selatan',
#   'pasti',
#   'ada',
#   'efek',
#   'dari',
#   'jk',
#   'sebagai',
#   'timses',
#   'jokowi',
#   'hanya',
#   'sumatera',
#   'utara',
#   'yang',
#   'masih',
#   'bisa',
#   'diperebutkan',
#   'oleh',
#   'kedua',
#   'koalisi'],
#  ['aduhorang',
#   '',
#   'orang',
#   'jangan',
#   'di',
#   'pilih',
#   'biar',
#   'negiri',
#   'ini',
#   'tidak',
#   'segera',
#   'bubar'],
#  ['belah', 'sono', 'ribut', 'terus', 'y'],
#  ['mungkin', 'sedang', 'panas', 'dalam', 'nambah', 'satu', 'kaki', 'lagi'],
#  ['kalo',
#   'pks',
#   'mah',
#   'emang',
#   'ga',
#   'ada',
#   'malunya',
#   'ikut',
#   'kabinet',
#   'sby',
#   'tapi',
#   'ngacak2',
#   'program',
#   'sbypresiennya',
#   'aja',
#   'sampe',
#   'makan',
#   'aspal',
#   'di',
#   'jalan',
#   'nangka',
#   'noh'],
#  ['ada', 'hubungannya', 'dengan', 'kardus', 'ga', 'nih', ''],
#  ['maling',
#   'teriak',
#   'maling',
#   'koalisi',
#   'kok',
#   'saling',
#   'menjelekkan',
#   'ud83dude02'],
#  ['bagus', 'bro', 'hajar', 'terussss', ''],
#  ['apa',
#   'yang',
#   'diungkapkan',
#   'bung',
#   'andi',
#   'arif',
#   'benar',
#   'sekali',
#   'kita',
#   'masih',
#   'ingat',
#   'waktu',
#   'pks',
#   'ikut',
#   'dalam',
#   'kabinet',
#   'pak',
#   'sby',
#   'tapi',
#   'apabila',
#   'ada',
#   'kebijakan',
#   'dari',
#   'sby',
#   'selalu',
#   'ditentang'],
#  ['ni',
#   'orang',
#   'dri',
#   'awal',
#   'udh',
#   'mulai',
#   'ribet',
#   'sebaik',
#   'nya',
#   'klo',
#   'memang',
#   'gk',
#   'searah',
#   'pecat',
#   'ni',
#   'pa',
#   'sby'],
#  ['pd',
#   'bubar',
#   'ajalah',
#   'uda',
#   'gak',
#   'ada',
#   'wibawa',
#   'di',
#   'mata',
#   'kadernya',
#   'apa',
#   'karena',
#   'ketumnya',
#   'gak',
#   'tegas',
#   'atau',
#   'mgkn',
#   'hal',
#   'yg',
#   'sengaja',
#   'dibuat',
#   'utk',
#   'main',
#   'dua',
#   'kaki',
#   'alias',
#   'mempraktekan',
#   'politik',
#   'bermuka',
#   'dua'],
#  ['lo',
#   'pade',
#   'ngomong',
#   'ngaler',
#   'ngidul',
#   'ga',
#   'jelas',
#   '',
#   'bangsa',
#   'ini',
#   'banyak',
#   'masalah',
#   'perburuhan',
#   'ekonomi',
#   'problem',
#   'kebangsaan',
#   'benturan',
#   'umat',
#   'dll',
#   'perlu',
#   'strong',
#   'leader',
#   '',
#   'pas',
#   'ok',
#   ''],
#  ['gawatttt',
#   'harusnya',
#   'pak',
#   'prabowo',
#   'kirim',
#   'utusan',
#   'mautnya',
#   'kayak',
#   'ahmad',
#   'dhani',
#   'neno',
#   'sarumpaet',
#   'ke',
#   'papua',
#   'wkwkwk'],
#  ['kader2mya',
#   'pd',
#   'cerdas',
#   'juga',
#   'ga',
#   'mau',
#   'dijadikan',
#   'boneka',
#   'gerindrong',
#   'cs'],
#  ['yang',
#   'jelas',
#   'perolehan',
#   'suaran',
#   'jokowi',
#   '',
#   'maruf',
#   'amin',
#   'akan',
#   'bertambahud83dude06'],
#  ['kira2',
#   'kalau',
#   'di',
#   'adu',
#   'dari',
#   'sisi',
#   'intelektual',
#   'kecerdasan',
#   'kesederhanaan',
#   'kepemimpinan',
#   'kekayaan',
#   'dari',
#   '4',
#   'kandidat',
#   'capres',
#   '',
#   'cawapres',
#   'siapa',
#   'yg',
#   'menang',
#   'ya',
#   '',
#   'gampang',
#   '',
#   'sandi',
#   'yg',
#   'menang',
#   '',
#   'muda',
#   'kaya',
#   'pinter',
#   'cerdas',
#   'sederhana',
#   'dan',
#   'yg',
#   'paling',
#   'penting',
#   '',
#   'setia',
#   'sama',
#   'istri',
#   'dan',
#   'sayang',
#   'anak',
#   '',
#   'gila',
#   '',
#   'perfect',
#   'banget',
#   'sih',
#   'lo',
#   'sandi',
#   '',
#   'yg',
#   'lain',
#   'pada',
#   'main',
#   'bini',
#   'muda',
#   'sama',
#   'selingkuh',
#   '',
#   'lo',
#   'yg',
#   'duitnya',
#   'banyak',
#   'kok',
#   'malah',
#   'setia',
#   '',
#   'top'],
#  ['2019jokowipresiden'],
#  ['bagi',
#   '90',
#   'pengurus',
#   'dpd',
#   'demokrat',
#   'di',
#   'papua',
#   'ini',
#   'hati',
#   'nurani',
#   'mereka',
#   'lebih',
#   'punya',
#   'integritas',
#   'krn',
#   'mereka',
#   'tau',
#   'sesungguhnya',
#   'siapa',
#   'yg',
#   'selama',
#   'ini',
#   'bekerja',
#   'utk',
#   'warganya'],
#  ['rakyat',
#   'papua',
#   'tau',
#   'mana',
#   'presiden',
#   'yang',
#   'perhatian',
#   'dengan',
#   'papua',
#   'mana',
#   'yang',
#   'purapura',
#   'perhatian',
#   'btw',
#   'balikin',
#   'kardusnya',
#   'sandi'],
#  ['jati',
#   'diri',
#   'gak',
#   'pentinglah',
#   'yahyg',
#   'penting',
#   'menangklik',
#   'google',
#   'hambalang'],
#  ['emang',
#   'jokowi',
#   'masih',
#   'diinginkan',
#   'sebagian',
#   'besar',
#   'rakyat',
#   'untuk',
#   'menjadi',
#   'presiden',
#   '2',
#   'periode',
#   'kok'],
#  ['masalah',
#   'papua',
#   'itu',
#   'sangat',
#   'gampang',
#   'dan',
#   'malah',
#   'terlalu',
#   'gampang',
#   'merebut',
#   'suara',
#   'orang',
#   'papua',
#   'sbb',
#   'orang',
#   'papua',
#   'gak',
#   'denger',
#   'gubernur',
#   'asal',
#   'di',
#   'serahkan',
#   'sama',
#   'yg',
#   'ahli',
#   'nya',
#   'di',
#   'jamin',
#   '100',
#   'beresyg',
#   'jelas',
#   'bkn',
#   'masalah',
#   'infra',
#   'struktur',
#   'sbb',
#   'yg',
#   'menikmati',
#   'nya',
#   'tetap',
#   'pendatang',
#   'sdgkn',
#   'orang',
#   'asli',
#   'papua',
#   'ttp',
#   'jd',
#   'penontonserahkan',
#   'pada',
#   'ahli',
#   'nya',
#   'papua',
#   'pasti',
#   'prabowo',
#   'sandi'],
#  ['demokrat',
#   'seharusnya',
#   'join',
#   'dengan',
#   'jokowi',
#   'saja',
#   'tim',
#   'prabowo',
#   'sandi',
#   'ga',
#   'butuh',
#   'demokrat',
#   'cukup',
#   'masyarakatemak2gerindrapkspan',
#   'saja',
#   'sudah',
#   'pasti',
#   'menang',
#   'di',
#   '2019'],
#  ['woi',
#   'kembalikan',
#   'kardusnya',
#   'kalo',
#   'ga',
#   '100',
#   'dukung',
#   'wowowkwkwk'],
#  ['alhamdulillah', 'amin'],
#  ['sebaiknya',
#   'demokrat',
#   'ke',
#   'jokowi',
#   'saja',
#   'tdk',
#   'apa',
#   'apa',
#   'pks',
#   'pan',
#   'gerindra',
#   'sangat',
#   'solid'],
#  ['harusx',
#   'dpd',
#   'tdk',
#   'bisa',
#   'mengatur',
#   'dppkepututsan',
#   'dpp',
#   'harusx',
#   'satu',
#   'komandomiris',
#   'jg',
#   'ini'],
#  ['demokrat', 'plin', 'plan'],
#  ['karna',
#   'tdk',
#   'terbendung',
#   'suara',
#   'kader',
#   'yg',
#   'terbelah',
#   'berobah',
#   'strategi',
#   'demi',
#   'menutup',
#   'muka',
#   'yg',
#   'sudah',
#   'malukasihan',
#   'demokrat'],
#  ['100', 'paksoalnya', 'joko', 'wi', 'orang', 'baik', ''],
#  ['rakyat',
#   'papua',
#   'merasakan',
#   'langsung',
#   'pembangunan',
#   'era',
#   'presiden',
#   'jokowi'],
#  ['hasil', 'akhirnya', 'dan', 'saya', 'yakin', 'jokowi', 'kalah', 'dipapua'],
#  ['bagus',
#   'jangan',
#   'ikut',
#   'orang',
#   'jahat',
#   'saudara2',
#   'papua',
#   'merasakan',
#   'pembangunan'],
#  ['apa', 'kata', 'gerinda', 'cs', 'ya', 'hayo', 'apa'],
#  ['karena', 'papu', 'maju'],
#  ['mbah', 'mien', 'langsung', 'kejangkejang'],
#  ['mereka',
#   'ini',
#   'yg',
#   'bener2',
#   'sdh',
#   'merasakan',
#   'langsung',
#   'dampak',
#   'pembangunan',
#   'jalan',
#   'dan',
#   'sebagainya',
#   'di',
#   'sana',
#   'tidak',
#   'bisa',
#   'ditutupi',
#   'dan',
#   'disangkal',
#   'lagi'],
#  ...]

# %%
#Menghilangkan token yang kosong
for comment in tok_comments:
    for sub_comment in comment:
        if sub_comment == '':
            comment.remove(sub_comment)

# %%
tok_comments
# Out:
# [['wkwkwk',
#   'gak',
#   'sekalian',
#   'pak',
#   'selawat',
#   'ke',
#   'dpr',
#   'kan',
#   'banyak',
#   'koruptor',
#   'disana'],
#  ['mantab',
#   'ini',
#   'br',
#   'dakwah',
#   'yg',
#   'sejati',
#   'kl',
#   'd',
#   'tempat',
#   'umum',
#   'mah',
#   'dh',
#   'biasa',
#   'ini',
#   'luar',
#   'biasa'],
#  ['salut', 'buat', 'gus', 'miftah'],
#  ['yg',
#   'nyinyir',
#   'gak',
#   'pernah',
#   'lihat',
#   'dan',
#   'baca',
#   'atw',
#   'mengetahui',
#   'sejarah',
#   'dakwah',
#   'walisongo',
#   'sunan',
#   'kali',
#   'jagasmua',
#   'ada',
#   'cara',
#   'demi',
#   'kebaikan',
#   'asal',
#   'jng',
#   'ajk',
#   'dg',
#   'cara',
#   'berjinah',
#   'lakukan',
#   'dg',
#   'porsi',
#   'dan',
#   'sikon',
#   'yg',
#   'tepat'],
#  ['ada',
#   'adabnya',
#   'sholawat',
#   'lebih',
#   'baik',
#   'ajak',
#   'ke',
#   'majelis',
#   'ilmu'],
#  ['setiap',
#   'ulama',
#   'punya',
#   'jalan',
#   'dan',
#   'cara',
#   'dakwah',
#   'masing2',
#   'jika',
#   'kamu',
#   'melihat',
#   'kemunkaran',
#   'lawan',
#   'dengan',
#   'tanganmukekuatanmu',
#   'jika',
#   'tidak',
#   'mampu',
#   'lawan',
#   'dengan',
#   'mulutmu',
#   'jika',
#   'tidak',
#   'mampu',
#   'juga',
#   'dengan',
#   'hatimu',
#   'itulah',
#   'selemah',
#   'lemahnya',
#   'iman',
#   'itu',
#   'sudah',
#   'menjadi',
#   'kewajiban',
#   'para',
#   'ulama',
#   'kalo',
#   'yg',
#   'komen',
#   'masih',
#   'ada',
#   'yg',
#   'nyinyirin',
#   'ulama',
#   'berarti',
#   'otaknya',
#   'sudah',
#   'disisipin',
#   'politik'],
#  ['umpanin', 'nocannya', 'yak'],
#  ['itulah', 'ceramah', 'yg', 'sebenarnya'],
#  ['besok', 'bugil', 'aja', 'selawat'],
#  ['bedanya',
#   'gus',
#   'miftah',
#   'dengan',
#   'fpi',
#   'hti',
#   'bagaikan',
#   'surga',
#   'dan',
#   'neraka',
#   'di',
#   'surga',
#   'penuh',
#   'kasih',
#   'di',
#   'neraka',
#   'penuh',
#   'penghancuran'],
#  ['knp',
#   'di',
#   'tempat',
#   'kerjanya',
#   'mending',
#   'diundang',
#   'ke',
#   'masjid',
#   'ponpes',
#   'aula',
#   'supaya',
#   'berbusana',
#   'yg',
#   'sopan'],
#  ['nah',
#   'ini',
#   'ulama',
#   'beneranditerima',
#   'di',
#   'semua',
#   'kalangankl',
#   'uas',
#   'malah',
#   'diblokir',
#   'sana',
#   'sini'],
#  ['kerennn',
#   'saya',
#   'pernah',
#   'dpt',
#   'info',
#   'seperti',
#   'ini',
#   'dr',
#   'keyakinan',
#   'yg',
#   'lain',
#   'tapi',
#   'tujuan',
#   'utama',
#   'kurang',
#   'lebih',
#   'sama',
#   'lah',
#   'kita',
#   'ambil',
#   'sisi',
#   'positifnya',
#   'ajah',
#   'terimakasih',
#   'atas',
#   'niat',
#   'baiknya',
#   'saya',
#   'yakin',
#   'pasti',
#   'bermanfaat'],
#  ['hebat',
#   'guslanjutkaninilah',
#   'makna',
#   'dakwah',
#   'sebenarnya',
#   'sampaikan',
#   'marwah',
#   'islam',
#   'dengan',
#   'penuh',
#   'kedamaian',
#   'dan',
#   'berikan',
#   'pemahaman',
#   'bukan',
#   'dengan',
#   'kebencian',
#   'dan',
#   'pemaksaan'],
#  ['diskotik', 'syariah', 'jadunya', 'nih', 'wkwkwkmantap'],
#  ['niat',
#   'dan',
#   'tujuan',
#   'yg',
#   'baik',
#   'pasti',
#   'mendapat',
#   'berkah',
#   'dr',
#   'allah',
#   'swt'],
#  ['mantaaappppbuat', 'di', 'gedung', 'dpr', 'perlu', 'jg', 'kayanya', 'gus'],
#  ['salut', 'buat', 'owner', 'klub', 'ini'],
#  ['josshhh', 'ini', 'baru', 'luar', 'biasa'],
#  ['dapat', 'gratisan', 'karena', 'sudah', 'punya', 'nope'],
#  ['sebaiknya',
#   'dimanapun',
#   'dilakukan',
#   'batas2',
#   'kesopanan',
#   'tetap',
#   'harus',
#   'dijaga'],
#  ['pemandu',
#   'lagi',
#   'yang',
#   'di',
#   'manga',
#   'besar',
#   'keknya',
#   'perlu',
#   'juga',
#   'diajak',
#   'mengaji',
#   'bos'],
#  ['jujur',
#   'ini',
#   'kereennnnnnn',
#   'cara',
#   'menyebarkan',
#   'agama',
#   'yang',
#   'baik',
#   'dan',
#   'snagat',
#   'simpatik',
#   'semoga',
#   'sukses'],
#  ['katimbang',
#   'alim',
#   'kemudian',
#   'jadi',
#   'maling',
#   'menurut',
#   'saya',
#   'lebih',
#   'baik',
#   'maling',
#   'kemudian',
#   'jadi',
#   'alim'],
#  ['sebenar',
#   'ulama',
#   'mengajak',
#   'mereka',
#   'yg',
#   'masih',
#   'tersesat',
#   'untuk',
#   'kembali',
#   'bukan',
#   'menjelekkan',
#   'orang',
#   'lain',
#   'tp',
#   'merangkul',
#   'mereka'],
#  ['ini', 'namanya', 'apa', 'ya'],
#  ['selamat',
#   'berjuang',
#   'gusjustru',
#   'tempat',
#   'seperti',
#   'itu',
#   'yg',
#   'butuh',
#   'lebih',
#   'bnyk',
#   'perhatian',
#   'dr',
#   'ulama'],
#  ['semoga', 'diberikan', 'hidayah'],
#  ['hati',
#   'hati',
#   'memviralkan',
#   'berita',
#   'yang',
#   'mengandung',
#   'isu',
#   'agama',
#   'bisa',
#   'menjadi',
#   'sumber',
#   'fitnah',
#   'dan',
#   'lahan',
#   'para',
#   'bedebah',
#   'yang',
#   'kerjanya',
#   'mengadu',
#   'domba',
#   'anak',
#   'bangsa',
#   'dan',
#   'rakyat',
#   'indonesia',
#   'ahok',
#   'sudah',
#   'jadi',
#   'korbannya'],
#  ['subhanallah',
#   'semoga',
#   'mendapatkan',
#   'hidayah',
#   'dari',
#   'allah',
#   'swt',
#   'amin'],
#  ['ulama', 'ngurus', 'umat', 'berarti', 'jenengan', 'gus'],
#  ['luar',
#   'biasa',
#   'salutterharu',
#   'mengajak',
#   'orang',
#   'lain',
#   'yang',
#   'dianggap',
#   'salah',
#   'dengan',
#   'cara',
#   'yang',
#   'baik',
#   'bukan',
#   'dengan',
#   'cacianluar',
#   'biasa'],
#  ['whats', 'up', 'boshe'],
#  ['lol',
#   'jadi',
#   'ketahuan',
#   'dong',
#   'isinya',
#   'boshe',
#   'bali',
#   'bukan',
#   'org',
#   'bali',
#   'ud83dude02ud83dude02'],
#  ['poligami', 'aja', 'guss'],
#  ['harusnya', 'dibakar', 'tempat', 'begituan', 'kalik'],
#  ['hahahaha',
#   'bahasa',
#   'hastag',
#   'y',
#   'kalo',
#   'd',
#   'plesetkan',
#   'jadi',
#   'y',
#   'santri',
#   'gaul',
#   'itu',
#   'yg',
#   'suka',
#   'sholawat',
#   'dan',
#   'suka',
#   'dugem',
#   'hahahaha',
#   'rusak',
#   'islam',
#   'd',
#   'biaskan',
#   'seperti',
#   'ini',
#   'ustad',
#   'y',
#   'dateng',
#   'k',
#   'sono',
#   'dugem',
#   'dulu',
#   'lalu',
#   'sholawat',
#   'lalu',
#   'dugem',
#   'lagi',
#   'dan',
#   'd',
#   'sebut',
#   'santri',
#   'gaul'],
#  ['knp',
#   'yg',
#   'kayak',
#   'gini',
#   'berita',
#   'nya',
#   'keluar',
#   'nya',
#   'pas',
#   'mau',
#   'pilpres',
#   'aja',
#   'ya'],
#  ['naaaah',
#   'ini',
#   'baru',
#   'bener',
#   'ceramah',
#   'atau',
#   'ngajak',
#   'orang',
#   'yg',
#   'belum',
#   'bersholawat',
#   'utk',
#   'bersholawat',
#   'ga',
#   'kaya',
#   'somat',
#   'ngajak',
#   'orang',
#   'sholawat',
#   'koq',
#   'ke',
#   'orang',
#   'yg',
#   'udah',
#   'bersholawat',
#   'maaaaat',
#   'mat'],
#  ['gila',
#   'nekat',
#   'juga',
#   'ulamanya',
#   'gak',
#   'tau',
#   'di',
#   'usir',
#   'gitu',
#   'tapi',
#   'bagus',
#   'lah',
#   'ada',
#   'keberanian',
#   'dan',
#   'semuanya',
#   'jg',
#   'mendengarkan',
#   'semoga',
#   'banyak',
#   'ustad',
#   'lainnya',
#   'yang',
#   'meniru',
#   'hal',
#   'ini'],
#  ['tambah',
#   'tempat',
#   'mantap',
#   'sak',
#   'cewek',
#   'seksi',
#   'nyadan',
#   'yg',
#   'paling',
#   'penting',
#   'bole',
#   'yg',
#   'g',
#   'setuju',
#   'pasti',
#   'ngiriweek'],
#  ['mengajak',
#   'orang',
#   'melakukan',
#   'sholawat',
#   'di',
#   'tempat',
#   'ibadah',
#   'ya',
#   'sudah',
#   'pasti',
#   'mudah',
#   'tapi',
#   'mengajak',
#   'orang',
#   'melakukan',
#   'sholawat',
#   'di',
#   'tempat',
#   'dugem',
#   'yang',
#   'penuh',
#   'cobaan',
#   'itu',
#   'sudah',
#   'jelas',
#   'pahala',
#   'nya',
#   'jauh',
#   'lebih',
#   'besar'],
#  ['apa',
#   'sih',
#   'yg',
#   'nggak',
#   'bisa',
#   'di',
#   'negeri',
#   'ini',
#   'semua',
#   'pada',
#   'bisa',
#   'sekrang'],
#  ['boleh', 'ya', 'menyebarkan', 'agama', 'seperti', 'ini'],
#  ['hahahaha', 'lucu', 'lucuan', 'biar', 'masuk', 'tipi', 'laah', 'hahaha'],
#  ['coba',
#   'lah',
#   'ustad',
#   'yg',
#   'lain',
#   'dakwah',
#   'di',
#   'nite',
#   'club',
#   'spt',
#   'iti'],
#  ['yang',
#   'ini',
#   'malah',
#   'di',
#   'dukung',
#   'yang',
#   'di',
#   'sana',
#   'di',
#   'jagain',
#   'supaya',
#   'ga',
#   'ceramah',
#   'apalagi',
#   'ini'],
#  ['ah',
#   'entahlah',
#   'satu',
#   'kau',
#   'maklumi',
#   'yg',
#   'lain',
#   'mengikuti',
#   'tinggal',
#   'tunggu',
#   'saja'],
#  ['mau', 'ngikik', 'takut', 'dosa'],
#  ['kalau',
#   'mau',
#   'melakukan',
#   'ibadah',
#   'perbaiki',
#   'dulu',
#   'penampilan',
#   'jauhi',
#   'miras',
#   'cari',
#   'tempat',
#   'yg',
#   'lebih',
#   'baik',
#   'lebih',
#   'baik',
#   'gus',
#   'kamu',
#   'mengajak',
#   'para',
#   'wanita',
#   'itu',
#   'menutupi',
#   'auratnya'],
#  ['lokalisasi', 'harapan', 'sadar'],
#  ['setelah', 'selawat', 'selesai', 'acara', 'selanjutnya'],
#  ['bagus', 'lanjutkan'],
#  ['bagus',
#   'itu',
#   'biar',
#   'sadar',
#   'islam',
#   'tdk',
#   'mengajari',
#   'kaumnya',
#   'buka',
#   'aurat',
#   'bagus',
#   'lanjut'],
#  ['banser', 'anshor', 'mana', 'suaranyaormas', 'liberal'],
#  ['pans',
#   'itu',
#   'ketika',
#   'simbah',
#   'yg',
#   'bicara',
#   'selalu',
#   'dibully',
#   'karena',
#   'kata',
#   'katanya',
#   'terkesan',
#   'emosional',
#   'nantang',
#   'nantang',
#   'pdhl',
#   'ketika',
#   'tantangan',
#   'bisa',
#   'di',
#   'buktikan',
#   'oleh',
#   'yg',
#   'di',
#   'tantang',
#   'trus',
#   'diem',
#   'tdk',
#   'ksatria',
#   'ngakui',
#   'dan',
#   'sering',
#   'menjelek',
#   'jelekkan',
#   'orang',
#   'lain',
#   'inilah',
#   'yg',
#   'jd',
#   'penyebab',
#   'sering',
#   'di',
#   'bully',
#   'dan',
#   'orang',
#   'lain',
#   'jd',
#   'gak',
#   'simpati',
#   'mungkin',
#   'dia',
#   'dengan',
#   'berkata',
#   'seperti',
#   'itu',
#   'merasa',
#   'hebat',
#   'dia',
#   'tdk',
#   'sadar',
#   'saat',
#   'nyapres',
#   'pun',
#   'rontok',
#   'saat',
#   'thn',
#   '2014',
#   'pun',
#   'keok',
#   'artinya',
#   'rakyat',
#   'g',
#   'percayaseolah',
#   'bicara',
#   'dulu',
#   'urusan',
#   'belakang',
#   'spt',
#   'janji',
#   'jalan',
#   'kaki',
#   'jogja',
#   'jakarta',
#   'terbukti',
#   'gak',
#   'kan',
#   'ini',
#   'mungkin',
#   'hal',
#   'sepele',
#   'bagi',
#   'dia',
#   'tapi',
#   'itu',
#   'tertanam',
#   'di',
#   'ingatan',
#   'oranghingga',
#   'berkesimpulan',
#   'klo',
#   'hanya',
#   'bisa',
#   'ngomong',
#   'tok',
#   'nglakoni',
#   'ora',
#   'iso'],
#  ['karena', 'mendukung', 'jokowi', 'jadi', 'tidak', 'dicopot'],
#  ['banyak', 'orang', 'pekalongan', 'yg', 'kemakan', 'hoax'],
#  ['pan',
#   'ancur',
#   'lebur',
#   'gara2',
#   'si',
#   'amien',
#   'rasis',
#   'makasih',
#   'amien',
#   'lanjutkan',
#   '2019panbakalgurem'],
#  ['padahal',
#   'sutrisno',
#   'bakhir',
#   'ini',
#   'dulunya',
#   'merupakan',
#   'penyandang',
#   'dana',
#   'pak',
#   'amin',
#   'rais',
#   'saat',
#   'awal',
#   'reformasi',
#   'akhirnya',
#   'berjalan',
#   'sendiri2'],
#  ['orang',
#   'bener',
#   'malah',
#   'tidak',
#   'dipake',
#   'di',
#   'pansutrisno',
#   'itu',
#   'sdh',
#   'habis2an',
#   'demi',
#   'pan',
#   'tapi',
#   'tetap',
#   'tdk',
#   'berdaya',
#   'melawan',
#   'amien',
#   'raispan',
#   'cahayanya',
#   'semakin',
#   'tidak',
#   'bersinar',
#   'sejak',
#   'amien',
#   'makin',
#   'kumat'],
#  ['lagu', 'lama'],
#  ['pan', 'sekarang', 'butek', 'karena', 'diobok2', 'si', 'amien'],
#  ['karena', 'mendukung', 'jadi', 'tdk', 'dicopot'],
#  ['masak',
#   'sih',
#   'dari',
#   'beberapa',
#   'ex',
#   'pemimpin',
#   'pan',
#   'yg',
#   'punya',
#   'pikiran',
#   'sehat',
#   'cuma',
#   'pak',
#   'sutrisno'],
#  ['tolong',
#   'dikoreksi',
#   'untuk',
#   'jabatan',
#   'pak',
#   'pramono',
#   'itu',
#   'menseskab',
#   'bukan',
#   'mensesneg',
#   'terima',
#   'kasih'],
#  ['mantap',
#   'bukti',
#   'orang',
#   'baik',
#   'pasti',
#   'banyak',
#   'yg',
#   'mendukung',
#   'salam',
#   '2',
#   'periode'],
#  ['ksih', 'mkan', 'buaya', 'aja', 'org', 'kyak', 'gini'],
#  ['mantab',
#   'penyebar',
#   'fitnah',
#   'bisa',
#   'tidur',
#   'di',
#   'bui',
#   'jg',
#   'akhirnya'],
#  ['allahuakbar',
#   'alhamdulillah',
#   'akhirnya',
#   'para',
#   'ahlul',
#   'fitnah',
#   'penebar',
#   'kebencian',
#   'tersebut',
#   'dipenjara',
#   'juga',
#   'sudah',
#   'cukup',
#   'lama',
#   'mereka',
#   'menunggu',
#   'nikmatnya',
#   'lp',
#   'cipinang'],
#  ['selamat',
#   'menikmati',
#   'hukuman',
#   'dunia',
#   'atas',
#   'prilaku',
#   'fitnah',
#   'menebar',
#   'kebencian',
#   'hukuman',
#   'akhirat',
#   'yg',
#   'lebih',
#   'berat',
#   'menunggu',
#   'anda',
#   'para',
#   'ahlul',
#   'fitnah',
#   'penebar',
#   'kebencian'],
#  ['dasar',
#   'preman',
#   'ngak',
#   'tanggung',
#   'jawab',
#   'kok',
#   'malah',
#   'buron',
#   'katanya',
#   'lu',
#   'anak',
#   'buah',
#   'wowo',
#   'yg',
#   'bocor',
#   'bocor',
#   'itu',
#   'hehehhe'],
#  ['orang',
#   'grindong',
#   'gak',
#   'akan',
#   'ngomentari',
#   'brita',
#   'ini',
#   'krena',
#   'sebagian',
#   'tabir',
#   'obor',
#   'rakyat',
#   'sdh',
#   'dibuka',
#   'sebagian',
#   'oleh',
#   'rommy'],
#  ['ayo',
#   'gerombolannya',
#   'kok',
#   'nggak',
#   'ada',
#   'yang',
#   'komentar',
#   'nih',
#   'biasanya',
#   'koar2',
#   'bilang',
#   'pelanggaran',
#   'ham',
#   'seperti',
#   'menangkap',
#   'teroris',
#   'pakai',
#   'senjata',
#   'lengkap',
#   'dsb'],
#  ['sik',
#   'asik',
#   'selamat',
#   'menikmati',
#   'hotel',
#   'prodeo',
#   'kawan',
#   'siapa',
#   'menebar',
#   'angin',
#   'dia',
#   'menuai',
#   'badai'],
#  ['buni', 'yaniiii', 'dimana', 'anda', 'kejaaarr'],
#  ['wowo', 'ga', 'sekalian'],
#  ['jangan',
#   'tangkap',
#   'pimrednya',
#   'doank',
#   'tangkap',
#   'penyadang',
#   'dana',
#   'dan',
#   'hubungan',
#   'mereka',
#   'dgn',
#   'kandidat',
#   'capres',
#   'yg',
#   'diusung'],
#  ['walaupun',
#   'cuma',
#   '1',
#   'tahun',
#   'ente',
#   'sudah',
#   'dapat',
#   'gelar',
#   'mantan',
#   'narapidana',
#   'menjelang',
#   'pemilu',
#   'buat',
#   'lagi',
#   'biar',
#   'dikurung',
#   '10tahun',
#   'makan',
#   'gratis'],
#  ['gantung', 'az'],
#  ['sekalian', 'buni', 'yani', 'biar', 'adil'],
#  ['kirim', 'ke', 'kamar', 'bonita', 'bonita', 'itu', 'nama', 'macan'],
#  ['gua',
#   'paling',
#   'senang',
#   'liat',
#   'ginian',
#   'buronan',
#   'sensasinya',
#   'kayak',
#   'di',
#   'film2',
#   'hollywood'],
#  ['tungguin',
#   'aja',
#   'nih',
#   'bentar',
#   'lagi',
#   'kubu',
#   'prabocor',
#   'terutama',
#   'zonk',
#   'bakalan',
#   'komen',
#   'liat',
#   'aja'],
#  ['karena', 'kabur', 'tambahin', 'yah', 'hukuman', 'nya'],
#  ['ini', 'kabar', 'terbagus', 'yang', 'boleh', 'kudengar', 'hari', 'ini'],
#  ['telat', 'kabur', 'tongkaciann'],
#  ['nyari',
#   'duit',
#   'dr',
#   'nyebar',
#   'fitnahduitnya',
#   'buat',
#   'makan',
#   'anak',
#   'istrimau',
#   'jd',
#   'apa',
#   'anakmu',
#   'makan',
#   'duit',
#   'gituan'],
#  ['semoga', 'bahagia', 'di', 'rumah', 'yg', 'baru'],
#  ['periksa',
#   'bank',
#   'account',
#   'nya',
#   'atau',
#   'bank',
#   'account',
#   'keluarga',
#   'ada',
#   'transferan',
#   'nggak',
#   'dari',
#   'wowo'],
#  ['semoga',
#   'bisa',
#   'belajar',
#   'untuk',
#   'tdk',
#   'mencari',
#   'nafkah',
#   'dari',
#   'uang',
#   'hitam',
#   'dengan',
#   'cara',
#   'yang',
#   'hitam'],
#  ['suntik', 'mati'],
#  ['sikat',
#   'semua',
#   'org',
#   'org',
#   'pengacau',
#   'negeri',
#   'demi',
#   'uang',
#   'apalagi',
#   'mo',
#   'pilpres',
#   'malah',
#   'bikin',
#   'kacau',
#   'negara',
#   'klo',
#   'ga',
#   'segera',
#   'dikarungin'],
#  ['habisin',
#   'aja',
#   'jok',
#   'orang',
#   'yang',
#   'gangu',
#   'elu',
#   'jadi',
#   'presiden',
#   'lgi'],
#  ['nunggu',
#   'buni',
#   'yani',
#   'kapan',
#   'ditangkapnya',
#   'pdhl',
#   'sdh',
#   'ada',
#   'putusan',
#   'pengadilan',
#   'jg'],
#  ['koq', 'cuma', 'setahun'],
#  ['laaaahhh',
#   'bukannya',
#   'kata',
#   'nasbung',
#   'pemred',
#   'obor',
#   'rakyat',
#   'diangkat',
#   'jadi',
#   'prekom',
#   'bumnwelehwelehitu',
#   'fitnah',
#   'lagi',
#   'dong'],
#  ['kapan', 'buni', 'yani'],
#  ['sip',
#   'tinggal',
#   'yg',
#   'kabur',
#   'umroh',
#   'ga',
#   'balik2',
#   'segera',
#   'dieksekusi',
#   'pak',
#   'pol'],
#  ['yg',
#   'model',
#   'ginian',
#   'main',
#   'fitnah',
#   'sih',
#   'mesti',
#   'di',
#   'kandangin'],
#  ['mantap'],
#  ['sip'],
#  ['semoga', 'pas', 'di', 'dalam', 'penjarakedua2nya', 'gantung', 'diri'],
#  ['terbukti',
#   'memfitnah',
#   'bukan',
#   'menghina',
#   'dan',
#   'ingat',
#   'fitnah',
#   'lebih',
#   'kejam',
#   'dari',
#   'pembunuhan',
#   'bro'],
#  ['hukuman', 'mati'],
#  ['alhamdulillah', 'si', 'penebar', 'dosa', 'sudah', 'tertangkap'],
#  ['jokowi',
#   'sudah',
#   'memaafkan',
#   'tapi',
#   'proses',
#   'hukum',
#   'tetap',
#   'berlaku',
#   'bos'],
#  ['hmm'],
#  ['siap2', 'buat', 'gerombolan', 'micin', 'ama', 'nasi', 'bungkus'],
#  ['tambah', 'hukumannya', 'karena', 'mau', 'kabur'],
#  ['lho', 'kok', 'cuma', '1', 'tahun', '5', 'thn', 'pantas', 'kok'],
#  ['yg',
#   'menjamin',
#   'mau',
#   'mem',
#   'back',
#   'up',
#   'mereka',
#   'pada',
#   'kemana',
#   'mau',
#   'menemani',
#   'mereka',
#   'hidup',
#   'bersama',
#   'di',
#   'lp',
#   'cipinang',
#   'jangan',
#   'macem',
#   'ayam',
#   'sayur',
#   'lari',
#   'lintang',
#   'pukang',
#   'meninggalkan',
#   'kawan'],
#  ['gagah',
#   'saat',
#   'bikin',
#   'obor',
#   'rakyat',
#   'mewek',
#   'dan',
#   'buron',
#   'saat',
#   'diproses',
#   'hukum',
#   'dasar',
#   'preman',
#   'gembeng',
#   'kalau',
#   'begini',
#   'apakah',
#   'orang',
#   'yang',
#   'anda',
#   'junjung',
#   'akan',
#   'gantian',
#   'membela',
#   'anda'],
#  ['2019gantipresiden',
#   'kelihatan',
#   'bgt',
#   'tebang',
#   'pilihnya',
#   'hukum',
#   'tajam',
#   'ke',
#   'lawan',
#   'politik',
#   'tumpul',
#   'ke',
#   'cebong😏'],
#  ['orangnya',
#   'tambah',
#   'gemuk',
#   'makan',
#   'uang',
#   'sisa',
#   'anggaran',
#   'obor',
#   'rakyat'],
#  ['buset',
#   'dahjamintelnya',
#   'tetangga',
#   'sebelah',
#   'rumahnya',
#   'sendirimiris'],
#  ['bisa', 'jadi', '2019', 'muncul', 'petromak', 'rakyat', '😹😹'],
#  ['kalau',
#   'sudah',
#   'dieksekusi',
#   'ngga',
#   'lagi',
#   'dilindungi',
#   'kan',
#   'sama',
#   'janji',
#   'back',
#   'up',
#   'kalo',
#   'kena',
#   'masalah',
#   'hehehe',
#   'makan',
#   'tuh',
#   'janji',
#   'saat',
#   'kampanye'],
#  ['makan', 'pencarian', 'lu', 'tuhhhhh'],
#  ['selamat', 'ya'],
#  ['masih', 'mudabuaknnya', 'mendukung', 'presiden', 'generasi', 'mudapayah'],
#  ['yess',
#   'tidur',
#   'aaaah',
#   'biar',
#   'cepet',
#   'besok',
#   'ada',
#   'yg',
#   'berani',
#   'taruhan',
#   'siapa',
#   'yang',
#   'belain',
#   'mereka'],
#  ['tukang', 'fitnah', 'hukum', 'seberat2nya'],
#  ['hrsnya', 'min', '10thn', 'di', 'sel'],
#  ['nah',
#   'ini',
#   'dia',
#   'paling',
#   'lawyernya',
#   'habibu',
#   'getombolan',
#   'nasi',
#   'bungkus',
#   'micin',
#   'jantungan'],
#  ['cuma', '1', 'thn', 'enak', 'bener'],
#  ['ini',
#   'bodoh',
#   'amat',
#   'cuma',
#   '8',
#   'bulan',
#   'seharusnya',
#   'jangan',
#   'banding',
#   'malah',
#   'jadi',
#   '2',
#   'tahun'],
#  ['bos', 'nya', 'sikat'],
#  ['mari',
#   'kita',
#   'tunggu',
#   'siapa',
#   'saja',
#   'yg',
#   'nyinyir',
#   'atas',
#   'penangkapan',
#   'ini'],
#  ['muka2', 'tegar', 'menjalani', 'hukuman'],
#  ['bosnya', 'dah', 'ketangkap', 'blum'],
#  ['wowok', 'cs', 'banyak', 'mudarat', 'nya'],
#  ['bravo', 'kejaksaan', 'selamat', 'bertugas'],
#  ['hukum', 'seberatberatnya'],
#  ['kalo',
#   'cebong',
#   'mah',
#   'gk',
#   'di',
#   'tangkap',
#   'kebal',
#   'hukum',
#   'spt',
#   'viktor',
#   'laiskodat',
#   'ade',
#   'armando',
#   'nathan',
#   'ananda',
#   'sukarlan',
#   'dll',
#   '2019gantipresiden😏'],
#  ['good',
#   'job',
#   'jgn',
#   'lupa',
#   'gerombolan',
#   'surveyor',
#   'ines',
#   'juga',
#   'hrs',
#   'diawasi',
#   'dr',
#   'pada',
#   'menyebarkan',
#   'hasil',
#   'survey',
#   'abal',
#   'abal',
#   'apalagi',
#   'mo',
#   'pilpres',
#   'malah',
#   'bikin',
#   'perpecahan'],
#  ['sdh',
#   'dibongkar',
#   'kan',
#   'sama',
#   'pak',
#   'romi',
#   'pasti',
#   'ada',
#   'pendananya',
#   'si',
#   'kejar',
#   'juga',
#   'pak',
#   'jaksaterus',
#   'pak',
#   'berjuang',
#   'demi',
#   'bersihnya',
#   'negara',
#   'ini',
#   'dari',
#   'tukang',
#   'fitnah'],
#  ['usut', 'dana', 'nya', 'dari', 'mana', 'itu', 'baru', 'hebat👍'],
#  ['silahkan',
#   'bernyanyi',
#   'denga',
#   'bebas',
#   'walaupum',
#   'sumbangtempat',
#   'telah',
#   'disediakanwkwkwkwkkw'],
#  ['kok', 'cuma', 'setahun'],
#  ['ayo',
#   'donk',
#   'polisi',
#   'kalo',
#   'nangkep2',
#   'kaya',
#   'gini',
#   'dicari',
#   'tahu',
#   'bosnya',
#   'siapa',
#   'siapa',
#   'yang',
#   'memberi',
#   'dana',
#   'terus',
#   'kalo',
#   'udah',
#   'tau',
#   'tangkep',
#   'lansung'],
#  ['disate', 'aje', 'pak', 'jaksa'],
#  ['tembak', 'jidat', 'nya'],
#  ['tangkap',
#   'bandar',
#   'dan',
#   'pemimpin',
#   'gembong',
#   'hoaxnya',
#   'biar',
#   'jelas'],
#  ['tukang', 'fitnah', 'plus', 'juragannya', 'wajib', 'dihukum'],
#  ['sudah',
#   'terbukti',
#   'komplotan',
#   'sana',
#   'cuma',
#   'bisa',
#   'fitnah',
#   'hoax',
#   'pki',
#   'kerjanya',
#   'ngga',
#   'ada'],
#  ['mendingan', 'ditenggelamkan', 'aje'],
#  ['aktor',
#   'intelektual',
#   'yang',
#   'mendanai',
#   'kerja',
#   'obor',
#   'rakyat',
#   'untuk',
#   'kepentingan',
#   'politik',
#   'sang',
#   'aktor',
#   'intelektual',
#   'juga',
#   'harus',
#   'di',
#   'tangkap',
#   'dan',
#   'ditenggelamkan'],
#  ['mo',
#   'bgs',
#   'atau',
#   'gapresiden',
#   'itu',
#   'kepala',
#   'negara',
#   'yg',
#   'hrs',
#   'dihormatikl',
#   'lu',
#   'hina',
#   'ya',
#   'pantaslah',
#   'msk',
#   'bui'],
#  ['mo',
#   'bgs',
#   'atau',
#   'gapresiden',
#   'itu',
#   'kepala',
#   'negara',
#   'yg',
#   'hrs',
#   'dihormatikl',
#   'lu',
#   'hina',
#   'ya',
#   'pantaslah',
#   'msk',
#   'bui'],
#  ['mo',
#   'bgs',
#   'atau',
#   'gapresiden',
#   'itu',
#   'kepala',
#   'negara',
#   'yg',
#   'hrs',
#   'dihormatikl',
#   'lu',
#   'hina',
#   'ya',
#   'pantaslah',
#   'msk',
#   'bui'],
#  ['tukang', 'fitnah', 'dan', 'penyebar', 'hoax', 'tenggelamkan'],
#  ['hhahahh',
#   'ya',
#   'jelas',
#   'uda',
#   'ketebak',
#   'negri',
#   'dagelan',
#   'yg',
#   'komen',
#   'jga',
#   'blaa',
#   'blaaa',
#   'blaaaa',
#   '😂🤣😂🤣',
#   'lanjutakan',
#   'saja'],
#  ['terima', 'kasih', 'kejaksaan'],
#  ['pak',
#   'jaksa',
#   'yg',
#   'hina',
#   'pak',
#   'jokowi',
#   'berkali2',
#   'pasti',
#   'pak',
#   'jaksa',
#   'tau',
#   'lahtolong',
#   'di',
#   'seret',
#   'ke',
#   'penjara',
#   'thanks'],
#  ['sekalipun',
#   'benci',
#   'dng',
#   'jokowi',
#   'bukan',
#   'berarti',
#   'menebar',
#   'fitnah',
#   'biar',
#   'bgaimanapun',
#   'jokowi',
#   'itu',
#   'presiden',
#   'pilihan',
#   'rakyat',
#   'memfitnah',
#   'presiden',
#   'memfitnah',
#   'rakyat'],
#  ['buron', 'wkwk'],
#  ['kalo',
#   'di',
#   'turki',
#   'ini',
#   'orang',
#   'sudah',
#   'diciduk',
#   'langsung',
#   'oleh',
#   'erdogan',
#   'presiden',
#   'idaman',
#   'nya',
#   'pks',
#   '🤣',
#   'untung',
#   'lah',
#   'di',
#   'indonesia',
#   'ini',
#   'presiden',
#   'nya',
#   'jokowi',
#   'yg',
#   'orang',
#   'nya',
#   'lembut',
#   'dan',
#   'kalem',
#   '😁'],
#  ['kalo', 'dulu', 'menang', 'udah', 'diangkat', 'menteri', 'nih', 'orang'],
#  ['kalo', 'dulu', 'menang', 'udah', 'diangkat', 'menteri', 'nih', 'orang'],
#  ['kalo', 'dulu', 'menang', 'udah', 'diangkat', 'menteri', 'nih', 'orang'],
#  ['kalo', 'dulu', 'menang', 'udah', 'diangkat', 'menteri', 'nih', 'orang'],
#  ['kalo', 'dulu', 'menang', 'udah', 'diangkat', 'menteri', 'nih', 'orang'],
#  ['boss', 'nya', 'juga', 'sekalian', 'disikat', 'toilet'],
#  ['boss', 'nya', 'juga', 'sekalian', 'disikat', 'toilet'],
#  ['jadi', 'inget', 'jaman', 'siapa', 'ya'],
#  ['orang', 'bikin', 'rusak', 'harus', 'musnahkan'],
#  ['super', 'muantap👍👍👍'],
#  ['baguslah',
#   'diciduk',
#   'sebelum',
#   'dikontrak',
#   'lagi',
#   'sama',
#   'tukang',
#   'fitnah'],
#  ['menjelekan',
#   'presiden',
#   'sama',
#   'saja',
#   'menghina',
#   'lambang',
#   'negara',
#   'harusnya',
#   'berpikir',
#   'apalagi',
#   'seorang',
#   'redaksi',
#   'berita',
#   'yang',
#   'seharusnya',
#   'menjadi',
#   'panutan',
#   'beritanya'],
#  ['semoga', 'betah', 'di', 'hotel', 'prodeo', 'ya', 'bro'],
#  ['sebaiknya', 'orang', 'spt', 'ini', 'dilenyapkan', 'saja'],
#  ['sikat', 'ikat', 'berkas'],
#  ['fitnah', 'krn', 'duit', '😆'],
#  ['tlg', 'dikubur', 'dalam2', 'org', 'begini'],
#  ['langsung', 'buang', 'aja', 'kelaut'],
#  ['tunggu', 'siapa', 'yang', 'komen', 'membelanah', 'itu', 'donaturnya'],
#  ['buniyani', 'gmn'],
#  ['kokk',
#   'lama',
#   'sekali',
#   'pelaku',
#   'kejahatan',
#   'hoax',
#   'ini',
#   'baru',
#   'dijebloskan',
#   'ke',
#   'bui',
#   'sekarang',
#   'usut',
#   'dan',
#   'tangkap',
#   'segera',
#   'pelaku',
#   'hoax',
#   'lainnya'],
#  ['obor', 'hoax'],
#  ['bravo', 'kejaksaanlumayan', 'ada', 'kerjanya'],
#  ['mantap', 'hajar', 'penyebar', 'hoax'],
#  ['yg', 'di', 'negri', 'sebrang', 'bgmn'],
#  ['4', 'tahun', 'pantesnya', '40', 'taon'],
#  ['itu', 'dlu', 'timses', 'syp', 'ea'],
#  ['masih', 'bisa', 'gaya', 'gaya', 'an', 'lihat', 'baju', 'mereka', 'seperti'],
#  ['mudah', '2', 'an', 'di', 'hukun', 'lebih', 'berat', 'lagi'],
#  ['wkwkwkwkwkw',
#   'syukurlah',
#   'kalian',
#   'banding',
#   'soalnya',
#   'hukuman',
#   'kalian',
#   'bakal',
#   'di',
#   'tambah',
#   'jd',
#   '10',
#   'thn',
#   'nyungsep',
#   'kalian'],
#  ['sakit', 'jiwa', 'luuu'],
#  ['sakit', 'jiwa', 'lluu'],
#  ['kasihan', 'bener', 'mas', 'eko', 'semoga', 'dapat', 'jalan', 'keluarnya'],
#  ['jahat', 'sekali', 'yang', 'nipu'],
#  ['sebutin', 'aja', 'pengacaranya'],
#  ['nah',
#   'mulai',
#   'terkuak',
#   'biang',
#   'keladinya',
#   'siapkan',
#   'bukti2',
#   'penyerahan',
#   'surat2',
#   'dan',
#   'tanda',
#   'terima',
#   'uang',
#   'dikasi',
#   'ga',
#   'waktu',
#   'entu',
#   'kalo',
#   'ga',
#   'ada',
#   'bukti',
#   'jangan',
#   'kau',
#   'harap',
#   'bisa',
#   'gugat',
#   'pengacara',
#   'ya'],
#  ['semoga',
#   'dapat',
#   'pengganti',
#   'pengacara',
#   'kondang',
#   'mas',
#   'yang',
#   'kemarin',
#   'itu',
#   'abal',
#   'abal',
#   'punya'],
#  ['kasian',
#   'mas',
#   'eko',
#   'ini',
#   'bisa2',
#   'dituduh',
#   'lg',
#   'sama',
#   'cebong',
#   'sebagai',
#   'sebar',
#   'hoax',
#   'krn',
#   'tdk',
#   'ada',
#   'buktinya'],
#  ['yang',
#   'komentar',
#   'pada',
#   'ga',
#   'tahu',
#   'tentang',
#   'bagaimana',
#   'sertifikat',
#   'dibuat',
#   'sertifikat',
#   'itu',
#   'bisa',
#   'muncul',
#   'kalau',
#   'ada',
#   'akses',
#   'jalan',
#   'suruh',
#   'dia',
#   'tunjukin',
#   'denah',
#   'sertifikatnya',
#   'kalau',
#   'dia',
#   'memang',
#   'punya',
#   'itu',
#   'pasti',
#   'sertifikatnya',
#   'masih',
#   'gabung',
#   'ama',
#   'sebelah',
#   'kiri',
#   'atau',
#   'sebelah',
#   'kanannya',
#   'dan',
#   'itu',
#   'pasti',
#   'masih',
#   'saudara',
#   'dia',
#   'sertifikatnya',
#   'belum',
#   'dipecah',
#   'ama',
#   'mereka',
#   'berdua'],
#  ['nanti', 'pintu', 'surganya', 'juga', 'diblokade', 'sama', 'tuhan'],
#  ['sdh',
#   'bp',
#   'camat',
#   'yg',
#   'harus',
#   'menyelesaikan',
#   'biar',
#   'p',
#   'camat',
#   'dpt',
#   'pahala',
#   'membantu',
#   'yg',
#   'tertindas',
#   'toh',
#   'ga',
#   'lama',
#   'lagi',
#   'kita',
#   'mati',
#   'dan',
#   'runah',
#   'tanah',
#   'itu',
#   'tdk',
#   'di',
#   'bawaq'],
#  ['saya',
#   'tahun',
#   'kemarin',
#   'beli',
#   'tanah',
#   '20',
#   '15',
#   'm',
#   'tapi',
#   'saya',
#   'bikin',
#   'fondasi',
#   'pagar',
#   '19',
#   '15m',
#   'jadi',
#   'ada',
#   '1',
#   'meter',
#   'untuk',
#   'akses',
#   'jalan',
#   'setapak',
#   'berarti',
#   'saya',
#   'relakan',
#   'tanah',
#   'saya',
#   '115m',
#   'utk',
#   'kepentingan',
#   'umum',
#   'tetangga',
#   'sebelah',
#   'juga',
#   'demikian',
#   'jadi',
#   'jalan',
#   'setapak',
#   'lebarnya',
#   '2',
#   'meter',
#   'kita',
#   'kan',
#   'hidup',
#   'bertetangga',
#   'masa',
#   'tanah',
#   'satu',
#   'meter',
#   'aja',
#   'menghalangi',
#   'silaturahmi',
#   'dengan',
#   'tetangga',
#   'jadi',
#   'harus',
#   'dibicarakan',
#   'baikbaik',
#   'semua',
#   'bisa',
#   'diatur',
#   'yg',
#   'penting',
#   'dengan',
#   'hati',
#   'nurani'],
#  ['lemah',
#   'mati',
#   'tidak',
#   'ada',
#   'akses',
#   'jalan',
#   'itu',
#   'murah',
#   'harganya',
#   'lha',
#   'ini',
#   'yg',
#   'punya',
#   'tanah',
#   'maruk',
#   'ud',
#   'deal',
#   '100jt',
#   'minta',
#   'naik',
#   '150jt',
#   'jengkel',
#   'di',
#   'tutup',
#   'sekalian',
#   'ma',
#   'tetangga',
#   'yakin',
#   'tuh',
#   'yg',
#   'punya',
#   'tanah',
#   'mati',
#   'pasti',
#   'kolot',
#   'jd',
#   'dikerjai',
#   'tetangga'],
#  ['klo',
#   'tdk',
#   'salah',
#   'ada',
#   'undangundang',
#   'pertanahan',
#   'yg',
#   'mengatur',
#   'tentang',
#   'kewajiban',
#   'bagi',
#   'pemilik',
#   'tanah',
#   'dan',
#   'bangunan',
#   'untuk',
#   'memberi',
#   'akses',
#   'jalan',
#   'bagi',
#   'pemilik',
#   'tanah',
#   'dan',
#   'bangunan',
#   'dibelakangnya',
#   'yg',
#   'tdk',
#   'memiliki',
#   'akses',
#   'jalan',
#   'dlm',
#   'sertifikat',
#   'tanahnya',
#   'istilahnya',
#   'tanah',
#   'helikopter',
#   'minimal',
#   'jalan',
#   'setapak',
#   'silahkan',
#   'dicek',
#   'saya',
#   'lupa',
#   'pasalnya'],
#  ['tidak',
#   'berperikemanusiaan',
#   'yang',
#   'nutup',
#   'akses',
#   'itu',
#   'maukah',
#   'dia',
#   'diperlakukan',
#   'seperti',
#   'itu',
#   'tanya',
#   'ke',
#   'kupingnya',
#   'dengan',
#   'keras',
#   'maukah',
#   'dia',
#   'diperlakukan',
#   'seperti',
#   'itu',
#   'jika',
#   'berada',
#   'di',
#   'belakang',
#   'rumah',
#   'orang',
#   'lain'],
#  ['u2063sepertinya',
#   'ada',
#   'yang',
#   'kurang',
#   'beres',
#   'dengan',
#   'sertifikatnya',
#   'di',
#   'antara',
#   'rumah',
#   'rumah',
#   'itu',
#   'logikanya',
#   'rtrw',
#   'lurahcamat',
#   'bppn',
#   'waktu',
#   'menerbitkan',
#   'sertifikat',
#   'itu',
#   'pasti',
#   'tahu',
#   'posisi',
#   'dan',
#   'batas',
#   'batas',
#   'rumah',
#   'pasti',
#   'ada',
#   'yang',
#   'salah',
#   'dengan',
#   'sertifikat',
#   'sertifikat',
#   'itu',
#   'tentang',
#   'batasbatas',
#   'tanahnya',
#   'minimal',
#   'ada',
#   'hak',
#   'orang',
#   'yang',
#   'diserobot',
#   'polisi',
#   'harus',
#   'turun',
#   'ini'],
#  ['priksa',
#   'dulu',
#   'imb',
#   'nya',
#   'ada',
#   'gak',
#   'kalau',
#   'gak',
#   'ada',
#   'suruk',
#   'satpol',
#   'yg',
#   'bongkar',
#   'jangan',
#   'korbankan',
#   'tetangga'],
#  ['sebelum',
#   'semuanya',
#   'menjudge',
#   'tanpa',
#   'tabayyunsimple',
#   'utk',
#   'mencari',
#   'siapa',
#   'yg',
#   'salahyg',
#   'diakui',
#   'selama',
#   'ini',
#   'sbagai',
#   'akses',
#   'jalan',
#   'pak',
#   'eko',
#   'ini',
#   'sebenarnya',
#   'memang',
#   'peruntukan',
#   'jalan',
#   'atau',
#   'menggunakan',
#   'melewati',
#   'tanah',
#   'orang',
#   'lainklo',
#   'memang',
#   'akses',
#   'jalantetangganya',
#   'jelas',
#   'salahtapi',
#   'klo',
#   'itu',
#   'memang',
#   'tanah',
#   'org',
#   'lainya',
#   'memang',
#   'haknya',
#   'dia',
#   'utk',
#   'menembokyg',
#   'salah',
#   'adalah',
#   'pemerintah',
#   'setempatmana',
#   'akses',
#   'jalan',
#   'selama',
#   'ini',
#   'yg',
#   'harusnya',
#   'ada'],
#  ['yang',
#   'punya',
#   'tanah',
#   'nggak',
#   'bisa',
#   'disalahin',
#   'jugamemang',
#   'itu',
#   'haknya',
#   'diaklo',
#   'dia',
#   'dituntut',
#   'harus',
#   'ngasih',
#   'sebagian',
#   'untuk',
#   'jalantetangga',
#   'kirikanan',
#   'n',
#   'belakang',
#   'pak',
#   'eko',
#   'juga',
#   'harus',
#   'dituntut',
#   'hal',
#   'yg',
#   'serupaapesnya',
#   'dia',
#   'adalah',
#   'dia',
#   'baru',
#   'beli',
#   'n',
#   'bangun',
#   'skrg'],
#  ['kasih', 'jln', 'pakitu', 'ladang', 'amal', 'bpk'],
#  ['klo',
#   'ud',
#   'deal',
#   '100jt',
#   'kok',
#   'ingkar',
#   'jd',
#   '150jt',
#   'ya',
#   'hrsnya',
#   'jgn',
#   'serakah',
#   'jg',
#   'ya',
#   'klo',
#   'emank',
#   'maunya',
#   '150jt',
#   'ya',
#   'jgn',
#   'buka',
#   '100jt',
#   'donkntar',
#   'ada',
#   'yg',
#   'mau',
#   '150jt',
#   'ingkar',
#   'lgi',
#   '200jt'],
#  ['akar', 'masalah', 'nya', '', '', 'duit'],
#  ['ya',
#   'sudah',
#   'to',
#   'pak',
#   'eko',
#   'pindah',
#   'aja',
#   'rumah',
#   'lama',
#   'jadikan',
#   'kandang',
#   'ayam',
#   'atau',
#   'studio',
#   'musik',
#   'kan',
#   'haknya',
#   'pak',
#   'eko',
#   'juga',
#   'to',
#   'saat',
#   'ketemu',
#   'tetangga',
#   'yang',
#   'gak',
#   'pedulian',
#   'ya',
#   'sudah',
#   'jadikan',
#   'kita',
#   'gak',
#   'peduli',
#   'ngalah',
#   'terus',
#   'tidak',
#   'selamanya',
#   'baik'],
#  ['benernya',
#   'siapa',
#   'sie',
#   'yang',
#   'mau',
#   'beli',
#   'siapa',
#   'yang',
#   'mau',
#   'jual',
#   'kok',
#   'keterangan',
#   'camat',
#   'beda',
#   'sama',
#   'eko',
#   'eko',
#   'bilang',
#   'dia',
#   'yang',
#   'mau',
#   'beli',
#   'tanah',
#   'tetangganya',
#   'buat',
#   'jalan',
#   'kata',
#   'camat',
#   'malah',
#   'eko',
#   'yang',
#   'mau',
#   'jual',
#   'malah',
#   'harga',
#   'naik',
#   'pulaini',
#   'yakin',
#   'ada',
#   'yang',
#   'ga',
#   'beres',
#   'sama',
#   'si',
#   'eko'],
#  ['gak',
#   'pernah',
#   'belajar',
#   'pmp',
#   'mana',
#   'toleransisaling',
#   'menghargaissopan',
#   'santunempati',
#   'dalam',
#   'bertetangga'],
#  ['dulu',
#   'sudah',
#   'mau',
#   'dibeli',
#   '100jt',
#   'tapi',
#   'ga',
#   'jadi',
#   'karena',
#   'naik',
#   'minta',
#   '150jt',
#   'giliran',
#   'dibikin',
#   'tembok',
#   'merengek',
#   'rengek',
#   'ngadu',
#   'kesana',
#   'kamari',
#   'lebay'],
#  ['ujung', 'ujungnya', 'duit'],
#  ['sdh', 'terbacapokok', 'permasalah', 'nya'],
#  ['camat',
#   'koq',
#   'minta2',
#   'keluar',
#   'dari',
#   'kantor',
#   'kalian',
#   'itu',
#   'hei',
#   'camat',
#   'lurah',
#   'jgn',
#   'ongkang2',
#   'keq',
#   'kumpeni',
#   'aje',
#   'lu',
#   'pade'],
#  ['jangan',
#   'maen',
#   'asal',
#   'ngomong',
#   'nuduh',
#   'salah',
#   'satu',
#   'pihak',
#   'masalah',
#   'ini',
#   'terjadi',
#   'bukan',
#   'krn',
#   'pihak',
#   'yg',
#   'bersengketa',
#   'saja',
#   'ada',
#   'peran',
#   'rt',
#   'rw',
#   'lurah',
#   'camat',
#   'serta',
#   'pihak',
#   'pertanahan',
#   'rencana',
#   'tata',
#   'ruangnya',
#   'mana',
#   'masing2',
#   'punya',
#   'andil',
#   'dalam',
#   'terjadinya',
#   'masalah',
#   'ini',
#   'bukan',
#   'serta',
#   'merta',
#   'gr2',
#   'pihak',
#   'pak',
#   'eko',
#   'ataupun',
#   'tetangganya'],
#  ['pny',
#   'tanah',
#   'pribadi',
#   'jng',
#   'dibuat',
#   'jalanan',
#   'nnt',
#   'diserobotud83dude0b'],
#  ['jadi',
#   'sudah',
#   'jelas',
#   'to',
#   'akar',
#   'masalahnyalain',
#   'kumbang',
#   'lain',
#   'belangnyaud83dude02'],
#  ['seharusnya',
#   'ke',
#   'pangadilan',
#   'saja',
#   'apapun',
#   'hasilnya',
#   'itu',
#   'yang',
#   'akan',
#   'diakui',
#   'secara',
#   'hukum',
#   'kalau',
#   'curhat',
#   'kemana2',
#   'pasti',
#   'hanya',
#   'dapat',
#   'lip',
#   'service',
#   'saja',
#   'karena',
#   'mereka',
#   'hanya',
#   'bisa',
#   'menghimbau'],
#  ['sdh',
#   'mau',
#   'dibeli',
#   '100jt',
#   'tp',
#   'naik',
#   'jd',
#   '150jt',
#   'lgdr',
#   'sini',
#   'sdh',
#   'sdkt',
#   'jls',
#   'akar',
#   'mslhnya'],
#  ['ko',
#   'masih',
#   'ada',
#   'ya',
#   'orang',
#   'kaya',
#   'gitutinggal',
#   'di',
#   'perkampungan',
#   'mending',
#   'di',
#   'kubur',
#   'aja'],
#  ['spekulasi',
#   'tu',
#   'yg',
#   'jd',
#   'pertanyaan',
#   'ketika',
#   'jual',
#   'beli',
#   'kan',
#   'ada',
#   'form',
#   'tanda',
#   'tangan',
#   'sepengetahuan',
#   'jiran',
#   'kanan',
#   'kiri',
#   'dpn',
#   'blkg',
#   'dr',
#   'situ',
#   'sdh',
#   'dpt',
#   'awal',
#   'masalahnya',
#   'kmn',
#   'tu',
#   'pak',
#   'rt',
#   'rw',
#   'kadus',
#   'n',
#   'kades'],
#  ['klpun',
#   'd',
#   'kasih',
#   'jalan',
#   'jg',
#   'mending',
#   'pindah',
#   'aja',
#   'pakpunya',
#   'tetangga',
#   'kayak',
#   'gitu',
#   'modelnya',
#   'susah',
#   'liat',
#   'orang',
#   'senangsenang',
#   'liat',
#   'orang',
#   'susah'],
#  ['knpa',
#   'setelah',
#   'viral',
#   'di',
#   'medsos',
#   'camat',
#   'nya',
#   'baru',
#   'turun',
#   'tangan',
#   'pak',
#   'eko',
#   'bilang',
#   'sdh',
#   '3',
#   'thn',
#   'mondarmandir',
#   'utk',
#   'cari',
#   'solusi',
#   'jadi',
#   'klu',
#   'ada',
#   'masalh',
#   'sprti',
#   'ini',
#   'mendingan',
#   'di',
#   'viralkan',
#   'spya',
#   'cepat',
#   'ditanggapi'],
#  ['masoook', 'pak', 'eko'],
#  ['tetangga',
#   'kayak',
#   'gini',
#   'harus',
#   'buru',
#   'buru',
#   'di',
#   'mandiin',
#   'di',
#   'solatin',
#   'di',
#   'kafanin',
#   'dan',
#   'dikuburin',
#   'langsung',
#   'ga',
#   'ada',
#   'adabnya'],
#  ['gabisa', 'masook', 'pak', 'ekooo'],
#  ['u2063saya',
#   'enggak',
#   'nyebutin',
#   'kronologi',
#   'karena',
#   'privacy',
#   'hmm',
#   'ada',
#   'yang',
#   'aneh'],
#  ['disini',
#   'banyak',
#   'pendukung',
#   'tetangga',
#   'pak',
#   'eko',
#   'atau',
#   'mgkn',
#   'tetangga',
#   'disitu',
#   'wkwkww'],
#  ['dijual', 'ke', 'tetangga', 'depan', 'samping', 'saja', 'pak'],
#  ['rt',
#   'rw',
#   'lurah',
#   'camat',
#   'bpn',
#   'walkot',
#   'bupati',
#   'tidorrrr',
#   'semuaaaaaa'],
#  ['masssook', 'pak', 'ekoo'],
#  ['harusnya',
#   'dipikirin',
#   'sejak',
#   'dini',
#   'kalo',
#   'sudah',
#   'begini',
#   'bingung',
#   'dah',
#   'lu',
#   'ekoud83dude33ud83dude33ud83dude33',
#   'slh',
#   'elu',
#   'sendiri'],
#  ['kalau',
#   'mau',
#   'jual',
#   'ya',
#   'ke',
#   'tetangganya',
#   'gak',
#   'usah',
#   'cari',
#   'sensasi',
#   'banyak',
#   'kok',
#   'org',
#   'lqin',
#   'yg',
#   'rugi',
#   'lebih',
#   'banyak',
#   'utk',
#   'urusan2',
#   'tanah',
#   'bahkan',
#   'tanah',
#   'dgn',
#   'surat',
#   'berlapis',
#   'juga',
#   'ada',
#   'toh',
#   'yg',
#   'rugi',
#   'pemilik',
#   'org',
#   'bpn',
#   'palingan',
#   'hanya',
#   'di',
#   'mutasi',
#   'apalagi',
#   'kl',
#   'sdh',
#   'pensiun',
#   'gak',
#   'ada',
#   'sangsi',
#   'apa2'],
#  ['ini',
#   'eko',
#   'nya',
#   'yg',
#   'bodohhh',
#   'sejak',
#   'awalud83dude06ud83dude06ud83dude06'],
#  ['undang2',
#   'sdh',
#   'mengatur',
#   'klo',
#   'pembangunan',
#   'tidal',
#   'boleh',
#   'menutup',
#   'akses',
#   'jalan',
#   'bagi',
#   'rumah',
#   'atau',
#   'tempat',
#   'tinggal',
#   'yg',
#   'sudah',
#   'ada',
#   'sebelumnya',
#   'mohon',
#   'koreksi',
#   'klo',
#   'salah'],
#  ['kayak',
#   'nya',
#   'si',
#   'eko',
#   'ini',
#   'punya',
#   'kelainan',
#   'cara',
#   'bertetangga',
#   'deh'],
#  ['masooookkkk', 'pak', 'ekooo'],
#  ['pak',
#   'eko',
#   'punya',
#   'imb',
#   'kok',
#   'bisa',
#   'bangun',
#   'rumah',
#   'tanpa',
#   'halaman'],
#  ['solusinya',
#   'ya',
#   'jual',
#   'ke',
#   'tetangga',
#   'depannya',
#   'itu',
#   'pak',
#   'hitung',
#   'harga',
#   'tanah',
#   'saja',
#   'karena',
#   'memang',
#   'rumah',
#   'tanah',
#   'bpk',
#   'di',
#   'block',
#   'sama',
#   'dia',
#   'banyak',
#   'yang',
#   'seperti',
#   'itu',
#   'istilahnya',
#   'lock',
#   'land',
#   'jadi',
#   'memang',
#   'dia',
#   'beli',
#   'atau',
#   'bpk',
#   'bisa',
#   'juga',
#   'beli',
#   'tanah',
#   'didepan',
#   'untuk',
#   'akses'],
#  ['beli',
#   'aja',
#   'tanah',
#   'tetangga',
#   'atau',
#   'jual',
#   'rumahnya',
#   'ke',
#   'tetangganya'],
#  ['ya',
#   'harusnya',
#   'dari',
#   'awal',
#   'pak',
#   'eko',
#   'sudah',
#   'membuat',
#   'jalan',
#   'utk',
#   'rumahnya',
#   'sendiri',
#   'bukan',
#   'nya',
#   'membuat',
#   'rumah',
#   'full',
#   'bangunan',
#   'tp',
#   'disisakan',
#   'utk',
#   'jalan',
#   'hak',
#   'tetangga',
#   'jg',
#   'membuat',
#   'rumah',
#   'di',
#   'tanahnya',
#   'sandiri',
#   'seperti',
#   'yg',
#   'dilakukan',
#   'pak',
#   'eko',
#   'kejadian',
#   'sebenarnya',
#   'masih',
#   'misteri',
#   'siapa',
#   'yg',
#   'salah',
#   'dan',
#   'yg',
#   'benar',
#   'masih',
#   'abu2'],
#  ['masuk', 'pak', 'eko'],
#  ['tata', 'ruangnya', 'amburadul'],
#  ['sebetulnya',
#   'yg',
#   'paling',
#   'salah',
#   'adalah',
#   'bpn',
#   'karna',
#   'di',
#   'peraturan',
#   'agraria',
#   'terutuang',
#   'hukum',
#   'mengenai',
#   'pemberian',
#   'jalan',
#   'kepada',
#   'tanah',
#   'yg',
#   'tdk',
#   'memiliki',
#   'jalan',
#   'cth',
#   'tanah',
#   'yg',
#   'di',
#   'tengah',
#   'telah',
#   'disertifikat',
#   'di',
#   'kanan',
#   'dan',
#   'dikiri',
#   'pun',
#   'telah',
#   'bersertifikat',
#   'dan',
#   'menutup',
#   'jalan',
#   'di',
#   'depannya',
#   'jg',
#   'dibuat',
#   'sertifikat',
#   'dan',
#   'menutup',
#   'akses',
#   'yg',
#   'ditgh',
#   'sementara',
#   'blkg',
#   'belum',
#   'nah',
#   'ketika',
#   'belakang',
#   'membuat',
#   'sertifikat',
#   'secara',
#   'otomatis',
#   'yg',
#   'belakang',
#   'akan',
#   'kepotong',
#   'tanahnya',
#   'dan',
#   'memberikan',
#   'akses',
#   'jalan',
#   'yg',
#   'ditengah',
#   'cuma',
#   'masyarakat',
#   'bnyk',
#   'yg',
#   'awam',
#   'dgn',
#   'peraturan',
#   'tersebut'],
#  ['ketua',
#   'rt',
#   'rw',
#   'lurah',
#   'ko',
#   'pd',
#   'diem',
#   'ayu',
#   'bantu',
#   'warganya',
#   'masa',
#   'kalah',
#   'gantian',
#   'tutup',
#   'jlnnya'],
#  ['kemungkinan',
#   'besar',
#   'ada',
#   'yg',
#   'gak',
#   'beres',
#   'dg',
#   'proses',
#   'penerbitan',
#   'imb'],
#  ['bisa',
#   'dirundingkan',
#   'lha',
#   'sebelumnya',
#   'ditawari',
#   'tanah',
#   'tetangganya',
#   'tidak',
#   'mau',
#   'ya',
#   'bukan',
#   'salah',
#   'yang',
#   'memblokade',
#   'makanya',
#   'harus',
#   'baik',
#   'baik',
#   'dengan',
#   'tetangga',
#   'dan',
#   'pengurus',
#   'rt',
#   'setempat'],
#  ['tdk',
#   'diperbolehkan',
#   'perda',
#   'membangun',
#   'tp',
#   'merugikan',
#   'tetangga',
#   'walaupun',
#   'di',
#   'lahan',
#   'sendiri',
#   'biasanya',
#   'jika',
#   'trjadi',
#   'spt',
#   'itu',
#   'dinas',
#   'pengawasan',
#   'pembangunan',
#   'akan',
#   'bertindak'],
#  ['masuuukkk', 'pakk', 'ekoo'],
#  ['pastinya', 'orang', 'ini', 'bermasalah', 'dengan', 'tetangganya'],
#  ['jual', 'sama', 'yg', 'ngeblokade'],
#  ['silaturahmi',
#   'dgn',
#   'tetangga',
#   'itu',
#   'penting',
#   'walau',
#   'akses',
#   'ditutup',
#   'kalau',
#   'tetangga',
#   'seperti',
#   'saudara',
#   'pasti',
#   'dikasih',
#   'jalan',
#   'tinggal',
#   'ketok',
#   'rumah',
#   'tetangga',
#   'terus',
#   'u201cmasuk',
#   'pak',
#   'ekou201d'],
#  ['imb', 'bisa', 'keluar'],
#  ['ya',
#   'hak',
#   'tetangga',
#   'juga',
#   'blokade',
#   'jalan',
#   'karena',
#   'mungkin',
#   'itu',
#   'tanah',
#   'tetangga',
#   'harusnya',
#   'di',
#   'musyawarahkan',
#   'baik2',
#   'dgn',
#   'tetangga',
#   'klo',
#   'kita',
#   'baik',
#   'ke',
#   'tetangga',
#   'gak',
#   'mungkin',
#   'tetangga',
#   'akan',
#   'setega',
#   'itu',
#   'memblokade',
#   'jlan'],
#  ['waras', 'slamet', 'pak', 'eko', 'tenang', 'aja', 'gusti', 'tak', 'sare'],
#  ['mana',
#   'kades',
#   'nya',
#   'masa',
#   'ada',
#   'warganya',
#   'yg',
#   'bermasalah',
#   'gini',
#   'ga',
#   'diselesaikan'],
#  ['surat',
#   'kog',
#   'dilempar',
#   'memangnya',
#   'koran',
#   'meskipun',
#   'bener',
#   'koran',
#   'apa',
#   'sopan',
#   'lempar',
#   'koran',
#   'ke',
#   'presiden',
#   'apa',
#   'gak',
#   'bisa',
#   'dititipkan',
#   'suratnya',
#   'lewat',
#   'paspampres'],
#  ['ya',
#   'jelas',
#   'dikejar',
#   'pampapres',
#   'ngelempar',
#   'benda',
#   'seperti',
#   'itu',
#   'ke',
#   'presiden',
#   'itu',
#   'sudah',
#   'tugas',
#   'mereka',
#   'menjaga',
#   'presiden'],
#  ['sifatmu',
#   'mungkin',
#   'juga',
#   'ga',
#   'benar',
#   'main',
#   'lempar',
#   'surat',
#   'tanpa',
#   'pikir',
#   'kesopanan',
#   'instropeksi',
#   'pak',
#   'eko'],
#  ['tetangga', 'masa', 'gitu'],
#  ['u2063sepertinya',
#   'ada',
#   'yang',
#   'kurang',
#   'beres',
#   'dengan',
#   'sertifikatnya',
#   'di',
#   'antara',
#   'rumah',
#   'rumah',
#   'itu',
#   'logikanya',
#   'rtrw',
#   'lurahcamat',
#   'bppn',
#   'waktu',
#   'menerbitkan',
#   'sertifikat',
#   'itu',
#   'pasti',
#   'tahu',
#   'posisi',
#   'dan',
#   'batas',
#   'batas',
#   'rumah',
#   'pasti',
#   'ada',
#   'yang',
#   'salah',
#   'dengan',
#   'sertifikat',
#   'sertifikat',
#   'itu',
#   'tentang',
#   'batasbatas',
#   'tanahnya',
#   'minimal',
#   'ada',
#   'hak',
#   'orang',
#   'yang',
#   'diserobot',
#   'polisi',
#   'harus',
#   'turun',
#   'ini'],
#  ['wah',
#   'kalo',
#   'saja',
#   'sampe',
#   'ke',
#   'telinga',
#   'jokowi',
#   'pasti',
#   'akan',
#   'dibuatin',
#   'flyover'],
#  ['bandung',
#   'jabar',
#   'ada',
#   'gubernur',
#   'baru',
#   'kalau',
#   'yang',
#   'dulu',
#   'emang',
#   'parah',
#   'sekarang',
#   'lapor',
#   'pasti',
#   'di',
#   'beresin',
#   'ngak',
#   'semuasemua',
#   'ke',
#   'presiden',
#   'kalees'],
#  ['katanya', 'pak', 'camat', 'tidak', 'tahu'],
#  ['yang',
#   'memblokade',
#   'pasti',
#   'orang',
#   'kuat',
#   'juga',
#   'orang',
#   'penting',
#   'sampai',
#   'camat',
#   'gak',
#   'bisa',
#   'nyelesaikan'],
#  ['sudah',
#   'bodoh',
#   'mau',
#   'menang',
#   'sendiri',
#   'ini',
#   'problem',
#   'di',
#   'daerah2',
#   'mengharapkan',
#   'tetangga',
#   'memberikan',
#   'jalan',
#   'sementara',
#   'mereka',
#   'banyak',
#   'yang',
#   'membuat',
#   'rumah',
#   'atau',
#   'pagar',
#   'melebihi',
#   'ukuran',
#   'sk',
#   'tanah',
#   'yang',
#   'dimiliki',
#   'alias',
#   'menyerobot',
#   'tanah',
#   'tetangga'],
#  ['coba', 'ke', 'kopi', 'joni', 'lahh'],
#  ['kalau',
#   'semua',
#   'ke',
#   'jokowi',
#   'ya',
#   'ga',
#   'mungkin',
#   'ada',
#   'jutaan',
#   'masalah',
#   'di',
#   'indonesia',
#   'urutannya',
#   'itu',
#   'bisa',
#   'minta',
#   'mediasi',
#   'didampingi',
#   'rtrw',
#   'ke',
#   'kelurahan',
#   'kalau',
#   'gagal',
#   'ya',
#   'ke',
#   'kecamatan',
#   'kalau',
#   'ga',
#   'bisa',
#   'dateng',
#   'mediasi',
#   'ya',
#   'tulis',
#   'surat',
#   'resmi',
#   'ke',
#   'kelurahan',
#   'kecamatan',
#   'kotamadya',
#   'kalau',
#   'tidak',
#   'ditanggapi',
#   'bisa',
#   'tulis',
#   'pengaduan',
#   'ke',
#   'ombudsman',
#   'banyak',
#   'kok',
#   'permasalahan',
#   'yg',
#   'sampai',
#   'ke',
#   'ombudsman',
#   'dan',
#   'langsung',
#   'di',
#   'follow',
#   'up',
#   'antara',
#   '12',
#   'bulan',
#   'ga',
#   'usah',
#   'tunggu',
#   '3',
#   'tahun',
#   'ngejar2',
#   'presiden'],
#  ['tp', 'msh', 'bisa', 'keluar', 'rumah', 'ga'],
#  ['inilah',
#   'contoh',
#   'manusia',
#   'indonesia',
#   'jaman',
#   'now',
#   'yg',
#   'katanya',
#   'pancasilais',
#   'ternyata',
#   'egois',
#   'tk',
#   'ada',
#   'toleransi',
#   'sedikitpun',
#   'kpd',
#   'sesama',
#   'pd',
#   'sesama',
#   'tetangga',
#   'rt',
#   'rw',
#   'lurah',
#   'nya',
#   'camaunya',
#   'walikota',
#   'nya',
#   'gubernur',
#   'nya',
#   'pancasila',
#   'nya',
#   'mana'],
#  ['akalnya',
#   'aja',
#   'kurang',
#   'pinter',
#   'itu',
#   'bikin',
#   'lif',
#   'sampai',
#   'atas',
#   'genteng',
#   'kan',
#   'bisa',
#   'terus',
#   'bikin',
#   'tol',
#   'diatas',
#   'genteng',
#   'sampai',
#   'jalan',
#   'raya',
#   'hehehe'],
#  ['pertanyaanya',
#   'bagaimana',
#   'hubungan',
#   'bertetangganya',
#   'kok',
#   'sampe',
#   'tega',
#   'di',
#   'block',
#   'gitu',
#   'kita',
#   'tdk',
#   'tau',
#   'ada',
#   'permasalahan',
#   'apa',
#   'sedangkan',
#   'pak',
#   'eko',
#   'slalu',
#   'bilang',
#   'privacy',
#   'lha',
#   'piye',
#   'to'],
#  ['surat',
#   'rumah',
#   'pak',
#   'eko',
#   'ternyata',
#   'gak',
#   'beres',
#   'pantesan',
#   'gak',
#   'ada',
#   'yg',
#   'bisa',
#   'belain',
#   'krn',
#   'secara',
#   'hukum',
#   'pak',
#   'eko',
#   'melakukan',
#   'pelanggaran',
#   'ternyata',
#   'pak',
#   'eko',
#   'minta',
#   'simpati',
#   'publik',
#   'pdhal',
#   'secara',
#   'hukum',
#   'dia',
#   'bersalah'],
#  ['knapa',
#   'buat',
#   'rumah',
#   'tidak',
#   'membuat',
#   'akses',
#   'utk',
#   'jalan',
#   'sendiri',
#   'bearti',
#   'selama',
#   'ini',
#   'mengambil',
#   'jalan',
#   'dari',
#   'tanah',
#   'orang',
#   'lain',
#   'mengambil',
#   'hak',
#   'tetangga',
#   'utk',
#   'kepentingan',
#   'sendiri'],
#  ['mungkin',
#   'pak',
#   'eko',
#   'disuruh',
#   'bayar',
#   'akses',
#   'jalan',
#   'tp',
#   'g',
#   'mau',
#   'kl',
#   'spt',
#   'ini',
#   'ya',
#   'g',
#   'akan',
#   'ada',
#   'titik',
#   'temu',
#   'krn',
#   'pemilik',
#   'jalan',
#   'mumgkin',
#   'beli',
#   'keseluruhan',
#   'tp',
#   'pak',
#   'eko',
#   'minta',
#   'cuma2',
#   'doang',
#   'tiap',
#   'jengkal',
#   'tanah',
#   'itu',
#   'berharga',
#   'apalagi',
#   'diperkotaan'],
#  ['aneh',
#   'sih',
#   'memang',
#   'kelakuan',
#   'tetangga',
#   'sprt',
#   'ini',
#   'biasanya',
#   'sihmhn',
#   'maaf',
#   'yg',
#   'sering',
#   'model2',
#   'tutup',
#   'jalan',
#   'tutup',
#   'got',
#   'krn',
#   'itu',
#   'dulu',
#   'tanah',
#   'engkong',
#   'gw',
#   'itu',
#   'dulu',
#   'punya',
#   'babak',
#   'gwkan',
#   'bukan',
#   'orang',
#   'sunda'],
#  ['salah',
#   'sendiri',
#   'lah',
#   'kenapa',
#   'dulu',
#   'gak',
#   'dijual',
#   'aja',
#   'tuh',
#   'rumah',
#   'jual',
#   'murah',
#   'aja',
#   'sama',
#   'tetangga',
#   'pake',
#   'njop',
#   'jgn',
#   'pake',
#   'harga',
#   'pasar',
#   'dungu',
#   'dipelihara'],
#  ['aparat',
#   'kecamatan',
#   'sama',
#   'desa',
#   'nya',
#   'saja',
#   'yg',
#   'gk',
#   'becus',
#   'buat',
#   'me',
#   'mediasi',
#   'masalah',
#   'seperti',
#   'itu',
#   'ganti',
#   'langsung',
#   'camat',
#   'sama',
#   'lurah',
#   'nya',
#   'kok',
#   'ada',
#   'masyarakat',
#   'nya',
#   'susah',
#   'gk',
#   'segera',
#   'di',
#   'bantu',
#   'penyelesaian',
#   'masalah',
#   'nya'],
#  ['mas',
#   'eko',
#   'anda',
#   'harus',
#   'info',
#   'ke',
#   'media',
#   'sewaktu',
#   'anda',
#   'sudah',
#   'melaporkan',
#   'ke',
#   'dinas',
#   'terkait',
#   'bahkan',
#   'sampai',
#   'gubernur',
#   'dan',
#   'tidak',
#   'ditanggapiada',
#   'hrs',
#   'cerita',
#   'siapa',
#   'saja',
#   'sehingga',
#   'anda',
#   'tidak',
#   'sebar',
#   'fitnahbiar',
#   'oknum2',
#   'ini',
#   'biar',
#   'ditindak',
#   'bila',
#   'itu',
#   'benar',
#   'adanyajgn',
#   'pernah',
#   'takut'],
#  ['rt', 'rw', 'kelurahan', 'camat', 'gk', 'becus'],
#  ['sabar',
#   'pak',
#   'eko',
#   'semua',
#   'akan',
#   'di',
#   'selesaikan',
#   'dlm',
#   'hitungan',
#   'jam',
#   'tp',
#   'di',
#   'tahun',
#   '2019',
#   'setelah',
#   'rezim',
#   'berganti'],
#  ['hhhh',
#   'aneh',
#   'org',
#   'lempar',
#   'kertas',
#   'dikejar',
#   'tapi',
#   'org',
#   'bisa',
#   'nepuk',
#   'jokowi',
#   'wkt',
#   'touring',
#   'motor',
#   'ga',
#   'diinterogasi',
#   'atau',
#   'dilumpuhkan',
#   'paspampressetting',
#   'pencitraan',
#   'atau',
#   'paspampresnya',
#   'yg',
#   'ga',
#   'becus',
#   'ngawal',
#   'presiden'],
#  ['teu',
#   'make',
#   'duit',
#   'mah',
#   'rek',
#   'aya',
#   'anu',
#   'peduli',
#   'kumaha',
#   'atuh',
#   'kang',
#   'sing',
#   'sadar',
#   'weh',
#   'ayeunamah',
#   'urang',
#   'hirup',
#   'di',
#   'nagara',
#   'kos',
#   'kumaha'],
#  ['kelihatannya',
#   'semua',
#   'tanahnya',
#   'sudah',
#   'ber',
#   'sertifikat',
#   'kenapa',
#   'tidak',
#   'di',
#   'pertanyakan',
#   'ke',
#   'badan',
#   'pertanahan',
#   'seharusnya',
#   'tidak',
#   'ada',
#   'penerbitan',
#   'sertifikat',
#   'tanpa',
#   'ada',
#   'jalan',
#   'melalui',
#   'tanah',
#   'tersebut',
#   'kalo',
#   'tidak',
#   'ada',
#   'tanggapan',
#   'dari',
#   'bpn',
#   'maka',
#   'ajukan',
#   'gugatan',
#   'ke',
#   'ptun',
#   'dimana',
#   'bpn',
#   'sebagai',
#   'tergugat',
#   '1'],
#  ['harusnya',
#   'waktu',
#   'dikejar',
#   'nyerahin',
#   'diri',
#   'aja',
#   'biar',
#   'pak',
#   'jokowi',
#   'tau',
#   'masalahnya',
#   'tapi',
#   'kenapa',
#   'bapak',
#   'lari',
#   'sih',
#   'itu',
#   'kesempatan',
#   'emas',
#   'padahal',
#   'pak'],
#  ['pemerintah', 'bandung', 'gak', 'becus', 'kerja'],
#  ['ya', 'iyalah', 'maen', 'lempar', 'aja'],
#  ['sebenarnya',
#   'masalahnya',
#   'apa',
#   'kenapa',
#   'tidak',
#   'ada',
#   'penyelesaian',
#   'mana',
#   'bupati',
#   'bandung',
#   'kenapa',
#   'diam',
#   'diam',
#   'saja',
#   'minta',
#   'dipecat'],
#  ['coba',
#   'diselesaikan',
#   'secara',
#   'kekeluargaan',
#   'dg',
#   'hati',
#   'dingin',
#   'tanpa',
#   'erosi',
#   'insyaallah',
#   'ketemu',
#   'jalanyaud83dude0e'],
#  ['aneh',
#   'segitu',
#   'egoisnya',
#   'kah',
#   'paravtetangga',
#   'rt',
#   'rw',
#   'sama',
#   'lurah',
#   'gak',
#   'bisa',
#   'tangani',
#   'kah',
#   'mudah2an',
#   'masalah',
#   'ini',
#   'nyampr',
#   'ke',
#   'jokowi',
#   'biar',
#   'masalah',
#   'selesai',
#   'sebenarnya',
#   'masalah',
#   'kyk',
#   'gini',
#   'bukan',
#   'urusan',
#   'presiden',
#   'karena',
#   'nyangkut2',
#   'urusan',
#   'paspampres',
#   'atau',
#   'oknum',
#   'yg',
#   'ngaku2',
#   'paspampres',
#   'jadi',
#   'gak',
#   'ada',
#   'salahnya',
#   'pak',
#   'jokowi',
#   'bantu',
#   'selesaikan',
#   'masalah'],
#  ['sepertinya',
#   'dua',
#   'pihak',
#   'awal',
#   'nya',
#   'sama2',
#   'kepala',
#   'batu',
#   'sehingga',
#   'kejadian',
#   'seperti',
#   'itu',
#   'akhirnya'],
#  ['kok',
#   'bisa',
#   'bangun',
#   'rumah',
#   'tp',
#   'akses',
#   'ke',
#   'jalan',
#   'nya',
#   'ga',
#   'ada',
#   'pasti',
#   'ga',
#   'ada',
#   'imb',
#   'nya',
#   'yaaa'],
#  ['tetangga', 'gila'],
#  ['jual', 'aja', 'rmhnya', 'pa', 'gitu', 'aja', 'repot'],
#  ['gimana',
#   'mau',
#   'nuntut',
#   'hak',
#   'bukan',
#   'tanah',
#   'nya',
#   'kok',
#   'yg',
#   'di',
#   'sekitar',
#   'nya',
#   'sdh',
#   'tau',
#   'dari',
#   'dulu',
#   'sehrsnya',
#   'jual',
#   'pindah',
#   'dong'],
#  ['apesstressnasib', 'orang', 'kecil'],
#  ['gambar',
#   'lokasi',
#   'bangunan',
#   'beserta',
#   'tetangganya',
#   'bisa',
#   'diupload',
#   'jg',
#   'min'],
#  ['ada',
#   'kades',
#   'camat',
#   'walkot',
#   'gubernur',
#   'semua',
#   'dpt',
#   'gaji',
#   'dr',
#   'negara',
#   'ada',
#   'hirarki',
#   'job',
#   'description'],
#  ['wahh',
#   'tetangga',
#   'serahkan',
#   'sabar',
#   'mas',
#   'di',
#   'dunia',
# ...
#  ['mantappp', 'keadilan', 'sosial', 'bagi', 'seluruh', 'rakyat', 'indonesia'],
#  ['ternyata', 'besar', 'minatnyaud83dude04ud83dude04ud83dude04'],
#  ['klau',
#   'liat',
#   'kdekatan',
#   'dan',
#   'jasa',
#   'pak',
#   'maruf',
#   'hrusnya',
#   'sby',
#   'mndukung',
#   'dan',
#   'mngusungnya',
#   'tpi',
#   'karena',
#   'udh',
#   'kplang',
#   'baper',
#   'dan',
#   'udh',
#   'kplang',
#   'janji',
#   'sama',
#   'prabowo',
#   'walau',
#   'berat',
#   'hati',
#   'ya',
#   'mau',
#   'gk',
#   'mau',
#   'mngusung',
#   'prabowo'],
#  ['ketum', 'demokrat', 'sdh', 'kagak', 'ada', 'giginya'],
#  ['nafsu', 'berkuasa', 'ya', 'hahaha'],
#  ['jelas',
#   'bisa',
#   'dimengerti',
#   'rakyat',
#   'papua',
#   'merasakan',
#   'sekali',
#   'apa',
#   'yg',
#   'sdh',
#   'dilakukan',
#   'pres',
#   'jokowi',
#   'disanaprinsip',
#   'keadilan',
#   'nyata',
#   'dilakukan',
#   'bukan',
#   'sekedar',
#   'jargon',
#   'politik',
#   '2019orangbaikhasilnyabaik'],
#  ['ngomong',
#   'ngak',
#   'kuat',
#   'krn',
#   'kardus',
#   'sdh',
#   'di',
#   'embat',
#   'kelakuan',
#   'politisi',
#   'sontoloyo'],
#  ['coba',
#   'pendapat',
#   'bapak',
#   'ini',
#   'disampaikan',
#   'ke',
#   'junjungan',
#   'bapakar',
#   'supaya',
#   'gak',
#   'nyinyirkata',
#   'beliau',
#   'gak',
#   'mungkin'],
#  ['ibarat',
#   'bangunan',
#   'mewah',
#   'koalisi',
#   'ini',
#   'sebenarnya',
#   'kropos',
#   'dan',
#   'rapuhgmn',
#   'mau',
#   'mau',
#   'menang',
#   'ini',
#   'ngurus',
#   'intern',
#   'koalisi',
#   'iji',
#   'aja',
#   'ga',
#   'bisahidup',
#   'jkw',
#   '2',
#   'periode'],
#  ['hahahahaseru',
#   'nehmantap',
#   'masa',
#   'pks',
#   'dan',
#   'pan',
#   'aja',
#   'yg',
#   'dapat',
#   'sikatlah',
#   'pd',
#   'jgn',
#   'mau',
#   'dibohongi',
#   'sama',
#   'gerindra',
#   'pks',
#   'dan',
#   'panhahaha'],
#  ['hajar',
#   'bleh',
#   'sikat',
#   'terus',
#   'masa',
#   'cuma',
#   'mereka',
#   'doang',
#   'yang',
#   'dapat',
#   'kardus',
#   'pd',
#   'engga',
#   'ayo',
#   'jangan',
#   'mau',
#   'tuntut',
#   'juga',
#   'bagian',
#   'kardusmu'],
#  ['koalisi',
#   'gak',
#   'mutupercuma',
#   'lo',
#   'pada',
#   'eker2nyungsep',
#   'lo',
#   'semua'],
#  ['mau',
#   'menuding',
#   'dua',
#   'atau',
#   'tiga',
#   'kaki',
#   'juga',
#   'gamasalah',
#   'bosyg',
#   'penting',
#   'pks',
#   'sudah',
#   'dapat',
#   '500',
#   'mberarti',
#   'pertahun',
#   '100mlumayan',
#   'kan',
#   'coba',
#   'klw',
#   'ngandalkan',
#   'dari',
#   'hasil',
#   'korupsi',
#   'atau',
#   'pemberian',
#   'jangan2',
#   'di',
#   'ott',
#   'sama',
#   'kpk',
#   'ahirnya',
#   'gigit',
#   'jari',
#   'donk',
#   'klw',
#   'ini',
#   'kan',
#   'barter',
#   'meskipun',
#   'nantinya',
#   'kalah',
#   'pasti',
#   'kalah',
#   'dlm',
#   'pilpres',
#   'gamasalah',
#   'yg',
#   'rugi',
#   'kan',
#   'bukan',
#   'pks',
#   'atau',
#   'pan',
#   'paham',
#   'kan',
#   'sekarangyg',
#   'penting',
#   'duitnya',
#   'gerindra',
#   'sdh',
#   'keluar',
#   'klw',
#   'ada',
#   'bahasa',
#   'untuk',
#   'kampanye',
#   'itu',
#   'kan',
#   'cuma',
#   'alasan',
#   'saja',
#   'biar',
#   'garibut'],
#  ['yahh',
#   'kenyataannya',
#   'semuanya',
#   'main',
#   '2',
#   'kaki',
#   'dan',
#   'oportunis',
#   'mau',
#   'apa',
#   'lagi'],
#  ['andi',
#   'juga',
#   'aneh',
#   'pake',
#   'ngomong',
#   'udah',
#   'jelas',
#   'parte',
#   'kemunafikan',
#   'sejati',
#   'cebong',
#   'kejet2',
#   'gagal',
#   'mupe',
#   'on'],
#  ['yah', 'apakah', 'masih', 'percaya', 'dengan', 'omomgannya'],
#  ['kalau', 'panas', 'dalam', 'minum', 'tuh', 'kaki', '3', 'biar', 'ademhehe'],
#  ['ketua', 'diam', 'bisa', 'dianggap', 'seruju'],
#  ['udaah',
#   'mending',
#   'bubar',
#   'aja',
#   'niih',
#   'koalisi',
#   'ga',
#   'bermutubukanya',
#   'bikin',
#   'program',
#   'malah',
#   'ribut',
#   'sendiri',
#   'mendiing',
#   'bubar',
#   'lagian',
#   'sdh',
#   'pasti',
#   'kalah',
#   'kok',
#   'ngapain',
#   'd',
#   'lanjutkan'],
#  ['haqulyakin',
#   'pekaes',
#   'dan',
#   'pante',
#   'nyungsep',
#   'suaranya',
#   'pemilu',
#   '2019'],
#  ['koalisi', 'serapuh', 'kardus', 'basah'],
#  ['andi',
#   'arief',
#   'yg',
#   'selalu',
#   'menyerang',
#   'koalisi',
#   'sendiri',
#   'ini',
#   'kenapa',
#   'tdk',
#   'ditegur',
#   'sby',
#   'ada',
#   'apa',
#   'di',
#   'koalisi',
#   'prabowo',
#   'sandiaga',
#   'padahal',
#   'bersikap',
#   'pura2',
#   'netral',
#   'di',
#   'pilpres',
#   '2014',
#   'sama',
#   'juga',
#   'bermain',
#   '2',
#   'kaki',
#   'pak',
#   'andi'],
#  ['dulu',
#   'mencari',
#   'makan',
#   'setelah',
#   'menjabat',
#   'jadi',
#   'kaya2',
#   'bahkan',
#   'daging',
#   'juga',
#   'di',
#   'empat',
#   'penjara',
#   'dan',
#   'akhirnya',
#   'neraka'],
#  ['nah', 'lu', 'kena', 'deh'],
#  ['kardus', 'kardus', 'kardusmana', 'bagian', 'kardusku'],
#  ['politik', 'cari', 'makan', 'alias', 'parpol', 'kardus'],
#  ['dia', 'minta', 'isi', 'kardus', 'tu'],
#  ['badut',
#   'badut',
#   'politikkerja',
#   'nolll',
#   'buat',
#   'rakyatnyir',
#   'nyir',
#   'bocor',
#   'coorrrrrrr'],
#  ['u2063jokowi',
#   'menang',
#   'mudah',
#   'di',
#   'pilpres',
#   '2019',
#   'democraaat',
#   'nyungsep'],
#  ['jokowi',
#   'menang',
#   'mudah',
#   'di',
#   'pilpres',
#   '2019',
#   'democraaat',
#   'nyungsep'],
#  ['lebih', 'bagus', 'cap', 'kaki', 'tigabisa', 'buat', 'kesehatan'],
#  ['kaki', 'empatud83dude07'],
#  ['salam', 'dua', 'kaki', 'euyhahaha'],
#  ['pak',
#   'sby',
#   'itu',
#   'kalau',
#   'ngomong',
#   'selalu',
#   'pinjam',
#   'banyak',
#   'moncong',
#   'mas',
#   'kayak',
#   'ban',
#   'bocor',
#   'alus',
#   'tapi',
#   'kelilingud83dude03',
#   'baru',
#   'lahir',
#   'ya'],
#  ['kl',
#   'sudah',
#   'berdasarkan',
#   'data',
#   'dan',
#   'fakta',
#   'ya',
#   'susah',
#   'untuk',
#   'dijawab',
#   'hahahaha'],
#  ['setdeh',
#   'kho',
#   'seneng',
#   'banget',
#   'ribut',
#   'sich',
#   'rebutan',
#   'apa',
#   'lagi',
#   'nech',
#   'engingeng',
#   'datang',
#   'zonk',
#   'ah',
#   'nggak',
#   'papa',
#   'masih',
#   'solid',
#   'kho',
#   'itu',
#   'hanya',
#   'dinamika',
#   'politikcapek',
#   'dech'],
#  ['sesama', 'begundal', 'politik', 'dilarang', 'saling', 'mendahului'],
#  ['karena',
#   'aa',
#   'pakai',
#   'data',
#   'dan',
#   'fakta',
#   'maka',
#   'tidak',
#   'bisa',
#   'berbalas',
#   'pantun'],
#  ['pan', 'pks', 'sebaiknya', 'diam', 'klo', 'ga', 'punya', 'kaca'],
#  ['koalisi',
#   'aja',
#   'ribut',
#   'gimana',
#   'mau',
#   'menang',
#   'jargon',
#   'doang',
#   'kenceng',
#   'kualitas',
#   'nol'],
#  ['mari',
#   'kita',
#   'bertepuk',
#   'tangansesama',
#   'begundal',
#   'sdh',
#   'mulai',
#   'ribut'],
#  ['kayaknya',
#   'bener',
#   'juga',
#   'dulu',
#   'kan',
#   'koalisi',
#   'demokrat',
#   'tp',
#   'sering',
#   'gak',
#   'nurut'],
#  ['diam', 'itu', 'emas'],
#  ['lah',
#   'ngapain',
#   'jg',
#   'ribut2',
#   'politik',
#   'pilkada',
#   'kemaren',
#   'jg',
#   'banyak',
#   'koalisi',
#   'ngacak',
#   'politik',
#   'disini',
#   'ya',
#   'gt',
#   'cari',
#   'sensasi',
#   'doang'],
#  ['bukan',
#   '2',
#   'kaki',
#   'itu',
#   'mah',
#   'yg',
#   'kita',
#   'tahu',
#   'tapi',
#   '4',
#   'kaki',
#   '2',
#   'kaki',
#   'yg',
#   'sah',
#   '2',
#   'kaki',
#   'yg',
#   'siri',
#   'kan'],
#  ['main',
#   'dua',
#   'kaki',
#   'saat',
#   'pemilu',
#   'sudah',
#   'usai',
#   'bargain',
#   'dan',
#   'kompromi',
#   'lah',
#   'ini',
#   'baru',
#   'mau',
#   'mulai',
#   'haha',
#   'cerdas',
#   'dong',
#   'kamu',
#   'dek'],
#  ['pd',
#   'pan',
#   'pks',
#   'semua',
#   'ahli',
#   'main',
#   '2',
#   'kaki',
#   'cuman',
#   'gerindra',
#   'yg',
#   'ga',
#   'punya',
#   'kaki'],
#  ['andi', 'arief', 'dicari', 'bawaslu', 'tuh'],
#  ['abis',
#   'mau',
#   'bagemana',
#   'lagi',
#   'ga',
#   'mau',
#   'rugi',
#   'maunya',
#   'untung',
#   'terus'],
#  ['bertiga', 'saling', 'selingkuh'],
#  ['andi',
#   'arief',
#   'ini',
#   'awalnya',
#   'mencak2',
#   'teriak2',
#   'terkait',
#   'dana',
#   'logistik',
#   '500m',
#   'untuk',
#   'kubu',
#   'koalisi',
#   'prabowo',
#   'karena',
#   'demokrat',
#   'tdk',
#   'di',
#   'ajak',
#   'bicara',
#   'sekarang',
#   'diem',
#   'dia',
#   'di',
#   'amankan',
#   'oleh',
#   'sandi',
#   'wajar',
#   'andi',
#   'arief',
#   'ini',
#   'ngebela',
#   'demokrat',
#   'dan',
#   'sby'],
#  ['tepatnya', 'pan', 'dan', 'pks', 'tergantung', 'bayaran'],
#  ['satu',
#   'koalisi',
#   'aja',
#   'udah',
#   'gak',
#   'kompak',
#   'gmn',
#   'mau',
#   'menang',
#   'udah',
#   'pd',
#   'jgn',
#   'ribut',
#   'nikmatin',
#   'aja',
#   'dl',
#   'kardus2nya',
#   'mudah2',
#   'anjlog',
#   'hancura',
#   'suara',
#   'kalian',
#   'di',
#   'pemilu',
#   '2019'],
#  ['salut',
#   'buat',
#   'timses',
#   'padi',
#   'dinamika',
#   'adalah',
#   'keharusan',
#   'dlm',
#   'sebuah',
#   'perjuangan',
#   'politik',
#   'ada',
#   'perbedaan',
#   'pendapat',
#   'kritik',
#   'juga',
#   'wajar2',
#   'saja',
#   'solid',
#   'gak',
#   'perlu',
#   'harus',
#   'yes',
#   'semua',
#   'diam',
#   'seribu',
#   'bahasa',
#   'spt',
#   'dikekang',
#   'satu',
#   'suara',
#   'seperti',
#   'koalisi',
#   'jokowi',
#   'yg',
#   'ujung2nya',
#   'melampiaskan',
#   'uneg2',
#   'dgn',
#   'menyerang',
#   'koalisi',
#   'lawanberbeda',
#   'suara',
#   'bukan',
#   'masalah',
#   'tapi',
#   'saling',
#   'menghargai',
#   'harus',
#   'dijaga',
#   'dekati',
#   'terus',
#   'rakyat',
#   'krn',
#   'rakyatlah',
#   'yg',
#   'menentukan',
#   'kemenangan',
#   'di',
#   'pilpres',
#   'nanti'],
#  ['hajar'],
#  ['percaya',
#   'dehklo',
#   'jokowi',
#   'menang',
#   'lgpan',
#   'akan',
#   'merapat',
#   'ke',
#   'jokowi',
#   'lg',
#   'supaya',
#   'dpt',
#   'mentri',
#   'lgkan',
#   'kmpren',
#   'brgitu'],
#  ['pd',
#   'maen',
#   'dua',
#   'kaki',
#   'di',
#   'parlemen',
#   'seabis',
#   'pilpres',
#   'katenye',
#   'netral',
#   'tapi',
#   'condong',
#   'ke',
#   'kmp'],
#  ['kelompok', 'sebelah', 'pemain', '2', 'kaki', 'semua', 'wkwkwkwk'],
#  ['andi', 'arif', 'buang', 'aja', 'bikin', 'rusuh', 'aja'],
#  ['ayo', 'bertengkar', 'lah', 'aku', 'suka', 'hahaha'],
#  ['andi', 'arif', 'knp', 'yam'],
#  ['jadi', 'penonton', 'ah', 'menghibur'],
#  ['ular',
#   'beludak',
#   'ini',
#   'keluar',
#   'lagi',
#   'setelah',
#   'mumpet',
#   'terkencing2',
#   'tdk',
#   'berani',
#   'bicara',
#   'di',
#   'dpn',
#   'bawaslu',
#   'ud83dude03'],
#  ['sudah',
#   'tahu',
#   'bahwa',
#   'kalau',
#   'berkata',
#   'bohong',
#   'tidak',
#   'sesuai',
#   'omongan',
#   'kalau',
#   'janji',
#   'ingkar',
#   'plinplan',
#   'kalau',
#   'dipercaya',
#   'ingkar',
#   'tidak',
#   'konsisten',
#   'tahu',
#   'munafik',
#   'kok',
#   'seteju',
#   'yg',
#   'waras',
#   'siapa',
#   'ya'],
#  ['u2063pertempuran',
#   'utama',
#   'di',
#   'pilpres',
#   '2019',
#   'ialah',
#   'jawa',
#   'barat',
#   'jawa',
#   'tengah',
#   'jawa',
#   'timur',
#   'sumatera',
#   'utara',
#   'dan',
#   'sulawesi',
#   'selatan',
#   'jawa',
#   'tengah',
#   'jelas',
#   'sudah',
#   'dijaga',
#   'ganjar',
#   'jawa',
#   'timur',
#   'ada',
#   'mbak',
#   'khofifah',
#   'jawa',
#   'barat',
#   'kemungkinan',
#   'dengan',
#   'naiknya',
#   'rk',
#   'jokowi',
#   'bakal',
#   'menang',
#   'sulawesi',
#   'selatan',
#   'pasti',
#   'ada',
#   'efek',
#   'dari',
#   'jk',
#   'sebagai',
#   'timses',
#   'jokowi',
#   'hanya',
#   'sumatera',
#   'utara',
#   'yang',
#   'masih',
#   'bisa',
#   'diperebutkan',
#   'oleh',
#   'kedua',
#   'koalisi'],
#  ['aduhorang',
#   'orang',
#   'jangan',
#   'di',
#   'pilih',
#   'biar',
#   'negiri',
#   'ini',
#   'tidak',
#   'segera',
#   'bubar'],
#  ['belah', 'sono', 'ribut', 'terus', 'y'],
#  ['mungkin', 'sedang', 'panas', 'dalam', 'nambah', 'satu', 'kaki', 'lagi'],
#  ['kalo',
#   'pks',
#   'mah',
#   'emang',
#   'ga',
#   'ada',
#   'malunya',
#   'ikut',
#   'kabinet',
#   'sby',
#   'tapi',
#   'ngacak2',
#   'program',
#   'sbypresiennya',
#   'aja',
#   'sampe',
#   'makan',
#   'aspal',
#   'di',
#   'jalan',
#   'nangka',
#   'noh'],
#  ['ada', 'hubungannya', 'dengan', 'kardus', 'ga', 'nih'],
#  ['maling',
#   'teriak',
#   'maling',
#   'koalisi',
#   'kok',
#   'saling',
#   'menjelekkan',
#   'ud83dude02'],
#  ['bagus', 'bro', 'hajar', 'terussss'],
#  ['apa',
#   'yang',
#   'diungkapkan',
#   'bung',
#   'andi',
#   'arif',
#   'benar',
#   'sekali',
#   'kita',
#   'masih',
#   'ingat',
#   'waktu',
#   'pks',
#   'ikut',
#   'dalam',
#   'kabinet',
#   'pak',
#   'sby',
#   'tapi',
#   'apabila',
#   'ada',
#   'kebijakan',
#   'dari',
#   'sby',
#   'selalu',
#   'ditentang'],
#  ['ni',
#   'orang',
#   'dri',
#   'awal',
#   'udh',
#   'mulai',
#   'ribet',
#   'sebaik',
#   'nya',
#   'klo',
#   'memang',
#   'gk',
#   'searah',
#   'pecat',
#   'ni',
#   'pa',
#   'sby'],
#  ['pd',
#   'bubar',
#   'ajalah',
#   'uda',
#   'gak',
#   'ada',
#   'wibawa',
#   'di',
#   'mata',
#   'kadernya',
#   'apa',
#   'karena',
#   'ketumnya',
#   'gak',
#   'tegas',
#   'atau',
#   'mgkn',
#   'hal',
#   'yg',
#   'sengaja',
#   'dibuat',
#   'utk',
#   'main',
#   'dua',
#   'kaki',
#   'alias',
#   'mempraktekan',
#   'politik',
#   'bermuka',
#   'dua'],
#  ['lo',
#   'pade',
#   'ngomong',
#   'ngaler',
#   'ngidul',
#   'ga',
#   'jelas',
#   'bangsa',
#   'ini',
#   'banyak',
#   'masalah',
#   'perburuhan',
#   'ekonomi',
#   'problem',
#   'kebangsaan',
#   'benturan',
#   'umat',
#   'dll',
#   'perlu',
#   'strong',
#   'leader',
#   'pas',
#   'ok'],
#  ['gawatttt',
#   'harusnya',
#   'pak',
#   'prabowo',
#   'kirim',
#   'utusan',
#   'mautnya',
#   'kayak',
#   'ahmad',
#   'dhani',
#   'neno',
#   'sarumpaet',
#   'ke',
#   'papua',
#   'wkwkwk'],
#  ['kader2mya',
#   'pd',
#   'cerdas',
#   'juga',
#   'ga',
#   'mau',
#   'dijadikan',
#   'boneka',
#   'gerindrong',
#   'cs'],
#  ['yang',
#   'jelas',
#   'perolehan',
#   'suaran',
#   'jokowi',
#   'maruf',
#   'amin',
#   'akan',
#   'bertambahud83dude06'],
#  ['kira2',
#   'kalau',
#   'di',
#   'adu',
#   'dari',
#   'sisi',
#   'intelektual',
#   'kecerdasan',
#   'kesederhanaan',
#   'kepemimpinan',
#   'kekayaan',
#   'dari',
#   '4',
#   'kandidat',
#   'capres',
#   'cawapres',
#   'siapa',
#   'yg',
#   'menang',
#   'ya',
#   'gampang',
#   'sandi',
#   'yg',
#   'menang',
#   'muda',
#   'kaya',
#   'pinter',
#   'cerdas',
#   'sederhana',
#   'dan',
#   'yg',
#   'paling',
#   'penting',
#   'setia',
#   'sama',
#   'istri',
#   'dan',
#   'sayang',
#   'anak',
#   'gila',
#   'perfect',
#   'banget',
#   'sih',
#   'lo',
#   'sandi',
#   'yg',
#   'lain',
#   'pada',
#   'main',
#   'bini',
#   'muda',
#   'sama',
#   'selingkuh',
#   'lo',
#   'yg',
#   'duitnya',
#   'banyak',
#   'kok',
#   'malah',
#   'setia',
#   'top'],
#  ['2019jokowipresiden'],
#  ['bagi',
#   '90',
#   'pengurus',
#   'dpd',
#   'demokrat',
#   'di',
#   'papua',
#   'ini',
#   'hati',
#   'nurani',
#   'mereka',
#   'lebih',
#   'punya',
#   'integritas',
#   'krn',
#   'mereka',
#   'tau',
#   'sesungguhnya',
#   'siapa',
#   'yg',
#   'selama',
#   'ini',
#   'bekerja',
#   'utk',
#   'warganya'],
#  ['rakyat',
#   'papua',
#   'tau',
#   'mana',
#   'presiden',
#   'yang',
#   'perhatian',
#   'dengan',
#   'papua',
#   'mana',
#   'yang',
#   'purapura',
#   'perhatian',
#   'btw',
#   'balikin',
#   'kardusnya',
#   'sandi'],
#  ['jati',
#   'diri',
#   'gak',
#   'pentinglah',
#   'yahyg',
#   'penting',
#   'menangklik',
#   'google',
#   'hambalang'],
#  ['emang',
#   'jokowi',
#   'masih',
#   'diinginkan',
#   'sebagian',
#   'besar',
#   'rakyat',
#   'untuk',
#   'menjadi',
#   'presiden',
#   '2',
#   'periode',
#   'kok'],
#  ['masalah',
#   'papua',
#   'itu',
#   'sangat',
#   'gampang',
#   'dan',
#   'malah',
#   'terlalu',
#   'gampang',
#   'merebut',
#   'suara',
#   'orang',
#   'papua',
#   'sbb',
#   'orang',
#   'papua',
#   'gak',
#   'denger',
#   'gubernur',
#   'asal',
#   'di',
#   'serahkan',
#   'sama',
#   'yg',
#   'ahli',
#   'nya',
#   'di',
#   'jamin',
#   '100',
#   'beresyg',
#   'jelas',
#   'bkn',
#   'masalah',
#   'infra',
#   'struktur',
#   'sbb',
#   'yg',
#   'menikmati',
#   'nya',
#   'tetap',
#   'pendatang',
#   'sdgkn',
#   'orang',
#   'asli',
#   'papua',
#   'ttp',
#   'jd',
#   'penontonserahkan',
#   'pada',
#   'ahli',
#   'nya',
#   'papua',
#   'pasti',
#   'prabowo',
#   'sandi'],
#  ['demokrat',
#   'seharusnya',
#   'join',
#   'dengan',
#   'jokowi',
#   'saja',
#   'tim',
#   'prabowo',
#   'sandi',
#   'ga',
#   'butuh',
#   'demokrat',
#   'cukup',
#   'masyarakatemak2gerindrapkspan',
#   'saja',
#   'sudah',
#   'pasti',
#   'menang',
#   'di',
#   '2019'],
#  ['woi',
#   'kembalikan',
#   'kardusnya',
#   'kalo',
#   'ga',
#   '100',
#   'dukung',
#   'wowowkwkwk'],
#  ['alhamdulillah', 'amin'],
#  ['sebaiknya',
#   'demokrat',
#   'ke',
#   'jokowi',
#   'saja',
#   'tdk',
#   'apa',
#   'apa',
#   'pks',
#   'pan',
#   'gerindra',
#   'sangat',
#   'solid'],
#  ['harusx',
#   'dpd',
#   'tdk',
#   'bisa',
#   'mengatur',
#   'dppkepututsan',
#   'dpp',
#   'harusx',
#   'satu',
#   'komandomiris',
#   'jg',
#   'ini'],
#  ['demokrat', 'plin', 'plan'],
#  ['karna',
#   'tdk',
#   'terbendung',
#   'suara',
#   'kader',
#   'yg',
#   'terbelah',
#   'berobah',
#   'strategi',
#   'demi',
#   'menutup',
#   'muka',
#   'yg',
#   'sudah',
#   'malukasihan',
#   'demokrat'],
#  ['100', 'paksoalnya', 'joko', 'wi', 'orang', 'baik'],
#  ['rakyat',
#   'papua',
#   'merasakan',
#   'langsung',
#   'pembangunan',
#   'era',
#   'presiden',
#   'jokowi'],
#  ['hasil', 'akhirnya', 'dan', 'saya', 'yakin', 'jokowi', 'kalah', 'dipapua'],
#  ['bagus',
#   'jangan',
#   'ikut',
#   'orang',
#   'jahat',
#   'saudara2',
#   'papua',
#   'merasakan',
#   'pembangunan'],
#  ['apa', 'kata', 'gerinda', 'cs', 'ya', 'hayo', 'apa'],
#  ['karena', 'papu', 'maju'],
#  ['mbah', 'mien', 'langsung', 'kejangkejang'],
#  ['mereka',
#   'ini',
#   'yg',
#   'bener2',
#   'sdh',
#   'merasakan',
#   'langsung',
#   'dampak',
#   'pembangunan',
#   'jalan',
#   'dan',
#   'sebagainya',
#   'di',
#   'sana',
#   'tidak',
#   'bisa',
#   'ditutupi',
#   'dan',
#   'disangkal',
#   'lagi'],
#  ...]

# %%
#Memotong comment agar mempercepat proses
tok_comments = tok_comments[:1000]

# %%
len(tok_comments)
# Out:
# 1000

# %%
#Mengolah corpus yang ada
import io
import time
from datetime import timedelta
import gensim
start_time = time.time()
print('Streaming wiki...')
id_wiki = gensim.corpora.WikiCorpus('idwiki-latest-pages-articles.xml.bz2', lemmatize=False, dictionary={})
article_count = 0
with io.open('idwiki.txt', 'w', encoding='utf-8') as wiki_txt:
    for text in id_wiki.get_texts():
        wiki_txt.write(" ".join(text) + '\n')
        article_count += 1
        if article_count % 10000 == 0:
            print('{} articles processed'.format(article_count))
    print('total: {} articles'.format(article_count))
finish_time = time.time()
print('Elapsed time: {}'.format(timedelta(seconds=finish_time-start_time)))
# Out:
# Streaming wiki...
# C:\Users\User\Anaconda3\lib\site-packages\gensim\utils.py:1254: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# 10000 articles processed
# 20000 articles processed
# 30000 articles processed
# 40000 articles processed
# 50000 articles processed
# 60000 articles processed
# 70000 articles processed
# 80000 articles processed
# 90000 articles processed
# 100000 articles processed
# 110000 articles processed
# 120000 articles processed
# 130000 articles processed
# 140000 articles processed
# 150000 articles processed
# 160000 articles processed
# 170000 articles processed
# 180000 articles processed
# 190000 articles processed
# 200000 articles processed
# 210000 articles processed
# 220000 articles processed
# 230000 articles processed
# 240000 articles processed
# 250000 articles processed
# 260000 articles processed
# 270000 articles processed
# 280000 articles processed
# 290000 articles processed
# 300000 articles processed
# 310000 articles processed
# 320000 articles processed
# 330000 articles processed
# 340000 articles processed
# 350000 articles processed
# 360000 articles processed
# 370000 articles processed
# 380000 articles processed
# 390000 articles processed
# total: 396822 articles
# Elapsed time: 0:10:03.408350

# %%
#Word2Vec the Corpus
import time
import multiprocessing
from datetime import timedelta
from gensim.models import word2vec
start_time = time.time()
print('Training Word2Vec Model...')
sentences = word2vec.LineSentence('idwiki.txt')
id_w2v = word2vec.Word2Vec(sentences, size=200, workers=multiprocessing.cpu_count()-1)
id_w2v.save('idwiki_word2vec.model')
finish_time = time.time()
print('Finished. Elapsed time: {}'.format(timedelta(seconds=finish_time-start_time)))
# Out:
# Training Word2Vec Model...
# Finished. Elapsed time: 0:10:59.059050

# %%
#Cheking the model
id_w2v.wv.most_similar("yg")
# Out:
# [('yang', 0.6554850339889526),
#  ('disini', 0.48962175846099854),
#  ('memang', 0.4674992561340332),
#  ('apabila', 0.4321090579032898),
#  ('bila', 0.4316939115524292),
#  ('jika', 0.42876383662223816),
#  ('yag', 0.4264660179615021),
#  ('maka', 0.4250125288963318),
#  ('sehingga', 0.41329556703567505),
#  ('karena', 0.40245938301086426)]

# %%
id_w2v.wv.most_similar("gak")
# Out:
# [('nggak', 0.8128730058670044),
#  ('aja', 0.7777500152587891),
#  ('enggak', 0.7628958225250244),
#  ('sih', 0.7455835342407227),
#  ('gue', 0.7286921143531799),
#  ('udah', 0.7181901335716248),
#  ('kalo', 0.7105299234390259),
#  ('ngomong', 0.706667423248291),
#  ('gimana', 0.7044582366943359),
#  ('ngga', 0.700126051902771)]

# %%
#Memproses data slang
import pandas as pd
slang_corpus = pd.read_csv("colloquial-indonesian-lexicon.csv")
slang_corpus
# Out:
#             slang         formal  In-dictionary  \
# 0            woww            wow              1
# 1           aminn           amin              1
# 2             met        selamat              1
# 3          netaas        menetas              1
# 4         keberpa       keberapa              0
# 5        eeeehhhh             eh              1
# 6      kata2nyaaa   kata-katanya              0
# 7           hallo           halo              1
# 8            kaka          kakak              1
# 9              ka            kak              1
# 10           daah            dah              1
# 11      aaaaahhhh             ah              1
# 12            yaa             ya              1
# 13           smga         semoga              1
# 14          slalu         selalu              1
# 15          amiin           amin              1
# 16             kk          kakak              1
# 17           trus          terus              1
# 18             kk          kakak              1
# 19            sii            sih              1
# 20      nyenengin   menyenangkan              1
# 21            bgt         banget              1
# 22         gemess          gemas              1
# 23          akuuu            aku              1
# 24            jgn         jangan              1
# 25            yaa             ya              1
# 26           udah          sudah              1
# 27           gitu         begitu              1
# 28            aja           saja              1
# 29       gemesiin   menggemaskan              1
# ...           ...            ...            ...
# 14976          kl           kalo              1
# 14977        sich            sih              1
# 14978         pgn         pengin              1
# 14979     senang2  senang-senang              1
# 14980          jh           saja              1
# 14981         seh            sih              1
# 14982       nggak         enggak              1
# 14983  kereeennnn          keren              1
# 14984        donk           dong              1
# 14985         bln          bulan              1
# 14986         gmn      bagaimana              1
# 14987     gilakkk           gila              1
# 14988        gtu2    begitu-gitu              0
# 14989        sehh            sih              1
# 14990        kakk            kak              1
# 14991        ajah           saja              1
# 14992        cpet          cepat              1
# 14993       bnget         banget              1
# 14994          aq            aku              1
# 14995         uda          sudah              1
# 14996     nyobain        mencoba              1
# 14997         dlm          dalam              1
# 14998        wktu          waktu              1
# 14999          hr           hari              1
# 15000       gatau     enggak tau              0
# 15001    gataunya  enggak taunya              0
# 15002        gtau     enggak tau              0
# 15003       gatau     enggak tau              0
# 15004       fans2        fan-fan              0
# 15005     gaharus   enggak harus              0
#
#                                                  context         category1  \
# 0                                                    wow          elongasi
# 1      Selamat ulang tahun kakak tulus semoga panjang...          elongasi
# 2      Met hari netaas kak!? Wish you all the best @t...         abreviasi
# 3      Met hari netaas kak!? Wish you all the best @t...          afiksasi
# 4                               Birthday yg keberpa kak?         abreviasi
# 5                       Eh ada @ghessawarsana . Eeeehhhh          elongasi
# 6                                           Kata2nyaaa ?       reduplikasi
# 7                                      Hallo kakak tulus          elongasi
# 8      Ngefans banget sama kaka? sukses selalu ka? @t...         zeroisasi
# 9      Ngefans banget sama kaka? sukses selalu ka? @t...         zeroisasi
# 10            Senyumnya bikin aku meleleh daah?? @tulusm          elongasi
# 11     Aaaaahhhh @tulusm ,aku suka banget sama pria i...          elongasi
# 12     Aaaaahhhh @tulusm ,aku suka banget sama pria i...          elongasi
# 13     Udo @tulusm happy milad ya..?? smga diberi kes...         abreviasi
# 14     Udo @tulusm happy milad ya..?? smga diberi kes...         zeroisasi
# 15     Udo @tulusm happy milad ya..?? smga diberi kes...          elongasi
# 16     hiii kk ganteng..I realy love you somuch..suks...         abreviasi
# 17     hiii kk ganteng..I realy love you somuch..suks...         zeroisasi
# 18     hiii kk ganteng..I realy love you somuch..suks...         abreviasi
# 19     Mas tulus kenapa sii.. Orangnya nyenengin bgt....         zeroisasi
# 20     Mas tulus kenapa sii.. Orangnya nyenengin bgt....          afiksasi
# 21     Mas tulus kenapa sii.. Orangnya nyenengin bgt....         abreviasi
# 22     Mas tulus kenapa sii.. Orangnya nyenengin bgt....  modifikasi vokal
# 23     Mas tulus kenapa sii.. Orangnya nyenengin bgt....          elongasi
# 24     Mas tulus kenapa sii.. Orangnya nyenengin bgt....         abreviasi
# 25     Mas tulus kenapa sii.. Orangnya nyenengin bgt....          elongasi
# 26     Mas tulus kenapa sii.. Orangnya nyenengin bgt....         zeroisasi
# 27     Mas tulus kenapa sii.. Orangnya nyenengin bgt....         abreviasi
# 28     Mas tulus kenapa sii.. Orangnya nyenengin bgt....         zeroisasi
# 29     Mas tulus kenapa sii.. Orangnya nyenengin bgt....          afiksasi
# ...                                                  ...               ...
# 14976  wkwkkwkwkkw itu hamil ya aja masi kurus gile @...         abreviasi
# 14977  Apa sich ka rahasia nya.sudah punya anak tetap...        anaptiksis
# 14978  Gatau pgn ngetag kalian aja rasanya.... "dunia...         abreviasi
# 14979  @vivibiniling dia deliver anak senang2 jh slim...       reduplikasi
# 14980  @vivibiniling dia deliver anak senang2 jh slim...         abreviasi
# 14981  @vivibiniling dia deliver anak senang2 jh slim...  modifikasi vokal
# 14982  Sama aja deh kalo kak olla hamil dg nggak hami...         zeroisasi
# 14983                              Kereeennnn @ajengongg          elongasi
# 14984                          Bagi tips donk kak,please           homofon
# 14985         Caranya -16 kilo 1 bln gmn kak olla cantik         abreviasi
# 14986         Caranya -16 kilo 1 bln gmn kak olla cantik         abreviasi
# 14987                   Gilakkk diluk ee😭😭😭😭😭@itsdianary          elongasi
# 14988              Diet aja kagak gtu2 amat. Sedot lemak       reduplikasi
# 14989      Kak ollah berat bedan nya berapa sehh kakk ??  modifikasi vokal
# 14990      Kak ollah berat bedan nya berapa sehh kakk ??          elongasi
# 14991  Minum MOMENT SLIMMER ajah...cpet bnget, aq uda...         zeroisasi
# 14992  Minum MOMENT SLIMMER ajah...cpet bnget, aq uda...         abreviasi
# 14993  Minum MOMENT SLIMMER ajah...cpet bnget, aq uda...         abreviasi
# 14994  Minum MOMENT SLIMMER ajah...cpet bnget, aq uda...         abreviasi
# 14995  Minum MOMENT SLIMMER ajah...cpet bnget, aq uda...         zeroisasi
# 14996  Minum MOMENT SLIMMER ajah...cpet bnget, aq uda...          afiksasi
# 14997  Minum MOMENT SLIMMER ajah...cpet bnget, aq uda...         abreviasi
# 14998  Minum MOMENT SLIMMER ajah...cpet bnget, aq uda...         abreviasi
# 14999  Minum MOMENT SLIMMER ajah...cpet bnget, aq uda...         abreviasi
# 15000  Kak aku gatau harus bilang apa lg,soalnya kaka...           akronim
# 15001  Ini kaya nenek2 ya beb gataunya agnezz @yugime...           akronim
# 15002  Stidaknya mrka may berkarya Dan berusaha yg tr...           akronim
# 15003                                      Ih gatau malu           akronim
# 15004  Jkt48 adalah tempat di mana sesama fans saling...       reduplikasi
# 15005  belajar tuh bisa dimana aja gaharus belajar di...           akronim
#
#               category2 category3
# 0                     0         0
# 1                     0         0
# 2                     0         0
# 3              elongasi         0
# 4                     0         0
# 5                     0         0
# 6              elongasi         0
# 7                     0         0
# 8                     0         0
# 9                     0         0
# 10                    0         0
# 11                    0         0
# 12                    0         0
# 13                    0         0
# 14                    0         0
# 15                    0         0
# 16                    0         0
# 17                    0         0
# 18                    0         0
# 19             elongasi         0
# 20                    0         0
# 21                    0         0
# 22                    0         0
# 23                    0         0
# 24                    0         0
# 25                    0         0
# 26                    0         0
# 27                    0         0
# 28                    0         0
# 29             elongasi         0
# ...                 ...       ...
# 14976                 0         0
# 14977                 0         0
# 14978                 0         0
# 14979  modifikasi vokal         0
# 14980        anaptiksis         0
# 14981                 0         0
# 14982                 0         0
# 14983                 0         0
# 14984         subtitusi         0
# 14985                 0         0
# 14986                 0         0
# 14987        anaptiksis         0
# 14988         abreviasi         0
# 14989          elongasi         0
# 14990                 0         0
# 14991        anaptiksis         0
# 14992  modifikasi vokal         0
# 14993                 0         0
# 14994           homofon         0
# 14995                 0         0
# 14996                 0         0
# 14997                 0         0
# 14998                 0         0
# 14999                 0         0
# 15000                 0         0
# 15001                 0         0
# 15002         abreviasi         0
# 15003                 0         0
# 15004      naturalisasi         0
# 15005                 0         0
#
# [15006 rows x 7 columns]

# %%
#Filter data slang
slang_corpus = slang_corpus[slang_corpus.columns[0:2]]
slang_corpus
# Out:
#             slang         formal
# 0            woww            wow
# 1           aminn           amin
# 2             met        selamat
# 3          netaas        menetas
# 4         keberpa       keberapa
# 5        eeeehhhh             eh
# 6      kata2nyaaa   kata-katanya
# 7           hallo           halo
# 8            kaka          kakak
# 9              ka            kak
# 10           daah            dah
# 11      aaaaahhhh             ah
# 12            yaa             ya
# 13           smga         semoga
# 14          slalu         selalu
# 15          amiin           amin
# 16             kk          kakak
# 17           trus          terus
# 18             kk          kakak
# 19            sii            sih
# 20      nyenengin   menyenangkan
# 21            bgt         banget
# 22         gemess          gemas
# 23          akuuu            aku
# 24            jgn         jangan
# 25            yaa             ya
# 26           udah          sudah
# 27           gitu         begitu
# 28            aja           saja
# 29       gemesiin   menggemaskan
# ...           ...            ...
# 14976          kl           kalo
# 14977        sich            sih
# 14978         pgn         pengin
# 14979     senang2  senang-senang
# 14980          jh           saja
# 14981         seh            sih
# 14982       nggak         enggak
# 14983  kereeennnn          keren
# 14984        donk           dong
# 14985         bln          bulan
# 14986         gmn      bagaimana
# 14987     gilakkk           gila
# 14988        gtu2    begitu-gitu
# 14989        sehh            sih
# 14990        kakk            kak
# 14991        ajah           saja
# 14992        cpet          cepat
# 14993       bnget         banget
# 14994          aq            aku
# 14995         uda          sudah
# 14996     nyobain        mencoba
# 14997         dlm          dalam
# 14998        wktu          waktu
# 14999          hr           hari
# 15000       gatau     enggak tau
# 15001    gataunya  enggak taunya
# 15002        gtau     enggak tau
# 15003       gatau     enggak tau
# 15004       fans2        fan-fan
# 15005     gaharus   enggak harus
#
# [15006 rows x 2 columns]

# %%
#Menggunakan perbandingan dengan word2vec yang ada dan edit distance untuk membuat kata menjadi kata formal
print("Processing data...")
start_time = time.time()
import nltk
corr_comments = []
slang_words = []
reco_words = []
corr_word = 0
tot_word = 0
for comment in tok_comments:
    corr_comment = []
    slang_word = []
    for sub_comment in comment:
        if sub_comment in id_w2v.wv.vocab:
            sim_slang = slang_corpus[slang_corpus['slang'] == sub_comment]
            if len(sim_slang) != 0:
                mode_word = sim_slang.formal.mode()[0]
                corr_word = corr_word + 1
                corr_comment.append(mode_word)
            else:
                corr_word = corr_word + 1
                corr_comment.append(sub_comment)
        else:
            comment_found = False
            sim_slang = slang_corpus[slang_corpus['slang'] == sub_comment]
            if len(sim_slang) != 0:
                mode_word = sim_slang.formal.mode()[0]
                corr_word = corr_word + 1
                corr_comment.append(mode_word)
                comment_found = True
            else:
                rat_words = []
                for slang in slang_corpus['slang']:
                    rat_word = nltk.edit_distance(sub_comment, slang)
                    rat_words.append(rat_word)
                min_rat = rat_words.index(min(rat_words))
                value = str(slang_corpus.formal.loc[min_rat])
                corr_words = corr_word + 1
                corr_comment.append(value)
                slang_words.append(sub_comment + " = " + value)
                comment_found = True
            if comment_found ==  False:
                corr_comment.append(sub_comment)
                slang_words.append(sub_comment + " = " + "Not Found")
        tot_word = tot_word + 1
    corr_comments.append(corr_comment)
    print("Total kata yang sudah diproses : " + str(tot_word))
print("Total kata yang diperbaiki : " + str(corr_word) + " dari total semua kata : " + str(tot_word))
finish_time = time.time()
print('Elapsed time: {}'.format(timedelta(seconds=finish_time-start_time)))
# Out:
# Processing data...
# Total kata yang sudah diproses : 11
# Total kata yang sudah diproses : 27
# Total kata yang sudah diproses : 31
# Total kata yang sudah diproses : 63
# Total kata yang sudah diproses : 72
# Total kata yang sudah diproses : 122
# Total kata yang sudah diproses : 125
# Total kata yang sudah diproses : 129
# Total kata yang sudah diproses : 133
# Total kata yang sudah diproses : 151
# Total kata yang sudah diproses : 165
# Total kata yang sudah diproses : 177
# Total kata yang sudah diproses : 208
# Total kata yang sudah diproses : 227
# Total kata yang sudah diproses : 232
# Total kata yang sudah diproses : 243
# Total kata yang sudah diproses : 251
# Total kata yang sudah diproses : 256
# Total kata yang sudah diproses : 261
# Total kata yang sudah diproses : 267
# Total kata yang sudah diproses : 275
# Total kata yang sudah diproses : 287
# Total kata yang sudah diproses : 300
# Total kata yang sudah diproses : 313
# Total kata yang sudah diproses : 329
# Total kata yang sudah diproses : 333
# Total kata yang sudah diproses : 346
# Total kata yang sudah diproses : 349
# Total kata yang sudah diproses : 378
# Total kata yang sudah diproses : 386
# Total kata yang sudah diproses : 392
# Total kata yang sudah diproses : 409
# Total kata yang sudah diproses : 412
# Total kata yang sudah diproses : 423
# Total kata yang sudah diproses : 426
# Total kata yang sudah diproses : 431
# Total kata yang sudah diproses : 473
# Total kata yang sudah diproses : 486
# Total kata yang sudah diproses : 513
# Total kata yang sudah diproses : 539
# Total kata yang sudah diproses : 555
# Total kata yang sudah diproses : 585
# Total kata yang sudah diproses : 597
# Total kata yang sudah diproses : 603
# Total kata yang sudah diproses : 611
# Total kata yang sudah diproses : 622
# Total kata yang sudah diproses : 637
# Total kata yang sudah diproses : 648
# Total kata yang sudah diproses : 652
# Total kata yang sudah diproses : 676
# Total kata yang sudah diproses : 679
# Total kata yang sudah diproses : 684
# Total kata yang sudah diproses : 686
# Total kata yang sudah diproses : 698
# Total kata yang sudah diproses : 703
# Total kata yang sudah diproses : 810
# Total kata yang sudah diproses : 816
# Total kata yang sudah diproses : 822
# Total kata yang sudah diproses : 833
# Total kata yang sudah diproses : 850
# Total kata yang sudah diproses : 877
# Total kata yang sudah diproses : 879
# Total kata yang sudah diproses : 886
# Total kata yang sudah diproses : 891
# Total kata yang sudah diproses : 905
# Total kata yang sudah diproses : 917
# Total kata yang sudah diproses : 928
# Total kata yang sudah diproses : 935
# Total kata yang sudah diproses : 944
# Total kata yang sudah diproses : 963
# Total kata yang sudah diproses : 984
# Total kata yang sudah diproses : 1002
# Total kata yang sudah diproses : 1019
# Total kata yang sudah diproses : 1039
# Total kata yang sudah diproses : 1052
# Total kata yang sudah diproses : 1057
# Total kata yang sudah diproses : 1060
# Total kata yang sudah diproses : 1075
# Total kata yang sudah diproses : 1094
# Total kata yang sudah diproses : 1096
# Total kata yang sudah diproses : 1101
# Total kata yang sudah diproses : 1109
# Total kata yang sudah diproses : 1120
# Total kata yang sudah diproses : 1133
# Total kata yang sudah diproses : 1139
# Total kata yang sudah diproses : 1147
# Total kata yang sudah diproses : 1150
# Total kata yang sudah diproses : 1165
# Total kata yang sudah diproses : 1171
# Total kata yang sudah diproses : 1184
# Total kata yang sudah diproses : 1198
# Total kata yang sudah diproses : 1200
# Total kata yang sudah diproses : 1219
# Total kata yang sudah diproses : 1229
# Total kata yang sudah diproses : 1240
# Total kata yang sudah diproses : 1243
# Total kata yang sudah diproses : 1257
# Total kata yang sudah diproses : 1260
# Total kata yang sudah diproses : 1271
# Total kata yang sudah diproses : 1280
# Total kata yang sudah diproses : 1281
# Total kata yang sudah diproses : 1282
# Total kata yang sudah diproses : 1289
# Total kata yang sudah diproses : 1301
# Total kata yang sudah diproses : 1303
# Total kata yang sudah diproses : 1309
# Total kata yang sudah diproses : 1318
# Total kata yang sudah diproses : 1319
# Total kata yang sudah diproses : 1326
# Total kata yang sudah diproses : 1331
# Total kata yang sudah diproses : 1340
# Total kata yang sudah diproses : 1366
# Total kata yang sudah diproses : 1391
# Total kata yang sudah diproses : 1404
# Total kata yang sudah diproses : 1413
# Total kata yang sudah diproses : 1419
# Total kata yang sudah diproses : 1426
# Total kata yang sudah diproses : 1446
# Total kata yang sudah diproses : 1450
# Total kata yang sudah diproses : 1452
# Total kata yang sudah diproses : 1458
# Total kata yang sudah diproses : 1472
# Total kata yang sudah diproses : 1476
# Total kata yang sudah diproses : 1481
# Total kata yang sudah diproses : 1492
# Total kata yang sudah diproses : 1497
# Total kata yang sudah diproses : 1510
# Total kata yang sudah diproses : 1513
# Total kata yang sudah diproses : 1523
# Total kata yang sudah diproses : 1527
# Total kata yang sudah diproses : 1531
# Total kata yang sudah diproses : 1536
# Total kata yang sudah diproses : 1540
# Total kata yang sudah diproses : 1542
# Total kata yang sudah diproses : 1560
# Total kata yang sudah diproses : 1583
# Total kata yang sudah diproses : 1606
# Total kata yang sudah diproses : 1614
# Total kata yang sudah diproses : 1622
# Total kata yang sudah diproses : 1625
# Total kata yang sudah diproses : 1646
# Total kata yang sudah diproses : 1650
# Total kata yang sudah diproses : 1653
# Total kata yang sudah diproses : 1661
# Total kata yang sudah diproses : 1667
# Total kata yang sudah diproses : 1679
# Total kata yang sudah diproses : 1682
# Total kata yang sudah diproses : 1701
# Total kata yang sudah diproses : 1717
# Total kata yang sudah diproses : 1733
# Total kata yang sudah diproses : 1749
# Total kata yang sudah diproses : 1755
# Total kata yang sudah diproses : 1771
# Total kata yang sudah diproses : 1774
# Total kata yang sudah diproses : 1791
# Total kata yang sudah diproses : 1810
# Total kata yang sudah diproses : 1812
# Total kata yang sudah diproses : 1842
# Total kata yang sudah diproses : 1850
# Total kata yang sudah diproses : 1858
# Total kata yang sudah diproses : 1866
# Total kata yang sudah diproses : 1874
# Total kata yang sudah diproses : 1882
# Total kata yang sudah diproses : 1888
# Total kata yang sudah diproses : 1894
# Total kata yang sudah diproses : 1899
# Total kata yang sudah diproses : 1904
# Total kata yang sudah diproses : 1906
# Total kata yang sudah diproses : 1914
# Total kata yang sudah diproses : 1932
# Total kata yang sudah diproses : 1939
# Total kata yang sudah diproses : 1945
# Total kata yang sudah diproses : 1948
# Total kata yang sudah diproses : 1952
# Total kata yang sudah diproses : 1957
# Total kata yang sudah diproses : 1961
# Total kata yang sudah diproses : 1968
# Total kata yang sudah diproses : 1970
# Total kata yang sudah diproses : 1989
# Total kata yang sudah diproses : 1991
# Total kata yang sudah diproses : 1995
# Total kata yang sudah diproses : 1999
# Total kata yang sudah diproses : 2004
# Total kata yang sudah diproses : 2009
# Total kata yang sudah diproses : 2014
# Total kata yang sudah diproses : 2023
# Total kata yang sudah diproses : 2031
# Total kata yang sudah diproses : 2046
# Total kata yang sudah diproses : 2049
# Total kata yang sudah diproses : 2052
# Total kata yang sudah diproses : 2060
# Total kata yang sudah diproses : 2064
# Total kata yang sudah diproses : 2067
# Total kata yang sudah diproses : 2095
# Total kata yang sudah diproses : 2107
# Total kata yang sudah diproses : 2123
# Total kata yang sudah diproses : 2172
# Total kata yang sudah diproses : 2179
# Total kata yang sudah diproses : 2206
# Total kata yang sudah diproses : 2273
# Total kata yang sudah diproses : 2311
# Total kata yang sudah diproses : 2355
# Total kata yang sudah diproses : 2383
# Total kata yang sudah diproses : 2431
# Total kata yang sudah diproses : 2447
# Total kata yang sudah diproses : 2503
# Total kata yang sudah diproses : 2539
# Total kata yang sudah diproses : 2545
# Total kata yang sudah diproses : 2575
# Total kata yang sudah diproses : 2581
# Total kata yang sudah diproses : 2619
# Total kata yang sudah diproses : 2664
# Total kata yang sudah diproses : 2674
# Total kata yang sudah diproses : 2695
# Total kata yang sudah diproses : 2698
# Total kata yang sudah diproses : 2702
# Total kata yang sudah diproses : 2720
# Total kata yang sudah diproses : 2766
# Total kata yang sudah diproses : 2774
# Total kata yang sudah diproses : 2783
# Total kata yang sudah diproses : 2809
# Total kata yang sudah diproses : 2824
# Total kata yang sudah diproses : 2837
# Total kata yang sudah diproses : 2870
# Total kata yang sudah diproses : 2890
# Total kata yang sudah diproses : 2922
# Total kata yang sudah diproses : 2925
# Total kata yang sudah diproses : 2943
# Total kata yang sudah diproses : 2947
# Total kata yang sudah diproses : 2957
# Total kata yang sudah diproses : 2968
# Total kata yang sudah diproses : 2975
# Total kata yang sudah diproses : 2984
# Total kata yang sudah diproses : 2987
# Total kata yang sudah diproses : 3001
# Total kata yang sudah diproses : 3047
# Total kata yang sudah diproses : 3054
# Total kata yang sudah diproses : 3077
# Total kata yang sudah diproses : 3087
# Total kata yang sudah diproses : 3090
# Total kata yang sudah diproses : 3100
# Total kata yang sudah diproses : 3141
# Total kata yang sudah diproses : 3150
# Total kata yang sudah diproses : 3197
# Total kata yang sudah diproses : 3200
# Total kata yang sudah diproses : 3203
# Total kata yang sudah diproses : 3280
# Total kata yang sudah diproses : 3295
# Total kata yang sudah diproses : 3305
# Total kata yang sudah diproses : 3329
# Total kata yang sudah diproses : 3350
# Total kata yang sudah diproses : 3353
# Total kata yang sudah diproses : 3359
# Total kata yang sudah diproses : 3363
# Total kata yang sudah diproses : 3386
# Total kata yang sudah diproses : 3389
# Total kata yang sudah diproses : 3419
# Total kata yang sudah diproses : 3428
# Total kata yang sudah diproses : 3439
# Total kata yang sudah diproses : 3460
# Total kata yang sudah diproses : 3476
# Total kata yang sudah diproses : 3490
# Total kata yang sudah diproses : 3493
# Total kata yang sudah diproses : 3541
# Total kata yang sudah diproses : 3552
# Total kata yang sudah diproses : 3572
# Total kata yang sudah diproses : 3577
# Total kata yang sudah diproses : 3590
# Total kata yang sudah diproses : 3621
# Total kata yang sudah diproses : 3626
# Total kata yang sudah diproses : 3695
# Total kata yang sudah diproses : 3701
# Total kata yang sudah diproses : 3733
# Total kata yang sudah diproses : 3754
# Total kata yang sudah diproses : 3779
# Total kata yang sudah diproses : 3810
# Total kata yang sudah diproses : 3834
# Total kata yang sudah diproses : 3872
# Total kata yang sudah diproses : 3903
# Total kata yang sudah diproses : 3926
# Total kata yang sudah diproses : 3959
# Total kata yang sudah diproses : 3998
# Total kata yang sudah diproses : 4004
# Total kata yang sudah diproses : 4021
# Total kata yang sudah diproses : 4048
# Total kata yang sudah diproses : 4069
# Total kata yang sudah diproses : 4109
# Total kata yang sudah diproses : 4130
# Total kata yang sudah diproses : 4135
# Total kata yang sudah diproses : 4140
# Total kata yang sudah diproses : 4156
# Total kata yang sudah diproses : 4168
# Total kata yang sudah diproses : 4215
# Total kata yang sudah diproses : 4228
# Total kata yang sudah diproses : 4245
# Total kata yang sudah diproses : 4247
# Total kata yang sudah diproses : 4254
# Total kata yang sudah diproses : 4274
# Total kata yang sudah diproses : 4277
# Total kata yang sudah diproses : 4286
# Total kata yang sudah diproses : 4300
# Total kata yang sudah diproses : 4324
# Total kata yang sudah diproses : 4337
# Total kata yang sudah diproses : 4345
# Total kata yang sudah diproses : 4374
# Total kata yang sudah diproses : 4388
# Total kata yang sudah diproses : 4409
# Total kata yang sudah diproses : 4420
# Total kata yang sudah diproses : 4421
# Total kata yang sudah diproses : 4451
# Total kata yang sudah diproses : 4461
# Total kata yang sudah diproses : 4474
# Total kata yang sudah diproses : 4492
# Total kata yang sudah diproses : 4518
# Total kata yang sudah diproses : 4533
# Total kata yang sudah diproses : 4543
# Total kata yang sudah diproses : 4555
# Total kata yang sudah diproses : 4583
# Total kata yang sudah diproses : 4586
# Total kata yang sudah diproses : 4597
# Total kata yang sudah diproses : 4620
# Total kata yang sudah diproses : 4630
# Total kata yang sudah diproses : 4645
# Total kata yang sudah diproses : 4662
# Total kata yang sudah diproses : 4681
# Total kata yang sudah diproses : 4691
# Total kata yang sudah diproses : 4711
# Total kata yang sudah diproses : 4729
# Total kata yang sudah diproses : 4769
# Total kata yang sudah diproses : 4779
# Total kata yang sudah diproses : 4800
# Total kata yang sudah diproses : 4816
# Total kata yang sudah diproses : 4828
# Total kata yang sudah diproses : 4855
# Total kata yang sudah diproses : 4873
# Total kata yang sudah diproses : 4893
# Total kata yang sudah diproses : 4921
# Total kata yang sudah diproses : 4931
# Total kata yang sudah diproses : 4958
# Total kata yang sudah diproses : 4976
# Total kata yang sudah diproses : 5010
# Total kata yang sudah diproses : 5019
# Total kata yang sudah diproses : 5038
# Total kata yang sudah diproses : 5101
# Total kata yang sudah diproses : 5105
# Total kata yang sudah diproses : 5133
# Total kata yang sudah diproses : 5190
# Total kata yang sudah diproses : 5195
# Total kata yang sudah diproses : 5202
# Total kata yang sudah diproses : 5209
# Total kata yang sudah diproses : 5222
# Total kata yang sudah diproses : 5230
# Total kata yang sudah diproses : 5239
# Total kata yang sudah diproses : 5244
# Total kata yang sudah diproses : 5264
# Total kata yang sudah diproses : 5294
# Total kata yang sudah diproses : 5303
# Total kata yang sudah diproses : 5332
# Total kata yang sudah diproses : 5335
# Total kata yang sudah diproses : 5337
# Total kata yang sudah diproses : 5349
# Total kata yang sudah diproses : 5354
# Total kata yang sudah diproses : 5362
# Total kata yang sudah diproses : 5373
# Total kata yang sudah diproses : 5382
# Total kata yang sudah diproses : 5397
# Total kata yang sudah diproses : 5406
# Total kata yang sudah diproses : 5431
# Total kata yang sudah diproses : 5446
# Total kata yang sudah diproses : 5457
# Total kata yang sudah diproses : 5490
# Total kata yang sudah diproses : 5502
# Total kata yang sudah diproses : 5508
# Total kata yang sudah diproses : 5516
# Total kata yang sudah diproses : 5547
# Total kata yang sudah diproses : 5551
# Total kata yang sudah diproses : 5580
# Total kata yang sudah diproses : 5596
# Total kata yang sudah diproses : 5643
# Total kata yang sudah diproses : 5653
# Total kata yang sudah diproses : 5673
# Total kata yang sudah diproses : 5684
# Total kata yang sudah diproses : 5694
# Total kata yang sudah diproses : 5713
# Total kata yang sudah diproses : 5739
# Total kata yang sudah diproses : 5745
# Total kata yang sudah diproses : 5748
# Total kata yang sudah diproses : 5756
# Total kata yang sudah diproses : 5764
# Total kata yang sudah diproses : 5778
# Total kata yang sudah diproses : 5785
# Total kata yang sudah diproses : 5796
# Total kata yang sudah diproses : 5806
# Total kata yang sudah diproses : 5819
# Total kata yang sudah diproses : 5825
# Total kata yang sudah diproses : 5874
# Total kata yang sudah diproses : 5876
# Total kata yang sudah diproses : 5906
# Total kata yang sudah diproses : 5912
# Total kata yang sudah diproses : 5964
# Total kata yang sudah diproses : 5967
# Total kata yang sudah diproses : 5974
# Total kata yang sudah diproses : 5988
# Total kata yang sudah diproses : 6009
# Total kata yang sudah diproses : 6017
# Total kata yang sudah diproses : 6020
# Total kata yang sudah diproses : 6041
# Total kata yang sudah diproses : 6044
# Total kata yang sudah diproses : 6092
# Total kata yang sudah diproses : 6097
# Total kata yang sudah diproses : 6104
# Total kata yang sudah diproses : 6120
# Total kata yang sudah diproses : 6122
# Total kata yang sudah diproses : 6138
# Total kata yang sudah diproses : 6152
# Total kata yang sudah diproses : 6172
# Total kata yang sudah diproses : 6180
# Total kata yang sudah diproses : 6206
# Total kata yang sudah diproses : 6227
# Total kata yang sudah diproses : 6235
# Total kata yang sudah diproses : 6246
# Total kata yang sudah diproses : 6287
# Total kata yang sudah diproses : 6318
# Total kata yang sudah diproses : 6321
# Total kata yang sudah diproses : 6326
# Total kata yang sudah diproses : 6346
# Total kata yang sudah diproses : 6356
# Total kata yang sudah diproses : 6359
# Total kata yang sudah diproses : 6373
# Total kata yang sudah diproses : 6420
# Total kata yang sudah diproses : 6425
# Total kata yang sudah diproses : 6429
# Total kata yang sudah diproses : 6476
# Total kata yang sudah diproses : 6484
# Total kata yang sudah diproses : 6496
# Total kata yang sudah diproses : 6513
# Total kata yang sudah diproses : 6526
# Total kata yang sudah diproses : 6554
# Total kata yang sudah diproses : 6572
# Total kata yang sudah diproses : 6580
# Total kata yang sudah diproses : 6583
# Total kata yang sudah diproses : 6588
# Total kata yang sudah diproses : 6601
# Total kata yang sudah diproses : 6626
# Total kata yang sudah diproses : 6669
# Total kata yang sudah diproses : 6676
# Total kata yang sudah diproses : 6684
# Total kata yang sudah diproses : 6693
# Total kata yang sudah diproses : 6704
# Total kata yang sudah diproses : 6711
# Total kata yang sudah diproses : 6735
# Total kata yang sudah diproses : 6738
# Total kata yang sudah diproses : 6792
# Total kata yang sudah diproses : 6818
# Total kata yang sudah diproses : 6826
# Total kata yang sudah diproses : 6830
# Total kata yang sudah diproses : 6834
# Total kata yang sudah diproses : 6838
# Total kata yang sudah diproses : 6845
# Total kata yang sudah diproses : 6860
# Total kata yang sudah diproses : 6900
# Total kata yang sudah diproses : 6948
# Total kata yang sudah diproses : 6951
# Total kata yang sudah diproses : 7075
# Total kata yang sudah diproses : 7130
# Total kata yang sudah diproses : 7159
# Total kata yang sudah diproses : 7164
# Total kata yang sudah diproses : 7176
# Total kata yang sudah diproses : 7189
# Total kata yang sudah diproses : 7222
# Total kata yang sudah diproses : 7285
# Total kata yang sudah diproses : 7296
# Total kata yang sudah diproses : 7307
# Total kata yang sudah diproses : 7336
# Total kata yang sudah diproses : 7361
# Total kata yang sudah diproses : 7370
# Total kata yang sudah diproses : 7409
# Total kata yang sudah diproses : 7448
# Total kata yang sudah diproses : 7472
# Total kata yang sudah diproses : 7509
# Total kata yang sudah diproses : 7519
# Total kata yang sudah diproses : 7524
# Total kata yang sudah diproses : 7577
# Total kata yang sudah diproses : 7584
# Total kata yang sudah diproses : 7639
# Total kata yang sudah diproses : 7660
# Total kata yang sudah diproses : 7676
# Total kata yang sudah diproses : 7684
# Total kata yang sudah diproses : 7697
# Total kata yang sudah diproses : 7732
# Total kata yang sudah diproses : 7796
# Total kata yang sudah diproses : 7816
# Total kata yang sudah diproses : 7870
# Total kata yang sudah diproses : 7872
# Total kata yang sudah diproses : 7890
# Total kata yang sudah diproses : 7912
# Total kata yang sudah diproses : 7926
# Total kata yang sudah diproses : 7965
# Total kata yang sudah diproses : 7969
# Total kata yang sudah diproses : 7986
# Total kata yang sudah diproses : 7991
# Total kata yang sudah diproses : 8005
# Total kata yang sudah diproses : 8010
# Total kata yang sudah diproses : 8043
# Total kata yang sudah diproses : 8072
# Total kata yang sudah diproses : 8095
# Total kata yang sudah diproses : 8103
# Total kata yang sudah diproses : 8108
# Total kata yang sudah diproses : 8113
# Total kata yang sudah diproses : 8152
# Total kata yang sudah diproses : 8163
# Total kata yang sudah diproses : 8184
# Total kata yang sudah diproses : 8191
# Total kata yang sudah diproses : 8198
# Total kata yang sudah diproses : 8215
# Total kata yang sudah diproses : 8246
# Total kata yang sudah diproses : 8251
# Total kata yang sudah diproses : 8271
# Total kata yang sudah diproses : 8274
# Total kata yang sudah diproses : 8304
# Total kata yang sudah diproses : 8343
# Total kata yang sudah diproses : 8355
# Total kata yang sudah diproses : 8381
# Total kata yang sudah diproses : 8394
# Total kata yang sudah diproses : 8399
# Total kata yang sudah diproses : 8431
# Total kata yang sudah diproses : 8446
# Total kata yang sudah diproses : 8459
# Total kata yang sudah diproses : 8473
# Total kata yang sudah diproses : 8492
# Total kata yang sudah diproses : 8518
# Total kata yang sudah diproses : 8550
# Total kata yang sudah diproses : 8567
# Total kata yang sudah diproses : 8611
# Total kata yang sudah diproses : 8628
# Total kata yang sudah diproses : 8638
# Total kata yang sudah diproses : 8659
# Total kata yang sudah diproses : 8683
# Total kata yang sudah diproses : 8690
# Total kata yang sudah diproses : 8699
# Total kata yang sudah diproses : 8710
# Total kata yang sudah diproses : 8742
# Total kata yang sudah diproses : 8747
# Total kata yang sudah diproses : 8775
# Total kata yang sudah diproses : 8792
# Total kata yang sudah diproses : 8799
# Total kata yang sudah diproses : 8818
# Total kata yang sudah diproses : 8852
# Total kata yang sudah diproses : 8924
# Total kata yang sudah diproses : 8936
# Total kata yang sudah diproses : 8941
# Total kata yang sudah diproses : 8957
# Total kata yang sudah diproses : 8966
# Total kata yang sudah diproses : 8984
# Total kata yang sudah diproses : 8997
# Total kata yang sudah diproses : 9009
# Total kata yang sudah diproses : 9014
# Total kata yang sudah diproses : 9037
# Total kata yang sudah diproses : 9045
# Total kata yang sudah diproses : 9068
# Total kata yang sudah diproses : 9098
# Total kata yang sudah diproses : 9104
# Total kata yang sudah diproses : 9115
# Total kata yang sudah diproses : 9140
# Total kata yang sudah diproses : 9142
# Total kata yang sudah diproses : 9147
# Total kata yang sudah diproses : 9152
# Total kata yang sudah diproses : 9159
# Total kata yang sudah diproses : 9173
# Total kata yang sudah diproses : 9197
# Total kata yang sudah diproses : 9211
# Total kata yang sudah diproses : 9230
# Total kata yang sudah diproses : 9243
# Total kata yang sudah diproses : 9263
# Total kata yang sudah diproses : 9274
# Total kata yang sudah diproses : 9289
# Total kata yang sudah diproses : 9298
# Total kata yang sudah diproses : 9313
# Total kata yang sudah diproses : 9343
# Total kata yang sudah diproses : 9354
# Total kata yang sudah diproses : 9359
# Total kata yang sudah diproses : 9376
# Total kata yang sudah diproses : 9413
# Total kata yang sudah diproses : 9425
# Total kata yang sudah diproses : 9441
# Total kata yang sudah diproses : 9480
# Total kata yang sudah diproses : 9504
# Total kata yang sudah diproses : 9511
# Total kata yang sudah diproses : 9533
# Total kata yang sudah diproses : 9540
# Total kata yang sudah diproses : 9542
# Total kata yang sudah diproses : 9551
# Total kata yang sudah diproses : 9564
# Total kata yang sudah diproses : 9584
# Total kata yang sudah diproses : 9601
# Total kata yang sudah diproses : 9608
# Total kata yang sudah diproses : 9611
# Total kata yang sudah diproses : 9615
# Total kata yang sudah diproses : 9687
# Total kata yang sudah diproses : 9696
# Total kata yang sudah diproses : 9703
# Total kata yang sudah diproses : 9740
# Total kata yang sudah diproses : 9746
# Total kata yang sudah diproses : 9748
# Total kata yang sudah diproses : 9753
# Total kata yang sudah diproses : 9799
# Total kata yang sudah diproses : 9803
# Total kata yang sudah diproses : 9816
# Total kata yang sudah diproses : 9822
# Total kata yang sudah diproses : 9836
# Total kata yang sudah diproses : 9851
# Total kata yang sudah diproses : 9854
# Total kata yang sudah diproses : 9866
# Total kata yang sudah diproses : 9871
# Total kata yang sudah diproses : 9930
# Total kata yang sudah diproses : 9938
# Total kata yang sudah diproses : 9949
# Total kata yang sudah diproses : 9963
# Total kata yang sudah diproses : 9973
# Total kata yang sudah diproses : 9979
# Total kata yang sudah diproses : 9990
# Total kata yang sudah diproses : 10027
# Total kata yang sudah diproses : 10045
# Total kata yang sudah diproses : 10052
# Total kata yang sudah diproses : 10054
# Total kata yang sudah diproses : 10055
# Total kata yang sudah diproses : 10092
# Total kata yang sudah diproses : 10095
# Total kata yang sudah diproses : 10126
# Total kata yang sudah diproses : 10154
# Total kata yang sudah diproses : 10160
# Total kata yang sudah diproses : 10172
# Total kata yang sudah diproses : 10184
# Total kata yang sudah diproses : 10211
# Total kata yang sudah diproses : 10219
# Total kata yang sudah diproses : 10228
# Total kata yang sudah diproses : 10230
# Total kata yang sudah diproses : 10234
# Total kata yang sudah diproses : 10236
# Total kata yang sudah diproses : 10251
# Total kata yang sudah diproses : 10263
# Total kata yang sudah diproses : 10294
# Total kata yang sudah diproses : 10320
# Total kata yang sudah diproses : 10335
# Total kata yang sudah diproses : 10339
# Total kata yang sudah diproses : 10360
# Total kata yang sudah diproses : 10365
# Total kata yang sudah diproses : 10375
# Total kata yang sudah diproses : 10393
# Total kata yang sudah diproses : 10413
# Total kata yang sudah diproses : 10426
# Total kata yang sudah diproses : 10467
# Total kata yang sudah diproses : 10477
# Total kata yang sudah diproses : 10481
# Total kata yang sudah diproses : 10493
# Total kata yang sudah diproses : 10497
# Total kata yang sudah diproses : 10505
# Total kata yang sudah diproses : 10516
# Total kata yang sudah diproses : 10518
# Total kata yang sudah diproses : 10531
# Total kata yang sudah diproses : 10536
# Total kata yang sudah diproses : 10556
# Total kata yang sudah diproses : 10562
# Total kata yang sudah diproses : 10577
# Total kata yang sudah diproses : 10589
# Total kata yang sudah diproses : 10608
# Total kata yang sudah diproses : 10658
# Total kata yang sudah diproses : 10669
# Total kata yang sudah diproses : 10674
# Total kata yang sudah diproses : 10677
# Total kata yang sudah diproses : 10705
# Total kata yang sudah diproses : 10715
# Total kata yang sudah diproses : 10720
# Total kata yang sudah diproses : 10729
# Total kata yang sudah diproses : 10740
# Total kata yang sudah diproses : 10755
# Total kata yang sudah diproses : 10778
# Total kata yang sudah diproses : 10784
# Total kata yang sudah diproses : 10842
# Total kata yang sudah diproses : 10857
# Total kata yang sudah diproses : 10885
# Total kata yang sudah diproses : 10907
# Total kata yang sudah diproses : 10926
# Total kata yang sudah diproses : 10941
# Total kata yang sudah diproses : 10966
# Total kata yang sudah diproses : 10981
# Total kata yang sudah diproses : 11005
# Total kata yang sudah diproses : 11050
# Total kata yang sudah diproses : 11067
# Total kata yang sudah diproses : 11085
# Total kata yang sudah diproses : 11088
# Total kata yang sudah diproses : 11100
# Total kata yang sudah diproses : 11112
# Total kata yang sudah diproses : 11120
# Total kata yang sudah diproses : 11140
# Total kata yang sudah diproses : 11152
# Total kata yang sudah diproses : 11168
# Total kata yang sudah diproses : 11172
# Total kata yang sudah diproses : 11175
# Total kata yang sudah diproses : 11185
# Total kata yang sudah diproses : 11192
# Total kata yang sudah diproses : 11212
# Total kata yang sudah diproses : 11247
# Total kata yang sudah diproses : 11272
# Total kata yang sudah diproses : 11288
# Total kata yang sudah diproses : 11298
# Total kata yang sudah diproses : 11306
# Total kata yang sudah diproses : 11318
# Total kata yang sudah diproses : 11344
# Total kata yang sudah diproses : 11360
# Total kata yang sudah diproses : 11378
# Total kata yang sudah diproses : 11395
# Total kata yang sudah diproses : 11417
# Total kata yang sudah diproses : 11423
# Total kata yang sudah diproses : 11442
# Total kata yang sudah diproses : 11477
# Total kata yang sudah diproses : 11483
# Total kata yang sudah diproses : 11565
# Total kata yang sudah diproses : 11572
# Total kata yang sudah diproses : 11592
# Total kata yang sudah diproses : 11601
# Total kata yang sudah diproses : 11610
# Total kata yang sudah diproses : 11621
# Total kata yang sudah diproses : 11642
# Total kata yang sudah diproses : 11656
# Total kata yang sudah diproses : 11678
# Total kata yang sudah diproses : 11695
# Total kata yang sudah diproses : 11709
# Total kata yang sudah diproses : 11728
# Total kata yang sudah diproses : 11740
# Total kata yang sudah diproses : 11768
# Total kata yang sudah diproses : 11796
# Total kata yang sudah diproses : 11806
# Total kata yang sudah diproses : 11816
# Total kata yang sudah diproses : 11825
# Total kata yang sudah diproses : 11830
# Total kata yang sudah diproses : 11842
# Total kata yang sudah diproses : 11851
# Total kata yang sudah diproses : 11858
# Total kata yang sudah diproses : 11876
# Total kata yang sudah diproses : 11887
# Total kata yang sudah diproses : 11902
# Total kata yang sudah diproses : 11914
# Total kata yang sudah diproses : 11922
# Total kata yang sudah diproses : 11948
# Total kata yang sudah diproses : 11956
# Total kata yang sudah diproses : 11977
# Total kata yang sudah diproses : 11984
# Total kata yang sudah diproses : 11992
# Total kata yang sudah diproses : 11997
# Total kata yang sudah diproses : 12008
# Total kata yang sudah diproses : 12026
# Total kata yang sudah diproses : 12041
# Total kata yang sudah diproses : 12082
# Total kata yang sudah diproses : 12139
# Total kata yang sudah diproses : 12148
# Total kata yang sudah diproses : 12156
# Total kata yang sudah diproses : 12162
# Total kata yang sudah diproses : 12188
# Total kata yang sudah diproses : 12199
# Total kata yang sudah diproses : 12210
# Total kata yang sudah diproses : 12237
# Total kata yang sudah diproses : 12272
# Total kata yang sudah diproses : 12298
# Total kata yang sudah diproses : 12315
# Total kata yang sudah diproses : 12328
# Total kata yang sudah diproses : 12364
# Total kata yang sudah diproses : 12404
# Total kata yang sudah diproses : 12413
# Total kata yang sudah diproses : 12418
# Total kata yang sudah diproses : 12464
# Total kata yang sudah diproses : 12496
# Total kata yang sudah diproses : 12501
# Total kata yang sudah diproses : 12508
# Total kata yang sudah diproses : 12518
# Total kata yang sudah diproses : 12530
# Total kata yang sudah diproses : 12540
# Total kata yang sudah diproses : 12562
# Total kata yang sudah diproses : 12581
# Total kata yang sudah diproses : 12594
# Total kata yang sudah diproses : 12607
# Total kata yang sudah diproses : 12632
# Total kata yang sudah diproses : 12656
# Total kata yang sudah diproses : 12661
# Total kata yang sudah diproses : 12681
# Total kata yang sudah diproses : 12690
# Total kata yang sudah diproses : 12712
# Total kata yang sudah diproses : 12735
# Total kata yang sudah diproses : 12739
# Total kata yang sudah diproses : 12758
# Total kata yang sudah diproses : 12786
# Total kata yang sudah diproses : 12798
# Total kata yang sudah diproses : 12821
# Total kata yang sudah diproses : 12825
# Total kata yang sudah diproses : 12842
# Total kata yang sudah diproses : 12852
# Total kata yang sudah diproses : 12858
# Total kata yang sudah diproses : 12866
# Total kata yang sudah diproses : 12872
# Total kata yang sudah diproses : 12879
# Total kata yang sudah diproses : 12891
# Total kata yang sudah diproses : 12898
# Total kata yang sudah diproses : 12904
# Total kata yang sudah diproses : 12930
# Total kata yang sudah diproses : 12955
# Total kata yang sudah diproses : 12982
# Total kata yang sudah diproses : 12996
# Total kata yang sudah diproses : 13011
# Total kata yang sudah diproses : 13020
# Total kata yang sudah diproses : 13027
# Total kata yang sudah diproses : 13050
# Total kata yang sudah diproses : 13056
# Total kata yang sudah diproses : 13067
# Total kata yang sudah diproses : 13069
# Total kata yang sudah diproses : 13119
# Total kata yang sudah diproses : 13135
# Total kata yang sudah diproses : 13138
# Total kata yang sudah diproses : 13156
# Total kata yang sudah diproses : 13168
# Total kata yang sudah diproses : 13174
# Total kata yang sudah diproses : 13191
# Total kata yang sudah diproses : 13202
# Total kata yang sudah diproses : 13228
# Total kata yang sudah diproses : 13236
# Total kata yang sudah diproses : 13240
# Total kata yang sudah diproses : 13242
# Total kata yang sudah diproses : 13253
# Total kata yang sudah diproses : 13259
# Total kata yang sudah diproses : 13267
# Total kata yang sudah diproses : 13273
# Total kata yang sudah diproses : 13280
# Total kata yang sudah diproses : 13297
# Total kata yang sudah diproses : 13304
# Total kata yang sudah diproses : 13323
# Total kata yang sudah diproses : 13331
# Total kata yang sudah diproses : 13340
# Total kata yang sudah diproses : 13402
# Total kata yang sudah diproses : 13441
# Total kata yang sudah diproses : 13449
# Total kata yang sudah diproses : 13451
# Total kata yang sudah diproses : 13466
# Total kata yang sudah diproses : 13479
# Total kata yang sudah diproses : 13483
# Total kata yang sudah diproses : 13486
# Total kata yang sudah diproses : 13529
# Total kata yang sudah diproses : 13533
# Total kata yang sudah diproses : 13548
# Total kata yang sudah diproses : 13576
# Total kata yang sudah diproses : 13581
# Total kata yang sudah diproses : 13604
# Total kata yang sudah diproses : 13616
# Total kata yang sudah diproses : 13625
# Total kata yang sudah diproses : 13630
# Total kata yang sudah diproses : 13650
# Total kata yang sudah diproses : 13651
# Total kata yang sudah diproses : 13658
# Total kata yang sudah diproses : 13671
# Total kata yang sudah diproses : 13685
# Total kata yang sudah diproses : 13699
# Total kata yang sudah diproses : 13720
# Total kata yang sudah diproses : 13723
# Total kata yang sudah diproses : 13735
# Total kata yang sudah diproses : 13754
# Total kata yang sudah diproses : 13758
# Total kata yang sudah diproses : 13772
# Total kata yang sudah diproses : 13807
# Total kata yang sudah diproses : 13818
# Total kata yang sudah diproses : 13830
# Total kata yang sudah diproses : 13853
# Total kata yang sudah diproses : 13862
# Total kata yang sudah diproses : 13873
# Total kata yang sudah diproses : 13874
# Total kata yang sudah diproses : 13894
# Total kata yang sudah diproses : 13897
# Total kata yang sudah diproses : 13902
# Total kata yang sudah diproses : 13926
# Total kata yang sudah diproses : 13953
# Total kata yang sudah diproses : 13998
# Total kata yang sudah diproses : 14003
# Total kata yang sudah diproses : 14011
# Total kata yang sudah diproses : 14013
# Total kata yang sudah diproses : 14030
# Total kata yang sudah diproses : 14045
# Total kata yang sudah diproses : 14099
# Total kata yang sudah diproses : 14110
# Total kata yang sudah diproses : 14116
# Total kata yang sudah diproses : 14124
# Total kata yang sudah diproses : 14151
# Total kata yang sudah diproses : 14153
# Total kata yang sudah diproses : 14162
# Total kata yang sudah diproses : 14167
# Total kata yang sudah diproses : 14174
# Total kata yang sudah diproses : 14187
# Total kata yang sudah diproses : 14191
# Total kata yang sudah diproses : 14200
# Total kata yang sudah diproses : 14203
# Total kata yang sudah diproses : 14207
# Total kata yang sudah diproses : 14249
# Total kata yang sudah diproses : 14253
# Total kata yang sudah diproses : 14260
# Total kata yang sudah diproses : 14263
# Total kata yang sudah diproses : 14295
# Total kata yang sudah diproses : 14301
# Total kata yang sudah diproses : 14305
# Total kata yang sudah diproses : 14327
# Total kata yang sudah diproses : 14338
# Total kata yang sudah diproses : 14352
# Total kata yang sudah diproses : 14375
# Total kata yang sudah diproses : 14394
# Total kata yang sudah diproses : 14414
# Total kata yang sudah diproses : 14422
# Total kata yang sudah diproses : 14496
# Total kata yang sudah diproses : 14507
# Total kata yang sudah diproses : 14522
# Total kata yang sudah diproses : 14528
# Total kata yang sudah diproses : 14537
# Total kata yang sudah diproses : 14542
# Total kata yang sudah diproses : 14565
# Total kata yang sudah diproses : 14573
# Total kata yang sudah diproses : 14577
# Total kata yang sudah diproses : 14609
# Total kata yang sudah diproses : 14625
# Total kata yang sudah diproses : 14629
# Total kata yang sudah diproses : 14634
# Total kata yang sudah diproses : 14640
# Total kata yang sudah diproses : 14645
# Total kata yang sudah diproses : 14654
# Total kata yang sudah diproses : 14662
# Total kata yang sudah diproses : 14670
# Total kata yang sudah diproses : 14677
# Total kata yang sudah diproses : 14679
# Total kata yang sudah diproses : 14683
# Total kata yang sudah diproses : 14702
# Total kata yang sudah diproses : 14713
# Total kata yang sudah diproses : 14737
# Total kata yang sudah diproses : 14743
# Total kata yang sudah diproses : 14754
# Total kata yang sudah diproses : 14762
# Total kata yang sudah diproses : 14773
# Total kata yang sudah diproses : 14781
# Total kata yang sudah diproses : 14792
# Total kata yang sudah diproses : 14795
# Total kata yang sudah diproses : 14813
# Total kata yang sudah diproses : 14833
# Total kata yang sudah diproses : 14853
# Total kata yang sudah diproses : 14867
# Total kata yang sudah diproses : 14872
# Total kata yang sudah diproses : 14882
# Total kata yang sudah diproses : 14885
# Total kata yang sudah diproses : 14920
# Total kata yang sudah diproses : 14926
# Total kata yang sudah diproses : 14951
# Total kata yang sudah diproses : 15012
# Total kata yang sudah diproses : 15013
# Total kata yang sudah diproses : 15029
# Total kata yang sudah diproses : 15043
# Total kata yang sudah diproses : 15050
# Total kata yang sudah diproses : 15057
# Total kata yang sudah diproses : 15063
# Total kata yang sudah diproses : 15067
# Total kata yang sudah diproses : 15071
# Total kata yang sudah diproses : 15086
# Total kata yang sudah diproses : 15112
# Total kata yang sudah diproses : 15169
# Total kata yang sudah diproses : 15180
# Total kata yang sudah diproses : 15185
# Total kata yang sudah diproses : 15193
# Total kata yang sudah diproses : 15215
# Total kata yang sudah diproses : 15221
# Total kata yang sudah diproses : 15229
# Total kata yang sudah diproses : 15233
# Total kata yang sudah diproses : 15259
# Total kata yang sudah diproses : 15276
# Total kata yang sudah diproses : 15306
# Total kata yang sudah diproses : 15329
# Total kata yang sudah diproses : 15344
# Total kata yang sudah diproses : 15354
# Total kata yang sudah diproses : 15363
# Total kata yang sudah diproses : 15424
# Total kata yang sudah diproses : 15425
# Total kata yang sudah diproses : 15450
# Total kata yang sudah diproses : 15467
# Total kata yang sudah diproses : 15476
# Total kata yang sudah diproses : 15489
# Total kata yang sudah diproses : 15544
# Total kata yang sudah diproses : 15564
# Total kata yang sudah diproses : 15572
# Total kata yang sudah diproses : 15574
# Total kata yang sudah diproses : 15587
# Total kata yang sudah diproses : 15599
# Total kata yang sudah diproses : 15602
# Total kata yang sudah diproses : 15618
# Total kata yang sudah diproses : 15624
# Total kata yang sudah diproses : 15632
# Total kata yang sudah diproses : 15640
# Total kata yang sudah diproses : 15649
# Total kata yang sudah diproses : 15656
# Total kata yang sudah diproses : 15659
# Total kata yang sudah diproses : 15663
# Total kata yang sudah diproses : 15683
# Total kata yang diperbaiki : 14562 dari total semua kata : 15683
# Elapsed time: 0:11:21.008719

# %%
#Commentar yang sudah diperbaiki
corr_comments
# Out:
# [['wkwkwk',
#   'enggak',
#   'sekalian',
#   'pak',
#   'selawat',
#   'ke',
#   'dpr',
#   'kan',
#   'banyak',
#   'koruptor',
#   'disana'],
#  ['mantab',
#   'ini',
#   'baru',
#   'dakwah',
#   'yang',
#   'sejati',
#   'kalo',
#   'di',
#   'tempat',
#   'umum',
#   'mah',
#   'dah',
#   'biasa',
#   'ini',
#   'luar',
#   'biasa'],
#  ['salut', 'buat', 'gus', 'miftah'],
#  ['yang',
#   'nyinyir',
#   'enggak',
#   'pernah',
#   'lihat',
#   'dan',
#   'baca',
#   'atau',
#   'mengetahui',
#   'sejarah',
#   'dakwah',
#   'walisongo',
#   'sunan',
#   'kali',
#   'bagaimana',
#   'ada',
#   'cara',
#   'demi',
#   'kebaikan',
#   'asal',
#   'jangan',
#   'ajk',
#   'dengan',
#   'cara',
#   'berzina',
#   'lakukan',
#   'dengan',
#   'porsi',
#   'dan',
#   'sikon',
#   'yang',
#   'tepat'],
#  ['ada',
#   'adabnya',
#   'sholawat',
#   'lebih',
#   'baik',
#   'ajak',
#   'ke',
#   'majelis',
#   'ilmu'],
#  ['setiap',
#   'ulama',
#   'punya',
#   'jalan',
#   'dan',
#   'cara',
#   'dakwah',
#   'masing-masing',
#   'jika',
#   'kamu',
#   'melihat',
#   'kemunkaran',
#   'lawan',
#   'dengan',
#   'ambekan',
#   'jika',
#   'tidak',
#   'mampu',
#   'lawan',
#   'dengan',
#   'mulutmu',
#   'jika',
#   'tidak',
#   'mampu',
#   'juga',
#   'dengan',
#   'hatimu',
#   'itulah',
#   'selemah',
#   'lemahnya',
#   'iman',
#   'itu',
#   'sudah',
#   'menjadi',
#   'kewajiban',
#   'para',
#   'ulama',
#   'kalo',
#   'yang',
#   'komen',
#   'masih',
#   'ada',
#   'yang',
#   'nyinyir',
#   'ulama',
#   'berarti',
#   'otaknya',
#   'sudah',
#   'disini',
#   'politik'],
#  ['menyarankan', 'menontonnya', 'ya'],
#  ['itulah', 'ceramah', 'yang', 'sebenarnya'],
#  ['besok', 'bugil', 'saja', 'selawat'],
#  ['bedanya',
#   'gus',
#   'miftah',
#   'dengan',
#   'fpi',
#   'hti',
#   'bagaikan',
#   'surga',
#   'dan',
#   'neraka',
#   'di',
#   'surga',
#   'penuh',
#   'kasih',
#   'di',
#   'neraka',
#   'penuh',
#   'penghancuran'],
#  ['kenapa',
#   'di',
#   'tempat',
#   'kerjanya',
#   'mending',
#   'diundang',
#   'ke',
#   'masjid',
#   'ponpes',
#   'aula',
#   'supaya',
#   'berbusana',
#   'yang',
#   'sopan'],
#  ['nah',
#   'ini',
#   'ulama',
#   'benaran',
#   'di',
#   'semua',
#   'jangan',
#   'uas',
#   'malah',
#   'diblokir',
#   'sana',
#   'sini'],
#  ['keren',
#   'saya',
#   'pernah',
#   'dapat',
#   'info',
#   'seperti',
#   'ini',
#   'dari',
#   'keyakinan',
#   'yang',
#   'lain',
#   'tapi',
#   'tujuan',
#   'utama',
#   'kurang',
#   'lebih',
#   'sama',
#   'lah',
#   'kita',
#   'ambil',
#   'sisi',
#   'positifnya',
#   'saja',
#   'terimakasih',
#   'atas',
#   'niat',
#   'baiknya',
#   'saya',
#   'yakin',
#   'pasti',
#   'bermanfaat'],
#  ['hebat',
#   'lanjutkan',
#   'makna',
#   'dakwah',
#   'sebenarnya',
#   'sampaikan',
#   'marwah',
#   'islam',
#   'dengan',
#   'penuh',
#   'kedamaian',
#   'dan',
#   'berikan',
#   'pemahaman',
#   'bukan',
#   'dengan',
#   'kebencian',
#   'dan',
#   'pemaksaan'],
#  ['diskotik', 'syariah', 'jaman dulunya', 'nih', 'mantap'],
#  ['niat',
#   'dan',
#   'tujuan',
#   'yang',
#   'baik',
#   'pasti',
#   'mendapat',
#   'berkah',
#   'dari',
#   'allah',
#   'swt'],
#  ['mantap', 'di', 'gedung', 'dpr', 'perlu', 'juga', 'kayanya', 'gus'],
#  ['salut', 'buat', 'owner', 'klub', 'ini'],
#  ['loh', 'ini', 'baru', 'luar', 'biasa'],
#  ['dapat', 'gratisan', 'karena', 'sudah', 'punya', 'nope'],
#  ['sebaiknya',
#   'dimanapun',
#   'dilakukan',
#   'bahas-bahas',
#   'kesopanan',
#   'tetap',
#   'harus',
#   'dijaga'],
#  ['pemandu',
#   'lagi',
#   'yang',
#   'di',
#   'manga',
#   'besar',
#   'kayaknya',
#   'perlu',
#   'juga',
#   'diajak',
#   'mengaji',
#   'bos'],
#  ['jujur',
#   'ini',
#   'keren',
#   'cara',
#   'menyebarkan',
#   'agama',
#   'yang',
#   'baik',
#   'dan',
#   'ingat',
#   'simpatik',
#   'semoga',
#   'sukses'],
#  ['katimbang',
#   'alim',
#   'kemudian',
#   'jadi',
#   'maling',
#   'menurut',
#   'saya',
#   'lebih',
#   'baik',
#   'maling',
#   'kemudian',
#   'jadi',
#   'alim'],
#  ['sebenar',
#   'ulama',
#   'mengajak',
#   'mereka',
#   'yang',
#   'masih',
#   'tersesat',
#   'untuk',
#   'kembali',
#   'bukan',
#   'menjelekkan',
#   'orang',
#   'lain',
#   'tapi',
#   'merangkul',
#   'mereka'],
#  ['ini', 'namanya', 'apa', 'ya'],
#  ['selamat',
#   'berjuang',
#   'justru',
#   'tempat',
#   'seperti',
#   'itu',
#   'yang',
#   'butuh',
#   'lebih',
#   'banyak',
#   'perhatian',
#   'dari',
#   'ulama'],
#  ['semoga', 'diberikan', 'hidayah'],
#  ['hati',
#   'hati',
#   'termiripkan',
#   'berita',
#   'yang',
#   'mengandung',
#   'isu',
#   'agama',
#   'bisa',
#   'menjadi',
#   'sumber',
#   'fitnah',
#   'dan',
#   'lahan',
#   'para',
#   'bedebah',
#   'yang',
#   'kerjanya',
#   'mengadu',
#   'domba',
#   'anak',
#   'bangsa',
#   'dan',
#   'rakyat',
#   'indonesia',
#   'ahok',
#   'sudah',
#   'jadi',
#   'korbannya'],
#  ['subhanallah',
#   'semoga',
#   'mendapatkan',
#   'hidayah',
#   'dari',
#   'allah',
#   'swt',
#   'amin'],
#  ['ulama', 'mengurus', 'umat', 'berarti', 'jenengan', 'gus'],
#  ['luar',
#   'biasa',
#   'terharu',
#   'mengajak',
#   'orang',
#   'lain',
#   'yang',
#   'dianggap',
#   'salah',
#   'dengan',
#   'cara',
#   'yang',
#   'baik',
#   'bukan',
#   'dengan',
#   'caranya',
#   'biasa'],
#  ['whats', 'up', 'boleh'],
#  ['lol',
#   'jadi',
#   'ketahuan',
#   'dong',
#   'isinya',
#   'boleh',
#   'bali',
#   'bukan',
#   'orang',
#   'bali',
#   'dulu'],
#  ['poligami', 'saja', 'guss'],
#  ['harusnya', 'dibakar', 'tempat', 'begituan', 'kali'],
#  ['alah',
#   'bahasa',
#   'kasihan',
#   'ya',
#   'kalo',
#   'di',
#   'ledeki',
#   'jadi',
#   'ya',
#   'santri',
#   'gaul',
#   'itu',
#   'yang',
#   'suka',
#   'sholawat',
#   'dan',
#   'suka',
#   'dugem',
#   'alah',
#   'rusak',
#   'islam',
#   'di',
#   'biasa-biasa',
#   'seperti',
#   'ini',
#   'ustad',
#   'ya',
#   'datang',
#   'kak',
#   'sono',
#   'dugem',
#   'dulu',
#   'lalu',
#   'sholawat',
#   'lalu',
#   'dugem',
#   'lagi',
#   'dan',
#   'di',
#   'sebut',
#   'santri',
#   'gaul'],
#  ['kenapa',
#   'yang',
#   'kayak',
#   'begini',
#   'berita',
#   'nya',
#   'keluar',
#   'nya',
#   'pas',
#   'mau',
#   'pilpres',
#   'saja',
#   'ya'],
#  ['deh',
#   'ini',
#   'baru',
#   'benar',
#   'ceramah',
#   'atau',
#   'mengajak',
#   'orang',
#   'yang',
#   'belum',
#   'selamat',
#   'untuk',
#   'selamat',
#   'enggak',
#   'kayak',
#   'somat',
#   'mengajak',
#   'orang',
#   'sholawat',
#   'kok',
#   'ke',
#   'orang',
#   'yang',
#   'sudah',
#   'selamat',
#   'ya',
#   'mat'],
#  ['gila',
#   'nekat',
#   'juga',
#   'ulamanya',
#   'enggak',
#   'tau',
#   'di',
#   'usir',
#   'begitu',
#   'tapi',
#   'bagus',
#   'lah',
#   'ada',
#   'keberanian',
#   'dan',
#   'semuanya',
#   'juga',
#   'mendengarkan',
#   'semoga',
#   'banyak',
#   'ustad',
#   'lainnya',
#   'yang',
#   'meniru',
#   'hal',
#   'ini'],
#  ['tambah',
#   'tempat',
#   'mantap',
#   'sak',
#   'cewek',
#   'seksi',
#   'menyadari',
#   'yang',
#   'paling',
#   'penting',
#   'boleh',
#   'yang',
#   'enggak',
#   'setuju',
#   'pasti',
#   'mengiri'],
#  ['mengajak',
#   'orang',
#   'melakukan',
#   'sholawat',
#   'di',
#   'tempat',
#   'ibadah',
#   'ya',
#   'sudah',
#   'pasti',
#   'mudah',
#   'tapi',
#   'mengajak',
#   'orang',
#   'melakukan',
#   'sholawat',
#   'di',
#   'tempat',
#   'dugem',
#   'yang',
#   'penuh',
#   'cobaan',
#   'itu',
#   'sudah',
#   'jelas',
#   'pahala',
#   'nya',
#   'jauh',
#   'lebih',
#   'besar'],
#  ['apa',
#   'sih',
#   'yang',
#   'enggak',
#   'bisa',
#   'di',
#   'negeri',
#   'ini',
#   'semua',
#   'pada',
#   'bisa',
#   'sekarang'],
#  ['boleh', 'ya', 'menyebarkan', 'agama', 'seperti', 'ini'],
#  ['alah', 'lucu', 'lucuan', 'biar', 'masuk', 'tipi', 'dah', 'hahaha'],
#  ['coba',
#   'lah',
#   'ustad',
#   'yang',
#   'lain',
#   'dakwah',
#   'di',
#   'nite',
#   'club',
#   'seperti',
#   'iti'],
#  ['yang',
#   'ini',
#   'malah',
#   'di',
#   'dukung',
#   'yang',
#   'di',
#   'sana',
#   'di',
#   'menjaga',
#   'supaya',
#   'enggak',
#   'ceramah',
#   'apalagi',
#   'ini'],
#  ['ah',
#   'entahlah',
#   'satu',
#   'kau',
#   'maklumi',
#   'yang',
#   'lain',
#   'mengikuti',
#   'tinggal',
#   'tunggu',
#   'saja'],
#  ['mau', 'mengakak', 'takut', 'dosa'],
#  ['kalau',
#   'mau',
#   'melakukan',
#   'ibadah',
#   'perbaiki',
#   'dulu',
#   'penampilan',
#   'jauhi',
#   'miras',
#   'cari',
#   'tempat',
#   'yang',
#   'lebih',
#   'baik',
#   'lebih',
#   'baik',
#   'gus',
#   'kamu',
#   'mengajak',
#   'para',
#   'wanita',
#   'itu',
#   'menutupi',
#   'auratnya'],
#  ['lokalisasi', 'harapan', 'sadar'],
#  ['setelah', 'selawat', 'selesai', 'acara', 'selanjutnya'],
#  ['bagus', 'lanjutkan'],
#  ['bagus',
#   'itu',
#   'biar',
#   'sadar',
#   'islam',
#   'tidak',
#   'mengajari',
#   'kaumnya',
#   'buka',
#   'aurat',
#   'bagus',
#   'lanjut'],
#  ['banser', 'anshor', 'mana', 'suaranya', 'liberal'],
#  ['fan',
#   'itu',
#   'ketika',
#   'simbah',
#   'yang',
#   'bicara',
#   'selalu',
#   'dibully',
#   'karena',
#   'kata',
#   'katanya',
#   'terkesan',
#   'emosional',
#   'nantang',
#   'nantang',
#   'padahal',
#   'ketika',
#   'tantangan',
#   'bisa',
#   'di',
#   'buktikan',
#   'oleh',
#   'yang',
#   'di',
#   'tantang',
#   'terus',
#   'diam',
#   'tidak',
#   'ksatria',
#   'mengaku',
#   'dan',
#   'sering',
#   'menjelek',
#   'jelekkan',
#   'orang',
#   'lain',
#   'inilah',
#   'yang',
#   'jadi',
#   'penyebab',
#   'sering',
#   'di',
#   'bully',
#   'dan',
#   'orang',
#   'lain',
#   'jadi',
#   'enggak',
#   'simpati',
#   'mungkin',
#   'dia',
#   'dengan',
#   'berkata',
#   'seperti',
#   'itu',
#   'merasa',
#   'hebat',
#   'dia',
#   'tidak',
#   'sadar',
#   'saat',
#   'mencari',
#   'pun',
#   'rontok',
#   'saat',
#   'tahun',
#   'tempat',
#   'pun',
#   'keok',
#   'artinya',
#   'rakyat',
#   'enggak',
#   'permasalahkan',
#   'bicara',
#   'dulu',
#   'urusan',
#   'belakang',
#   'seperti',
#   'janji',
#   'jalan',
#   'kaki',
#   'jogja',
#   'jakarta',
#   'terbukti',
#   'enggak',
#   'kan',
#   'ini',
#   'mungkin',
#   'hal',
#   'sepele',
#   'bagi',
#   'dia',
#   'tapi',
#   'itu',
#   'tertanam',
#   'di',
#   'ingatan',
#   'pangling',
#   'berkesimpulan',
#   'kalo',
#   'hanya',
#   'bisa',
#   'mengomong',
#   'tok',
#   'nglakoni',
#   'ora',
#   'iso'],
#  ['karena', 'mendukung', 'jokowi', 'jadi', 'tidak', 'dicopot'],
#  ['banyak', 'orang', 'pekalongan', 'yang', 'termakan', 'hoax'],
#  ['kapan',
#   'hancur',
#   'lebur',
#   'gara-gara',
#   'sih',
#   'amien',
#   'rasis',
#   'terima kasih',
#   'amien',
#   'lanjutkan',
#   'enggak bakal'],
#  ['padahal',
#   'sutrisno',
#   'menaksir',
#   'ini',
#   'dulunya',
#   'merupakan',
#   'penyandang',
#   'dana',
#   'pak',
#   'amin',
#   'rais',
#   'saat',
#   'awal',
#   'reformasi',
#   'akhirnya',
#   'berjalan',
#   'sendiri'],
#  ['orang',
#   'benar',
#   'malah',
#   'tidak',
#   'dipakai',
#   'di',
#   'menghancurkan',
#   'itu',
#   'sudah',
#   'habis-habis',
#   'demi',
#   'kapan',
#   'tapi',
#   'tetap',
#   'tidak',
#   'berdaya',
#   'melawan',
#   'amien',
#   'kasihan',
#   'cahayanya',
#   'semakin',
#   'tidak',
#   'bersinar',
#   'sejak',
#   'amien',
#   'makin',
#   'kumat'],
#  ['lagu', 'lama'],
#  ['kapan', 'sekarang', 'bulat', 'karena', 'ibu-ibu', 'sih', 'amien'],
#  ['karena', 'mendukung', 'jadi', 'tidak', 'dicopot'],
#  ['masak',
#   'sih',
#   'dari',
#   'beberapa',
#   'ex',
#   'pemimpin',
#   'kapan',
#   'yang',
#   'punya',
#   'pikiran',
#   'sehat',
#   'cuma',
#   'pak',
#   'sutrisno'],
#  ['tolong',
#   'dikoreksi',
#   'untuk',
#   'jabatan',
#   'pak',
#   'pramono',
#   'itu',
#   'membelah',
#   'bukan',
#   'mensesneg',
#   'terima',
#   'kasih'],
#  ['mantap',
#   'bukti',
#   'orang',
#   'baik',
#   'pasti',
#   'banyak',
#   'yang',
#   'mendukung',
#   'salam',
#   'ada',
#   'periode'],
#  ['kasih', 'bukan', 'buaya', 'saja', 'orang', 'kayak', 'begini'],
#  ['mantab',
#   'penyebar',
#   'fitnah',
#   'bisa',
#   'tidur',
#   'di',
#   'bui',
#   'juga',
#   'akhirnya'],
#  ['allah',
#   'alhamdulillah',
#   'akhirnya',
#   'para',
#   'ahlul',
#   'fitnah',
#   'penebar',
#   'kebencian',
#   'tersebut',
#   'dipenjara',
#   'juga',
#   'sudah',
#   'cukup',
#   'lama',
#   'mereka',
#   'menunggu',
#   'nikmatnya',
#   'lp',
#   'cipinang'],
#  ['selamat',
#   'menikmati',
#   'hukuman',
#   'dunia',
#   'atas',
#   'prilaku',
#   'fitnah',
#   'menebar',
#   'kebencian',
#   'hukuman',
#   'akhirat',
#   'yang',
#   'lebih',
#   'berat',
#   'menunggu',
#   'anda',
#   'para',
#   'ahlul',
#   'fitnah',
#   'penebar',
#   'kebencian'],
#  ['dasar',
#   'preman',
#   'enggak',
#   'tanggung',
#   'jawab',
#   'kok',
#   'malah',
#   'buron',
#   'katanya',
#   'lu',
#   'anak',
#   'buah',
#   'wowo',
#   'yang',
#   'bocor',
#   'bocor',
#   'itu',
#   'sih'],
#  ['orang',
#   'ganteng',
#   'enggak',
#   'akan',
#   'mengomentari',
#   'berita',
#   'ini',
#   'karena',
#   'sebagian',
#   'tabir',
#   'obor',
#   'rakyat',
#   'sudah',
#   'dibuka',
#   'sebagian',
#   'oleh',
#   'rommy'],
#  ['ayo',
#   'gerombolannya',
#   'kok',
#   'enggak',
#   'ada',
#   'yang',
#   'komentar',
#   'nih',
#   'biasanya',
#   'doa-doa',
#   'bilang',
#   'pelanggaran',
#   'ham',
#   'seperti',
#   'menangkap',
#   'teroris',
#   'pakai',
#   'senjata',
#   'lengkap',
#   'dsb'],
#  ['sik',
#   'asik',
#   'selamat',
#   'menikmati',
#   'hotel',
#   'prodeo',
#   'kawan',
#   'siapa',
#   'menebar',
#   'angin',
#   'dia',
#   'menuai',
#   'badai'],
#  ['buni', 'lagi', 'dimana', 'anda', 'terjawab'],
#  ['wowo', 'enggak', 'sekalian'],
#  ['jangan',
#   'tangkap',
#   'pacarnya',
#   'doang',
#   'tangkap',
#   'pandang',
#   'dana',
#   'dan',
#   'hubungan',
#   'mereka',
#   'dengan',
#   'kandidat',
#   'capres',
#   'yang',
#   'diusung'],
#  ['walaupun',
#   'cuma',
#   'ada',
#   'tahun',
#   'ente',
#   'sudah',
#   'dapat',
#   'gelar',
#   'mantan',
#   'narapidana',
#   'menjelang',
#   'pemilu',
#   'buat',
#   'lagi',
#   'biar',
#   'dikurung',
#   'tahun',
#   'makan',
#   'gratis'],
#  ['gantung', 'az'],
#  ['sekalian', 'buni', 'yani', 'biar', 'adil'],
#  ['kirim', 'ke', 'kamar', 'bonita', 'bonita', 'itu', 'nama', 'macan'],
#  ['gua',
#   'paling',
#   'senang',
#   'lihat',
#   'beginian',
#   'buronan',
#   'sensasinya',
#   'kayak',
#   'di',
#   'film',
#   'hollywood'],
#  ['menunggu',
#   'saja',
#   'nih',
#   'bentar',
#   'lagi',
#   'kubu',
#   'promo',
#   'terutama',
#   'zonk',
#   'bakalan',
#   'komen',
#   'lihat',
#   'saja'],
#  ['karena', 'kabur', 'tambahkan', 'ya', 'hukuman', 'nya'],
#  ['ini', 'kabar', 'terbagus', 'yang', 'boleh', 'kudengar', 'hari', 'ini'],
#  ['telat', 'kabur', 'menongol'],
#  ['mencari',
#   'duit',
#   'dari',
#   'mencebur',
#   'mengeditnya',
#   'buat',
#   'makan',
#   'anak',
#   'terima',
#   'jadi',
#   'apa',
#   'anakmu',
#   'makan',
#   'duit',
#   'begituan'],
#  ['semoga', 'bahagia', 'di', 'rumah', 'yang', 'baru'],
#  ['periksa',
#   'bank',
#   'account',
#   'nya',
#   'atau',
#   'bank',
#   'account',
#   'keluarga',
#   'ada',
#   'transferan',
#   'enggak',
#   'dari',
#   'wowo'],
#  ['semoga',
#   'bisa',
#   'belajar',
#   'untuk',
#   'tidak',
#   'mencari',
#   'nafkah',
#   'dari',
#   'uang',
#   'hitam',
#   'dengan',
#   'cara',
#   'yang',
#   'hitam'],
#  ['suntik', 'mati'],
#  ['sikat',
#   'semua',
#   'orang',
#   'orang',
#   'pengacau',
#   'negeri',
#   'demi',
#   'uang',
#   'apalagi',
#   'mau',
#   'pilpres',
#   'malah',
#   'bikin',
#   'kacau',
#   'negara',
#   'kalo',
#   'enggak',
#   'segera',
#   'ditayangkan'],
#  ['hapuskan',
#   'saja',
#   'jok',
#   'orang',
#   'yang',
#   'gangu',
#   'lu',
#   'jadi',
#   'presiden',
#   'lagi'],
#  ['menunggu',
#   'buni',
#   'yani',
#   'kapan',
#   'ditangkapnya',
#   'padahal',
#   'sudah',
#   'ada',
#   'putusan',
#   'pengadilan',
#   'juga'],
#  ['kok', 'cuma', 'setahun'],
#  ['ah',
#   'bukannya',
#   'kata',
#   'menyambung',
#   'pemred',
#   'obor',
#   'rakyat',
#   'diangkat',
#   'jadi',
#   'neko-neko',
#   'banget',
#   'fitnah',
#   'lagi',
#   'dong'],
#  ['kapan', 'buni', 'yani'],
#  ['sip',
#   'tinggal',
#   'yang',
#   'kabur',
#   'umroh',
#   'enggak',
#   'baik-baik',
#   'segera',
#   'dieksekusi',
#   'pak',
#   'pol'],
#  ['yang',
#   'model',
#   'beginian',
#   'main',
#   'fitnah',
#   'sih',
#   'mesti',
#   'di',
#   'menantang'],
#  ['mantap'],
#  ['sip'],
#  ['semoga', 'pas', 'di', 'dalam', 'penasaran', 'gantung', 'diri'],
#  ['terbukti',
#   'memfitnah',
#   'bukan',
#   'menghina',
#   'dan',
#   'ingat',
#   'fitnah',
#   'lebih',
#   'kejam',
#   'dari',
#   'pembunuhan',
#   'bro'],
#  ['hukuman', 'mati'],
#  ['alhamdulillah', 'sih', 'penebar', 'dosa', 'sudah', 'tertangkap'],
#  ['jokowi',
#   'sudah',
#   'memaafkan',
#   'tapi',
#   'proses',
#   'hukum',
#   'tetap',
#   'berlaku',
#   'bos'],
#  ['hmm'],
#  ['siapa-siapa', 'buat', 'gerombolan', 'micin', 'sama', 'nasi', 'bungkus'],
#  ['tambah', 'hukumannya', 'karena', 'mau', 'kabur'],
#  ['lho', 'kok', 'cuma', 'ada', 'tahun', 'ada', 'tahun', 'pantas', 'kok'],
#  ['yang',
#   'menjamin',
#   'mau',
#   'mem',
#   'back',
#   'up',
#   'mereka',
#   'pada',
#   'kemana',
#   'mau',
#   'menemani',
#   'mereka',
#   'hidup',
#   'bersama',
#   'di',
#   'lp',
#   'cipinang',
#   'jangan',
#   'macam',
#   'ayam',
#   'sayur',
#   'lari',
#   'lintang',
#   'pukang',
#   'meninggalkan',
#   'kawan'],
#  ['gagah',
#   'saat',
#   'bikin',
#   'obor',
#   'rakyat',
#   'mewek',
#   'dan',
#   'buron',
#   'saat',
#   'diproses',
#   'hukum',
#   'dasar',
#   'preman',
#   'mengomong',
#   'kalau',
#   'begini',
#   'apakah',
#   'orang',
#   'yang',
#   'anda',
#   'junjung',
#   'akan',
#   'gantian',
#   'membela',
#   'anda'],
#  ['menggantikan',
#   'kelihatan',
#   'banget',
#   'tebang',
#   'pilihnya',
#   'hukum',
#   'tajam',
#   'ke',
#   'lawan',
#   'politik',
#   'tumpul',
#   'ke',
#   'repot'],
#  ['orangnya',
#   'tambah',
#   'gemuk',
#   'makan',
#   'uang',
#   'sisa',
#   'anggaran',
#   'obor',
#   'rakyat'],
#  ['buset', 'jaman-jamannya', 'tetangga', 'sebelah', 'rumahnya', 'sendiri'],
#  ['bisa', 'jadi', 'wow', 'muncul', 'petromak', 'rakyat', 'kak'],
#  ['kalau',
#   'sudah',
#   'dieksekusi',
#   'enggak',
#   'lagi',
#   'dilindungi',
#   'kan',
#   'sama',
#   'janji',
#   'back',
#   'up',
#   'kalo',
#   'kena',
#   'masalah',
#   'hehehe',
#   'makan',
#   'tuh',
#   'janji',
#   'saat',
#   'kampanye'],
#  ['makan', 'pencarian', 'lu', 'duh'],
#  ['selamat', 'ya'],
#  ['masih', 'kelahirannya', 'mendukung', 'presiden', 'generasi', 'murah'],
#  ['yess',
#   'tidur',
#   'deh',
#   'biar',
#   'cepat',
#   'besok',
#   'ada',
#   'yang',
#   'berani',
#   'taruhan',
#   'siapa',
#   'yang',
#   'membela',
#   'mereka'],
#  ['tukang', 'fitnah', 'hukum', 'sebelum-sebelumnya'],
#  ['harusnya', 'min', 'tahun', 'di', 'sel'],
#  ['nah',
#   'ini',
#   'dia',
#   'paling',
#   'kelahirannya',
#   'habibu',
#   'menongol',
#   'nasi',
#   'bungkus',
#   'micin',
#   'hitungan'],
#  ['cuma', 'ada', 'tahun', 'enak', 'benar'],
#  ['ini',
#   'bodoh',
#   'amat',
#   'cuma',
#   'ada',
#   'bulan',
#   'seharusnya',
#   'jangan',
#   'banding',
#   'malah',
#   'jadi',
#   'ada',
#   'tahun'],
#  ['bos', 'nya', 'sikat'],
#  ['mari',
#   'kita',
#   'tunggu',
#   'siapa',
#   'saja',
#   'yang',
#   'nyinyir',
#   'atas',
#   'penangkapan',
#   'ini'],
#  ['muka-muka', 'tegar', 'menjalani', 'hukuman'],
#  ['bosnya', 'deh', 'ketangkap', 'belum'],
#  ['wowok', 'cs', 'banyak', 'mudarat', 'nya'],
#  ['bravo', 'kejaksaan', 'selamat', 'bertugas'],
#  ['hukum', 'sebenarnya'],
#  ['kalo',
#   'cebong',
#   'mah',
#   'enggak',
#   'di',
#   'tangkap',
#   'kebal',
#   'hukum',
#   'seperti',
#   'viktor',
#   'laiskodat',
#   'adek',
#   'armando',
#   'nathan',
#   'ananda',
#   'sukarlan',
#   'dll',
#   'menggantikan'],
#  ['good',
#   'job',
#   'jangan',
#   'lupa',
#   'gerombolan',
#   'surveyor',
#   'ines',
#   'juga',
#   'harus',
#   'diawasi',
#   'dari',
#   'pada',
#   'menyebarkan',
#   'hasil',
#   'survey',
#   'abal',
#   'abal',
#   'apalagi',
#   'mau',
#   'pilpres',
#   'malah',
#   'bikin',
#   'perpecahan'],
#  ['sudah',
#   'dibongkar',
#   'kan',
#   'sama',
#   'pak',
#   'romi',
#   'pasti',
#   'ada',
#   'memandanginya',
#   'sih',
#   'kejar',
#   'juga',
#   'pak',
#   'justru',
#   'pak',
#   'berjuang',
#   'demi',
#   'bersihnya',
#   'negara',
#   'ini',
#   'dari',
#   'tukang',
#   'fitnah'],
#  ['usut', 'dana', 'nya', 'dari', 'mana', 'itu', 'baru', 'hebat'],
#  ['silakan',
#   'bernyanyi',
#   'denga',
#   'bebas',
#   'walaupun',
#   'semangat',
#   'telah',
#   'gila'],
#  ['kok', 'cuma', 'setahun'],
#  ['ayo',
#   'dong',
#   'polisi',
#   'kalo',
#   'tangkap',
#   'kayak',
#   'begini',
#   'dicari',
#   'tahu',
#   'bosnya',
#   'siapa',
#   'siapa',
#   'yang',
#   'memberi',
#   'dana',
#   'terus',
#   'kalo',
#   'sudah',
#   'tau',
#   'tangkap',
#   'lansung'],
#  ['dipakai', 'saja', 'pak', 'jaksa'],
#  ['tembak', 'jidat', 'nya'],
#  ['tangkap',
#   'bandar',
#   'dan',
#   'pemimpin',
#   'gembong',
#   'kayanya',
#   'biar',
#   'jelas'],
#  ['tukang', 'fitnah', 'plus', 'jaman-jamannya', 'wajib', 'dihukum'],
#  ['sudah',
#   'terbukti',
#   'komplotan',
#   'sana',
#   'cuma',
#   'bisa',
#   'fitnah',
#   'hoax',
#   'pki',
#   'kerjanya',
#   'enggak',
#   'ada'],
#  ['mendingan', 'ditenggelamkan', 'saja'],
#  ['aktor',
#   'intelektual',
#   'yang',
#   'mendanai',
#   'kerja',
#   'obor',
#   'rakyat',
#   'untuk',
#   'kepentingan',
#   'politik',
#   'sang',
#   'aktor',
#   'intelektual',
#   'juga',
#   'harus',
#   'di',
#   'tangkap',
#   'dan',
#   'ditenggelamkan'],
#  ['mau',
#   'bagus',
#   'atau',
#   'garami',
#   'itu',
#   'kepala',
#   'negara',
#   'yang',
#   'harus',
#   'dihargai',
#   'lu',
#   'hina',
#   'ya',
#   'pantaslah',
#   'masuk',
#   'bui'],
#  ['mau',
#   'bagus',
#   'atau',
#   'garami',
#   'itu',
#   'kepala',
#   'negara',
#   'yang',
#   'harus',
#   'dihargai',
#   'lu',
#   'hina',
#   'ya',
#   'pantaslah',
#   'masuk',
#   'bui'],
#  ['mau',
#   'bagus',
#   'atau',
#   'garami',
#   'itu',
#   'kepala',
#   'negara',
#   'yang',
#   'harus',
#   'dihargai',
#   'lu',
#   'hina',
#   'ya',
#   'pantaslah',
#   'masuk',
#   'bui'],
#  ['tukang', 'fitnah', 'dan', 'penyebar', 'hoax', 'tenggelamkan'],
#  ['alah',
#   'ya',
#   'jelas',
#   'sudah',
#   'kembar',
#   'negeri',
#   'dagelan',
#   'yang',
#   'komen',
#   'juga',
#   'lah',
#   'ya',
#   'gila',
#   'wow',
#   'lanjutkan',
#   'saja'],
#  ['terima', 'kasih', 'kejaksaan'],
#  ['pak',
#   'jaksa',
#   'yang',
#   'hina',
#   'pak',
#   'jokowi',
#   'sekali-kali',
#   'pasti',
#   'pak',
#   'jaksa',
#   'tau',
#   'mencolong',
#   'di',
#   'seret',
#   'ke',
#   'penjara',
#   'thanks'],
#  ['sekalipun',
#   'benci',
#   'dengan',
#   'jokowi',
#   'bukan',
#   'berarti',
#   'menebar',
#   'fitnah',
#   'biar',
#   'bagaimanapun',
#   'jokowi',
#   'itu',
#   'presiden',
#   'pilihan',
#   'rakyat',
#   'memfitnah',
#   'presiden',
#   'memfitnah',
#   'rakyat'],
#  ['buron', 'wow'],
#  ['kalo',
#   'di',
#   'turki',
#   'ini',
#   'orang',
#   'sudah',
#   'diciduk',
#   'langsung',
#   'oleh',
#   'erdogan',
#   'presiden',
#   'idaman',
#   'nya',
#   'pks',
#   'ada',
#   'untung',
#   'lah',
#   'di',
#   'indonesia',
#   'ini',
#   'presiden',
#   'nya',
#   'jokowi',
#   'yang',
#   'orang',
#   'nya',
#   'lembut',
#   'dan',
#   'kalem',
#   'ada'],
#  ['kalo', 'dulu', 'menang', 'sudah', 'diangkat', 'menteri', 'nih', 'orang'],
#  ['kalo', 'dulu', 'menang', 'sudah', 'diangkat', 'menteri', 'nih', 'orang'],
#  ['kalo', 'dulu', 'menang', 'sudah', 'diangkat', 'menteri', 'nih', 'orang'],
#  ['kalo', 'dulu', 'menang', 'sudah', 'diangkat', 'menteri', 'nih', 'orang'],
#  ['kalo', 'dulu', 'menang', 'sudah', 'diangkat', 'menteri', 'nih', 'orang'],
#  ['bos', 'nya', 'juga', 'sekalian', 'disikat', 'toilet'],
#  ['bos', 'nya', 'juga', 'sekalian', 'disikat', 'toilet'],
#  ['jadi', 'ingat', 'jaman', 'siapa', 'ya'],
#  ['orang', 'bikin', 'rusak', 'harus', 'musnahkan'],
#  ['super', 'mantap'],
#  ['bangunlah',
#   'diciduk',
#   'sebelum',
#   'dikontrak',
#   'lagi',
#   'sama',
#   'tukang',
#   'fitnah'],
#  ['menjelekkan',
#   'presiden',
#   'sama',
#   'saja',
#   'menghina',
#   'lambang',
#   'negara',
#   'harusnya',
#   'berpikir',
#   'apalagi',
#   'seorang',
#   'redaksi',
#   'berita',
#   'yang',
#   'seharusnya',
#   'menjadi',
#   'panutan',
#   'beritanya'],
#  ['semoga', 'betah', 'di', 'hotel', 'prodeo', 'ya', 'bro'],
#  ['sebaiknya', 'orang', 'seperti', 'ini', 'dilenyapkan', 'saja'],
#  ['sikat', 'ikat', 'berkas'],
#  ['fitnah', 'karena', 'duit', 'ada'],
#  ['tolong', 'dikubur', 'dalam-dalam', 'orang', 'begini'],
#  ['langsung', 'buang', 'saja', 'kelaut'],
#  ['tunggu', 'siapa', 'yang', 'komen', 'membelah', 'itu', 'menontonnya'],
#  ['punya', 'bagaimana'],
#  ['kak',
#   'lama',
#   'sekali',
#   'pelaku',
#   'kejahatan',
#   'hoax',
#   'ini',
#   'baru',
#   'dijebloskan',
#   'ke',
#   'bui',
#   'sekarang',
#   'usut',
#   'dan',
#   'tangkap',
#   'segera',
#   'pelaku',
#   'hoax',
#   'lainnya'],
#  ['obor', 'hoax'],
#  ['bravo', 'kebayanya', 'ada', 'kerjanya'],
#  ['mantap', 'hajar', 'penyebar', 'hoax'],
#  ['yang', 'di', 'negeri', 'sebrang', 'bagaimana'],
#  ['ada', 'tahun', 'pantas', 'kak', 'tahun'],
#  ['itu', 'dulu', 'timses', 'siapa', 'ya'],
#  ['masih', 'bisa', 'gaya', 'gaya', 'an', 'lihat', 'baju', 'mereka', 'seperti'],
#  ['mudah', 'ada', 'an', 'di', 'hukun', 'lebih', 'berat', 'lagi'],
#  ['wow',
#   'syukurlah',
#   'kalian',
#   'banding',
#   'soalnya',
#   'hukuman',
#   'kalian',
#   'bakal',
#   'di',
#   'tambah',
#   'jadi',
#   'kak',
#   'tahun',
#   'menyangka',
#   'kalian'],
#  ['sakit', 'jiwa', 'lucu'],
#  ['sakit', 'jiwa', 'lu'],
#  ['kasihan', 'benar', 'mas', 'eko', 'semoga', 'dapat', 'jalan', 'keluarnya'],
#  ['jahat', 'sekali', 'yang', 'meniru'],
#  ['menyembuhkan', 'saja', 'pengacaranya'],
#  ['nah',
#   'mulai',
#   'terkuak',
#   'biang',
#   'keladinya',
#   'siapkan',
#   'bukti-bukti',
#   'penyerahan',
#   'sehat-sehat',
#   'dan',
#   'tanda',
#   'terima',
#   'uang',
#   'dikasih',
#   'enggak',
#   'waktu',
#   'bantu',
#   'kalo',
#   'enggak',
#   'ada',
#   'bukti',
#   'jangan',
#   'kau',
#   'harap',
#   'bisa',
#   'gugat',
#   'pengacara',
#   'ya'],
#  ['semoga',
#   'dapat',
#   'pengganti',
#   'pengacara',
#   'kondang',
#   'mas',
#   'yang',
#   'kemarin',
#   'itu',
#   'abal',
#   'abal',
#   'punya'],
#  ['kasihan',
#   'mas',
#   'eko',
#   'ini',
#   'biasa-biasa',
#   'dituduh',
#   'lagi',
#   'sama',
#   'cebong',
#   'sebagai',
#   'sebar',
#   'hoax',
#   'karena',
#   'tidak',
#   'ada',
#   'buktinya'],
#  ['yang',
#   'komentar',
#   'pada',
#   'enggak',
#   'tahu',
#   'tentang',
#   'bagaimana',
#   'sertifikat',
#   'dibuat',
#   'sertifikat',
#   'itu',
#   'bisa',
#   'muncul',
#   'kalau',
#   'ada',
#   'akses',
#   'jalan',
#   'suruh',
#   'dia',
#   'tunjukkan',
#   'denah',
#   'sertifikatnya',
#   'kalau',
#   'dia',
#   'memang',
#   'punya',
#   'itu',
#   'pasti',
#   'sertifikatnya',
#   'masih',
#   'gabung',
#   'sama',
#   'sebelah',
#   'kiri',
#   'atau',
#   'sebelah',
#   'kanannya',
#   'dan',
#   'itu',
#   'pasti',
#   'masih',
#   'saudara',
#   'dia',
#   'sertifikatnya',
#   'belum',
#   'dipecah',
#   'sama',
#   'mereka',
#   'berdua'],
#  ['nanti', 'pintu', 'surganya', 'juga', 'diblokade', 'sama', 'tuhan'],
#  ['sudah',
#   'bp',
#   'camat',
#   'yang',
#   'harus',
#   'menyelesaikan',
#   'biar',
#   'tapi',
#   'camat',
#   'dapat',
#   'pahala',
#   'membantu',
#   'yang',
#   'tertindas',
#   'toh',
#   'enggak',
#   'lama',
#   'lagi',
#   'kita',
#   'mati',
#   'dan',
#   'sudah',
#   'tanah',
#   'itu',
#   'tidak',
#   'di',
#   'bawa'],
#  ['saya',
#   'tahun',
#   'kemarin',
#   'beli',
#   'tanah',
#   'kak',
#   'kak',
#   'sama',
#   'tapi',
#   'saya',
#   'bikin',
#   'fondasi',
#   'pagar',
#   'kak',
#   'almarhum',
#   'jadi',
#   'ada',
#   'ada',
#   'meter',
#   'untuk',
#   'akses',
#   'jalan',
#   'setapak',
#   'berarti',
#   'saya',
#   'relakan',
#   'tanah',
#   'saya',
#   'almarhum',
#   'untuk',
#   'kepentingan',
#   'umum',
#   'tetangga',
#   'sebelah',
#   'juga',
#   'demikian',
#   'jadi',
#   'jalan',
#   'setapak',
#   'lebarnya',
#   'ada',
#   'meter',
#   'kita',
#   'kan',
#   'hidup',
#   'bertetangga',
#   'masa',
#   'tanah',
#   'satu',
#   'meter',
#   'saja',
#   'menghalangi',
#   'silaturahmi',
#   'dengan',
#   'tetangga',
#   'jadi',
#   'harus',
#   'dibicarakan',
#   'baiknya',
#   'semua',
#   'bisa',
#   'diatur',
#   'yang',
#   'penting',
#   'dengan',
#   'hati',
#   'nurani'],
#  ['lemah',
#   'mati',
#   'tidak',
#   'ada',
#   'akses',
#   'jalan',
#   'itu',
#   'murah',
#   'harganya',
#   'lah',
#   'ini',
#   'yang',
#   'punya',
#   'tanah',
#   'maruk',
#   'sudah',
#   'deal',
#   'juta',
#   'meminta',
#   'naik',
#   'juta',
#   'jengkel',
#   'di',
#   'tutup',
#   'sekalian',
#   'sama',
#   'tetangga',
#   'yakin',
#   'tuh',
#   'yang',
#   'punya',
#   'tanah',
#   'mati',
#   'pasti',
#   'kolot',
#   'jadi',
#   'dikerjai',
#   'tetangga'],
#  ['kalo',
#   'tidak',
#   'salah',
#   'ada',
#   'undangundang',
#   'pertanahan',
#   'yang',
#   'mengatur',
#   'tentang',
#   'kewajiban',
#   'bagi',
#   'pemilik',
#   'tanah',
#   'dan',
#   'bangunan',
#   'untuk',
#   'memberi',
#   'akses',
#   'jalan',
#   'bagi',
#   'pemilik',
#   'tanah',
#   'dan',
#   'bangunan',
#   'dibelakangnya',
#   'yang',
#   'tidak',
#   'memiliki',
#   'akses',
#   'jalan',
#   'dalam',
#   'sertifikat',
#   'tanahnya',
#   'istilahnya',
#   'tanah',
#   'helikopter',
#   'minimal',
#   'jalan',
#   'setapak',
#   'silakan',
#   'dicek',
#   'saya',
#   'lupa',
#   'pasalnya'],
#  ['tidak',
#   'dikemanakan',
#   'yang',
#   'nutup',
#   'akses',
#   'itu',
#   'maukah',
#   'dia',
#   'diperlakukan',
#   'seperti',
#   'itu',
#   'tanya',
#   'ke',
#   'kupingnya',
#   'dengan',
#   'keras',
#   'maukah',
#   'dia',
#   'diperlakukan',
#   'seperti',
#   'itu',
#   'jika',
#   'berada',
#   'di',
#   'belakang',
#   'rumah',
#   'orang',
#   'lain'],
#  ['sepertinya',
#   'ada',
#   'yang',
#   'kurang',
#   'beres',
#   'dengan',
#   'sertifikatnya',
#   'di',
#   'antara',
#   'rumah',
#   'rumah',
#   'itu',
#   'logikanya',
#   'rtrw',
#   'lihat',
#   'bppn',
#   'waktu',
#   'menerbitkan',
#   'sertifikat',
#   'itu',
#   'pasti',
#   'tahu',
#   'posisi',
#   'dan',
#   'batas',
#   'batas',
#   'rumah',
#   'pasti',
#   'ada',
#   'yang',
#   'salah',
#   'dengan',
#   'sertifikat',
#   'sertifikat',
#   'itu',
#   'tentang',
#   'banget',
#   'tanahnya',
#   'minimal',
#   'ada',
#   'hak',
#   'orang',
#   'yang',
#   'diserobot',
#   'polisi',
#   'harus',
#   'turun',
#   'ini'],
#  ['terasa',
#   'dulu',
#   'imb',
#   'nya',
#   'ada',
#   'enggak',
#   'kalau',
#   'enggak',
#   'ada',
#   'suruk',
#   'satpol',
#   'yang',
#   'bongkar',
#   'jangan',
#   'korbankan',
#   'tetangga'],
#  ['sebelum',
#   'semuanya',
#   'menjadi',
#   'tanpa',
#   'bayangkan',
#   'untuk',
#   'mencari',
#   'siapa',
#   'yang',
#   'salahkan',
#   'diakui',
#   'selama',
#   'ini',
#   'sebagai',
#   'akses',
#   'jalan',
#   'pak',
#   'eko',
#   'ini',
#   'sebenarnya',
#   'memang',
#   'peruntukan',
#   'jalan',
#   'atau',
#   'menggunakan',
#   'melewati',
#   'tanah',
#   'orang',
#   'lain',
#   'memang',
#   'akses',
#   'jalan-jalannya',
#   'jelas',
#   'silakan',
#   'kalo',
#   'itu',
#   'memang',
#   'tanah',
#   'orang',
#   'lainya',
#   'memang',
#   'haknya',
#   'dia',
#   'untuk',
#   'tembok',
#   'salah',
#   'adalah',
#   'pemerintah',
#   'tempat-tempat',
#   'akses',
#   'jalan',
#   'selama',
#   'ini',
#   'yang',
#   'harusnya',
#   'ada'],
#  ['yang',
#   'punya',
#   'tanah',
#   'enggak',
#   'bisa',
#   'salahkan',
#   'segampang',
#   'itu',
#   'haknya',
#   'halo',
#   'dia',
#   'dituntut',
#   'harus',
#   'mengasih',
#   'sebagian',
#   'untuk',
#   'ganteng',
#   'kelihatan',
#   'kan',
#   'belakang',
#   'pak',
#   'eko',
#   'juga',
#   'harus',
#   'dituntut',
#   'hal',
#   'yang',
#   'rupa-rupanya',
#   'dia',
#   'adalah',
#   'dia',
#   'baru',
#   'beli',
#   'kan',
#   'bangun',
#   'sekarang'],
#  ['kasih', 'jalan', 'pahit', 'ladang', 'amal', 'bpk'],
#  ['kalo',
#   'sudah',
#   'deal',
#   'juta',
#   'kok',
#   'ingkar',
#   'jadi',
#   'juta',
#   'ya',
#   'harusnya',
#   'jangan',
#   'serakah',
#   'juga',
#   'ya',
#   'kalo',
#   'memang',
#   'maunya',
#   'juta',
#   'ya',
#   'jangan',
#   'buka',
#   'juta',
#   'entar',
#   'ada',
#   'yang',
#   'mau',
#   'juta',
#   'ingkar',
#   'lagi',
#   'juta'],
#  ['akar', 'masalah', 'nya', 'ada', 'ada', 'duit'],
#  ['ya',
#   'sudah',
#   'tapi',
#   'pak',
#   'eko',
#   'pindah',
#   'saja',
#   'rumah',
#   'lama',
#   'jadikan',
#   'kandang',
#   'ayam',
#   'atau',
#   'studio',
#   'musik',
#   'kan',
#   'haknya',
#   'pak',
#   'eko',
#   'juga',
#   'tapi',
#   'saat',
#   'ketemu',
#   'tetangga',
#   'yang',
#   'enggak',
#   'pedulian',
#   'ya',
#   'sudah',
#   'jadikan',
#   'kita',
#   'enggak',
#   'peduli',
#   'mengalah',
#   'terus',
#   'tidak',
#   'selamanya',
#   'baik'],
#  ['sebenarnya',
#   'siapa',
#   'sih',
#   'yang',
#   'mau',
#   'beli',
#   'siapa',
#   'yang',
#   'mau',
#   'jual',
#   'kok',
#   'keterangan',
#   'camat',
#   'beda',
#   'sama',
#   'eko',
#   'eko',
#   'bilang',
#   'dia',
#   'yang',
#   'mau',
#   'beli',
#   'tanah',
#   'tetangganya',
#   'buat',
#   'jalan',
#   'kata',
#   'camat',
#   'malah',
#   'eko',
#   'yang',
#   'mau',
#   'jual',
#   'malah',
#   'harga',
#   'naik',
#   'pula',
#   'yakin',
#   'ada',
#   'yang',
#   'enggak',
#   'beres',
#   'sama',
#   'sih',
#   'eko'],
#  ['enggak',
#   'pernah',
#   'belajar',
#   'pmp',
#   'mana',
#   'toleransi',
#   'penghargaan',
#   'mengumpat-ngumpat',
#   'dalam',
#   'bertetangga'],
#  ['dulu',
#   'sudah',
#   'mau',
#   'dibeli',
#   'juta',
#   'tapi',
#   'enggak',
#   'jadi',
#   'karena',
#   'naik',
#   'meminta',
#   'juta',
#   'giliran',
#   'dibikin',
#   'tembok',
#   'merengek',
#   'rengek',
#   'mengadu',
#   'kesana',
#   'kamari',
#   'lebay'],
#  ['ujung', 'ujungnya', 'duit'],
#  ['sudah', 'terbaik', 'permasalah', 'nya'],
#  ['camat',
#   'kok',
#   'meminta',
#   'keluar',
#   'dari',
#   'kantor',
#   'kalian',
#   'itu',
#   'hei',
#   'camat',
#   'lurah',
#   'jangan',
#   'orang-orang',
#   'kayak',
#   'kumpeni',
#   'saja',
#   'lu',
#   'pade'],
#  ['jangan',
#   'main',
#   'asal',
#   'mengomong',
#   'menuduh',
#   'salah',
#   'satu',
#   'pihak',
#   'masalah',
#   'ini',
#   'terjadi',
#   'bukan',
#   'karena',
#   'pihak',
#   'yang',
#   'bersengketa',
#   'saja',
#   'ada',
#   'peran',
#   'rt',
#   'rw',
#   'lurah',
#   'camat',
#   'serta',
#   'pihak',
#   'pertanahan',
#   'rencana',
#   'tata',
#   'ruangnya',
#   'mana',
#   'masing-masing',
#   'punya',
#   'andil',
#   'dalam',
#   'terjadinya',
#   'masalah',
#   'ini',
#   'bukan',
#   'serta',
#   'merta',
#   'gara-gara',
#   'pihak',
#   'pak',
#   'eko',
#   'ataupun',
#   'tetangganya'],
#  ['punya',
#   'tanah',
#   'pribadi',
#   'jangan',
#   'dibuat',
#   'jalanan',
#   'nanti',
#   'seburuk-buruk'],
#  ['jadi',
#   'sudah',
#   'jelas',
#   'tapi',
#   'akar',
#   'masalah',
#   'kumbang',
#   'lain',
#   'memangnya'],
#  ['seharusnya',
#   'ke',
#   'pangadilan',
#   'saja',
#   'apapun',
#   'hasilnya',
#   'itu',
#   'yang',
#   'akan',
#   'diakui',
#   'secara',
#   'hukum',
#   'kalau',
#   'curhat',
#   'kemana-mana',
#   'pasti',
#   'hanya',
#   'dapat',
#   'lip',
#   'service',
#   'saja',
#   'karena',
#   'mereka',
#   'hanya',
#   'bisa',
#   'menghimbau'],
#  ['sudah',
#   'mau',
#   'dibeli',
#   'juta',
#   'tapi',
#   'naik',
#   'jadi',
#   'juta',
#   'lagi',
#   'sini',
#   'sudah',
#   'sedikit',
#   'jls',
#   'akar',
#   'masalahnya'],
#  ['kok',
#   'masih',
#   'ada',
#   'ya',
#   'orang',
#   'kayak',
#   'hitungan',
#   'di',
#   'perkampungan',
#   'mending',
#   'di',
#   'kubur',
#   'saja'],
#  ['spekulasi',
#   'itu',
#   'yang',
#   'jadi',
#   'pertanyaan',
#   'ketika',
#   'jual',
#   'beli',
#   'kan',
#   'ada',
#   'form',
#   'tanda',
#   'tangan',
#   'sepengetahuan',
#   'jiran',
#   'kanan',
#   'kiri',
#   'depan',
#   'bilang',
#   'dari',
#   'situ',
#   'sudah',
#   'dapat',
#   'awal',
#   'masalahnya',
#   'kemana',
#   'itu',
#   'pak',
#   'rt',
#   'rw',
#   'kadus',
#   'kan',
#   'kades'],
#  ['kapan',
#   'di',
#   'kasih',
#   'jalan',
#   'juga',
#   'mending',
#   'pindah',
#   'saja',
#   'enggak punya',
#   'tetangga',
#   'kayak',
#   'begitu',
#   'modelnya',
#   'susah',
#   'lihat',
#   'orang',
#   'kesenangan',
#   'lihat',
#   'orang',
#   'susah'],
#  ['kenapa',
#   'setelah',
#   'viral',
#   'di',
#   'medsos',
#   'camat',
#   'nya',
#   'baru',
#   'turun',
#   'tangan',
#   'pak',
#   'eko',
#   'bilang',
#   'sudah',
#   'ada',
#   'tahun',
#   'menyarankan',
#   'untuk',
#   'cari',
#   'solusi',
#   'jadi',
#   'kalau',
#   'ada',
#   'masalh',
#   'seperti',
#   'ini',
#   'mendingan',
#   'di',
#   'silakan',
#   'saya',
#   'cepat',
#   'ditanggapi'],
#  ['ayo', 'pak', 'eko'],
#  ['tetangga',
#   'kayak',
#   'begini',
#   'harus',
#   'buru',
#   'buru',
#   'di',
#   'memandikan',
#   'di',
#   'salahkan',
#   'di',
#   'menyarankan',
#   'dan',
#   'diputuskan',
#   'langsung',
#   'enggak',
#   'ada',
#   'adabnya'],
#  ['enggak bisa', 'masih', 'pak', 'lo'],
#  ['saya',
#   'enggak',
#   'menyebutkan',
#   'kronologi',
#   'karena',
#   'privacy',
#   'hmm',
#   'ada',
#   'yang',
#   'aneh'],
#  ['disini',
#   'banyak',
#   'pendukung',
#   'tetangga',
#   'pak',
#   'eko',
#   'atau',
#   'mungkin',
#   'tetangga',
#   'disitu',
#   'wow'],
#  ['dijual', 'ke', 'tetangga', 'depan', 'samping', 'saja', 'pak'],
#  ['rt',
#   'rw',
#   'lurah',
#   'camat',
#   'bpn',
#   'warung kopi',
#   'bupati',
#   'anjir',
#   'semuanya'],
#  ['mas', 'pak', 'lo'],
#  ['harusnya',
#   'dipikirkan',
#   'sejak',
#   'dini',
#   'kalo',
#   'sudah',
#   'begini',
#   'bingung',
#   'deh',
#   'lu',
#   'rindu',
#   'salah',
#   'lu',
#   'sendiri'],
#  ['kalau',
#   'mau',
#   'jual',
#   'ya',
#   'ke',
#   'tetangganya',
#   'enggak',
#   'usah',
#   'cari',
#   'sensasi',
#   'banyak',
#   'kok',
#   'orang',
#   'lagi',
#   'yang',
#   'rugi',
#   'lebih',
#   'banyak',
#   'untuk',
#   'mengurusi',
#   'tanah',
#   'bahkan',
#   'tanah',
#   'dengan',
#   'surat',
#   'berlapis',
#   'juga',
#   'ada',
#   'toh',
#   'yang',
#   'rugi',
#   'pemilik',
#   'orang',
#   'bpn',
#   'palingan',
#   'hanya',
#   'di',
#   'mutasi',
#   'apalagi',
#   'kalo',
#   'sudah',
#   'pensiun',
#   'enggak',
#   'ada',
#   'sangsi',
#   'apa-apa'],
#  ['ini', 'eko', 'nya', 'yang', 'loh', 'sejak', 'mau'],
#  ['pandang',
#   'sudah',
#   'mengatur',
#   'kalo',
#   'pembangunan',
#   'tidal',
#   'boleh',
#   'menutup',
#   'akses',
#   'jalan',
#   'bagi',
#   'rumah',
#   'atau',
#   'tempat',
#   'tinggal',
#   'yang',
#   'sudah',
#   'ada',
#   'sebelumnya',
#   'mohon',
#   'koreksi',
#   'kalo',
#   'salah'],
#  ['kayak',
#   'nya',
#   'sih',
#   'eko',
#   'ini',
#   'punya',
#   'kelainan',
#   'cara',
#   'bertetangga',
#   'deh'],
#  ['ayo', 'pak', 'lo'],
#  ['pak',
#   'eko',
#   'punya',
#   'imb',
#   'kok',
#   'bisa',
#   'bangun',
#   'rumah',
#   'tanpa',
#   'halaman'],
#  ['solusinya',
#   'ya',
#   'jual',
#   'ke',
#   'tetangga',
#   'depannya',
#   'itu',
#   'pak',
#   'hitung',
#   'harga',
#   'tanah',
#   'saja',
#   'karena',
#   'memang',
#   'rumah',
#   'tanah',
#   'bpk',
#   'di',
#   'block',
#   'sama',
#   'dia',
#   'banyak',
#   'yang',
#   'seperti',
#   'itu',
#   'istilahnya',
#   'lock',
#   'land',
#   'jadi',
#   'memang',
#   'dia',
#   'beli',
#   'atau',
#   'bpk',
#   'bisa',
#   'juga',
#   'beli',
#   'tanah',
#   'didepan',
#   'untuk',
#   'akses'],
#  ['beli',
#   'saja',
#   'tanah',
#   'tetangga',
#   'atau',
#   'jual',
#   'rumahnya',
#   'ke',
#   'tetangganya'],
#  ['ya',
#   'harusnya',
#   'dari',
#   'awal',
#   'pak',
#   'eko',
#   'sudah',
#   'membuat',
#   'jalan',
#   'untuk',
#   'rumahnya',
#   'sendiri',
#   'bukan',
#   'nya',
#   'membuat',
#   'rumah',
#   'full',
#   'bangunan',
#   'tapi',
#   'disisakan',
#   'untuk',
#   'jalan',
#   'hak',
#   'tetangga',
#   'juga',
#   'membuat',
#   'rumah',
#   'di',
#   'tanahnya',
#   'sandiri',
#   'seperti',
#   'yang',
#   'dilakukan',
#   'pak',
#   'eko',
#   'kejadian',
#   'sebenarnya',
#   'masih',
#   'misteri',
#   'siapa',
#   'yang',
#   'salah',
#   'dan',
#   'yang',
#   'benar',
#   'masih',
#   'ibu-ibu'],
#  ['masuk', 'pak', 'eko'],
#  ['tata', 'ruangnya', 'amburadul'],
#  ['sebetulnya',
#   'yang',
#   'paling',
#   'salah',
#   'adalah',
#   'bpn',
#   'karena',
#   'di',
#   'peraturan',
#   'agraria',
#   'beruntung',
#   'hukum',
#   'mengenai',
#   'pemberian',
#   'jalan',
#   'kepada',
#   'tanah',
#   'yang',
#   'tidak',
#   'memiliki',
#   'jalan',
#   'cth',
#   'tanah',
#   'yang',
#   'di',
#   'tengah',
#   'telah',
#   'dibeginikan',
#   'di',
#   'kanan',
#   'dan',
#   'dikiri',
#   'pun',
#   'telah',
#   'bersertifikat',
#   'dan',
#   'menutup',
#   'jalan',
#   'di',
#   'depannya',
#   'juga',
#   'dibuat',
#   'sertifikat',
#   'dan',
#   'menutup',
#   'akses',
#   'yang',
#   'begitu',
#   'sementara',
#   'bilang',
#   'belum',
#   'nah',
#   'ketika',
#   'belakang',
#   'membuat',
#   'sertifikat',
#   'secara',
#   'otomatis',
#   'yang',
#   'belakang',
#   'akan',
#   'dipotong',
#   'tanahnya',
#   'dan',
#   'memberikan',
#   'akses',
#   'jalan',
#   'yang',
#   'ditengah',
#   'cuma',
#   'masyarakat',
#   'banyak',
#   'yang',
#   'awam',
#   'dengan',
#   'peraturan',
#   'tersebut'],
#  ['ketua',
#   'rt',
#   'rw',
#   'lurah',
#   'kok',
#   'pada',
#   'diam',
#   'ayu',
#   'bantu',
#   'warganya',
#   'masa',
#   'kalah',
#   'gantian',
#   'tutup',
#   'jamnya'],
#  ['kemungkinan',
#   'besar',
#   'ada',
#   'yang',
#   'enggak',
#   'beres',
#   'dengan',
#   'proses',
#   'penerbitan',
#   'imb'],
#  ['bisa',
#   'dirundingkan',
#   'lah',
#   'sebelumnya',
#   'ditawari',
#   'tanah',
#   'tetangganya',
#   'tidak',
#   'mau',
#   'ya',
#   'bukan',
#   'salah',
#   'yang',
#   'memblokade',
#   'makanya',
#   'harus',
#   'baik',
#   'baik',
#   'dengan',
#   'tetangga',
#   'dan',
#   'pengurus',
#   'rt',
#   'setempat'],
#  ['tidak',
#   'diperbolehkan',
#   'perda',
#   'membangun',
#   'tapi',
#   'merugikan',
#   'tetangga',
#   'walaupun',
#   'di',
#   'lahan',
#   'sendiri',
#   'biasanya',
#   'jika',
#   'terjadi',
#   'seperti',
#   'itu',
#   'dinas',
#   'pengawasan',
#   'pembangunan',
#   'akan',
#   'bertindak'],
#  ['yuk', 'ya', 'lo'],
#  ['pastinya', 'orang', 'ini', 'bermasalah', 'dengan', 'tetangganya'],
#  ['jual', 'sama', 'yang', 'melarang'],
#  ['silaturahmi',
#   'dengan',
#   'tetangga',
#   'itu',
#   'penting',
#   'walau',
#   'akses',
#   'ditutup',
#   'kalau',
#   'tetangga',
#   'seperti',
#   'saudara',
#   'pasti',
#   'dikasih',
#   'jalan',
#   'tinggal',
#   'ketok',
#   'rumah',
#   'tetangga',
#   'terus',
#   'termasuk',
#   'pak',
#   'maksud'],
#  ['imb', 'bisa', 'keluar'],
#  ['ya',
#   'hak',
#   'tetangga',
#   'juga',
#   'blokade',
#   'jalan',
#   'karena',
#   'mungkin',
#   'itu',
#   'tanah',
#   'tetangga',
#   'harusnya',
#   'di',
#   'masyarakat',
#   'baik-baik',
#   'dengan',
#   'tetangga',
#   'kalo',
#   'kita',
#   'baik',
#   'ke',
#   'tetangga',
#   'enggak',
#   'mungkin',
#   'tetangga',
#   'akan',
#   'semoga',
#   'itu',
#   'memblokade',
#   'jalan'],
#  ['waras', 'selamat', 'pak', 'eko', 'tenang', 'saja', 'gusti', 'tak', 'sare'],
#  ['mana',
#   'kades',
#   'nya',
#   'masa',
#   'ada',
#   'warganya',
#   'yang',
#   'bermasalah',
#   'begini',
#   'enggak',
#   'diselesaikan'],
#  ['surat',
#   'kok',
#   'dilempar',
#   'memangnya',
#   'koran',
#   'meskipun',
#   'benar',
#   'koran',
#   'apa',
#   'sopan',
#   'lempar',
#   'koran',
#   'ke',
#   'presiden',
#   'apa',
#   'enggak',
#   'bisa',
#   'dititipkan',
#   'suratnya',
#   'lewat',
#   'paspampres'],
#  ['ya',
#   'jelas',
#   'dikejar',
#   'hempas',
#   'menggampar',
#   'benda',
#   'seperti',
#   'itu',
#   'ke',
#   'presiden',
#   'itu',
#   'sudah',
#   'tugas',
#   'mereka',
#   'menjaga',
#   'presiden'],
#  ['silau',
#   'mungkin',
#   'juga',
#   'enggak',
#   'benar',
#   'main',
#   'lempar',
#   'surat',
#   'tanpa',
#   'pikir',
#   'kesopanan',
#   'stres',
#   'pak',
#   'eko'],
#  ['tetangga', 'masa', 'begitu'],
#  ['sepertinya',
#   'ada',
#   'yang',
#   'kurang',
#   'beres',
#   'dengan',
#   'sertifikatnya',
#   'di',
#   'antara',
#   'rumah',
#   'rumah',
#   'itu',
#   'logikanya',
#   'rtrw',
#   'lihat',
#   'bppn',
#   'waktu',
#   'menerbitkan',
#   'sertifikat',
#   'itu',
#   'pasti',
#   'tahu',
#   'posisi',
#   'dan',
#   'batas',
#   'batas',
#   'rumah',
#   'pasti',
#   'ada',
#   'yang',
#   'salah',
#   'dengan',
#   'sertifikat',
#   'sertifikat',
#   'itu',
#   'tentang',
#   'banget',
#   'tanahnya',
#   'minimal',
#   'ada',
#   'hak',
#   'orang',
#   'yang',
#   'diserobot',
#   'polisi',
#   'harus',
#   'turun',
#   'ini'],
#  ['wah',
#   'kalo',
#   'saja',
#   'sampai',
#   'ke',
#   'telinga',
#   'jokowi',
#   'pasti',
#   'akan',
#   'buatkan',
#   'flyover'],
#  ['bandung',
#   'jabar',
#   'ada',
#   'gubernur',
#   'baru',
#   'kalau',
#   'yang',
#   'dulu',
#   'memang',
#   'parah',
#   'sekarang',
#   'lapor',
#   'pasti',
#   'di',
#   'menggemaskan',
#   'enggak',
#   'semuasemua',
#   'ke',
#   'presiden',
#   'kali'],
#  ['katanya', 'pak', 'camat', 'tidak', 'tahu'],
#  ['yang',
#   'memblokade',
#   'pasti',
#   'orang',
#   'kuat',
#   'juga',
#   'orang',
#   'penting',
#   'sampai',
#   'camat',
#   'enggak',
#   'bisa',
#   'menyelesaikan'],
#  ['sudah',
#   'bodoh',
#   'mau',
#   'menang',
#   'sendiri',
#   'ini',
#   'problem',
#   'di',
#   'marah-marah',
#   'mengharapkan',
#   'tetangga',
#   'memberikan',
#   'jalan',
#   'sementara',
#   'mereka',
#   'banyak',
#   'yang',
#   'membuat',
#   'rumah',
#   'atau',
#   'pagar',
#   'melebihi',
#   'ukuran',
#   'suka',
#   'tanah',
#   'yang',
#   'dimiliki',
#   'alias',
#   'menyerobot',
#   'tanah',
#   'tetangga'],
#  ['coba', 'ke', 'kopi', 'joni', 'lah'],
#  ['kalau',
#   'semua',
#   'ke',
#   'jokowi',
#   'ya',
#   'enggak',
#   'mungkin',
#   'ada',
#   'jutaan',
#   'masalah',
#   'di',
#   'indonesia',
#   'urutannya',
#   'itu',
#   'bisa',
#   'meminta',
#   'mediasi',
#   'didampingi',
#   'rtrw',
#   'ke',
#   'kelurahan',
#   'kalau',
#   'gagal',
#   'ya',
#   'ke',
#   'kecamatan',
#   'kalau',
#   'enggak',
#   'bisa',
#   'datang',
#   'mediasi',
#   'ya',
#   'tulis',
#   'surat',
#   'resmi',
#   'ke',
#   'kelurahan',
#   'kecamatan',
#   'kotamadya',
#   'kalau',
#   'tidak',
#   'ditanggapi',
#   'bisa',
#   'tulis',
#   'pengaduan',
#   'ke',
#   'ombudsman',
#   'banyak',
#   'kok',
#   'permasalahan',
#   'yang',
#   'sampai',
#   'ke',
#   'ombudsman',
#   'dan',
#   'langsung',
#   'di',
#   'follow',
#   'up',
#   'antara',
#   'berdua',
#   'bulan',
#   'enggak',
#   'usah',
#   'tunggu',
#   'ada',
#   'tahun',
#   'mengajar',
#   'presiden'],
#  ['tapi', 'masih', 'bisa', 'keluar', 'rumah', 'enggak'],
#  ['inilah',
#   'contoh',
#   'manusia',
#   'indonesia',
#   'jaman',
#   'now',
#   'yang',
#   'katanya',
#   'pancasilais',
#   'ternyata',
#   'egois',
#   'tak',
#   'ada',
#   'toleransi',
#   'sedikitpun',
#   'kepada',
#   'sesama',
#   'pada',
#   'sesama',
#   'tetangga',
#   'rt',
#   'rw',
#   'lurah',
#   'nya',
#   'enggak taunya',
#   'walikota',
#   'nya',
#   'gubernur',
#   'nya',
#   'pancasila',
#   'nya',
#   'mana'],
#  ['akalnya',
#   'saja',
#   'kurang',
#   'pintar',
#   'itu',
#   'bikin',
#   'lif',
#   'sampai',
#   'atas',
#   'genteng',
#   'kan',
#   'bisa',
#   'terus',
#   'bikin',
#   'tol',
#   'diatas',
#   'genteng',
#   'sampai',
#   'jalan',
#   'raya',
#   'hehehe'],
#  ['pertamanya',
#   'bagaimana',
#   'hubungan',
#   'barangnya',
#   'kok',
#   'sampai',
#   'tega',
#   'di',
#   'block',
#   'begitu',
#   'kita',
#   'tidak',
#   'tau',
#   'ada',
#   'permasalahan',
#   'apa',
#   'sedangkan',
#   'pak',
#   'eko',
#   'selalu',
#   'bilang',
#   'privacy',
#   'lah',
#   'piye',
#   'tapi'],
#  ['surat',
#   'rumah',
#   'pak',
#   'eko',
#   'ternyata',
#   'enggak',
#   'beres',
#   'pantas',
#   'enggak',
#   'ada',
#   'yang',
#   'bisa',
#   'membela',
#   'karena',
#   'secara',
#   'hukum',
#   'pak',
#   'eko',
#   'melakukan',
#   'pelanggaran',
#   'ternyata',
#   'pak',
#   'eko',
#   'meminta',
#   'simpati',
#   'publik',
#   'padahal',
#   'secara',
#   'hukum',
#   'dia',
#   'bersalah'],
#  ['kenapa',
#   'buat',
#   'rumah',
#   'tidak',
#   'membuat',
#   'akses',
#   'untuk',
#   'jalan',
#   'sendiri',
#   'bearti',
#   'selama',
#   'ini',
#   'mengambil',
#   'jalan',
#   'dari',
#   'tanah',
#   'orang',
#   'lain',
#   'mengambil',
#   'hak',
#   'tetangga',
#   'untuk',
#   'kepentingan',
#   'sendiri'],
#  ['mungkin',
#   'pak',
#   'eko',
#   'disuruh',
#   'bayar',
#   'akses',
#   'jalan',
#   'tapi',
#   'enggak',
#   'mau',
#   'kalo',
#   'seperti',
#   'ini',
#   'ya',
#   'enggak',
#   'akan',
#   'ada',
#   'titik',
#   'temu',
#   'karena',
#   'pemilik',
#   'jalan',
#   'mungkin',
#   'beli',
#   'keseluruhan',
#   'tapi',
#   'pak',
#   'eko',
#   'meminta',
#   'buka-buka',
#   'doang',
#   'tiap',
#   'jengkal',
#   'tanah',
#   'itu',
#   'berharga',
#   'apalagi',
#   'diperkotaan'],
#  ['aneh',
#   'sih',
#   'memang',
#   'kelakuan',
#   'tetangga',
#   'seperti',
#   'ini',
#   'biasanya',
#   'sih',
#   'maaf',
#   'yang',
#   'sering',
#   'model-model',
#   'tutup',
#   'jalan',
#   'tutup',
#   'got',
#   'karena',
#   'itu',
#   'dulu',
#   'tanah',
#   'engkong',
#   'gue',
#   'itu',
#   'dulu',
#   'punya',
#   'babak',
#   'enggak akan',
#   'bukan',
#   'orang',
#   'sunda'],
#  ['salah',
#   'sendiri',
#   'lah',
#   'kenapa',
#   'dulu',
#   'enggak',
#   'dijual',
#   'saja',
#   'tuh',
#   'rumah',
#   'jual',
#   'murah',
#   'saja',
#   'sama',
#   'tetangga',
#   'pakai',
#   'njop',
#   'jangan',
#   'pakai',
#   'harga',
#   'pasar',
#   'dungu',
#   'dipelihara'],
#  ['aparat',
#   'kecamatan',
#   'sama',
#   'desa',
#   'nya',
#   'saja',
#   'yang',
#   'enggak',
#   'becus',
#   'buat',
#   'me',
#   'mediasi',
#   'masalah',
#   'seperti',
#   'itu',
#   'ganti',
#   'langsung',
#   'camat',
#   'sama',
#   'lurah',
#   'nya',
#   'kok',
#   'ada',
#   'masyarakat',
#   'nya',
#   'susah',
#   'enggak',
#   'segera',
#   'di',
#   'bantu',
#   'penyelesaian',
#   'masalah',
#   'nya'],
#  ['mas',
#   'eko',
#   'anda',
#   'harus',
#   'info',
#   'ke',
#   'media',
#   'sewaktu',
#   'anda',
#   'sudah',
#   'melaporkan',
#   'ke',
#   'dinas',
#   'terkait',
#   'bahkan',
#   'sampai',
#   'gubernur',
#   'dan',
#   'tidak',
#   'dibangga-banggakan',
#   'harus',
#   'cerita',
#   'siapa',
#   'saja',
#   'sehingga',
#   'anda',
#   'tidak',
#   'sebar',
#   'foto bareng',
#   'ikut-ikut',
#   'ini',
#   'biar',
#   'ditindak',
#   'bila',
#   'itu',
#   'benar',
#   'tayang',
#   'pernah',
#   'takut'],
#  ['rt', 'rw', 'kelurahan', 'camat', 'enggak', 'becus'],
#  ['sabar',
#   'pak',
#   'eko',
#   'semua',
#   'akan',
#   'di',
#   'selesaikan',
#   'dalam',
#   'hitungan',
#   'jam',
#   'tapi',
#   'di',
#   'tahun',
#   'wow',
#   'setelah',
#   'rezim',
#   'berganti'],
#  ['ah',
#   'aneh',
#   'orang',
#   'lempar',
#   'kertas',
#   'dikejar',
#   'tapi',
#   'orang',
#   'bisa',
#   'nepuk',
#   'jokowi',
#   'waktu',
#   'touring',
#   'motor',
#   'enggak',
#   'diinterogasi',
#   'atau',
#   'dilumpuhkan',
#   'sampaikan',
#   'pencitraan',
#   'atau',
#   'sampainya',
#   'yang',
#   'enggak',
#   'becus',
#   'mengkhayal',
#   'presiden'],
#  ['teu',
#   'memakai',
#   'duit',
#   'mah',
#   'rek',
#   'aya',
#   'anu',
#   'peduli',
#   'kumaha',
#   'atuh',
#   'kang',
#   'sing',
#   'sadar',
#   'weh',
#   'namanya',
#   'urang',
#   'hirup',
#   'di',
#   'nagara',
#   'kos',
#   'kumaha'],
#  ['kelihatannya',
#   'semua',
#   'tanahnya',
#   'sudah',
#   'ber',
#   'sertifikat',
#   'kenapa',
#   'tidak',
#   'di',
#   'pertanyakan',
#   'ke',
#   'badan',
#   'pertanahan',
#   'seharusnya',
#   'tidak',
#   'ada',
#   'penerbitan',
#   'sertifikat',
#   'tanpa',
#   'ada',
#   'jalan',
#   'melalui',
#   'tanah',
#   'tersebut',
#   'kalo',
#   'tidak',
#   'ada',
#   'tanggapan',
#   'dari',
#   'bpn',
#   'maka',
#   'ajukan',
#   'gugatan',
#   'ke',
#   'ptun',
#   'dimana',
#   'bpn',
#   'sebagai',
#   'tergugat',
#   'ada'],
#  ['harusnya',
#   'waktu',
#   'dikejar',
#   'menyarankan',
#   'diri',
#   'saja',
#   'biar',
#   'pak',
#   'jokowi',
#   'tau',
#   'masalahnya',
#   'tapi',
#   'kenapa',
#   'bapak',
#   'lari',
#   'sih',
#   'itu',
#   'kesempatan',
#   'emas',
#   'padahal',
#   'pak'],
#  ['pemerintah', 'bandung', 'enggak', 'becus', 'kerja'],
#  ['ya', 'iyalah', 'main', 'lempar', 'saja'],
#  ['sebenarnya',
#   'masalahnya',
#   'apa',
#   'kenapa',
#   'tidak',
#   'ada',
#   'penyelesaian',
#   'mana',
#   'bupati',
#   'bandung',
#   'kenapa',
#   'diam',
#   'diam',
#   'saja',
#   'meminta',
#   'dipecat'],
#  ['coba',
#   'diselesaikan',
#   'secara',
#   'kekeluargaan',
#   'dengan',
#   'hati',
#   'dingin',
#   'tanpa',
#   'erosi',
#   'insyaallah',
#   'ketemu',
#   'menjalani'],
#  ['aneh',
#   'segitu',
#   'egoisnya',
#   'kah',
#   'ganteng',
#   'rt',
#   'rw',
#   'sama',
#   'lurah',
#   'enggak',
#   'bisa',
#   'tangani',
#   'kah',
#   'mudah-mudahan',
#   'masalah',
#   'ini',
#   'sampai',
#   'ke',
#   'jokowi',
#   'biar',
#   'masalah',
#   'selesai',
#   'sebenarnya',
#   'masalah',
#   'kayak',
#   'begini',
#   'bukan',
#   'urusan',
#   'presiden',
#   'karena',
#   'menyangka',
#   'urusan',
#   'paspampres',
#   'atau',
#   'oknum',
#   'yang',
#   'mengaku',
#   'paspampres',
#   'jadi',
#   'enggak',
#   'ada',
#   'salahnya',
#   'pak',
#   'jokowi',
#   'bantu',
#   'selesaikan',
#   'masalah'],
#  ['sepertinya',
#   'dua',
#   'pihak',
#   'awal',
#   'nya',
#   'sama-sama',
#   'kepala',
#   'batu',
#   'sehingga',
#   'kejadian',
#   'seperti',
#   'itu',
#   'akhirnya'],
#  ['kok',
#   'bisa',
#   'bangun',
#   'rumah',
#   'tapi',
#   'akses',
#   'ke',
#   'jalan',
#   'nya',
#   'enggak',
#   'ada',
#   'pasti',
#   'enggak',
#   'ada',
#   'imb',
#   'nya',
#   'ya'],
#  ['tetangga', 'gila'],
# ...
#   'jasa',
#   'pak',
#   'maruf',
#   'harusnya',
#   'surabaya',
#   'mendukung',
#   'dan',
#   'mengomongnya',
#   'tapi',
#   'karena',
#   'sudah',
#   'kapan',
#   'bawa perasaan',
#   'dan',
#   'sudah',
#   'kapan',
#   'janji',
#   'sama',
#   'prabowo',
#   'walau',
#   'berat',
#   'hati',
#   'ya',
#   'mau',
#   'enggak',
#   'mau',
#   'langsung',
#   'prabowo'],
#  ['ketum', 'demokrat', 'sudah', 'kak', 'ada', 'giginya'],
#  ['nafsu', 'berkuasa', 'ya', 'hahaha'],
#  ['jelas',
#   'bisa',
#   'dimengerti',
#   'rakyat',
#   'papua',
#   'merasakan',
#   'sekali',
#   'apa',
#   'yang',
#   'sudah',
#   'dilakukan',
#   'pres',
#   'jokowi',
#   'diantar',
#   'keadilan',
#   'nyata',
#   'dilakukan',
#   'bukan',
#   'sekedar',
#   'jargon',
#   'politik',
#   'hasilnya'],
#  ['mengomong',
#   'enggak',
#   'kuat',
#   'karena',
#   'kardus',
#   'sudah',
#   'di',
#   'banget',
#   'kelakuan',
#   'politisi',
#   'sontoloyo'],
#  ['coba',
#   'pendapat',
#   'bapak',
#   'ini',
#   'disampaikan',
#   'ke',
#   'junjungan',
#   'apa',
#   'supaya',
#   'enggak',
#   'nyinyir',
#   'beliau',
#   'enggak',
#   'mungkin'],
#  ['ibarat',
#   'bangunan',
#   'mewah',
#   'koalisi',
#   'ini',
#   'sebenarnya',
#   'kepo',
#   'dan',
#   'jauhi',
#   'mau',
#   'mau',
#   'menang',
#   'ini',
#   'mengurus',
#   'intern',
#   'koalisi',
#   'iji',
#   'saja',
#   'enggak',
#   'hidup',
#   'kau',
#   'ada',
#   'periode'],
#  ['anjir',
#   'mantap',
#   'masa',
#   'pks',
#   'dan',
#   'kapan',
#   'saja',
#   'yang',
#   'dapat',
#   'lihatlah',
#   'pada',
#   'jangan',
#   'mau',
#   'dibohongi',
#   'sama',
#   'gerindra',
#   'pks',
#   'dan',
#   'punya'],
#  ['hajar',
#   'boleh',
#   'sikat',
#   'terus',
#   'masa',
#   'cuma',
#   'mereka',
#   'doang',
#   'yang',
#   'dapat',
#   'kardus',
#   'pada',
#   'enggak',
#   'ayo',
#   'jangan',
#   'mau',
#   'tuntut',
#   'juga',
#   'bagian',
#   'kamu'],
#  ['koalisi', 'enggak', 'percuma', 'lo', 'pada', 'beruntung', 'lo', 'semua'],
#  ['mau',
#   'menuding',
#   'dua',
#   'atau',
#   'tiga',
#   'kaki',
#   'juga',
#   'enggak salah',
#   'sayang',
#   'penting',
#   'pks',
#   'sudah',
#   'dapat',
#   'selamat',
#   'berarti',
#   'pertahun',
#   'sebelumnya',
#   'kan',
#   'coba',
#   'kalau',
#   'gandakan',
#   'dari',
#   'hasil',
#   'korupsi',
#   'atau',
#   'pemberian',
#   'jangan-jangan',
#   'di',
#   'ott',
#   'sama',
#   'kpk',
#   'ahirnya',
#   'gigit',
#   'jari',
#   'dong',
#   'kalau',
#   'ini',
#   'kan',
#   'barter',
#   'meskipun',
#   'nantinya',
#   'kalah',
#   'pasti',
#   'kalah',
#   'dalam',
#   'pilpres',
#   'enggak salah',
#   'yang',
#   'rugi',
#   'kan',
#   'bukan',
#   'pks',
#   'atau',
#   'kapan',
#   'paham',
#   'kan',
#   'sekarang',
#   'penting',
#   'duitnya',
#   'gerindra',
#   'sudah',
#   'keluar',
#   'kalau',
#   'ada',
#   'bahasa',
#   'untuk',
#   'kampanye',
#   'itu',
#   'kan',
#   'cuma',
#   'alasan',
#   'saja',
#   'biar',
#   'perebut'],
#  ['ya',
#   'kenyataannya',
#   'semuanya',
#   'main',
#   'ada',
#   'kaki',
#   'dan',
#   'oportunis',
#   'mau',
#   'apa',
#   'lagi'],
#  ['andi',
#   'juga',
#   'aneh',
#   'pakai',
#   'mengomong',
#   'sudah',
#   'jelas',
#   'parte',
#   'kemunafikan',
#   'sejati',
#   'cebong',
#   'cepat-cepat',
#   'gagal',
#   'muka',
#   'on'],
#  ['ya', 'apakah', 'masih', 'percaya', 'dengan', 'komentarnya'],
#  ['kalau', 'panas', 'dalam', 'minum', 'tuh', 'kaki', 'ada', 'biar', 'deh'],
#  ['ketua', 'diam', 'bisa', 'dianggap', 'seru'],
#  ['dah',
#   'mending',
#   'bubar',
#   'saja',
#   'nih',
#   'koalisi',
#   'enggak',
#   'orang tuanya',
#   'bikin',
#   'program',
#   'malah',
#   'ribut',
#   'sendiri',
#   'mending',
#   'bubar',
#   'latihan',
#   'sudah',
#   'pasti',
#   'kalah',
#   'kok',
#   'mengapai',
#   'di',
#   'lanjutkan'],
#  ['membanyaki',
#   'pedas',
#   'dan',
#   'pante',
#   'menyangka',
#   'suaranya',
#   'pemilu',
#   'wow'],
#  ['koalisi', 'serapuh', 'kardus', 'basah'],
#  ['andi',
#   'arief',
#   'yang',
#   'selalu',
#   'menyerang',
#   'koalisi',
#   'sendiri',
#   'ini',
#   'kenapa',
#   'tidak',
#   'ditegur',
#   'surabaya',
#   'ada',
#   'apa',
#   'di',
#   'koalisi',
#   'prabowo',
#   'sandiaga',
#   'padahal',
#   'bersikap',
#   'pura-pura',
#   'netral',
#   'di',
#   'pilpres',
#   'tempat',
#   'sama',
#   'juga',
#   'bermain',
#   'ada',
#   'kaki',
#   'pak',
#   'andi'],
#  ['dulu',
#   'mencari',
#   'makan',
#   'setelah',
#   'menjabat',
#   'jadi',
#   'kata-kata',
#   'bahkan',
#   'daging',
#   'juga',
#   'di',
#   'empat',
#   'penjara',
#   'dan',
#   'akhirnya',
#   'neraka'],
#  ['nah', 'lu', 'kena', 'deh'],
#  ['kardus', 'kardus', 'karismanya', 'bagian', 'garuk-garuk'],
#  ['politik', 'cari', 'makan', 'alias', 'parpol', 'kardus'],
#  ['dia', 'meminta', 'isi', 'kardus', 'itu'],
#  ['badut',
#   'badut',
#   'positif',
#   'pol',
#   'buat',
#   'gayanya',
#   'anjir',
#   'bocor',
#   'sabar'],
#  ['jerawat',
#   'menang',
#   'mudah',
#   'di',
#   'pilpres',
#   'wow',
#   'semangat',
#   'menyangka'],
#  ['jokowi',
#   'menang',
#   'mudah',
#   'di',
#   'pilpres',
#   'wow',
#   'semangat',
#   'menyangka'],
#  ['lebih', 'bagus', 'cap', 'kaki', 'enggak bisa', 'buat', 'kesehatan'],
#  ['kaki', 'mau'],
#  ['salam', 'dua', 'kaki', 'ya'],
#  ['pak',
#   'surabaya',
#   'itu',
#   'kalau',
#   'mengomong',
#   'selalu',
#   'pinjam',
#   'banyak',
#   'moncong',
#   'mas',
#   'kayak',
#   'ban',
#   'bocor',
#   'alus',
#   'tapi',
#   'dilindungi',
#   'baru',
#   'lahir',
#   'ya'],
#  ['kalo',
#   'sudah',
#   'berdasarkan',
#   'data',
#   'dan',
#   'fakta',
#   'ya',
#   'susah',
#   'untuk',
#   'dijawab',
#   'alah'],
#  ['sih',
#   'kho',
#   'senang',
#   'banget',
#   'ribut',
#   'sih',
#   'rebutan',
#   'apa',
#   'lagi',
#   'deh',
#   'ganteng',
#   'datang',
#   'zonk',
#   'ah',
#   'enggak',
#   'papa',
#   'masih',
#   'solid',
#   'kho',
#   'itu',
#   'hanya',
#   'dinamika',
#   'positif',
#   'deh'],
#  ['sesama', 'begundal', 'politik', 'dilarang', 'saling', 'mendahului'],
#  ['karena',
#   'aa',
#   'pakai',
#   'data',
#   'dan',
#   'fakta',
#   'maka',
#   'tidak',
#   'bisa',
#   'berbalas',
#   'pantun'],
#  ['kapan', 'pks', 'sebaiknya', 'diam', 'kalo', 'enggak', 'punya', 'kaca'],
#  ['koalisi',
#   'saja',
#   'ribut',
#   'bagaimana',
#   'mau',
#   'menang',
#   'jargon',
#   'doang',
#   'kencang',
#   'kualitas',
#   'nol'],
#  ['mari',
#   'kita',
#   'bertepuk',
#   'bangsat',
#   'begundal',
#   'sudah',
#   'mulai',
#   'ribut'],
#  ['kayaknya',
#   'benar',
#   'juga',
#   'dulu',
#   'kan',
#   'koalisi',
#   'demokrat',
#   'tapi',
#   'sering',
#   'enggak',
#   'nurut'],
#  ['diam', 'itu', 'emas'],
#  ['lah',
#   'mengapai',
#   'juga',
#   'ibu-ibu',
#   'politik',
#   'pilkada',
#   'kemarin',
#   'juga',
#   'banyak',
#   'koalisi',
#   'mengakak',
#   'politik',
#   'disini',
#   'ya',
#   'begitu',
#   'cari',
#   'sensasi',
#   'doang'],
#  ['bukan',
#   'ada',
#   'kaki',
#   'itu',
#   'mah',
#   'yang',
#   'kita',
#   'tahu',
#   'tapi',
#   'ada',
#   'kaki',
#   'ada',
#   'kaki',
#   'yang',
#   'sah',
#   'ada',
#   'kaki',
#   'yang',
#   'siri',
#   'kan'],
#  ['main',
#   'dua',
#   'kaki',
#   'saat',
#   'pemilu',
#   'sudah',
#   'usai',
#   'bargain',
#   'dan',
#   'kompromi',
#   'lah',
#   'ini',
#   'baru',
#   'mau',
#   'mulai',
#   'haha',
#   'cerdas',
#   'dong',
#   'kamu',
#   'dek'],
#  ['pada',
#   'kapan',
#   'pks',
#   'semua',
#   'ahli',
#   'main',
#   'ada',
#   'kaki',
#   'cuman',
#   'gerindra',
#   'yang',
#   'enggak',
#   'punya',
#   'kaki'],
#  ['andi', 'arief', 'dicari', 'bawaslu', 'tuh'],
#  ['habis',
#   'mau',
#   'bagaimana',
#   'lagi',
#   'enggak',
#   'mau',
#   'rugi',
#   'maunya',
#   'untung',
#   'terus'],
#  ['bertiga', 'saling', 'selingkuh'],
#  ['andi',
#   'arief',
#   'ini',
#   'awalnya',
#   'anak-anak',
#   'meriah',
#   'terkait',
#   'dana',
#   'logistik',
#   'almarhum',
#   'untuk',
#   'kubu',
#   'koalisi',
#   'prabowo',
#   'karena',
#   'demokrat',
#   'tidak',
#   'di',
#   'ajak',
#   'bicara',
#   'sekarang',
#   'diam',
#   'dia',
#   'di',
#   'amankan',
#   'oleh',
#   'sandi',
#   'wajar',
#   'andi',
#   'arief',
#   'ini',
#   'membela',
#   'demokrat',
#   'dan',
#   'surabaya'],
#  ['tepatnya', 'kapan', 'dan', 'pks', 'tergantung', 'bayaran'],
#  ['satu',
#   'koalisi',
#   'saja',
#   'sudah',
#   'enggak',
#   'kompak',
#   'bagaimana',
#   'mau',
#   'menang',
#   'sudah',
#   'pada',
#   'jangan',
#   'ribut',
#   'menikmati',
#   'saja',
#   'dulu',
#   'kata-katanya',
#   'mudah-mudah',
#   'allah',
#   'menghancurkan',
#   'suara',
#   'kalian',
#   'di',
#   'pemilu',
#   'wow'],
#  ['salut',
#   'buat',
#   'timses',
#   'padi',
#   'dinamika',
#   'adalah',
#   'keharusan',
#   'dalam',
#   'sebuah',
#   'perjuangan',
#   'politik',
#   'ada',
#   'perbedaan',
#   'pendapat',
#   'kritik',
#   'juga',
#   'wajar',
#   'saja',
#   'solid',
#   'enggak',
#   'perlu',
#   'harus',
#   'yes',
#   'semua',
#   'diam',
#   'seribu',
#   'bahasa',
#   'seperti',
#   'dikekang',
#   'satu',
#   'suara',
#   'seperti',
#   'koalisi',
#   'jokowi',
#   'yang',
#   'ujung-ujung',
#   'melampiaskan',
#   'aneh-aneh',
#   'dengan',
#   'menyerang',
#   'koalisi',
#   'berbeda-beda',
#   'suara',
#   'bukan',
#   'masalah',
#   'tapi',
#   'saling',
#   'menghargai',
#   'harus',
#   'dijaga',
#   'dekati',
#   'terus',
#   'rakyat',
#   'karena',
#   'ya allah',
#   'yang',
#   'menentukan',
#   'kemenangan',
#   'di',
#   'pilpres',
#   'nanti'],
#  ['hajar'],
#  ['percaya',
#   'kalo',
#   'jokowi',
#   'menang',
#   'kapan',
#   'akan',
#   'merapat',
#   'ke',
#   'jokowi',
#   'lagi',
#   'supaya',
#   'dapat',
#   'mentri',
#   'jangan',
#   'kemarin',
#   'begitu'],
#  ['pada',
#   'main',
#   'dua',
#   'kaki',
#   'di',
#   'parlemen',
#   'habis',
#   'pilpres',
#   'kayanya',
#   'netral',
#   'tapi',
#   'condong',
#   'ke',
#   'kmp'],
#  ['kelompok', 'sebelah', 'pemain', 'ada', 'kaki', 'semua', 'kak'],
#  ['andi', 'arif', 'buang', 'saja', 'bikin', 'rusuh', 'saja'],
#  ['ayo', 'bertengkar', 'lah', 'aku', 'suka', 'hahaha'],
#  ['andi', 'arif', 'kenapa', 'ya'],
#  ['jadi', 'penonton', 'ah', 'menghibur'],
#  ['ular',
#   'beludak',
#   'ini',
#   'keluar',
#   'lagi',
#   'setelah',
#   'sempat',
#   'terkenal',
#   'tidak',
#   'berani',
#   'bicara',
#   'di',
#   'depan',
#   'bawaslu',
#   'duren'],
#  ['sudah',
#   'tahu',
#   'bahwa',
#   'kalau',
#   'berkata',
#   'bohong',
#   'tidak',
#   'sesuai',
#   'omongan',
#   'kalau',
#   'janji',
#   'ingkar',
#   'pengin',
#   'kalau',
#   'dipercaya',
#   'ingkar',
#   'tidak',
#   'konsisten',
#   'tahu',
#   'munafik',
#   'kok',
#   'setuju',
#   'yang',
#   'waras',
#   'siapa',
#   'ya'],
#  ['perempuan',
#   'utama',
#   'di',
#   'pilpres',
#   'wow',
#   'ialah',
#   'jawa',
#   'barat',
#   'jawa',
#   'tengah',
#   'jawa',
#   'timur',
#   'sumatera',
#   'utara',
#   'dan',
#   'sulawesi',
#   'selatan',
#   'jawa',
#   'tengah',
#   'jelas',
#   'sudah',
#   'dijaga',
#   'ganjar',
#   'jawa',
#   'timur',
#   'ada',
#   'mbak',
#   'khofifah',
#   'jawa',
#   'barat',
#   'kemungkinan',
#   'dengan',
#   'naiknya',
#   'rk',
#   'jokowi',
#   'bakal',
#   'menang',
#   'sulawesi',
#   'selatan',
#   'pasti',
#   'ada',
#   'efek',
#   'dari',
#   'jika',
#   'sebagai',
#   'timses',
#   'jokowi',
#   'hanya',
#   'sumatera',
#   'utara',
#   'yang',
#   'masih',
#   'bisa',
#   'diperebutkan',
#   'oleh',
#   'kedua',
#   'koalisi'],
#  ['doang',
#   'orang',
#   'jangan',
#   'di',
#   'pilih',
#   'biar',
#   'negeri',
#   'ini',
#   'tidak',
#   'segera',
#   'bubar'],
#  ['belah', 'sono', 'ribut', 'terus', 'ya'],
#  ['mungkin', 'sedang', 'panas', 'dalam', 'bertambah', 'satu', 'kaki', 'lagi'],
#  ['kalo',
#   'pks',
#   'mah',
#   'memang',
#   'enggak',
#   'ada',
#   'malunya',
#   'ikut',
#   'kabinet',
#   'surabaya',
#   'tapi',
#   'mengakak',
#   'program',
#   'pasien-pasiennya',
#   'saja',
#   'sampai',
#   'makan',
#   'aspal',
#   'di',
#   'jalan',
#   'nangka',
#   'noh'],
#  ['ada', 'hubungannya', 'dengan', 'kardus', 'enggak', 'nih'],
#  ['maling',
#   'teriak',
#   'maling',
#   'koalisi',
#   'kok',
#   'saling',
#   'menjelekkan',
#   'model-model'],
#  ['bagus', 'bro', 'hajar', 'terus'],
#  ['apa',
#   'yang',
#   'diungkapkan',
#   'bung',
#   'andi',
#   'arif',
#   'benar',
#   'sekali',
#   'kita',
#   'masih',
#   'ingat',
#   'waktu',
#   'pks',
#   'ikut',
#   'dalam',
#   'kabinet',
#   'pak',
#   'surabaya',
#   'tapi',
#   'apabila',
#   'ada',
#   'kebijakan',
#   'dari',
#   'surabaya',
#   'selalu',
#   'ditentang'],
#  ['ini',
#   'orang',
#   'dari',
#   'awal',
#   'sudah',
#   'mulai',
#   'ribet',
#   'sebaik',
#   'nya',
#   'kalo',
#   'memang',
#   'enggak',
#   'searah',
#   'pecat',
#   'ini',
#   'apa',
#   'surabaya'],
#  ['pada',
#   'bubar',
#   'saja',
#   'sudah',
#   'enggak',
#   'ada',
#   'wibawa',
#   'di',
#   'mata',
#   'kadernya',
#   'apa',
#   'karena',
#   'waktunya',
#   'enggak',
#   'tegas',
#   'atau',
#   'mungkin',
#   'hal',
#   'yang',
#   'sengaja',
#   'dibuat',
#   'untuk',
#   'main',
#   'dua',
#   'kaki',
#   'alias',
#   'mempraktekan',
#   'politik',
#   'bermuka',
#   'dua'],
#  ['lo',
#   'pade',
#   'mengomong',
#   'mengalir',
#   'ngidul',
#   'enggak',
#   'jelas',
#   'bangsa',
#   'ini',
#   'banyak',
#   'masalah',
#   'perburuhan',
#   'ekonomi',
#   'problem',
#   'kebangsaan',
#   'benturan',
#   'umat',
#   'dll',
#   'perlu',
#   'strong',
#   'leader',
#   'pas',
#   'ok'],
#  ['kuat',
#   'harusnya',
#   'pak',
#   'prabowo',
#   'kirim',
#   'utusan',
#   'mautnya',
#   'kayak',
#   'ahmad',
#   'dhani',
#   'neno',
#   'sarumpaet',
#   'ke',
#   'papua',
#   'wkwkwk'],
#  ['kata-katanya',
#   'pada',
#   'cerdas',
#   'juga',
#   'enggak',
#   'mau',
#   'dijadikan',
#   'boneka',
#   'senang',
#   'cs'],
#  ['yang',
#   'jelas',
#   'perolehan',
#   'suaran',
#   'jokowi',
#   'maruf',
#   'amin',
#   'akan',
#   'tambahkan'],
#  ['kira-kira',
#   'kalau',
#   'di',
#   'adu',
#   'dari',
#   'sisi',
#   'intelektual',
#   'kecerdasan',
#   'kesederhanaan',
#   'kepemimpinan',
#   'kekayaan',
#   'dari',
#   'ada',
#   'kandidat',
#   'capres',
#   'cawapres',
#   'siapa',
#   'yang',
#   'menang',
#   'ya',
#   'gampang',
#   'sandi',
#   'yang',
#   'menang',
#   'muda',
#   'kayak',
#   'pintar',
#   'cerdas',
#   'sederhana',
#   'dan',
#   'yang',
#   'paling',
#   'penting',
#   'setia',
#   'sama',
#   'istri',
#   'dan',
#   'sayang',
#   'anak',
#   'gila',
#   'perfect',
#   'banget',
#   'sih',
#   'lo',
#   'sandi',
#   'yang',
#   'lain',
#   'pada',
#   'main',
#   'bini',
#   'muda',
#   'sama',
#   'selingkuh',
#   'lo',
#   'yang',
#   'duitnya',
#   'banyak',
#   'kok',
#   'malah',
#   'setia',
#   'top'],
#  ['keren'],
#  ['bagi',
#   'kak',
#   'pengurus',
#   'dpd',
#   'demokrat',
#   'di',
#   'papua',
#   'ini',
#   'hati',
#   'nurani',
#   'mereka',
#   'lebih',
#   'punya',
#   'integritas',
#   'karena',
#   'mereka',
#   'tau',
#   'sesungguhnya',
#   'siapa',
#   'yang',
#   'selama',
#   'ini',
#   'bekerja',
#   'untuk',
#   'warganya'],
#  ['rakyat',
#   'papua',
#   'tau',
#   'mana',
#   'presiden',
#   'yang',
#   'perhatian',
#   'dengan',
#   'papua',
#   'mana',
#   'yang',
#   'pura-pura',
#   'perhatian',
#   'btw',
#   'balikin',
#   'jaman dulunya',
#   'sandi'],
#  ['jati',
#   'diri',
#   'enggak',
#   'penting',
#   'ya',
#   'penting',
#   'memegang',
#   'google',
#   'hambalang'],
#  ['memang',
#   'jokowi',
#   'masih',
#   'diinginkan',
#   'sebagian',
#   'besar',
#   'rakyat',
#   'untuk',
#   'menjadi',
#   'presiden',
#   'ada',
#   'periode',
#   'kok'],
#  ['masalah',
#   'papua',
#   'itu',
#   'sangat',
#   'gampang',
#   'dan',
#   'malah',
#   'terlalu',
#   'gampang',
#   'merebut',
#   'suara',
#   'orang',
#   'papua',
#   'sebab',
#   'orang',
#   'papua',
#   'enggak',
#   'dengar',
#   'gubernur',
#   'asal',
#   'di',
#   'serahkan',
#   'sama',
#   'yang',
#   'ahli',
#   'nya',
#   'di',
#   'jamin',
#   'selamat',
#   'beres',
#   'jelas',
#   'bukan',
#   'masalah',
#   'infra',
#   'struktur',
#   'sebab',
#   'yang',
#   'menikmati',
#   'nya',
#   'tetap',
#   'pendatang',
#   'sedangkan',
#   'orang',
#   'asli',
#   'papua',
#   'tetap',
#   'jadi',
#   'penasaran',
#   'pada',
#   'ahli',
#   'nya',
#   'papua',
#   'pasti',
#   'prabowo',
#   'sandi'],
#  ['demokrat',
#   'seharusnya',
#   'join',
#   'dengan',
#   'jokowi',
#   'saja',
#   'tim',
#   'prabowo',
#   'sandi',
#   'enggak',
#   'butuh',
#   'demokrat',
#   'cukup',
#   'merekomendasikan',
#   'saja',
#   'sudah',
#   'pasti',
#   'menang',
#   'di',
#   'wow'],
#  ['woi',
#   'kembalikan',
#   'jaman dulunya',
#   'kalo',
#   'enggak',
#   'selamat',
#   'dukung',
#   'wow'],
#  ['alhamdulillah', 'amin'],
#  ['sebaiknya',
#   'demokrat',
#   'ke',
#   'jokowi',
#   'saja',
#   'tidak',
#   'apa',
#   'apa',
#   'pks',
#   'kapan',
#   'gerindra',
#   'sangat',
#   'solid'],
#  ['harus',
#   'dpd',
#   'tidak',
#   'bisa',
#   'mengatur',
#   'diputuskan',
#   'dpp',
#   'harus',
#   'satu',
#   'komentari',
#   'juga',
#   'ini'],
#  ['demokrat', 'plin', 'plan'],
#  ['karena',
#   'tidak',
#   'terbendung',
#   'suara',
#   'kader',
#   'yang',
#   'terbelah',
#   'berobah',
#   'strategi',
#   'demi',
#   'menutup',
#   'muka',
#   'yang',
#   'sudah',
#   'terima kasih',
#   'demokrat'],
#  ['selamat', 'kakaknya', 'joko', 'wi', 'orang', 'baik'],
#  ['rakyat',
#   'papua',
#   'merasakan',
#   'langsung',
#   'pembangunan',
#   'era',
#   'presiden',
#   'jokowi'],
#  ['hasil', 'akhirnya', 'dan', 'saya', 'yakin', 'jokowi', 'kalah', 'dia'],
#  ['bagus',
#   'jangan',
#   'ikut',
#   'orang',
#   'jahat',
#   'saudara',
#   'papua',
#   'merasakan',
#   'pembangunan'],
#  ['apa', 'kata', 'gerinda', 'cs', 'ya', 'hayo', 'apa'],
#  ['karena', 'papu', 'maju'],
#  ['mbah', 'mien', 'langsung', 'kebanggaan'],
#  ['mereka',
#   'ini',
#   'yang',
#   'benar-benar',
#   'sudah',
#   'merasakan',
#   'langsung',
#   'dampak',
#   'pembangunan',
#   'jalan',
#   'dan',
#   'sebagainya',
#   'di',
#   'sana',
#   'tidak',
#   'bisa',
#   'ditutupi',
#   'dan',
#   'disangkal',
#   'lagi']]

# %%
#Kata singkatan yang tidak ada pada slang corpus dan diolah dengan edit distance
slang_words
# Out:
# ['jagasmua = bagaimana',
#  'tanganmukekuatanmu = ambekan',
#  'disisipin = disini',
#  'umpanin = menyarankan',
#  'nocannya = menontonnya',
#  'beneranditerima = benaran',
#  'kalangankl = jangan',
#  'guslanjutkaninilah = lanjutkan',
#  'jadunya = jaman dulunya',
#  'wkwkwkmantap = mantap',
#  'mantaaappppbuat = mantap',
#  'josshhh = loh',
#  'batas2 = bahas-bahas',
#  'kereennnnnnn = keren',
#  'snagat = ingat',
#  'gusjustru = justru',
#  'memviralkan = termiripkan',
#  'salutterharu = terharu',
#  'cacianluar = caranya',
#  'boshe = boleh',
#  'boshe = boleh',
#  'ud83dude02ud83dude02 = dulu',
#  'begituan = begituan',
#  'hahahaha = alah',
#  'hastag = kasihan',
#  'plesetkan = ledeki',
#  'hahahaha = alah',
#  'biaskan = biasa-biasa',
#  'naaaah = deh',
#  'bersholawat = selamat',
#  'bersholawat = selamat',
#  'bersholawat = selamat',
#  'maaaaat = ya',
#  'nyadan = menyadari',
#  'ngiriweek = mengiri',
#  'hahahaha = alah',
#  'laah = dah',
#  'ngikik = mengakak',
#  'suaranyaormas = suaranya',
#  'ngakui = mengaku',
#  'nyapres = mencari',
#  '2014 = tempat',
#  'percayaseolah = permasalahkan',
#  'oranghingga = pangling',
#  '2019panbakalgurem = enggak bakal',
#  'bakhir = menaksir',
#  'sendiri2 = sendiri',
#  'pansutrisno = menghancurkan',
#  'habis2an = habis-habis',
#  'raispan = kasihan',
#  'butek = bulat',
#  'diobok2 = ibu-ibu',
#  'menseskab = membelah',
#  '2 = ada',
#  'mkan = bukan',
#  'allahuakbar = allah',
#  'hehehhe = sih',
#  'grindong = ganteng',
#  'ngomentari = mengomentari',
#  'koar2 = doa-doa',
#  'yaniiii = lagi',
#  'kejaaarr = terjawab',
#  'pimrednya = pacarnya',
#  'penyadang = pandang',
#  '1 = ada',
#  '10tahun = tahun',
#  'film2 = film',
#  'tungguin = menunggu',
#  'prabocor = promo',
#  'tongkaciann = menongol',
#  'nyebar = mencebur',
#  'fitnahduitnya = mengeditnya',
#  'istrimau = terima',
#  'dikarungin = ditayangkan',
#  'habisin = hapuskan',
#  'laaaahhh = ah',
#  'nasbung = menyambung',
#  'prekom = neko-neko',
#  'bumnwelehwelehitu = banget',
#  'balik2 = baik-baik',
#  'kandangin = menantang',
#  'penjarakedua2nya = penasaran',
#  'siap2 = siapa-siapa',
#  '1 = ada',
#  '5 = ada',
#  'gembeng = mengomong',
#  '2019gantipresiden = menggantikan',
#  'cebong😏 = repot',
#  'dahjamintelnya = jaman-jamannya',
#  'sendirimiris = sendiri',
#  '2019 = wow',
#  '😹😹 = kak',
#  'tuhhhhh = duh',
#  'mudabuaknnya = kelahirannya',
#  'mudapayah = murah',
#  'aaaah = deh',
#  'seberat2nya = sebelum-sebelumnya',
#  '10thn = tahun',
#  'lawyernya = kelahirannya',
#  'getombolan = menongol',
#  'jantungan = hitungan',
#  '1 = ada',
#  '8 = ada',
#  '2 = ada',
#  'seberatberatnya = sebenarnya',
#  '2019gantipresiden😏 = menggantikan',
#  'pendananya = memandanginya',
#  'jaksaterus = justru',
#  'hebat👍 = hebat',
#  'walaupum = walaupun',
#  'sumbangtempat = semangat',
#  'disediakanwkwkwkwkkw = gila',
#  'nangkep2 = tangkap',
#  'disate = dipakai',
#  'hoaxnya = kayanya',
#  'juragannya = jaman-jamannya',
#  'gapresiden = garami',
#  'dihormatikl = dihargai',
#  'gapresiden = garami',
#  'dihormatikl = dihargai',
#  'gapresiden = garami',
#  'dihormatikl = dihargai',
#  'hhahahh = alah',
#  'ketebak = kembar',
#  'blaa = lah',
#  'blaaa = ya',
#  'blaaaa = gila',
#  '😂🤣😂🤣 = wow',
#  'lanjutakan = lanjutkan',
#  'berkali2 = sekali-kali',
#  'lahtolong = mencolong',
#  'bgaimanapun = bagaimanapun',
#  'wkwk = wow',
#  '🤣 = ada',
#  '😁 = ada',
#  'muantap👍👍👍 = mantap',
#  'baguslah = bangunlah',
#  '😆 = ada',
#  'dalam2 = dalam-dalam',
#  'membelanah = membelah',
#  'donaturnya = menontonnya',
#  'buniyani = punya',
#  'kokk = kak',
#  'kejaksaanlumayan = kebayanya',
#  '4 = ada',
#  'pantesnya = pantas',
#  '40 = kak',
#  '2 = ada',
#  'wkwkwkwkwkw = wow',
#  '10 = kak',
#  'nyungsep = menyangka',
#  'luuu = lucu',
#  'nipu = meniru',
#  'sebutin = menyembuhkan',
#  'surat2 = sehat-sehat',
#  'dikasi = dikasih',
#  'entu = bantu',
#  'bisa2 = biasa-biasa',
#  'p = tapi',
#  'runah = sudah',
#  'bawaq = bawa',
#  '20 = kak',
#  '15 = kak',
#  '19 = kak',
#  '15m = almarhum',
#  '1 = ada',
#  '115m = almarhum',
#  '2 = ada',
#  'baikbaik = baiknya',
#  '100jt = juta',
#  '150jt = juta',
#  'berperikemanusiaan = dikemanakan',
#  'u2063sepertinya = sepertinya',
#  'lurahcamat = lihat',
#  'batasbatas = banget',
#  'priksa = terasa',
#  'menjudge = menjadi',
#  'tabayyunsimple = bayangkan',
#  'salahyg = salahkan',
#  'lainklo = lain',
#  'jalantetangganya = jalan-jalannya',
#  'salahtapi = silakan',
#  'menembokyg = tembok',
#  'setempatmana = tempat-tempat',
#  'disalahin = salahkan',
#  'jugamemang = segampang',
#  'diaklo = halo',
#  'jalantetangga = ganteng',
#  'kirikanan = kelihatan',
#  'n = kan',
#  'serupaapesnya = rupa-rupanya',
#  'n = kan',
#  'pakitu = pahit',
#  '100jt = juta',
#  '150jt = juta',
#  '150jt = juta',
#  '100jt = juta',
#  'donkntar = entar',
#  '150jt = juta',
#  '200jt = juta',
#  ' = ada',
#  ' = ada',
#  'benernya = sebenarnya',
#  'pulaini = pula',
#  'toleransisaling = toleransi',
#  'menghargaissopan = penghargaan',
#  'santunempati = mengumpat-ngumpat',
#  '100jt = juta',
#  '150jt = juta',
#  'terbacapokok = terbaik',
#  'minta2 = meminta',
#  'ongkang2 = orang-orang',
#  'diserobotud83dude0b = seburuk-buruk',
#  'masalahnyalain = masalah',
#  'belangnyaud83dude02 = memangnya',
#  'kemana2 = kemana-mana',
#  '100jt = juta',
#  '150jt = juta',
#  'lgdr = lagi',
#  'gitutinggal = hitungan',
#  'blkg = bilang',
#  'n = kan',
#  'klpun = kapan',
#  'pakpunya = enggak punya',
#  'senangsenang = kesenangan',
#  '3 = ada',
#  'mondarmandir = menyarankan',
#  'viralkan = silakan',
#  'spya = saya',
#  'masoook = ayo',
#  'solatin = salahkan',
#  'kafanin = menyarankan',
#  'dikuburin = diputuskan',
#  'masook = masih',
#  'ekooo = lo',
#  'u2063saya = saya',
#  'wkwkww = wow',
#  'walkot = warung kopi',
#  'tidorrrr = anjir',
#  'semuaaaaaa = semuanya',
#  'masssook = mas',
#  'ekoo = lo',
#  'ekoud83dude33ud83dude33ud83dude33 = rindu',
#  'lqin = lagi',
#  'urusan2 = mengurusi',
#  'palingan = palingan',
#  'bodohhh = loh',
#  'awalud83dude06ud83dude06ud83dude06 = mau',
#  'undang2 = pandang',
#  'masooookkkk = ayo',
#  'ekooo = lo',
#  'abu2 = ibu-ibu',
#  'terutuang = beruntung',
#  'disertifikat = dibeginikan',
#  'ditgh = begitu',
#  'blkg = bilang',
#  'kepotong = dipotong',
#  'jlnnya = jamnya',
#  'masuuukkk = yuk',
#  'pakk = ya',
#  'ekoo = lo',
#  'ngeblokade = melarang',
#  'u201cmasuk = termasuk',
#  'ekou201d = maksud',
#  'musyawarahkan = masyarakat',
#  'setega = semoga',
#  'jlan = jalan',
#  'pampapres = hempas',
#  'ngelempar = menggampar',
#  'sifatmu = silau',
#  'instropeksi = stres',
#  'u2063sepertinya = sepertinya',
#  'lurahcamat = lihat',
#  'batasbatas = banget',
#  'dibuatin = buatkan',
#  'beresin = menggemaskan',
#  'kalees = kali',
#  'nyelesaikan = menyelesaikan',
#  'daerah2 = marah-marah',
#  '12 = berdua',
#  '3 = ada',
#  'ngejar2 = mengajar',
#  'camaunya = enggak taunya',
#  'pertanyaanya = pertamanya',
#  'bertetangganya = barangnya',
#  'pantesan = pantas',
#  'knapa = kenapa',
#  'mumgkin = mungkin',
#  'cuma2 = buka-buka',
#  'sihmhn = sih',
#  'gwkan = enggak akan',
#  'ditanggapiada = dibangga-banggakan',
#  'fitnahbiar = foto bareng',
#  'oknum2 = ikut-ikut',
#  'adanyajgn = tayang',
#  '2019 = wow',
#  'hhhh = ah',
#  'paspampressetting = sampaikan',
#  'paspampresnya = sampainya',
#  'ngawal = mengkhayal',
#  'ayeunamah = namanya',
#  '1 = ada',
#  'nyerahin = menyarankan',
#  'jalanyaud83dude0e = menjalani',
#  'paravtetangga = ganteng',
#  'nyampr = sampai',
#  'nyangkut2 = menyangka',
#  'ngaku2 = mengaku',
#  'rmhnya = jamnya',
#  'sehrsnya = harusnya',
#  'apesstressnasib = pedas',
#  'walkot = warung kopi',
#  'nyananti = menyarankan',
#  'kelurahankecwalikota = kebayanya',
#  'tahuteryata = waktunya',
#  'dilaporkanteryata = kelahirannya',
#  'megadu = memegang',
#  'bisa2 = biasa-biasa',
#  'anehsekali = sekali-kali',
#  'dinkmati = menikmati',
#  'uanganya = kakaknya',
#  'p = tapi',
#  'u2063eko = kayak',
#  'u2063semoga = semoga',
#  'ketiadilan = kelihatan',
#  'gituawalnya = tuanya',
#  'gimanabisa = bagaimana',
#  'sepuruh = seluruh',
#  'hhahaha = alah',
#  'berbagilahtoh = berbakti',
#  'seisinyapaling = menyamakan',
#  'kepake = pakai',
#  '2x1 = tak',
#  'segalaasal = segala-galanya',
#  'amplopnya = amplop',
#  'imbgila = sambil',
#  'kuhperd = bawa perasaan',
#  'ditutupwalaupun = ditutupi',
#  'viralkan = silakan',
#  '100 = selamat',
#  '100 = selamat',
#  'angep2 = aneh-aneh',
#  '6 = ada',
#  'akheratnya = syaratnya',
#  'pemdarmh = pemainnya',
#  'bakarntr = bakar-bakari',
#  'rumay = gemas',
#  'ituud83dude01 = itu',
#  'p = tapi',
#  'semenrara = sementara',
#  'bedoa = beda',
#  'p = tapi',
#  'diijabah = dah',
#  'gabener = benar',
#  'ketutup = keju',
#  'setapaknya = segala-galanya',
#  'aparat2 = parah-parah',
#  'lain2 = main-main',
#  'hadewww = aduh',
#  'ajabiar = saja',
#  'lahatnya = lihatnya',
#  'selonjoran = benaran',
#  'pastinyaud83dude00 = cantiknya',
#  'dirubuhin = diputuskan',
#  'sertinya = sepertinya',
#  'didzolimi = idola',
#  'ksalahan = kesalahan',
#  'misalakn = masalah',
#  'menngangu = memegang',
#  'kuburanya = dikuburnya',
#  'teriak2 = meriah',
#  'gietuh = begitu',
#  'ufffcufffc = lucu',
#  'ud83dude01 = duren',
#  'tetanga = memegang',
#  '2 = ada',
#  'ituamiinn = amin',
#  'taulah = enggak usah',
#  'n = kan',
#  'biat = lihat',
#  'ngubur = mencebur',
#  'sertipikat = seketika',
#  'disertipikat = dibeginikan',
#  'perjuangankan = perjuangan',
#  'nyati = mencari',
#  'keranah = karena',
#  'lsolusi = asli',
#  'desisi = disisi',
#  'lamakelamaan = sama',
#  '2 = ada',
#  '7 = ada',
#  'menyang = memegang',
#  'tahak = kak',
#  'mashook = masih',
#  'ditembok = tembok',
#  'blkg = bilang',
#  '2x = tak',
#  'sekalianjgn = sekalian',
#  'temboknyabenci = tembok',
#  'lokasibagaimana = bagaimana',
#  'tolongi = menolong',
#  'obrak = banyak',
#  '1 = ada',
#  'dstrunya = waktunya',
#  'tembuskan = terus-terusan',
#  'mendinga = mending',
#  'pidanakan = mendapatkan',
#  '667 = selamat',
#  'nolong = mencolong',
#  'agamahampuraaa = bagaimana',
#  '1 = ada',
#  'ud83dude02ud83dude02ud83dude02ud83dude02ud83dude02 = rindu',
#  'sertifikat2 = sehat-sehat',
#  '4 = ada',
#  'viralkan = silakan',
#  'ahokmana = bagaimana',
#  'alhamdullih = alhamdulillah',
#  'jokowisama = bisa',
#  'instropeksi = stres',
#  'maaalah = masalah',
#  'nyogok = ayo',
#  'viralkan = silakan',
#  'ngawasin = mengapai',
#  'mustinya = testimoninya',
#  'pidanakan = mendapatkan',
#  'semenamena = berteman',
#  'ud83dude01ud83dude01 = dulu',
#  'egodan = badan',
#  '5 = ada',
#  'sosialini = menyisakan',
#  'baerani = berani',
#  'tersebuttjangan = kesenangan',
#  'janganahh = jangan-jangan',
#  'memag = memegang',
#  'berkerpimanusiaan = pengin',
#  'masalahna = masalah',
#  'nutupna = lucunya',
#  'ngalieuk = mengambek',
#  'tangkurakna = teguran-teguran',
#  'ngaliwat = melihat',
#  'bangpak = bangsat',
#  'bantingkeun = bandingkan',
#  'punyaimb = punya',
#  'baikaamiinsabar = bagaimana',
#  'terblokade = tembok',
#  '10 = kak',
#  'ngebangun = membantu',
#  'antaranusia = menyarankan',
#  'bettetanngga = kelihatannya',
#  'raumah = enggak usah',
#  'biasay = biasa-biasa',
#  'harysnya = harusnya',
#  '60cm = cuma',
#  'budek = bulat',
#  'tetangganyatrus = kebanggaan',
#  'pertanahangmn = penasaran',
#  '73 = bertiga',
#  'murahpakai = durhaka-durhaka',
#  'begitudugaan = sebegitunya',
#  '2 = ada',
#  'meteramal = mereka',
#  'fairsblum = sebelum',
#  'ajapasti = awas',
#  'mempertimbangkan = menyenangkan',
#  'melapang = memegang',
#  'viralin = mengira',
#  'imbnya = jamnya',
#  'yaudah = ya sudah',
#  'servituut = seru',
#  'hukumbagaiman = kuberikan',
#  'p = tapi',
#  'kepakek = pakai',
#  'ngebangun = membantu',
#  'laporin = mendapati',
#  'kedirinya = sendirinya',
#  'manysia2 = manusia',
#  'bihongi = banget',
#  'tempok = tembok',
#  'mgaku = mengaku',
#  'citeurep = tetap',
#  'ttangga = tinggi',
#  'belakangdapur = berangkat',
#  'heraan = pekerjaan',
#  'kmanusian = kasihan',
#  'bdempetan = menyempatkan',
#  'kluarmsk = keluarga',
#  'mentang2 = mentang-mentang',
#  ' = ada',
#  'pikip = sip',
#  'siap2 = siapa-siapa',
#  'nyelesaikannya = menyelesaikan',
#  'penembokan = tembok',
#  'u2063pasal = juga',
#  '667 = selamat',
#  'u201cpemilik = cantik',
#  'tanahtanah = tentang',
#  'pemilikpemilik = memiliki',
#  'diakibatkannyau201d = diakibatkan',
#  'dimana2sejengkal = menyenangkan',
#  'sosialny = soalnya',
#  'mustinya = testimoninya',
#  'mendzalimi = memendam',
#  'mendzalimi = memendam',
#  'mafianya = kakaknya',
#  'pastimasa = pasti',
#  'pertanyaanya = pertamanya',
#  'imbnya = jamnya',
#  'apayang = sayang',
#  'ngebangun = membantu',
#  'belakangpegawai = belanja',
#  'tuatanah = tentang',
#  'sosialpernah = enggak pernah',
#  'ngalami = mengalahkan',
#  'tetanggadia = tengah',
#  'belakangtanah = belanja',
#  'belitapi = kelihatan',
#  'kanginsya = cantiknya',
#  'solusinyaini = sekalinya',
#  'ujiansabar = kebiasaan',
#  'kangterus = memantas',
#  'solusiyakin = memperlihatkan',
#  'solusinyaaamiin = sekalinya',
#  'setega = semoga',
#  'ituketerlaluan = kelakuan',
#  'viralkan = silakan',
#  'tega2nya = tiga-tiganya',
#  'taroin = tahun',
#  'setujubuat = setuju',
#  'kanankiri = nanti',
#  'distarcip = diajari',
#  'bandungterus = banget',
#  'kepolisiandemikian = kelihatan',
#  'sayasalam = saya',
#  '10 = kak',
#  'ngebangun = membantu',
#  'kirikanan = kelihatan',
#  'depanbelakang = melarang',
#  'bossss = mas',
#  'memneli = membela',
#  'jalannnyasetelah = jalan-jalannya',
#  'ngebangun = membantu',
#  'sekalihatinya = melihatnya',
#  'tertutupduniawi = kerudungan',
#  '70 = kak',
#  'kepengadilan = pengin',
#  'dikwalifikasikan = dibeginikan',
#  'semrawutnya = syaratnya',
#  'jelasjelas = jelas',
#  'trdahulu = terlalu',
#  'tawarin = menawari',
#  'mudahmudahan = mudah-mudahan',
#  '100 = selamat',
#  'bijitrus = terus',
#  '50 = kak',
#  '6 = ada',
#  'wakakaka = kakak',
#  'pejabatnyahalo = kebayanya',
#  'disadarkannya = kehadirannya',
#  '667 = selamat',
#  '668 = selamat',
#  'kitaaminnn = amin',
#  '1 = ada',
#  'berkuasasemoga = berkeluarga',
#  '2 = ada',
#  'persenanjasa = mereka',
#  'dijatuhin = diputuskan',
#  'sampingnyaagar = gantengnya',
#  'kasihlah = kasihan',
#  'setapakjahat = tetaplah',
#  'dimusuhin = dimuseumkan',
#  'palingan = palingan',
#  'walkot = warung kopi',
#  'wkwkwkw = wow',
#  'ngandelin = mengantarkan',
#  'jegat = juga',
#  'cicil = sini',
#  'skalian = kasihan',
#  'aizin = amin',
#  'semeteran = benaran',
#  '05 = kak',
#  'ngebangun = membantu',
#  'n = kan',
#  'bersama2 = bersama',
#  'n = kan',
#  'berlembut = perebut',
#  'tjd = tadi',
#  'n = kan',
#  'apkh = apa',
#  'p = tapi',
#  'nytega = mencela',
#  'orang2x = orang-orang',
#  'rmhnya = jamnya',
#  'n = kan',
#  'emanh = memang',
#  'kadang2 = barang-barang',
#  '1 = ada',
#  'knapa = kenapa',
#  'ud83dude2bud83dude2d = terburu-buru',
#  'pemkotnya = pokoknya',
#  'terbengkalaiu3002u3002gawat = mereka',
#  'amatsedih = terima kasih',
#  'laporin = mendapati',
#  'berewajib = jerawat',
#  'kesanyanya = kebayanya',
#  'manusiakan = manusia',
#  'dikasihbjalan = kasihan',
#  '1 = ada',
#  'disalahin = salahkan',
#  'ud83dude02ud83dude02ud83dude02 = rindu',
#  'p = tapi',
#  'laporin = mendapati',
#  'p = tapi',
#  'santaaaii = mantap',
#  'p = tapi',
#  'beseerta = buset',
#  'isi2nya = manis-manisnya',
#  'beresin = menggemaskan',
#  'soalnye = soalnya',
#  'ekomilik = memilih',
#  'tsbtp = tetap',
#  'ngebangun = membantu',
#  'orgnya = orangnya',
#  'hatidi = hati',
#  '60cm = cuma',
#  'viralkanngemeng2 = mengomong',
#  'diem2 = diam',
#  'imbnya = jamnya',
#  'nindas = menetas',
#  'menyadarai = menyadari',
#  'agamajangan = jangan',
#  'waduhjadi = waduh',
#  'imbprofesor = imut',
#  'semuajgn = semua',
#  'jalanjgn = menjalani',
#  'lahkecuali = terkenal',
#  '5 = ada',
#  '1 = ada',
#  'demoapalagi = apalagi',
#  'peehatian = perhatian',
#  'kasihtau = kasihan',
#  'kejem = kali',
#  'sholawatin = menyemangati',
#  '2 = ada',
#  'berpeerikemanusiaan = dikemanakan',
#  'tolongmenolong = menongol',
#  'toleransikang = toleransi',
#  'aregois = menangis',
#  'bangunanbangunan = kangen',
#  'yayg = ya',
#  'pengwasan = pengin',
#  'warung2 = barang-barang',
#  'jalaan = jalan-jalan',
#  'nyerobot = mencerocos',
#  'sadissssadissssadisss = habis',
#  '1 = ada',
#  'kapling2 = maling',
#  'emilllllll = lucu',
#  'ngurung = mengomong',
#  'laba2 = lama-lama',
#  '100 = selamat',
#  'tetangga2nya = tanda-tandanya',
#  'ujuian = juga',
#  'ekoooooo = kepo',
#  'ngusir = mengasih',
#  'sihpadahl = siapa ya',
#  '1 = ada',
#  'sihitu = sehat',
#  'tetangganyaa = kebayanya',
#  'pakorg = orang',
#  'tibatiba = tiga-tiganya',
#  'parahkelakuan = kelakuan',
#  'desanyadan = bedanya',
#  'rumahcoba = mencoba',
#  'aksesnyaperasaan = kebarat-baratan',
#  'izimendirikan = menyindir',
#  'persetujuaan = persatukan',
#  'tetanggajejam = tengah',
#  'dzolimnya = dilihatnya',
#  'rumah2 = mudah-mudah',
#  'perijinannya = kelihatannya',
#  'tenggangrasa = merasa',
#  'hayoooo = ayo',
#  '1966 = wow',
#  'mundurkan = tunjukkan',
#  '2 = ada',
#  'pensiunud83dude00ud83dude00ud83dude01curcol = rindu',
#  'kekepolisian = kelihatan',
#  'jalanpun = menjalani',
#  'busyet = bulat',
#  'dableg = geblek',
#  'nyagak = mengakak',
#  '60cm = cuma',
#  'bersertipikat = termiripkan',
#  'mintakan = minyak-minyakan',
#  'sipenutup = menutup',
#  'ekoooo = ayo',
#  'hakakan = kakak',
#  'pidanakan = mendapatkan',
#  'pidanakan = mendapatkan',
#  'sertipikat = seketika',
#  'distifikat = dibeginikan',
#  'kanankiridepanbelakanh = karismanya',
#  'pemberintah = pembelian',
#  'bangunan2 = jangan-jangan',
#  'camatmasa = sama',
#  'mosok = mohon',
#  'nyengsarakan = penasaran',
#  'disiti = disini',
#  'tatakota = kata-katanya',
#  'pemdanya = pemainnya',
#  'duitnya = duitnya',
#  'yakayana = ya',
#  'tetanggacuiiih = tengah',
#  'sertipikat = seketika',
#  'sertipikat = seketika',
#  'sertipikat = seketika',
#  'sertipikat = seketika',
#  'ngalamin = mengalahkan',
#  'sbeelum = sebelum',
#  '5thn = tahun',
#  'laintutup = lanjutkan',
#  'murahtp = murah',
#  'giladinegeri = didengarkan',
#  'berketuhanan = benaran',
#  'yangmaha = menyangka',
#  'gilaharusnya = seharusnya',
#  'wkwkwkkirain = mengira',
#  'keingetan = teringat',
#  'capeee = cape',
#  '1t = kita',
#  'pulitik = pula',
#  'abadijadi = badai',
#  'begithuu = begitu',
#  '5 = ada',
#  '2019 = wow',
#  'lagian = latihan',
#  'mentingkan = cantikan',
#  'digadang2 = barang-barang',
#  'nyapres = mencari',
#  '2024 = tahun-tahun',
#  'wowosandi = woy',
#  'dimanamana = bagaimana',
#  'opini2 = pengin',
#  'apaapa = apa',
#  'mungkiiiin = mungkin',
#  'ud83dude02 = model-model',
#  'zombi2 = sambil',
#  'dlk = dulu',
#  'dikadalin = dikata-katai',
#  'sihhhbuaya = sih',
#  'dikadalin = dikata-katai',
#  'nyonyah = kayanya',
#  'berpolitikdan = membelikan',
#  'tausiapa = kasihan',
#  'pilpreslagian = pembelian',
#  'ud83dude01 = duren',
#  'nihsalut = lihat',
#  '2 = ada',
#  '2019 = wow',
#  '500m = almarhum',
#  'kalahin = salahkan',
#  'hahahaha = alah',
#  'kecerdasanya = keadaannya',
#  'buanyak = banyak',
#  'omonganya = mengomongkan',
#  'ektabilitasnya = karismanya',
#  'naik2 = baik-baik',
#  'jawabanmu = jawabannya',
#  'lahkalau = pahalanya',
#  'peragujd = peragakan',
#  '1 = ada',
#  'tmasuk = termasuk',
#  'tgkt = tengok',
#  '2 = ada',
#  'pertanggungjawabkan = permasalahkan',
#  'mahar500m = mahal',
#  'nyalonin = menyarankan',
#  'perlu2 = seru-seru',
#  'baguslah = bangunlah',
#  'parlentary = bentar',
#  'sgat = sangat',
#  '2 = ada',
#  '2 = ada',
#  'hahahaha = alah',
#  'teraniyaya = bedanya',
#  '2014 = tempat',
#  '2019 = wow',
#  'ngumpulin = mengurusi',
#  'duitnya = duitnya',
#  '500m = almarhum',
#  '1t = kita',
#  'orangnyamatilah = mengamati',
#  'abalabal = apa',
#  'karduss = terus',
#  'berjilid2 = berpikir',
#  'luardalam = warna',
#  'gerindong = senang',
#  'sihingat = semangat',
#  '2 = ada',
#  'mngabaikan = digantikan',
#  'ekoperhitungan = ketergantungan',
#  '2019 = wow',
#  'hihisdh = hidayah',
#  'haragailah = menghargai',
#  'demohrat = sehat',
#  'fekaes = menetas',
#  'gerindrapernah = enggak pernah',
#  'pernahkarena = pernikahan',
#  '2 = ada',
#  'wakakakkakamantap = kakak',
#  'dahmusuh = kamu',
#  '1 = ada',
#  'mati2an = mati-matian',
#  'caprescawapres = cape',
#  'aplg = pulang',
#  'memimpinyg = admin',
#  'kadang2 = barang-barang',
#  'ud83dude04 = duren',
#  'gantiketuaumumpd = gantengku',
#  'betulsaat = kebetulan',
#  'kampanyekasihan = terima kasih',
#  'pendukungbisabisa = mendukung',
#  'cawapresnya = pacarannya',
#  'nyiyir = menyindir',
#  'nyungsep = menyangka',
#  'ngangkat = menyangka',
#  'josspak = juga',
#  'andidia = sendiri',
#  'menangdia = memegang',
#  'drps = daripada',
#  'semuacuman = semua',
#  'knapa = kenapa',
#  'skalian = kasihan',
#  'p = tapi',
#  'paksaya = memaksa',
#  'huahahapada = gua',
#  'apaapa = apa',
#  'colapsnya = jalan-jalannya',
#  '2 = ada',
#  'jongosnya = menontonnya',
#  'nyapres = mencari',
#  '2 = ada',
#  '25 = kak',
#  'gembosin = menggemaskan',
#  'gerindera = benar-benar',
#  'pksmereka = mereka',
#  'koalisilihat = kali',
#  'gerindera = benar-benar',
#  'apa2u263a = apa-apanya',
#  'bropks = brondong manis',
#  'gerindrongyg = merinding',
#  'kardusnya = jaman dulunya',
#  'bossoal = bosan',
#  'nyungsep = menyangka',
#  'blakanganyg = bayangkan',
#  'kardusnya = jaman dulunya',
#  '2019 = wow',
#  'u2018mengapau2019 = mendapatkan',
#  'depankenapa = kapan-kapan',
#  '2019 = wow',
#  'lemah2 = lama-lama',
#  'gerinderaya = sebenarnya',
#  'prabowimending = rekomendasikan',
#  'gerindera = benar-benar',
#  'nanggung2u263a = tanggung-tanggung',
#  'ngandalin = mengadakan',
#  'menjauhfekaes = menjelekkan',
#  'gaknpunya = enggak punya',
#  'jelaspaling = jelas',
#  'kader2 = adek-adek',
#  'dinana = dia',
#  'kader2 = adek-adek',
#  'nyinyirannya = nyinyir',
#  'fekaesjadi = sekarang',
#  'tenggelamditahun = tengah',
#  '2019 = wow',
#  'sandiagaato = sangat',
#  'apakoalisi = apalagi',
#  'ributyg = meributkan',
#  '500 = selamat',
#  '2 = ada',
#  'ketumnya = waktunya',
#  'nolak = indak',
#  'jdnya = jamnya',
#  'inidasar = indah',
#  'kardusud83dude0e = kerudungan',
#  'yyaaaa = ya',
#  'biasalah = biasa',
#  'didaun = badan',
#  'nyerup = mencebur',
#  'yyaaaa = ya',
#  '2 = ada',
#  'konpensasi = konten-konten',
#  'dahitu = begitu',
#  '1t = kita',
#  'beresin = menggemaskan',
#  '1 = ada',
#  '2 = ada',
#  'mingkem = ingat',
#  'duitanpolitisi = disini',
#  'kropos = kepo',
#  'dilihatpikiran = dipikirkan',
#  'ud83dude05 = duren',
#  'ketumnya = waktunya',
#  'matau201d = mau',
#  'ud83dudc4eud83cudffbud83dudc4eud83cudffb = rindu',
#  'sbysebenarnya = sebenarnya',
#  'sebelahbeda = sebelumnya',
#  'jenisdan = kelihatan',
#  'dikapling = diapakan',
#  'pekaesgerindera = penasaran',
#  'pangaknada = bangsat',
#  'berkurangbkursi = bungkuskan',
#  'parnokokita = pokoknya',
#  'demokrattapi = kebarat-baratan',
#  '5 = ada',
#  'imbangbukannya = mangkanya',
#  'daerah2 = marah-marah',
#  'u263a = juga',
#  'demokratdrpd = berarti',
#  'rempongsuaranya = orang tuanya',
#  'loyocukup = lucu',
#  'pkspan = kapan',
#  'n = kan',
#  'kahhihihihi = lah',
#  'tendangemang = kedengaran',
#  'ud83eudd14ud83eudd14ud83eudd14ud83eudd14ud83eudd11ud83eudd11ud83eudd11ud83eudd11u2620ufe0fu2620ufe0fu2620ufe0fu2620ufe0f = mati',
#  'kadul = kabul',
#  'beyek = benar',
#  'gontok2an = menonton',
#  'diperlihatkn = kelihatan',
#  'hahahahaa = ya',
#  'jadiijtimak = cantik',
#  'sia2 = sama-sama',
#  'karduss = terus',
#  'prabosan = perawatan',
#  '1 = ada',
#  'parpolnyatp = pacarnya',
#  'taudah = sudah',
#  'nyeberang = menyerang',
#  'palingan = palingan',
#  'lunglung = langsung',
#  'bocorbocorrrr = cocok',
#  'gerindrong = senang',
#  'dehalias = terbalas',
#  '2019prabowosandiuno = pelampiasan',
#  'habin = hati-hati',
#  'puyuono = ayo',
#  'habiburohman = menghancurkan',
#  'bhuahahahaha = bacalah',
#  'ud83dude02ud83dude02 = dulu',
#  'kacianya = kakaknya',
#  'zonkgara2 = gara-gara',
#  'merataakhirnya = perasaannya',
#  'ketumnya = waktunya',
#  'uangkader = banget',
#  'sendiridaripada = sendiri',
#  'situasitentunya = pasien-pasiennya',
#  'warganyamemang = warna',
#  'pandaikalau = padahal',
#  'sebutin = menyembuhkan',
#  'omongane = mengomongkan',
#  'hadew = aduh',
#  'menghalal = pengalaman',
#  '2019prabowosandiuno = pelampiasan',
#  'dipapua = dia',
#  'dikitkok = diakibatkan',
#  'minatnyaud83dude04ud83dude04ud83dude04 = rindu',
#  'kdekatan = kelihatan',
#  'mndukung = mendukung',
#  'mngusungnya = mengomongnya',
#  'kplang = kapan',
#  'kplang = kapan',
#  'mngusung = langsung',
#  'kagak = kak',
#  'disanaprinsip = diantar',
#  '2019orangbaikhasilnyabaik = hasilnya',
#  'embat = banget',
#  'bapakar = apa',
#  'nyinyirkata = nyinyir',
#  'kropos = kepo',
#  'rapuhgmn = jauhi',
#  'bisahidup = hidup',
#  'jkw = kau',
#  '2 = ada',
#  'hahahahaseru = anjir',
#  'nehmantap = mantap',
#  'sikatlah = lihatlah',
#  'panhahaha = punya',
#  'kardusmu = kamu',
#  'mutupercuma = percuma',
#  'eker2nyungsep = beruntung',
#  'gamasalah = enggak salah',
#  'bosyg = sayang',
#  '500 = selamat',
#  'mberarti = berarti',
#  '100mlumayan = sebelumnya',
#  'ngandalkan = gandakan',
#  'gamasalah = enggak salah',
#  'sekarangyg = sekarang',
#  ...]
